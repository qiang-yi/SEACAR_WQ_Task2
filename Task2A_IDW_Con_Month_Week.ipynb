# %% [markdown]
# # Cross Validation for IDW Interpolation
# ## Task 2A (continuous)
#
# This document includes Python codes that conduct cross validation (CV) for Inverse Distance Weighting (IDW) Interpolation on water quality parameters, including 4 water quality parameters in arcpy environment:
# - Dissolved oxygen (DO_mgl)
# - Salinity (Sal_ppt)
# - Turbidity (Turb_ntu)
# - Temperature (T_c)
#
# The analysis is conducted in the separate water bodies:
# - Guana Tolomato Matanzas (GTM)
# - Estero Bay (EB)
# - Charlotte Harbor (CH)
# - Biscayne Bay (BB)
# - Big Bend Seagrasses (BBS)
#
# **Tasks:**
#
# - Task 2A Calculate the RMSE and Mean Error (ME) for IDW results using both continuous and discrete data
#
# - **Task 2B Calculate the RMSE and Mean Error (ME) for IDW results using continuous data.**
#
#
# **Monthly: The SEACAR team would like the USF team to define their months as six 30-day
# increments prior to the storm day, and then six 30-day increments following the storm day.**
#
# **Weekly: The SEACAR team would like the USF team to define their weeks as 26 7-day
# increments prior to the storm day, and then 26 7-day increments following the storm day**
#
# **Contents:**
# * [1. Data Preprocess](#reg_preprocessing)
#     * [1.1 Subsetting Dataset](#reg_subset)
#     * [1.2 Preview Dataset](#reg_preview)
#     * [1.3 Fill Unique ID](#reg_id)
# * [2. Create Shapefile](#reg_create_shp)
# * [3. Cross Validation for IDW](#reg_cv_idw)
# * [4. Monthly Results](#month)

# %%
import pandas as pd
import numpy as np
import arcpy
from arcpy.sa import *
import os
import math

import importlib
import sys
#path = r'M:\2024\WQ\Spring\IDW\git\misc'
path = r'F:\SEACAR_WQ_2024\git\misc'
sys.path.insert(0, path)
import idw_rk
importlib.reload(idw_rk)

import pyproj

# define scratch folder to avoid overwritting from parallel threats
arcpy.env.scratchWorkspace = r"F:\SEACAR_WQ_2024\scratch/IDW_con"

# %% [markdown]
# # 1. Data Preprocessing <a class="anchor" id="reg_preprocessing"></a>

# %%
gis_path = r'F:\SEACAR_WQ_2024/GIS_Data/'
dfCon = pd.read_csv(gis_path + 'OEAT_Continuous_WQ-2024-Jan-16.csv', low_memory=False)

# %% [markdown]
# ## 1.1 Subsetting Data <a class="anchor" id="reg_subset"></a>

# %% [markdown]
# ### Include the time period from 9 am to 17 pm in a day

# %%
area_shortnames = {
    'Guana Tolomato Matanzas': 'GTM',
    'Estero Bay': 'EB',
    'Charlotte Harbor': 'CH',
    'Biscayne Bay': 'BB',
    'Big Bend Seagrasses':'BBS'
}

param_shortnames = {
    'Salinity': 'Sal_ppt',
    'Total Nitrogen': 'TN_mgl',
    'Dissolved Oxygen': 'DO_mgl',
    'Turbidity':'Turb_ntu',
    'Secchi Depth':'Secc_m',
    'Water Temperature':'T_c'
}

# %%
dfCon['SampleDate'] = pd.to_datetime(dfCon['SampleDate'], format='%b %d %Y %I:%M%p')

# %%
# Include date from 9:00 am to 17:00 pm
start_time = '09:00'
end_time = '17:00'

dfConTime = dfCon[dfCon['SampleDate'].dt.time.between(pd.to_datetime(start_time).time(), pd.to_datetime(end_time).time())]
dfConTime["SampleDate"] = pd.to_datetime(dfConTime['SampleDate'])
dfConTime.head()
# Out:
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\3310628739.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfConTime["SampleDate"] = pd.to_datetime(dfConTime['SampleDate'])
#       RowID  ProgramID      ParameterName ParameterUnits ProgramLocationID  \
# 0  88286023        474  Water Temperature      Degrees C              EB04
# 2  88291057        474  Water Temperature      Degrees C              EB01
# 3  88294267        474  Water Temperature      Degrees C              EB01
# 5  88302636        474  Water Temperature      Degrees C              EB01
# 6  88302639        474  Water Temperature      Degrees C              EB01
#
#    ActivityType          SampleDate  Year  Month RelativeDepth  ResultValue  \
# 0           NaN 2022-09-08 09:15:00  2022      9        bottom         31.3
# 2           NaN 2022-08-30 13:00:00  2022      8        bottom         31.0
# 3           NaN 2022-08-29 15:45:00  2022      8        bottom         31.9
# 5           NaN 2022-09-09 15:15:00  2022      9        bottom         30.9
# 6           NaN 2022-09-10 14:15:00  2022      9        bottom         30.5
#
#    Latitude_DD  Longitude_DD              ManagedAreaName  AreaID  \
# 0    26.449685    -81.871465  Estero Bay Aquatic Preserve      14
# 2    26.434900    -81.911400  Estero Bay Aquatic Preserve      14
# 3    26.434900    -81.911400  Estero Bay Aquatic Preserve      14
# 5    26.434900    -81.911400  Estero Bay Aquatic Preserve      14
# 6    26.434900    -81.911400  Estero Bay Aquatic Preserve      14
#
#   SEACAR_QAQCFlagCode   WaterBody WbodyAcronym  Season
# 0                  6Q  Estero Bay           EB  Summer
# 2                  6Q  Estero Bay           EB  Summer
# 3                  6Q  Estero Bay           EB  Summer
# 5                  6Q  Estero Bay           EB  Summer
# 6                  6Q  Estero Bay           EB  Summer

# %% [markdown]
# ### Select the data based on the 52 weeks excel file.

# %%
area_ab = ["GTM","EB","CH","BB","BBS"]
period_type = [" 52 week"," Month"]
dfConTime["Period"] = ""
def select_data_period(df,area,period):
    sheet_name = str(area) + str(period)
    df_period_table = pd.read_excel(gis_path + "All_Waterbodies_Season_Month_Week_Definitions.xlsx",sheet_name=sheet_name)
    df_select_area = df[df["WbodyAcronym"]==str(area)]
    df_period_table['Start Date'] = pd.to_datetime(df_period_table['Start Date'])
    df_period_table['End Date']   = pd.to_datetime(df_period_table['End Date'])
    sub_dfs = []

    for index, row in df_period_table.iterrows():
        start_date = row['Start Date']
        end_date   = row['End Date']
        sub_df = df_select_area[(df_select_area['SampleDate'] >= start_date) & (df_select_area['SampleDate'] < end_date)]
        sub_df['Period'] = row["Week"]
        sub_dfs.append(sub_df)
        
    df_period = pd.concat(sub_dfs,ignore_index=True)
    return df_period
# Out:
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\3754268539.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfConTime["Period"] = ""

# %% [markdown]
# ### Generate the aggregated mean value for weekly data.

# %%
sel_week_temp = []
for each in area_ab:
    df_week_temp = select_data_period(dfConTime,str(each)," 52 week")
    df_week_temp_group = df_week_temp.groupby(['WaterBody','ParameterName','ParameterUnits',
                                          'Year','Season','Latitude_DD','Longitude_DD','WbodyAcronym',"Period"])["ResultValue"].agg("mean").reset_index()
    sel_week_temp.append(df_week_temp_group)
df_week_select_Mean = pd.concat(sel_week_temp,ignore_index=True)
# Out:
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\3754268539.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['Period'] = row["Week"]
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\3754268539.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['Period'] = row["Week"]
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\3754268539.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['Period'] = row["Week"]
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\3754268539.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['Period'] = row["Week"]
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\3754268539.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['Period'] = row["Week"]

# %%
# Define the EPSG codes for source (EPSG:4326) and target (EPSG:3086) coordinate systems
source_epsg = 'EPSG:4326'
target_epsg = 'EPSG:3086'

# Create a PyProj Transformer for the conversion
transformer = pyproj.Transformer.from_crs(source_epsg, target_epsg, always_xy=True)

# Define a function to apply the transformation to each row of the DataFrame
def transform_coordinates(row):
    x, y = transformer.transform(row['Longitude_DD'], row['Latitude_DD'])
    return pd.Series({'x': x, 'y': y})

# Apply the transformation function to the DataFrame and create new columns for the converted coordinates
df_week_select_Mean[['x', 'y']] = df_week_select_Mean.apply(transform_coordinates, axis=1)

# %% [markdown]
# ### Define the barrier files

# %%
barrier_folder = os.path.join(gis_path, 'Barriers')
barrier_folder

barriers = []
for file in os.listdir(barrier_folder):
    if file.endswith(".shp"):
        barriers.append(os.path.join(barrier_folder, file))

for barrier in barriers:
    print(barrier)
# Out:
# F:\SEACAR_WQ_2024/GIS_Data/Barriers\BBS_Barriers.shp
# F:\SEACAR_WQ_2024/GIS_Data/Barriers\BB_Barriers.shp
# F:\SEACAR_WQ_2024/GIS_Data/Barriers\CH_Barriers.shp
# F:\SEACAR_WQ_2024/GIS_Data/Barriers\EB_Barriers.shp
# F:\SEACAR_WQ_2024/GIS_Data/Barriers\GTM_Barriers.shp

# %% [markdown]
# ### Define waterbody boundary for spatial extent and masking

# %%
waterbody_extent = os.path.join(gis_path, 'OEAT_Waterbody_Boundaries', 'OEAT_Waterbody_Boundary.shp')

unique_waterbodies = []
with arcpy.da.SearchCursor(waterbody_extent, ['WaterbodyA']) as cursor:
    for row in cursor:
        unique_waterbodies.append(row[0])

print("Unique Waterbodies:", unique_waterbodies)
# Out:
# Unique Waterbodies: ['BBS', 'BB', 'CH', 'EB', 'GTM']

# %% [markdown]
# ### Define and generate weekly table.

# %%
waterBody = ['Big Bend Seagrasses', 'Biscayne Bay', 'Charlotte Harbor', 'Estero Bay', 'Guana Tolomato Matanzas']
parameter = ['Dissolved Oxygen', 'Salinity', 'Turbidity', 'Water Temperature']
waterBody_list = []
parameter_list= []
week_list = []
for i in waterBody:
    for j in parameter:
        for k in range(1,53):
            waterBody_list.append(i)
            parameter_list.append(j)
            week_list.append(k)

# %%
df_week_table = pd.DataFrame({
    "WaterBody":waterBody_list,
    "Parameter":parameter_list,
    "Period":week_list
})
df_week_table["Filename"] = ""
df_week_table["NumDataPoints"] = ""
df_week_table["RMSE"] = ""
df_week_table["ME"] = ""
df_week_table["WbodyAcronym"] = df_week_table["WaterBody"].map(area_shortnames)

# %%
name_ab = df_week_table["WbodyAcronym"].unique()
para_list = df_week_table["Parameter"].unique()
dfs_sub = []
for each in name_ab:
    sheet_name_use = str(each) + " 52 week"
    df_period_table_used = pd.read_excel(gis_path + "All_Waterbodies_Season_Month_Week_Definitions.xlsx",sheet_name=sheet_name_use)
    startDate = list(df_period_table_used["Start Date"])
    endDate   = list(df_period_table_used["End Date"])
    for para in para_list:
        df_temp_use = df_week_table[(df_week_table["WbodyAcronym"]==str(each))&(df_week_table["Parameter"]==str(para))]
        df_temp_use["startDate"] = startDate
        df_temp_use["endDate"]   = endDate
        dfs_sub.append(df_temp_use)
df_week_table = pd.concat(dfs_sub)
df_week_table.to_csv(gis_path + 'week_table.csv')
# Out:
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\304806093.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate

# %%
df_week_table
# Out:
#                     WaterBody          Parameter  Period Filename  \
# 0         Big Bend Seagrasses   Dissolved Oxygen       1
# 1         Big Bend Seagrasses   Dissolved Oxygen       2
# 2         Big Bend Seagrasses   Dissolved Oxygen       3
# 3         Big Bend Seagrasses   Dissolved Oxygen       4
# 4         Big Bend Seagrasses   Dissolved Oxygen       5
# ...                       ...                ...     ...      ...
# 1035  Guana Tolomato Matanzas  Water Temperature      48
# 1036  Guana Tolomato Matanzas  Water Temperature      49
# 1037  Guana Tolomato Matanzas  Water Temperature      50
# 1038  Guana Tolomato Matanzas  Water Temperature      51
# 1039  Guana Tolomato Matanzas  Water Temperature      52
#
#      NumDataPoints RMSE ME WbodyAcronym  startDate    endDate
# 0                                   BBS 2021-01-06 2021-01-12
# 1                                   BBS 2021-01-13 2021-01-19
# 2                                   BBS 2021-01-20 2021-01-26
# 3                                   BBS 2021-01-27 2021-02-02
# 4                                   BBS 2021-02-03 2021-02-09
# ...            ...  ... ..          ...        ...        ...
# 1035                                GTM 2017-03-04 2017-03-11
# 1036                                GTM 2017-03-11 2017-03-18
# 1037                                GTM 2017-03-18 2017-03-25
# 1038                                GTM 2017-03-25 2017-04-01
# 1039                                GTM 2017-04-01 2017-04-08
#
# [1040 rows x 10 columns]

# %% [markdown]
# ### Define output folders

# %%
shpCon_folder = gis_path + r"shapefiles_Con/week"
idwCon_folder = gis_path + r"idw_Con/week"

# %% [markdown]
# # 1.2 Preview Dataset <a class="anchor" id="reg_preview"></a>

# %%
df_week_select_Mean
# Out:
#                     WaterBody      ParameterName ParameterUnits  Year  Season  \
# 0     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 1     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 2     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 3     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 4     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# ...                       ...                ...            ...   ...     ...
# 3221      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 3222      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 3223      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 3224      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 3225      Big Bend Seagrasses  Water Temperature      Degrees C  2022  Winter
#
#       Latitude_DD  Longitude_DD WbodyAcronym  Period  ResultValue  \
# 0       29.667071    -81.257403          GTM      23     5.566667
# 1       29.667071    -81.257403          GTM      24     5.106926
# 2       29.667071    -81.257403          GTM      25     4.686580
# 3       29.667071    -81.257403          GTM      26     5.511688
# 4       29.667071    -81.257403          GTM      27     2.891775
# ...           ...           ...          ...     ...          ...
# 3221    29.647203    -83.421196          BBS      49    20.032828
# 3222    29.647203    -83.421196          BBS      50    20.496970
# 3223    29.647203    -83.421196          BBS      51    16.403535
# 3224    29.647203    -83.421196          BBS      52    21.236364
# 3225    29.647203    -83.421196          BBS      52    21.214141
#
#                   x              y  RowID
# 0     665054.340859  631868.366218      1
# 1     665054.340859  631868.366218      2
# 2     665054.340859  631868.366218      3
# 3     665054.340859  631868.366218      4
# 4     665054.340859  631868.366218      5
# ...             ...            ...    ...
# 3221  455952.242067  626846.365120   3222
# 3222  455952.242067  626846.365120   3223
# 3223  455952.242067  626846.365120   3224
# 3224  455952.242067  626846.365120   3225
# 3225  455952.242067  626846.365120   3226
#
# [3226 rows x 13 columns]

# %% [markdown]
# ## 1.3 Fill NaN RowID with unique ID, IDW function needs unique ID <a class="anchor" id="reg_id"></a>

# %%
idw_rk.fill_nan_rowids(df_week_select_Mean, 'RowID')

df_week_select_Mean['RowID'] = df_week_select_Mean['RowID'].astype(int)
df_week_select_Mean
# Out:
#                     WaterBody      ParameterName ParameterUnits  Year  Season  \
# 0     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 1     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 2     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 3     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 4     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# ...                       ...                ...            ...   ...     ...
# 3221      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 3222      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 3223      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 3224      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 3225      Big Bend Seagrasses  Water Temperature      Degrees C  2022  Winter
#
#       Latitude_DD  Longitude_DD WbodyAcronym  Period  ResultValue  \
# 0       29.667071    -81.257403          GTM      23     5.566667
# 1       29.667071    -81.257403          GTM      24     5.106926
# 2       29.667071    -81.257403          GTM      25     4.686580
# 3       29.667071    -81.257403          GTM      26     5.511688
# 4       29.667071    -81.257403          GTM      27     2.891775
# ...           ...           ...          ...     ...          ...
# 3221    29.647203    -83.421196          BBS      49    20.032828
# 3222    29.647203    -83.421196          BBS      50    20.496970
# 3223    29.647203    -83.421196          BBS      51    16.403535
# 3224    29.647203    -83.421196          BBS      52    21.236364
# 3225    29.647203    -83.421196          BBS      52    21.214141
#
#                   x              y  RowID
# 0     665054.340859  631868.366218      1
# 1     665054.340859  631868.366218      2
# 2     665054.340859  631868.366218      3
# 3     665054.340859  631868.366218      4
# 4     665054.340859  631868.366218      5
# ...             ...            ...    ...
# 3221  455952.242067  626846.365120   3222
# 3222  455952.242067  626846.365120   3223
# 3223  455952.242067  626846.365120   3224
# 3224  455952.242067  626846.365120   3225
# 3225  455952.242067  626846.365120   3226
#
# [3226 rows x 13 columns]

# %% [markdown]
# # 2. Create Shapefile <a class="anchor" id="reg_create_shp"></a>

# %%
idw_rk.delete_all_files(shpCon_folder)

# %%
# Merge interested with latitude and longitude columns
seasons_con_coord = idw_rk.merge_with_lat_long1(df_week_table, df_week_select_Mean)

# %%
seasons_con_coord
# Out:
#                     WaterBody          Parameter  Period Filename  \
# 0         Big Bend Seagrasses   Dissolved Oxygen       1
# 1         Big Bend Seagrasses   Dissolved Oxygen       2
# 2         Big Bend Seagrasses   Dissolved Oxygen       3
# 3         Big Bend Seagrasses   Dissolved Oxygen       4
# 4         Big Bend Seagrasses   Dissolved Oxygen       5
# ...                       ...                ...     ...      ...
# 3292  Guana Tolomato Matanzas  Water Temperature      51
# 3293  Guana Tolomato Matanzas  Water Temperature      52
# 3294  Guana Tolomato Matanzas  Water Temperature      52
# 3295  Guana Tolomato Matanzas  Water Temperature      52
# 3296  Guana Tolomato Matanzas  Water Temperature      52
#
#      NumDataPoints RMSE ME WbodyAcronym  startDate    endDate              x  \
# 0                                   BBS 2021-01-06 2021-01-12  455952.242067
# 1                                   BBS 2021-01-13 2021-01-19  455952.242067
# 2                                   BBS 2021-01-20 2021-01-26  455952.242067
# 3                                   BBS 2021-01-27 2021-02-02  455952.242067
# 4                                   BBS 2021-02-03 2021-02-09  455952.242067
# ...            ...  ... ..          ...        ...        ...            ...
# 3292                                GTM 2017-03-25 2017-04-01  653509.737698
# 3293                                GTM 2017-04-01 2017-04-08  665054.340859
# 3294                                GTM 2017-04-01 2017-04-08  665987.248566
# 3295                                GTM 2017-04-01 2017-04-08  659731.434296
# 3296                                GTM 2017-04-01 2017-04-08  653509.737698
#
#                   y  RowID  ResultValue
# 0     626846.365120   3055     8.345960
# 1     626846.365120   3056     8.507576
# 2     626846.365120   3057     8.120202
# 3     626846.365120   3058     7.933838
# 4     626846.365120   3059     8.726263
# ...             ...    ...          ...
# 3292  674232.732990    747    22.775325
# 3293  631868.366218    733    24.606061
# 3294  639659.363097    738    21.770996
# 3295  654158.019057    743    22.544156
# 3296  674232.732990    748    23.817749
#
# [3297 rows x 14 columns]

# %%
idw_rk.create_shp_season1(seasons_con_coord, shpCon_folder)
# Out:
# Number of data rows for BBS, DO_mgl, 1: 1
# Shapefile for BBS: DO_mgl for period 1 has been saved as SHP_BBS_DO_mgl_1.shp
# Number of data rows for BBS, DO_mgl, 2: 1
# Shapefile for BBS: DO_mgl for period 2 has been saved as SHP_BBS_DO_mgl_2.shp
# Number of data rows for BBS, DO_mgl, 3: 1
# Shapefile for BBS: DO_mgl for period 3 has been saved as SHP_BBS_DO_mgl_3.shp
# Number of data rows for BBS, DO_mgl, 4: 1
# Shapefile for BBS: DO_mgl for period 4 has been saved as SHP_BBS_DO_mgl_4.shp
# Number of data rows for BBS, DO_mgl, 5: 1
# Shapefile for BBS: DO_mgl for period 5 has been saved as SHP_BBS_DO_mgl_5.shp
# Number of data rows for BBS, DO_mgl, 6: 1
# Shapefile for BBS: DO_mgl for period 6 has been saved as SHP_BBS_DO_mgl_6.shp
# Number of data rows for BBS, DO_mgl, 7: 1
# Shapefile for BBS: DO_mgl for period 7 has been saved as SHP_BBS_DO_mgl_7.shp
# Number of data rows for BBS, DO_mgl, 8: 1
# Shapefile for BBS: DO_mgl for period 8 has been saved as SHP_BBS_DO_mgl_8.shp
# Number of data rows for BBS, DO_mgl, 9: 1
# Shapefile for BBS: DO_mgl for period 9 has been saved as SHP_BBS_DO_mgl_9.shp
# Number of data rows for BBS, DO_mgl, 10: 1
# Shapefile for BBS: DO_mgl for period 10 has been saved as SHP_BBS_DO_mgl_10.shp
# Number of data rows for BBS, DO_mgl, 11: 1
# Shapefile for BBS: DO_mgl for period 11 has been saved as SHP_BBS_DO_mgl_11.shp
# Number of data rows for BBS, DO_mgl, 12: 1
# Shapefile for BBS: DO_mgl for period 12 has been saved as SHP_BBS_DO_mgl_12.shp
# Number of data rows for BBS, DO_mgl, 13: 1
# Shapefile for BBS: DO_mgl for period 13 has been saved as SHP_BBS_DO_mgl_13.shp
# Number of data rows for BBS, DO_mgl, 14: 1
# Shapefile for BBS: DO_mgl for period 14 has been saved as SHP_BBS_DO_mgl_14.shp
# Number of data rows for BBS, DO_mgl, 15: 1
# Shapefile for BBS: DO_mgl for period 15 has been saved as SHP_BBS_DO_mgl_15.shp
# Number of data rows for BBS, DO_mgl, 16: 1
# Shapefile for BBS: DO_mgl for period 16 has been saved as SHP_BBS_DO_mgl_16.shp
# Number of data rows for BBS, DO_mgl, 17: 1
# Shapefile for BBS: DO_mgl for period 17 has been saved as SHP_BBS_DO_mgl_17.shp
# Number of data rows for BBS, DO_mgl, 18: 1
# Shapefile for BBS: DO_mgl for period 18 has been saved as SHP_BBS_DO_mgl_18.shp
# Number of data rows for BBS, DO_mgl, 19: 1
# Shapefile for BBS: DO_mgl for period 19 has been saved as SHP_BBS_DO_mgl_19.shp
# Number of data rows for BBS, DO_mgl, 20: 1
# Shapefile for BBS: DO_mgl for period 20 has been saved as SHP_BBS_DO_mgl_20.shp
# Number of data rows for BBS, DO_mgl, 21: 1
# Shapefile for BBS: DO_mgl for period 21 has been saved as SHP_BBS_DO_mgl_21.shp
# No valid data found for area: BBS, parameter: DO_mgl, period: 22
# No valid data found for area: BBS, parameter: DO_mgl, period: 23
# No valid data found for area: BBS, parameter: DO_mgl, period: 24
# Number of data rows for BBS, DO_mgl, 25: 1
# Shapefile for BBS: DO_mgl for period 25 has been saved as SHP_BBS_DO_mgl_25.shp
# Number of data rows for BBS, DO_mgl, 26: 1
# Shapefile for BBS: DO_mgl for period 26 has been saved as SHP_BBS_DO_mgl_26.shp
# Number of data rows for BBS, DO_mgl, 27: 1
# Shapefile for BBS: DO_mgl for period 27 has been saved as SHP_BBS_DO_mgl_27.shp
# Number of data rows for BBS, DO_mgl, 28: 1
# Shapefile for BBS: DO_mgl for period 28 has been saved as SHP_BBS_DO_mgl_28.shp
# Number of data rows for BBS, DO_mgl, 29: 1
# Shapefile for BBS: DO_mgl for period 29 has been saved as SHP_BBS_DO_mgl_29.shp
# Number of data rows for BBS, DO_mgl, 30: 1
# Shapefile for BBS: DO_mgl for period 30 has been saved as SHP_BBS_DO_mgl_30.shp
# Number of data rows for BBS, DO_mgl, 31: 1
# Shapefile for BBS: DO_mgl for period 31 has been saved as SHP_BBS_DO_mgl_31.shp
# Number of data rows for BBS, DO_mgl, 32: 1
# Shapefile for BBS: DO_mgl for period 32 has been saved as SHP_BBS_DO_mgl_32.shp
# Number of data rows for BBS, DO_mgl, 33: 1
# Shapefile for BBS: DO_mgl for period 33 has been saved as SHP_BBS_DO_mgl_33.shp
# Number of data rows for BBS, DO_mgl, 34: 1
# Shapefile for BBS: DO_mgl for period 34 has been saved as SHP_BBS_DO_mgl_34.shp
# Number of data rows for BBS, DO_mgl, 35: 1
# Shapefile for BBS: DO_mgl for period 35 has been saved as SHP_BBS_DO_mgl_35.shp
# Number of data rows for BBS, DO_mgl, 36: 1
# Shapefile for BBS: DO_mgl for period 36 has been saved as SHP_BBS_DO_mgl_36.shp
# Number of data rows for BBS, DO_mgl, 37: 1
# Shapefile for BBS: DO_mgl for period 37 has been saved as SHP_BBS_DO_mgl_37.shp
# Number of data rows for BBS, DO_mgl, 38: 1
# Shapefile for BBS: DO_mgl for period 38 has been saved as SHP_BBS_DO_mgl_38.shp
# Number of data rows for BBS, DO_mgl, 39: 1
# Shapefile for BBS: DO_mgl for period 39 has been saved as SHP_BBS_DO_mgl_39.shp
# Number of data rows for BBS, DO_mgl, 40: 1
# Shapefile for BBS: DO_mgl for period 40 has been saved as SHP_BBS_DO_mgl_40.shp
# Number of data rows for BBS, DO_mgl, 41: 1
# Shapefile for BBS: DO_mgl for period 41 has been saved as SHP_BBS_DO_mgl_41.shp
# Number of data rows for BBS, DO_mgl, 42: 1
# Shapefile for BBS: DO_mgl for period 42 has been saved as SHP_BBS_DO_mgl_42.shp
# Number of data rows for BBS, DO_mgl, 43: 1
# Shapefile for BBS: DO_mgl for period 43 has been saved as SHP_BBS_DO_mgl_43.shp
# Number of data rows for BBS, DO_mgl, 44: 1
# Shapefile for BBS: DO_mgl for period 44 has been saved as SHP_BBS_DO_mgl_44.shp
# Number of data rows for BBS, DO_mgl, 45: 1
# Shapefile for BBS: DO_mgl for period 45 has been saved as SHP_BBS_DO_mgl_45.shp
# Number of data rows for BBS, DO_mgl, 46: 1
# Shapefile for BBS: DO_mgl for period 46 has been saved as SHP_BBS_DO_mgl_46.shp
# Number of data rows for BBS, DO_mgl, 47: 1
# Shapefile for BBS: DO_mgl for period 47 has been saved as SHP_BBS_DO_mgl_47.shp
# Number of data rows for BBS, DO_mgl, 48: 2
# Shapefile for BBS: DO_mgl for period 48 has been saved as SHP_BBS_DO_mgl_48.shp
# Number of data rows for BBS, DO_mgl, 49: 1
# Shapefile for BBS: DO_mgl for period 49 has been saved as SHP_BBS_DO_mgl_49.shp
# Number of data rows for BBS, DO_mgl, 50: 1
# Shapefile for BBS: DO_mgl for period 50 has been saved as SHP_BBS_DO_mgl_50.shp
# Number of data rows for BBS, DO_mgl, 51: 1
# Shapefile for BBS: DO_mgl for period 51 has been saved as SHP_BBS_DO_mgl_51.shp
# Number of data rows for BBS, DO_mgl, 52: 2
# Shapefile for BBS: DO_mgl for period 52 has been saved as SHP_BBS_DO_mgl_52.shp
# Number of data rows for BBS, Sal_ppt, 1: 1
# Shapefile for BBS: Sal_ppt for period 1 has been saved as SHP_BBS_Sal_ppt_1.shp
# Number of data rows for BBS, Sal_ppt, 2: 1
# Shapefile for BBS: Sal_ppt for period 2 has been saved as SHP_BBS_Sal_ppt_2.shp
# Number of data rows for BBS, Sal_ppt, 3: 1
# Shapefile for BBS: Sal_ppt for period 3 has been saved as SHP_BBS_Sal_ppt_3.shp
# Number of data rows for BBS, Sal_ppt, 4: 1
# Shapefile for BBS: Sal_ppt for period 4 has been saved as SHP_BBS_Sal_ppt_4.shp
# Number of data rows for BBS, Sal_ppt, 5: 1
# Shapefile for BBS: Sal_ppt for period 5 has been saved as SHP_BBS_Sal_ppt_5.shp
# Number of data rows for BBS, Sal_ppt, 6: 1
# Shapefile for BBS: Sal_ppt for period 6 has been saved as SHP_BBS_Sal_ppt_6.shp
# Number of data rows for BBS, Sal_ppt, 7: 1
# Shapefile for BBS: Sal_ppt for period 7 has been saved as SHP_BBS_Sal_ppt_7.shp
# Number of data rows for BBS, Sal_ppt, 8: 1
# Shapefile for BBS: Sal_ppt for period 8 has been saved as SHP_BBS_Sal_ppt_8.shp
# Number of data rows for BBS, Sal_ppt, 9: 1
# Shapefile for BBS: Sal_ppt for period 9 has been saved as SHP_BBS_Sal_ppt_9.shp
# Number of data rows for BBS, Sal_ppt, 10: 1
# Shapefile for BBS: Sal_ppt for period 10 has been saved as SHP_BBS_Sal_ppt_10.shp
# Number of data rows for BBS, Sal_ppt, 11: 1
# Shapefile for BBS: Sal_ppt for period 11 has been saved as SHP_BBS_Sal_ppt_11.shp
# Number of data rows for BBS, Sal_ppt, 12: 1
# Shapefile for BBS: Sal_ppt for period 12 has been saved as SHP_BBS_Sal_ppt_12.shp
# Number of data rows for BBS, Sal_ppt, 13: 1
# Shapefile for BBS: Sal_ppt for period 13 has been saved as SHP_BBS_Sal_ppt_13.shp
# Number of data rows for BBS, Sal_ppt, 14: 1
# Shapefile for BBS: Sal_ppt for period 14 has been saved as SHP_BBS_Sal_ppt_14.shp
# Number of data rows for BBS, Sal_ppt, 15: 1
# Shapefile for BBS: Sal_ppt for period 15 has been saved as SHP_BBS_Sal_ppt_15.shp
# Number of data rows for BBS, Sal_ppt, 16: 1
# Shapefile for BBS: Sal_ppt for period 16 has been saved as SHP_BBS_Sal_ppt_16.shp
# Number of data rows for BBS, Sal_ppt, 17: 1
# Shapefile for BBS: Sal_ppt for period 17 has been saved as SHP_BBS_Sal_ppt_17.shp
# Number of data rows for BBS, Sal_ppt, 18: 1
# Shapefile for BBS: Sal_ppt for period 18 has been saved as SHP_BBS_Sal_ppt_18.shp
# Number of data rows for BBS, Sal_ppt, 19: 1
# Shapefile for BBS: Sal_ppt for period 19 has been saved as SHP_BBS_Sal_ppt_19.shp
# Number of data rows for BBS, Sal_ppt, 20: 1
# Shapefile for BBS: Sal_ppt for period 20 has been saved as SHP_BBS_Sal_ppt_20.shp
# Number of data rows for BBS, Sal_ppt, 21: 1
# Shapefile for BBS: Sal_ppt for period 21 has been saved as SHP_BBS_Sal_ppt_21.shp
# No valid data found for area: BBS, parameter: Sal_ppt, period: 22
# No valid data found for area: BBS, parameter: Sal_ppt, period: 23
# No valid data found for area: BBS, parameter: Sal_ppt, period: 24
# Number of data rows for BBS, Sal_ppt, 25: 1
# Shapefile for BBS: Sal_ppt for period 25 has been saved as SHP_BBS_Sal_ppt_25.shp
# Number of data rows for BBS, Sal_ppt, 26: 1
# Shapefile for BBS: Sal_ppt for period 26 has been saved as SHP_BBS_Sal_ppt_26.shp
# Number of data rows for BBS, Sal_ppt, 27: 1
# Shapefile for BBS: Sal_ppt for period 27 has been saved as SHP_BBS_Sal_ppt_27.shp
# Number of data rows for BBS, Sal_ppt, 28: 1
# Shapefile for BBS: Sal_ppt for period 28 has been saved as SHP_BBS_Sal_ppt_28.shp
# Number of data rows for BBS, Sal_ppt, 29: 1
# Shapefile for BBS: Sal_ppt for period 29 has been saved as SHP_BBS_Sal_ppt_29.shp
# Number of data rows for BBS, Sal_ppt, 30: 1
# Shapefile for BBS: Sal_ppt for period 30 has been saved as SHP_BBS_Sal_ppt_30.shp
# Number of data rows for BBS, Sal_ppt, 31: 1
# Shapefile for BBS: Sal_ppt for period 31 has been saved as SHP_BBS_Sal_ppt_31.shp
# Number of data rows for BBS, Sal_ppt, 32: 1
# Shapefile for BBS: Sal_ppt for period 32 has been saved as SHP_BBS_Sal_ppt_32.shp
# Number of data rows for BBS, Sal_ppt, 33: 1
# Shapefile for BBS: Sal_ppt for period 33 has been saved as SHP_BBS_Sal_ppt_33.shp
# Number of data rows for BBS, Sal_ppt, 34: 1
# Shapefile for BBS: Sal_ppt for period 34 has been saved as SHP_BBS_Sal_ppt_34.shp
# Number of data rows for BBS, Sal_ppt, 35: 1
# Shapefile for BBS: Sal_ppt for period 35 has been saved as SHP_BBS_Sal_ppt_35.shp
# Number of data rows for BBS, Sal_ppt, 36: 1
# Shapefile for BBS: Sal_ppt for period 36 has been saved as SHP_BBS_Sal_ppt_36.shp
# Number of data rows for BBS, Sal_ppt, 37: 1
# Shapefile for BBS: Sal_ppt for period 37 has been saved as SHP_BBS_Sal_ppt_37.shp
# Number of data rows for BBS, Sal_ppt, 38: 1
# Shapefile for BBS: Sal_ppt for period 38 has been saved as SHP_BBS_Sal_ppt_38.shp
# Number of data rows for BBS, Sal_ppt, 39: 1
# Shapefile for BBS: Sal_ppt for period 39 has been saved as SHP_BBS_Sal_ppt_39.shp
# Number of data rows for BBS, Sal_ppt, 40: 1
# Shapefile for BBS: Sal_ppt for period 40 has been saved as SHP_BBS_Sal_ppt_40.shp
# Number of data rows for BBS, Sal_ppt, 41: 1
# Shapefile for BBS: Sal_ppt for period 41 has been saved as SHP_BBS_Sal_ppt_41.shp
# Number of data rows for BBS, Sal_ppt, 42: 1
# Shapefile for BBS: Sal_ppt for period 42 has been saved as SHP_BBS_Sal_ppt_42.shp
# Number of data rows for BBS, Sal_ppt, 43: 1
# Shapefile for BBS: Sal_ppt for period 43 has been saved as SHP_BBS_Sal_ppt_43.shp
# Number of data rows for BBS, Sal_ppt, 44: 1
# Shapefile for BBS: Sal_ppt for period 44 has been saved as SHP_BBS_Sal_ppt_44.shp
# Number of data rows for BBS, Sal_ppt, 45: 1
# Shapefile for BBS: Sal_ppt for period 45 has been saved as SHP_BBS_Sal_ppt_45.shp
# Number of data rows for BBS, Sal_ppt, 46: 1
# Shapefile for BBS: Sal_ppt for period 46 has been saved as SHP_BBS_Sal_ppt_46.shp
# Number of data rows for BBS, Sal_ppt, 47: 1
# Shapefile for BBS: Sal_ppt for period 47 has been saved as SHP_BBS_Sal_ppt_47.shp
# Number of data rows for BBS, Sal_ppt, 48: 2
# Shapefile for BBS: Sal_ppt for period 48 has been saved as SHP_BBS_Sal_ppt_48.shp
# Number of data rows for BBS, Sal_ppt, 49: 1
# Shapefile for BBS: Sal_ppt for period 49 has been saved as SHP_BBS_Sal_ppt_49.shp
# Number of data rows for BBS, Sal_ppt, 50: 1
# Shapefile for BBS: Sal_ppt for period 50 has been saved as SHP_BBS_Sal_ppt_50.shp
# Number of data rows for BBS, Sal_ppt, 51: 1
# Shapefile for BBS: Sal_ppt for period 51 has been saved as SHP_BBS_Sal_ppt_51.shp
# Number of data rows for BBS, Sal_ppt, 52: 2
# Shapefile for BBS: Sal_ppt for period 52 has been saved as SHP_BBS_Sal_ppt_52.shp
# Number of data rows for BBS, Turb_ntu, 1: 1
# Shapefile for BBS: Turb_ntu for period 1 has been saved as SHP_BBS_Turb_ntu_1.shp
# Number of data rows for BBS, Turb_ntu, 2: 1
# Shapefile for BBS: Turb_ntu for period 2 has been saved as SHP_BBS_Turb_ntu_2.shp
# Number of data rows for BBS, Turb_ntu, 3: 1
# Shapefile for BBS: Turb_ntu for period 3 has been saved as SHP_BBS_Turb_ntu_3.shp
# Number of data rows for BBS, Turb_ntu, 4: 1
# Shapefile for BBS: Turb_ntu for period 4 has been saved as SHP_BBS_Turb_ntu_4.shp
# No valid data found for area: BBS, parameter: Turb_ntu, period: 5
# Number of data rows for BBS, Turb_ntu, 6: 1
# Shapefile for BBS: Turb_ntu for period 6 has been saved as SHP_BBS_Turb_ntu_6.shp
# Number of data rows for BBS, Turb_ntu, 7: 1
# Shapefile for BBS: Turb_ntu for period 7 has been saved as SHP_BBS_Turb_ntu_7.shp
# Number of data rows for BBS, Turb_ntu, 8: 1
# Shapefile for BBS: Turb_ntu for period 8 has been saved as SHP_BBS_Turb_ntu_8.shp
# Number of data rows for BBS, Turb_ntu, 9: 1
# Shapefile for BBS: Turb_ntu for period 9 has been saved as SHP_BBS_Turb_ntu_9.shp
# Number of data rows for BBS, Turb_ntu, 10: 1
# Shapefile for BBS: Turb_ntu for period 10 has been saved as SHP_BBS_Turb_ntu_10.shp
# Number of data rows for BBS, Turb_ntu, 11: 1
# Shapefile for BBS: Turb_ntu for period 11 has been saved as SHP_BBS_Turb_ntu_11.shp
# Number of data rows for BBS, Turb_ntu, 12: 1
# Shapefile for BBS: Turb_ntu for period 12 has been saved as SHP_BBS_Turb_ntu_12.shp
# Number of data rows for BBS, Turb_ntu, 13: 1
# Shapefile for BBS: Turb_ntu for period 13 has been saved as SHP_BBS_Turb_ntu_13.shp
# Number of data rows for BBS, Turb_ntu, 14: 1
# Shapefile for BBS: Turb_ntu for period 14 has been saved as SHP_BBS_Turb_ntu_14.shp
# Number of data rows for BBS, Turb_ntu, 15: 1
# Shapefile for BBS: Turb_ntu for period 15 has been saved as SHP_BBS_Turb_ntu_15.shp
# Number of data rows for BBS, Turb_ntu, 16: 1
# Shapefile for BBS: Turb_ntu for period 16 has been saved as SHP_BBS_Turb_ntu_16.shp
# Number of data rows for BBS, Turb_ntu, 17: 1
# Shapefile for BBS: Turb_ntu for period 17 has been saved as SHP_BBS_Turb_ntu_17.shp
# Number of data rows for BBS, Turb_ntu, 18: 1
# Shapefile for BBS: Turb_ntu for period 18 has been saved as SHP_BBS_Turb_ntu_18.shp
# Number of data rows for BBS, Turb_ntu, 19: 1
# Shapefile for BBS: Turb_ntu for period 19 has been saved as SHP_BBS_Turb_ntu_19.shp
# Number of data rows for BBS, Turb_ntu, 20: 1
# Shapefile for BBS: Turb_ntu for period 20 has been saved as SHP_BBS_Turb_ntu_20.shp
# Number of data rows for BBS, Turb_ntu, 21: 1
# Shapefile for BBS: Turb_ntu for period 21 has been saved as SHP_BBS_Turb_ntu_21.shp
# Number of data rows for BBS, Turb_ntu, 22: 1
# Shapefile for BBS: Turb_ntu for period 22 has been saved as SHP_BBS_Turb_ntu_22.shp
# Number of data rows for BBS, Turb_ntu, 23: 1
# Shapefile for BBS: Turb_ntu for period 23 has been saved as SHP_BBS_Turb_ntu_23.shp
# Number of data rows for BBS, Turb_ntu, 24: 1
# Shapefile for BBS: Turb_ntu for period 24 has been saved as SHP_BBS_Turb_ntu_24.shp
# Number of data rows for BBS, Turb_ntu, 25: 1
# Shapefile for BBS: Turb_ntu for period 25 has been saved as SHP_BBS_Turb_ntu_25.shp
# Number of data rows for BBS, Turb_ntu, 26: 1
# Shapefile for BBS: Turb_ntu for period 26 has been saved as SHP_BBS_Turb_ntu_26.shp
# Number of data rows for BBS, Turb_ntu, 27: 1
# Shapefile for BBS: Turb_ntu for period 27 has been saved as SHP_BBS_Turb_ntu_27.shp
# Number of data rows for BBS, Turb_ntu, 28: 1
# Shapefile for BBS: Turb_ntu for period 28 has been saved as SHP_BBS_Turb_ntu_28.shp
# Number of data rows for BBS, Turb_ntu, 29: 1
# Shapefile for BBS: Turb_ntu for period 29 has been saved as SHP_BBS_Turb_ntu_29.shp
# Number of data rows for BBS, Turb_ntu, 30: 1
# Shapefile for BBS: Turb_ntu for period 30 has been saved as SHP_BBS_Turb_ntu_30.shp
# Number of data rows for BBS, Turb_ntu, 31: 1
# Shapefile for BBS: Turb_ntu for period 31 has been saved as SHP_BBS_Turb_ntu_31.shp
# Number of data rows for BBS, Turb_ntu, 32: 1
# Shapefile for BBS: Turb_ntu for period 32 has been saved as SHP_BBS_Turb_ntu_32.shp
# Number of data rows for BBS, Turb_ntu, 33: 1
# Shapefile for BBS: Turb_ntu for period 33 has been saved as SHP_BBS_Turb_ntu_33.shp
# Number of data rows for BBS, Turb_ntu, 34: 1
# Shapefile for BBS: Turb_ntu for period 34 has been saved as SHP_BBS_Turb_ntu_34.shp
# Number of data rows for BBS, Turb_ntu, 35: 1
# Shapefile for BBS: Turb_ntu for period 35 has been saved as SHP_BBS_Turb_ntu_35.shp
# Number of data rows for BBS, Turb_ntu, 36: 1
# Shapefile for BBS: Turb_ntu for period 36 has been saved as SHP_BBS_Turb_ntu_36.shp
# Number of data rows for BBS, Turb_ntu, 37: 1
# Shapefile for BBS: Turb_ntu for period 37 has been saved as SHP_BBS_Turb_ntu_37.shp
# Number of data rows for BBS, Turb_ntu, 38: 1
# Shapefile for BBS: Turb_ntu for period 38 has been saved as SHP_BBS_Turb_ntu_38.shp
# Number of data rows for BBS, Turb_ntu, 39: 1
# Shapefile for BBS: Turb_ntu for period 39 has been saved as SHP_BBS_Turb_ntu_39.shp
# Number of data rows for BBS, Turb_ntu, 40: 1
# Shapefile for BBS: Turb_ntu for period 40 has been saved as SHP_BBS_Turb_ntu_40.shp
# Number of data rows for BBS, Turb_ntu, 41: 1
# Shapefile for BBS: Turb_ntu for period 41 has been saved as SHP_BBS_Turb_ntu_41.shp
# Number of data rows for BBS, Turb_ntu, 42: 1
# Shapefile for BBS: Turb_ntu for period 42 has been saved as SHP_BBS_Turb_ntu_42.shp
# Number of data rows for BBS, Turb_ntu, 43: 1
# Shapefile for BBS: Turb_ntu for period 43 has been saved as SHP_BBS_Turb_ntu_43.shp
# Number of data rows for BBS, Turb_ntu, 44: 1
# Shapefile for BBS: Turb_ntu for period 44 has been saved as SHP_BBS_Turb_ntu_44.shp
# Number of data rows for BBS, Turb_ntu, 45: 1
# Shapefile for BBS: Turb_ntu for period 45 has been saved as SHP_BBS_Turb_ntu_45.shp
# Number of data rows for BBS, Turb_ntu, 46: 1
# Shapefile for BBS: Turb_ntu for period 46 has been saved as SHP_BBS_Turb_ntu_46.shp
# Number of data rows for BBS, Turb_ntu, 47: 1
# Shapefile for BBS: Turb_ntu for period 47 has been saved as SHP_BBS_Turb_ntu_47.shp
# Number of data rows for BBS, Turb_ntu, 48: 2
# Shapefile for BBS: Turb_ntu for period 48 has been saved as SHP_BBS_Turb_ntu_48.shp
# Number of data rows for BBS, Turb_ntu, 49: 1
# Shapefile for BBS: Turb_ntu for period 49 has been saved as SHP_BBS_Turb_ntu_49.shp
# Number of data rows for BBS, Turb_ntu, 50: 1
# Shapefile for BBS: Turb_ntu for period 50 has been saved as SHP_BBS_Turb_ntu_50.shp
# Number of data rows for BBS, Turb_ntu, 51: 1
# Shapefile for BBS: Turb_ntu for period 51 has been saved as SHP_BBS_Turb_ntu_51.shp
# Number of data rows for BBS, Turb_ntu, 52: 2
# Shapefile for BBS: Turb_ntu for period 52 has been saved as SHP_BBS_Turb_ntu_52.shp
# Number of data rows for BBS, T_c, 1: 1
# Shapefile for BBS: T_c for period 1 has been saved as SHP_BBS_T_c_1.shp
# Number of data rows for BBS, T_c, 2: 1
# Shapefile for BBS: T_c for period 2 has been saved as SHP_BBS_T_c_2.shp
# Number of data rows for BBS, T_c, 3: 1
# Shapefile for BBS: T_c for period 3 has been saved as SHP_BBS_T_c_3.shp
# Number of data rows for BBS, T_c, 4: 1
# Shapefile for BBS: T_c for period 4 has been saved as SHP_BBS_T_c_4.shp
# Number of data rows for BBS, T_c, 5: 1
# Shapefile for BBS: T_c for period 5 has been saved as SHP_BBS_T_c_5.shp
# Number of data rows for BBS, T_c, 6: 1
# Shapefile for BBS: T_c for period 6 has been saved as SHP_BBS_T_c_6.shp
# Number of data rows for BBS, T_c, 7: 1
# Shapefile for BBS: T_c for period 7 has been saved as SHP_BBS_T_c_7.shp
# Number of data rows for BBS, T_c, 8: 1
# Shapefile for BBS: T_c for period 8 has been saved as SHP_BBS_T_c_8.shp
# Number of data rows for BBS, T_c, 9: 1
# Shapefile for BBS: T_c for period 9 has been saved as SHP_BBS_T_c_9.shp
# Number of data rows for BBS, T_c, 10: 1
# Shapefile for BBS: T_c for period 10 has been saved as SHP_BBS_T_c_10.shp
# Number of data rows for BBS, T_c, 11: 1
# Shapefile for BBS: T_c for period 11 has been saved as SHP_BBS_T_c_11.shp
# Number of data rows for BBS, T_c, 12: 1
# Shapefile for BBS: T_c for period 12 has been saved as SHP_BBS_T_c_12.shp
# Number of data rows for BBS, T_c, 13: 1
# Shapefile for BBS: T_c for period 13 has been saved as SHP_BBS_T_c_13.shp
# Number of data rows for BBS, T_c, 14: 1
# Shapefile for BBS: T_c for period 14 has been saved as SHP_BBS_T_c_14.shp
# Number of data rows for BBS, T_c, 15: 1
# Shapefile for BBS: T_c for period 15 has been saved as SHP_BBS_T_c_15.shp
# Number of data rows for BBS, T_c, 16: 1
# Shapefile for BBS: T_c for period 16 has been saved as SHP_BBS_T_c_16.shp
# Number of data rows for BBS, T_c, 17: 1
# Shapefile for BBS: T_c for period 17 has been saved as SHP_BBS_T_c_17.shp
# Number of data rows for BBS, T_c, 18: 1
# Shapefile for BBS: T_c for period 18 has been saved as SHP_BBS_T_c_18.shp
# Number of data rows for BBS, T_c, 19: 1
# Shapefile for BBS: T_c for period 19 has been saved as SHP_BBS_T_c_19.shp
# Number of data rows for BBS, T_c, 20: 1
# Shapefile for BBS: T_c for period 20 has been saved as SHP_BBS_T_c_20.shp
# Number of data rows for BBS, T_c, 21: 1
# Shapefile for BBS: T_c for period 21 has been saved as SHP_BBS_T_c_21.shp
# Number of data rows for BBS, T_c, 22: 1
# Shapefile for BBS: T_c for period 22 has been saved as SHP_BBS_T_c_22.shp
# Number of data rows for BBS, T_c, 23: 1
# Shapefile for BBS: T_c for period 23 has been saved as SHP_BBS_T_c_23.shp
# Number of data rows for BBS, T_c, 24: 1
# Shapefile for BBS: T_c for period 24 has been saved as SHP_BBS_T_c_24.shp
# Number of data rows for BBS, T_c, 25: 1
# Shapefile for BBS: T_c for period 25 has been saved as SHP_BBS_T_c_25.shp
# Number of data rows for BBS, T_c, 26: 1
# Shapefile for BBS: T_c for period 26 has been saved as SHP_BBS_T_c_26.shp
# Number of data rows for BBS, T_c, 27: 1
# Shapefile for BBS: T_c for period 27 has been saved as SHP_BBS_T_c_27.shp
# Number of data rows for BBS, T_c, 28: 1
# Shapefile for BBS: T_c for period 28 has been saved as SHP_BBS_T_c_28.shp
# Number of data rows for BBS, T_c, 29: 1
# Shapefile for BBS: T_c for period 29 has been saved as SHP_BBS_T_c_29.shp
# Number of data rows for BBS, T_c, 30: 1
# Shapefile for BBS: T_c for period 30 has been saved as SHP_BBS_T_c_30.shp
# Number of data rows for BBS, T_c, 31: 1
# Shapefile for BBS: T_c for period 31 has been saved as SHP_BBS_T_c_31.shp
# Number of data rows for BBS, T_c, 32: 1
# Shapefile for BBS: T_c for period 32 has been saved as SHP_BBS_T_c_32.shp
# Number of data rows for BBS, T_c, 33: 1
# Shapefile for BBS: T_c for period 33 has been saved as SHP_BBS_T_c_33.shp
# Number of data rows for BBS, T_c, 34: 1
# Shapefile for BBS: T_c for period 34 has been saved as SHP_BBS_T_c_34.shp
# Number of data rows for BBS, T_c, 35: 1
# Shapefile for BBS: T_c for period 35 has been saved as SHP_BBS_T_c_35.shp
# Number of data rows for BBS, T_c, 36: 1
# Shapefile for BBS: T_c for period 36 has been saved as SHP_BBS_T_c_36.shp
# Number of data rows for BBS, T_c, 37: 1
# Shapefile for BBS: T_c for period 37 has been saved as SHP_BBS_T_c_37.shp
# Number of data rows for BBS, T_c, 38: 1
# Shapefile for BBS: T_c for period 38 has been saved as SHP_BBS_T_c_38.shp
# Number of data rows for BBS, T_c, 39: 1
# Shapefile for BBS: T_c for period 39 has been saved as SHP_BBS_T_c_39.shp
# Number of data rows for BBS, T_c, 40: 1
# Shapefile for BBS: T_c for period 40 has been saved as SHP_BBS_T_c_40.shp
# Number of data rows for BBS, T_c, 41: 1
# Shapefile for BBS: T_c for period 41 has been saved as SHP_BBS_T_c_41.shp
# Number of data rows for BBS, T_c, 42: 1
# Shapefile for BBS: T_c for period 42 has been saved as SHP_BBS_T_c_42.shp
# Number of data rows for BBS, T_c, 43: 1
# Shapefile for BBS: T_c for period 43 has been saved as SHP_BBS_T_c_43.shp
# Number of data rows for BBS, T_c, 44: 1
# Shapefile for BBS: T_c for period 44 has been saved as SHP_BBS_T_c_44.shp
# Number of data rows for BBS, T_c, 45: 1
# Shapefile for BBS: T_c for period 45 has been saved as SHP_BBS_T_c_45.shp
# Number of data rows for BBS, T_c, 46: 1
# Shapefile for BBS: T_c for period 46 has been saved as SHP_BBS_T_c_46.shp
# Number of data rows for BBS, T_c, 47: 1
# Shapefile for BBS: T_c for period 47 has been saved as SHP_BBS_T_c_47.shp
# Number of data rows for BBS, T_c, 48: 2
# Shapefile for BBS: T_c for period 48 has been saved as SHP_BBS_T_c_48.shp
# Number of data rows for BBS, T_c, 49: 1
# Shapefile for BBS: T_c for period 49 has been saved as SHP_BBS_T_c_49.shp
# Number of data rows for BBS, T_c, 50: 1
# Shapefile for BBS: T_c for period 50 has been saved as SHP_BBS_T_c_50.shp
# Number of data rows for BBS, T_c, 51: 1
# Shapefile for BBS: T_c for period 51 has been saved as SHP_BBS_T_c_51.shp
# Number of data rows for BBS, T_c, 52: 2
# Shapefile for BBS: T_c for period 52 has been saved as SHP_BBS_T_c_52.shp
# Number of data rows for BB, DO_mgl, 1: 4
# Shapefile for BB: DO_mgl for period 1 has been saved as SHP_BB_DO_mgl_1.shp
# Number of data rows for BB, DO_mgl, 2: 4
# Shapefile for BB: DO_mgl for period 2 has been saved as SHP_BB_DO_mgl_2.shp
# Number of data rows for BB, DO_mgl, 3: 5
# Shapefile for BB: DO_mgl for period 3 has been saved as SHP_BB_DO_mgl_3.shp
# Number of data rows for BB, DO_mgl, 4: 6
# Shapefile for BB: DO_mgl for period 4 has been saved as SHP_BB_DO_mgl_4.shp
# Number of data rows for BB, DO_mgl, 5: 6
# Shapefile for BB: DO_mgl for period 5 has been saved as SHP_BB_DO_mgl_5.shp
# Number of data rows for BB, DO_mgl, 6: 6
# Shapefile for BB: DO_mgl for period 6 has been saved as SHP_BB_DO_mgl_6.shp
# Number of data rows for BB, DO_mgl, 7: 5
# Shapefile for BB: DO_mgl for period 7 has been saved as SHP_BB_DO_mgl_7.shp
# Number of data rows for BB, DO_mgl, 8: 5
# Shapefile for BB: DO_mgl for period 8 has been saved as SHP_BB_DO_mgl_8.shp
# Number of data rows for BB, DO_mgl, 9: 6
# Shapefile for BB: DO_mgl for period 9 has been saved as SHP_BB_DO_mgl_9.shp
# Number of data rows for BB, DO_mgl, 10: 6
# Shapefile for BB: DO_mgl for period 10 has been saved as SHP_BB_DO_mgl_10.shp
# Number of data rows for BB, DO_mgl, 11: 6
# Shapefile for BB: DO_mgl for period 11 has been saved as SHP_BB_DO_mgl_11.shp
# Number of data rows for BB, DO_mgl, 12: 6
# Shapefile for BB: DO_mgl for period 12 has been saved as SHP_BB_DO_mgl_12.shp
# Number of data rows for BB, DO_mgl, 13: 6
# Shapefile for BB: DO_mgl for period 13 has been saved as SHP_BB_DO_mgl_13.shp
# Number of data rows for BB, DO_mgl, 14: 6
# Shapefile for BB: DO_mgl for period 14 has been saved as SHP_BB_DO_mgl_14.shp
# Number of data rows for BB, DO_mgl, 15: 6
# Shapefile for BB: DO_mgl for period 15 has been saved as SHP_BB_DO_mgl_15.shp
# Number of data rows for BB, DO_mgl, 16: 6
# Shapefile for BB: DO_mgl for period 16 has been saved as SHP_BB_DO_mgl_16.shp
# Number of data rows for BB, DO_mgl, 17: 6
# Shapefile for BB: DO_mgl for period 17 has been saved as SHP_BB_DO_mgl_17.shp
# Number of data rows for BB, DO_mgl, 18: 5
# Shapefile for BB: DO_mgl for period 18 has been saved as SHP_BB_DO_mgl_18.shp
# Number of data rows for BB, DO_mgl, 19: 5
# Shapefile for BB: DO_mgl for period 19 has been saved as SHP_BB_DO_mgl_19.shp
# Number of data rows for BB, DO_mgl, 20: 5
# Shapefile for BB: DO_mgl for period 20 has been saved as SHP_BB_DO_mgl_20.shp
# Number of data rows for BB, DO_mgl, 21: 5
# Shapefile for BB: DO_mgl for period 21 has been saved as SHP_BB_DO_mgl_21.shp
# Number of data rows for BB, DO_mgl, 22: 5
# Shapefile for BB: DO_mgl for period 22 has been saved as SHP_BB_DO_mgl_22.shp
# Number of data rows for BB, DO_mgl, 23: 5
# Shapefile for BB: DO_mgl for period 23 has been saved as SHP_BB_DO_mgl_23.shp
# Number of data rows for BB, DO_mgl, 24: 5
# Shapefile for BB: DO_mgl for period 24 has been saved as SHP_BB_DO_mgl_24.shp
# Number of data rows for BB, DO_mgl, 25: 6
# Shapefile for BB: DO_mgl for period 25 has been saved as SHP_BB_DO_mgl_25.shp
# Number of data rows for BB, DO_mgl, 26: 6
# Shapefile for BB: DO_mgl for period 26 has been saved as SHP_BB_DO_mgl_26.shp
# Number of data rows for BB, DO_mgl, 27: 6
# Shapefile for BB: DO_mgl for period 27 has been saved as SHP_BB_DO_mgl_27.shp
# Number of data rows for BB, DO_mgl, 28: 6
# Shapefile for BB: DO_mgl for period 28 has been saved as SHP_BB_DO_mgl_28.shp
# Number of data rows for BB, DO_mgl, 29: 6
# Shapefile for BB: DO_mgl for period 29 has been saved as SHP_BB_DO_mgl_29.shp
# Number of data rows for BB, DO_mgl, 30: 6
# Shapefile for BB: DO_mgl for period 30 has been saved as SHP_BB_DO_mgl_30.shp
# Number of data rows for BB, DO_mgl, 31: 6
# Shapefile for BB: DO_mgl for period 31 has been saved as SHP_BB_DO_mgl_31.shp
# Number of data rows for BB, DO_mgl, 32: 6
# Shapefile for BB: DO_mgl for period 32 has been saved as SHP_BB_DO_mgl_32.shp
# Number of data rows for BB, DO_mgl, 33: 6
# Shapefile for BB: DO_mgl for period 33 has been saved as SHP_BB_DO_mgl_33.shp
# Number of data rows for BB, DO_mgl, 34: 6
# Shapefile for BB: DO_mgl for period 34 has been saved as SHP_BB_DO_mgl_34.shp
# Number of data rows for BB, DO_mgl, 35: 5
# Shapefile for BB: DO_mgl for period 35 has been saved as SHP_BB_DO_mgl_35.shp
# Number of data rows for BB, DO_mgl, 36: 5
# Shapefile for BB: DO_mgl for period 36 has been saved as SHP_BB_DO_mgl_36.shp
# Number of data rows for BB, DO_mgl, 37: 6
# Shapefile for BB: DO_mgl for period 37 has been saved as SHP_BB_DO_mgl_37.shp
# Number of data rows for BB, DO_mgl, 38: 6
# Shapefile for BB: DO_mgl for period 38 has been saved as SHP_BB_DO_mgl_38.shp
# Number of data rows for BB, DO_mgl, 39: 12
# Shapefile for BB: DO_mgl for period 39 has been saved as SHP_BB_DO_mgl_39.shp
# Number of data rows for BB, DO_mgl, 40: 6
# Shapefile for BB: DO_mgl for period 40 has been saved as SHP_BB_DO_mgl_40.shp
# Number of data rows for BB, DO_mgl, 41: 6
# Shapefile for BB: DO_mgl for period 41 has been saved as SHP_BB_DO_mgl_41.shp
# Number of data rows for BB, DO_mgl, 42: 5
# Shapefile for BB: DO_mgl for period 42 has been saved as SHP_BB_DO_mgl_42.shp
# Number of data rows for BB, DO_mgl, 43: 5
# Shapefile for BB: DO_mgl for period 43 has been saved as SHP_BB_DO_mgl_43.shp
# Number of data rows for BB, DO_mgl, 44: 5
# Shapefile for BB: DO_mgl for period 44 has been saved as SHP_BB_DO_mgl_44.shp
# No valid data found for area: BB, parameter: DO_mgl, period: 45
# No valid data found for area: BB, parameter: DO_mgl, period: 46
# No valid data found for area: BB, parameter: DO_mgl, period: 47
# No valid data found for area: BB, parameter: DO_mgl, period: 48
# No valid data found for area: BB, parameter: DO_mgl, period: 49
# No valid data found for area: BB, parameter: DO_mgl, period: 50
# No valid data found for area: BB, parameter: DO_mgl, period: 51
# No valid data found for area: BB, parameter: DO_mgl, period: 52
# Number of data rows for BB, Sal_ppt, 1: 4
# Shapefile for BB: Sal_ppt for period 1 has been saved as SHP_BB_Sal_ppt_1.shp
# Number of data rows for BB, Sal_ppt, 2: 4
# Shapefile for BB: Sal_ppt for period 2 has been saved as SHP_BB_Sal_ppt_2.shp
# Number of data rows for BB, Sal_ppt, 3: 5
# Shapefile for BB: Sal_ppt for period 3 has been saved as SHP_BB_Sal_ppt_3.shp
# Number of data rows for BB, Sal_ppt, 4: 6
# Shapefile for BB: Sal_ppt for period 4 has been saved as SHP_BB_Sal_ppt_4.shp
# Number of data rows for BB, Sal_ppt, 5: 6
# Shapefile for BB: Sal_ppt for period 5 has been saved as SHP_BB_Sal_ppt_5.shp
# Number of data rows for BB, Sal_ppt, 6: 6
# Shapefile for BB: Sal_ppt for period 6 has been saved as SHP_BB_Sal_ppt_6.shp
# Number of data rows for BB, Sal_ppt, 7: 5
# Shapefile for BB: Sal_ppt for period 7 has been saved as SHP_BB_Sal_ppt_7.shp
# Number of data rows for BB, Sal_ppt, 8: 5
# Shapefile for BB: Sal_ppt for period 8 has been saved as SHP_BB_Sal_ppt_8.shp
# Number of data rows for BB, Sal_ppt, 9: 6
# Shapefile for BB: Sal_ppt for period 9 has been saved as SHP_BB_Sal_ppt_9.shp
# Number of data rows for BB, Sal_ppt, 10: 6
# Shapefile for BB: Sal_ppt for period 10 has been saved as SHP_BB_Sal_ppt_10.shp
# Number of data rows for BB, Sal_ppt, 11: 6
# Shapefile for BB: Sal_ppt for period 11 has been saved as SHP_BB_Sal_ppt_11.shp
# Number of data rows for BB, Sal_ppt, 12: 6
# Shapefile for BB: Sal_ppt for period 12 has been saved as SHP_BB_Sal_ppt_12.shp
# Number of data rows for BB, Sal_ppt, 13: 6
# Shapefile for BB: Sal_ppt for period 13 has been saved as SHP_BB_Sal_ppt_13.shp
# Number of data rows for BB, Sal_ppt, 14: 6
# Shapefile for BB: Sal_ppt for period 14 has been saved as SHP_BB_Sal_ppt_14.shp
# Number of data rows for BB, Sal_ppt, 15: 6
# Shapefile for BB: Sal_ppt for period 15 has been saved as SHP_BB_Sal_ppt_15.shp
# Number of data rows for BB, Sal_ppt, 16: 6
# Shapefile for BB: Sal_ppt for period 16 has been saved as SHP_BB_Sal_ppt_16.shp
# Number of data rows for BB, Sal_ppt, 17: 6
# Shapefile for BB: Sal_ppt for period 17 has been saved as SHP_BB_Sal_ppt_17.shp
# Number of data rows for BB, Sal_ppt, 18: 5
# Shapefile for BB: Sal_ppt for period 18 has been saved as SHP_BB_Sal_ppt_18.shp
# Number of data rows for BB, Sal_ppt, 19: 5
# Shapefile for BB: Sal_ppt for period 19 has been saved as SHP_BB_Sal_ppt_19.shp
# Number of data rows for BB, Sal_ppt, 20: 5
# Shapefile for BB: Sal_ppt for period 20 has been saved as SHP_BB_Sal_ppt_20.shp
# Number of data rows for BB, Sal_ppt, 21: 5
# Shapefile for BB: Sal_ppt for period 21 has been saved as SHP_BB_Sal_ppt_21.shp
# Number of data rows for BB, Sal_ppt, 22: 5
# Shapefile for BB: Sal_ppt for period 22 has been saved as SHP_BB_Sal_ppt_22.shp
# Number of data rows for BB, Sal_ppt, 23: 5
# Shapefile for BB: Sal_ppt for period 23 has been saved as SHP_BB_Sal_ppt_23.shp
# Number of data rows for BB, Sal_ppt, 24: 5
# Shapefile for BB: Sal_ppt for period 24 has been saved as SHP_BB_Sal_ppt_24.shp
# Number of data rows for BB, Sal_ppt, 25: 6
# Shapefile for BB: Sal_ppt for period 25 has been saved as SHP_BB_Sal_ppt_25.shp
# Number of data rows for BB, Sal_ppt, 26: 6
# Shapefile for BB: Sal_ppt for period 26 has been saved as SHP_BB_Sal_ppt_26.shp
# Number of data rows for BB, Sal_ppt, 27: 6
# Shapefile for BB: Sal_ppt for period 27 has been saved as SHP_BB_Sal_ppt_27.shp
# Number of data rows for BB, Sal_ppt, 28: 6
# Shapefile for BB: Sal_ppt for period 28 has been saved as SHP_BB_Sal_ppt_28.shp
# Number of data rows for BB, Sal_ppt, 29: 6
# Shapefile for BB: Sal_ppt for period 29 has been saved as SHP_BB_Sal_ppt_29.shp
# Number of data rows for BB, Sal_ppt, 30: 6
# Shapefile for BB: Sal_ppt for period 30 has been saved as SHP_BB_Sal_ppt_30.shp
# Number of data rows for BB, Sal_ppt, 31: 6
# Shapefile for BB: Sal_ppt for period 31 has been saved as SHP_BB_Sal_ppt_31.shp
# Number of data rows for BB, Sal_ppt, 32: 6
# Shapefile for BB: Sal_ppt for period 32 has been saved as SHP_BB_Sal_ppt_32.shp
# Number of data rows for BB, Sal_ppt, 33: 6
# Shapefile for BB: Sal_ppt for period 33 has been saved as SHP_BB_Sal_ppt_33.shp
# Number of data rows for BB, Sal_ppt, 34: 6
# Shapefile for BB: Sal_ppt for period 34 has been saved as SHP_BB_Sal_ppt_34.shp
# Number of data rows for BB, Sal_ppt, 35: 5
# Shapefile for BB: Sal_ppt for period 35 has been saved as SHP_BB_Sal_ppt_35.shp
# Number of data rows for BB, Sal_ppt, 36: 5
# Shapefile for BB: Sal_ppt for period 36 has been saved as SHP_BB_Sal_ppt_36.shp
# Number of data rows for BB, Sal_ppt, 37: 6
# Shapefile for BB: Sal_ppt for period 37 has been saved as SHP_BB_Sal_ppt_37.shp
# Number of data rows for BB, Sal_ppt, 38: 6
# Shapefile for BB: Sal_ppt for period 38 has been saved as SHP_BB_Sal_ppt_38.shp
# Number of data rows for BB, Sal_ppt, 39: 12
# Shapefile for BB: Sal_ppt for period 39 has been saved as SHP_BB_Sal_ppt_39.shp
# Number of data rows for BB, Sal_ppt, 40: 6
# Shapefile for BB: Sal_ppt for period 40 has been saved as SHP_BB_Sal_ppt_40.shp
# Number of data rows for BB, Sal_ppt, 41: 6
# Shapefile for BB: Sal_ppt for period 41 has been saved as SHP_BB_Sal_ppt_41.shp
# Number of data rows for BB, Sal_ppt, 42: 5
# Shapefile for BB: Sal_ppt for period 42 has been saved as SHP_BB_Sal_ppt_42.shp
# Number of data rows for BB, Sal_ppt, 43: 5
# Shapefile for BB: Sal_ppt for period 43 has been saved as SHP_BB_Sal_ppt_43.shp
# Number of data rows for BB, Sal_ppt, 44: 5
# Shapefile for BB: Sal_ppt for period 44 has been saved as SHP_BB_Sal_ppt_44.shp
# No valid data found for area: BB, parameter: Sal_ppt, period: 45
# No valid data found for area: BB, parameter: Sal_ppt, period: 46
# No valid data found for area: BB, parameter: Sal_ppt, period: 47
# No valid data found for area: BB, parameter: Sal_ppt, period: 48
# No valid data found for area: BB, parameter: Sal_ppt, period: 49
# No valid data found for area: BB, parameter: Sal_ppt, period: 50
# No valid data found for area: BB, parameter: Sal_ppt, period: 51
# No valid data found for area: BB, parameter: Sal_ppt, period: 52
# Number of data rows for BB, Turb_ntu, 1: 4
# Shapefile for BB: Turb_ntu for period 1 has been saved as SHP_BB_Turb_ntu_1.shp
# Number of data rows for BB, Turb_ntu, 2: 4
# Shapefile for BB: Turb_ntu for period 2 has been saved as SHP_BB_Turb_ntu_2.shp
# Number of data rows for BB, Turb_ntu, 3: 5
# Shapefile for BB: Turb_ntu for period 3 has been saved as SHP_BB_Turb_ntu_3.shp
# Number of data rows for BB, Turb_ntu, 4: 6
# Shapefile for BB: Turb_ntu for period 4 has been saved as SHP_BB_Turb_ntu_4.shp
# Number of data rows for BB, Turb_ntu, 5: 6
# Shapefile for BB: Turb_ntu for period 5 has been saved as SHP_BB_Turb_ntu_5.shp
# Number of data rows for BB, Turb_ntu, 6: 6
# Shapefile for BB: Turb_ntu for period 6 has been saved as SHP_BB_Turb_ntu_6.shp
# Number of data rows for BB, Turb_ntu, 7: 5
# Shapefile for BB: Turb_ntu for period 7 has been saved as SHP_BB_Turb_ntu_7.shp
# Number of data rows for BB, Turb_ntu, 8: 5
# Shapefile for BB: Turb_ntu for period 8 has been saved as SHP_BB_Turb_ntu_8.shp
# Number of data rows for BB, Turb_ntu, 9: 6
# Shapefile for BB: Turb_ntu for period 9 has been saved as SHP_BB_Turb_ntu_9.shp
# Number of data rows for BB, Turb_ntu, 10: 5
# Shapefile for BB: Turb_ntu for period 10 has been saved as SHP_BB_Turb_ntu_10.shp
# Number of data rows for BB, Turb_ntu, 11: 6
# Shapefile for BB: Turb_ntu for period 11 has been saved as SHP_BB_Turb_ntu_11.shp
# Number of data rows for BB, Turb_ntu, 12: 6
# Shapefile for BB: Turb_ntu for period 12 has been saved as SHP_BB_Turb_ntu_12.shp
# Number of data rows for BB, Turb_ntu, 13: 6
# Shapefile for BB: Turb_ntu for period 13 has been saved as SHP_BB_Turb_ntu_13.shp
# Number of data rows for BB, Turb_ntu, 14: 6
# Shapefile for BB: Turb_ntu for period 14 has been saved as SHP_BB_Turb_ntu_14.shp
# Number of data rows for BB, Turb_ntu, 15: 6
# Shapefile for BB: Turb_ntu for period 15 has been saved as SHP_BB_Turb_ntu_15.shp
# Number of data rows for BB, Turb_ntu, 16: 6
# Shapefile for BB: Turb_ntu for period 16 has been saved as SHP_BB_Turb_ntu_16.shp
# Number of data rows for BB, Turb_ntu, 17: 6
# Shapefile for BB: Turb_ntu for period 17 has been saved as SHP_BB_Turb_ntu_17.shp
# Number of data rows for BB, Turb_ntu, 18: 5
# Shapefile for BB: Turb_ntu for period 18 has been saved as SHP_BB_Turb_ntu_18.shp
# Number of data rows for BB, Turb_ntu, 19: 5
# Shapefile for BB: Turb_ntu for period 19 has been saved as SHP_BB_Turb_ntu_19.shp
# Number of data rows for BB, Turb_ntu, 20: 5
# Shapefile for BB: Turb_ntu for period 20 has been saved as SHP_BB_Turb_ntu_20.shp
# Number of data rows for BB, Turb_ntu, 21: 5
# Shapefile for BB: Turb_ntu for period 21 has been saved as SHP_BB_Turb_ntu_21.shp
# Number of data rows for BB, Turb_ntu, 22: 5
# Shapefile for BB: Turb_ntu for period 22 has been saved as SHP_BB_Turb_ntu_22.shp
# Number of data rows for BB, Turb_ntu, 23: 5
# Shapefile for BB: Turb_ntu for period 23 has been saved as SHP_BB_Turb_ntu_23.shp
# Number of data rows for BB, Turb_ntu, 24: 5
# Shapefile for BB: Turb_ntu for period 24 has been saved as SHP_BB_Turb_ntu_24.shp
# Number of data rows for BB, Turb_ntu, 25: 6
# Shapefile for BB: Turb_ntu for period 25 has been saved as SHP_BB_Turb_ntu_25.shp
# Number of data rows for BB, Turb_ntu, 26: 6
# Shapefile for BB: Turb_ntu for period 26 has been saved as SHP_BB_Turb_ntu_26.shp
# Number of data rows for BB, Turb_ntu, 27: 6
# Shapefile for BB: Turb_ntu for period 27 has been saved as SHP_BB_Turb_ntu_27.shp
# Number of data rows for BB, Turb_ntu, 28: 6
# Shapefile for BB: Turb_ntu for period 28 has been saved as SHP_BB_Turb_ntu_28.shp
# Number of data rows for BB, Turb_ntu, 29: 6
# Shapefile for BB: Turb_ntu for period 29 has been saved as SHP_BB_Turb_ntu_29.shp
# Number of data rows for BB, Turb_ntu, 30: 6
# Shapefile for BB: Turb_ntu for period 30 has been saved as SHP_BB_Turb_ntu_30.shp
# Number of data rows for BB, Turb_ntu, 31: 6
# Shapefile for BB: Turb_ntu for period 31 has been saved as SHP_BB_Turb_ntu_31.shp
# Number of data rows for BB, Turb_ntu, 32: 6
# Shapefile for BB: Turb_ntu for period 32 has been saved as SHP_BB_Turb_ntu_32.shp
# Number of data rows for BB, Turb_ntu, 33: 6
# Shapefile for BB: Turb_ntu for period 33 has been saved as SHP_BB_Turb_ntu_33.shp
# Number of data rows for BB, Turb_ntu, 34: 6
# Shapefile for BB: Turb_ntu for period 34 has been saved as SHP_BB_Turb_ntu_34.shp
# Number of data rows for BB, Turb_ntu, 35: 5
# Shapefile for BB: Turb_ntu for period 35 has been saved as SHP_BB_Turb_ntu_35.shp
# Number of data rows for BB, Turb_ntu, 36: 5
# Shapefile for BB: Turb_ntu for period 36 has been saved as SHP_BB_Turb_ntu_36.shp
# Number of data rows for BB, Turb_ntu, 37: 6
# Shapefile for BB: Turb_ntu for period 37 has been saved as SHP_BB_Turb_ntu_37.shp
# Number of data rows for BB, Turb_ntu, 38: 6
# Shapefile for BB: Turb_ntu for period 38 has been saved as SHP_BB_Turb_ntu_38.shp
# Number of data rows for BB, Turb_ntu, 39: 12
# Shapefile for BB: Turb_ntu for period 39 has been saved as SHP_BB_Turb_ntu_39.shp
# Number of data rows for BB, Turb_ntu, 40: 6
# Shapefile for BB: Turb_ntu for period 40 has been saved as SHP_BB_Turb_ntu_40.shp
# Number of data rows for BB, Turb_ntu, 41: 6
# Shapefile for BB: Turb_ntu for period 41 has been saved as SHP_BB_Turb_ntu_41.shp
# Number of data rows for BB, Turb_ntu, 42: 5
# Shapefile for BB: Turb_ntu for period 42 has been saved as SHP_BB_Turb_ntu_42.shp
# Number of data rows for BB, Turb_ntu, 43: 5
# Shapefile for BB: Turb_ntu for period 43 has been saved as SHP_BB_Turb_ntu_43.shp
# Number of data rows for BB, Turb_ntu, 44: 5
# Shapefile for BB: Turb_ntu for period 44 has been saved as SHP_BB_Turb_ntu_44.shp
# No valid data found for area: BB, parameter: Turb_ntu, period: 45
# No valid data found for area: BB, parameter: Turb_ntu, period: 46
# No valid data found for area: BB, parameter: Turb_ntu, period: 47
# No valid data found for area: BB, parameter: Turb_ntu, period: 48
# No valid data found for area: BB, parameter: Turb_ntu, period: 49
# No valid data found for area: BB, parameter: Turb_ntu, period: 50
# No valid data found for area: BB, parameter: Turb_ntu, period: 51
# No valid data found for area: BB, parameter: Turb_ntu, period: 52
# Number of data rows for BB, T_c, 1: 4
# Shapefile for BB: T_c for period 1 has been saved as SHP_BB_T_c_1.shp
# Number of data rows for BB, T_c, 2: 4
# Shapefile for BB: T_c for period 2 has been saved as SHP_BB_T_c_2.shp
# Number of data rows for BB, T_c, 3: 5
# Shapefile for BB: T_c for period 3 has been saved as SHP_BB_T_c_3.shp
# Number of data rows for BB, T_c, 4: 6
# Shapefile for BB: T_c for period 4 has been saved as SHP_BB_T_c_4.shp
# Number of data rows for BB, T_c, 5: 6
# Shapefile for BB: T_c for period 5 has been saved as SHP_BB_T_c_5.shp
# Number of data rows for BB, T_c, 6: 6
# Shapefile for BB: T_c for period 6 has been saved as SHP_BB_T_c_6.shp
# Number of data rows for BB, T_c, 7: 5
# Shapefile for BB: T_c for period 7 has been saved as SHP_BB_T_c_7.shp
# Number of data rows for BB, T_c, 8: 5
# Shapefile for BB: T_c for period 8 has been saved as SHP_BB_T_c_8.shp
# Number of data rows for BB, T_c, 9: 6
# Shapefile for BB: T_c for period 9 has been saved as SHP_BB_T_c_9.shp
# Number of data rows for BB, T_c, 10: 6
# Shapefile for BB: T_c for period 10 has been saved as SHP_BB_T_c_10.shp
# Number of data rows for BB, T_c, 11: 6
# Shapefile for BB: T_c for period 11 has been saved as SHP_BB_T_c_11.shp
# Number of data rows for BB, T_c, 12: 6
# Shapefile for BB: T_c for period 12 has been saved as SHP_BB_T_c_12.shp
# Number of data rows for BB, T_c, 13: 6
# Shapefile for BB: T_c for period 13 has been saved as SHP_BB_T_c_13.shp
# Number of data rows for BB, T_c, 14: 6
# Shapefile for BB: T_c for period 14 has been saved as SHP_BB_T_c_14.shp
# Number of data rows for BB, T_c, 15: 6
# Shapefile for BB: T_c for period 15 has been saved as SHP_BB_T_c_15.shp
# Number of data rows for BB, T_c, 16: 6
# Shapefile for BB: T_c for period 16 has been saved as SHP_BB_T_c_16.shp
# Number of data rows for BB, T_c, 17: 6
# Shapefile for BB: T_c for period 17 has been saved as SHP_BB_T_c_17.shp
# Number of data rows for BB, T_c, 18: 5
# Shapefile for BB: T_c for period 18 has been saved as SHP_BB_T_c_18.shp
# Number of data rows for BB, T_c, 19: 5
# Shapefile for BB: T_c for period 19 has been saved as SHP_BB_T_c_19.shp
# Number of data rows for BB, T_c, 20: 5
# Shapefile for BB: T_c for period 20 has been saved as SHP_BB_T_c_20.shp
# Number of data rows for BB, T_c, 21: 5
# Shapefile for BB: T_c for period 21 has been saved as SHP_BB_T_c_21.shp
# Number of data rows for BB, T_c, 22: 5
# Shapefile for BB: T_c for period 22 has been saved as SHP_BB_T_c_22.shp
# Number of data rows for BB, T_c, 23: 5
# Shapefile for BB: T_c for period 23 has been saved as SHP_BB_T_c_23.shp
# Number of data rows for BB, T_c, 24: 5
# Shapefile for BB: T_c for period 24 has been saved as SHP_BB_T_c_24.shp
# Number of data rows for BB, T_c, 25: 6
# Shapefile for BB: T_c for period 25 has been saved as SHP_BB_T_c_25.shp
# Number of data rows for BB, T_c, 26: 6
# Shapefile for BB: T_c for period 26 has been saved as SHP_BB_T_c_26.shp
# Number of data rows for BB, T_c, 27: 6
# Shapefile for BB: T_c for period 27 has been saved as SHP_BB_T_c_27.shp
# Number of data rows for BB, T_c, 28: 6
# Shapefile for BB: T_c for period 28 has been saved as SHP_BB_T_c_28.shp
# Number of data rows for BB, T_c, 29: 6
# Shapefile for BB: T_c for period 29 has been saved as SHP_BB_T_c_29.shp
# Number of data rows for BB, T_c, 30: 6
# Shapefile for BB: T_c for period 30 has been saved as SHP_BB_T_c_30.shp
# Number of data rows for BB, T_c, 31: 6
# Shapefile for BB: T_c for period 31 has been saved as SHP_BB_T_c_31.shp
# Number of data rows for BB, T_c, 32: 6
# Shapefile for BB: T_c for period 32 has been saved as SHP_BB_T_c_32.shp
# Number of data rows for BB, T_c, 33: 6
# Shapefile for BB: T_c for period 33 has been saved as SHP_BB_T_c_33.shp
# Number of data rows for BB, T_c, 34: 6
# Shapefile for BB: T_c for period 34 has been saved as SHP_BB_T_c_34.shp
# Number of data rows for BB, T_c, 35: 5
# Shapefile for BB: T_c for period 35 has been saved as SHP_BB_T_c_35.shp
# Number of data rows for BB, T_c, 36: 5
# Shapefile for BB: T_c for period 36 has been saved as SHP_BB_T_c_36.shp
# Number of data rows for BB, T_c, 37: 6
# Shapefile for BB: T_c for period 37 has been saved as SHP_BB_T_c_37.shp
# Number of data rows for BB, T_c, 38: 6
# Shapefile for BB: T_c for period 38 has been saved as SHP_BB_T_c_38.shp
# Number of data rows for BB, T_c, 39: 12
# Shapefile for BB: T_c for period 39 has been saved as SHP_BB_T_c_39.shp
# Number of data rows for BB, T_c, 40: 6
# Shapefile for BB: T_c for period 40 has been saved as SHP_BB_T_c_40.shp
# Number of data rows for BB, T_c, 41: 6
# Shapefile for BB: T_c for period 41 has been saved as SHP_BB_T_c_41.shp
# Number of data rows for BB, T_c, 42: 5
# Shapefile for BB: T_c for period 42 has been saved as SHP_BB_T_c_42.shp
# Number of data rows for BB, T_c, 43: 5
# Shapefile for BB: T_c for period 43 has been saved as SHP_BB_T_c_43.shp
# Number of data rows for BB, T_c, 44: 5
# Shapefile for BB: T_c for period 44 has been saved as SHP_BB_T_c_44.shp
# No valid data found for area: BB, parameter: T_c, period: 45
# No valid data found for area: BB, parameter: T_c, period: 46
# No valid data found for area: BB, parameter: T_c, period: 47
# No valid data found for area: BB, parameter: T_c, period: 48
# No valid data found for area: BB, parameter: T_c, period: 49
# ...
# Number of data rows for GTM, Sal_ppt, 15: 3
# Shapefile for GTM: Sal_ppt for period 15 has been saved as SHP_GTM_Sal_ppt_15.shp
# Number of data rows for GTM, Sal_ppt, 16: 4
# Shapefile for GTM: Sal_ppt for period 16 has been saved as SHP_GTM_Sal_ppt_16.shp
# Number of data rows for GTM, Sal_ppt, 17: 4
# Shapefile for GTM: Sal_ppt for period 17 has been saved as SHP_GTM_Sal_ppt_17.shp
# Number of data rows for GTM, Sal_ppt, 18: 4
# Shapefile for GTM: Sal_ppt for period 18 has been saved as SHP_GTM_Sal_ppt_18.shp
# Number of data rows for GTM, Sal_ppt, 19: 4
# Shapefile for GTM: Sal_ppt for period 19 has been saved as SHP_GTM_Sal_ppt_19.shp
# Number of data rows for GTM, Sal_ppt, 20: 4
# Shapefile for GTM: Sal_ppt for period 20 has been saved as SHP_GTM_Sal_ppt_20.shp
# Number of data rows for GTM, Sal_ppt, 21: 4
# Shapefile for GTM: Sal_ppt for period 21 has been saved as SHP_GTM_Sal_ppt_21.shp
# Number of data rows for GTM, Sal_ppt, 22: 4
# Shapefile for GTM: Sal_ppt for period 22 has been saved as SHP_GTM_Sal_ppt_22.shp
# Number of data rows for GTM, Sal_ppt, 23: 8
# Shapefile for GTM: Sal_ppt for period 23 has been saved as SHP_GTM_Sal_ppt_23.shp
# Number of data rows for GTM, Sal_ppt, 24: 4
# Shapefile for GTM: Sal_ppt for period 24 has been saved as SHP_GTM_Sal_ppt_24.shp
# Number of data rows for GTM, Sal_ppt, 25: 2
# Shapefile for GTM: Sal_ppt for period 25 has been saved as SHP_GTM_Sal_ppt_25.shp
# Number of data rows for GTM, Sal_ppt, 26: 2
# Shapefile for GTM: Sal_ppt for period 26 has been saved as SHP_GTM_Sal_ppt_26.shp
# Number of data rows for GTM, Sal_ppt, 27: 2
# Shapefile for GTM: Sal_ppt for period 27 has been saved as SHP_GTM_Sal_ppt_27.shp
# Number of data rows for GTM, Sal_ppt, 28: 4
# Shapefile for GTM: Sal_ppt for period 28 has been saved as SHP_GTM_Sal_ppt_28.shp
# Number of data rows for GTM, Sal_ppt, 29: 4
# Shapefile for GTM: Sal_ppt for period 29 has been saved as SHP_GTM_Sal_ppt_29.shp
# Number of data rows for GTM, Sal_ppt, 30: 4
# Shapefile for GTM: Sal_ppt for period 30 has been saved as SHP_GTM_Sal_ppt_30.shp
# Number of data rows for GTM, Sal_ppt, 31: 3
# Shapefile for GTM: Sal_ppt for period 31 has been saved as SHP_GTM_Sal_ppt_31.shp
# Number of data rows for GTM, Sal_ppt, 32: 4
# Shapefile for GTM: Sal_ppt for period 32 has been saved as SHP_GTM_Sal_ppt_32.shp
# Number of data rows for GTM, Sal_ppt, 33: 4
# Shapefile for GTM: Sal_ppt for period 33 has been saved as SHP_GTM_Sal_ppt_33.shp
# Number of data rows for GTM, Sal_ppt, 34: 4
# Shapefile for GTM: Sal_ppt for period 34 has been saved as SHP_GTM_Sal_ppt_34.shp
# Number of data rows for GTM, Sal_ppt, 35: 8
# Shapefile for GTM: Sal_ppt for period 35 has been saved as SHP_GTM_Sal_ppt_35.shp
# Number of data rows for GTM, Sal_ppt, 36: 4
# Shapefile for GTM: Sal_ppt for period 36 has been saved as SHP_GTM_Sal_ppt_36.shp
# Number of data rows for GTM, Sal_ppt, 37: 4
# Shapefile for GTM: Sal_ppt for period 37 has been saved as SHP_GTM_Sal_ppt_37.shp
# Number of data rows for GTM, Sal_ppt, 38: 4
# Shapefile for GTM: Sal_ppt for period 38 has been saved as SHP_GTM_Sal_ppt_38.shp
# Number of data rows for GTM, Sal_ppt, 39: 8
# Shapefile for GTM: Sal_ppt for period 39 has been saved as SHP_GTM_Sal_ppt_39.shp
# No valid data found for area: GTM, parameter: Sal_ppt, period: 40
# No valid data found for area: GTM, parameter: Sal_ppt, period: 41
# No valid data found for area: GTM, parameter: Sal_ppt, period: 42
# No valid data found for area: GTM, parameter: Sal_ppt, period: 43
# No valid data found for area: GTM, parameter: Sal_ppt, period: 44
# No valid data found for area: GTM, parameter: Sal_ppt, period: 45
# No valid data found for area: GTM, parameter: Sal_ppt, period: 46
# No valid data found for area: GTM, parameter: Sal_ppt, period: 47
# Number of data rows for GTM, Sal_ppt, 48: 4
# Shapefile for GTM: Sal_ppt for period 48 has been saved as SHP_GTM_Sal_ppt_48.shp
# Number of data rows for GTM, Sal_ppt, 49: 4
# Shapefile for GTM: Sal_ppt for period 49 has been saved as SHP_GTM_Sal_ppt_49.shp
# Number of data rows for GTM, Sal_ppt, 50: 4
# Shapefile for GTM: Sal_ppt for period 50 has been saved as SHP_GTM_Sal_ppt_50.shp
# Number of data rows for GTM, Sal_ppt, 51: 4
# Shapefile for GTM: Sal_ppt for period 51 has been saved as SHP_GTM_Sal_ppt_51.shp
# Number of data rows for GTM, Sal_ppt, 52: 4
# Shapefile for GTM: Sal_ppt for period 52 has been saved as SHP_GTM_Sal_ppt_52.shp
# Number of data rows for GTM, Turb_ntu, 1: 4
# Shapefile for GTM: Turb_ntu for period 1 has been saved as SHP_GTM_Turb_ntu_1.shp
# Number of data rows for GTM, Turb_ntu, 2: 4
# Shapefile for GTM: Turb_ntu for period 2 has been saved as SHP_GTM_Turb_ntu_2.shp
# Number of data rows for GTM, Turb_ntu, 3: 4
# Shapefile for GTM: Turb_ntu for period 3 has been saved as SHP_GTM_Turb_ntu_3.shp
# Number of data rows for GTM, Turb_ntu, 4: 4
# Shapefile for GTM: Turb_ntu for period 4 has been saved as SHP_GTM_Turb_ntu_4.shp
# Number of data rows for GTM, Turb_ntu, 5: 4
# Shapefile for GTM: Turb_ntu for period 5 has been saved as SHP_GTM_Turb_ntu_5.shp
# Number of data rows for GTM, Turb_ntu, 6: 4
# Shapefile for GTM: Turb_ntu for period 6 has been saved as SHP_GTM_Turb_ntu_6.shp
# Number of data rows for GTM, Turb_ntu, 7: 4
# Shapefile for GTM: Turb_ntu for period 7 has been saved as SHP_GTM_Turb_ntu_7.shp
# Number of data rows for GTM, Turb_ntu, 8: 4
# Shapefile for GTM: Turb_ntu for period 8 has been saved as SHP_GTM_Turb_ntu_8.shp
# Number of data rows for GTM, Turb_ntu, 9: 4
# Shapefile for GTM: Turb_ntu for period 9 has been saved as SHP_GTM_Turb_ntu_9.shp
# Number of data rows for GTM, Turb_ntu, 10: 8
# Shapefile for GTM: Turb_ntu for period 10 has been saved as SHP_GTM_Turb_ntu_10.shp
# Number of data rows for GTM, Turb_ntu, 11: 4
# Shapefile for GTM: Turb_ntu for period 11 has been saved as SHP_GTM_Turb_ntu_11.shp
# Number of data rows for GTM, Turb_ntu, 12: 4
# Shapefile for GTM: Turb_ntu for period 12 has been saved as SHP_GTM_Turb_ntu_12.shp
# Number of data rows for GTM, Turb_ntu, 13: 4
# Shapefile for GTM: Turb_ntu for period 13 has been saved as SHP_GTM_Turb_ntu_13.shp
# Number of data rows for GTM, Turb_ntu, 14: 4
# Shapefile for GTM: Turb_ntu for period 14 has been saved as SHP_GTM_Turb_ntu_14.shp
# Number of data rows for GTM, Turb_ntu, 15: 4
# Shapefile for GTM: Turb_ntu for period 15 has been saved as SHP_GTM_Turb_ntu_15.shp
# Number of data rows for GTM, Turb_ntu, 16: 4
# Shapefile for GTM: Turb_ntu for period 16 has been saved as SHP_GTM_Turb_ntu_16.shp
# Number of data rows for GTM, Turb_ntu, 17: 3
# Shapefile for GTM: Turb_ntu for period 17 has been saved as SHP_GTM_Turb_ntu_17.shp
# Number of data rows for GTM, Turb_ntu, 18: 4
# Shapefile for GTM: Turb_ntu for period 18 has been saved as SHP_GTM_Turb_ntu_18.shp
# Number of data rows for GTM, Turb_ntu, 19: 4
# Shapefile for GTM: Turb_ntu for period 19 has been saved as SHP_GTM_Turb_ntu_19.shp
# Number of data rows for GTM, Turb_ntu, 20: 4
# Shapefile for GTM: Turb_ntu for period 20 has been saved as SHP_GTM_Turb_ntu_20.shp
# Number of data rows for GTM, Turb_ntu, 21: 4
# Shapefile for GTM: Turb_ntu for period 21 has been saved as SHP_GTM_Turb_ntu_21.shp
# Number of data rows for GTM, Turb_ntu, 22: 4
# Shapefile for GTM: Turb_ntu for period 22 has been saved as SHP_GTM_Turb_ntu_22.shp
# Number of data rows for GTM, Turb_ntu, 23: 8
# Shapefile for GTM: Turb_ntu for period 23 has been saved as SHP_GTM_Turb_ntu_23.shp
# Number of data rows for GTM, Turb_ntu, 24: 4
# Shapefile for GTM: Turb_ntu for period 24 has been saved as SHP_GTM_Turb_ntu_24.shp
# Number of data rows for GTM, Turb_ntu, 25: 4
# Shapefile for GTM: Turb_ntu for period 25 has been saved as SHP_GTM_Turb_ntu_25.shp
# Number of data rows for GTM, Turb_ntu, 26: 4
# Shapefile for GTM: Turb_ntu for period 26 has been saved as SHP_GTM_Turb_ntu_26.shp
# Number of data rows for GTM, Turb_ntu, 27: 4
# Shapefile for GTM: Turb_ntu for period 27 has been saved as SHP_GTM_Turb_ntu_27.shp
# Number of data rows for GTM, Turb_ntu, 28: 4
# Shapefile for GTM: Turb_ntu for period 28 has been saved as SHP_GTM_Turb_ntu_28.shp
# Number of data rows for GTM, Turb_ntu, 29: 4
# Shapefile for GTM: Turb_ntu for period 29 has been saved as SHP_GTM_Turb_ntu_29.shp
# Number of data rows for GTM, Turb_ntu, 30: 4
# Shapefile for GTM: Turb_ntu for period 30 has been saved as SHP_GTM_Turb_ntu_30.shp
# Number of data rows for GTM, Turb_ntu, 31: 3
# Shapefile for GTM: Turb_ntu for period 31 has been saved as SHP_GTM_Turb_ntu_31.shp
# Number of data rows for GTM, Turb_ntu, 32: 4
# Shapefile for GTM: Turb_ntu for period 32 has been saved as SHP_GTM_Turb_ntu_32.shp
# Number of data rows for GTM, Turb_ntu, 33: 4
# Shapefile for GTM: Turb_ntu for period 33 has been saved as SHP_GTM_Turb_ntu_33.shp
# Number of data rows for GTM, Turb_ntu, 34: 4
# Shapefile for GTM: Turb_ntu for period 34 has been saved as SHP_GTM_Turb_ntu_34.shp
# Number of data rows for GTM, Turb_ntu, 35: 8
# Shapefile for GTM: Turb_ntu for period 35 has been saved as SHP_GTM_Turb_ntu_35.shp
# Number of data rows for GTM, Turb_ntu, 36: 4
# Shapefile for GTM: Turb_ntu for period 36 has been saved as SHP_GTM_Turb_ntu_36.shp
# Number of data rows for GTM, Turb_ntu, 37: 4
# Shapefile for GTM: Turb_ntu for period 37 has been saved as SHP_GTM_Turb_ntu_37.shp
# Number of data rows for GTM, Turb_ntu, 38: 4
# Shapefile for GTM: Turb_ntu for period 38 has been saved as SHP_GTM_Turb_ntu_38.shp
# Number of data rows for GTM, Turb_ntu, 39: 8
# Shapefile for GTM: Turb_ntu for period 39 has been saved as SHP_GTM_Turb_ntu_39.shp
# No valid data found for area: GTM, parameter: Turb_ntu, period: 40
# No valid data found for area: GTM, parameter: Turb_ntu, period: 41
# No valid data found for area: GTM, parameter: Turb_ntu, period: 42
# No valid data found for area: GTM, parameter: Turb_ntu, period: 43
# No valid data found for area: GTM, parameter: Turb_ntu, period: 44
# No valid data found for area: GTM, parameter: Turb_ntu, period: 45
# No valid data found for area: GTM, parameter: Turb_ntu, period: 46
# No valid data found for area: GTM, parameter: Turb_ntu, period: 47
# Number of data rows for GTM, Turb_ntu, 48: 4
# Shapefile for GTM: Turb_ntu for period 48 has been saved as SHP_GTM_Turb_ntu_48.shp
# Number of data rows for GTM, Turb_ntu, 49: 4
# Shapefile for GTM: Turb_ntu for period 49 has been saved as SHP_GTM_Turb_ntu_49.shp
# Number of data rows for GTM, Turb_ntu, 50: 4
# Shapefile for GTM: Turb_ntu for period 50 has been saved as SHP_GTM_Turb_ntu_50.shp
# Number of data rows for GTM, Turb_ntu, 51: 4
# Shapefile for GTM: Turb_ntu for period 51 has been saved as SHP_GTM_Turb_ntu_51.shp
# Number of data rows for GTM, Turb_ntu, 52: 4
# Shapefile for GTM: Turb_ntu for period 52 has been saved as SHP_GTM_Turb_ntu_52.shp
# Number of data rows for GTM, T_c, 1: 4
# Shapefile for GTM: T_c for period 1 has been saved as SHP_GTM_T_c_1.shp
# Number of data rows for GTM, T_c, 2: 4
# Shapefile for GTM: T_c for period 2 has been saved as SHP_GTM_T_c_2.shp
# Number of data rows for GTM, T_c, 3: 4
# Shapefile for GTM: T_c for period 3 has been saved as SHP_GTM_T_c_3.shp
# Number of data rows for GTM, T_c, 4: 4
# Shapefile for GTM: T_c for period 4 has been saved as SHP_GTM_T_c_4.shp
# Number of data rows for GTM, T_c, 5: 4
# Shapefile for GTM: T_c for period 5 has been saved as SHP_GTM_T_c_5.shp
# Number of data rows for GTM, T_c, 6: 4
# Shapefile for GTM: T_c for period 6 has been saved as SHP_GTM_T_c_6.shp
# Number of data rows for GTM, T_c, 7: 4
# Shapefile for GTM: T_c for period 7 has been saved as SHP_GTM_T_c_7.shp
# Number of data rows for GTM, T_c, 8: 4
# Shapefile for GTM: T_c for period 8 has been saved as SHP_GTM_T_c_8.shp
# Number of data rows for GTM, T_c, 9: 4
# Shapefile for GTM: T_c for period 9 has been saved as SHP_GTM_T_c_9.shp
# Number of data rows for GTM, T_c, 10: 8
# Shapefile for GTM: T_c for period 10 has been saved as SHP_GTM_T_c_10.shp
# Number of data rows for GTM, T_c, 11: 4
# Shapefile for GTM: T_c for period 11 has been saved as SHP_GTM_T_c_11.shp
# Number of data rows for GTM, T_c, 12: 4
# Shapefile for GTM: T_c for period 12 has been saved as SHP_GTM_T_c_12.shp
# Number of data rows for GTM, T_c, 13: 4
# Shapefile for GTM: T_c for period 13 has been saved as SHP_GTM_T_c_13.shp
# Number of data rows for GTM, T_c, 14: 4
# Shapefile for GTM: T_c for period 14 has been saved as SHP_GTM_T_c_14.shp
# Number of data rows for GTM, T_c, 15: 4
# Shapefile for GTM: T_c for period 15 has been saved as SHP_GTM_T_c_15.shp
# Number of data rows for GTM, T_c, 16: 4
# Shapefile for GTM: T_c for period 16 has been saved as SHP_GTM_T_c_16.shp
# Number of data rows for GTM, T_c, 17: 4
# Shapefile for GTM: T_c for period 17 has been saved as SHP_GTM_T_c_17.shp
# Number of data rows for GTM, T_c, 18: 4
# Shapefile for GTM: T_c for period 18 has been saved as SHP_GTM_T_c_18.shp
# Number of data rows for GTM, T_c, 19: 4
# Shapefile for GTM: T_c for period 19 has been saved as SHP_GTM_T_c_19.shp
# Number of data rows for GTM, T_c, 20: 4
# Shapefile for GTM: T_c for period 20 has been saved as SHP_GTM_T_c_20.shp
# Number of data rows for GTM, T_c, 21: 4
# Shapefile for GTM: T_c for period 21 has been saved as SHP_GTM_T_c_21.shp
# Number of data rows for GTM, T_c, 22: 4
# Shapefile for GTM: T_c for period 22 has been saved as SHP_GTM_T_c_22.shp
# Number of data rows for GTM, T_c, 23: 8
# Shapefile for GTM: T_c for period 23 has been saved as SHP_GTM_T_c_23.shp
# Number of data rows for GTM, T_c, 24: 4
# Shapefile for GTM: T_c for period 24 has been saved as SHP_GTM_T_c_24.shp
# Number of data rows for GTM, T_c, 25: 4
# Shapefile for GTM: T_c for period 25 has been saved as SHP_GTM_T_c_25.shp
# Number of data rows for GTM, T_c, 26: 4
# Shapefile for GTM: T_c for period 26 has been saved as SHP_GTM_T_c_26.shp
# Number of data rows for GTM, T_c, 27: 4
# Shapefile for GTM: T_c for period 27 has been saved as SHP_GTM_T_c_27.shp
# Number of data rows for GTM, T_c, 28: 4
# Shapefile for GTM: T_c for period 28 has been saved as SHP_GTM_T_c_28.shp
# Number of data rows for GTM, T_c, 29: 4
# Shapefile for GTM: T_c for period 29 has been saved as SHP_GTM_T_c_29.shp
# Number of data rows for GTM, T_c, 30: 4
# Shapefile for GTM: T_c for period 30 has been saved as SHP_GTM_T_c_30.shp
# Number of data rows for GTM, T_c, 31: 3
# Shapefile for GTM: T_c for period 31 has been saved as SHP_GTM_T_c_31.shp
# Number of data rows for GTM, T_c, 32: 4
# Shapefile for GTM: T_c for period 32 has been saved as SHP_GTM_T_c_32.shp
# Number of data rows for GTM, T_c, 33: 4
# Shapefile for GTM: T_c for period 33 has been saved as SHP_GTM_T_c_33.shp
# Number of data rows for GTM, T_c, 34: 4
# Shapefile for GTM: T_c for period 34 has been saved as SHP_GTM_T_c_34.shp
# Number of data rows for GTM, T_c, 35: 8
# Shapefile for GTM: T_c for period 35 has been saved as SHP_GTM_T_c_35.shp
# Number of data rows for GTM, T_c, 36: 4
# Shapefile for GTM: T_c for period 36 has been saved as SHP_GTM_T_c_36.shp
# Number of data rows for GTM, T_c, 37: 4
# Shapefile for GTM: T_c for period 37 has been saved as SHP_GTM_T_c_37.shp
# Number of data rows for GTM, T_c, 38: 4
# Shapefile for GTM: T_c for period 38 has been saved as SHP_GTM_T_c_38.shp
# Number of data rows for GTM, T_c, 39: 8
# Shapefile for GTM: T_c for period 39 has been saved as SHP_GTM_T_c_39.shp
# No valid data found for area: GTM, parameter: T_c, period: 40
# No valid data found for area: GTM, parameter: T_c, period: 41
# No valid data found for area: GTM, parameter: T_c, period: 42
# No valid data found for area: GTM, parameter: T_c, period: 43
# No valid data found for area: GTM, parameter: T_c, period: 44
# No valid data found for area: GTM, parameter: T_c, period: 45
# No valid data found for area: GTM, parameter: T_c, period: 46
# No valid data found for area: GTM, parameter: T_c, period: 47
# Number of data rows for GTM, T_c, 48: 4
# Shapefile for GTM: T_c for period 48 has been saved as SHP_GTM_T_c_48.shp
# Number of data rows for GTM, T_c, 49: 4
# Shapefile for GTM: T_c for period 49 has been saved as SHP_GTM_T_c_49.shp
# Number of data rows for GTM, T_c, 50: 4
# Shapefile for GTM: T_c for period 50 has been saved as SHP_GTM_T_c_50.shp
# Number of data rows for GTM, T_c, 51: 4
# Shapefile for GTM: T_c for period 51 has been saved as SHP_GTM_T_c_51.shp
# Number of data rows for GTM, T_c, 52: 4
# Shapefile for GTM: T_c for period 52 has been saved as SHP_GTM_T_c_52.shp

# %% [markdown]
# # 3. Cross Validation for IDW <a class="anchor" id="reg_cv_idw"></a>

# %%
# Empty the shapefile folder
idw_rk.delete_all_files(idwCon_folder)

# %%
df_week_table
# Out:
#                     WaterBody          Parameter  Period Filename  \
# 0         Big Bend Seagrasses   Dissolved Oxygen       1
# 1         Big Bend Seagrasses   Dissolved Oxygen       2
# 2         Big Bend Seagrasses   Dissolved Oxygen       3
# 3         Big Bend Seagrasses   Dissolved Oxygen       4
# 4         Big Bend Seagrasses   Dissolved Oxygen       5
# ...                       ...                ...     ...      ...
# 1035  Guana Tolomato Matanzas  Water Temperature      48
# 1036  Guana Tolomato Matanzas  Water Temperature      49
# 1037  Guana Tolomato Matanzas  Water Temperature      50
# 1038  Guana Tolomato Matanzas  Water Temperature      51
# 1039  Guana Tolomato Matanzas  Water Temperature      52
#
#      NumDataPoints RMSE ME WbodyAcronym  startDate    endDate
# 0                                   BBS 2021-01-06 2021-01-12
# 1                                   BBS 2021-01-13 2021-01-19
# 2                                   BBS 2021-01-20 2021-01-26
# 3                                   BBS 2021-01-27 2021-02-02
# 4                                   BBS 2021-02-03 2021-02-09
# ...            ...  ... ..          ...        ...        ...
# 1035                                GTM 2017-03-04 2017-03-11
# 1036                                GTM 2017-03-11 2017-03-18
# 1037                                GTM 2017-03-18 2017-03-25
# 1038                                GTM 2017-03-25 2017-04-01
# 1039                                GTM 2017-04-01 2017-04-08
#
# [1040 rows x 10 columns]

# %%
# If the number of data points is less than 3，skipping calculate IDW
idw_rk.idw_interpolation1(df_week_table, shpCon_folder, idwCon_folder, waterbody_extent, barrier_folder)

# %% [markdown]
# # 4. Monthly Results <a class="anchor" id="month"></a>

# %%
area_ab = ["GTM","EB","CH","BB","BBS"]
period_type = [" 52 week"," Month"]
dfConTime["Period"] = ""
def select_data_period1(df,area,period):
    sheet_name = str(area) + str(period)
    df_period_table = pd.read_excel(gis_path + "All_Waterbodies_Season_Month_Week_Definitions.xlsx",sheet_name=sheet_name)
    df_select_area = df[df["WbodyAcronym"]==str(area)]
    df_period_table['Start Date'] = pd.to_datetime(df_period_table['Start Date'])
    df_period_table['End Date']   = pd.to_datetime(df_period_table['End Date'])
    sub_dfs = []

    for index, row in df_period_table.iterrows():
        start_date = row['Start Date']
        end_date   = row['End Date']
        sub_df = df_select_area[(df_select_area['SampleDate'] >= start_date) & (df_select_area['SampleDate'] < end_date)]
        sub_df['Period'] = row["Month"]
        sub_dfs.append(sub_df)
        
    df_period = pd.concat(sub_dfs,ignore_index=True)
    return df_period
# Out:
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2905189280.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfConTime["Period"] = ""

# %%
sel_month_temp = []
for each in area_ab:
    df_month_temp = select_data_period1(dfConTime,str(each)," Month")
    df_month_temp_group = df_month_temp.groupby(['WaterBody','ParameterName','ParameterUnits',
                                          'Year','Season','Latitude_DD','Longitude_DD','WbodyAcronym',"Period"])["ResultValue"].agg("mean").reset_index()
    sel_month_temp.append(df_month_temp_group)
df_month_select_Mean = pd.concat(sel_month_temp,ignore_index=True)
# Out:
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2905189280.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['Period'] = row["Month"]
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2905189280.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['Period'] = row["Month"]
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2905189280.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['Period'] = row["Month"]
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2905189280.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['Period'] = row["Month"]
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2905189280.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['Period'] = row["Month"]

# %%
# Define the EPSG codes for source (EPSG:4326) and target (EPSG:3086) coordinate systems
source_epsg = 'EPSG:4326'
target_epsg = 'EPSG:3086'

# Create a PyProj Transformer for the conversion
transformer = pyproj.Transformer.from_crs(source_epsg, target_epsg, always_xy=True)

# Define a function to apply the transformation to each row of the DataFrame
def transform_coordinates(row):
    x, y = transformer.transform(row['Longitude_DD'], row['Latitude_DD'])
    return pd.Series({'x': x, 'y': y})

# Apply the transformation function to the DataFrame and create new columns for the converted coordinates
df_month_select_Mean[['x', 'y']] = df_month_select_Mean.apply(transform_coordinates, axis=1)

# %%
waterBody = ['Big Bend Seagrasses', 'Biscayne Bay', 'Charlotte Harbor', 'Estero Bay', 'Guana Tolomato Matanzas']
parameter = ['Dissolved Oxygen', 'Salinity', 'Turbidity', 'Water Temperature']
waterBody_list = []
parameter_list= []
month_list = []
for i in waterBody:
    for j in parameter:
        for k in range(1,13):
            waterBody_list.append(i)
            parameter_list.append(j)
            month_list.append(k)

# %%
df_month_table = pd.DataFrame({
    "WaterBody":waterBody_list,
    "Parameter":parameter_list,
    "Period":month_list
})
df_month_table["Filename"] = ""
df_month_table["NumDataPoints"] = ""
df_month_table["RMSE"] = ""
df_month_table["ME"] = ""
df_month_table["WbodyAcronym"] = df_month_table["WaterBody"].map(area_shortnames)

# %%
name_ab = df_month_table["WbodyAcronym"].unique()
para_list = df_month_table["Parameter"].unique()
dfs_sub = []
for each in name_ab:
    sheet_name_use = str(each) + " Month"
    df_period_table_used = pd.read_excel(gis_path + "All_Waterbodies_Season_Month_Week_Definitions.xlsx",sheet_name=sheet_name_use)
    startDate = list(df_period_table_used["Start Date"])
    endDate   = list(df_period_table_used["End Date"])
    for para in para_list:
        df_temp_use = df_month_table[(df_month_table["WbodyAcronym"]==str(each))&(df_month_table["Parameter"]==str(para))]
        df_temp_use["startDate"] = startDate
        df_temp_use["endDate"]   = endDate
        dfs_sub.append(df_temp_use)
df_month_table = pd.concat(dfs_sub)
df_month_table.to_csv(gis_path + 'month_table.csv')
# Out:
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["startDate"] = startDate
# C:\Users\xiang11\AppData\Local\Temp\ipykernel_17892\2367120537.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp_use["endDate"]   = endDate

# %%
df_month_table
# Out:
#                    WaterBody          Parameter  Period Filename  \
# 0        Big Bend Seagrasses   Dissolved Oxygen       1
# 1        Big Bend Seagrasses   Dissolved Oxygen       2
# 2        Big Bend Seagrasses   Dissolved Oxygen       3
# 3        Big Bend Seagrasses   Dissolved Oxygen       4
# 4        Big Bend Seagrasses   Dissolved Oxygen       5
# ..                       ...                ...     ...      ...
# 235  Guana Tolomato Matanzas  Water Temperature       8
# 236  Guana Tolomato Matanzas  Water Temperature       9
# 237  Guana Tolomato Matanzas  Water Temperature      10
# 238  Guana Tolomato Matanzas  Water Temperature      11
# 239  Guana Tolomato Matanzas  Water Temperature      12
#
#     NumDataPoints RMSE ME WbodyAcronym  startDate    endDate
# 0                                  BBS 2021-01-08 2021-02-06
# 1                                  BBS 2021-02-07 2021-03-08
# 2                                  BBS 2021-03-09 2021-04-07
# 3                                  BBS 2021-04-08 2021-05-07
# 4                                  BBS 2021-05-08 2021-06-06
# ..            ...  ... ..          ...        ...        ...
# 235                                GTM 2016-11-07 2016-12-07
# 236                                GTM 2016-12-07 2017-01-06
# 237                                GTM 2017-01-06 2017-02-05
# 238                                GTM 2017-02-05 2017-03-07
# 239                                GTM 2017-03-07 2017-04-06
#
# [240 rows x 10 columns]

# %%
shpCon_folder = gis_path + r"shapefiles_Con/month"
idwCon_folder = gis_path + r"idw_Con/month"

# %%
idw_rk.fill_nan_rowids(df_month_select_Mean, 'RowID')

df_month_select_Mean['RowID'] = df_month_select_Mean['RowID'].astype(int)
df_month_select_Mean
# Out:
#                    WaterBody      ParameterName ParameterUnits  Year  Season  \
# 0    Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 1    Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 2    Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 3    Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 4    Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# ..                       ...                ...            ...   ...     ...
# 989      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Summer
# 990      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 991      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 992      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 993      Big Bend Seagrasses  Water Temperature      Degrees C  2022  Winter
#
#      Latitude_DD  Longitude_DD WbodyAcronym  Period  ResultValue  \
# 0      29.667071    -81.257403          GTM       6     5.142161
# 1      29.667071    -81.257403          GTM       7     3.728834
# 2      29.667071    -81.257403          GTM       8     6.632493
# 3      29.737041    -81.245953          GTM       6     5.606851
# 4      29.737041    -81.245953          GTM       7     6.354141
# ..           ...           ...          ...     ...          ...
# 989    29.647203    -83.421196          BBS       9    29.325253
# 990    29.647203    -83.421196          BBS       1    13.373354
# 991    29.647203    -83.421196          BBS       2    17.077020
# 992    29.647203    -83.421196          BBS      12    19.022835
# 993    29.647203    -83.421196          BBS      12    21.878788
#
#                  x              y  RowID
# 0    665054.340859  631868.366218      1
# 1    665054.340859  631868.366218      2
# 2    665054.340859  631868.366218      3
# 3    665987.248566  639659.363097      4
# 4    665987.248566  639659.363097      5
# ..             ...            ...    ...
# 989  455952.242067  626846.365120    990
# 990  455952.242067  626846.365120    991
# 991  455952.242067  626846.365120    992
# 992  455952.242067  626846.365120    993
# 993  455952.242067  626846.365120    994
#
# [994 rows x 13 columns]

# %%
# Merge interested with latitude and longitude columns
seasons_con_coord = idw_rk.merge_with_lat_long1(df_month_table, df_month_select_Mean)
seasons_con_coord
# Out:
#                     WaterBody          Parameter  Period Filename  \
# 0         Big Bend Seagrasses   Dissolved Oxygen       1
# 1         Big Bend Seagrasses   Dissolved Oxygen       2
# 2         Big Bend Seagrasses   Dissolved Oxygen       2
# 3         Big Bend Seagrasses   Dissolved Oxygen       3
# 4         Big Bend Seagrasses   Dissolved Oxygen       4
# ...                       ...                ...     ...      ...
# 997   Guana Tolomato Matanzas  Water Temperature      11
# 998   Guana Tolomato Matanzas  Water Temperature      12
# 999   Guana Tolomato Matanzas  Water Temperature      12
# 1000  Guana Tolomato Matanzas  Water Temperature      12
# 1001  Guana Tolomato Matanzas  Water Temperature      12
#
#      NumDataPoints RMSE ME WbodyAcronym  startDate    endDate              x  \
# 0                                   BBS 2021-01-08 2021-02-06  455952.242067
# 1                                   BBS 2021-02-07 2021-03-08  455952.242067
# 2                                   BBS 2021-02-07 2021-03-08  455952.242067
# 3                                   BBS 2021-03-09 2021-04-07  455952.242067
# 4                                   BBS 2021-04-08 2021-05-07  455952.242067
# ...            ...  ... ..          ...        ...        ...            ...
# 997                                 GTM 2017-02-05 2017-03-07  653509.737698
# 998                                 GTM 2017-03-07 2017-04-06  665054.340859
# 999                                 GTM 2017-03-07 2017-04-06  665987.248566
# 1000                                GTM 2017-03-07 2017-04-06  659731.434296
# 1001                                GTM 2017-03-07 2017-04-06  653509.737698
#
#                   y  RowID  ResultValue
# 0     626846.365120    944     8.356844
# 1     626846.365120    936     7.433333
# 2     626846.365120    945     7.730177
# 3     626846.365120    937     7.490700
# 4     626846.365120    938     6.859352
# ...             ...    ...          ...
# 997   674232.732990    234    18.666667
# 998   631868.366218    229    21.517071
# 999   639659.363097    231    20.061616
# 1000  654158.019057    233    20.107685
# 1001  674232.732990    235    20.587475
#
# [1002 rows x 14 columns]

# %%
idw_rk.create_shp_season1(seasons_con_coord, shpCon_folder)

# %%
# If the number of data points is less than 3，skipping calculate IDW
idw_rk.idw_interpolation1(df_month_table, shpCon_folder, idwCon_folder, waterbody_extent, barrier_folder)
