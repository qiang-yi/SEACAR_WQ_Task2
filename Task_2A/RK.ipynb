# %% [markdown]
# # RK Interpolation
#
# This document includes Python codes that conduct Regression Kriging (RK) Interpolation on each waterbody, including Guana Tolomato Matanzas (GTM), Estero Bay (EB), Charlotte Harbor (CH), Biscayne Bay (BB), Big Bend Seagrasses (BBS).
# parameters, including Dissolved oxygen (DO_mgl), Salinity (Sal_ppt), Turbidity (Turb_ntu), Temperature (T_c), Secchi (Secc_m), Total Nitrogen (TN_mgl) in arcpy environment.
#
# The analysis is conducted in the separate managed parameters of Total Nitrogen (TN_mgl), Dissolved oxygen (DO_mgl), Salinity (Sal_ppt), Turbidity (Turb_ntu), Temperature (T_c), and Secchi (Secc_m) in arcpy environment.
#
# * [1. Data Preprocess](#preprocessing)
# * [2. Generate Shapefiles](#create_shp)
# * [3. Regression Kriging for All Stations](#rk_all)

# %% [markdown]
# ## Load packages

# %%
import pandas as pd
import numpy  as np
import arcpy
from arcpy.sa import *
import os, time, math, importlib, sys
path = r'E:\Projects\SEACAR_WQ_2024\git\misc'
sys.path.insert(0, path)
import idw_rk
# !install conda install conda-forge::pyproj
import pyproj,csv

importlib.reload(idw_rk)

import warnings
warnings.filterwarnings('ignore')

# define scratch folder to avoid overwritting from parallel threats
arcpy.env.scratchWorkspace = r"E:\Projects\SEACAR_WQ_2024\scratch/RK_all"
arcpy.env.overwriteOutput = True

# %% [markdown]
# # 1. Preprocessing <a class="anchor" id="preprocessing"></a>
#
# ## 1.1 Load csv files

# %%
gis_path = r'E:/Projects/SEACAR_WQ_2024/GIS_Data/'

dfCon = pd.read_csv(gis_path + 'OEAT_Continuous_WQ-2024-Feb-21.csv', low_memory=False)
dfDis = pd.read_csv(gis_path + 'OEAT_Discrete_WQ-2024-May-06.csv', low_memory=False)

# %% [markdown]
# ## 1.2 Select data from 8 am to 18 pm in the continuous data

# %%
# Convert string to datetime
dfDis['SampleDate'] = pd.to_datetime(dfDis['SampleDate'], format='%Y-%m-%d %H:%M:%S.%f')
dfCon['SampleDate'] = pd.to_datetime(dfCon['SampleDate'], format='%Y-%m-%d %H:%M:%S.%f')


# Include date from 08:00 am to 18:00 pm
start_time = '08:00'
end_time = '18:00'

dfConTime = dfCon[dfCon['SampleDate'].dt.time.between(pd.to_datetime(start_time).time(), pd.to_datetime(end_time).time())]

# Concatenate time-filtered continuous and discrete data
dfAll = pd.concat([dfDis, dfConTime], ignore_index=True)

# %% [markdown]
# ## 1.3 Calculating average values at unique observation points

# %%
dfAll_Mean = dfAll.groupby(['WaterBody','ParameterName','ParameterUnits', 'Year','Season','Latitude_DD','Longitude_DD','WbodyAcronym'])["ResultValue"].agg("mean").reset_index()
dfAll = dfAll_Mean

# %% [markdown]
# ## 1.4 Convert coordinate system to EPSG: 3086

# %%
# Define the EPSG codes for source (EPSG:4326) and target (EPSG:3086) coordinate systems
source_epsg = 'EPSG:4326'
target_epsg = 'EPSG:3086'

# Create a PyProj Transformer for the conversion
transformer = pyproj.Transformer.from_crs(source_epsg, target_epsg, always_xy=True)

# Define a function to apply the transformation to each row of the DataFrame
def transform_coordinates(row):
    x, y = transformer.transform(row['Longitude_DD'], row['Latitude_DD'])
    return pd.Series({'x': x, 'y': y})

# Apply the transformation function to the DataFrame and create new columns for the converted coordinates
dfAll[['x', 'y']] = dfAll.apply(transform_coordinates, axis=1)

# %% [markdown]
# #### Save aggregated data to csv file

# %%
dfAll.to_csv(gis_path + 'OEAT_All_WQ-2024-May-06.csv', index=False)

# %% [markdown]
# ## 2. Prepare for batch interpolation
# ### 2.1 Preset abbreviation for waterbody and parameter name

# %%
area_shortnames = {
    'Guana Tolomato Matanzas': 'GTM',
    'Estero Bay': 'EB',
    'Charlotte Harbor': 'CH',
    'Biscayne Bay': 'BB',
    'Big Bend Seagrasses':'BBS'
}

param_shortnames = {
    'Salinity': 'Sal_ppt',
    'Total Nitrogen': 'TN_mgl',
    'Dissolved Oxygen': 'DO_mgl',
    'Turbidity':'Turb_ntu',
    'Secchi Depth':'Secc_m',
    'Water Temperature':'T_c'
}

# Set input parameters
waterbody_names = [
    'Guana Tolomato Matanzas',
    'Estero Bay',
    'Charlotte Harbor',
    'Biscayne Bay',
    'Big Bend Seagrasses'
]

covariates_dict = {
    "GTM":"LDI",
    "EB":"bathymetry+LDI+popden",
    "CH":"bathymetry+LDI+popden+water_flow_wet",
    "BB":"bathymetry+LDI+popden",
    "BBS":"bathymetry+LDI"
}

parameter_names = ['Dissolved Oxygen', 'Salinity', 'Secchi Depth', 'Total Nitrogen', 'Turbidity', 'Water Temperature']
# years = unique_years
seasons = ['Fall', 'Spring', 'Summer', 'Winter']
# shp_folder = gis_path + r"shapefiles_All"
shp_folder = gis_path + r"shapefiles"

# %% [markdown]
# ### 2.3 Load the table of study periods,  parameters, and seasons

# %%
seasons_all = pd.read_csv(gis_path + 'Seasons_all.csv', low_memory=False)

# %% [markdown]
# ### 2.4 Define output folders

# %%
shpAll_folder = gis_path + r"shapefiles/shapefiles_All" 

# Preview dataset
dfAll
# Out:
#                      WaterBody      ParameterName ParameterUnits  Year  \
# 0          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# 1          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# 2          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# 3          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# 4          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# ...                        ...                ...            ...   ...
# 77793  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
# 77794  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
# 77795  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
# 77796  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
# 77797  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
#
#        Season  Latitude_DD  Longitude_DD WbodyAcronym  ResultValue  \
# 0        Fall    29.008300    -82.825250          BBS     6.350000
# 1        Fall    29.036716    -83.129066          BBS     6.200000
# 2        Fall    29.046916    -83.033200          BBS     7.100000
# 3        Fall    29.054833    -82.758666          BBS     6.500000
# 4        Fall    29.056800    -83.059133          BBS     6.000000
# ...       ...          ...           ...          ...          ...
# 77793  Summer    30.025360    -81.370918          GTM    29.150000
# 77794  Summer    30.026440    -81.369403          GTM    29.500000
# 77795  Summer    30.033611    -81.353027          GTM    29.766667
# 77796  Summer    30.050338    -81.371008          GTM    29.675000
# 77797  Winter    29.722944    -81.264222          GTM    16.500000
#
#                    x              y
# 0      514236.421551  556316.396318
# 1      484670.524231  559226.858975
# 2      493981.422006  560428.927830
# 3      520659.055377  561546.969670
# 4      491452.167490  561506.993606
# ...              ...            ...
# 77793  653237.586095  671395.945419
# 77794  653380.952596  671518.961956
# 77795  654940.976043  672348.548670
# 77796  653169.830710  674167.856772
# 77797  664257.827848  638055.404228
#
# [77798 rows x 11 columns]

# %% [markdown]
# ### 2.6 Fill NaN RowID with unique ID, IDW function needs unique ID <a class="anchor" id="reg_id"></a>#

# %%
idw_rk.fill_nan_rowids(dfAll, 'RowID')

# Keep RowID as integer
dfAll['RowID'] = dfAll['RowID'].astype(int)
dfAll
# Out:
#                      WaterBody      ParameterName ParameterUnits  Year  \
# 0          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# 1          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# 2          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# 3          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# 4          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# ...                        ...                ...            ...   ...
# 77793  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
# 77794  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
# 77795  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
# 77796  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
# 77797  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
#
#        Season  Latitude_DD  Longitude_DD WbodyAcronym  ResultValue  \
# 0        Fall    29.008300    -82.825250          BBS     6.350000
# 1        Fall    29.036716    -83.129066          BBS     6.200000
# 2        Fall    29.046916    -83.033200          BBS     7.100000
# 3        Fall    29.054833    -82.758666          BBS     6.500000
# 4        Fall    29.056800    -83.059133          BBS     6.000000
# ...       ...          ...           ...          ...          ...
# 77793  Summer    30.025360    -81.370918          GTM    29.150000
# 77794  Summer    30.026440    -81.369403          GTM    29.500000
# 77795  Summer    30.033611    -81.353027          GTM    29.766667
# 77796  Summer    30.050338    -81.371008          GTM    29.675000
# 77797  Winter    29.722944    -81.264222          GTM    16.500000
#
#                    x              y  RowID
# 0      514236.421551  556316.396318      1
# 1      484670.524231  559226.858975      2
# 2      493981.422006  560428.927830      3
# 3      520659.055377  561546.969670      4
# 4      491452.167490  561506.993606      5
# ...              ...            ...    ...
# 77793  653237.586095  671395.945419  77794
# 77794  653380.952596  671518.961956  77795
# 77795  654940.976043  672348.548670  77796
# 77796  653169.830710  674167.856772  77797
# 77797  664257.827848  638055.404228  77798
#
# [77798 rows x 12 columns]

# %% [markdown]
# # 3. Create Shapefiles <a class="anchor" id="reg_create_shp"></a>

# %%
# Empty the shapefile folder
# idw_rk.delete_all_files(shpAll_folder)

# %%
# Merge interested with latitude and longitude columns
seasons_all_coord = idw_rk.merge_with_lat_long(seasons_all, dfAll)

# %%
seasons_all_coord.head()
# Out:
#                  WaterBody  Year Season       Parameter Filename  \
# 0  Guana Tolomato Matanzas  2015   Fall  Total Nitrogen      NaN
# 1  Guana Tolomato Matanzas  2015   Fall  Total Nitrogen      NaN
# 2  Guana Tolomato Matanzas  2015   Fall  Total Nitrogen      NaN
# 3  Guana Tolomato Matanzas  2015   Fall  Total Nitrogen      NaN
# 4  Guana Tolomato Matanzas  2015   Fall  Total Nitrogen      NaN
#
#    NumDataPoints  RMSE  ME              x              y  RowID  ResultValue
# 0              0   NaN NaN  669975.848287  626752.656623  75890     0.212233
# 1              0   NaN NaN  662275.840738  630059.187470  75891     1.034500
# 2              0   NaN NaN  667035.271306  631036.021679  75892     1.366500
# 3              0   NaN NaN  668862.259531  631692.835328  75893     0.192567
# 4              0   NaN NaN  665055.970903  631868.535738  75894     0.862000

# %% [markdown]
# ### Create Shapefiles

# %%
# Clean the shapefile folder if necessary
# RK.delete_all_files(shp_folder)
# Print number of data points in each shapefile
idw_rk.create_shp_season(seasons_all_coord, shpAll_folder)
# Out:
# Number of data rows for BBS, DO_mgl, 2020, Fall: 31
# Shapefile for BBS: DO_mgl for year 2020 and season Fall has been saved as SHP_BBS_DO_mgl_2020_Fall.shp
# Number of data rows for BBS, Sal_ppt, 2020, Fall: 26
# Shapefile for BBS: Sal_ppt for year 2020 and season Fall has been saved as SHP_BBS_Sal_ppt_2020_Fall.shp
# Number of data rows for BBS, Secc_m, 2020, Fall: 30
# Shapefile for BBS: Secc_m for year 2020 and season Fall has been saved as SHP_BBS_Secc_m_2020_Fall.shp
# Number of data rows for BBS, TN_mgl, 2020, Fall: 24
# Shapefile for BBS: TN_mgl for year 2020 and season Fall has been saved as SHP_BBS_TN_mgl_2020_Fall.shp
# Number of data rows for BBS, Turb_ntu, 2020, Fall: 31
# Shapefile for BBS: Turb_ntu for year 2020 and season Fall has been saved as SHP_BBS_Turb_ntu_2020_Fall.shp
# Number of data rows for BBS, T_c, 2020, Fall: 31
# Shapefile for BBS: T_c for year 2020 and season Fall has been saved as SHP_BBS_T_c_2020_Fall.shp
# Number of data rows for BBS, DO_mgl, 2020, Summer: 30
# Shapefile for BBS: DO_mgl for year 2020 and season Summer has been saved as SHP_BBS_DO_mgl_2020_Summer.shp
# Number of data rows for BBS, Sal_ppt, 2020, Summer: 24
# Shapefile for BBS: Sal_ppt for year 2020 and season Summer has been saved as SHP_BBS_Sal_ppt_2020_Summer.shp
# Number of data rows for BBS, Secc_m, 2020, Summer: 28
# Shapefile for BBS: Secc_m for year 2020 and season Summer has been saved as SHP_BBS_Secc_m_2020_Summer.shp
# Number of data rows for BBS, TN_mgl, 2020, Summer: 21
# Shapefile for BBS: TN_mgl for year 2020 and season Summer has been saved as SHP_BBS_TN_mgl_2020_Summer.shp
# Number of data rows for BBS, Turb_ntu, 2020, Summer: 28
# Shapefile for BBS: Turb_ntu for year 2020 and season Summer has been saved as SHP_BBS_Turb_ntu_2020_Summer.shp
# Number of data rows for BBS, T_c, 2020, Summer: 30
# Shapefile for BBS: T_c for year 2020 and season Summer has been saved as SHP_BBS_T_c_2020_Summer.shp
# Number of data rows for BBS, DO_mgl, 2020, Winter: 135
# Shapefile for BBS: DO_mgl for year 2020 and season Winter has been saved as SHP_BBS_DO_mgl_2020_Winter.shp
# Number of data rows for BBS, Sal_ppt, 2020, Winter: 134
# Shapefile for BBS: Sal_ppt for year 2020 and season Winter has been saved as SHP_BBS_Sal_ppt_2020_Winter.shp
# Number of data rows for BBS, Secc_m, 2020, Winter: 32
# Shapefile for BBS: Secc_m for year 2020 and season Winter has been saved as SHP_BBS_Secc_m_2020_Winter.shp
# Number of data rows for BBS, TN_mgl, 2020, Winter: 34
# Shapefile for BBS: TN_mgl for year 2020 and season Winter has been saved as SHP_BBS_TN_mgl_2020_Winter.shp
# Number of data rows for BBS, Turb_ntu, 2020, Winter: 39
# Shapefile for BBS: Turb_ntu for year 2020 and season Winter has been saved as SHP_BBS_Turb_ntu_2020_Winter.shp
# Number of data rows for BBS, T_c, 2020, Winter: 136
# Shapefile for BBS: T_c for year 2020 and season Winter has been saved as SHP_BBS_T_c_2020_Winter.shp
# Number of data rows for BBS, DO_mgl, 2021, Fall: 39
# Shapefile for BBS: DO_mgl for year 2021 and season Fall has been saved as SHP_BBS_DO_mgl_2021_Fall.shp
# Number of data rows for BBS, Sal_ppt, 2021, Fall: 30
# Shapefile for BBS: Sal_ppt for year 2021 and season Fall has been saved as SHP_BBS_Sal_ppt_2021_Fall.shp
# Number of data rows for BBS, Secc_m, 2021, Fall: 31
# Shapefile for BBS: Secc_m for year 2021 and season Fall has been saved as SHP_BBS_Secc_m_2021_Fall.shp
# Number of data rows for BBS, TN_mgl, 2021, Fall: 34
# Shapefile for BBS: TN_mgl for year 2021 and season Fall has been saved as SHP_BBS_TN_mgl_2021_Fall.shp
# Number of data rows for BBS, Turb_ntu, 2021, Fall: 35
# Shapefile for BBS: Turb_ntu for year 2021 and season Fall has been saved as SHP_BBS_Turb_ntu_2021_Fall.shp
# Number of data rows for BBS, T_c, 2021, Fall: 39
# Shapefile for BBS: T_c for year 2021 and season Fall has been saved as SHP_BBS_T_c_2021_Fall.shp
# Number of data rows for BBS, DO_mgl, 2021, Spring: 48
# Shapefile for BBS: DO_mgl for year 2021 and season Spring has been saved as SHP_BBS_DO_mgl_2021_Spring.shp
# Number of data rows for BBS, Sal_ppt, 2021, Spring: 37
# Shapefile for BBS: Sal_ppt for year 2021 and season Spring has been saved as SHP_BBS_Sal_ppt_2021_Spring.shp
# Number of data rows for BBS, Secc_m, 2021, Spring: 41
# Shapefile for BBS: Secc_m for year 2021 and season Spring has been saved as SHP_BBS_Secc_m_2021_Spring.shp
# Number of data rows for BBS, TN_mgl, 2021, Spring: 37
# Shapefile for BBS: TN_mgl for year 2021 and season Spring has been saved as SHP_BBS_TN_mgl_2021_Spring.shp
# Number of data rows for BBS, Turb_ntu, 2021, Spring: 40
# Shapefile for BBS: Turb_ntu for year 2021 and season Spring has been saved as SHP_BBS_Turb_ntu_2021_Spring.shp
# Number of data rows for BBS, T_c, 2021, Spring: 48
# Shapefile for BBS: T_c for year 2021 and season Spring has been saved as SHP_BBS_T_c_2021_Spring.shp
# Number of data rows for BBS, DO_mgl, 2021, Summer: 47
# Shapefile for BBS: DO_mgl for year 2021 and season Summer has been saved as SHP_BBS_DO_mgl_2021_Summer.shp
# Number of data rows for BBS, Sal_ppt, 2021, Summer: 39
# Shapefile for BBS: Sal_ppt for year 2021 and season Summer has been saved as SHP_BBS_Sal_ppt_2021_Summer.shp
# Number of data rows for BBS, Secc_m, 2021, Summer: 36
# Shapefile for BBS: Secc_m for year 2021 and season Summer has been saved as SHP_BBS_Secc_m_2021_Summer.shp
# Number of data rows for BBS, TN_mgl, 2021, Summer: 33
# Shapefile for BBS: TN_mgl for year 2021 and season Summer has been saved as SHP_BBS_TN_mgl_2021_Summer.shp
# Number of data rows for BBS, Turb_ntu, 2021, Summer: 37
# Shapefile for BBS: Turb_ntu for year 2021 and season Summer has been saved as SHP_BBS_Turb_ntu_2021_Summer.shp
# Number of data rows for BBS, T_c, 2021, Summer: 47
# Shapefile for BBS: T_c for year 2021 and season Summer has been saved as SHP_BBS_T_c_2021_Summer.shp
# Number of data rows for BBS, DO_mgl, 2021, Winter: 137
# Shapefile for BBS: DO_mgl for year 2021 and season Winter has been saved as SHP_BBS_DO_mgl_2021_Winter.shp
# Number of data rows for BBS, Sal_ppt, 2021, Winter: 132
# Shapefile for BBS: Sal_ppt for year 2021 and season Winter has been saved as SHP_BBS_Sal_ppt_2021_Winter.shp
# Number of data rows for BBS, Secc_m, 2021, Winter: 32
# Shapefile for BBS: Secc_m for year 2021 and season Winter has been saved as SHP_BBS_Secc_m_2021_Winter.shp
# Number of data rows for BBS, TN_mgl, 2021, Winter: 31
# Shapefile for BBS: TN_mgl for year 2021 and season Winter has been saved as SHP_BBS_TN_mgl_2021_Winter.shp
# Number of data rows for BBS, Turb_ntu, 2021, Winter: 35
# Shapefile for BBS: Turb_ntu for year 2021 and season Winter has been saved as SHP_BBS_Turb_ntu_2021_Winter.shp
# Number of data rows for BBS, T_c, 2021, Winter: 138
# Shapefile for BBS: T_c for year 2021 and season Winter has been saved as SHP_BBS_T_c_2021_Winter.shp
# Number of data rows for BBS, DO_mgl, 2022, Spring: 30
# Shapefile for BBS: DO_mgl for year 2022 and season Spring has been saved as SHP_BBS_DO_mgl_2022_Spring.shp
# Number of data rows for BBS, Sal_ppt, 2022, Spring: 17
# Shapefile for BBS: Sal_ppt for year 2022 and season Spring has been saved as SHP_BBS_Sal_ppt_2022_Spring.shp
# Number of data rows for BBS, Secc_m, 2022, Spring: 29
# Shapefile for BBS: Secc_m for year 2022 and season Spring has been saved as SHP_BBS_Secc_m_2022_Spring.shp
# Number of data rows for BBS, TN_mgl, 2022, Spring: 25
# Shapefile for BBS: TN_mgl for year 2022 and season Spring has been saved as SHP_BBS_TN_mgl_2022_Spring.shp
# Number of data rows for BBS, Turb_ntu, 2022, Spring: 29
# Shapefile for BBS: Turb_ntu for year 2022 and season Spring has been saved as SHP_BBS_Turb_ntu_2022_Spring.shp
# Number of data rows for BBS, T_c, 2022, Spring: 28
# Shapefile for BBS: T_c for year 2022 and season Spring has been saved as SHP_BBS_T_c_2022_Spring.shp
# Number of data rows for BB, DO_mgl, 2021, Fall: 86
# Shapefile for BB: DO_mgl for year 2021 and season Fall has been saved as SHP_BB_DO_mgl_2021_Fall.shp
# Number of data rows for BB, Sal_ppt, 2021, Fall: 66
# Shapefile for BB: Sal_ppt for year 2021 and season Fall has been saved as SHP_BB_Sal_ppt_2021_Fall.shp
# No valid data found for area: BB, parameter: Secc_m, year: 2021, and season: Fall
# Number of data rows for BB, TN_mgl, 2021, Fall: 81
# Shapefile for BB: TN_mgl for year 2021 and season Fall has been saved as SHP_BB_TN_mgl_2021_Fall.shp
# Number of data rows for BB, Turb_ntu, 2021, Fall: 65
# Shapefile for BB: Turb_ntu for year 2021 and season Fall has been saved as SHP_BB_Turb_ntu_2021_Fall.shp
# Number of data rows for BB, T_c, 2021, Fall: 86
# Shapefile for BB: T_c for year 2021 and season Fall has been saved as SHP_BB_T_c_2021_Fall.shp
# Number of data rows for BB, DO_mgl, 2021, Summer: 88
# Shapefile for BB: DO_mgl for year 2021 and season Summer has been saved as SHP_BB_DO_mgl_2021_Summer.shp
# Number of data rows for BB, Sal_ppt, 2021, Summer: 66
# Shapefile for BB: Sal_ppt for year 2021 and season Summer has been saved as SHP_BB_Sal_ppt_2021_Summer.shp
# Number of data rows for BB, Secc_m, 2021, Summer: 1
# Shapefile for BB: Secc_m for year 2021 and season Summer has been saved as SHP_BB_Secc_m_2021_Summer.shp
# Number of data rows for BB, TN_mgl, 2021, Summer: 81
# Shapefile for BB: TN_mgl for year 2021 and season Summer has been saved as SHP_BB_TN_mgl_2021_Summer.shp
# Number of data rows for BB, Turb_ntu, 2021, Summer: 66
# Shapefile for BB: Turb_ntu for year 2021 and season Summer has been saved as SHP_BB_Turb_ntu_2021_Summer.shp
# Number of data rows for BB, T_c, 2021, Summer: 88
# Shapefile for BB: T_c for year 2021 and season Summer has been saved as SHP_BB_T_c_2021_Summer.shp
# Number of data rows for BB, DO_mgl, 2021, Winter: 89
# Shapefile for BB: DO_mgl for year 2021 and season Winter has been saved as SHP_BB_DO_mgl_2021_Winter.shp
# Number of data rows for BB, Sal_ppt, 2021, Winter: 66
# Shapefile for BB: Sal_ppt for year 2021 and season Winter has been saved as SHP_BB_Sal_ppt_2021_Winter.shp
# No valid data found for area: BB, parameter: Secc_m, year: 2021, and season: Winter
# Number of data rows for BB, TN_mgl, 2021, Winter: 99
# Shapefile for BB: TN_mgl for year 2021 and season Winter has been saved as SHP_BB_TN_mgl_2021_Winter.shp
# Number of data rows for BB, Turb_ntu, 2021, Winter: 65
# Shapefile for BB: Turb_ntu for year 2021 and season Winter has been saved as SHP_BB_Turb_ntu_2021_Winter.shp
# Number of data rows for BB, T_c, 2021, Winter: 89
# Shapefile for BB: T_c for year 2021 and season Winter has been saved as SHP_BB_T_c_2021_Winter.shp
# Number of data rows for BB, DO_mgl, 2022, Fall: 69
# Shapefile for BB: DO_mgl for year 2022 and season Fall has been saved as SHP_BB_DO_mgl_2022_Fall.shp
# Number of data rows for BB, Sal_ppt, 2022, Fall: 51
# Shapefile for BB: Sal_ppt for year 2022 and season Fall has been saved as SHP_BB_Sal_ppt_2022_Fall.shp
# No valid data found for area: BB, parameter: Secc_m, year: 2022, and season: Fall
# Number of data rows for BB, TN_mgl, 2022, Fall: 59
# Shapefile for BB: TN_mgl for year 2022 and season Fall has been saved as SHP_BB_TN_mgl_2022_Fall.shp
# Number of data rows for BB, Turb_ntu, 2022, Fall: 51
# Shapefile for BB: Turb_ntu for year 2022 and season Fall has been saved as SHP_BB_Turb_ntu_2022_Fall.shp
# Number of data rows for BB, T_c, 2022, Fall: 71
# Shapefile for BB: T_c for year 2022 and season Fall has been saved as SHP_BB_T_c_2022_Fall.shp
# Number of data rows for BB, DO_mgl, 2022, Spring: 50
# Shapefile for BB: DO_mgl for year 2022 and season Spring has been saved as SHP_BB_DO_mgl_2022_Spring.shp
# Number of data rows for BB, Sal_ppt, 2022, Spring: 52
# Shapefile for BB: Sal_ppt for year 2022 and season Spring has been saved as SHP_BB_Sal_ppt_2022_Spring.shp
# No valid data found for area: BB, parameter: Secc_m, year: 2022, and season: Spring
# Number of data rows for BB, TN_mgl, 2022, Spring: 39
# Shapefile for BB: TN_mgl for year 2022 and season Spring has been saved as SHP_BB_TN_mgl_2022_Spring.shp
# Number of data rows for BB, Turb_ntu, 2022, Spring: 51
# Shapefile for BB: Turb_ntu for year 2022 and season Spring has been saved as SHP_BB_Turb_ntu_2022_Spring.shp
# Number of data rows for BB, T_c, 2022, Spring: 52
# Shapefile for BB: T_c for year 2022 and season Spring has been saved as SHP_BB_T_c_2022_Spring.shp
# Number of data rows for BB, DO_mgl, 2022, Summer: 70
# Shapefile for BB: DO_mgl for year 2022 and season Summer has been saved as SHP_BB_DO_mgl_2022_Summer.shp
# Number of data rows for BB, Sal_ppt, 2022, Summer: 49
# Shapefile for BB: Sal_ppt for year 2022 and season Summer has been saved as SHP_BB_Sal_ppt_2022_Summer.shp
# Number of data rows for BB, Secc_m, 2022, Summer: 1
# Shapefile for BB: Secc_m for year 2022 and season Summer has been saved as SHP_BB_Secc_m_2022_Summer.shp
# Number of data rows for BB, TN_mgl, 2022, Summer: 58
# Shapefile for BB: TN_mgl for year 2022 and season Summer has been saved as SHP_BB_TN_mgl_2022_Summer.shp
# Number of data rows for BB, Turb_ntu, 2022, Summer: 50
# Shapefile for BB: Turb_ntu for year 2022 and season Summer has been saved as SHP_BB_Turb_ntu_2022_Summer.shp
# Number of data rows for BB, T_c, 2022, Summer: 70
# Shapefile for BB: T_c for year 2022 and season Summer has been saved as SHP_BB_T_c_2022_Summer.shp
# Number of data rows for BB, DO_mgl, 2022, Winter: 70
# Shapefile for BB: DO_mgl for year 2022 and season Winter has been saved as SHP_BB_DO_mgl_2022_Winter.shp
# Number of data rows for BB, Sal_ppt, 2022, Winter: 52
# Shapefile for BB: Sal_ppt for year 2022 and season Winter has been saved as SHP_BB_Sal_ppt_2022_Winter.shp
# No valid data found for area: BB, parameter: Secc_m, year: 2022, and season: Winter
# Number of data rows for BB, TN_mgl, 2022, Winter: 59
# Shapefile for BB: TN_mgl for year 2022 and season Winter has been saved as SHP_BB_TN_mgl_2022_Winter.shp
# Number of data rows for BB, Turb_ntu, 2022, Winter: 52
# Shapefile for BB: Turb_ntu for year 2022 and season Winter has been saved as SHP_BB_Turb_ntu_2022_Winter.shp
# Number of data rows for BB, T_c, 2022, Winter: 72
# Shapefile for BB: T_c for year 2022 and season Winter has been saved as SHP_BB_T_c_2022_Winter.shp
# Number of data rows for BB, DO_mgl, 2023, Spring: 70
# Shapefile for BB: DO_mgl for year 2023 and season Spring has been saved as SHP_BB_DO_mgl_2023_Spring.shp
# Number of data rows for BB, Sal_ppt, 2023, Spring: 64
# Shapefile for BB: Sal_ppt for year 2023 and season Spring has been saved as SHP_BB_Sal_ppt_2023_Spring.shp
# No valid data found for area: BB, parameter: Secc_m, year: 2023, and season: Spring
# Number of data rows for BB, TN_mgl, 2023, Spring: 65
# Shapefile for BB: TN_mgl for year 2023 and season Spring has been saved as SHP_BB_TN_mgl_2023_Spring.shp
# Number of data rows for BB, Turb_ntu, 2023, Spring: 50
# Shapefile for BB: Turb_ntu for year 2023 and season Spring has been saved as SHP_BB_Turb_ntu_2023_Spring.shp
# Number of data rows for BB, T_c, 2023, Spring: 72
# Shapefile for BB: T_c for year 2023 and season Spring has been saved as SHP_BB_T_c_2023_Spring.shp
# Number of data rows for CH, DO_mgl, 2016, Fall: 475
# Shapefile for CH: DO_mgl for year 2016 and season Fall has been saved as SHP_CH_DO_mgl_2016_Fall.shp
# Number of data rows for CH, Sal_ppt, 2016, Fall: 483
# Shapefile for CH: Sal_ppt for year 2016 and season Fall has been saved as SHP_CH_Sal_ppt_2016_Fall.shp
# Number of data rows for CH, Secc_m, 2016, Fall: 382
# Shapefile for CH: Secc_m for year 2016 and season Fall has been saved as SHP_CH_Secc_m_2016_Fall.shp
# Number of data rows for CH, TN_mgl, 2016, Fall: 43
# Shapefile for CH: TN_mgl for year 2016 and season Fall has been saved as SHP_CH_TN_mgl_2016_Fall.shp
# Number of data rows for CH, Turb_ntu, 2016, Fall: 40
# Shapefile for CH: Turb_ntu for year 2016 and season Fall has been saved as SHP_CH_Turb_ntu_2016_Fall.shp
# Number of data rows for CH, T_c, 2016, Fall: 510
# Shapefile for CH: T_c for year 2016 and season Fall has been saved as SHP_CH_T_c_2016_Fall.shp
# Number of data rows for CH, DO_mgl, 2016, Summer: 503
# Shapefile for CH: DO_mgl for year 2016 and season Summer has been saved as SHP_CH_DO_mgl_2016_Summer.shp
# Number of data rows for CH, Sal_ppt, 2016, Summer: 476
# Shapefile for CH: Sal_ppt for year 2016 and season Summer has been saved as SHP_CH_Sal_ppt_2016_Summer.shp
# Number of data rows for CH, Secc_m, 2016, Summer: 387
# Shapefile for CH: Secc_m for year 2016 and season Summer has been saved as SHP_CH_Secc_m_2016_Summer.shp
# Number of data rows for CH, TN_mgl, 2016, Summer: 61
# Shapefile for CH: TN_mgl for year 2016 and season Summer has been saved as SHP_CH_TN_mgl_2016_Summer.shp
# Number of data rows for CH, Turb_ntu, 2016, Summer: 49
# Shapefile for CH: Turb_ntu for year 2016 and season Summer has been saved as SHP_CH_Turb_ntu_2016_Summer.shp
# Number of data rows for CH, T_c, 2016, Summer: 513
# Shapefile for CH: T_c for year 2016 and season Summer has been saved as SHP_CH_T_c_2016_Summer.shp
# Number of data rows for CH, DO_mgl, 2016, Winter: 393
# Shapefile for CH: DO_mgl for year 2016 and season Winter has been saved as SHP_CH_DO_mgl_2016_Winter.shp
# Number of data rows for CH, Sal_ppt, 2016, Winter: 401
# Shapefile for CH: Sal_ppt for year 2016 and season Winter has been saved as SHP_CH_Sal_ppt_2016_Winter.shp
# Number of data rows for CH, Secc_m, 2016, Winter: 342
# Shapefile for CH: Secc_m for year 2016 and season Winter has been saved as SHP_CH_Secc_m_2016_Winter.shp
# Number of data rows for CH, TN_mgl, 2016, Winter: 55
# Shapefile for CH: TN_mgl for year 2016 and season Winter has been saved as SHP_CH_TN_mgl_2016_Winter.shp
# Number of data rows for CH, Turb_ntu, 2016, Winter: 51
# Shapefile for CH: Turb_ntu for year 2016 and season Winter has been saved as SHP_CH_Turb_ntu_2016_Winter.shp
# Number of data rows for CH, T_c, 2016, Winter: 429
# Shapefile for CH: T_c for year 2016 and season Winter has been saved as SHP_CH_T_c_2016_Winter.shp
# Number of data rows for CH, DO_mgl, 2017, Fall: 445
# Shapefile for CH: DO_mgl for year 2017 and season Fall has been saved as SHP_CH_DO_mgl_2017_Fall.shp
# Number of data rows for CH, Sal_ppt, 2017, Fall: 411
# Shapefile for CH: Sal_ppt for year 2017 and season Fall has been saved as SHP_CH_Sal_ppt_2017_Fall.shp
# Number of data rows for CH, Secc_m, 2017, Fall: 319
# Shapefile for CH: Secc_m for year 2017 and season Fall has been saved as SHP_CH_Secc_m_2017_Fall.shp
# Number of data rows for CH, TN_mgl, 2017, Fall: 51
# Shapefile for CH: TN_mgl for year 2017 and season Fall has been saved as SHP_CH_TN_mgl_2017_Fall.shp
# Number of data rows for CH, Turb_ntu, 2017, Fall: 51
# Shapefile for CH: Turb_ntu for year 2017 and season Fall has been saved as SHP_CH_Turb_ntu_2017_Fall.shp
# Number of data rows for CH, T_c, 2017, Fall: 445
# Shapefile for CH: T_c for year 2017 and season Fall has been saved as SHP_CH_T_c_2017_Fall.shp
# Number of data rows for CH, DO_mgl, 2017, Spring: 434
# Shapefile for CH: DO_mgl for year 2017 and season Spring has been saved as SHP_CH_DO_mgl_2017_Spring.shp
# Number of data rows for CH, Sal_ppt, 2017, Spring: 402
# Shapefile for CH: Sal_ppt for year 2017 and season Spring has been saved as SHP_CH_Sal_ppt_2017_Spring.shp
# Number of data rows for CH, Secc_m, 2017, Spring: 351
# Shapefile for CH: Secc_m for year 2017 and season Spring has been saved as SHP_CH_Secc_m_2017_Spring.shp
# Number of data rows for CH, TN_mgl, 2017, Spring: 57
# Shapefile for CH: TN_mgl for year 2017 and season Spring has been saved as SHP_CH_TN_mgl_2017_Spring.shp
# Number of data rows for CH, Turb_ntu, 2017, Spring: 57
# Shapefile for CH: Turb_ntu for year 2017 and season Spring has been saved as SHP_CH_Turb_ntu_2017_Spring.shp
# Number of data rows for CH, T_c, 2017, Spring: 440
# Shapefile for CH: T_c for year 2017 and season Spring has been saved as SHP_CH_T_c_2017_Spring.shp
# Number of data rows for CH, DO_mgl, 2017, Summer: 461
# Shapefile for CH: DO_mgl for year 2017 and season Summer has been saved as SHP_CH_DO_mgl_2017_Summer.shp
# Number of data rows for CH, Sal_ppt, 2017, Summer: 434
# Shapefile for CH: Sal_ppt for year 2017 and season Summer has been saved as SHP_CH_Sal_ppt_2017_Summer.shp
# Number of data rows for CH, Secc_m, 2017, Summer: 339
# Shapefile for CH: Secc_m for year 2017 and season Summer has been saved as SHP_CH_Secc_m_2017_Summer.shp
# Number of data rows for CH, TN_mgl, 2017, Summer: 42
# Shapefile for CH: TN_mgl for year 2017 and season Summer has been saved as SHP_CH_TN_mgl_2017_Summer.shp
# Number of data rows for CH, Turb_ntu, 2017, Summer: 42
# Shapefile for CH: Turb_ntu for year 2017 and season Summer has been saved as SHP_CH_Turb_ntu_2017_Summer.shp
# Number of data rows for CH, T_c, 2017, Summer: 461
# Shapefile for CH: T_c for year 2017 and season Summer has been saved as SHP_CH_T_c_2017_Summer.shp
# Number of data rows for CH, DO_mgl, 2017, Winter: 375
# Shapefile for CH: DO_mgl for year 2017 and season Winter has been saved as SHP_CH_DO_mgl_2017_Winter.shp
# Number of data rows for CH, Sal_ppt, 2017, Winter: 372
# Shapefile for CH: Sal_ppt for year 2017 and season Winter has been saved as SHP_CH_Sal_ppt_2017_Winter.shp
# Number of data rows for CH, Secc_m, 2017, Winter: 334
# Shapefile for CH: Secc_m for year 2017 and season Winter has been saved as SHP_CH_Secc_m_2017_Winter.shp
# Number of data rows for CH, TN_mgl, 2017, Winter: 61
# Shapefile for CH: TN_mgl for year 2017 and season Winter has been saved as SHP_CH_TN_mgl_2017_Winter.shp
# Number of data rows for CH, Turb_ntu, 2017, Winter: 61
# Shapefile for CH: Turb_ntu for year 2017 and season Winter has been saved as SHP_CH_Turb_ntu_2017_Winter.shp
# Number of data rows for CH, T_c, 2017, Winter: 408
# Shapefile for CH: T_c for year 2017 and season Winter has been saved as SHP_CH_T_c_2017_Winter.shp
# Number of data rows for CH, DO_mgl, 2018, Spring: 71
# Shapefile for CH: DO_mgl for year 2018 and season Spring has been saved as SHP_CH_DO_mgl_2018_Spring.shp
# Number of data rows for CH, Sal_ppt, 2018, Spring: 39
# Shapefile for CH: Sal_ppt for year 2018 and season Spring has been saved as SHP_CH_Sal_ppt_2018_Spring.shp
# Number of data rows for CH, Secc_m, 2018, Spring: 13
# Shapefile for CH: Secc_m for year 2018 and season Spring has been saved as SHP_CH_Secc_m_2018_Spring.shp
# Number of data rows for CH, TN_mgl, 2018, Spring: 65
# Shapefile for CH: TN_mgl for year 2018 and season Spring has been saved as SHP_CH_TN_mgl_2018_Spring.shp
# Number of data rows for CH, Turb_ntu, 2018, Spring: 65
# Shapefile for CH: Turb_ntu for year 2018 and season Spring has been saved as SHP_CH_Turb_ntu_2018_Spring.shp
# Number of data rows for CH, T_c, 2018, Spring: 74
# Shapefile for CH: T_c for year 2018 and season Spring has been saved as SHP_CH_T_c_2018_Spring.shp
# Number of data rows for EB, DO_mgl, 2016, Fall: 39
# Shapefile for EB: DO_mgl for year 2016 and season Fall has been saved as SHP_EB_DO_mgl_2016_Fall.shp
# Number of data rows for EB, Sal_ppt, 2016, Fall: 12
# Shapefile for EB: Sal_ppt for year 2016 and season Fall has been saved as SHP_EB_Sal_ppt_2016_Fall.shp
# Number of data rows for EB, Secc_m, 2016, Fall: 4
# Shapefile for EB: Secc_m for year 2016 and season Fall has been saved as SHP_EB_Secc_m_2016_Fall.shp
# Number of data rows for EB, TN_mgl, 2016, Fall: 31
# Shapefile for EB: TN_mgl for year 2016 and season Fall has been saved as SHP_EB_TN_mgl_2016_Fall.shp
# Number of data rows for EB, Turb_ntu, 2016, Fall: 34
# Shapefile for EB: Turb_ntu for year 2016 and season Fall has been saved as SHP_EB_Turb_ntu_2016_Fall.shp
# Number of data rows for EB, T_c, 2016, Fall: 41
# Shapefile for EB: T_c for year 2016 and season Fall has been saved as SHP_EB_T_c_2016_Fall.shp
# Number of data rows for EB, DO_mgl, 2016, Summer: 48
# Shapefile for EB: DO_mgl for year 2016 and season Summer has been saved as SHP_EB_DO_mgl_2016_Summer.shp
# Number of data rows for EB, Sal_ppt, 2016, Summer: 15
# Shapefile for EB: Sal_ppt for year 2016 and season Summer has been saved as SHP_EB_Sal_ppt_2016_Summer.shp
# Number of data rows for EB, Secc_m, 2016, Summer: 5
# Shapefile for EB: Secc_m for year 2016 and season Summer has been saved as SHP_EB_Secc_m_2016_Summer.shp
# Number of data rows for EB, TN_mgl, 2016, Summer: 39
# Shapefile for EB: TN_mgl for year 2016 and season Summer has been saved as SHP_EB_TN_mgl_2016_Summer.shp
# Number of data rows for EB, Turb_ntu, 2016, Summer: 42
# Shapefile for EB: Turb_ntu for year 2016 and season Summer has been saved as SHP_EB_Turb_ntu_2016_Summer.shp
# Number of data rows for EB, T_c, 2016, Summer: 49
# Shapefile for EB: T_c for year 2016 and season Summer has been saved as SHP_EB_T_c_2016_Summer.shp
# Number of data rows for EB, DO_mgl, 2016, Winter: 51
# Shapefile for EB: DO_mgl for year 2016 and season Winter has been saved as SHP_EB_DO_mgl_2016_Winter.shp
# Number of data rows for EB, Sal_ppt, 2016, Winter: 17
# Shapefile for EB: Sal_ppt for year 2016 and season Winter has been saved as SHP_EB_Sal_ppt_2016_Winter.shp
# Number of data rows for EB, Secc_m, 2016, Winter: 8
# Shapefile for EB: Secc_m for year 2016 and season Winter has been saved as SHP_EB_Secc_m_2016_Winter.shp
# Number of data rows for EB, TN_mgl, 2016, Winter: 46
# Shapefile for EB: TN_mgl for year 2016 and season Winter has been saved as SHP_EB_TN_mgl_2016_Winter.shp
# Number of data rows for EB, Turb_ntu, 2016, Winter: 46
# Shapefile for EB: Turb_ntu for year 2016 and season Winter has been saved as SHP_EB_Turb_ntu_2016_Winter.shp
# Number of data rows for EB, T_c, 2016, Winter: 52
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     270                     if str(e).find("nullable")>-1:
#     271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
# --> 272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#     274                         empty_out_bounds.append(str(i))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in AddSpatialIndex(in_features, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    8541         return retval
#    8542     except Exception as e:
# -> 8543         raise e
#    8544
#    8545 @gptooldoc('RemoveIndex_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in AddSpatialIndex(in_features, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    8538     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    8539     try:
# -> 8540         retval = convertArcObjectToPythonObject(gp.AddSpatialIndex_management(*gp_fixargs((in_features, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    8541         return retval
#    8542     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000464: Cannot get exclusive schema lock.  Either being edited or in use by another application or service.
# Failed to execute (AddSpatialIndex).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for EB, DO_mgl, 2017, Fall: 45
# Shapefile for EB: DO_mgl for year 2017 and season Fall has been saved as SHP_EB_DO_mgl_2017_Fall.shp
# Number of data rows for EB, Sal_ppt, 2017, Fall: 15
# Shapefile for EB: Sal_ppt for year 2017 and season Fall has been saved as SHP_EB_Sal_ppt_2017_Fall.shp
# Number of data rows for EB, Secc_m, 2017, Fall: 4
# Shapefile for EB: Secc_m for year 2017 and season Fall has been saved as SHP_EB_Secc_m_2017_Fall.shp
# Number of data rows for EB, TN_mgl, 2017, Fall: 35
# Shapefile for EB: TN_mgl for year 2017 and season Fall has been saved as SHP_EB_TN_mgl_2017_Fall.shp
# Number of data rows for EB, Turb_ntu, 2017, Fall: 39
# Shapefile for EB: Turb_ntu for year 2017 and season Fall has been saved as SHP_EB_Turb_ntu_2017_Fall.shp
# Number of data rows for EB, T_c, 2017, Fall: 45
# Shapefile for EB: T_c for year 2017 and season Fall has been saved as SHP_EB_T_c_2017_Fall.shp
# Number of data rows for EB, DO_mgl, 2017, Spring: 47
# Shapefile for EB: DO_mgl for year 2017 and season Spring has been saved as SHP_EB_DO_mgl_2017_Spring.shp
# Number of data rows for EB, Sal_ppt, 2017, Spring: 16
# Shapefile for EB: Sal_ppt for year 2017 and season Spring has been saved as SHP_EB_Sal_ppt_2017_Spring.shp
# Number of data rows for EB, Secc_m, 2017, Spring: 6
# Shapefile for EB: Secc_m for year 2017 and season Spring has been saved as SHP_EB_Secc_m_2017_Spring.shp
# Number of data rows for EB, TN_mgl, 2017, Spring: 37
# Shapefile for EB: TN_mgl for year 2017 and season Spring has been saved as SHP_EB_TN_mgl_2017_Spring.shp
# Number of data rows for EB, Turb_ntu, 2017, Spring: 41
# Shapefile for EB: Turb_ntu for year 2017 and season Spring has been saved as SHP_EB_Turb_ntu_2017_Spring.shp
# Number of data rows for EB, T_c, 2017, Spring: 49
# Shapefile for EB: T_c for year 2017 and season Spring has been saved as SHP_EB_T_c_2017_Spring.shp
# Number of data rows for EB, DO_mgl, 2017, Summer: 45
# Shapefile for EB: DO_mgl for year 2017 and season Summer has been saved as SHP_EB_DO_mgl_2017_Summer.shp
# Number of data rows for EB, Sal_ppt, 2017, Summer: 15
# Shapefile for EB: Sal_ppt for year 2017 and season Summer has been saved as SHP_EB_Sal_ppt_2017_Summer.shp
# Number of data rows for EB, Secc_m, 2017, Summer: 7
# Shapefile for EB: Secc_m for year 2017 and season Summer has been saved as SHP_EB_Secc_m_2017_Summer.shp
# Number of data rows for EB, TN_mgl, 2017, Summer: 38
# Shapefile for EB: TN_mgl for year 2017 and season Summer has been saved as SHP_EB_TN_mgl_2017_Summer.shp
# Number of data rows for EB, Turb_ntu, 2017, Summer: 38
# Shapefile for EB: Turb_ntu for year 2017 and season Summer has been saved as SHP_EB_Turb_ntu_2017_Summer.shp
# Number of data rows for EB, T_c, 2017, Summer: 45
# Shapefile for EB: T_c for year 2017 and season Summer has been saved as SHP_EB_T_c_2017_Summer.shp
# Number of data rows for EB, DO_mgl, 2017, Winter: 49
# Shapefile for EB: DO_mgl for year 2017 and season Winter has been saved as SHP_EB_DO_mgl_2017_Winter.shp
# Number of data rows for EB, Sal_ppt, 2017, Winter: 17
# Shapefile for EB: Sal_ppt for year 2017 and season Winter has been saved as SHP_EB_Sal_ppt_2017_Winter.shp
# Number of data rows for EB, Secc_m, 2017, Winter: 7
# Shapefile for EB: Secc_m for year 2017 and season Winter has been saved as SHP_EB_Secc_m_2017_Winter.shp
# Number of data rows for EB, TN_mgl, 2017, Winter: 39
# Shapefile for EB: TN_mgl for year 2017 and season Winter has been saved as SHP_EB_TN_mgl_2017_Winter.shp
# Number of data rows for EB, Turb_ntu, 2017, Winter: 42
# Shapefile for EB: Turb_ntu for year 2017 and season Winter has been saved as SHP_EB_Turb_ntu_2017_Winter.shp
# Number of data rows for EB, T_c, 2017, Winter: 50
# Shapefile for EB: T_c for year 2017 and season Winter has been saved as SHP_EB_T_c_2017_Winter.shp
# Number of data rows for EB, DO_mgl, 2018, Spring: 40
# Shapefile for EB: DO_mgl for year 2018 and season Spring has been saved as SHP_EB_DO_mgl_2018_Spring.shp
# Number of data rows for EB, Sal_ppt, 2018, Spring: 16
# Shapefile for EB: Sal_ppt for year 2018 and season Spring has been saved as SHP_EB_Sal_ppt_2018_Spring.shp
# Number of data rows for EB, Secc_m, 2018, Spring: 5
# Shapefile for EB: Secc_m for year 2018 and season Spring has been saved as SHP_EB_Secc_m_2018_Spring.shp
# Number of data rows for EB, TN_mgl, 2018, Spring: 32
# Shapefile for EB: TN_mgl for year 2018 and season Spring has been saved as SHP_EB_TN_mgl_2018_Spring.shp
# Number of data rows for EB, Turb_ntu, 2018, Spring: 36
# Shapefile for EB: Turb_ntu for year 2018 and season Spring has been saved as SHP_EB_Turb_ntu_2018_Spring.shp
# Number of data rows for EB, T_c, 2018, Spring: 40
# Shapefile for EB: T_c for year 2018 and season Spring has been saved as SHP_EB_T_c_2018_Spring.shp
# Number of data rows for GTM, DO_mgl, 2015, Fall: 78
# Shapefile for GTM: DO_mgl for year 2015 and season Fall has been saved as SHP_GTM_DO_mgl_2015_Fall.shp
# Number of data rows for GTM, Sal_ppt, 2015, Fall: 80
# Shapefile for GTM: Sal_ppt for year 2015 and season Fall has been saved as SHP_GTM_Sal_ppt_2015_Fall.shp
# Number of data rows for GTM, Secc_m, 2015, Fall: 6
# Shapefile for GTM: Secc_m for year 2015 and season Fall has been saved as SHP_GTM_Secc_m_2015_Fall.shp
# Number of data rows for GTM, TN_mgl, 2015, Fall: 10
# Shapefile for GTM: TN_mgl for year 2015 and season Fall has been saved as SHP_GTM_TN_mgl_2015_Fall.shp
# Number of data rows for GTM, Turb_ntu, 2015, Fall: 14
# Shapefile for GTM: Turb_ntu for year 2015 and season Fall has been saved as SHP_GTM_Turb_ntu_2015_Fall.shp
# Number of data rows for GTM, T_c, 2015, Fall: 55
# Shapefile for GTM: T_c for year 2015 and season Fall has been saved as SHP_GTM_T_c_2015_Fall.shp
# Number of data rows for GTM, DO_mgl, 2015, Winter: 19
# Shapefile for GTM: DO_mgl for year 2015 and season Winter has been saved as SHP_GTM_DO_mgl_2015_Winter.shp
# Number of data rows for GTM, Sal_ppt, 2015, Winter: 19
# Shapefile for GTM: Sal_ppt for year 2015 and season Winter has been saved as SHP_GTM_Sal_ppt_2015_Winter.shp
# No valid data found for area: GTM, parameter: Secc_m, year: 2015, and season: Winter
# Number of data rows for GTM, TN_mgl, 2015, Winter: 6
# Shapefile for GTM: TN_mgl for year 2015 and season Winter has been saved as SHP_GTM_TN_mgl_2015_Winter.shp
# Number of data rows for GTM, Turb_ntu, 2015, Winter: 10
# Shapefile for GTM: Turb_ntu for year 2015 and season Winter has been saved as SHP_GTM_Turb_ntu_2015_Winter.shp
# Number of data rows for GTM, T_c, 2015, Winter: 19
# Shapefile for GTM: T_c for year 2015 and season Winter has been saved as SHP_GTM_T_c_2015_Winter.shp
# Number of data rows for GTM, DO_mgl, 2016, Fall: 47
# Shapefile for GTM: DO_mgl for year 2016 and season Fall has been saved as SHP_GTM_DO_mgl_2016_Fall.shp
# Number of data rows for GTM, Sal_ppt, 2016, Fall: 44
# Shapefile for GTM: Sal_ppt for year 2016 and season Fall has been saved as SHP_GTM_Sal_ppt_2016_Fall.shp
# No valid data found for area: GTM, parameter: Secc_m, year: 2016, and season: Fall
# Number of data rows for GTM, TN_mgl, 2016, Fall: 5
# Shapefile for GTM: TN_mgl for year 2016 and season Fall has been saved as SHP_GTM_TN_mgl_2016_Fall.shp
# Number of data rows for GTM, Turb_ntu, 2016, Fall: 9
# Shapefile for GTM: Turb_ntu for year 2016 and season Fall has been saved as SHP_GTM_Turb_ntu_2016_Fall.shp
# Number of data rows for GTM, T_c, 2016, Fall: 21
# Shapefile for GTM: T_c for year 2016 and season Fall has been saved as SHP_GTM_T_c_2016_Fall.shp
# Number of data rows for GTM, DO_mgl, 2016, Spring: 72
# Shapefile for GTM: DO_mgl for year 2016 and season Spring has been saved as SHP_GTM_DO_mgl_2016_Spring.shp
# Number of data rows for GTM, Sal_ppt, 2016, Spring: 71
# Shapefile for GTM: Sal_ppt for year 2016 and season Spring has been saved as SHP_GTM_Sal_ppt_2016_Spring.shp
# No valid data found for area: GTM, parameter: Secc_m, year: 2016, and season: Spring
# Number of data rows for GTM, TN_mgl, 2016, Spring: 5
# Shapefile for GTM: TN_mgl for year 2016 and season Spring has been saved as SHP_GTM_TN_mgl_2016_Spring.shp
# Number of data rows for GTM, Turb_ntu, 2016, Spring: 9
# Shapefile for GTM: Turb_ntu for year 2016 and season Spring has been saved as SHP_GTM_Turb_ntu_2016_Spring.shp
# Number of data rows for GTM, T_c, 2016, Spring: 49
# Shapefile for GTM: T_c for year 2016 and season Spring has been saved as SHP_GTM_T_c_2016_Spring.shp
# Number of data rows for GTM, DO_mgl, 2016, Summer: 78
# Shapefile for GTM: DO_mgl for year 2016 and season Summer has been saved as SHP_GTM_DO_mgl_2016_Summer.shp
# Number of data rows for GTM, Sal_ppt, 2016, Summer: 76
# Shapefile for GTM: Sal_ppt for year 2016 and season Summer has been saved as SHP_GTM_Sal_ppt_2016_Summer.shp
# No valid data found for area: GTM, parameter: Secc_m, year: 2016, and season: Summer
# Number of data rows for GTM, TN_mgl, 2016, Summer: 5
# Shapefile for GTM: TN_mgl for year 2016 and season Summer has been saved as SHP_GTM_TN_mgl_2016_Summer.shp
# Number of data rows for GTM, Turb_ntu, 2016, Summer: 9
# Shapefile for GTM: Turb_ntu for year 2016 and season Summer has been saved as SHP_GTM_Turb_ntu_2016_Summer.shp
# Number of data rows for GTM, T_c, 2016, Summer: 45
# Shapefile for GTM: T_c for year 2016 and season Summer has been saved as SHP_GTM_T_c_2016_Summer.shp
# Number of data rows for GTM, DO_mgl, 2016, Winter: 17
# Shapefile for GTM: DO_mgl for year 2016 and season Winter has been saved as SHP_GTM_DO_mgl_2016_Winter.shp
# Number of data rows for GTM, Sal_ppt, 2016, Winter: 15
# Shapefile for GTM: Sal_ppt for year 2016 and season Winter has been saved as SHP_GTM_Sal_ppt_2016_Winter.shp
# No valid data found for area: GTM, parameter: Secc_m, year: 2016, and season: Winter
# Number of data rows for GTM, TN_mgl, 2016, Winter: 5
# Shapefile for GTM: TN_mgl for year 2016 and season Winter has been saved as SHP_GTM_TN_mgl_2016_Winter.shp
# Number of data rows for GTM, Turb_ntu, 2016, Winter: 9
# Shapefile for GTM: Turb_ntu for year 2016 and season Winter has been saved as SHP_GTM_Turb_ntu_2016_Winter.shp
# Number of data rows for GTM, T_c, 2016, Winter: 19
# Shapefile for GTM: T_c for year 2016 and season Winter has been saved as SHP_GTM_T_c_2016_Winter.shp
# Number of data rows for GTM, DO_mgl, 2017, Spring: 68
# Shapefile for GTM: DO_mgl for year 2017 and season Spring has been saved as SHP_GTM_DO_mgl_2017_Spring.shp
# Number of data rows for GTM, Sal_ppt, 2017, Spring: 66
# Shapefile for GTM: Sal_ppt for year 2017 and season Spring has been saved as SHP_GTM_Sal_ppt_2017_Spring.shp
# Number of data rows for GTM, Secc_m, 2017, Spring: 2
# Shapefile for GTM: Secc_m for year 2017 and season Spring has been saved as SHP_GTM_Secc_m_2017_Spring.shp
# Number of data rows for GTM, TN_mgl, 2017, Spring: 6
# Shapefile for GTM: TN_mgl for year 2017 and season Spring has been saved as SHP_GTM_TN_mgl_2017_Spring.shp
# Number of data rows for GTM, Turb_ntu, 2017, Spring: 10
# Shapefile for GTM: Turb_ntu for year 2017 and season Spring has been saved as SHP_GTM_Turb_ntu_2017_Spring.shp
# Number of data rows for GTM, T_c, 2017, Spring: 23
# Shapefile for GTM: T_c for year 2017 and season Spring has been saved as SHP_GTM_T_c_2017_Spring.shp
# Number of data rows for GTM, DO_mgl, 2017, Summer: 28
# Shapefile for GTM: DO_mgl for year 2017 and season Summer has been saved as SHP_GTM_DO_mgl_2017_Summer.shp
# Number of data rows for GTM, Sal_ppt, 2017, Summer: 32
# Shapefile for GTM: Sal_ppt for year 2017 and season Summer has been saved as SHP_GTM_Sal_ppt_2017_Summer.shp
# Number of data rows for GTM, Secc_m, 2017, Summer: 9
# Shapefile for GTM: Secc_m for year 2017 and season Summer has been saved as SHP_GTM_Secc_m_2017_Summer.shp
# Number of data rows for GTM, TN_mgl, 2017, Summer: 19
# Shapefile for GTM: TN_mgl for year 2017 and season Summer has been saved as SHP_GTM_TN_mgl_2017_Summer.shp
# Number of data rows for GTM, Turb_ntu, 2017, Summer: 9
# Shapefile for GTM: Turb_ntu for year 2017 and season Summer has been saved as SHP_GTM_Turb_ntu_2017_Summer.shp
# Number of data rows for GTM, T_c, 2017, Summer: 32
# Shapefile for GTM: T_c for year 2017 and season Summer has been saved as SHP_GTM_T_c_2017_Summer.shp

# %% [markdown]
# # 3. Regression Kriging for both continuous and discrete data<a class="anchor" id="rk_all"></a>
#
# ## Loop for all parameters

# %% [markdown]
# ### Clean the output folder

# %%
out_raster_floder = gis_path + r"raster_output/rk_All/"
out_ga_folder     = gis_path + r"ga_output_rk/"
diagnostic_folder = gis_path + r"diagnostic_rk/"
std_error_folder  = gis_path + r"std_error_pred/std_error_rk_2s/"

# Clean existing files in folders
# idw_rk.delete_all_files(out_raster_floder)
# idw_rk.delete_all_files(out_ga_folder)
# idw_rk.delete_all_files(diagnostic_folder)
# idw_rk.delete_all_files(std_error_folder)

# %%
seasons_all = seasons_all[seasons_all['WaterBody']!= 'Big Bend Seagrasses']

# %%
importlib.reload(idw_rk)

# Write the output in a csv file
with open(gis_path+"rk_results_temp.csv", 'w', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    # Write the header line
    cols = list(seasons_all.columns)
    cols.append('covariates')
    csv_writer.writerow(cols)
    
    for i in seasons_all.index:
        s_time =time.time() 
        process,rmse,me,count,file_loc = idw_rk.rk_interpolation(method = "rk",
                                           radius = 10000,
                                           folder_path = gis_path,
                                           shp_path = shpAll_folder,
                                           waterbody = area_shortnames[seasons_all.loc[i]["WaterBody"]],
                                           parameter = param_shortnames[seasons_all.loc[i]["Parameter"]],
                                           year      = seasons_all.loc[i]["Year"],
                                           season    = seasons_all.loc[i]['Season'],
                                           covariates= covariates_dict[area_shortnames[seasons_all.loc[i]["WaterBody"]]],
                                           out_raster_folder = out_raster_floder,
                                           out_ga_folder     = out_ga_folder,
                                           std_error_folder  = std_error_folder,                  
                                           diagnostic_folder = diagnostic_folder)
        e_time =time.time()

        print(f"{int(e_time-s_time)} seconds elapsed for processing {count} points in {i}th row: RMSE: {rmse}, ME: {me}, file exported to {file_loc}")
        csv_writer.writerow([seasons_all.loc[i]["WaterBody"], 
                             seasons_all.loc[i]["Year"],
                             seasons_all.loc[i]['Season'],
                             seasons_all.loc[i]["Parameter"],
                             file_loc, count, rmse, me,
                             covariates_dict[area_shortnames[seasons_all.loc[i]["WaterBody"]]]])
        if i%10 == 0: csvfile.flush() # flush the csv file in every 20 rows.
#         seasons_all['RMSE'][i:i+1] = rmse
#         seasons_all['ME'][i:i+1] = me
#         seasons_all['NumDataPoints'][i:i+1] = count
#         seasons_all['Filename'][i:i+1] = file_loc
#     seasons_all.to_csv(gis_path+"result_RK_all.csv")
# Out:
# Processing file: SHP_GTM_TN_mgl_2015_Fall.shp
# --- Time lapse: 61.736483097076416 seconds ---
# 62 seconds elapsed for processing 10 points in 0th row: RMSE: 0.44906412833, ME: 0.0557400542326, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_TN_mgl_2015_Fall_RK.tif
# TN_mgl in 2015 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 6 points in 1th row: RMSE: nan, ME: nan, file exported to nan
# TN_mgl in 2016 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 5 points in 2th row: RMSE: nan, ME: nan, file exported to nan
# TN_mgl in 2016 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 5 points in 3th row: RMSE: nan, ME: nan, file exported to nan
# TN_mgl in 2016 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 5 points in 4th row: RMSE: nan, ME: nan, file exported to nan
# TN_mgl in 2016 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 5 points in 5th row: RMSE: nan, ME: nan, file exported to nan
# TN_mgl in 2017 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 6 points in 6th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_GTM_TN_mgl_2017_Summer.shp
# --- Time lapse: 61.68416476249695 seconds ---
# 61 seconds elapsed for processing 19 points in 7th row: RMSE: 0.0884660644447, ME: 0.0367652109093, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_TN_mgl_2017_Summer_RK.tif
# Processing file: SHP_EB_TN_mgl_2016_Summer.shp
# --- Time lapse: 103.11745071411133 seconds ---
# 103 seconds elapsed for processing 39 points in 8th row: RMSE: 0.152387833894, ME: 0.0104740098709, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_TN_mgl_2016_Summer_RK.tif
# Processing file: SHP_EB_TN_mgl_2016_Fall.shp
# --- Time lapse: 83.1264922618866 seconds ---
# 83 seconds elapsed for processing 31 points in 9th row: RMSE: 0.125802020776, ME: 0.00282075015282, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_TN_mgl_2016_Fall_RK.tif
# Processing file: SHP_EB_TN_mgl_2016_Winter.shp
# --- Time lapse: 121.68768858909607 seconds ---
# 121 seconds elapsed for processing 46 points in 10th row: RMSE: 0.225816277408, ME: -0.0218989472828, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_TN_mgl_2016_Winter_RK.tif
# Processing file: SHP_EB_TN_mgl_2017_Spring.shp
# --- Time lapse: 97.39402890205383 seconds ---
# 97 seconds elapsed for processing 37 points in 11th row: RMSE: 0.142141714149, ME: 0.00223591140085, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_TN_mgl_2017_Spring_RK.tif
# Processing file: SHP_EB_TN_mgl_2017_Summer.shp
# --- Time lapse: 96.07820534706116 seconds ---
# 96 seconds elapsed for processing 38 points in 12th row: RMSE: 0.203937213472, ME: -0.00589953314386, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_TN_mgl_2017_Summer_RK.tif
# Processing file: SHP_EB_TN_mgl_2017_Fall.shp
# --- Time lapse: 91.14509081840515 seconds ---
# 91 seconds elapsed for processing 35 points in 13th row: RMSE: 0.144556881868, ME: 0.00528908078941, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_TN_mgl_2017_Fall_RK.tif
# Processing file: SHP_EB_TN_mgl_2017_Winter.shp
# --- Time lapse: 100.41905236244202 seconds ---
# 100 seconds elapsed for processing 39 points in 14th row: RMSE: 0.12633684484, ME: 0.00484129172836, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_TN_mgl_2017_Winter_RK.tif
# Processing file: SHP_EB_TN_mgl_2018_Spring.shp
# --- Time lapse: 86.05073046684265 seconds ---
# 86 seconds elapsed for processing 32 points in 15th row: RMSE: 0.140930849515, ME: -0.00341676688129, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_TN_mgl_2018_Spring_RK.tif
# Processing file: SHP_CH_TN_mgl_2016_Summer.shp
# --- Time lapse: 808.6655378341675 seconds ---
# 808 seconds elapsed for processing 61 points in 16th row: RMSE: 0.468599435245, ME: 0.0280680034893, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_TN_mgl_2016_Summer_RK.tif
# Processing file: SHP_CH_TN_mgl_2016_Fall.shp
# --- Time lapse: 826.1628670692444 seconds ---
# 826 seconds elapsed for processing 43 points in 17th row: RMSE: 0.19613390416, ME: 0.00450049079904, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_TN_mgl_2016_Fall_RK.tif
# Processing file: SHP_CH_TN_mgl_2016_Winter.shp
# --- Time lapse: 1016.0363662242889 seconds ---
# 1016 seconds elapsed for processing 55 points in 18th row: RMSE: 0.120073905552, ME: -0.0019194139725, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_TN_mgl_2016_Winter_RK.tif
# Processing file: SHP_CH_TN_mgl_2017_Spring.shp
# --- Time lapse: 1059.3387894630432 seconds ---
# 1059 seconds elapsed for processing 57 points in 19th row: RMSE: 0.281051759953, ME: 0.00421122036424, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_TN_mgl_2017_Spring_RK.tif
# Processing file: SHP_CH_TN_mgl_2017_Summer.shp
# --- Time lapse: 813.360814332962 seconds ---
# 813 seconds elapsed for processing 42 points in 20th row: RMSE: 0.111250308931, ME: -0.000280532796195, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_TN_mgl_2017_Summer_RK.tif
# Processing file: SHP_CH_TN_mgl_2017_Fall.shp
# --- Time lapse: 991.9618864059448 seconds ---
# 992 seconds elapsed for processing 51 points in 21th row: RMSE: 0.194828361323, ME: 0.000415183360353, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_TN_mgl_2017_Fall_RK.tif
# Processing file: SHP_CH_TN_mgl_2017_Winter.shp
# --- Time lapse: 1026.2138724327087 seconds ---
# 1026 seconds elapsed for processing 61 points in 22th row: RMSE: 0.124463436365, ME: 0.00206394235818, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_TN_mgl_2017_Winter_RK.tif
# Processing file: SHP_CH_TN_mgl_2018_Spring.shp
# --- Time lapse: 1295.6441555023193 seconds ---
# 1295 seconds elapsed for processing 65 points in 23th row: RMSE: 0.186677569412, ME: -0.00362747440954, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_TN_mgl_2018_Spring_RK.tif
# Processing file: SHP_BB_TN_mgl_2021_Summer.shp
# --- Time lapse: 447.8770041465759 seconds ---
# 447 seconds elapsed for processing 81 points in 24th row: RMSE: 0.247748865868, ME: -0.00326558248917, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_TN_mgl_2021_Summer_RK.tif
# Processing file: SHP_BB_TN_mgl_2021_Fall.shp
# --- Time lapse: 433.3387141227722 seconds ---
# 433 seconds elapsed for processing 81 points in 25th row: RMSE: 0.225260127704, ME: -0.00336697378775, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_TN_mgl_2021_Fall_RK.tif
# Processing file: SHP_BB_TN_mgl_2021_Winter.shp
# --- Time lapse: 449.4211311340332 seconds ---
# 449 seconds elapsed for processing 99 points in 26th row: RMSE: 0.205432385023, ME: -0.0135146020168, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_TN_mgl_2021_Winter_RK.tif
# Processing file: SHP_BB_TN_mgl_2022_Spring.shp
# --- Time lapse: 203.60273838043213 seconds ---
# 203 seconds elapsed for processing 39 points in 27th row: RMSE: 0.163960951466, ME: -0.00889351551962, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_TN_mgl_2022_Spring_RK.tif
# Processing file: SHP_BB_TN_mgl_2022_Summer.shp
# --- Time lapse: 319.74710297584534 seconds ---
# 319 seconds elapsed for processing 58 points in 28th row: RMSE: 0.146825681216, ME: -0.00964865012663, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_TN_mgl_2022_Summer_RK.tif
# Processing file: SHP_BB_TN_mgl_2022_Fall.shp
# --- Time lapse: 222.91591572761536 seconds ---
# 222 seconds elapsed for processing 59 points in 29th row: RMSE: 0.163460759484, ME: -0.00745043172939, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_TN_mgl_2022_Fall_RK.tif
# Processing file: SHP_BB_TN_mgl_2022_Winter.shp
# --- Time lapse: 325.83646035194397 seconds ---
# 325 seconds elapsed for processing 59 points in 30th row: RMSE: 0.109330580966, ME: 3.53813703276e-05, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_TN_mgl_2022_Winter_RK.tif
# Processing file: SHP_BB_TN_mgl_2023_Spring.shp
# --- Time lapse: 329.25987815856934 seconds ---
# 329 seconds elapsed for processing 65 points in 31th row: RMSE: 0.117502694627, ME: -0.00442517741538, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_TN_mgl_2023_Spring_RK.tif
# Processing file: SHP_GTM_Sal_ppt_2015_Fall.shp
# --- Time lapse: 143.75197386741638 seconds ---
# 143 seconds elapsed for processing 80 points in 40th row: RMSE: 10.3635001852, ME: 0.560595022407, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_Sal_ppt_2015_Fall_RK.tif
# Processing file: SHP_GTM_Sal_ppt_2015_Winter.shp
# --- Time lapse: 70.66383695602417 seconds ---
# 70 seconds elapsed for processing 19 points in 41th row: RMSE: 6.88483980458, ME: 0.07479283725, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_Sal_ppt_2015_Winter_RK.tif
# Processing file: SHP_GTM_Sal_ppt_2016_Spring.shp
# --- Time lapse: 96.06814217567444 seconds ---
# 96 seconds elapsed for processing 71 points in 42th row: RMSE: 7.55876534952, ME: 0.407839865723, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_Sal_ppt_2016_Spring_RK.tif
# Processing file: SHP_GTM_Sal_ppt_2016_Summer.shp
# --- Time lapse: 164.590811252594 seconds ---
# 164 seconds elapsed for processing 76 points in 43th row: RMSE: 13.5480152598, ME: -3.9042938639, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_Sal_ppt_2016_Summer_RK.tif
# Processing file: SHP_GTM_Sal_ppt_2016_Fall.shp
# --- Time lapse: 65.535813331604 seconds ---
# 65 seconds elapsed for processing 44 points in 44th row: RMSE: 11.2971950731, ME: -1.86370708605, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_Sal_ppt_2016_Fall_RK.tif
# Processing file: SHP_GTM_Sal_ppt_2016_Winter.shp
# --- Time lapse: 67.37584280967712 seconds ---
# 67 seconds elapsed for processing 15 points in 45th row: RMSE: 3.58451478226, ME: -0.518608874718, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_Sal_ppt_2016_Winter_RK.tif
# Processing file: SHP_GTM_Sal_ppt_2017_Spring.shp
# --- Time lapse: 140.28776860237122 seconds ---
# 140 seconds elapsed for processing 66 points in 46th row: RMSE: 12.889025947, ME: -1.22404792617, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_Sal_ppt_2017_Spring_RK.tif
# Processing file: SHP_GTM_Sal_ppt_2017_Summer.shp
# --- Time lapse: 98.43994688987732 seconds ---
# 98 seconds elapsed for processing 32 points in 47th row: RMSE: 4.4546945765, ME: -1.79790738628, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_Sal_ppt_2017_Summer_RK.tif
# Processing file: SHP_EB_Sal_ppt_2016_Summer.shp
# --- Time lapse: 39.59000825881958 seconds ---
# 39 seconds elapsed for processing 15 points in 48th row: RMSE: 2.41567012231, ME: -0.286100392983, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_Sal_ppt_2016_Summer_RK.tif
# Processing file: SHP_EB_Sal_ppt_2016_Fall.shp
# --- Time lapse: 29.66183876991272 seconds ---
# 29 seconds elapsed for processing 12 points in 49th row: RMSE: 0.594398952423, ME: 0.20086107047, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_Sal_ppt_2016_Fall_RK.tif
# Processing file: SHP_EB_Sal_ppt_2016_Winter.shp
# --- Time lapse: 44.88170862197876 seconds ---
# 44 seconds elapsed for processing 17 points in 50th row: RMSE: 1.66762654813, ME: 0.15334109933, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_Sal_ppt_2016_Winter_RK.tif
# Processing file: SHP_EB_Sal_ppt_2017_Spring.shp
# --- Time lapse: 43.19327116012573 seconds ---
# 43 seconds elapsed for processing 16 points in 51th row: RMSE: 2.34083664905, ME: -0.301021245758, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_Sal_ppt_2017_Spring_RK.tif
# Processing file: SHP_EB_Sal_ppt_2017_Summer.shp
# --- Time lapse: 39.86227345466614 seconds ---
# 39 seconds elapsed for processing 15 points in 52th row: RMSE: 4.11958694214, ME: 0.18279044595, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_Sal_ppt_2017_Summer_RK.tif
# Processing file: SHP_EB_Sal_ppt_2017_Fall.shp
# --- Time lapse: 41.00022840499878 seconds ---
# 41 seconds elapsed for processing 15 points in 53th row: RMSE: 5.10149328494, ME: -0.59909911228, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_Sal_ppt_2017_Fall_RK.tif
# Processing file: SHP_EB_Sal_ppt_2017_Winter.shp
# --- Time lapse: 44.01809573173523 seconds ---
# 44 seconds elapsed for processing 17 points in 54th row: RMSE: 2.30767280858, ME: -0.168518465196, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_Sal_ppt_2017_Winter_RK.tif
# Processing file: SHP_EB_Sal_ppt_2018_Spring.shp
# --- Time lapse: 39.00762963294983 seconds ---
# 39 seconds elapsed for processing 16 points in 55th row: RMSE: 2.61744422117, ME: -0.217747831891, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_Sal_ppt_2018_Spring_RK.tif
# Processing file: SHP_CH_Sal_ppt_2016_Summer.shp
# --- Time lapse: 6050.539682149887 seconds ---
# 6050 seconds elapsed for processing 476 points in 56th row: RMSE: 2.92989527839, ME: 0.121767384349, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Sal_ppt_2016_Summer_RK.tif
# Processing file: SHP_CH_Sal_ppt_2016_Fall.shp
# --- Time lapse: 5898.480284452438 seconds ---
# 5898 seconds elapsed for processing 483 points in 57th row: RMSE: 6.10876150883, ME: 0.216557790094, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Sal_ppt_2016_Fall_RK.tif
# Processing file: SHP_CH_Sal_ppt_2016_Winter.shp
# --- Time lapse: 4976.445533037186 seconds ---
# 4976 seconds elapsed for processing 401 points in 58th row: RMSE: 6.06362079785, ME: 0.243623031744, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Sal_ppt_2016_Winter_RK.tif
# Processing file: SHP_CH_Sal_ppt_2017_Spring.shp
# --- Time lapse: 5107.10187625885 seconds ---
# 5107 seconds elapsed for processing 402 points in 59th row: RMSE: 1.83903336129, ME: 0.0626371118382, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Sal_ppt_2017_Spring_RK.tif
# Processing file: SHP_CH_Sal_ppt_2017_Summer.shp
# --- Time lapse: 6633.822252988815 seconds ---
# 6633 seconds elapsed for processing 434 points in 60th row: RMSE: 3.83159183041, ME: -0.123130861838, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Sal_ppt_2017_Summer_RK.tif
# Processing file: SHP_CH_Sal_ppt_2017_Fall.shp
# --- Time lapse: 4964.235018014908 seconds ---
# 4964 seconds elapsed for processing 411 points in 61th row: RMSE: 5.69292779522, ME: 0.139952221388, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Sal_ppt_2017_Fall_RK.tif
# Processing file: SHP_CH_Sal_ppt_2017_Winter.shp
# --- Time lapse: 4871.219514369965 seconds ---
# 4871 seconds elapsed for processing 372 points in 62th row: RMSE: 2.61931051889, ME: 0.0868043081229, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Sal_ppt_2017_Winter_RK.tif
# Processing file: SHP_CH_Sal_ppt_2018_Spring.shp
# --- Time lapse: 634.7316970825195 seconds ---
# 634 seconds elapsed for processing 39 points in 63th row: RMSE: 1.84014266171, ME: 0.116755882294, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Sal_ppt_2018_Spring_RK.tif
# Processing file: SHP_BB_Sal_ppt_2021_Summer.shp
# --- Time lapse: 184.00302839279175 seconds ---
# 184 seconds elapsed for processing 66 points in 64th row: RMSE: 5.25953268045, ME: 0.365991421662, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_Sal_ppt_2021_Summer_RK.tif
# Processing file: SHP_BB_Sal_ppt_2021_Fall.shp
# --- Time lapse: 232.11251068115234 seconds ---
# 232 seconds elapsed for processing 66 points in 65th row: RMSE: 4.56409444488, ME: -0.0850729997401, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_Sal_ppt_2021_Fall_RK.tif
# Processing file: SHP_BB_Sal_ppt_2021_Winter.shp
# --- Time lapse: 320.42043828964233 seconds ---
# 320 seconds elapsed for processing 66 points in 66th row: RMSE: 6.03256089796, ME: 0.038386862525, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_Sal_ppt_2021_Winter_RK.tif
# Processing file: SHP_BB_Sal_ppt_2022_Spring.shp
# --- Time lapse: 161.29373621940613 seconds ---
# 161 seconds elapsed for processing 52 points in 67th row: RMSE: 5.01371555608, ME: 0.294147473036, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_Sal_ppt_2022_Spring_RK.tif
# Processing file: SHP_BB_Sal_ppt_2022_Summer.shp
# --- Time lapse: 145.5575590133667 seconds ---
# 145 seconds elapsed for processing 49 points in 68th row: RMSE: 3.68843040346, ME: 0.0824791521975, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_Sal_ppt_2022_Summer_RK.tif
# Processing file: SHP_BB_Sal_ppt_2022_Fall.shp
# --- Time lapse: 170.14521718025208 seconds ---
# 170 seconds elapsed for processing 51 points in 69th row: RMSE: 3.55955327483, ME: 0.240850787591, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_Sal_ppt_2022_Fall_RK.tif
# Processing file: SHP_BB_Sal_ppt_2022_Winter.shp
# --- Time lapse: 139.66290283203125 seconds ---
# 139 seconds elapsed for processing 52 points in 70th row: RMSE: 3.58279237823, ME: 0.253603352798, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_Sal_ppt_2022_Winter_RK.tif
# Processing file: SHP_BB_Sal_ppt_2023_Spring.shp
# --- Time lapse: 219.80840015411377 seconds ---
# 219 seconds elapsed for processing 64 points in 71th row: RMSE: 3.46987962733, ME: 0.230576133064, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_Sal_ppt_2023_Spring_RK.tif
# Processing file: SHP_GTM_DO_mgl_2015_Fall.shp
# --- Time lapse: 187.3322377204895 seconds ---
# 187 seconds elapsed for processing 78 points in 80th row: RMSE: 1.57877294532, ME: -0.0799394572521, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_DO_mgl_2015_Fall_RK.tif
# Processing file: SHP_GTM_DO_mgl_2015_Winter.shp
# --- Time lapse: 71.94526052474976 seconds ---
# 72 seconds elapsed for processing 19 points in 81th row: RMSE: 0.661447635549, ME: 0.0429844475828, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_DO_mgl_2015_Winter_RK.tif
# Processing file: SHP_GTM_DO_mgl_2016_Spring.shp
# --- Time lapse: 151.84879851341248 seconds ---
# 151 seconds elapsed for processing 72 points in 82th row: RMSE: 1.35918914481, ME: 0.0205393444964, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_DO_mgl_2016_Spring_RK.tif
# Processing file: SHP_GTM_DO_mgl_2016_Summer.shp
# --- Time lapse: 156.70044827461243 seconds ---
# 156 seconds elapsed for processing 78 points in 83th row: RMSE: 1.92853195043, ME: -0.34944410288, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_DO_mgl_2016_Summer_RK.tif
# Processing file: SHP_GTM_DO_mgl_2016_Fall.shp
# --- Time lapse: 98.47983407974243 seconds ---
# 98 seconds elapsed for processing 47 points in 84th row: RMSE: 1.99412260115, ME: -0.434805008924, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_DO_mgl_2016_Fall_RK.tif
# Processing file: SHP_GTM_DO_mgl_2016_Winter.shp
# --- Time lapse: 58.043041944503784 seconds ---
# 58 seconds elapsed for processing 17 points in 85th row: RMSE: 0.266611300527, ME: 0.00382312488412, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_DO_mgl_2016_Winter_RK.tif
# Processing file: SHP_GTM_DO_mgl_2017_Spring.shp
# --- Time lapse: 126.89042496681213 seconds ---
# 126 seconds elapsed for processing 68 points in 86th row: RMSE: 2.19621476467, ME: -0.42020940705, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_DO_mgl_2017_Spring_RK.tif
# Processing file: SHP_GTM_DO_mgl_2017_Summer.shp
# --- Time lapse: 83.4267110824585 seconds ---
# 83 seconds elapsed for processing 28 points in 87th row: RMSE: 0.92184271121, ME: 0.0104057565074, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_DO_mgl_2017_Summer_RK.tif
# Processing file: SHP_EB_DO_mgl_2016_Summer.shp
# --- Time lapse: 125.21778392791748 seconds ---
# 125 seconds elapsed for processing 48 points in 88th row: RMSE: 0.987197928799, ME: -0.0310959678822, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_DO_mgl_2016_Summer_RK.tif
# Processing file: SHP_EB_DO_mgl_2016_Fall.shp
# --- Time lapse: 100.22209024429321 seconds ---
# 100 seconds elapsed for processing 39 points in 89th row: RMSE: 0.874258955433, ME: -0.0162170113347, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_DO_mgl_2016_Fall_RK.tif
# Processing file: SHP_EB_DO_mgl_2016_Winter.shp
# --- Time lapse: 130.137042760849 seconds ---
# 130 seconds elapsed for processing 51 points in 90th row: RMSE: 1.06811673785, ME: 0.0472693378431, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_DO_mgl_2016_Winter_RK.tif
# Processing file: SHP_EB_DO_mgl_2017_Spring.shp
# --- Time lapse: 123.07538294792175 seconds ---
# 123 seconds elapsed for processing 47 points in 91th row: RMSE: 0.888623439282, ME: -0.035199524513, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_DO_mgl_2017_Spring_RK.tif
# Processing file: SHP_EB_DO_mgl_2017_Summer.shp
# --- Time lapse: 114.41536355018616 seconds ---
# 114 seconds elapsed for processing 45 points in 92th row: RMSE: 0.942960378011, ME: -0.0490726332747, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_DO_mgl_2017_Summer_RK.tif
# Processing file: SHP_EB_DO_mgl_2017_Fall.shp
# --- Time lapse: 113.92410063743591 seconds ---
# 114 seconds elapsed for processing 45 points in 93th row: RMSE: 0.833402804754, ME: 0.0441863105204, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_DO_mgl_2017_Fall_RK.tif
# Processing file: SHP_EB_DO_mgl_2017_Winter.shp
# --- Time lapse: 122.55303049087524 seconds ---
# 122 seconds elapsed for processing 49 points in 94th row: RMSE: 1.05581575531, ME: -0.145913044919, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_DO_mgl_2017_Winter_RK.tif
# Processing file: SHP_EB_DO_mgl_2018_Spring.shp
# --- Time lapse: 107.00098848342896 seconds ---
# 107 seconds elapsed for processing 40 points in 95th row: RMSE: 0.977126943124, ME: 0.075411637139, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_DO_mgl_2018_Spring_RK.tif
# Processing file: SHP_CH_DO_mgl_2016_Summer.shp
# --- Time lapse: 6291.951899051666 seconds ---
# 6292 seconds elapsed for processing 503 points in 96th row: RMSE: 1.43985475034, ME: 0.0573883891501, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_DO_mgl_2016_Summer_RK.tif
# Processing file: SHP_CH_DO_mgl_2016_Fall.shp
# --- Time lapse: 6534.466640949249 seconds ---
# 6534 seconds elapsed for processing 475 points in 97th row: RMSE: 1.76652311072, ME: 0.069050364551, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_DO_mgl_2016_Fall_RK.tif
# Processing file: SHP_CH_DO_mgl_2016_Winter.shp
# --- Time lapse: 5260.690196275711 seconds ---
# 5260 seconds elapsed for processing 393 points in 98th row: RMSE: 1.61250892832, ME: 0.00545513610412, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_DO_mgl_2016_Winter_RK.tif
# Processing file: SHP_CH_DO_mgl_2017_Spring.shp
# --- Time lapse: 6978.454547166824 seconds ---
# 6978 seconds elapsed for processing 434 points in 99th row: RMSE: 1.84880217754, ME: 0.0884294115855, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_DO_mgl_2017_Spring_RK.tif
# Processing file: SHP_CH_DO_mgl_2017_Summer.shp
# --- Time lapse: 6952.399735689163 seconds ---
# 6952 seconds elapsed for processing 461 points in 100th row: RMSE: 2.02728214024, ME: 0.13984323271, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_DO_mgl_2017_Summer_RK.tif
# Processing file: SHP_CH_DO_mgl_2017_Fall.shp
# --- Time lapse: 6482.056753396988 seconds ---
# 6482 seconds elapsed for processing 445 points in 101th row: RMSE: 2.00364047873, ME: 0.0471114169257, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_DO_mgl_2017_Fall_RK.tif
# Processing file: SHP_CH_DO_mgl_2017_Winter.shp
# --- Time lapse: 5238.452392339706 seconds ---
# 5238 seconds elapsed for processing 375 points in 102th row: RMSE: 1.25127377496, ME: 0.00497869820688, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_DO_mgl_2017_Winter_RK.tif
# Processing file: SHP_CH_DO_mgl_2018_Spring.shp
# --- Time lapse: 1266.0542414188385 seconds ---
# 1266 seconds elapsed for processing 71 points in 103th row: RMSE: 0.813343412755, ME: -0.0439816160111, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_DO_mgl_2018_Spring_RK.tif
# Processing file: SHP_BB_DO_mgl_2021_Summer.shp
# --- Time lapse: 458.8295202255249 seconds ---
# 458 seconds elapsed for processing 88 points in 104th row: RMSE: 1.040368076, ME: -0.00505294523936, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_DO_mgl_2021_Summer_RK.tif
# Processing file: SHP_BB_DO_mgl_2021_Fall.shp
# --- Time lapse: 432.9088566303253 seconds ---
# 433 seconds elapsed for processing 86 points in 105th row: RMSE: 0.804064408908, ME: -0.0130151396922, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_DO_mgl_2021_Fall_RK.tif
# Processing file: SHP_BB_DO_mgl_2021_Winter.shp
# --- Time lapse: 448.4330937862396 seconds ---
# 448 seconds elapsed for processing 89 points in 106th row: RMSE: 1.17147684037, ME: 0.00641384527228, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_DO_mgl_2021_Winter_RK.tif
# Processing file: SHP_BB_DO_mgl_2022_Spring.shp
# --- Time lapse: 261.03491401672363 seconds ---
# 261 seconds elapsed for processing 50 points in 107th row: RMSE: 0.881563054087, ME: 0.00744341754331, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_DO_mgl_2022_Spring_RK.tif
# Processing file: SHP_BB_DO_mgl_2022_Summer.shp
# --- Time lapse: 395.01209354400635 seconds ---
# 395 seconds elapsed for processing 70 points in 108th row: RMSE: 0.852270078892, ME: 0.0253210125174, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_DO_mgl_2022_Summer_RK.tif
# Processing file: SHP_BB_DO_mgl_2022_Fall.shp
# --- Time lapse: 391.7245988845825 seconds ---
# 391 seconds elapsed for processing 69 points in 109th row: RMSE: 0.790759360073, ME: -0.00328425388124, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_DO_mgl_2022_Fall_RK.tif
# Processing file: SHP_BB_DO_mgl_2022_Winter.shp
# --- Time lapse: 383.2809545993805 seconds ---
# 383 seconds elapsed for processing 70 points in 110th row: RMSE: 0.866284848636, ME: 0.0158526641866, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_DO_mgl_2022_Winter_RK.tif
# Processing file: SHP_BB_DO_mgl_2023_Spring.shp
# --- Time lapse: 384.27579045295715 seconds ---
# 384 seconds elapsed for processing 70 points in 111th row: RMSE: 1.05201492166, ME: 0.0802309257272, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_DO_mgl_2023_Spring_RK.tif
# Processing file: SHP_GTM_Turb_ntu_2015_Fall.shp
# --- Time lapse: 58.58255863189697 seconds ---
# 58 seconds elapsed for processing 14 points in 120th row: RMSE: 3.33108346241, ME: -0.00550312423241, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_Turb_ntu_2015_Fall_RK.tif
# Processing file: SHP_GTM_Turb_ntu_2015_Winter.shp
# --- Time lapse: 43.10090112686157 seconds ---
# 43 seconds elapsed for processing 10 points in 121th row: RMSE: 10.024001907, ME: 2.50015467072, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_Turb_ntu_2015_Winter_RK.tif
# Turb_ntu in 2016 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 9 points in 122th row: RMSE: nan, ME: nan, file exported to nan
# Turb_ntu in 2016 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 9 points in 123th row: RMSE: nan, ME: nan, file exported to nan
# Turb_ntu in 2016 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 9 points in 124th row: RMSE: nan, ME: nan, file exported to nan
# Turb_ntu in 2016 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 9 points in 125th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_GTM_Turb_ntu_2017_Spring.shp
# --- Time lapse: 43.29039645195007 seconds ---
# 43 seconds elapsed for processing 10 points in 126th row: RMSE: 2.80298588253, ME: 0.0695311915467, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_Turb_ntu_2017_Spring_RK.tif
# Turb_ntu in 2017 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 9 points in 127th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_EB_Turb_ntu_2016_Summer.shp
# --- Time lapse: 102.17414832115173 seconds ---
# 102 seconds elapsed for processing 42 points in 128th row: RMSE: 1.23464154485, ME: 0.0327510582329, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_Turb_ntu_2016_Summer_RK.tif
# Processing file: SHP_EB_Turb_ntu_2016_Fall.shp
# --- Time lapse: 84.37867259979248 seconds ---
# 84 seconds elapsed for processing 34 points in 129th row: RMSE: 1.73275002464, ME: 0.0765243366598, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_Turb_ntu_2016_Fall_RK.tif
# Processing file: SHP_EB_Turb_ntu_2016_Winter.shp
# --- Time lapse: 113.05010652542114 seconds ---
# 113 seconds elapsed for processing 46 points in 130th row: RMSE: 5.53825036407, ME: -0.169412585025, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_Turb_ntu_2016_Winter_RK.tif
# Processing file: SHP_EB_Turb_ntu_2017_Spring.shp
# --- Time lapse: 104.7811975479126 seconds ---
# 104 seconds elapsed for processing 41 points in 131th row: RMSE: 2.98735251494, ME: 0.148759138166, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_Turb_ntu_2017_Spring_RK.tif
# Processing file: SHP_EB_Turb_ntu_2017_Summer.shp
# --- Time lapse: 86.29256892204285 seconds ---
# 86 seconds elapsed for processing 38 points in 132th row: RMSE: 1.66600705224, ME: 0.0139422901588, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_Turb_ntu_2017_Summer_RK.tif
# Processing file: SHP_EB_Turb_ntu_2017_Fall.shp
# --- Time lapse: 84.86539268493652 seconds ---
# 84 seconds elapsed for processing 39 points in 133th row: RMSE: 3.42512124423, ME: 0.373969883895, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_Turb_ntu_2017_Fall_RK.tif
# Processing file: SHP_EB_Turb_ntu_2017_Winter.shp
# --- Time lapse: 107.68644189834595 seconds ---
# 107 seconds elapsed for processing 42 points in 134th row: RMSE: 3.11696126419, ME: 0.150939843245, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_Turb_ntu_2017_Winter_RK.tif
# Processing file: SHP_EB_Turb_ntu_2018_Spring.shp
# --- Time lapse: 93.39659929275513 seconds ---
# 93 seconds elapsed for processing 36 points in 135th row: RMSE: 1.51400512087, ME: -0.00653824284135, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_Turb_ntu_2018_Spring_RK.tif
# Processing file: SHP_CH_Turb_ntu_2016_Summer.shp
# --- Time lapse: 677.3183624744415 seconds ---
# 677 seconds elapsed for processing 49 points in 136th row: RMSE: 6.25523794159, ME: -0.50008996711, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Turb_ntu_2016_Summer_RK.tif
# Processing file: SHP_CH_Turb_ntu_2016_Fall.shp
# --- Time lapse: 724.1941945552826 seconds ---
# 724 seconds elapsed for processing 40 points in 137th row: RMSE: 3.07880156601, ME: 0.404533575892, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Turb_ntu_2016_Fall_RK.tif
# Processing file: SHP_CH_Turb_ntu_2016_Winter.shp
# --- Time lapse: 887.9938464164734 seconds ---
# 888 seconds elapsed for processing 51 points in 138th row: RMSE: 3.58708976869, ME: 0.240021766715, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Turb_ntu_2016_Winter_RK.tif
# Processing file: SHP_CH_Turb_ntu_2017_Spring.shp
# --- Time lapse: 952.5229353904724 seconds ---
# 952 seconds elapsed for processing 57 points in 139th row: RMSE: 4.11964558758, ME: -0.00168547595085, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Turb_ntu_2017_Spring_RK.tif
# Processing file: SHP_CH_Turb_ntu_2017_Summer.shp
# --- Time lapse: 798.6594116687775 seconds ---
# 798 seconds elapsed for processing 42 points in 140th row: RMSE: 2.76503839865, ME: 0.196666977974, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Turb_ntu_2017_Summer_RK.tif
# Processing file: SHP_CH_Turb_ntu_2017_Fall.shp
# --- Time lapse: 874.0147352218628 seconds ---
# 874 seconds elapsed for processing 51 points in 141th row: RMSE: 1.69961264509, ME: 0.0489326224878, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Turb_ntu_2017_Fall_RK.tif
# Processing file: SHP_CH_Turb_ntu_2017_Winter.shp
# --- Time lapse: 1117.800374031067 seconds ---
# 1117 seconds elapsed for processing 61 points in 142th row: RMSE: 2.50964939212, ME: -0.00809484710342, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Turb_ntu_2017_Winter_RK.tif
# Processing file: SHP_CH_Turb_ntu_2018_Spring.shp
# --- Time lapse: 271.9917001724243 seconds ---
# 272 seconds elapsed for processing 65 points in 143th row: RMSE: 11.7554990974, ME: -0.474545518403, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Turb_ntu_2018_Spring_RK.tif
# Processing file: SHP_BB_Turb_ntu_2021_Summer.shp
# --- Time lapse: 356.01542806625366 seconds ---
# 356 seconds elapsed for processing 66 points in 144th row: RMSE: 1.37291780254, ME: -0.0176193353341, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_Turb_ntu_2021_Summer_RK.tif
# Processing file: SHP_BB_Turb_ntu_2021_Fall.shp
# --- Time lapse: 230.24822902679443 seconds ---
# 230 seconds elapsed for processing 65 points in 145th row: RMSE: 1.99064693645, ME: -0.106004534082, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_Turb_ntu_2021_Fall_RK.tif
# Processing file: SHP_BB_Turb_ntu_2021_Winter.shp
# --- Time lapse: 229.58418607711792 seconds ---
# 229 seconds elapsed for processing 65 points in 146th row: RMSE: 2.21586353578, ME: -0.100044543325, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_Turb_ntu_2021_Winter_RK.tif
# Processing file: SHP_BB_Turb_ntu_2022_Spring.shp
# --- Time lapse: 211.71072506904602 seconds ---
# 211 seconds elapsed for processing 51 points in 147th row: RMSE: 1.80509156576, ME: 0.0165102349417, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_Turb_ntu_2022_Spring_RK.tif
# Processing file: SHP_BB_Turb_ntu_2022_Summer.shp
# --- Time lapse: 193.68639206886292 seconds ---
# 193 seconds elapsed for processing 50 points in 148th row: RMSE: 1.61730685715, ME: -0.128876802409, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_Turb_ntu_2022_Summer_RK.tif
# Processing file: SHP_BB_Turb_ntu_2022_Fall.shp
# --- Time lapse: 250.85520815849304 seconds ---
# 250 seconds elapsed for processing 51 points in 149th row: RMSE: 1.09519259464, ME: 0.0222070820434, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_Turb_ntu_2022_Fall_RK.tif
# Processing file: SHP_BB_Turb_ntu_2022_Winter.shp
# --- Time lapse: 280.8243522644043 seconds ---
# 280 seconds elapsed for processing 52 points in 150th row: RMSE: 0.883477440151, ME: -0.00764194018961, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_Turb_ntu_2022_Winter_RK.tif
# Processing file: SHP_BB_Turb_ntu_2023_Spring.shp
# --- Time lapse: 266.6400611400604 seconds ---
# 266 seconds elapsed for processing 50 points in 151th row: RMSE: 1.20119646563, ME: -0.0305184271244, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_Turb_ntu_2023_Spring_RK.tif
# Secc_m in 2015 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 6 points in 160th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_GTM_Secc_m_2015_Winter.shp, skipping
# 0 seconds elapsed for processing 0 points in 161th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_GTM_Secc_m_2016_Spring.shp, skipping
# 0 seconds elapsed for processing 0 points in 162th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_GTM_Secc_m_2016_Summer.shp, skipping
# 0 seconds elapsed for processing 0 points in 163th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_GTM_Secc_m_2016_Fall.shp, skipping
# 0 seconds elapsed for processing 0 points in 164th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_GTM_Secc_m_2016_Winter.shp, skipping
# 0 seconds elapsed for processing 0 points in 165th row: RMSE: nan, ME: nan, file exported to nan
# Secc_m in 2017 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 2 points in 166th row: RMSE: nan, ME: nan, file exported to nan
# Secc_m in 2017 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 9 points in 167th row: RMSE: nan, ME: nan, file exported to nan
# Secc_m in 2016 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 5 points in 168th row: RMSE: nan, ME: nan, file exported to nan
# Secc_m in 2016 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 4 points in 169th row: RMSE: nan, ME: nan, file exported to nan
# Secc_m in 2016 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 8 points in 170th row: RMSE: nan, ME: nan, file exported to nan
# Secc_m in 2017 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 6 points in 171th row: RMSE: nan, ME: nan, file exported to nan
# Secc_m in 2017 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 7 points in 172th row: RMSE: nan, ME: nan, file exported to nan
# Secc_m in 2017 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 4 points in 173th row: RMSE: nan, ME: nan, file exported to nan
# Secc_m in 2017 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 7 points in 174th row: RMSE: nan, ME: nan, file exported to nan
# Secc_m in 2018 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 5 points in 175th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_CH_Secc_m_2016_Summer.shp
# --- Time lapse: 5384.96027970314 seconds ---
# 5385 seconds elapsed for processing 387 points in 176th row: RMSE: 0.216628578715, ME: 0.00320686568504, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Secc_m_2016_Summer_RK.tif
# Processing file: SHP_CH_Secc_m_2016_Fall.shp
# --- Time lapse: 5277.670109510422 seconds ---
# 5277 seconds elapsed for processing 382 points in 177th row: RMSE: 0.337630484659, ME: 0.000382301963664, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Secc_m_2016_Fall_RK.tif
# Processing file: SHP_CH_Secc_m_2016_Winter.shp
# --- Time lapse: 5298.427699565887 seconds ---
# 5298 seconds elapsed for processing 342 points in 178th row: RMSE: 0.411268430022, ME: 0.000213688471797, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Secc_m_2016_Winter_RK.tif
# Processing file: SHP_CH_Secc_m_2017_Spring.shp
# --- Time lapse: 5239.873451471329 seconds ---
# 5240 seconds elapsed for processing 351 points in 179th row: RMSE: 0.441179751868, ME: -0.0166103280277, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Secc_m_2017_Spring_RK.tif
# Processing file: SHP_CH_Secc_m_2017_Summer.shp
# --- Time lapse: 5605.274613380432 seconds ---
# 5605 seconds elapsed for processing 339 points in 180th row: RMSE: 0.325121251156, ME: -0.000487827425113, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Secc_m_2017_Summer_RK.tif
# Processing file: SHP_CH_Secc_m_2017_Fall.shp
# --- Time lapse: 5319.992224693298 seconds ---
# 5320 seconds elapsed for processing 319 points in 181th row: RMSE: 0.351035057941, ME: 0.0207733037276, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Secc_m_2017_Fall_RK.tif
# Processing file: SHP_CH_Secc_m_2017_Winter.shp
# --- Time lapse: 5392.820962667465 seconds ---
# 5393 seconds elapsed for processing 334 points in 182th row: RMSE: 0.364355641669, ME: -0.017033648326, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Secc_m_2017_Winter_RK.tif
# Processing file: SHP_CH_Secc_m_2018_Spring.shp
# --- Time lapse: 253.52400922775269 seconds ---
# 253 seconds elapsed for processing 13 points in 183th row: RMSE: 0.228511518343, ME: 0.00579785217492, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_Secc_m_2018_Spring_RK.tif
# Secc_m in 2021 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 3 seconds elapsed for processing 1 points in 184th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_BB_Secc_m_2021_Fall.shp, skipping
# 0 seconds elapsed for processing 0 points in 185th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_BB_Secc_m_2021_Winter.shp, skipping
# 0 seconds elapsed for processing 0 points in 186th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_BB_Secc_m_2022_Spring.shp, skipping
# 0 seconds elapsed for processing 0 points in 187th row: RMSE: nan, ME: nan, file exported to nan
# Secc_m in 2022 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 3 seconds elapsed for processing 1 points in 188th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_BB_Secc_m_2022_Fall.shp, skipping
# 0 seconds elapsed for processing 0 points in 189th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_BB_Secc_m_2022_Winter.shp, skipping
# 0 seconds elapsed for processing 0 points in 190th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_BB_Secc_m_2023_Spring.shp, skipping
# 0 seconds elapsed for processing 0 points in 191th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_GTM_T_c_2015_Fall.shp
# --- Time lapse: 145.4981083869934 seconds ---
# 145 seconds elapsed for processing 55 points in 200th row: RMSE: 0.976096406929, ME: 0.0869137642618, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_T_c_2015_Fall_RK.tif
# Processing file: SHP_GTM_T_c_2015_Winter.shp
# --- Time lapse: 71.02994728088379 seconds ---
# 71 seconds elapsed for processing 19 points in 201th row: RMSE: 1.60699615699, ME: 0.0119997186561, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_T_c_2015_Winter_RK.tif
# Processing file: SHP_GTM_T_c_2016_Spring.shp
# --- Time lapse: 131.76042079925537 seconds ---
# 131 seconds elapsed for processing 49 points in 202th row: RMSE: 1.2556350956, ME: -0.0142697019525, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_T_c_2016_Spring_RK.tif
# Processing file: SHP_GTM_T_c_2016_Summer.shp
# --- Time lapse: 138.36958503723145 seconds ---
# 138 seconds elapsed for processing 45 points in 203th row: RMSE: 10.0134144764, ME: 0.551348625318, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_T_c_2016_Summer_RK.tif
# Processing file: SHP_GTM_T_c_2016_Fall.shp
# --- Time lapse: 67.19473171234131 seconds ---
# 67 seconds elapsed for processing 21 points in 204th row: RMSE: 1.31587862185, ME: 0.0316625107805, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_T_c_2016_Fall_RK.tif
# Processing file: SHP_GTM_T_c_2016_Winter.shp
# --- Time lapse: 61.90592074394226 seconds ---
# 62 seconds elapsed for processing 19 points in 205th row: RMSE: 0.748396980942, ME: -0.0139769715539, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_T_c_2016_Winter_RK.tif
# Processing file: SHP_GTM_T_c_2017_Spring.shp
# --- Time lapse: 76.78668546676636 seconds ---
# 76 seconds elapsed for processing 23 points in 206th row: RMSE: 1.27719337115, ME: -0.0982398747614, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_T_c_2017_Spring_RK.tif
# Processing file: SHP_GTM_T_c_2017_Summer.shp
# --- Time lapse: 88.18363404273987 seconds ---
# 88 seconds elapsed for processing 32 points in 207th row: RMSE: 3.88965421421, ME: 0.194532848254, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/GTM_T_c_2017_Summer_RK.tif
# Processing file: SHP_EB_T_c_2016_Summer.shp
# --- Time lapse: 124.35199093818665 seconds ---
# 124 seconds elapsed for processing 49 points in 208th row: RMSE: 0.75847750551, ME: -0.0193431174636, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_T_c_2016_Summer_RK.tif
# Processing file: SHP_EB_T_c_2016_Fall.shp
# --- Time lapse: 103.89035153388977 seconds ---
# 104 seconds elapsed for processing 41 points in 209th row: RMSE: 1.53572903658, ME: -0.0422852350383, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_T_c_2016_Fall_RK.tif
# Processing file: SHP_EB_T_c_2016_Winter.shp
# --- Time lapse: 131.32817554473877 seconds ---
# 131 seconds elapsed for processing 52 points in 210th row: RMSE: 1.54210767921, ME: 0.121316510118, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_T_c_2016_Winter_RK.tif
# Processing file: SHP_EB_T_c_2017_Spring.shp
# --- Time lapse: 128.99704480171204 seconds ---
# 129 seconds elapsed for processing 49 points in 211th row: RMSE: 1.73144664392, ME: 0.117626128655, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_T_c_2017_Spring_RK.tif
# Processing file: SHP_EB_T_c_2017_Summer.shp
# --- Time lapse: 118.35309600830078 seconds ---
# 118 seconds elapsed for processing 45 points in 212th row: RMSE: 1.27682548883, ME: -0.00415666285917, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_T_c_2017_Summer_RK.tif
# Processing file: SHP_EB_T_c_2017_Fall.shp
# --- Time lapse: 113.53507876396179 seconds ---
# 113 seconds elapsed for processing 45 points in 213th row: RMSE: 1.54865445039, ME: 0.0727088024682, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_T_c_2017_Fall_RK.tif
# Processing file: SHP_EB_T_c_2017_Winter.shp
# --- Time lapse: 124.42750597000122 seconds ---
# 124 seconds elapsed for processing 50 points in 214th row: RMSE: 2.12188259952, ME: -0.156523115413, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_T_c_2017_Winter_RK.tif
# Processing file: SHP_EB_T_c_2018_Spring.shp
# --- Time lapse: 105.93993616104126 seconds ---
# 106 seconds elapsed for processing 40 points in 215th row: RMSE: 1.7088479979, ME: 0.127134406938, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/EB_T_c_2018_Spring_RK.tif
# Processing file: SHP_CH_T_c_2016_Summer.shp
# --- Time lapse: 6031.765822887421 seconds ---
# 6031 seconds elapsed for processing 513 points in 216th row: RMSE: 1.35794916131, ME: 0.0066790708865, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_T_c_2016_Summer_RK.tif
# Processing file: SHP_CH_T_c_2016_Fall.shp
# --- Time lapse: 6437.612372159958 seconds ---
# 6437 seconds elapsed for processing 510 points in 217th row: RMSE: 2.81238055145, ME: -0.106348110797, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_T_c_2016_Fall_RK.tif
# Processing file: SHP_CH_T_c_2016_Winter.shp
# --- Time lapse: 7011.407678604126 seconds ---
# 7011 seconds elapsed for processing 429 points in 218th row: RMSE: 3.01953717431, ME: -0.0968352592513, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_T_c_2016_Winter_RK.tif
# Processing file: SHP_CH_T_c_2017_Spring.shp
# --- Time lapse: 6873.923624753952 seconds ---
# 6874 seconds elapsed for processing 440 points in 219th row: RMSE: 2.72615264734, ME: -0.110811130155, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_T_c_2017_Spring_RK.tif
# Processing file: SHP_CH_T_c_2017_Summer.shp
# --- Time lapse: 6946.810841083527 seconds ---
# 6946 seconds elapsed for processing 461 points in 220th row: RMSE: 1.48637593714, ME: 0.0662740954827, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_T_c_2017_Summer_RK.tif
# Processing file: SHP_CH_T_c_2017_Fall.shp
# --- Time lapse: 6638.765144109726 seconds ---
# 6638 seconds elapsed for processing 445 points in 221th row: RMSE: 2.57063740252, ME: -0.00486647675045, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_T_c_2017_Fall_RK.tif
# Processing file: SHP_CH_T_c_2017_Winter.shp
# --- Time lapse: 5159.156436443329 seconds ---
# 5159 seconds elapsed for processing 408 points in 222th row: RMSE: 2.06681827237, ME: -0.00262690175674, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_T_c_2017_Winter_RK.tif
# Processing file: SHP_CH_T_c_2018_Spring.shp
# --- Time lapse: 1309.206523656845 seconds ---
# 1309 seconds elapsed for processing 74 points in 223th row: RMSE: 2.52535947768, ME: -0.241491426401, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/CH_T_c_2018_Spring_RK.tif
# Processing file: SHP_BB_T_c_2021_Summer.shp
# --- Time lapse: 463.13674783706665 seconds ---
# 463 seconds elapsed for processing 88 points in 224th row: RMSE: 0.876472018134, ME: -0.00966567948024, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_T_c_2021_Summer_RK.tif
# Processing file: SHP_BB_T_c_2021_Fall.shp
# --- Time lapse: 450.95041060447693 seconds ---
# 451 seconds elapsed for processing 86 points in 225th row: RMSE: 0.561568694997, ME: -0.0271633113532, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_T_c_2021_Fall_RK.tif
# Processing file: SHP_BB_T_c_2021_Winter.shp
# --- Time lapse: 449.96239256858826 seconds ---
# 450 seconds elapsed for processing 89 points in 226th row: RMSE: 0.899224646936, ME: 0.00585233329356, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_T_c_2021_Winter_RK.tif
# Processing file: SHP_BB_T_c_2022_Spring.shp
# --- Time lapse: 275.25406861305237 seconds ---
# 275 seconds elapsed for processing 52 points in 227th row: RMSE: 0.484023534715, ME: 0.00369324324445, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_T_c_2022_Spring_RK.tif
# Processing file: SHP_BB_T_c_2022_Summer.shp
# --- Time lapse: 393.7046010494232 seconds ---
# 393 seconds elapsed for processing 70 points in 228th row: RMSE: 0.546602652507, ME: -0.00590032995016, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_T_c_2022_Summer_RK.tif
# Processing file: SHP_BB_T_c_2022_Fall.shp
# --- Time lapse: 380.71422052383423 seconds ---
# 380 seconds elapsed for processing 71 points in 229th row: RMSE: 1.04008205803, ME: 0.0659129330298, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_T_c_2022_Fall_RK.tif
# Processing file: SHP_BB_T_c_2022_Winter.shp
# --- Time lapse: 377.4065260887146 seconds ---
# 377 seconds elapsed for processing 72 points in 230th row: RMSE: 1.03540632249, ME: 0.0695933691776, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_T_c_2022_Winter_RK.tif
# Processing file: SHP_BB_T_c_2023_Spring.shp
# --- Time lapse: 398.84316086769104 seconds ---
# 399 seconds elapsed for processing 72 points in 231th row: RMSE: 0.801841012779, ME: 0.0133076326375, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BB_T_c_2023_Spring_RK.tif

# %% [markdown]
# ### Select the abnormal value from the generated results, here we defined that if the RMSE is too low (<-10000), it is the abnormal value.

# %%
error_row = pd.read_csv(gis_path+"rk_results_temp.csv")
error_row_new = error_row.loc[error_row["RMSE"]<-10000]
#error_row_new = error_row_new.drop("Unnamed: 0",axis=1)

error_row_new.to_csv(gis_path+"temp_error.csv")

# %% [markdown]
# ### Reset the smooth_radius from 10 km to 50 km

# %%
error_row_new
# Out:
#                WaterBody  Year  Season          Parameter  \
# 32   Big Bend Seagrasses  2020  Summer     Total Nitrogen
# 33   Big Bend Seagrasses  2020    Fall     Total Nitrogen
# 34   Big Bend Seagrasses  2020  Winter     Total Nitrogen
# 35   Big Bend Seagrasses  2021  Spring     Total Nitrogen
# 36   Big Bend Seagrasses  2021  Summer     Total Nitrogen
# 37   Big Bend Seagrasses  2021    Fall     Total Nitrogen
# 38   Big Bend Seagrasses  2021  Winter     Total Nitrogen
# 39   Big Bend Seagrasses  2022  Spring     Total Nitrogen
# 72   Big Bend Seagrasses  2020  Summer           Salinity
# 73   Big Bend Seagrasses  2020    Fall           Salinity
# 74   Big Bend Seagrasses  2020  Winter           Salinity
# 75   Big Bend Seagrasses  2021  Spring           Salinity
# 76   Big Bend Seagrasses  2021  Summer           Salinity
# 77   Big Bend Seagrasses  2021    Fall           Salinity
# 78   Big Bend Seagrasses  2021  Winter           Salinity
# 79   Big Bend Seagrasses  2022  Spring           Salinity
# 112  Big Bend Seagrasses  2020  Summer   Dissolved Oxygen
# 113  Big Bend Seagrasses  2020    Fall   Dissolved Oxygen
# 114  Big Bend Seagrasses  2020  Winter   Dissolved Oxygen
# 115  Big Bend Seagrasses  2021  Spring   Dissolved Oxygen
# 116  Big Bend Seagrasses  2021  Summer   Dissolved Oxygen
# 117  Big Bend Seagrasses  2021    Fall   Dissolved Oxygen
# 118  Big Bend Seagrasses  2021  Winter   Dissolved Oxygen
# 119  Big Bend Seagrasses  2022  Spring   Dissolved Oxygen
# 152  Big Bend Seagrasses  2020  Summer          Turbidity
# 153  Big Bend Seagrasses  2020    Fall          Turbidity
# 154  Big Bend Seagrasses  2020  Winter          Turbidity
# 155  Big Bend Seagrasses  2021  Spring          Turbidity
# 156  Big Bend Seagrasses  2021  Summer          Turbidity
# 157  Big Bend Seagrasses  2021    Fall          Turbidity
# 158  Big Bend Seagrasses  2021  Winter          Turbidity
# 159  Big Bend Seagrasses  2022  Spring          Turbidity
# 192  Big Bend Seagrasses  2020  Summer       Secchi Depth
# 193  Big Bend Seagrasses  2020    Fall       Secchi Depth
# 194  Big Bend Seagrasses  2020  Winter       Secchi Depth
# 195  Big Bend Seagrasses  2021  Spring       Secchi Depth
# 196  Big Bend Seagrasses  2021  Summer       Secchi Depth
# 197  Big Bend Seagrasses  2021    Fall       Secchi Depth
# 198  Big Bend Seagrasses  2021  Winter       Secchi Depth
# 199  Big Bend Seagrasses  2022  Spring       Secchi Depth
# 232  Big Bend Seagrasses  2020  Summer  Water Temperature
# 233  Big Bend Seagrasses  2020    Fall  Water Temperature
# 234  Big Bend Seagrasses  2020  Winter  Water Temperature
# 235  Big Bend Seagrasses  2021  Spring  Water Temperature
# 236  Big Bend Seagrasses  2021  Summer  Water Temperature
# 237  Big Bend Seagrasses  2021    Fall  Water Temperature
# 238  Big Bend Seagrasses  2021  Winter  Water Temperature
# 239  Big Bend Seagrasses  2022  Spring  Water Temperature
#
#                                               Filename  NumDataPoints  \
# 32   E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             21
# 33   E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             24
# 34   E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             34
# 35   E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             37
# 36   E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             33
# 37   E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             34
# 38   E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             31
# 39   E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             25
# 72   E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             24
# 73   E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             26
# 74   E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...            134
# 75   E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             37
# 76   E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             39
# 77   E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             30
# 78   E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...            132
# 79   E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             17
# 112  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             30
# 113  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             31
# 114  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...            135
# 115  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             48
# 116  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             47
# 117  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             39
# 118  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...            137
# 119  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             30
# 152  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             28
# 153  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             31
# 154  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             39
# 155  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             40
# 156  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             37
# 157  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             35
# 158  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             35
# 159  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             29
# 192  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             28
# 193  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             30
# 194  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             32
# 195  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             41
# 196  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             36
# 197  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             31
# 198  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             32
# 199  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             29
# 232  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             30
# 233  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             31
# 234  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...            136
# 235  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             48
# 236  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             47
# 237  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             39
# 238  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...            138
# 239  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             28
#
#               RMSE             ME      covariates
# 32  -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 33  -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 34  -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 35  -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 36  -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 37  -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 38  -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 39  -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 72  -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 73  -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 74  -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 75  -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 76  -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 77  -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 78  -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 79  -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 112 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 113 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 114 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 115 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 116 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 117 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 118 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 119 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 152 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 153 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 154 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 155 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 156 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 157 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 158 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 159 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 192 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 193 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 194 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 195 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 196 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 197 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 198 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 199 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 232 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 233 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 234 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 235 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 236 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 237 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 238 -1.797693e+308 -1.797693e+308  bathymetry+LDI
# 239 -1.797693e+308 -1.797693e+308  bathymetry+LDI

# %%
# Write the output in a csv file
with open(gis_path+"temp_error.csv", 'w', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    # Write the header line
    cols = list(error_row_new.columns)
    cols.append('covariates')
    csv_writer.writerow(cols)
    
    for i in error_row_new.index:
        s_time =time.time() 
        process,rmse,me,count,file_loc = idw_rk.rk_interpolation(method = "rk",
                                         radius = 50000,
                                         folder_path = shpAll_folder,
                                         covariate_path = gis_path + 'covariates',
                                         waterbody_path = gis_path + "managed_area_boundary/",
                                         waterbody = area_shortnames[error_row_new.loc[i]["WaterBody"]],
                                         parameter = param_shortnames[error_row_new.loc[i]["Parameter"]],
                                         year      = error_row_new.loc[i]["Year"],
                                         season    = error_row_new.loc[i]['Season'],
                                         covariates= covariates_dict[area_shortnames[error_row_new.loc[i]["WaterBody"]]],
                                         out_raster_folder = out_raster_floder,
                                         out_ga_folder     = out_ga_folder,
                                         std_error_folder  = std_error_folder,
                                         diagnostic_folder = diagnostic_folder)
        e_time =time.time()
        print(f"{int(e_time-s_time)} seconds elapsed for processing {count} points in {i}th row: RMSE: {rmse}, ME: {me}, file exported to {file_loc}")
        csv_writer.writerow([error_row_new.loc[i]["WaterBody"], 
                             error_row_new.loc[i]["Year"],
                             error_row_new.loc[i]['Season'],
                             error_row_new.loc[i]["Parameter"],
                             file_loc, count, rmse, me,
                             covariates_dict[area_shortnames[error_row_new.loc[i]["WaterBody"]]]])
        if i%10 == 0: csvfile.flush() # flush the csv file in every 20 rows.
#         seasons_all['RMSE'][i:i+1] = rmse
#         seasons_all['ME'][i:i+1] = me
#         seasons_all['NumDataPoints'][i:i+1] = count
#         seasons_all['Filename'][i:i+1] = file_loc
#     seasons_all.to_csv(gis_path+"result_RK_all.csv")
# Out:
# Processing file: SHP_BBS_TN_mgl_2020_Summer.shp
# --- Time lapse: 1243.7007274627686 seconds ---
# 1243 seconds elapsed for processing 21 points in 32th row: RMSE: 0.36269660957, ME: -0.00546533503078, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_TN_mgl_2020_Summer_RK.tif
# Processing file: SHP_BBS_TN_mgl_2020_Fall.shp
# --- Time lapse: 1412.3664746284485 seconds ---
# 1412 seconds elapsed for processing 24 points in 33th row: RMSE: 0.119020045865, ME: -0.00873171146534, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_TN_mgl_2020_Fall_RK.tif
# Processing file: SHP_BBS_TN_mgl_2020_Winter.shp
# --- Time lapse: 2343.838243484497 seconds ---
# 2343 seconds elapsed for processing 34 points in 34th row: RMSE: 0.202855833315, ME: 0.00810422364266, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_TN_mgl_2020_Winter_RK.tif
# Processing file: SHP_BBS_TN_mgl_2021_Spring.shp
# --- Time lapse: 2365.6148660182953 seconds ---
# 2365 seconds elapsed for processing 37 points in 35th row: RMSE: 0.225832192114, ME: -0.0151354595778, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_TN_mgl_2021_Spring_RK.tif
# Processing file: SHP_BBS_TN_mgl_2021_Summer.shp
# --- Time lapse: 2060.5091803073883 seconds ---
# 2060 seconds elapsed for processing 33 points in 36th row: RMSE: 0.209778274431, ME: 0.00474779732205, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_TN_mgl_2021_Summer_RK.tif
# Processing file: SHP_BBS_TN_mgl_2021_Fall.shp
# --- Time lapse: 2380.3001639842987 seconds ---
# 2380 seconds elapsed for processing 34 points in 37th row: RMSE: 0.177034427747, ME: -0.0110137171364, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_TN_mgl_2021_Fall_RK.tif
# Processing file: SHP_BBS_TN_mgl_2021_Winter.shp
# --- Time lapse: 2189.449254989624 seconds ---
# 2189 seconds elapsed for processing 31 points in 38th row: RMSE: 0.150413296977, ME: -0.000642684327367, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_TN_mgl_2021_Winter_RK.tif
# Processing file: SHP_BBS_TN_mgl_2022_Spring.shp
# --- Time lapse: 1487.2811028957367 seconds ---
# 1487 seconds elapsed for processing 25 points in 39th row: RMSE: 0.0935470103999, ME: -0.000504431218668, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_TN_mgl_2022_Spring_RK.tif
# Processing file: SHP_BBS_Sal_ppt_2020_Summer.shp
# --- Time lapse: 1630.596866607666 seconds ---
# 1630 seconds elapsed for processing 24 points in 72th row: RMSE: 3.67796900469, ME: -0.167718401109, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Sal_ppt_2020_Summer_RK.tif
# Processing file: SHP_BBS_Sal_ppt_2020_Fall.shp
# --- Time lapse: 1976.3668382167816 seconds ---
# 1976 seconds elapsed for processing 26 points in 73th row: RMSE: 4.14489490914, ME: -0.318540133038, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Sal_ppt_2020_Fall_RK.tif
# Processing file: SHP_BBS_Sal_ppt_2020_Winter.shp
# --- Time lapse: 8498.256042003632 seconds ---
# 8498 seconds elapsed for processing 134 points in 74th row: RMSE: 3.13128510682, ME: -0.105074921011, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Sal_ppt_2020_Winter_RK.tif
# Processing file: SHP_BBS_Sal_ppt_2021_Spring.shp
# --- Time lapse: 2856.2471795082092 seconds ---
# 2856 seconds elapsed for processing 37 points in 75th row: RMSE: 5.29515368017, ME: -0.490581312925, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Sal_ppt_2021_Spring_RK.tif
# Processing file: SHP_BBS_Sal_ppt_2021_Summer.shp
# --- Time lapse: 2808.0324289798737 seconds ---
# 2808 seconds elapsed for processing 39 points in 76th row: RMSE: 6.45997495077, ME: -0.826768483584, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Sal_ppt_2021_Summer_RK.tif
# Processing file: SHP_BBS_Sal_ppt_2021_Fall.shp
# --- Time lapse: 2238.675530910492 seconds ---
# 2238 seconds elapsed for processing 30 points in 77th row: RMSE: 5.68747909518, ME: -0.301336932688, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Sal_ppt_2021_Fall_RK.tif
# Processing file: SHP_BBS_Sal_ppt_2021_Winter.shp
# --- Time lapse: 10054.576964616776 seconds ---
# 10054 seconds elapsed for processing 132 points in 78th row: RMSE: 3.32383389084, ME: 0.0596612450433, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Sal_ppt_2021_Winter_RK.tif
# Processing file: SHP_BBS_Sal_ppt_2022_Spring.shp
# --- Time lapse: 1368.2427771091461 seconds ---
# 1368 seconds elapsed for processing 17 points in 79th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Sal_ppt_2022_Spring_RK.tif
# Processing file: SHP_BBS_DO_mgl_2020_Summer.shp
# --- Time lapse: 2043.2693717479706 seconds ---
# 2043 seconds elapsed for processing 30 points in 112th row: RMSE: 1.67454157754, ME: -0.17693944709, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_DO_mgl_2020_Summer_RK.tif
# Processing file: SHP_BBS_DO_mgl_2020_Fall.shp
# --- Time lapse: 2175.3673481941223 seconds ---
# 2175 seconds elapsed for processing 31 points in 113th row: RMSE: 1.22851268557, ME: -0.0509589383986, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_DO_mgl_2020_Fall_RK.tif
# Processing file: SHP_BBS_DO_mgl_2020_Winter.shp
# --- Time lapse: 11485.295891523361 seconds ---
# 11485 seconds elapsed for processing 135 points in 114th row: RMSE: 1.22393567322, ME: 0.040983509867, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_DO_mgl_2020_Winter_RK.tif
# Processing file: SHP_BBS_DO_mgl_2021_Spring.shp
# --- Time lapse: 3306.0170459747314 seconds ---
# 3306 seconds elapsed for processing 48 points in 115th row: RMSE: 1.04384961025, ME: -0.211543164692, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_DO_mgl_2021_Spring_RK.tif
# Processing file: SHP_BBS_DO_mgl_2021_Summer.shp
# --- Time lapse: 3367.8387348651886 seconds ---
# 3367 seconds elapsed for processing 47 points in 116th row: RMSE: 0.971915263352, ME: -0.0987333454759, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_DO_mgl_2021_Summer_RK.tif
# Processing file: SHP_BBS_DO_mgl_2021_Fall.shp
# --- Time lapse: 2764.352724790573 seconds ---
# 2764 seconds elapsed for processing 39 points in 117th row: RMSE: 1.04227817957, ME: -0.207441732119, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_DO_mgl_2021_Fall_RK.tif
# Processing file: SHP_BBS_DO_mgl_2021_Winter.shp
# --- Time lapse: 11581.002548217773 seconds ---
# 11581 seconds elapsed for processing 137 points in 118th row: RMSE: 0.897527640701, ME: -0.0330164050113, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_DO_mgl_2021_Winter_RK.tif
# Processing file: SHP_BBS_DO_mgl_2022_Spring.shp
# --- Time lapse: 2066.6807432174683 seconds ---
# 2066 seconds elapsed for processing 30 points in 119th row: RMSE: 1.60073937692, ME: -0.0973375795246, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_DO_mgl_2022_Spring_RK.tif
# Processing file: SHP_BBS_Turb_ntu_2020_Summer.shp
# --- Time lapse: 1869.473645210266 seconds ---
# 1869 seconds elapsed for processing 28 points in 152th row: RMSE: 3.59184280497, ME: -0.00491673140707, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Turb_ntu_2020_Summer_RK.tif
# Processing file: SHP_BBS_Turb_ntu_2020_Fall.shp
# --- Time lapse: 2145.543501138687 seconds ---
# 2145 seconds elapsed for processing 31 points in 153th row: RMSE: 2.44958284248, ME: 0.00892832468543, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Turb_ntu_2020_Fall_RK.tif
# Processing file: SHP_BBS_Turb_ntu_2020_Winter.shp
# --- Time lapse: 2677.809057235718 seconds ---
# 2677 seconds elapsed for processing 39 points in 154th row: RMSE: 3.31607773368, ME: -0.199085159344, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Turb_ntu_2020_Winter_RK.tif
# Processing file: SHP_BBS_Turb_ntu_2021_Spring.shp
# --- Time lapse: 2743.9066920280457 seconds ---
# 2744 seconds elapsed for processing 40 points in 155th row: RMSE: 1.8381842999, ME: -0.00820663980232, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Turb_ntu_2021_Spring_RK.tif
# Processing file: SHP_BBS_Turb_ntu_2021_Summer.shp
# --- Time lapse: 1846.7193732261658 seconds ---
# 1846 seconds elapsed for processing 37 points in 156th row: RMSE: 4.24610556119, ME: 0.126021608593, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Turb_ntu_2021_Summer_RK.tif
# Processing file: SHP_BBS_Turb_ntu_2021_Fall.shp
# --- Time lapse: 2188.2067263126373 seconds ---
# 2188 seconds elapsed for processing 35 points in 157th row: RMSE: 2.11561020138, ME: 0.0563472780595, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Turb_ntu_2021_Fall_RK.tif
# Processing file: SHP_BBS_Turb_ntu_2021_Winter.shp
# --- Time lapse: 2288.771324634552 seconds ---
# 2288 seconds elapsed for processing 35 points in 158th row: RMSE: 2.40376761844, ME: 0.11179622214, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Turb_ntu_2021_Winter_RK.tif
# Processing file: SHP_BBS_Turb_ntu_2022_Spring.shp
# --- Time lapse: 1913.753386259079 seconds ---
# 1913 seconds elapsed for processing 29 points in 159th row: RMSE: 5.06950585554, ME: -0.0561152642542, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Turb_ntu_2022_Spring_RK.tif
# Processing file: SHP_BBS_Secc_m_2020_Summer.shp
# --- Time lapse: 1155.716234922409 seconds ---
# 1155 seconds elapsed for processing 28 points in 192th row: RMSE: 1.09775260014, ME: 0.03662082094, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Secc_m_2020_Summer_RK.tif
# Processing file: SHP_BBS_Secc_m_2020_Fall.shp
# --- Time lapse: 1387.0791459083557 seconds ---
# 1387 seconds elapsed for processing 30 points in 193th row: RMSE: 0.797728892884, ME: 0.0752070802021, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Secc_m_2020_Fall_RK.tif
# Processing file: SHP_BBS_Secc_m_2020_Winter.shp
# --- Time lapse: 1504.4772794246674 seconds ---
# 1504 seconds elapsed for processing 32 points in 194th row: RMSE: 1.41301760856, ME: 0.0632446118113, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Secc_m_2020_Winter_RK.tif
# Processing file: SHP_BBS_Secc_m_2021_Spring.shp
# --- Time lapse: 1803.8746161460876 seconds ---
# 1803 seconds elapsed for processing 41 points in 195th row: RMSE: 1.23163768269, ME: 0.0464940889479, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Secc_m_2021_Spring_RK.tif
# Processing file: SHP_BBS_Secc_m_2021_Summer.shp
# --- Time lapse: 2000.755532026291 seconds ---
# 2000 seconds elapsed for processing 36 points in 196th row: RMSE: 1.10370633665, ME: 0.0833477917945, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Secc_m_2021_Summer_RK.tif
# Processing file: SHP_BBS_Secc_m_2021_Fall.shp
# --- Time lapse: 1601.1247508525848 seconds ---
# 1601 seconds elapsed for processing 31 points in 197th row: RMSE: 0.801242891481, ME: 0.033045689043, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Secc_m_2021_Fall_RK.tif
# Processing file: SHP_BBS_Secc_m_2021_Winter.shp
# --- Time lapse: 1876.0200412273407 seconds ---
# 1876 seconds elapsed for processing 32 points in 198th row: RMSE: 0.464286917332, ME: 0.0802825596494, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Secc_m_2021_Winter_RK.tif
# Processing file: SHP_BBS_Secc_m_2022_Spring.shp
# --- Time lapse: 1626.5202889442444 seconds ---
# 1626 seconds elapsed for processing 29 points in 199th row: RMSE: 1.58246529441, ME: 0.110297333473, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_Secc_m_2022_Spring_RK.tif
# Processing file: SHP_BBS_T_c_2020_Summer.shp
# --- Time lapse: 2026.0124344825745 seconds ---
# 2026 seconds elapsed for processing 30 points in 232th row: RMSE: 1.27944696171, ME: -0.069852123331, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_T_c_2020_Summer_RK.tif
# Processing file: SHP_BBS_T_c_2020_Fall.shp
# --- Time lapse: 2199.6179263591766 seconds ---
# 2199 seconds elapsed for processing 31 points in 233th row: RMSE: 2.07849464809, ME: 0.0963584421718, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_T_c_2020_Fall_RK.tif
# Processing file: SHP_BBS_T_c_2020_Winter.shp
# --- Time lapse: 10967.95088148117 seconds ---
# 10968 seconds elapsed for processing 136 points in 234th row: RMSE: 4.80274961001, ME: 0.27590543522, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_T_c_2020_Winter_RK.tif
# Processing file: SHP_BBS_T_c_2021_Spring.shp
# --- Time lapse: 3185.7733855247498 seconds ---
# 3185 seconds elapsed for processing 48 points in 235th row: RMSE: 2.30141727246, ME: -0.0563408650595, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_T_c_2021_Spring_RK.tif
# Processing file: SHP_BBS_T_c_2021_Summer.shp
# --- Time lapse: 3184.8464591503143 seconds ---
# 3184 seconds elapsed for processing 47 points in 236th row: RMSE: 0.86843800462, ME: -0.062430159704, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_T_c_2021_Summer_RK.tif
# Processing file: SHP_BBS_T_c_2021_Fall.shp
# --- Time lapse: 2808.739917755127 seconds ---
# 2808 seconds elapsed for processing 39 points in 237th row: RMSE: 2.56690978004, ME: -0.0262918827314, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_T_c_2021_Fall_RK.tif
# Processing file: SHP_BBS_T_c_2021_Winter.shp
# --- Time lapse: 10483.627133131027 seconds ---
# 10483 seconds elapsed for processing 138 points in 238th row: RMSE: 3.29664080706, ME: 0.205118507442, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_T_c_2021_Winter_RK.tif
# Processing file: SHP_BBS_T_c_2022_Spring.shp
# --- Time lapse: 1884.1308734416962 seconds ---
# 1884 seconds elapsed for processing 28 points in 239th row: RMSE: 1.48695558475, ME: 0.0513451394552, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/rk_All/BBS_T_c_2022_Spring_RK.tif

# %% [markdown]
# ### Merge the revised results into original results

# %%
# Specify the file paths of the CSV files you want to remove
file1 = gis_path+"rk_results_temp.csv"
file2 = gis_path+"temp_error.csv"

original_file = pd.read_csv(file1)
error_row_file= pd.read_csv(file2)

# %%
error_index = original_file[original_file["RMSE"]<-10000].index

abnormal_drop = original_file.drop(index=error_index)

# %%
new_file = pd.concat([abnormal_drop,error_row_file])
new_file = new_file.drop(columns=['covariates.1'])

# %% [markdown]
# ### Export the final results

# %%
new_file.to_csv(gis_path+"rk_results.csv")

#os.remove(file1)
#os.remove(file2)

# %% [markdown]
# ### Join IDW all data and IDW of continuous data

# %%
# Define result folder
result_folder = "E:/Projects/SEACAR_WQ_2024/result/result_v3/"

# Read RK results
new_file = pd.read_csv(result_folder+"rk_results.csv")

# Read IDW con and discrete result
df_idw_all = pd.read_csv(result_folder + "idw_all.csv") # read results of IDW of all samples
df_idw_con = pd.read_csv(gis_path + "raster_output/idw_Con/updated_idw.csv") # read results of IDW of continuous samples

# join idw_con with idw_all
df_idw = pd.merge(df_idw_all, df_idw_con, on=['WaterBody', 'Year', 'Season', 'Parameter'], how='left', suffixes=('_idw_all','_idw_con'))


# rename and remove certain columns
df_idw = df_idw.drop(columns = ['Filename_idw_con']).rename(columns={'Filename_idw_all':'Filename',
                                                                     'NumDataPoints_idw_all':'NumDataPoints_all',
                                                                    'NumDataPoints_idw_con':'NumDataPoints_con'})


# convert number of data points to integer and remove NaN
df_idw['NumDataPoints_con'] = df_idw['NumDataPoints_con'].fillna(0).astype(int)

# %% [markdown]
# ### Join IDW and RK results

# %%
df_all = pd.merge(df_idw, new_file, on=['WaterBody', 'Year', 'Season', 'Parameter'], how='left', suffixes=('','_rk'))
df_all = df_all.drop(columns = ['Filename_rk','NumDataPoints']).rename(columns={'Filename_idw':'Filename',
                                                                                   'NumDataPoints_idw':'NumDataPoints',
                                                                                  'RMSE':'RMSE_rk',
                                                                                  'ME':'ME_rk'})
df_all.to_csv(result_folder+"rk_idw_comp.csv")

df_all
# Out:
#                    WaterBody  Year  Season       Parameter  \
# 0    Guana Tolomato Matanzas  2015    Fall  Total Nitrogen
# 1    Guana Tolomato Matanzas  2015  Winter  Total Nitrogen
# 2    Guana Tolomato Matanzas  2016  Spring  Total Nitrogen
# 3    Guana Tolomato Matanzas  2016  Summer  Total Nitrogen
# 4    Guana Tolomato Matanzas  2016    Fall  Total Nitrogen
# ..                       ...   ...     ...             ...
# 235         Charlotte Harbor  2017  Spring  Total Nitrogen
# 236         Charlotte Harbor  2017  Summer  Total Nitrogen
# 237         Charlotte Harbor  2017    Fall  Total Nitrogen
# 238         Charlotte Harbor  2017  Winter  Total Nitrogen
# 239         Charlotte Harbor  2018  Spring  Total Nitrogen
#
#                            Filename  NumDataPoints_all  RMSE_idw_all  \
# 0      SHP_GTM_TN_mgl_2015_Fall.shp                 10      0.561377
# 1    SHP_GTM_TN_mgl_2015_Winter.shp                  6      0.140398
# 2    SHP_GTM_TN_mgl_2016_Spring.shp                  5      0.147875
# 3    SHP_GTM_TN_mgl_2016_Summer.shp                  5      0.096097
# 4      SHP_GTM_TN_mgl_2016_Fall.shp                  5      0.163046
# ..                              ...                ...           ...
# 235   SHP_CH_TN_mgl_2017_Spring.shp                 57      0.400803
# 236   SHP_CH_TN_mgl_2017_Summer.shp                 42      0.149936
# 237     SHP_CH_TN_mgl_2017_Fall.shp                 51      0.219190
# 238   SHP_CH_TN_mgl_2017_Winter.shp                 61      0.160795
# 239   SHP_CH_TN_mgl_2018_Spring.shp                 65      0.212305
#
#      ME_idw_all  NumDataPoints_con  RMSE_idw_con  ME_idw_con  Unnamed: 0  \
# 0      0.118043                  0           NaN         NaN           0
# 1     -0.037123                  0           NaN         NaN           1
# 2     -0.037670                  0           NaN         NaN           2
# 3     -0.026495                  0           NaN         NaN           3
# 4     -0.044804                  0           NaN         NaN           4
# ..          ...                ...           ...         ...         ...
# 235    0.004530                  0           NaN         NaN          19
# 236   -0.002792                  0           NaN         NaN          20
# 237    0.004765                  0           NaN         NaN          21
# 238    0.005508                  0           NaN         NaN          22
# 239    0.035442                  0           NaN         NaN          23
#
#       RMSE_rk     ME_rk                            covariates
# 0    0.449064  0.055740                                   LDI
# 1         NaN       NaN                                   LDI
# 2         NaN       NaN                                   LDI
# 3         NaN       NaN                                   LDI
# 4         NaN       NaN                                   LDI
# ..        ...       ...                                   ...
# 235  0.281052  0.004211  bathymetry+LDI+popden+water_flow_wet
# 236  0.111250 -0.000281  bathymetry+LDI+popden+water_flow_wet
# 237  0.194828  0.000415  bathymetry+LDI+popden+water_flow_wet
# 238  0.124463  0.002064  bathymetry+LDI+popden+water_flow_wet
# 239  0.186678 -0.003627  bathymetry+LDI+popden+water_flow_wet
#
# [240 rows x 15 columns]
