# %% [markdown]
# # Cross Validation for IDW Interpolation
# ## Task 2A (IDW for continuous & discrete)
#
# This document includes Python codes that conduct cross validation (CV) for Inverse Distance Weighting (IDW) Interpolation on water quality parameters, including 6 water quality parameters in arcpy environment:
# - Dissolved oxygen (DO_mgl)
# - Salinity (Sal_ppt)
# - Turbidity (Turb_ntu)
# - Temperature (T_c)
# - Secchi (Secc_m)
# - Total Nitrogen (TN_mgl)
#
# The analysis is conducted in the separate water bodies:
# - Guana Tolomato Matanzas (GTM)
# - Estero Bay (EB)
# - Charlotte Harbor (CH)
# - Biscayne Bay (BB)
# - Big Bend Seagrasses (BBS)
#
# **Tasks:**
#
# - **Task 2A Calculate the RMSE and Mean Error (ME) for IDW results using both continuous and discrete data**
#
# - Task 2B Calculate the RMSE and Mean Error (ME) for IDW results using continuous data.
#
# Time periods one year before and after storm event for Task 2A tests (seasons).
# <br>
# <div style="text-align: left;">
#     <img src="../misc/TimePeriods.png" style="display: block; margin-left: 0; margin-right: auto; width: 600px;"/>
# </div>
#
# Summary of IDK and RK Accuracy Assessments.
# <br>
# <div style="text-align: left;">
#     <img src="../misc/Table3.png" style="display: block; margin-left: 0; margin-right: auto; width: 600px;"/>
# </div>
#
# **Contents:**
# * [1. Data Preprocess](#reg_preprocessing)
#     * [1.1 Subsetting Dataset](#reg_subset)
#     * [1.2 Preview Dataset](#reg_preview)
#     * [1.3 Fill Unique ID](#reg_id)
# * [2. Create Shapefile](#reg_create_shp)
# * [3. Cross Validation for IDW](#reg_cv_idw)

# %% [markdown]
# # 1. Loading packages

# %%
import pandas as pd
import numpy  as np
import arcpy
from arcpy.sa import *
import os, time, math, importlib, sys
path = r'E:\Projects\SEACAR_WQ_2024\git\misc'
sys.path.insert(0, path)
import idw_rk
# !install conda install conda-forge::pyproj
import pyproj,csv

importlib.reload(idw_rk)

import warnings
warnings.filterwarnings('ignore')

# define scratch folder to avoid overwritting from parallel threats
arcpy.env.scratchWorkspace = r"E:\Projects\SEACAR_WQ_2024\scratch/IDW_all"

# %% [markdown]
# # 1. Data Preprocessing <a class="anchor" id="reg_preprocessing"></a>
#
# ## 1.1 Load csv files

# %%
gis_path = r'E:/Projects/SEACAR_WQ_2024/GIS_Data/'

dfCon = pd.read_csv(gis_path + 'OEAT_Continuous_WQ-2024-Feb-21.csv', low_memory=False)
dfDis = pd.read_csv(gis_path + 'OEAT_Discrete_WQ-2024-May-06.csv', low_memory=False)

# %% [markdown]
# ## 1.2 Subsetting Data <a class="anchor" id="reg_subset"></a>
#
# ### Selecting data from 8 am to 18 pm (daytime)

# %%
# Convert string to datetime
dfDis['SampleDate'] = pd.to_datetime(dfDis['SampleDate'], format='%Y-%m-%d %H:%M:%S.%f')
dfCon['SampleDate'] = pd.to_datetime(dfCon['SampleDate'], format='%Y-%m-%d %H:%M:%S.%f')


# Include date from 8:00 am to 18:00 pm
start_time = '08:00'
end_time = '18:00'

dfConTime = dfCon[dfCon['SampleDate'].dt.time.between(pd.to_datetime(start_time).time(), pd.to_datetime(end_time).time())]

# Concatenate time-filtered continuous and discrete data
dfAll = pd.concat([dfDis, dfConTime], ignore_index=True)

# %% [markdown]
# ## 1.3 Calculating average values at unique observation points

# %%
dfAll_Mean = dfAll.groupby(['WaterBody','ParameterName','ParameterUnits', 'Year','Season','Latitude_DD','Longitude_DD','WbodyAcronym'])["ResultValue"].agg("mean").reset_index()
dfAll = dfAll_Mean

# %% [markdown]
# ## 1.4 Convert coordinate system to EPSG: 3086

# %%
# Define the EPSG codes for source (EPSG:4326) and target (EPSG:3086) coordinate systems
source_epsg = 'EPSG:4326'
target_epsg = 'EPSG:3086'

# Create a PyProj Transformer for the conversion
transformer = pyproj.Transformer.from_crs(source_epsg, target_epsg, always_xy=True)

# Define a function to apply the transformation to each row of the DataFrame
def transform_coordinates(row):
    x, y = transformer.transform(row['Longitude_DD'], row['Latitude_DD'])
    return pd.Series({'x': x, 'y': y})

# Apply the transformation function to the DataFrame and create new columns for the converted coordinates
dfAll[['x', 'y']] = dfAll.apply(transform_coordinates, axis=1)

# %% [markdown]
# #### Save aggregated data to csv file

# %%
dfAll.to_csv(gis_path + 'OEAT_All_WQ-2024-Feb-21.csv', index=False)

# %% [markdown]
# ## 2. Prepare for batch interpolation
# ### 2.1 Preset abbreviation for waterbody and parameter name

# %%
area_shortnames = {
    'Guana Tolomato Matanzas': 'GTM',
    'Estero Bay': 'EB',
    'Charlotte Harbor': 'CH',
    'Biscayne Bay': 'BB',
    'Big Bend Seagrasses':'BBS'
}

param_shortnames = {
    'Salinity': 'Sal_ppt',
    'Total Nitrogen': 'TN_mgl',
    'Dissolved Oxygen': 'DO_mgl',
    'Turbidity':'Turb_ntu',
    'Secchi Depth':'Secc_m',
    'Water Temperature':'T_c'
}

# Set input parameters
waterbody_names = [
    'Guana Tolomato Matanzas',
    'Estero Bay',
    'Charlotte Harbor',
    'Biscayne Bay',
    'Big Bend Seagrasses'
]

covariates_dict = {
    "GTM":"LDI",
    "EB":"bathymetry+LDI+popden",
    "CH":"bathymetry+LDI+popden+water_flow_wet",
    "BB":"bathymetry+LDI+popden",
    "BBS":"bathymetry+LDI"
}

parameter_names = ['Dissolved Oxygen', 'Salinity', 'Secchi Depth', 'Total Nitrogen', 'Turbidity', 'Water Temperature']
# years = unique_years
seasons = ['Fall', 'Spring', 'Summer', 'Winter']
# shp_folder = gis_path + r"shapefiles_All"
shp_folder = gis_path + r"shapefiles"

# %% [markdown]
# ### 2.2 Define the barrier files

# %%
barrier_folder = os.path.join(gis_path, 'Barriers')
barrier_folder

barriers = []
for file in os.listdir(barrier_folder):
    if file.endswith(".shp"):
        barriers.append(os.path.join(barrier_folder, file))

for barrier in barriers:
    print(barrier)
# Out:
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\BBS_Barriers.shp
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\BB_Barriers.shp
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\CH_Barriers.shp
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\EB_Barriers.shp
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\GTM_Barriers.shp

# %% [markdown]
# ### 2.3 Define waterbody boundary for spatial extent and masking

# %%
waterbody_extent = os.path.join(gis_path, 'OEAT_Waterbody_Boundaries', 'OEAT_Waterbody_Boundary.shp')

unique_waterbodies = []
with arcpy.da.SearchCursor(waterbody_extent, ['WaterbodyA']) as cursor:
    for row in cursor:
        unique_waterbodies.append(row[0])

print("Unique Waterbodies:", unique_waterbodies)
# Out:
# Unique Waterbodies: ['BBS', 'BB', 'CH', 'EB', 'GTM']

# %% [markdown]
# ### 2.4 Load the table of study periods,  parameters, and seasons

# %%
seasons_all = pd.read_csv(gis_path + 'Seasons_all.csv', low_memory=False)

# %% [markdown]
# ### 2.5 Define output folders

# %%
shpAll_folder = gis_path + r"shapefiles/shapefiles_All" 
idwAll_folder = gis_path + r"raster_output/idw_All"

# Preview dataset
dfAll
# Out:
#                      WaterBody      ParameterName ParameterUnits  Year  \
# 0          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# 1          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# 2          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# 3          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# 4          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# ...                        ...                ...            ...   ...
# 77793  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
# 77794  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
# 77795  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
# 77796  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
# 77797  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
#
#        Season  Latitude_DD  Longitude_DD WbodyAcronym  ResultValue  \
# 0        Fall    29.008300    -82.825250          BBS     6.350000
# 1        Fall    29.036716    -83.129066          BBS     6.200000
# 2        Fall    29.046916    -83.033200          BBS     7.100000
# 3        Fall    29.054833    -82.758666          BBS     6.500000
# 4        Fall    29.056800    -83.059133          BBS     6.000000
# ...       ...          ...           ...          ...          ...
# 77793  Summer    30.025360    -81.370918          GTM    29.150000
# 77794  Summer    30.026440    -81.369403          GTM    29.500000
# 77795  Summer    30.033611    -81.353027          GTM    29.766667
# 77796  Summer    30.050338    -81.371008          GTM    29.675000
# 77797  Winter    29.722944    -81.264222          GTM    16.500000
#
#                    x              y
# 0      514236.421551  556316.396318
# 1      484670.524231  559226.858975
# 2      493981.422006  560428.927830
# 3      520659.055377  561546.969670
# 4      491452.167490  561506.993606
# ...              ...            ...
# 77793  653237.586095  671395.945419
# 77794  653380.952596  671518.961956
# 77795  654940.976043  672348.548670
# 77796  653169.830710  674167.856772
# 77797  664257.827848  638055.404228
#
# [77798 rows x 11 columns]

# %% [markdown]
# ## 2.6 Fill NaN RowID with unique ID, IDW function needs unique ID <a class="anchor" id="reg_id"></a>

# %%
idw_rk.fill_nan_rowids(dfAll, 'RowID')

# Keep RowID as integer
dfAll['RowID'] = dfAll['RowID'].astype(int)
dfAll
# Out:
#                      WaterBody      ParameterName ParameterUnits  Year  \
# 0          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# 1          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# 2          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# 3          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# 4          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# ...                        ...                ...            ...   ...
# 77793  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
# 77794  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
# 77795  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
# 77796  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
# 77797  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
#
#        Season  Latitude_DD  Longitude_DD WbodyAcronym  ResultValue  \
# 0        Fall    29.008300    -82.825250          BBS     6.350000
# 1        Fall    29.036716    -83.129066          BBS     6.200000
# 2        Fall    29.046916    -83.033200          BBS     7.100000
# 3        Fall    29.054833    -82.758666          BBS     6.500000
# 4        Fall    29.056800    -83.059133          BBS     6.000000
# ...       ...          ...           ...          ...          ...
# 77793  Summer    30.025360    -81.370918          GTM    29.150000
# 77794  Summer    30.026440    -81.369403          GTM    29.500000
# 77795  Summer    30.033611    -81.353027          GTM    29.766667
# 77796  Summer    30.050338    -81.371008          GTM    29.675000
# 77797  Winter    29.722944    -81.264222          GTM    16.500000
#
#                    x              y  RowID
# 0      514236.421551  556316.396318      1
# 1      484670.524231  559226.858975      2
# 2      493981.422006  560428.927830      3
# 3      520659.055377  561546.969670      4
# 4      491452.167490  561506.993606      5
# ...              ...            ...    ...
# 77793  653237.586095  671395.945419  77794
# 77794  653380.952596  671518.961956  77795
# 77795  654940.976043  672348.548670  77796
# 77796  653169.830710  674167.856772  77797
# 77797  664257.827848  638055.404228  77798
#
# [77798 rows x 12 columns]

# %% [markdown]
# # 3. Create Shapefiles <a class="anchor" id="reg_create_shp"></a>

# %%
# Merge interested with latitude and longitude columns
seasons_all_coord = idw_rk.merge_with_lat_long(seasons_all, dfAll)
seasons_all_coord
# Out:
#                      WaterBody  Year  Season          Parameter  \
# 0      Guana Tolomato Matanzas  2015    Fall     Total Nitrogen
# 1      Guana Tolomato Matanzas  2015    Fall     Total Nitrogen
# 2      Guana Tolomato Matanzas  2015    Fall     Total Nitrogen
# 3      Guana Tolomato Matanzas  2015    Fall     Total Nitrogen
# 4      Guana Tolomato Matanzas  2015    Fall     Total Nitrogen
# ...                        ...   ...     ...                ...
# 20384      Big Bend Seagrasses  2022  Spring  Water Temperature
# 20385      Big Bend Seagrasses  2022  Spring  Water Temperature
# 20386      Big Bend Seagrasses  2022  Spring  Water Temperature
# 20387      Big Bend Seagrasses  2022  Spring  Water Temperature
# 20388      Big Bend Seagrasses  2022  Spring  Water Temperature
#
#                                                 Filename  NumDataPoints  \
# 0                                                    NaN              0
# 1                                                    NaN              0
# 2                                                    NaN              0
# 3                                                    NaN              0
# 4                                                    NaN              0
# ...                                                  ...            ...
# 20384  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             27
# 20385  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             27
# 20386  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             27
# 20387  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             27
# 20388  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             27
#
#                 RMSE             ME              x              y  RowID  \
# 0                NaN            NaN  669975.848287  626752.656623  75890
# 1                NaN            NaN  662275.840738  630059.187470  75891
# 2                NaN            NaN  667035.271306  631036.021679  75892
# 3                NaN            NaN  668862.259531  631692.835328  75893
# 4                NaN            NaN  665055.970903  631868.535738  75894
# ...              ...            ...            ...            ...    ...
# 20384 -1.797693e+308 -1.797693e+308  374832.099897  689623.362197  26660
# 20385 -1.797693e+308 -1.797693e+308  371015.090649  692081.211171  26661
# 20386 -1.797693e+308 -1.797693e+308  401894.595993  699335.031753  26662
# 20387 -1.797693e+308 -1.797693e+308  401457.362103  702258.799507  26663
# 20388 -1.797693e+308 -1.797693e+308  418525.986339  706988.805812  26664
#
#        ResultValue
# 0         0.212233
# 1         1.034500
# 2         1.366500
# 3         0.192567
# 4         0.862000
# ...            ...
# 20384    20.533333
# 20385    20.740000
# 20386    19.500000
# 20387    20.500000
# 20388    15.900000
#
# [20389 rows x 12 columns]

# %%
# Skip if RK has already created and is currently running
idw_rk.create_shp_season(seasons_all_coord, shpAll_folder)

# %% [markdown]
# # 4. Cross Validation for IDW <a class="anchor" id="reg_cv_idw"></a>

# %%
# Empty the shapefile folder
idw_rk.delete_all_files(idwAll_folder)

# %%
# Select a section of table to process
seasons_slct = seasons_all.iloc[:]
# seasons_slct = seasons_all.iloc[:56].reset_index()
seasons_slct.drop(seasons_slct[seasons_slct['WaterBody'] == 'Charlotte Harbor'].index, inplace=True)
seasons_slct
# Out:
#     index                WaterBody  Year  Season       Parameter Filename  \
# 0       0  Guana Tolomato Matanzas  2015    Fall  Total Nitrogen      NaN
# 1       1  Guana Tolomato Matanzas  2015  Winter  Total Nitrogen      NaN
# 2       2  Guana Tolomato Matanzas  2016  Spring  Total Nitrogen      NaN
# 3       3  Guana Tolomato Matanzas  2016  Summer  Total Nitrogen      NaN
# 4       4  Guana Tolomato Matanzas  2016    Fall  Total Nitrogen      NaN
# 5       5  Guana Tolomato Matanzas  2016  Winter  Total Nitrogen      NaN
# 6       6  Guana Tolomato Matanzas  2017  Spring  Total Nitrogen      NaN
# 7       7  Guana Tolomato Matanzas  2017  Summer  Total Nitrogen      NaN
# 8       8               Estero Bay  2016  Summer  Total Nitrogen      NaN
# 9       9               Estero Bay  2016    Fall  Total Nitrogen      NaN
# 10     10               Estero Bay  2016  Winter  Total Nitrogen      NaN
# 11     11               Estero Bay  2017  Spring  Total Nitrogen      NaN
# 12     12               Estero Bay  2017  Summer  Total Nitrogen      NaN
# 13     13               Estero Bay  2017    Fall  Total Nitrogen      NaN
# 14     14               Estero Bay  2017  Winter  Total Nitrogen      NaN
# 15     15               Estero Bay  2018  Spring  Total Nitrogen      NaN
# 24     24             Biscayne Bay  2021  Summer  Total Nitrogen      NaN
# 25     25             Biscayne Bay  2021    Fall  Total Nitrogen      NaN
# 26     26             Biscayne Bay  2021  Winter  Total Nitrogen      NaN
# 27     27             Biscayne Bay  2022  Spring  Total Nitrogen      NaN
# 28     28             Biscayne Bay  2022  Summer  Total Nitrogen      NaN
# 29     29             Biscayne Bay  2022    Fall  Total Nitrogen      NaN
# 30     30             Biscayne Bay  2022  Winter  Total Nitrogen      NaN
# 31     31             Biscayne Bay  2023  Spring  Total Nitrogen      NaN
# 32     32      Big Bend Seagrasses  2020  Summer  Total Nitrogen      NaN
# 33     33      Big Bend Seagrasses  2020    Fall  Total Nitrogen      NaN
# 34     34      Big Bend Seagrasses  2020  Winter  Total Nitrogen      NaN
# 35     35      Big Bend Seagrasses  2021  Spring  Total Nitrogen      NaN
# 36     36      Big Bend Seagrasses  2021  Summer  Total Nitrogen      NaN
# 37     37      Big Bend Seagrasses  2021    Fall  Total Nitrogen      NaN
# 38     38      Big Bend Seagrasses  2021  Winter  Total Nitrogen      NaN
# 39     39      Big Bend Seagrasses  2022  Spring  Total Nitrogen      NaN
# 40     40  Guana Tolomato Matanzas  2015    Fall        Salinity      NaN
# 41     41  Guana Tolomato Matanzas  2015  Winter        Salinity      NaN
# 42     42  Guana Tolomato Matanzas  2016  Spring        Salinity      NaN
# 43     43  Guana Tolomato Matanzas  2016  Summer        Salinity      NaN
# 44     44  Guana Tolomato Matanzas  2016    Fall        Salinity      NaN
# 45     45  Guana Tolomato Matanzas  2016  Winter        Salinity      NaN
# 46     46  Guana Tolomato Matanzas  2017  Spring        Salinity      NaN
# 47     47  Guana Tolomato Matanzas  2017  Summer        Salinity      NaN
# 48     48               Estero Bay  2016  Summer        Salinity      NaN
# 49     49               Estero Bay  2016    Fall        Salinity      NaN
# 50     50               Estero Bay  2016  Winter        Salinity      NaN
# 51     51               Estero Bay  2017  Spring        Salinity      NaN
# 52     52               Estero Bay  2017  Summer        Salinity      NaN
# 53     53               Estero Bay  2017    Fall        Salinity      NaN
# 54     54               Estero Bay  2017  Winter        Salinity      NaN
# 55     55               Estero Bay  2018  Spring        Salinity      NaN
#
#     NumDataPoints  RMSE  ME
# 0               0   NaN NaN
# 1               0   NaN NaN
# 2               0   NaN NaN
# 3               0   NaN NaN
# 4               0   NaN NaN
# 5               0   NaN NaN
# 6               0   NaN NaN
# 7              13   NaN NaN
# 8               0   NaN NaN
# 9               0   NaN NaN
# 10              0   NaN NaN
# 11              0   NaN NaN
# 12              0   NaN NaN
# 13              1   NaN NaN
# 14              0   NaN NaN
# 15             27   NaN NaN
# 24             76   NaN NaN
# 25             78   NaN NaN
# 26             80   NaN NaN
# 27             34   NaN NaN
# 28             57   NaN NaN
# 29             58   NaN NaN
# 30             53   NaN NaN
# 31             23   NaN NaN
# 32             21   NaN NaN
# 33             23   NaN NaN
# 34             32   NaN NaN
# 35             35   NaN NaN
# 36             28   NaN NaN
# 37             33   NaN NaN
# 38             31   NaN NaN
# 39             25   NaN NaN
# 40              8   NaN NaN
# 41              7   NaN NaN
# 42              4   NaN NaN
# 43              4   NaN NaN
# 44              5   NaN NaN
# 45              4   NaN NaN
# 46              4   NaN NaN
# 47             16   NaN NaN
# 48              3   NaN NaN
# 49              3   NaN NaN
# 50              3   NaN NaN
# 51              3   NaN NaN
# 52              3   NaN NaN
# 53              3   NaN NaN
# 54              3   NaN NaN
# 55              3   NaN NaN

# %%
importlib.reload(idw_rk)

# If the number of data points is less than 3，skipping calculate IDW
idw_rk.idw_interpolation(seasons_slct, shpAll_folder, idwAll_folder, waterbody_extent, barrier_folder)
# Out:
# Processing file: SHP_GTM_TN_mgl_2015_Fall.shp
