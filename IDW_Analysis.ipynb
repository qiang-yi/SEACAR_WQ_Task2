# %% [markdown]
# # Cross Validation for IDW Interpolation
#
# This document includes Python codes that conduct cross validation (CV) for Inverse Distance Weighting (IDW) Interpolation on water quality parameters, including Dissolved oxygen (DO_mgl), Salinity (Sal_ppt), Turbidity (Turb_ntu), Temperature (T_c), Secchi (Secc_m), Total Nitrogen (TN_mgl) in arcpy environment.
#
# The analysis is conducted in the separate managed areas of Guana Tolomato Matanzas (GTM), Estero Bay (EB), Charlotte Harbor (CH),
# Biscayne Bay (BB), Big Bend Seagrasses (BBS).
#
# Tasks:
#
# • Calculate the RMSE and Mean Error for IDW results using both continuous and discrete data points.
#
# * [1. Data Preprocess](#preprocessing)
# * [2. Create Shapefile](#reg_create_shp)
# * [3. Cross Validation for IDW](#reg_cv_idw)
#     * [3.1 Guana Tolomato Matanzas](#reg_result_idw_gtm)
#     * [3.2 Estero Bay](#reg_result_idw_eb)
#     * [3.3 Charlotte Harbor](#reg_result_idw_ch)
#     * [3.4 Biscayne Bay](#reg_result_idw_bb)
#     * [3.5 Big Bend Seagrasses](#reg_result_idw_bbs)

# %%
import pandas as pd
import arcpy
from arcpy.sa import *
import os
import math

import importlib
import sys
path = r'../git/misc'
sys.path.insert(0, path)
import IDW
importlib.reload(IDW)
# Out:
# <module 'IDW' from 'E:\\Projects\\SEACAR_WQ_2024\\git\\../git/misc\\IDW.py'>

# %% [markdown]
# # 1. Data Preprocessing <a class="anchor" id="preprocessing"></a>

# %%
# Define water quality files
# gis_path = r'E:/Spring_2024/WQ/Spring/IDW/GIS_Data/'
gis_path = r'E:/Projects/SEACAR_WQ_2024/GIS_Data/'


dfDis_orig = pd.read_csv(gis_path + "OEAT_Discrete_WQ-2023-Dec-12.csv", low_memory=False)
dfCon_orig = pd.read_csv(gis_path + "OEAT_Continuous_WQ-2023-Dec-12.csv", low_memory=False)

# Combine discrete and continuous file
dfAll_orig = pd.concat([dfDis_orig, dfCon_orig], ignore_index=True)
dfAll_orig.to_csv(gis_path + "OEAT_All_WQ-2023-Dec-12.csv", index=False)

# %%
area_shortnames = {
    'Guana Tolomato Matanzas': 'GTM',
    'Estero Bay': 'EB',
    'Charlotte Harbor': 'CH',
    'Biscayne Bay': 'BB',
    'Big Bend Seagrasses':'BBS'
}

param_shortnames = {
    'Salinity': 'Sal_ppt',
    'Total Nitrogen': 'TN_mgl',
    'Dissolved Oxygen': 'DO_mgl',
    'Turbidity':'Turb_ntu',
    'Secchi Depth':'Secc_m',
    'Water Temperature':'T_c'
}

# %%
# Define the barriers
barrier_folder = os.path.join(gis_path, 'Barriers')
barrier_folder

barriers = []
for file in os.listdir(barrier_folder):
    if file.endswith(".shp"):
        barriers.append(os.path.join(barrier_folder, file))

for barrier in barriers:
    print(barrier)
# Out:
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\BBS_Barriers.shp
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\BB_Barriers.shp
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\CH_Barriers.shp
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\EB_Barriers.shp
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\GTM_Barriers.shp

# %%
# Define waterbody boudnary for spatial extent and mask
waterbody_extent = os.path.join(gis_path, 'OEAT_Waterbody_Boundaries', 'OEAT_Waterbody_Boundary.shp')

unique_waterbodies = []
with arcpy.da.SearchCursor(waterbody_extent, ['WaterbodyA']) as cursor:
    for row in cursor:
        unique_waterbodies.append(row[0])

print("Unique Waterbodies:", unique_waterbodies)
# Out:
# Unique Waterbodies: ['BBS', 'BB', 'CH', 'EB', 'GTM']

# %%
dfAll_orig
# Out:
#              RowID  ProgramID      ParameterName ParameterUnits  \
# 0          5062527       5014           Salinity            ppt
# 1          5062528       5014           Salinity            ppt
# 2          5062529       5014       Secchi Depth              m
# 3          5062606       5014           Salinity            ppt
# 4          5062607       5014           Salinity            ppt
# ...            ...        ...                ...            ...
# 4828313  137022711       5077  Water Temperature      Degrees C
# 4828314  137022825       5077          Turbidity            NTU
# 4828315  137022872       5077           Salinity            ppt
# 4828316  137022885       5077          Turbidity            NTU
# 4828317  137023236       5077           Salinity            ppt
#
#         ProgramLocationID ActivityType           SampleDate  Year  Month  \
# 0                GTMMKNUT        Field  Aug  3 2017 11:24AM  2017      8
# 1                GTMMKNUT        Field  Sep 20 2017  9:06AM  2017      9
# 2                GTMMKNUT        Field  Nov  2 2017  1:11PM  2017     11
# 3                GTMMKNUT        Field  Oct 18 2017 12:52PM  2017     10
# 4                GTMMKNUT        Field  Apr 24 2018 10:56AM  2018      4
# ...                   ...          ...                  ...   ...    ...
# 4828313           BBCWA4           NaN  Apr  2 2022  1:45PM  2022      4
# 4828314            BBJT71          NaN  Jun 13 2020  8:30AM  2020      6
# 4828315            BBLR03          NaN  Apr 23 2022  9:30AM  2022      4
# 4828316            BBLR03          NaN  May  7 2021  5:45PM  2021      5
# 4828317            BBJT71          NaN  Apr  2 2022  8:45AM  2022      4
#
#         RelativeDepth  ResultValue  Latitude_DD  Longitude_DD  \
# 0             Surface         0.34    30.160736    -81.360278
# 1             Surface         0.32    30.160736    -81.360278
# 2             Surface         1.20    30.160736    -81.360278
# 3             Surface         0.34    30.160736    -81.360278
# 4             Surface         0.33    30.160736    -81.360278
# ...               ...          ...          ...           ...
# 4828313        bottom        26.80    25.758020    -80.167690
# 4828314        bottom         3.00    25.821730    -80.151250
# 4828315        bottom        29.40    25.846841    -80.182861
# 4828316        bottom         2.00    25.846841    -80.182861
# 4828317        bottom        34.20    25.821730    -80.151250
#
#                                            ManagedAreaName  AreaID  \
# 0        Guana Tolomato Matanzas National Estuarine Res...      20
# 1        Guana Tolomato Matanzas National Estuarine Res...      20
# 2        Guana Tolomato Matanzas National Estuarine Res...      20
# 3        Guana Tolomato Matanzas National Estuarine Res...      20
# 4        Guana Tolomato Matanzas National Estuarine Res...      20
# ...                                                    ...     ...
# 4828313                      Biscayne Bay Aquatic Preserve       6
# 4828314                      Biscayne Bay Aquatic Preserve       6
# 4828315                      Biscayne Bay Aquatic Preserve       6
# 4828316                      Biscayne Bay Aquatic Preserve       6
# 4828317                      Biscayne Bay Aquatic Preserve       6
#
#         SEACAR_QAQCFlagCode                WaterBody WbodyAcronym  Season
# 0                        6Q  Guana Tolomato Matanzas      GTMNERR  Summer
# 1                        6Q  Guana Tolomato Matanzas      GTMNERR    Fall
# 2                        6Q  Guana Tolomato Matanzas      GTMNERR    Fall
# 3                        6Q  Guana Tolomato Matanzas      GTMNERR    Fall
# 4                        6Q  Guana Tolomato Matanzas      GTMNERR  Spring
# ...                     ...                      ...          ...     ...
# 4828313                  6Q             Biscayne Bay         BBAP  Spring
# 4828314                  6Q             Biscayne Bay         BBAP  Spring
# 4828315                  6Q             Biscayne Bay         BBAP  Spring
# 4828316                  6Q             Biscayne Bay         BBAP  Spring
# 4828317                  6Q             Biscayne Bay         BBAP  Spring
#
# [4828318 rows x 19 columns]

# %%
# Define output folders
shp_folder = gis_path + r"shapefiles"

idw_folder = gis_path + r"idw"

# %%
unique_years = dfAll_orig['Year'].unique()
unique_years.sort()
print("Unique years in 'Year' column:", unique_years)
# Out:
# Unique years in 'Year' column: [2015 2016 2017 2018 2019 2020 2021 2022 2023]

# %%
unique_years = dfAll_orig['ParameterName'].unique()
unique_years.sort()
print("Unique Parameter in 'ParameterName' column:", unique_years)
# Out:
# Unique Parameter in 'ParameterName' column: ['Dissolved Oxygen' 'Salinity' 'Secchi Depth' 'Total Nitrogen' 'Turbidity'
#  'Water Temperature']

# %%
unique_years = dfAll_orig['Season'].unique()
unique_years.sort()
print("Unique Season in 'Season' column:", unique_years)
# Out:
# Unique Season in 'Season' column: ['Fall' 'Spring' 'Summer' 'Winter']

# %% [markdown]
# # 2. Create Shapefile <a class="anchor" id="reg_create_shp"></a>

# %%
# Set input parameters
waterbody_names = [
    'Guana Tolomato Matanzas',
    'Estero Bay',
    'Charlotte Harbor',
    'Biscayne Bay',
    'Big Bend Seagrasses'
]

#parameter_names = ['Dissolved Oxygen']
parameter_names = ['Dissolved Oxygen', 'Salinity', 'Secchi Depth', 'Total Nitrogen', 'Turbidity', 'Water Temperature']

# for instance
years = [2023] 
#seasons = ['Spring']
seasons = ['Fall', 'Spring', 'Summer', 'Winter']

# %%
# Empty the shapefile folder
IDW.delete_all_files(shp_folder)

# %%
# Create shapefiles by waterbody,parameter，year, and season
# Print number of data points in each shapefile
IDW.create_shp_season(dfAll_orig, waterbody_names, parameter_names, years, seasons, shp_folder)
# Out:
# No data found for area: GTM, parameter: Dissolved Oxygen, year: 2023, and season: Fall
# No data found for area: GTM, parameter: Salinity, year: 2023, and season: Fall
# No data found for area: GTM, parameter: Secchi Depth, year: 2023, and season: Fall
# No data found for area: GTM, parameter: Total Nitrogen, year: 2023, and season: Fall
# No data found for area: GTM, parameter: Turbidity, year: 2023, and season: Fall
# No data found for area: GTM, parameter: Water Temperature, year: 2023, and season: Fall
# Number of data rows for GTM, Dissolved Oxygen, 2023, Spring: 18
# Shapefile for GTM: DO_mgl for year 2023 and season Spring has been saved as SHP_GTM_DO_mgl_2023_Spring.shp
# Number of data rows for GTM, Salinity, 2023, Spring: 18
# Shapefile for GTM: Sal_ppt for year 2023 and season Spring has been saved as SHP_GTM_Sal_ppt_2023_Spring.shp
# Number of data rows for GTM, Secchi Depth, 2023, Spring: 11
# Shapefile for GTM: Secc_m for year 2023 and season Spring has been saved as SHP_GTM_Secc_m_2023_Spring.shp
# Number of data rows for GTM, Total Nitrogen, 2023, Spring: 7
# Shapefile for GTM: TN_mgl for year 2023 and season Spring has been saved as SHP_GTM_TN_mgl_2023_Spring.shp
# Number of data rows for GTM, Turbidity, 2023, Spring: 7
# Shapefile for GTM: Turb_ntu for year 2023 and season Spring has been saved as SHP_GTM_Turb_ntu_2023_Spring.shp
# Number of data rows for GTM, Water Temperature, 2023, Spring: 18
# Shapefile for GTM: T_c for year 2023 and season Spring has been saved as SHP_GTM_T_c_2023_Spring.shp
# Number of data rows for GTM, Dissolved Oxygen, 2023, Summer: 17
# Shapefile for GTM: DO_mgl for year 2023 and season Summer has been saved as SHP_GTM_DO_mgl_2023_Summer.shp
# Number of data rows for GTM, Salinity, 2023, Summer: 17
# Shapefile for GTM: Sal_ppt for year 2023 and season Summer has been saved as SHP_GTM_Sal_ppt_2023_Summer.shp
# Number of data rows for GTM, Secchi Depth, 2023, Summer: 12
# Shapefile for GTM: Secc_m for year 2023 and season Summer has been saved as SHP_GTM_Secc_m_2023_Summer.shp
# Number of data rows for GTM, Total Nitrogen, 2023, Summer: 8
# Shapefile for GTM: TN_mgl for year 2023 and season Summer has been saved as SHP_GTM_TN_mgl_2023_Summer.shp
# Number of data rows for GTM, Turbidity, 2023, Summer: 8
# Shapefile for GTM: Turb_ntu for year 2023 and season Summer has been saved as SHP_GTM_Turb_ntu_2023_Summer.shp
# Number of data rows for GTM, Water Temperature, 2023, Summer: 17
# Shapefile for GTM: T_c for year 2023 and season Summer has been saved as SHP_GTM_T_c_2023_Summer.shp
# No data found for area: GTM, parameter: Dissolved Oxygen, year: 2023, and season: Winter
# No data found for area: GTM, parameter: Salinity, year: 2023, and season: Winter
# No data found for area: GTM, parameter: Secchi Depth, year: 2023, and season: Winter
# No data found for area: GTM, parameter: Total Nitrogen, year: 2023, and season: Winter
# No data found for area: GTM, parameter: Turbidity, year: 2023, and season: Winter
# No data found for area: GTM, parameter: Water Temperature, year: 2023, and season: Winter
# No data found for area: EB, parameter: Dissolved Oxygen, year: 2023, and season: Fall
# No data found for area: EB, parameter: Salinity, year: 2023, and season: Fall
# No data found for area: EB, parameter: Secchi Depth, year: 2023, and season: Fall
# No data found for area: EB, parameter: Total Nitrogen, year: 2023, and season: Fall
# No data found for area: EB, parameter: Turbidity, year: 2023, and season: Fall
# No data found for area: EB, parameter: Water Temperature, year: 2023, and season: Fall
# Number of data rows for EB, Dissolved Oxygen, 2023, Spring: 61
# Shapefile for EB: DO_mgl for year 2023 and season Spring has been saved as SHP_EB_DO_mgl_2023_Spring.shp
# Number of data rows for EB, Salinity, 2023, Spring: 1
# Shapefile for EB: Sal_ppt for year 2023 and season Spring has been saved as SHP_EB_Sal_ppt_2023_Spring.shp
# Number of data rows for EB, Secchi Depth, 2023, Spring: 1
# Shapefile for EB: Secc_m for year 2023 and season Spring has been saved as SHP_EB_Secc_m_2023_Spring.shp
# Number of data rows for EB, Total Nitrogen, 2023, Spring: 63
# Shapefile for EB: TN_mgl for year 2023 and season Spring has been saved as SHP_EB_TN_mgl_2023_Spring.shp
# Number of data rows for EB, Turbidity, 2023, Spring: 59
# Shapefile for EB: Turb_ntu for year 2023 and season Spring has been saved as SHP_EB_Turb_ntu_2023_Spring.shp
# Number of data rows for EB, Water Temperature, 2023, Spring: 61
# Shapefile for EB: T_c for year 2023 and season Spring has been saved as SHP_EB_T_c_2023_Spring.shp
# Number of data rows for EB, Dissolved Oxygen, 2023, Summer: 41
# Shapefile for EB: DO_mgl for year 2023 and season Summer has been saved as SHP_EB_DO_mgl_2023_Summer.shp
# Number of data rows for EB, Salinity, 2023, Summer: 2
# Shapefile for EB: Sal_ppt for year 2023 and season Summer has been saved as SHP_EB_Sal_ppt_2023_Summer.shp
# Number of data rows for EB, Secchi Depth, 2023, Summer: 2
# Shapefile for EB: Secc_m for year 2023 and season Summer has been saved as SHP_EB_Secc_m_2023_Summer.shp
# Number of data rows for EB, Total Nitrogen, 2023, Summer: 36
# Shapefile for EB: TN_mgl for year 2023 and season Summer has been saved as SHP_EB_TN_mgl_2023_Summer.shp
# Number of data rows for EB, Turbidity, 2023, Summer: 34
# Shapefile for EB: Turb_ntu for year 2023 and season Summer has been saved as SHP_EB_Turb_ntu_2023_Summer.shp
# Number of data rows for EB, Water Temperature, 2023, Summer: 41
# Shapefile for EB: T_c for year 2023 and season Summer has been saved as SHP_EB_T_c_2023_Summer.shp
# Number of data rows for EB, Dissolved Oxygen, 2023, Winter: 27
# Shapefile for EB: DO_mgl for year 2023 and season Winter has been saved as SHP_EB_DO_mgl_2023_Winter.shp
# Number of data rows for EB, Salinity, 2023, Winter: 1
# Shapefile for EB: Sal_ppt for year 2023 and season Winter has been saved as SHP_EB_Sal_ppt_2023_Winter.shp
# Number of data rows for EB, Secchi Depth, 2023, Winter: 1
# Shapefile for EB: Secc_m for year 2023 and season Winter has been saved as SHP_EB_Secc_m_2023_Winter.shp
# Number of data rows for EB, Total Nitrogen, 2023, Winter: 24
# Shapefile for EB: TN_mgl for year 2023 and season Winter has been saved as SHP_EB_TN_mgl_2023_Winter.shp
# Number of data rows for EB, Turbidity, 2023, Winter: 24
# Shapefile for EB: Turb_ntu for year 2023 and season Winter has been saved as SHP_EB_Turb_ntu_2023_Winter.shp
# Number of data rows for EB, Water Temperature, 2023, Winter: 27
# Shapefile for EB: T_c for year 2023 and season Winter has been saved as SHP_EB_T_c_2023_Winter.shp
# No data found for area: CH, parameter: Dissolved Oxygen, year: 2023, and season: Fall
# No data found for area: CH, parameter: Salinity, year: 2023, and season: Fall
# No data found for area: CH, parameter: Secchi Depth, year: 2023, and season: Fall
# No data found for area: CH, parameter: Total Nitrogen, year: 2023, and season: Fall
# No data found for area: CH, parameter: Turbidity, year: 2023, and season: Fall
# No data found for area: CH, parameter: Water Temperature, year: 2023, and season: Fall
# Number of data rows for CH, Dissolved Oxygen, 2023, Spring: 168
# Shapefile for CH: DO_mgl for year 2023 and season Spring has been saved as SHP_CH_DO_mgl_2023_Spring.shp
# Number of data rows for CH, Salinity, 2023, Spring: 57
# Shapefile for CH: Sal_ppt for year 2023 and season Spring has been saved as SHP_CH_Sal_ppt_2023_Spring.shp
# Number of data rows for CH, Secchi Depth, 2023, Spring: 42
# Shapefile for CH: Secc_m for year 2023 and season Spring has been saved as SHP_CH_Secc_m_2023_Spring.shp
# Number of data rows for CH, Total Nitrogen, 2023, Spring: 119
# Shapefile for CH: TN_mgl for year 2023 and season Spring has been saved as SHP_CH_TN_mgl_2023_Spring.shp
# Number of data rows for CH, Turbidity, 2023, Spring: 126
# Shapefile for CH: Turb_ntu for year 2023 and season Spring has been saved as SHP_CH_Turb_ntu_2023_Spring.shp
# Number of data rows for CH, Water Temperature, 2023, Spring: 169
# Shapefile for CH: T_c for year 2023 and season Spring has been saved as SHP_CH_T_c_2023_Spring.shp
# Number of data rows for CH, Dissolved Oxygen, 2023, Summer: 50
# Shapefile for CH: DO_mgl for year 2023 and season Summer has been saved as SHP_CH_DO_mgl_2023_Summer.shp
# Number of data rows for CH, Salinity, 2023, Summer: 19
# Shapefile for CH: Sal_ppt for year 2023 and season Summer has been saved as SHP_CH_Sal_ppt_2023_Summer.shp
# Number of data rows for CH, Secchi Depth, 2023, Summer: 13
# Shapefile for CH: Secc_m for year 2023 and season Summer has been saved as SHP_CH_Secc_m_2023_Summer.shp
# Number of data rows for CH, Total Nitrogen, 2023, Summer: 33
# Shapefile for CH: TN_mgl for year 2023 and season Summer has been saved as SHP_CH_TN_mgl_2023_Summer.shp
# Number of data rows for CH, Turbidity, 2023, Summer: 36
# Shapefile for CH: Turb_ntu for year 2023 and season Summer has been saved as SHP_CH_Turb_ntu_2023_Summer.shp
# Number of data rows for CH, Water Temperature, 2023, Summer: 50
# Shapefile for CH: T_c for year 2023 and season Summer has been saved as SHP_CH_T_c_2023_Summer.shp
# Number of data rows for CH, Dissolved Oxygen, 2023, Winter: 70
# Shapefile for CH: DO_mgl for year 2023 and season Winter has been saved as SHP_CH_DO_mgl_2023_Winter.shp
# Number of data rows for CH, Salinity, 2023, Winter: 51
# Shapefile for CH: Sal_ppt for year 2023 and season Winter has been saved as SHP_CH_Sal_ppt_2023_Winter.shp
# Number of data rows for CH, Secchi Depth, 2023, Winter: 25
# Shapefile for CH: Secc_m for year 2023 and season Winter has been saved as SHP_CH_Secc_m_2023_Winter.shp
# Number of data rows for CH, Total Nitrogen, 2023, Winter: 57
# Shapefile for CH: TN_mgl for year 2023 and season Winter has been saved as SHP_CH_TN_mgl_2023_Winter.shp
# Number of data rows for CH, Turbidity, 2023, Winter: 60
# Shapefile for CH: Turb_ntu for year 2023 and season Winter has been saved as SHP_CH_Turb_ntu_2023_Winter.shp
# Number of data rows for CH, Water Temperature, 2023, Winter: 85
# Shapefile for CH: T_c for year 2023 and season Winter has been saved as SHP_CH_T_c_2023_Winter.shp
# No data found for area: BB, parameter: Dissolved Oxygen, year: 2023, and season: Fall
# No data found for area: BB, parameter: Salinity, year: 2023, and season: Fall
# No data found for area: BB, parameter: Secchi Depth, year: 2023, and season: Fall
# No data found for area: BB, parameter: Total Nitrogen, year: 2023, and season: Fall
# No data found for area: BB, parameter: Turbidity, year: 2023, and season: Fall
# No data found for area: BB, parameter: Water Temperature, year: 2023, and season: Fall
# Number of data rows for BB, Dissolved Oxygen, 2023, Spring: 255
# Shapefile for BB: DO_mgl for year 2023 and season Spring has been saved as SHP_BB_DO_mgl_2023_Spring.shp
# Number of data rows for BB, Salinity, 2023, Spring: 232
# Shapefile for BB: Sal_ppt for year 2023 and season Spring has been saved as SHP_BB_Sal_ppt_2023_Spring.shp
# No data found for area: BB, parameter: Secchi Depth, year: 2023, and season: Spring
# Number of data rows for BB, Total Nitrogen, 2023, Spring: 40
# Shapefile for BB: TN_mgl for year 2023 and season Spring has been saved as SHP_BB_TN_mgl_2023_Spring.shp
# Number of data rows for BB, Turbidity, 2023, Spring: 78
# Shapefile for BB: Turb_ntu for year 2023 and season Spring has been saved as SHP_BB_Turb_ntu_2023_Spring.shp
# Number of data rows for BB, Water Temperature, 2023, Spring: 248
# Shapefile for BB: T_c for year 2023 and season Spring has been saved as SHP_BB_T_c_2023_Spring.shp
# No data found for area: BB, parameter: Dissolved Oxygen, year: 2023, and season: Summer
# No data found for area: BB, parameter: Salinity, year: 2023, and season: Summer
# No data found for area: BB, parameter: Secchi Depth, year: 2023, and season: Summer
# No data found for area: BB, parameter: Total Nitrogen, year: 2023, and season: Summer
# No data found for area: BB, parameter: Turbidity, year: 2023, and season: Summer
# No data found for area: BB, parameter: Water Temperature, year: 2023, and season: Summer
# Number of data rows for BB, Dissolved Oxygen, 2023, Winter: 333
# Shapefile for BB: DO_mgl for year 2023 and season Winter has been saved as SHP_BB_DO_mgl_2023_Winter.shp
# Number of data rows for BB, Salinity, 2023, Winter: 283
# Shapefile for BB: Sal_ppt for year 2023 and season Winter has been saved as SHP_BB_Sal_ppt_2023_Winter.shp
# No data found for area: BB, parameter: Secchi Depth, year: 2023, and season: Winter
# Number of data rows for BB, Total Nitrogen, 2023, Winter: 91
# Shapefile for BB: TN_mgl for year 2023 and season Winter has been saved as SHP_BB_TN_mgl_2023_Winter.shp
# Number of data rows for BB, Turbidity, 2023, Winter: 135
# Shapefile for BB: Turb_ntu for year 2023 and season Winter has been saved as SHP_BB_Turb_ntu_2023_Winter.shp
# Number of data rows for BB, Water Temperature, 2023, Winter: 335
# Shapefile for BB: T_c for year 2023 and season Winter has been saved as SHP_BB_T_c_2023_Winter.shp
# No data found for area: BBS, parameter: Dissolved Oxygen, year: 2023, and season: Fall
# No data found for area: BBS, parameter: Salinity, year: 2023, and season: Fall
# No data found for area: BBS, parameter: Secchi Depth, year: 2023, and season: Fall
# No data found for area: BBS, parameter: Total Nitrogen, year: 2023, and season: Fall
# No data found for area: BBS, parameter: Turbidity, year: 2023, and season: Fall
# No data found for area: BBS, parameter: Water Temperature, year: 2023, and season: Fall
# No data found for area: BBS, parameter: Dissolved Oxygen, year: 2023, and season: Spring
# No data found for area: BBS, parameter: Salinity, year: 2023, and season: Spring
# No data found for area: BBS, parameter: Secchi Depth, year: 2023, and season: Spring
# No data found for area: BBS, parameter: Total Nitrogen, year: 2023, and season: Spring
# No data found for area: BBS, parameter: Turbidity, year: 2023, and season: Spring
# No data found for area: BBS, parameter: Water Temperature, year: 2023, and season: Spring
# No data found for area: BBS, parameter: Dissolved Oxygen, year: 2023, and season: Summer
# No data found for area: BBS, parameter: Salinity, year: 2023, and season: Summer
# No data found for area: BBS, parameter: Secchi Depth, year: 2023, and season: Summer
# No data found for area: BBS, parameter: Total Nitrogen, year: 2023, and season: Summer
# No data found for area: BBS, parameter: Turbidity, year: 2023, and season: Summer
# No data found for area: BBS, parameter: Water Temperature, year: 2023, and season: Summer
# No data found for area: BBS, parameter: Dissolved Oxygen, year: 2023, and season: Winter
# No data found for area: BBS, parameter: Salinity, year: 2023, and season: Winter
# No data found for area: BBS, parameter: Secchi Depth, year: 2023, and season: Winter
# No data found for area: BBS, parameter: Total Nitrogen, year: 2023, and season: Winter
# No data found for area: BBS, parameter: Turbidity, year: 2023, and season: Winter
# No data found for area: BBS, parameter: Water Temperature, year: 2023, and season: Winter

# %% [markdown]
# # 3. Cross Validation for IDW <a class="anchor" id="reg_cv_idw"></a>

# %% [markdown]
# ## 3.1 Guana Tolomato Matanzas <a class="anchor" id="reg_result_idw_gtm"></a>

# %%
# Empty the shapefile folder
IDW.delete_all_files(idw_folder)

# %%
waterbody_gtm = ['Guana Tolomato Matanzas']
# If the number of data points is less than 3，skipping calculate IDW
IDW.idw_interpolation(shp_folder, idw_folder, parameter_names, waterbody_gtm, waterbody_extent, years, seasons,barrier_folder)
# Out:
# Processing file: SHP_GTM_DO_mgl_2023_Spring.shp
# Calculated RMSE: 1.90977869490684, ME: 0.4097752117647057 for file: SHP_GTM_DO_mgl_2023_Spring.shp
# File SHP_GTM_DO_mgl_2023_Spring.shp has completed 18 cross-validation iterations.
# Processing file: SHP_GTM_DO_mgl_2023_Summer.shp
# Calculated RMSE: 0.4842527157809326, ME: -0.04840464117647052 for file: SHP_GTM_DO_mgl_2023_Summer.shp
# File SHP_GTM_DO_mgl_2023_Summer.shp has completed 17 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2023_Spring.shp
# Calculated RMSE: 0.5594887899146133, ME: -0.04790094117647068 for file: SHP_GTM_Sal_ppt_2023_Spring.shp
# File SHP_GTM_Sal_ppt_2023_Spring.shp has completed 18 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2023_Summer.shp
# Calculated RMSE: 4.591693872902942, ME: 0.24784371752941137 for file: SHP_GTM_Sal_ppt_2023_Summer.shp
# File SHP_GTM_Sal_ppt_2023_Summer.shp has completed 17 cross-validation iterations.
# Processing file: SHP_GTM_Secc_m_2023_Spring.shp
# Calculated RMSE: 0.24050937361360536, ME: -4.017699999999125e-05 for file: SHP_GTM_Secc_m_2023_Spring.shp
# File SHP_GTM_Secc_m_2023_Spring.shp has completed 11 cross-validation iterations.
# Processing file: SHP_GTM_Secc_m_2023_Summer.shp
# Calculated RMSE: 0.13522392762368415, ME: -0.0003198091666666754 for file: SHP_GTM_Secc_m_2023_Summer.shp
# File SHP_GTM_Secc_m_2023_Summer.shp has completed 12 cross-validation iterations.
# Processing file: SHP_GTM_TN_mgl_2023_Spring.shp
# Calculated RMSE: 0.1980776182443271, ME: -6.434999999980577e-06 for file: SHP_GTM_TN_mgl_2023_Spring.shp
# File SHP_GTM_TN_mgl_2023_Spring.shp has completed 7 cross-validation iterations.
# Processing file: SHP_GTM_TN_mgl_2023_Summer.shp
# Calculated RMSE: 0.4045849292283613, ME: -1.7237499999947503e-06 for file: SHP_GTM_TN_mgl_2023_Summer.shp
# File SHP_GTM_TN_mgl_2023_Summer.shp has completed 8 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2023_Spring.shp
# Calculated RMSE: 6.421305802772394, ME: -0.0009194166666670611 for file: SHP_GTM_Turb_ntu_2023_Spring.shp
# File SHP_GTM_Turb_ntu_2023_Spring.shp has completed 7 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2023_Summer.shp
# Calculated RMSE: 3.3617692827440004, ME: -0.00029815000000010805 for file: SHP_GTM_Turb_ntu_2023_Summer.shp
# File SHP_GTM_Turb_ntu_2023_Summer.shp has completed 8 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2023_Spring.shp
# Calculated RMSE: 6.008241182313663, ME: -1.272253411764705 for file: SHP_GTM_T_c_2023_Spring.shp
# File SHP_GTM_T_c_2023_Spring.shp has completed 18 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2023_Summer.shp
# Calculated RMSE: 1.242397637265092, ME: -0.04004705882352928 for file: SHP_GTM_T_c_2023_Summer.shp
# File SHP_GTM_T_c_2023_Summer.shp has completed 17 cross-validation iterations.

# %% [markdown]
# ## 3.2 Estero Bay  <a class="anchor" id="reg_result_idw_eb"></a>

# %%
waterbody_eb = ['Estero Bay']
IDW.idw_interpolation(shp_folder, idw_folder, parameter_names, waterbody_eb, waterbody_extent, years, seasons,barrier_folder)
# Out:
# Processing file: SHP_EB_DO_mgl_2023_Spring.shp

# %% [markdown]
# ## 3.3 Charlotte Harbor <a class="anchor" id="reg_result_idw_ch"></a>

# %%
waterbody_ch = ['Charlotte Harbor']
IDW.idw_interpolation(shp_folder, idw_folder, parameter_names, waterbody_ch, waterbody_extent, years, seasons,barrier_folder)

# %% [markdown]
# ## 3.4 Biscayne Bay <a class="anchor" id="reg_result_idw_bbay"></a>

# %%
waterbody_bb = ['Biscayne Bay']
IDW.idw_interpolation(shp_folder, idw_folder, parameter_names, waterbody_bb, waterbody_extent, years, seasons,barrier_folder)

# %% [markdown]
# ##  3.5 Big Bend <a class="anchor" id="reg_result_idw_bb"></a>

# %%
waterbody_bbs = ['Big Bend Seagrasses']
IDW.idw_interpolation(shp_folder, idw_folder, parameter_names, waterbody_bbs, waterbody_extent, years, seasons,barrier_folder)
