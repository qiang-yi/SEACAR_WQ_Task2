# %% [markdown]
# # IDW Interpolation for weekly intervals
# ## Task 2B
#
# This document includes Python codes that conduct cross validation (CV) for Inverse Distance Weighting (IDW) Interpolation on water quality parameters, including 4 water quality parameters in arcpy environment:
# - Dissolved oxygen (DO_mgl)
# - Salinity (Sal_ppt)
# - Turbidity (Turb_ntu)
# - Temperature (T_c)
#
# The analysis is conducted in the separate water bodies:
# - Guana Tolomato Matanzas (GTM)
# - Estero Bay (EB)
# - Charlotte Harbor (CH)
# - Biscayne Bay (BB)
# - Big Bend Seagrasses (BBS)
#
# **Tasks:**
#
# - Task 2A Calculate the RMSE and Mean Error (ME) for IDW results using both continuous and discrete data
#
# - **Task 2B Calculate the RMSE and Mean Error (ME) for IDW results using continuous data.**
#
#
# **Monthly: The SEACAR team would like the USF team to define their months as six 30-day
# increments prior to the storm day, and then six 30-day increments following the storm day.**
#
# **Weekly: The SEACAR team would like the USF team to define their weeks as 26 7-day
# increments prior to the storm day, and then 26 7-day increments following the storm day**
#
# **Contents:**
# * [1. Data Preprocess](#reg_preprocessing)
#     * [1.1 Subsetting Dataset](#reg_subset)
#     * [1.2 Preview Dataset](#reg_preview)
#     * [1.3 Fill Unique ID](#reg_id)
# * [2. Create Shapefile](#reg_create_shp)
# * [3. Cross Validation for IDW](#reg_cv_idw)
# * [4. Monthly Results](#month)

# %%
import pandas as pd
import numpy as np
import arcpy
from arcpy.sa import *
import os
import math
import warnings

import importlib
import sys
#path = r'F:\SEACAR_WQ_2024\git\misc'
path = r'E:\Projects\SEACAR_WQ_2024\git\misc'

sys.path.insert(0, path)
# import idw_rk
import idw_rk_x
# importlib.reload(idw_rk)
importlib.reload(idw_rk_x)

import pyproj

# define scratch folder to avoid overwritting from parallel threats

arcpy.env.scratchWorkspace = r"E:\Projects\SEACAR_WQ_2024\scratch/IDW_week"

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Data Preprocessing <a class="anchor" id="reg_preprocessing"></a>
# ### 1.1 Load csv files

# %%
#gis_path = r'F:\SEACAR_WQ_2024/GIS_Data/'
gis_path = r'E:\Projects\SEACAR_WQ_2024/GIS_Data/'
dfCon = pd.read_csv(gis_path + 'OEAT_Continuous_WQ-2024-Feb-21.csv', low_memory=False)

# %% [markdown]
# ### Define output folder. Here is the folder setting for week.

# %%
# shpCon_folder = gis_path + r"shapefiles_Con/week"
# idwCon_folder = gis_path + r"idw_Con/week"

shpCon_folder = gis_path + r"shapefiles/idw_week"
idwCon_folder = gis_path + r"raster_output/idw_week"

# %% [markdown]
# ### 1.2 Subsetting Data <a class="anchor" id="reg_subset"></a>
#
# #### Include the time period from 8 am to 18 pm in a day

# %%
dfCon['SampleDate'] = pd.to_datetime(dfCon['SampleDate'], format='%Y-%m-%d %H:%M:%S.%f')

# Include date from 9:00 am to 17:00 pm
start_time = '08:00'
end_time = '18:00'

dfConTime = dfCon[dfCon['SampleDate'].dt.time.between(pd.to_datetime(start_time).time(), pd.to_datetime(end_time).time())]
dfConTime["SampleDate"] = pd.to_datetime(dfConTime['SampleDate'])
dfConTime.head()
# Out:
#    RowID  ProgramID      ParameterName ParameterUnits ProgramLocationID  \
# 0      1        512  Water Temperature      Degrees C             CHWW1
# 1      2        512  Water Temperature      Degrees C             CHWW1
# 2      3        512  Water Temperature      Degrees C             CHWW1
# 3      4        512  Water Temperature      Degrees C             CHWW1
# 4      5        512  Water Temperature      Degrees C             CHWW1
#
#    ActivityType          SampleDate  Year  Month RelativeDepth  ResultValue  \
# 0           NaN 2021-11-25 11:45:00  2021     11        bottom         19.2
# 1           NaN 2021-11-13 16:15:00  2021     11        bottom         22.3
# 2           NaN 2021-10-26 14:15:00  2021     10        bottom         28.3
# 3           NaN 2022-09-16 12:45:00  2022      9        bottom         29.7
# 4           NaN 2022-09-20 10:30:00  2022      9        bottom         29.3
#
#    Latitude_DD  Longitude_DD             ManagedAreaName  AreaID  \
# 0      26.8325     -82.14805  Cape Haze Aquatic Preserve       9
# 1      26.8325     -82.14805  Cape Haze Aquatic Preserve       9
# 2      26.8325     -82.14805  Cape Haze Aquatic Preserve       9
# 3      26.8325     -82.14805  Cape Haze Aquatic Preserve       9
# 4      26.8325     -82.14805  Cape Haze Aquatic Preserve       9
#
#   SEACAR_QAQCFlagCode         WaterBody WbodyAcronym Season
# 0                  6Q  Charlotte Harbor           CH   Fall
# 1                  6Q  Charlotte Harbor           CH   Fall
# 2                  6Q  Charlotte Harbor           CH   Fall
# 3                  6Q  Charlotte Harbor           CH   Fall
# 4                  6Q  Charlotte Harbor           CH   Fall

# %% [markdown]
# ### 1.3 Select the data based on the 52 weeks excel file.

# %%
area_ab = ["GTM","EB","CH","BB","BBS"]
period_type = [" 52 week"," Month"]
dfConTime["Period"] = ""
def select_data_period(df,area,period):
    sheet_name = str(area) + str(period)
    df_period_table = pd.read_excel(gis_path + "All_Waterbodies_Season_Month_Week_Definitions.xlsx",sheet_name=sheet_name)
    df_select_area = df[df["WbodyAcronym"]==str(area)]
    df_period_table['Start Date'] = pd.to_datetime(df_period_table['Start Date'])
    df_period_table['End Date']   = pd.to_datetime(df_period_table['End Date'])
    sub_dfs = []

    for index, row in df_period_table.iterrows():
        start_date = row['Start Date']
        end_date   = row['End Date']
        sub_df = df_select_area[(df_select_area['SampleDate'] >= start_date) & (df_select_area['SampleDate'] < end_date)]
        sub_df['Period'] = row["Week"]
        sub_dfs.append(sub_df)
        
    df_period = pd.concat(sub_dfs,ignore_index=True)
    return df_period

# %% [markdown]
# ### 1.4 Generate the aggregated mean value for weekly data.

# %%
sel_week_temp = []
for each in area_ab:
    df_week_temp = select_data_period(dfConTime,str(each)," 52 week")
    df_week_temp_group = df_week_temp.groupby(['WaterBody','ParameterName','ParameterUnits',
                                          'Year','Season','Latitude_DD','Longitude_DD','WbodyAcronym',"Period"])["ResultValue"].agg("mean").reset_index()
    sel_week_temp.append(df_week_temp_group)
df_week_select_Mean = pd.concat(sel_week_temp,ignore_index=True)

# %%
df_week_select_Mean.head(50)
# Out:
#                   WaterBody     ParameterName ParameterUnits  Year Season  \
# 0   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 1   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 2   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 3   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 4   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 5   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 6   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 7   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 8   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 9   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 10  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 11  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 12  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 13  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 14  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 15  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 16  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 17  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 18  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 19  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 20  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 21  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 22  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 23  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 24  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 25  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 26  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 27  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 28  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 29  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 30  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 31  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 32  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 33  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 34  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 35  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 36  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 37  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 38  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 39  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 40  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 41  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 42  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 43  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 44  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 45  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 46  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 47  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 48  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 49  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
#
#     Latitude_DD  Longitude_DD WbodyAcronym  Period  ResultValue
# 0     29.667071    -81.257403          GTM      23     5.536585
# 1     29.667071    -81.257403          GTM      24     5.028920
# 2     29.667071    -81.257403          GTM      25     4.721951
# 3     29.667071    -81.257403          GTM      26     5.433798
# 4     29.667071    -81.257403          GTM      27     3.042509
# 5     29.667071    -81.257403          GTM      28     3.554704
# 6     29.667071    -81.257403          GTM      29     4.092683
# 7     29.667071    -81.257403          GTM      30     4.660667
# 8     29.667071    -81.257403          GTM      32     5.649735
# 9     29.667071    -81.257403          GTM      33     6.990244
# 10    29.667071    -81.257403          GTM      34     6.492334
# 11    29.667071    -81.257403          GTM      35     7.352033
# 12    29.737041    -81.245953          GTM      23     5.771951
# 13    29.737041    -81.245953          GTM      24     5.579443
# 14    29.737041    -81.245953          GTM      25     5.524390
# 15    29.737041    -81.245953          GTM      26     5.729965
# 16    29.737041    -81.245953          GTM      27     6.048432
# 17    29.737041    -81.245953          GTM      28     6.281185
# 18    29.737041    -81.245953          GTM      29     6.565505
# 19    29.737041    -81.245953          GTM      30     6.458885
# 20    29.737041    -81.245953          GTM      31     6.726481
# 21    29.737041    -81.245953          GTM      32     6.778049
# 22    29.737041    -81.245953          GTM      33     7.229965
# 23    29.737041    -81.245953          GTM      34     7.003136
# 24    29.737041    -81.245953          GTM      35     7.287805
# 25    29.868851    -81.307428          GTM      23     5.510976
# 26    29.868851    -81.307428          GTM      24     5.709756
# 27    29.868851    -81.307428          GTM      25     5.117422
# 28    29.868851    -81.307428          GTM      26     6.013240
# 29    29.868851    -81.307428          GTM      27     5.914634
# 30    29.868851    -81.307428          GTM      28     6.104878
# 31    29.868851    -81.307428          GTM      29     6.035540
# 32    29.868851    -81.307428          GTM      30     6.246853
# 33    29.868851    -81.307428          GTM      31     6.624042
# 34    29.868851    -81.307428          GTM      32     6.814634
# 35    29.868851    -81.307428          GTM      33     7.081882
# 36    29.868851    -81.307428          GTM      34     6.954355
# 37    29.868851    -81.307428          GTM      35     7.491870
# 38    30.050857    -81.367465          GTM      23     4.654878
# 39    30.050857    -81.367465          GTM      24     4.521603
# 40    30.050857    -81.367465          GTM      25     4.376655
# 41    30.050857    -81.367465          GTM      26     5.585714
# 42    30.050857    -81.367465          GTM      27     5.267944
# 43    30.050857    -81.367465          GTM      28     4.780139
# 44    30.050857    -81.367465          GTM      29     5.096864
# 45    30.050857    -81.367465          GTM      30     5.361672
# 46    30.050857    -81.367465          GTM      31     5.923345
# 47    30.050857    -81.367465          GTM      32     6.316376
# 48    30.050857    -81.367465          GTM      33     6.670035
# 49    30.050857    -81.367465          GTM      34     6.795122

# %% [markdown]
# ### 1.5 Convert coordinate system to EPSG: 3086<a class="anchor" id="reg_coordinate"></a>

# %%
# Define the EPSG codes for source (EPSG:4326) and target (EPSG:3086) coordinate systems
source_epsg = 'EPSG:4326'
target_epsg = 'EPSG:3086'

# Create a PyProj Transformer for the conversion
transformer = pyproj.Transformer.from_crs(source_epsg, target_epsg, always_xy=True)

# Define a function to apply the transformation to each row of the DataFrame
def transform_coordinates(row):
    x, y = transformer.transform(row['Longitude_DD'], row['Latitude_DD'])
    return pd.Series({'x': x, 'y': y})

# Apply the transformation function to the DataFrame and create new columns for the converted coordinates
df_week_select_Mean[['x', 'y']] = df_week_select_Mean.apply(transform_coordinates, axis=1)

# %% [markdown]
# ## 2. Prepare for batch interpolation<a class="anchor" id="reg_batch"></a>

# %%
area_shortnames = {
    'Guana Tolomato Matanzas': 'GTM',
    'Estero Bay': 'EB',
    'Charlotte Harbor': 'CH',
    'Biscayne Bay': 'BB',
    'Big Bend Seagrasses':'BBS'
}

param_shortnames = {
    'Salinity': 'Sal_ppt',
    'Total Nitrogen': 'TN_mgl',
    'Dissolved Oxygen': 'DO_mgl',
    'Turbidity':'Turb_ntu',
    'Secchi Depth':'Secc_m',
    'Water Temperature':'T_c'
}

# %% [markdown]
# ### 2.2 Define the barrier files

# %%
barrier_folder = os.path.join(gis_path, 'Barriers')
barrier_folder

barriers = []
for file in os.listdir(barrier_folder):
    if file.endswith(".shp"):
        barriers.append(os.path.join(barrier_folder, file))

for barrier in barriers:
    print(barrier)
# Out:
# E:\Projects\SEACAR_WQ_2024/GIS_Data/Barriers\BBS_Barriers.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/Barriers\BB_Barriers.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/Barriers\CH_Barriers.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/Barriers\EB_Barriers.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/Barriers\GTM_Barriers.shp

# %% [markdown]
# ### 2.3 Define waterbody boundary for spatial extent and masking

# %%
waterbody_extent = os.path.join(gis_path, 'OEAT_Waterbody_Boundaries', 'OEAT_Waterbody_Boundary.shp')

unique_waterbodies = []
with arcpy.da.SearchCursor(waterbody_extent, ['WaterbodyA']) as cursor:
    for row in cursor:
        unique_waterbodies.append(row[0])

print("Unique Waterbodies:", unique_waterbodies)
# Out:
# Unique Waterbodies: ['BBS', 'BB', 'CH', 'EB', 'GTM']

# %% [markdown]
# ### 2.4 Define and generate weekly table.

# %%
waterBody = ['Big Bend Seagrasses', 'Biscayne Bay', 'Charlotte Harbor', 'Estero Bay', 'Guana Tolomato Matanzas']
parameter = ['Dissolved Oxygen', 'Salinity', 'Turbidity', 'Water Temperature']
waterBody_list = []
parameter_list= []
week_list = []
for i in waterBody:
    for j in parameter:
        for k in range(1,53):
            waterBody_list.append(i)
            parameter_list.append(j)
            week_list.append(k)

# %%
df_week_table = pd.DataFrame({
    "WaterBody":waterBody_list,
    "Parameter":parameter_list,
    "Period":week_list
})
df_week_table["Filename"] = ""
df_week_table["NumDataPoints"] = ""
df_week_table["RMSE"] = ""
df_week_table["ME"] = ""
df_week_table["WbodyAcronym"] = df_week_table["WaterBody"].map(area_shortnames)

# %%
name_ab = df_week_table["WbodyAcronym"].unique()
para_list = df_week_table["Parameter"].unique()
dfs_sub = []
for each in name_ab:
    sheet_name_use = str(each) + " 52 week"
    df_period_table_used = pd.read_excel(gis_path + "All_Waterbodies_Season_Month_Week_Definitions.xlsx",sheet_name=sheet_name_use)
    startDate = list(df_period_table_used["Start Date"])
    endDate   = list(df_period_table_used["End Date"])
    for para in para_list:
        df_temp_use = df_week_table[(df_week_table["WbodyAcronym"]==str(each))&(df_week_table["Parameter"]==str(para))]
        df_temp_use["startDate"] = startDate
        df_temp_use["endDate"]   = endDate
        dfs_sub.append(df_temp_use)
df_week_table = pd.concat(dfs_sub)
df_week_table["Year"] = df_week_table["startDate"].dt.year
df_week_table.to_csv(gis_path + 'week_table.csv')

# %% [markdown]
# # 1.2 Preview Dataset <a class="anchor" id="reg_preview"></a>

# %%
df_week_select_Mean.head(50)
# Out:
#                   WaterBody     ParameterName ParameterUnits  Year Season  \
# 0   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 1   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 2   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 3   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 4   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 5   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 6   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 7   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 8   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 9   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 10  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 11  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 12  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 13  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 14  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 15  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 16  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 17  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 18  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 19  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 20  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 21  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 22  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 23  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 24  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 25  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 26  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 27  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 28  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 29  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 30  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 31  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 32  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 33  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 34  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 35  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 36  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 37  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 38  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 39  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 40  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 41  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 42  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 43  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 44  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 45  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 46  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 47  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 48  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 49  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
#
#     Latitude_DD  Longitude_DD WbodyAcronym  Period  ResultValue  \
# 0     29.667071    -81.257403          GTM      23     5.536585
# 1     29.667071    -81.257403          GTM      24     5.028920
# 2     29.667071    -81.257403          GTM      25     4.721951
# 3     29.667071    -81.257403          GTM      26     5.433798
# 4     29.667071    -81.257403          GTM      27     3.042509
# 5     29.667071    -81.257403          GTM      28     3.554704
# 6     29.667071    -81.257403          GTM      29     4.092683
# 7     29.667071    -81.257403          GTM      30     4.660667
# 8     29.667071    -81.257403          GTM      32     5.649735
# 9     29.667071    -81.257403          GTM      33     6.990244
# 10    29.667071    -81.257403          GTM      34     6.492334
# 11    29.667071    -81.257403          GTM      35     7.352033
# 12    29.737041    -81.245953          GTM      23     5.771951
# 13    29.737041    -81.245953          GTM      24     5.579443
# 14    29.737041    -81.245953          GTM      25     5.524390
# 15    29.737041    -81.245953          GTM      26     5.729965
# 16    29.737041    -81.245953          GTM      27     6.048432
# 17    29.737041    -81.245953          GTM      28     6.281185
# 18    29.737041    -81.245953          GTM      29     6.565505
# 19    29.737041    -81.245953          GTM      30     6.458885
# 20    29.737041    -81.245953          GTM      31     6.726481
# 21    29.737041    -81.245953          GTM      32     6.778049
# 22    29.737041    -81.245953          GTM      33     7.229965
# 23    29.737041    -81.245953          GTM      34     7.003136
# 24    29.737041    -81.245953          GTM      35     7.287805
# 25    29.868851    -81.307428          GTM      23     5.510976
# 26    29.868851    -81.307428          GTM      24     5.709756
# 27    29.868851    -81.307428          GTM      25     5.117422
# 28    29.868851    -81.307428          GTM      26     6.013240
# 29    29.868851    -81.307428          GTM      27     5.914634
# 30    29.868851    -81.307428          GTM      28     6.104878
# 31    29.868851    -81.307428          GTM      29     6.035540
# 32    29.868851    -81.307428          GTM      30     6.246853
# 33    29.868851    -81.307428          GTM      31     6.624042
# 34    29.868851    -81.307428          GTM      32     6.814634
# 35    29.868851    -81.307428          GTM      33     7.081882
# 36    29.868851    -81.307428          GTM      34     6.954355
# 37    29.868851    -81.307428          GTM      35     7.491870
# 38    30.050857    -81.367465          GTM      23     4.654878
# 39    30.050857    -81.367465          GTM      24     4.521603
# 40    30.050857    -81.367465          GTM      25     4.376655
# 41    30.050857    -81.367465          GTM      26     5.585714
# 42    30.050857    -81.367465          GTM      27     5.267944
# 43    30.050857    -81.367465          GTM      28     4.780139
# 44    30.050857    -81.367465          GTM      29     5.096864
# 45    30.050857    -81.367465          GTM      30     5.361672
# 46    30.050857    -81.367465          GTM      31     5.923345
# 47    30.050857    -81.367465          GTM      32     6.316376
# 48    30.050857    -81.367465          GTM      33     6.670035
# 49    30.050857    -81.367465          GTM      34     6.795122
#
#                 x              y
# 0   665054.640076  631868.177645
# 1   665054.640076  631868.177645
# 2   665054.640076  631868.177645
# 3   665054.640076  631868.177645
# 4   665054.640076  631868.177645
# 5   665054.640076  631868.177645
# 6   665054.640076  631868.177645
# 7   665054.640076  631868.177645
# 8   665054.640076  631868.177645
# 9   665054.640076  631868.177645
# 10  665054.640076  631868.177645
# 11  665054.640076  631868.177645
# 12  665987.547779  639659.183554
# 13  665987.547779  639659.183554
# 14  665987.547779  639659.183554
# 15  665987.547779  639659.183554
# 16  665987.547779  639659.183554
# 17  665987.547779  639659.183554
# 18  665987.547779  639659.183554
# 19  665987.547779  639659.183554
# 20  665987.547779  639659.183554
# 21  665987.547779  639659.183554
# 22  665987.547779  639659.183554
# 23  665987.547779  639659.183554
# 24  665987.547779  639659.183554
# 25  659731.716683  654157.848803
# 26  659731.716683  654157.848803
# 27  659731.716683  654157.848803
# 28  659731.716683  654157.848803
# 29  659731.716683  654157.848803
# 30  659731.716683  654157.848803
# 31  659731.716683  654157.848803
# 32  659731.716683  654157.848803
# 33  659731.716683  654157.848803
# 34  659731.716683  654157.848803
# 35  659731.716683  654157.848803
# 36  659731.716683  654157.848803
# 37  659731.716683  654157.848803
# 38  653510.005839  674232.563906
# 39  653510.005839  674232.563906
# 40  653510.005839  674232.563906
# 41  653510.005839  674232.563906
# 42  653510.005839  674232.563906
# 43  653510.005839  674232.563906
# 44  653510.005839  674232.563906
# 45  653510.005839  674232.563906
# 46  653510.005839  674232.563906
# 47  653510.005839  674232.563906
# 48  653510.005839  674232.563906
# 49  653510.005839  674232.563906

# %% [markdown]
# ## 1.3 Fill NaN RowID with unique ID, IDW function needs unique ID <a class="anchor" id="reg_id"></a>

# %%
idw_rk_x.fill_nan_rowids(df_week_select_Mean, 'RowID')

df_week_select_Mean['RowID'] = df_week_select_Mean['RowID'].astype(int)
df_week_select_Mean
# Out:
#                     WaterBody      ParameterName ParameterUnits  Year  Season  \
# 0     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 1     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 2     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 3     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 4     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# ...                       ...                ...            ...   ...     ...
# 3452      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 3453      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 3454      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 3455      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 3456      Big Bend Seagrasses  Water Temperature      Degrees C  2022  Winter
#
#       Latitude_DD  Longitude_DD WbodyAcronym  Period  ResultValue  \
# 0       29.667071    -81.257403          GTM      23     5.536585
# 1       29.667071    -81.257403          GTM      24     5.028920
# 2       29.667071    -81.257403          GTM      25     4.721951
# 3       29.667071    -81.257403          GTM      26     5.433798
# 4       29.667071    -81.257403          GTM      27     3.042509
# ...           ...           ...          ...     ...          ...
# 3452    29.647203    -83.421196          BBS      49    20.009756
# 3453    29.647203    -83.421196          BBS      50    20.522764
# 3454    29.647203    -83.421196          BBS      51    16.418699
# 3455    29.647203    -83.421196          BBS      52    21.247967
# 3456    29.647203    -83.421196          BBS      52    21.245528
#
#                   x              y  RowID
# 0     665054.640076  631868.177645      1
# 1     665054.640076  631868.177645      2
# 2     665054.640076  631868.177645      3
# 3     665054.640076  631868.177645      4
# 4     665054.640076  631868.177645      5
# ...             ...            ...    ...
# 3452  455952.502950  626846.023588   3453
# 3453  455952.502950  626846.023588   3454
# 3454  455952.502950  626846.023588   3455
# 3455  455952.502950  626846.023588   3456
# 3456  455952.502950  626846.023588   3457
#
# [3457 rows x 13 columns]

# %% [markdown]
# # 2. Create Shapefile <a class="anchor" id="reg_create_shp"></a>

# %%
idw_rk_x.delete_all_files(shpCon_folder)

# %%
# Merge interested with latitude and longitude columns
seasons_con_coord = idw_rk_x.merge_with_lat_long1(df_week_table, df_week_select_Mean)

seasons_con_coord
# Out:
#                     WaterBody          Parameter  Period Filename  \
# 0         Big Bend Seagrasses   Dissolved Oxygen       1
# 1         Big Bend Seagrasses   Dissolved Oxygen       2
# 2         Big Bend Seagrasses   Dissolved Oxygen       3
# 3         Big Bend Seagrasses   Dissolved Oxygen       4
# 4         Big Bend Seagrasses   Dissolved Oxygen       5
# ...                       ...                ...     ...      ...
# 3491  Guana Tolomato Matanzas  Water Temperature      51
# 3492  Guana Tolomato Matanzas  Water Temperature      52
# 3493  Guana Tolomato Matanzas  Water Temperature      52
# 3494  Guana Tolomato Matanzas  Water Temperature      52
# 3495  Guana Tolomato Matanzas  Water Temperature      52
#
#      NumDataPoints RMSE ME WbodyAcronym  startDate    endDate  Year  \
# 0                                   BBS 2021-01-06 2021-01-12  2021
# 1                                   BBS 2021-01-13 2021-01-19  2021
# 2                                   BBS 2021-01-20 2021-01-26  2021
# 3                                   BBS 2021-01-27 2021-02-02  2021
# 4                                   BBS 2021-02-03 2021-02-09  2021
# ...            ...  ... ..          ...        ...        ...   ...
# 3491                                GTM 2017-03-25 2017-04-01  2017
# 3492                                GTM 2017-04-01 2017-04-08  2017
# 3493                                GTM 2017-04-01 2017-04-08  2017
# 3494                                GTM 2017-04-01 2017-04-08  2017
# 3495                                GTM 2017-04-01 2017-04-08  2017
#
#                   x              y  RowID  ResultValue
# 0     455952.502950  626846.023588   3286     8.334146
# 1     455952.502950  626846.023588   3287     8.486992
# 2     455952.502950  626846.023588   3288     8.124390
# 3     455952.502950  626846.023588   3289     7.903659
# 4     455952.502950  626846.023588   3290     8.734146
# ...             ...            ...    ...          ...
# 3491  653510.005839  674232.563906    747    22.810801
# 3492  665054.640076  631868.177645    733    24.600348
# 3493  665987.547779  639659.183554    738    21.855401
# 3494  659731.716683  654157.848803    743    22.620557
# 3495  653510.005839  674232.563906    748    23.841812
#
# [3496 rows x 15 columns]

# %%
idw_rk_x.create_shp_season1(seasons_con_coord, shpCon_folder)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000002DBA8608D90>
# Number of data rows for BBS, DO_mgl, 1: 1
# Shapefile for BBS: DO_mgl for period 1 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_1.shp
# Number of data rows for BBS, DO_mgl, 2: 1
# Shapefile for BBS: DO_mgl for period 2 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_2.shp
# Number of data rows for BBS, DO_mgl, 3: 1
# Shapefile for BBS: DO_mgl for period 3 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_3.shp
# Number of data rows for BBS, DO_mgl, 4: 1
# Shapefile for BBS: DO_mgl for period 4 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_4.shp
# Number of data rows for BBS, DO_mgl, 5: 1
# Shapefile for BBS: DO_mgl for period 5 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_5.shp
# Number of data rows for BBS, DO_mgl, 6: 1
# Shapefile for BBS: DO_mgl for period 6 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_6.shp
# Number of data rows for BBS, DO_mgl, 7: 1
# Shapefile for BBS: DO_mgl for period 7 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_7.shp
# Number of data rows for BBS, DO_mgl, 8: 1
# Shapefile for BBS: DO_mgl for period 8 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_8.shp
# Number of data rows for BBS, DO_mgl, 9: 1
# Shapefile for BBS: DO_mgl for period 9 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_9.shp
# Number of data rows for BBS, DO_mgl, 10: 1
# Shapefile for BBS: DO_mgl for period 10 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_10.shp
# Number of data rows for BBS, DO_mgl, 11: 1
# Shapefile for BBS: DO_mgl for period 11 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_11.shp
# Number of data rows for BBS, DO_mgl, 12: 1
# Shapefile for BBS: DO_mgl for period 12 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_12.shp
# Number of data rows for BBS, DO_mgl, 13: 1
# Shapefile for BBS: DO_mgl for period 13 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_13.shp
# Number of data rows for BBS, DO_mgl, 14: 1
# Shapefile for BBS: DO_mgl for period 14 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_14.shp
# Number of data rows for BBS, DO_mgl, 15: 1
# Shapefile for BBS: DO_mgl for period 15 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_15.shp
# Number of data rows for BBS, DO_mgl, 16: 1
# Shapefile for BBS: DO_mgl for period 16 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_16.shp
# Number of data rows for BBS, DO_mgl, 17: 1
# Shapefile for BBS: DO_mgl for period 17 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_17.shp
# Number of data rows for BBS, DO_mgl, 18: 1
# Shapefile for BBS: DO_mgl for period 18 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_18.shp
# Number of data rows for BBS, DO_mgl, 19: 1
# Shapefile for BBS: DO_mgl for period 19 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_19.shp
# Number of data rows for BBS, DO_mgl, 20: 1
# Shapefile for BBS: DO_mgl for period 20 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_20.shp
# Number of data rows for BBS, DO_mgl, 21: 1
# Shapefile for BBS: DO_mgl for period 21 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_21.shp
# No valid data found for area: BBS, parameter: DO_mgl, period: 22
# No valid data found for area: BBS, parameter: DO_mgl, period: 23
# No valid data found for area: BBS, parameter: DO_mgl, period: 24
# Number of data rows for BBS, DO_mgl, 25: 1
# Shapefile for BBS: DO_mgl for period 25 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_25.shp
# Number of data rows for BBS, DO_mgl, 26: 1
# Shapefile for BBS: DO_mgl for period 26 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_26.shp
# Number of data rows for BBS, DO_mgl, 27: 1
# Shapefile for BBS: DO_mgl for period 27 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_27.shp
# Number of data rows for BBS, DO_mgl, 28: 1
# Shapefile for BBS: DO_mgl for period 28 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_28.shp
# Number of data rows for BBS, DO_mgl, 29: 1
# Shapefile for BBS: DO_mgl for period 29 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_29.shp
# Number of data rows for BBS, DO_mgl, 30: 1
# Shapefile for BBS: DO_mgl for period 30 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_30.shp
# Number of data rows for BBS, DO_mgl, 31: 1
# Shapefile for BBS: DO_mgl for period 31 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_31.shp
# Number of data rows for BBS, DO_mgl, 32: 1
# Shapefile for BBS: DO_mgl for period 32 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_32.shp
# Number of data rows for BBS, DO_mgl, 33: 1
# Shapefile for BBS: DO_mgl for period 33 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_33.shp
# Number of data rows for BBS, DO_mgl, 34: 1
# Shapefile for BBS: DO_mgl for period 34 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_34.shp
# Number of data rows for BBS, DO_mgl, 35: 1
# Shapefile for BBS: DO_mgl for period 35 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_35.shp
# Number of data rows for BBS, DO_mgl, 36: 1
# Shapefile for BBS: DO_mgl for period 36 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_36.shp
# Number of data rows for BBS, DO_mgl, 37: 1
# Shapefile for BBS: DO_mgl for period 37 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_37.shp
# Number of data rows for BBS, DO_mgl, 38: 1
# Shapefile for BBS: DO_mgl for period 38 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_38.shp
# Number of data rows for BBS, DO_mgl, 39: 1
# Shapefile for BBS: DO_mgl for period 39 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_39.shp
# Number of data rows for BBS, DO_mgl, 40: 1
# Shapefile for BBS: DO_mgl for period 40 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_40.shp
# Number of data rows for BBS, DO_mgl, 41: 1
# Shapefile for BBS: DO_mgl for period 41 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_41.shp
# Number of data rows for BBS, DO_mgl, 42: 1
# Shapefile for BBS: DO_mgl for period 42 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_42.shp
# Number of data rows for BBS, DO_mgl, 43: 1
# Shapefile for BBS: DO_mgl for period 43 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_43.shp
# Number of data rows for BBS, DO_mgl, 44: 1
# Shapefile for BBS: DO_mgl for period 44 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_44.shp
# Number of data rows for BBS, DO_mgl, 45: 1
# Shapefile for BBS: DO_mgl for period 45 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_45.shp
# Number of data rows for BBS, DO_mgl, 46: 1
# Shapefile for BBS: DO_mgl for period 46 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_46.shp
# Number of data rows for BBS, DO_mgl, 47: 1
# Shapefile for BBS: DO_mgl for period 47 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_47.shp
# Number of data rows for BBS, DO_mgl, 48: 2
# Shapefile for BBS: DO_mgl for period 48 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_48.shp
# Number of data rows for BBS, DO_mgl, 49: 1
# Shapefile for BBS: DO_mgl for period 49 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_49.shp
# Number of data rows for BBS, DO_mgl, 50: 1
# Shapefile for BBS: DO_mgl for period 50 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_50.shp
# Number of data rows for BBS, DO_mgl, 51: 1
# Shapefile for BBS: DO_mgl for period 51 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_51.shp
# Number of data rows for BBS, DO_mgl, 52: 2
# Shapefile for BBS: DO_mgl for period 52 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_52.shp
# Number of data rows for BBS, Sal_ppt, 1: 1
# Shapefile for BBS: Sal_ppt for period 1 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_1.shp
# Number of data rows for BBS, Sal_ppt, 2: 1
# Shapefile for BBS: Sal_ppt for period 2 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_2.shp
# Number of data rows for BBS, Sal_ppt, 3: 1
# Shapefile for BBS: Sal_ppt for period 3 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_3.shp
# Number of data rows for BBS, Sal_ppt, 4: 1
# Shapefile for BBS: Sal_ppt for period 4 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_4.shp
# Number of data rows for BBS, Sal_ppt, 5: 1
# Shapefile for BBS: Sal_ppt for period 5 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_5.shp
# Number of data rows for BBS, Sal_ppt, 6: 1
# Shapefile for BBS: Sal_ppt for period 6 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_6.shp
# Number of data rows for BBS, Sal_ppt, 7: 1
# Shapefile for BBS: Sal_ppt for period 7 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_7.shp
# Number of data rows for BBS, Sal_ppt, 8: 1
# Shapefile for BBS: Sal_ppt for period 8 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_8.shp
# Number of data rows for BBS, Sal_ppt, 9: 1
# Shapefile for BBS: Sal_ppt for period 9 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_9.shp
# Number of data rows for BBS, Sal_ppt, 10: 1
# Shapefile for BBS: Sal_ppt for period 10 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_10.shp
# Number of data rows for BBS, Sal_ppt, 11: 1
# Shapefile for BBS: Sal_ppt for period 11 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_11.shp
# Number of data rows for BBS, Sal_ppt, 12: 1
# Shapefile for BBS: Sal_ppt for period 12 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_12.shp
# Number of data rows for BBS, Sal_ppt, 13: 1
# Shapefile for BBS: Sal_ppt for period 13 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_13.shp
# Number of data rows for BBS, Sal_ppt, 14: 1
# Shapefile for BBS: Sal_ppt for period 14 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_14.shp
# Number of data rows for BBS, Sal_ppt, 15: 1
# Shapefile for BBS: Sal_ppt for period 15 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_15.shp
# Number of data rows for BBS, Sal_ppt, 16: 1
# Shapefile for BBS: Sal_ppt for period 16 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_16.shp
# Number of data rows for BBS, Sal_ppt, 17: 1
# Shapefile for BBS: Sal_ppt for period 17 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_17.shp
# Number of data rows for BBS, Sal_ppt, 18: 1
# Shapefile for BBS: Sal_ppt for period 18 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_18.shp
# Number of data rows for BBS, Sal_ppt, 19: 1
# Shapefile for BBS: Sal_ppt for period 19 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_19.shp
# Number of data rows for BBS, Sal_ppt, 20: 1
# Shapefile for BBS: Sal_ppt for period 20 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_20.shp
# Number of data rows for BBS, Sal_ppt, 21: 1
# Shapefile for BBS: Sal_ppt for period 21 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_21.shp
# No valid data found for area: BBS, parameter: Sal_ppt, period: 22
# No valid data found for area: BBS, parameter: Sal_ppt, period: 23
# No valid data found for area: BBS, parameter: Sal_ppt, period: 24
# Number of data rows for BBS, Sal_ppt, 25: 1
# Shapefile for BBS: Sal_ppt for period 25 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_25.shp
# Number of data rows for BBS, Sal_ppt, 26: 1
# Shapefile for BBS: Sal_ppt for period 26 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_26.shp
# Number of data rows for BBS, Sal_ppt, 27: 1
# Shapefile for BBS: Sal_ppt for period 27 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_27.shp
# Number of data rows for BBS, Sal_ppt, 28: 1
# Shapefile for BBS: Sal_ppt for period 28 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_28.shp
# Number of data rows for BBS, Sal_ppt, 29: 1
# Shapefile for BBS: Sal_ppt for period 29 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_29.shp
# Number of data rows for BBS, Sal_ppt, 30: 1
# Shapefile for BBS: Sal_ppt for period 30 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_30.shp
# Number of data rows for BBS, Sal_ppt, 31: 1
# Shapefile for BBS: Sal_ppt for period 31 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_31.shp
# Number of data rows for BBS, Sal_ppt, 32: 1
# Shapefile for BBS: Sal_ppt for period 32 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_32.shp
# Number of data rows for BBS, Sal_ppt, 33: 1
# Shapefile for BBS: Sal_ppt for period 33 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_33.shp
# Number of data rows for BBS, Sal_ppt, 34: 1
# Shapefile for BBS: Sal_ppt for period 34 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_34.shp
# Number of data rows for BBS, Sal_ppt, 35: 1
# Shapefile for BBS: Sal_ppt for period 35 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_35.shp
# Number of data rows for BBS, Sal_ppt, 36: 1
# Shapefile for BBS: Sal_ppt for period 36 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_36.shp
# Number of data rows for BBS, Sal_ppt, 37: 1
# Shapefile for BBS: Sal_ppt for period 37 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_37.shp
# Number of data rows for BBS, Sal_ppt, 38: 1
# Shapefile for BBS: Sal_ppt for period 38 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_38.shp
# Number of data rows for BBS, Sal_ppt, 39: 1
# Shapefile for BBS: Sal_ppt for period 39 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_39.shp
# Number of data rows for BBS, Sal_ppt, 40: 1
# Shapefile for BBS: Sal_ppt for period 40 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_40.shp
# Number of data rows for BBS, Sal_ppt, 41: 1
# Shapefile for BBS: Sal_ppt for period 41 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_41.shp
# Number of data rows for BBS, Sal_ppt, 42: 1
# Shapefile for BBS: Sal_ppt for period 42 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_42.shp
# Number of data rows for BBS, Sal_ppt, 43: 1
# Shapefile for BBS: Sal_ppt for period 43 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_43.shp
# Number of data rows for BBS, Sal_ppt, 44: 1
# Shapefile for BBS: Sal_ppt for period 44 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_44.shp
# Number of data rows for BBS, Sal_ppt, 45: 1
# Shapefile for BBS: Sal_ppt for period 45 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_45.shp
# Number of data rows for BBS, Sal_ppt, 46: 1
# Shapefile for BBS: Sal_ppt for period 46 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_46.shp
# Number of data rows for BBS, Sal_ppt, 47: 1
# Shapefile for BBS: Sal_ppt for period 47 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_47.shp
# Number of data rows for BBS, Sal_ppt, 48: 2
# Shapefile for BBS: Sal_ppt for period 48 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_48.shp
# Number of data rows for BBS, Sal_ppt, 49: 1
# Shapefile for BBS: Sal_ppt for period 49 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_49.shp
# Number of data rows for BBS, Sal_ppt, 50: 1
# Shapefile for BBS: Sal_ppt for period 50 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_50.shp
# Number of data rows for BBS, Sal_ppt, 51: 1
# Shapefile for BBS: Sal_ppt for period 51 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_51.shp
# Number of data rows for BBS, Sal_ppt, 52: 2
# Shapefile for BBS: Sal_ppt for period 52 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_52.shp
# Number of data rows for BBS, Turb_ntu, 1: 1
# Shapefile for BBS: Turb_ntu for period 1 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_1.shp
# Number of data rows for BBS, Turb_ntu, 2: 1
# Shapefile for BBS: Turb_ntu for period 2 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_2.shp
# Number of data rows for BBS, Turb_ntu, 3: 1
# Shapefile for BBS: Turb_ntu for period 3 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_3.shp
# Number of data rows for BBS, Turb_ntu, 4: 1
# Shapefile for BBS: Turb_ntu for period 4 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_4.shp
# No valid data found for area: BBS, parameter: Turb_ntu, period: 5
# Number of data rows for BBS, Turb_ntu, 6: 1
# Shapefile for BBS: Turb_ntu for period 6 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_6.shp
# Number of data rows for BBS, Turb_ntu, 7: 1
# Shapefile for BBS: Turb_ntu for period 7 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_7.shp
# Number of data rows for BBS, Turb_ntu, 8: 1
# Shapefile for BBS: Turb_ntu for period 8 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_8.shp
# Number of data rows for BBS, Turb_ntu, 9: 1
# Shapefile for BBS: Turb_ntu for period 9 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_9.shp
# Number of data rows for BBS, Turb_ntu, 10: 1
# Shapefile for BBS: Turb_ntu for period 10 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_10.shp
# Number of data rows for BBS, Turb_ntu, 11: 1
# Shapefile for BBS: Turb_ntu for period 11 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_11.shp
# Number of data rows for BBS, Turb_ntu, 12: 1
# Shapefile for BBS: Turb_ntu for period 12 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_12.shp
# Number of data rows for BBS, Turb_ntu, 13: 1
# Shapefile for BBS: Turb_ntu for period 13 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_13.shp
# Number of data rows for BBS, Turb_ntu, 14: 1
# Shapefile for BBS: Turb_ntu for period 14 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_14.shp
# Number of data rows for BBS, Turb_ntu, 15: 1
# Shapefile for BBS: Turb_ntu for period 15 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_15.shp
# Number of data rows for BBS, Turb_ntu, 16: 1
# Shapefile for BBS: Turb_ntu for period 16 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_16.shp
# Number of data rows for BBS, Turb_ntu, 17: 1
# Shapefile for BBS: Turb_ntu for period 17 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_17.shp
# Number of data rows for BBS, Turb_ntu, 18: 1
# Shapefile for BBS: Turb_ntu for period 18 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_18.shp
# Number of data rows for BBS, Turb_ntu, 19: 1
# Shapefile for BBS: Turb_ntu for period 19 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_19.shp
# Number of data rows for BBS, Turb_ntu, 20: 1
# Shapefile for BBS: Turb_ntu for period 20 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_20.shp
# Number of data rows for BBS, Turb_ntu, 21: 1
# Shapefile for BBS: Turb_ntu for period 21 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_21.shp
# Number of data rows for BBS, Turb_ntu, 22: 1
# Shapefile for BBS: Turb_ntu for period 22 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_22.shp
# Number of data rows for BBS, Turb_ntu, 23: 1
# Shapefile for BBS: Turb_ntu for period 23 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_23.shp
# Number of data rows for BBS, Turb_ntu, 24: 1
# Shapefile for BBS: Turb_ntu for period 24 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_24.shp
# Number of data rows for BBS, Turb_ntu, 25: 1
# Shapefile for BBS: Turb_ntu for period 25 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_25.shp
# Number of data rows for BBS, Turb_ntu, 26: 1
# Shapefile for BBS: Turb_ntu for period 26 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_26.shp
# Number of data rows for BBS, Turb_ntu, 27: 1
# Shapefile for BBS: Turb_ntu for period 27 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_27.shp
# Number of data rows for BBS, Turb_ntu, 28: 1
# Shapefile for BBS: Turb_ntu for period 28 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_28.shp
# Number of data rows for BBS, Turb_ntu, 29: 1
# Shapefile for BBS: Turb_ntu for period 29 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_29.shp
# Number of data rows for BBS, Turb_ntu, 30: 1
# Shapefile for BBS: Turb_ntu for period 30 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_30.shp
# Number of data rows for BBS, Turb_ntu, 31: 1
# Shapefile for BBS: Turb_ntu for period 31 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_31.shp
# Number of data rows for BBS, Turb_ntu, 32: 1
# Shapefile for BBS: Turb_ntu for period 32 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_32.shp
# Number of data rows for BBS, Turb_ntu, 33: 1
# Shapefile for BBS: Turb_ntu for period 33 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_33.shp
# Number of data rows for BBS, Turb_ntu, 34: 1
# Shapefile for BBS: Turb_ntu for period 34 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_34.shp
# Number of data rows for BBS, Turb_ntu, 35: 1
# Shapefile for BBS: Turb_ntu for period 35 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_35.shp
# Number of data rows for BBS, Turb_ntu, 36: 1
# Shapefile for BBS: Turb_ntu for period 36 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_36.shp
# Number of data rows for BBS, Turb_ntu, 37: 1
# Shapefile for BBS: Turb_ntu for period 37 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_37.shp
# Number of data rows for BBS, Turb_ntu, 38: 1
# Shapefile for BBS: Turb_ntu for period 38 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_38.shp
# Number of data rows for BBS, Turb_ntu, 39: 1
# Shapefile for BBS: Turb_ntu for period 39 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_39.shp
# Number of data rows for BBS, Turb_ntu, 40: 1
# Shapefile for BBS: Turb_ntu for period 40 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_40.shp
# Number of data rows for BBS, Turb_ntu, 41: 1
# Shapefile for BBS: Turb_ntu for period 41 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_41.shp
# Number of data rows for BBS, Turb_ntu, 42: 1
# Shapefile for BBS: Turb_ntu for period 42 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_42.shp
# Number of data rows for BBS, Turb_ntu, 43: 1
# Shapefile for BBS: Turb_ntu for period 43 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_43.shp
# Number of data rows for BBS, Turb_ntu, 44: 1
# Shapefile for BBS: Turb_ntu for period 44 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_44.shp
# Number of data rows for BBS, Turb_ntu, 45: 1
# Shapefile for BBS: Turb_ntu for period 45 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_45.shp
# Number of data rows for BBS, Turb_ntu, 46: 1
# Shapefile for BBS: Turb_ntu for period 46 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_46.shp
# Number of data rows for BBS, Turb_ntu, 47: 1
# Shapefile for BBS: Turb_ntu for period 47 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_47.shp
# Number of data rows for BBS, Turb_ntu, 48: 2
# Shapefile for BBS: Turb_ntu for period 48 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_48.shp
# Number of data rows for BBS, Turb_ntu, 49: 1
# Shapefile for BBS: Turb_ntu for period 49 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_49.shp
# Number of data rows for BBS, Turb_ntu, 50: 1
# Shapefile for BBS: Turb_ntu for period 50 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_50.shp
# Number of data rows for BBS, Turb_ntu, 51: 1
# Shapefile for BBS: Turb_ntu for period 51 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_51.shp
# Number of data rows for BBS, Turb_ntu, 52: 2
# Shapefile for BBS: Turb_ntu for period 52 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_52.shp
# Number of data rows for BBS, T_c, 1: 1
# Shapefile for BBS: T_c for period 1 of year 2021 has been saved as SHP_BBS_T_c_2021_1.shp
# Number of data rows for BBS, T_c, 2: 1
# Shapefile for BBS: T_c for period 2 of year 2021 has been saved as SHP_BBS_T_c_2021_2.shp
# Number of data rows for BBS, T_c, 3: 1
# Shapefile for BBS: T_c for period 3 of year 2021 has been saved as SHP_BBS_T_c_2021_3.shp
# Number of data rows for BBS, T_c, 4: 1
# Shapefile for BBS: T_c for period 4 of year 2021 has been saved as SHP_BBS_T_c_2021_4.shp
# Number of data rows for BBS, T_c, 5: 1
# Shapefile for BBS: T_c for period 5 of year 2021 has been saved as SHP_BBS_T_c_2021_5.shp
# Number of data rows for BBS, T_c, 6: 1
# Shapefile for BBS: T_c for period 6 of year 2021 has been saved as SHP_BBS_T_c_2021_6.shp
# Number of data rows for BBS, T_c, 7: 1
# Shapefile for BBS: T_c for period 7 of year 2021 has been saved as SHP_BBS_T_c_2021_7.shp
# Number of data rows for BBS, T_c, 8: 1
# Shapefile for BBS: T_c for period 8 of year 2021 has been saved as SHP_BBS_T_c_2021_8.shp
# Number of data rows for BBS, T_c, 9: 1
# Shapefile for BBS: T_c for period 9 of year 2021 has been saved as SHP_BBS_T_c_2021_9.shp
# Number of data rows for BBS, T_c, 10: 1
# Shapefile for BBS: T_c for period 10 of year 2021 has been saved as SHP_BBS_T_c_2021_10.shp
# Number of data rows for BBS, T_c, 11: 1
# Shapefile for BBS: T_c for period 11 of year 2021 has been saved as SHP_BBS_T_c_2021_11.shp
# Number of data rows for BBS, T_c, 12: 1
# Shapefile for BBS: T_c for period 12 of year 2021 has been saved as SHP_BBS_T_c_2021_12.shp
# Number of data rows for BBS, T_c, 13: 1
# Shapefile for BBS: T_c for period 13 of year 2021 has been saved as SHP_BBS_T_c_2021_13.shp
# Number of data rows for BBS, T_c, 14: 1
# Shapefile for BBS: T_c for period 14 of year 2021 has been saved as SHP_BBS_T_c_2021_14.shp
# Number of data rows for BBS, T_c, 15: 1
# Shapefile for BBS: T_c for period 15 of year 2021 has been saved as SHP_BBS_T_c_2021_15.shp
# Number of data rows for BBS, T_c, 16: 1
# Shapefile for BBS: T_c for period 16 of year 2021 has been saved as SHP_BBS_T_c_2021_16.shp
# Number of data rows for BBS, T_c, 17: 1
# Shapefile for BBS: T_c for period 17 of year 2021 has been saved as SHP_BBS_T_c_2021_17.shp
# Number of data rows for BBS, T_c, 18: 1
# Shapefile for BBS: T_c for period 18 of year 2021 has been saved as SHP_BBS_T_c_2021_18.shp
# Number of data rows for BBS, T_c, 19: 1
# Shapefile for BBS: T_c for period 19 of year 2021 has been saved as SHP_BBS_T_c_2021_19.shp
# Number of data rows for BBS, T_c, 20: 1
# Shapefile for BBS: T_c for period 20 of year 2021 has been saved as SHP_BBS_T_c_2021_20.shp
# Number of data rows for BBS, T_c, 21: 1
# Shapefile for BBS: T_c for period 21 of year 2021 has been saved as SHP_BBS_T_c_2021_21.shp
# Number of data rows for BBS, T_c, 22: 1
# Shapefile for BBS: T_c for period 22 of year 2021 has been saved as SHP_BBS_T_c_2021_22.shp
# Number of data rows for BBS, T_c, 23: 1
# Shapefile for BBS: T_c for period 23 of year 2021 has been saved as SHP_BBS_T_c_2021_23.shp
# Number of data rows for BBS, T_c, 24: 1
# Shapefile for BBS: T_c for period 24 of year 2021 has been saved as SHP_BBS_T_c_2021_24.shp
# Number of data rows for BBS, T_c, 25: 1
# Shapefile for BBS: T_c for period 25 of year 2021 has been saved as SHP_BBS_T_c_2021_25.shp
# Number of data rows for BBS, T_c, 26: 1
# Shapefile for BBS: T_c for period 26 of year 2021 has been saved as SHP_BBS_T_c_2021_26.shp
# Number of data rows for BBS, T_c, 27: 1
# Shapefile for BBS: T_c for period 27 of year 2021 has been saved as SHP_BBS_T_c_2021_27.shp
# Number of data rows for BBS, T_c, 28: 1
# Shapefile for BBS: T_c for period 28 of year 2021 has been saved as SHP_BBS_T_c_2021_28.shp
# Number of data rows for BBS, T_c, 29: 1
# Shapefile for BBS: T_c for period 29 of year 2021 has been saved as SHP_BBS_T_c_2021_29.shp
# Number of data rows for BBS, T_c, 30: 1
# Shapefile for BBS: T_c for period 30 of year 2021 has been saved as SHP_BBS_T_c_2021_30.shp
# Number of data rows for BBS, T_c, 31: 1
# Shapefile for BBS: T_c for period 31 of year 2021 has been saved as SHP_BBS_T_c_2021_31.shp
# Number of data rows for BBS, T_c, 32: 1
# Shapefile for BBS: T_c for period 32 of year 2021 has been saved as SHP_BBS_T_c_2021_32.shp
# Number of data rows for BBS, T_c, 33: 1
# Shapefile for BBS: T_c for period 33 of year 2021 has been saved as SHP_BBS_T_c_2021_33.shp
# Number of data rows for BBS, T_c, 34: 1
# Shapefile for BBS: T_c for period 34 of year 2021 has been saved as SHP_BBS_T_c_2021_34.shp
# Number of data rows for BBS, T_c, 35: 1
# Shapefile for BBS: T_c for period 35 of year 2021 has been saved as SHP_BBS_T_c_2021_35.shp
# Number of data rows for BBS, T_c, 36: 1
# Shapefile for BBS: T_c for period 36 of year 2021 has been saved as SHP_BBS_T_c_2021_36.shp
# Number of data rows for BBS, T_c, 37: 1
# Shapefile for BBS: T_c for period 37 of year 2021 has been saved as SHP_BBS_T_c_2021_37.shp
# Number of data rows for BBS, T_c, 38: 1
# Shapefile for BBS: T_c for period 38 of year 2021 has been saved as SHP_BBS_T_c_2021_38.shp
# Number of data rows for BBS, T_c, 39: 1
# Shapefile for BBS: T_c for period 39 of year 2021 has been saved as SHP_BBS_T_c_2021_39.shp
# Number of data rows for BBS, T_c, 40: 1
# Shapefile for BBS: T_c for period 40 of year 2021 has been saved as SHP_BBS_T_c_2021_40.shp
# Number of data rows for BBS, T_c, 41: 1
# Shapefile for BBS: T_c for period 41 of year 2021 has been saved as SHP_BBS_T_c_2021_41.shp
# Number of data rows for BBS, T_c, 42: 1
# Shapefile for BBS: T_c for period 42 of year 2021 has been saved as SHP_BBS_T_c_2021_42.shp
# Number of data rows for BBS, T_c, 43: 1
# Shapefile for BBS: T_c for period 43 of year 2021 has been saved as SHP_BBS_T_c_2021_43.shp
# Number of data rows for BBS, T_c, 44: 1
# Shapefile for BBS: T_c for period 44 of year 2021 has been saved as SHP_BBS_T_c_2021_44.shp
# Number of data rows for BBS, T_c, 45: 1
# Shapefile for BBS: T_c for period 45 of year 2021 has been saved as SHP_BBS_T_c_2021_45.shp
# Number of data rows for BBS, T_c, 46: 1
# Shapefile for BBS: T_c for period 46 of year 2021 has been saved as SHP_BBS_T_c_2021_46.shp
# Number of data rows for BBS, T_c, 47: 1
# Shapefile for BBS: T_c for period 47 of year 2021 has been saved as SHP_BBS_T_c_2021_47.shp
# Number of data rows for BBS, T_c, 48: 2
# Shapefile for BBS: T_c for period 48 of year 2021 has been saved as SHP_BBS_T_c_2021_48.shp
# Number of data rows for BBS, T_c, 49: 1
# Shapefile for BBS: T_c for period 49 of year 2021 has been saved as SHP_BBS_T_c_2021_49.shp
# Number of data rows for BBS, T_c, 50: 1
# Shapefile for BBS: T_c for period 50 of year 2021 has been saved as SHP_BBS_T_c_2021_50.shp
# Number of data rows for BBS, T_c, 51: 1
# Shapefile for BBS: T_c for period 51 of year 2021 has been saved as SHP_BBS_T_c_2021_51.shp
# Number of data rows for BBS, T_c, 52: 2
# Shapefile for BBS: T_c for period 52 of year 2021 has been saved as SHP_BBS_T_c_2021_52.shp
# Number of data rows for BB, DO_mgl, 1: 4
# Shapefile for BB: DO_mgl for period 1 of year 2022 has been saved as SHP_BB_DO_mgl_2022_1.shp
# Number of data rows for BB, DO_mgl, 2: 4
# Shapefile for BB: DO_mgl for period 2 of year 2022 has been saved as SHP_BB_DO_mgl_2022_2.shp
# Number of data rows for BB, DO_mgl, 3: 5
# Shapefile for BB: DO_mgl for period 3 of year 2022 has been saved as SHP_BB_DO_mgl_2022_3.shp
# Number of data rows for BB, DO_mgl, 4: 6
# Shapefile for BB: DO_mgl for period 4 of year 2022 has been saved as SHP_BB_DO_mgl_2022_4.shp
# Number of data rows for BB, DO_mgl, 5: 6
# Shapefile for BB: DO_mgl for period 5 of year 2022 has been saved as SHP_BB_DO_mgl_2022_5.shp
# Number of data rows for BB, DO_mgl, 6: 6
# Shapefile for BB: DO_mgl for period 6 of year 2022 has been saved as SHP_BB_DO_mgl_2022_6.shp
# Number of data rows for BB, DO_mgl, 7: 5
# Shapefile for BB: DO_mgl for period 7 of year 2022 has been saved as SHP_BB_DO_mgl_2022_7.shp
# Number of data rows for BB, DO_mgl, 8: 5
# Shapefile for BB: DO_mgl for period 8 of year 2022 has been saved as SHP_BB_DO_mgl_2022_8.shp
# Number of data rows for BB, DO_mgl, 9: 6
# Shapefile for BB: DO_mgl for period 9 of year 2022 has been saved as SHP_BB_DO_mgl_2022_9.shp
# Number of data rows for BB, DO_mgl, 10: 6
# Shapefile for BB: DO_mgl for period 10 of year 2022 has been saved as SHP_BB_DO_mgl_2022_10.shp
# Number of data rows for BB, DO_mgl, 11: 6
# Shapefile for BB: DO_mgl for period 11 of year 2022 has been saved as SHP_BB_DO_mgl_2022_11.shp
# Number of data rows for BB, DO_mgl, 12: 6
# Shapefile for BB: DO_mgl for period 12 of year 2022 has been saved as SHP_BB_DO_mgl_2022_12.shp
# Number of data rows for BB, DO_mgl, 13: 6
# Shapefile for BB: DO_mgl for period 13 of year 2022 has been saved as SHP_BB_DO_mgl_2022_13.shp
# Number of data rows for BB, DO_mgl, 14: 6
# Shapefile for BB: DO_mgl for period 14 of year 2022 has been saved as SHP_BB_DO_mgl_2022_14.shp
# Number of data rows for BB, DO_mgl, 15: 6
# Shapefile for BB: DO_mgl for period 15 of year 2022 has been saved as SHP_BB_DO_mgl_2022_15.shp
# Number of data rows for BB, DO_mgl, 16: 6
# Shapefile for BB: DO_mgl for period 16 of year 2022 has been saved as SHP_BB_DO_mgl_2022_16.shp
# Number of data rows for BB, DO_mgl, 17: 6
# Shapefile for BB: DO_mgl for period 17 of year 2022 has been saved as SHP_BB_DO_mgl_2022_17.shp
# Number of data rows for BB, DO_mgl, 18: 5
# Shapefile for BB: DO_mgl for period 18 of year 2022 has been saved as SHP_BB_DO_mgl_2022_18.shp
# Number of data rows for BB, DO_mgl, 19: 5
# Shapefile for BB: DO_mgl for period 19 of year 2022 has been saved as SHP_BB_DO_mgl_2022_19.shp
# Number of data rows for BB, DO_mgl, 20: 5
# Shapefile for BB: DO_mgl for period 20 of year 2022 has been saved as SHP_BB_DO_mgl_2022_20.shp
# Number of data rows for BB, DO_mgl, 21: 5
# Shapefile for BB: DO_mgl for period 21 of year 2022 has been saved as SHP_BB_DO_mgl_2022_21.shp
# Number of data rows for BB, DO_mgl, 22: 5
# Shapefile for BB: DO_mgl for period 22 of year 2022 has been saved as SHP_BB_DO_mgl_2022_22.shp
# Number of data rows for BB, DO_mgl, 23: 5
# Shapefile for BB: DO_mgl for period 23 of year 2022 has been saved as SHP_BB_DO_mgl_2022_23.shp
# Number of data rows for BB, DO_mgl, 24: 5
# Shapefile for BB: DO_mgl for period 24 of year 2022 has been saved as SHP_BB_DO_mgl_2022_24.shp
# Number of data rows for BB, DO_mgl, 25: 6
# Shapefile for BB: DO_mgl for period 25 of year 2022 has been saved as SHP_BB_DO_mgl_2022_25.shp
# Number of data rows for BB, DO_mgl, 26: 6
# Shapefile for BB: DO_mgl for period 26 of year 2022 has been saved as SHP_BB_DO_mgl_2022_26.shp
# Number of data rows for BB, DO_mgl, 27: 6
# Shapefile for BB: DO_mgl for period 27 of year 2022 has been saved as SHP_BB_DO_mgl_2022_27.shp
# Number of data rows for BB, DO_mgl, 28: 6
# Shapefile for BB: DO_mgl for period 28 of year 2022 has been saved as SHP_BB_DO_mgl_2022_28.shp
# Number of data rows for BB, DO_mgl, 29: 6
# Shapefile for BB: DO_mgl for period 29 of year 2022 has been saved as SHP_BB_DO_mgl_2022_29.shp
# Number of data rows for BB, DO_mgl, 30: 6
# Shapefile for BB: DO_mgl for period 30 of year 2022 has been saved as SHP_BB_DO_mgl_2022_30.shp
# Number of data rows for BB, DO_mgl, 31: 6
# Shapefile for BB: DO_mgl for period 31 of year 2022 has been saved as SHP_BB_DO_mgl_2022_31.shp
# Number of data rows for BB, DO_mgl, 32: 6
# Shapefile for BB: DO_mgl for period 32 of year 2022 has been saved as SHP_BB_DO_mgl_2022_32.shp
# Number of data rows for BB, DO_mgl, 33: 6
# Shapefile for BB: DO_mgl for period 33 of year 2022 has been saved as SHP_BB_DO_mgl_2022_33.shp
# Number of data rows for BB, DO_mgl, 34: 6
# Shapefile for BB: DO_mgl for period 34 of year 2022 has been saved as SHP_BB_DO_mgl_2022_34.shp
# Number of data rows for BB, DO_mgl, 35: 5
# Shapefile for BB: DO_mgl for period 35 of year 2022 has been saved as SHP_BB_DO_mgl_2022_35.shp
# Number of data rows for BB, DO_mgl, 36: 5
# Shapefile for BB: DO_mgl for period 36 of year 2022 has been saved as SHP_BB_DO_mgl_2022_36.shp
# Number of data rows for BB, DO_mgl, 37: 6
# Shapefile for BB: DO_mgl for period 37 of year 2022 has been saved as SHP_BB_DO_mgl_2022_37.shp
# Number of data rows for BB, DO_mgl, 38: 6
# Shapefile for BB: DO_mgl for period 38 of year 2022 has been saved as SHP_BB_DO_mgl_2022_38.shp
# Number of data rows for BB, DO_mgl, 39: 12
# Shapefile for BB: DO_mgl for period 39 of year 2022 has been saved as SHP_BB_DO_mgl_2022_39.shp
# Number of data rows for BB, DO_mgl, 40: 6
# Shapefile for BB: DO_mgl for period 40 of year 2022 has been saved as SHP_BB_DO_mgl_2022_40.shp
# Number of data rows for BB, DO_mgl, 41: 6
# Shapefile for BB: DO_mgl for period 41 of year 2022 has been saved as SHP_BB_DO_mgl_2022_41.shp
# Number of data rows for BB, DO_mgl, 42: 5
# Shapefile for BB: DO_mgl for period 42 of year 2022 has been saved as SHP_BB_DO_mgl_2022_42.shp
# Number of data rows for BB, DO_mgl, 43: 5
# Shapefile for BB: DO_mgl for period 43 of year 2022 has been saved as SHP_BB_DO_mgl_2022_43.shp
# Number of data rows for BB, DO_mgl, 44: 10
# Shapefile for BB: DO_mgl for period 44 of year 2022 has been saved as SHP_BB_DO_mgl_2022_44.shp
# Number of data rows for BB, DO_mgl, 45: 6
# Shapefile for BB: DO_mgl for period 45 of year 2023 has been saved as SHP_BB_DO_mgl_2023_45.shp
# Number of data rows for BB, DO_mgl, 46: 6
# Shapefile for BB: DO_mgl for period 46 of year 2023 has been saved as SHP_BB_DO_mgl_2023_46.shp
# Number of data rows for BB, DO_mgl, 47: 6
# Shapefile for BB: DO_mgl for period 47 of year 2023 has been saved as SHP_BB_DO_mgl_2023_47.shp
# Number of data rows for BB, DO_mgl, 48: 6
# Shapefile for BB: DO_mgl for period 48 of year 2023 has been saved as SHP_BB_DO_mgl_2023_48.shp
# Number of data rows for BB, DO_mgl, 49: 6
# Shapefile for BB: DO_mgl for period 49 of year 2023 has been saved as SHP_BB_DO_mgl_2023_49.shp
# Number of data rows for BB, DO_mgl, 50: 6
# Shapefile for BB: DO_mgl for period 50 of year 2023 has been saved as SHP_BB_DO_mgl_2023_50.shp
# Number of data rows for BB, DO_mgl, 51: 6
# Shapefile for BB: DO_mgl for period 51 of year 2023 has been saved as SHP_BB_DO_mgl_2023_51.shp
# Number of data rows for BB, DO_mgl, 52: 12
# Shapefile for BB: DO_mgl for period 52 of year 2023 has been saved as SHP_BB_DO_mgl_2023_52.shp
# Number of data rows for BB, Sal_ppt, 1: 4
# Shapefile for BB: Sal_ppt for period 1 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_1.shp
# Number of data rows for BB, Sal_ppt, 2: 4
# Shapefile for BB: Sal_ppt for period 2 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_2.shp
# Number of data rows for BB, Sal_ppt, 3: 5
# Shapefile for BB: Sal_ppt for period 3 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_3.shp
# Number of data rows for BB, Sal_ppt, 4: 6
# Shapefile for BB: Sal_ppt for period 4 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_4.shp
# Number of data rows for BB, Sal_ppt, 5: 6
# Shapefile for BB: Sal_ppt for period 5 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_5.shp
# Number of data rows for BB, Sal_ppt, 6: 6
# Shapefile for BB: Sal_ppt for period 6 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_6.shp
# Number of data rows for BB, Sal_ppt, 7: 5
# Shapefile for BB: Sal_ppt for period 7 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_7.shp
# Number of data rows for BB, Sal_ppt, 8: 5
# Shapefile for BB: Sal_ppt for period 8 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_8.shp
# Number of data rows for BB, Sal_ppt, 9: 6
# Shapefile for BB: Sal_ppt for period 9 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_9.shp
# Number of data rows for BB, Sal_ppt, 10: 6
# Shapefile for BB: Sal_ppt for period 10 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_10.shp
# Number of data rows for BB, Sal_ppt, 11: 6
# Shapefile for BB: Sal_ppt for period 11 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_11.shp
# Number of data rows for BB, Sal_ppt, 12: 6
# Shapefile for BB: Sal_ppt for period 12 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_12.shp
# Number of data rows for BB, Sal_ppt, 13: 6
# Shapefile for BB: Sal_ppt for period 13 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_13.shp
# Number of data rows for BB, Sal_ppt, 14: 6
# Shapefile for BB: Sal_ppt for period 14 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_14.shp
# Number of data rows for BB, Sal_ppt, 15: 6
# Shapefile for BB: Sal_ppt for period 15 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_15.shp
# Number of data rows for BB, Sal_ppt, 16: 6
# Shapefile for BB: Sal_ppt for period 16 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_16.shp
# Number of data rows for BB, Sal_ppt, 17: 6
# Shapefile for BB: Sal_ppt for period 17 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_17.shp
# Number of data rows for BB, Sal_ppt, 18: 5
# Shapefile for BB: Sal_ppt for period 18 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_18.shp
# Number of data rows for BB, Sal_ppt, 19: 5
# Shapefile for BB: Sal_ppt for period 19 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_19.shp
# Number of data rows for BB, Sal_ppt, 20: 5
# Shapefile for BB: Sal_ppt for period 20 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_20.shp
# Number of data rows for BB, Sal_ppt, 21: 5
# Shapefile for BB: Sal_ppt for period 21 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_21.shp
# Number of data rows for BB, Sal_ppt, 22: 5
# Shapefile for BB: Sal_ppt for period 22 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_22.shp
# Number of data rows for BB, Sal_ppt, 23: 5
# Shapefile for BB: Sal_ppt for period 23 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_23.shp
# Number of data rows for BB, Sal_ppt, 24: 5
# Shapefile for BB: Sal_ppt for period 24 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_24.shp
# Number of data rows for BB, Sal_ppt, 25: 6
# Shapefile for BB: Sal_ppt for period 25 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_25.shp
# Number of data rows for BB, Sal_ppt, 26: 6
# Shapefile for BB: Sal_ppt for period 26 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_26.shp
# Number of data rows for BB, Sal_ppt, 27: 6
# Shapefile for BB: Sal_ppt for period 27 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_27.shp
# Number of data rows for BB, Sal_ppt, 28: 6
# Shapefile for BB: Sal_ppt for period 28 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_28.shp
# Number of data rows for BB, Sal_ppt, 29: 6
# Shapefile for BB: Sal_ppt for period 29 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_29.shp
# Number of data rows for BB, Sal_ppt, 30: 6
# Shapefile for BB: Sal_ppt for period 30 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_30.shp
# Number of data rows for BB, Sal_ppt, 31: 6
# Shapefile for BB: Sal_ppt for period 31 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_31.shp
# Number of data rows for BB, Sal_ppt, 32: 6
# Shapefile for BB: Sal_ppt for period 32 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_32.shp
# Number of data rows for BB, Sal_ppt, 33: 6
# Shapefile for BB: Sal_ppt for period 33 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_33.shp
# Number of data rows for BB, Sal_ppt, 34: 6
# Shapefile for BB: Sal_ppt for period 34 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_34.shp
# Number of data rows for BB, Sal_ppt, 35: 5
# Shapefile for BB: Sal_ppt for period 35 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_35.shp
# Number of data rows for BB, Sal_ppt, 36: 5
# Shapefile for BB: Sal_ppt for period 36 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_36.shp
# Number of data rows for BB, Sal_ppt, 37: 6
# Shapefile for BB: Sal_ppt for period 37 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_37.shp
# Number of data rows for BB, Sal_ppt, 38: 6
# Shapefile for BB: Sal_ppt for period 38 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_38.shp
# Number of data rows for BB, Sal_ppt, 39: 12
# Shapefile for BB: Sal_ppt for period 39 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_39.shp
# Number of data rows for BB, Sal_ppt, 40: 6
# Shapefile for BB: Sal_ppt for period 40 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_40.shp
# Number of data rows for BB, Sal_ppt, 41: 6
# Shapefile for BB: Sal_ppt for period 41 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_41.shp
# Number of data rows for BB, Sal_ppt, 42: 5
# Shapefile for BB: Sal_ppt for period 42 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_42.shp
# Number of data rows for BB, Sal_ppt, 43: 5
# Shapefile for BB: Sal_ppt for period 43 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_43.shp
# Number of data rows for BB, Sal_ppt, 44: 10
# Shapefile for BB: Sal_ppt for period 44 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_44.shp
# Number of data rows for BB, Sal_ppt, 45: 6
# Shapefile for BB: Sal_ppt for period 45 of year 2023 has been saved as SHP_BB_Sal_ppt_2023_45.shp
# Number of data rows for BB, Sal_ppt, 46: 5
# Shapefile for BB: Sal_ppt for period 46 of year 2023 has been saved as SHP_BB_Sal_ppt_2023_46.shp
# Number of data rows for BB, Sal_ppt, 47: 5
# Shapefile for BB: Sal_ppt for period 47 of year 2023 has been saved as SHP_BB_Sal_ppt_2023_47.shp
# Number of data rows for BB, Sal_ppt, 48: 6
# Shapefile for BB: Sal_ppt for period 48 of year 2023 has been saved as SHP_BB_Sal_ppt_2023_48.shp
# Number of data rows for BB, Sal_ppt, 49: 6
# Shapefile for BB: Sal_ppt for period 49 of year 2023 has been saved as SHP_BB_Sal_ppt_2023_49.shp
# Number of data rows for BB, Sal_ppt, 50: 6
# Shapefile for BB: Sal_ppt for period 50 of year 2023 has been saved as SHP_BB_Sal_ppt_2023_50.shp
# Number of data rows for BB, Sal_ppt, 51: 6
# Shapefile for BB: Sal_ppt for period 51 of year 2023 has been saved as SHP_BB_Sal_ppt_2023_51.shp
# Number of data rows for BB, Sal_ppt, 52: 12
# Shapefile for BB: Sal_ppt for period 52 of year 2023 has been saved as SHP_BB_Sal_ppt_2023_52.shp
# Number of data rows for BB, Turb_ntu, 1: 4
# Shapefile for BB: Turb_ntu for period 1 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_1.shp
# Number of data rows for BB, Turb_ntu, 2: 4
# Shapefile for BB: Turb_ntu for period 2 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_2.shp
# Number of data rows for BB, Turb_ntu, 3: 5
# Shapefile for BB: Turb_ntu for period 3 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_3.shp
# Number of data rows for BB, Turb_ntu, 4: 6
# Shapefile for BB: Turb_ntu for period 4 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_4.shp
# Number of data rows for BB, Turb_ntu, 5: 6
# Shapefile for BB: Turb_ntu for period 5 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_5.shp
# Number of data rows for BB, Turb_ntu, 6: 6
# Shapefile for BB: Turb_ntu for period 6 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_6.shp
# Number of data rows for BB, Turb_ntu, 7: 5
# Shapefile for BB: Turb_ntu for period 7 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_7.shp
# Number of data rows for BB, Turb_ntu, 8: 5
# Shapefile for BB: Turb_ntu for period 8 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_8.shp
# Number of data rows for BB, Turb_ntu, 9: 6
# Shapefile for BB: Turb_ntu for period 9 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_9.shp
# Number of data rows for BB, Turb_ntu, 10: 5
# Shapefile for BB: Turb_ntu for period 10 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_10.shp
# Number of data rows for BB, Turb_ntu, 11: 6
# Shapefile for BB: Turb_ntu for period 11 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_11.shp
# Number of data rows for BB, Turb_ntu, 12: 6
# Shapefile for BB: Turb_ntu for period 12 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_12.shp
# Number of data rows for BB, Turb_ntu, 13: 6
# Shapefile for BB: Turb_ntu for period 13 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_13.shp
# Number of data rows for BB, Turb_ntu, 14: 6
# Shapefile for BB: Turb_ntu for period 14 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_14.shp
# Number of data rows for BB, Turb_ntu, 15: 6
# Shapefile for BB: Turb_ntu for period 15 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_15.shp
# Number of data rows for BB, Turb_ntu, 16: 6
# Shapefile for BB: Turb_ntu for period 16 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_16.shp
# Number of data rows for BB, Turb_ntu, 17: 6
# Shapefile for BB: Turb_ntu for period 17 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_17.shp
# Number of data rows for BB, Turb_ntu, 18: 5
# Shapefile for BB: Turb_ntu for period 18 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_18.shp
# Number of data rows for BB, Turb_ntu, 19: 5
# Shapefile for BB: Turb_ntu for period 19 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_19.shp
# Number of data rows for BB, Turb_ntu, 20: 5
# Shapefile for BB: Turb_ntu for period 20 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_20.shp
# Number of data rows for BB, Turb_ntu, 21: 5
# Shapefile for BB: Turb_ntu for period 21 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_21.shp
# Number of data rows for BB, Turb_ntu, 22: 5
# Shapefile for BB: Turb_ntu for period 22 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_22.shp
# Number of data rows for BB, Turb_ntu, 23: 5
# Shapefile for BB: Turb_ntu for period 23 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_23.shp
# Number of data rows for BB, Turb_ntu, 24: 5
# Shapefile for BB: Turb_ntu for period 24 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_24.shp
# Number of data rows for BB, Turb_ntu, 25: 6
# Shapefile for BB: Turb_ntu for period 25 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_25.shp
# Number of data rows for BB, Turb_ntu, 26: 6
# Shapefile for BB: Turb_ntu for period 26 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_26.shp
# Number of data rows for BB, Turb_ntu, 27: 6
# Shapefile for BB: Turb_ntu for period 27 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_27.shp
# Number of data rows for BB, Turb_ntu, 28: 6
# Shapefile for BB: Turb_ntu for period 28 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_28.shp
# Number of data rows for BB, Turb_ntu, 29: 6
# Shapefile for BB: Turb_ntu for period 29 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_29.shp
# Number of data rows for BB, Turb_ntu, 30: 6
# Shapefile for BB: Turb_ntu for period 30 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_30.shp
# Number of data rows for BB, Turb_ntu, 31: 6
# Shapefile for BB: Turb_ntu for period 31 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_31.shp
# Number of data rows for BB, Turb_ntu, 32: 6
# Shapefile for BB: Turb_ntu for period 32 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_32.shp
# Number of data rows for BB, Turb_ntu, 33: 6
# Shapefile for BB: Turb_ntu for period 33 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_33.shp
# Number of data rows for BB, Turb_ntu, 34: 6
# ...
# Number of data rows for GTM, Sal_ppt, 30: 4
# Shapefile for GTM: Sal_ppt for period 30 of year 2016 has been saved as SHP_GTM_Sal_ppt_2016_30.shp
# Number of data rows for GTM, Sal_ppt, 31: 3
# Shapefile for GTM: Sal_ppt for period 31 of year 2016 has been saved as SHP_GTM_Sal_ppt_2016_31.shp
# Number of data rows for GTM, Sal_ppt, 32: 4
# Shapefile for GTM: Sal_ppt for period 32 of year 2016 has been saved as SHP_GTM_Sal_ppt_2016_32.shp
# Number of data rows for GTM, Sal_ppt, 33: 4
# Shapefile for GTM: Sal_ppt for period 33 of year 2016 has been saved as SHP_GTM_Sal_ppt_2016_33.shp
# Number of data rows for GTM, Sal_ppt, 34: 4
# Shapefile for GTM: Sal_ppt for period 34 of year 2016 has been saved as SHP_GTM_Sal_ppt_2016_34.shp
# Number of data rows for GTM, Sal_ppt, 35: 8
# Shapefile for GTM: Sal_ppt for period 35 of year 2016 has been saved as SHP_GTM_Sal_ppt_2016_35.shp
# Number of data rows for GTM, Sal_ppt, 36: 4
# Shapefile for GTM: Sal_ppt for period 36 of year 2016 has been saved as SHP_GTM_Sal_ppt_2016_36.shp
# Number of data rows for GTM, Sal_ppt, 37: 4
# Shapefile for GTM: Sal_ppt for period 37 of year 2016 has been saved as SHP_GTM_Sal_ppt_2016_37.shp
# Number of data rows for GTM, Sal_ppt, 38: 4
# Shapefile for GTM: Sal_ppt for period 38 of year 2016 has been saved as SHP_GTM_Sal_ppt_2016_38.shp
# Number of data rows for GTM, Sal_ppt, 39: 8
# Shapefile for GTM: Sal_ppt for period 39 of year 2016 has been saved as SHP_GTM_Sal_ppt_2016_39.shp
# No valid data found for area: GTM, parameter: Sal_ppt, period: 40
# No valid data found for area: GTM, parameter: Sal_ppt, period: 41
# No valid data found for area: GTM, parameter: Sal_ppt, period: 42
# No valid data found for area: GTM, parameter: Sal_ppt, period: 43
# No valid data found for area: GTM, parameter: Sal_ppt, period: 44
# No valid data found for area: GTM, parameter: Sal_ppt, period: 45
# No valid data found for area: GTM, parameter: Sal_ppt, period: 46
# No valid data found for area: GTM, parameter: Sal_ppt, period: 47
# Number of data rows for GTM, Sal_ppt, 48: 4
# Shapefile for GTM: Sal_ppt for period 48 of year 2017 has been saved as SHP_GTM_Sal_ppt_2017_48.shp
# Number of data rows for GTM, Sal_ppt, 49: 4
# Shapefile for GTM: Sal_ppt for period 49 of year 2017 has been saved as SHP_GTM_Sal_ppt_2017_49.shp
# Number of data rows for GTM, Sal_ppt, 50: 4
# Shapefile for GTM: Sal_ppt for period 50 of year 2017 has been saved as SHP_GTM_Sal_ppt_2017_50.shp
# Number of data rows for GTM, Sal_ppt, 51: 4
# Shapefile for GTM: Sal_ppt for period 51 of year 2017 has been saved as SHP_GTM_Sal_ppt_2017_51.shp
# Number of data rows for GTM, Sal_ppt, 52: 4
# Shapefile for GTM: Sal_ppt for period 52 of year 2017 has been saved as SHP_GTM_Sal_ppt_2017_52.shp
# Number of data rows for GTM, Turb_ntu, 1: 4
# Shapefile for GTM: Turb_ntu for period 1 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_1.shp
# Number of data rows for GTM, Turb_ntu, 2: 4
# Shapefile for GTM: Turb_ntu for period 2 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_2.shp
# Number of data rows for GTM, Turb_ntu, 3: 4
# Shapefile for GTM: Turb_ntu for period 3 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_3.shp
# Number of data rows for GTM, Turb_ntu, 4: 4
# Shapefile for GTM: Turb_ntu for period 4 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_4.shp
# Number of data rows for GTM, Turb_ntu, 5: 4
# Shapefile for GTM: Turb_ntu for period 5 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_5.shp
# Number of data rows for GTM, Turb_ntu, 6: 4
# Shapefile for GTM: Turb_ntu for period 6 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_6.shp
# Number of data rows for GTM, Turb_ntu, 7: 4
# Shapefile for GTM: Turb_ntu for period 7 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_7.shp
# Number of data rows for GTM, Turb_ntu, 8: 4
# Shapefile for GTM: Turb_ntu for period 8 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_8.shp
# Number of data rows for GTM, Turb_ntu, 9: 4
# Shapefile for GTM: Turb_ntu for period 9 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_9.shp
# Number of data rows for GTM, Turb_ntu, 10: 8
# Shapefile for GTM: Turb_ntu for period 10 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_10.shp
# Number of data rows for GTM, Turb_ntu, 11: 4
# Shapefile for GTM: Turb_ntu for period 11 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_11.shp
# Number of data rows for GTM, Turb_ntu, 12: 4
# Shapefile for GTM: Turb_ntu for period 12 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_12.shp
# Number of data rows for GTM, Turb_ntu, 13: 4
# Shapefile for GTM: Turb_ntu for period 13 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_13.shp
# Number of data rows for GTM, Turb_ntu, 14: 4
# Shapefile for GTM: Turb_ntu for period 14 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_14.shp
# Number of data rows for GTM, Turb_ntu, 15: 4
# Shapefile for GTM: Turb_ntu for period 15 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_15.shp
# Number of data rows for GTM, Turb_ntu, 16: 4
# Shapefile for GTM: Turb_ntu for period 16 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_16.shp
# Number of data rows for GTM, Turb_ntu, 17: 3
# Shapefile for GTM: Turb_ntu for period 17 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_17.shp
# Number of data rows for GTM, Turb_ntu, 18: 4
# Shapefile for GTM: Turb_ntu for period 18 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_18.shp
# Number of data rows for GTM, Turb_ntu, 19: 4
# Shapefile for GTM: Turb_ntu for period 19 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_19.shp
# Number of data rows for GTM, Turb_ntu, 20: 4
# Shapefile for GTM: Turb_ntu for period 20 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_20.shp
# Number of data rows for GTM, Turb_ntu, 21: 4
# Shapefile for GTM: Turb_ntu for period 21 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_21.shp
# Number of data rows for GTM, Turb_ntu, 22: 4
# Shapefile for GTM: Turb_ntu for period 22 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_22.shp
# Number of data rows for GTM, Turb_ntu, 23: 8
# Shapefile for GTM: Turb_ntu for period 23 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_23.shp
# Number of data rows for GTM, Turb_ntu, 24: 4
# Shapefile for GTM: Turb_ntu for period 24 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_24.shp
# Number of data rows for GTM, Turb_ntu, 25: 4
# Shapefile for GTM: Turb_ntu for period 25 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_25.shp
# Number of data rows for GTM, Turb_ntu, 26: 4
# Shapefile for GTM: Turb_ntu for period 26 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_26.shp
# Number of data rows for GTM, Turb_ntu, 27: 4
# Shapefile for GTM: Turb_ntu for period 27 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_27.shp
# Number of data rows for GTM, Turb_ntu, 28: 4
# Shapefile for GTM: Turb_ntu for period 28 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_28.shp
# Number of data rows for GTM, Turb_ntu, 29: 4
# Shapefile for GTM: Turb_ntu for period 29 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_29.shp
# Number of data rows for GTM, Turb_ntu, 30: 4
# Shapefile for GTM: Turb_ntu for period 30 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_30.shp
# Number of data rows for GTM, Turb_ntu, 31: 3
# Shapefile for GTM: Turb_ntu for period 31 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_31.shp
# Number of data rows for GTM, Turb_ntu, 32: 4
# Shapefile for GTM: Turb_ntu for period 32 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_32.shp
# Number of data rows for GTM, Turb_ntu, 33: 4
# Shapefile for GTM: Turb_ntu for period 33 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_33.shp
# Number of data rows for GTM, Turb_ntu, 34: 4
# Shapefile for GTM: Turb_ntu for period 34 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_34.shp
# Number of data rows for GTM, Turb_ntu, 35: 8
# Shapefile for GTM: Turb_ntu for period 35 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_35.shp
# Number of data rows for GTM, Turb_ntu, 36: 4
# Shapefile for GTM: Turb_ntu for period 36 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_36.shp
# Number of data rows for GTM, Turb_ntu, 37: 4
# Shapefile for GTM: Turb_ntu for period 37 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_37.shp
# Number of data rows for GTM, Turb_ntu, 38: 4
# Shapefile for GTM: Turb_ntu for period 38 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_38.shp
# Number of data rows for GTM, Turb_ntu, 39: 8
# Shapefile for GTM: Turb_ntu for period 39 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_39.shp
# No valid data found for area: GTM, parameter: Turb_ntu, period: 40
# No valid data found for area: GTM, parameter: Turb_ntu, period: 41
# No valid data found for area: GTM, parameter: Turb_ntu, period: 42
# No valid data found for area: GTM, parameter: Turb_ntu, period: 43
# No valid data found for area: GTM, parameter: Turb_ntu, period: 44
# No valid data found for area: GTM, parameter: Turb_ntu, period: 45
# No valid data found for area: GTM, parameter: Turb_ntu, period: 46
# No valid data found for area: GTM, parameter: Turb_ntu, period: 47
# Number of data rows for GTM, Turb_ntu, 48: 4
# Shapefile for GTM: Turb_ntu for period 48 of year 2017 has been saved as SHP_GTM_Turb_ntu_2017_48.shp
# Number of data rows for GTM, Turb_ntu, 49: 4
# Shapefile for GTM: Turb_ntu for period 49 of year 2017 has been saved as SHP_GTM_Turb_ntu_2017_49.shp
# Number of data rows for GTM, Turb_ntu, 50: 4
# Shapefile for GTM: Turb_ntu for period 50 of year 2017 has been saved as SHP_GTM_Turb_ntu_2017_50.shp
# Number of data rows for GTM, Turb_ntu, 51: 4
# Shapefile for GTM: Turb_ntu for period 51 of year 2017 has been saved as SHP_GTM_Turb_ntu_2017_51.shp
# Number of data rows for GTM, Turb_ntu, 52: 4
# Shapefile for GTM: Turb_ntu for period 52 of year 2017 has been saved as SHP_GTM_Turb_ntu_2017_52.shp
# Number of data rows for GTM, T_c, 1: 4
# Shapefile for GTM: T_c for period 1 of year 2016 has been saved as SHP_GTM_T_c_2016_1.shp
# Number of data rows for GTM, T_c, 2: 4
# Shapefile for GTM: T_c for period 2 of year 2016 has been saved as SHP_GTM_T_c_2016_2.shp
# Number of data rows for GTM, T_c, 3: 4
# Shapefile for GTM: T_c for period 3 of year 2016 has been saved as SHP_GTM_T_c_2016_3.shp
# Number of data rows for GTM, T_c, 4: 4
# Shapefile for GTM: T_c for period 4 of year 2016 has been saved as SHP_GTM_T_c_2016_4.shp
# Number of data rows for GTM, T_c, 5: 4
# Shapefile for GTM: T_c for period 5 of year 2016 has been saved as SHP_GTM_T_c_2016_5.shp
# Number of data rows for GTM, T_c, 6: 4
# Shapefile for GTM: T_c for period 6 of year 2016 has been saved as SHP_GTM_T_c_2016_6.shp
# Number of data rows for GTM, T_c, 7: 4
# Shapefile for GTM: T_c for period 7 of year 2016 has been saved as SHP_GTM_T_c_2016_7.shp
# Number of data rows for GTM, T_c, 8: 4
# Shapefile for GTM: T_c for period 8 of year 2016 has been saved as SHP_GTM_T_c_2016_8.shp
# Number of data rows for GTM, T_c, 9: 4
# Shapefile for GTM: T_c for period 9 of year 2016 has been saved as SHP_GTM_T_c_2016_9.shp
# Number of data rows for GTM, T_c, 10: 8
# Shapefile for GTM: T_c for period 10 of year 2016 has been saved as SHP_GTM_T_c_2016_10.shp
# Number of data rows for GTM, T_c, 11: 4
# Shapefile for GTM: T_c for period 11 of year 2016 has been saved as SHP_GTM_T_c_2016_11.shp
# Number of data rows for GTM, T_c, 12: 4
# Shapefile for GTM: T_c for period 12 of year 2016 has been saved as SHP_GTM_T_c_2016_12.shp
# Number of data rows for GTM, T_c, 13: 4
# Shapefile for GTM: T_c for period 13 of year 2016 has been saved as SHP_GTM_T_c_2016_13.shp
# Number of data rows for GTM, T_c, 14: 4
# Shapefile for GTM: T_c for period 14 of year 2016 has been saved as SHP_GTM_T_c_2016_14.shp
# Number of data rows for GTM, T_c, 15: 4
# Shapefile for GTM: T_c for period 15 of year 2016 has been saved as SHP_GTM_T_c_2016_15.shp
# Number of data rows for GTM, T_c, 16: 4
# Shapefile for GTM: T_c for period 16 of year 2016 has been saved as SHP_GTM_T_c_2016_16.shp
# Number of data rows for GTM, T_c, 17: 4
# Shapefile for GTM: T_c for period 17 of year 2016 has been saved as SHP_GTM_T_c_2016_17.shp
# Number of data rows for GTM, T_c, 18: 4
# Shapefile for GTM: T_c for period 18 of year 2016 has been saved as SHP_GTM_T_c_2016_18.shp
# Number of data rows for GTM, T_c, 19: 4
# Shapefile for GTM: T_c for period 19 of year 2016 has been saved as SHP_GTM_T_c_2016_19.shp
# Number of data rows for GTM, T_c, 20: 4
# Shapefile for GTM: T_c for period 20 of year 2016 has been saved as SHP_GTM_T_c_2016_20.shp
# Number of data rows for GTM, T_c, 21: 4
# Shapefile for GTM: T_c for period 21 of year 2016 has been saved as SHP_GTM_T_c_2016_21.shp
# Number of data rows for GTM, T_c, 22: 4
# Shapefile for GTM: T_c for period 22 of year 2016 has been saved as SHP_GTM_T_c_2016_22.shp
# Number of data rows for GTM, T_c, 23: 8
# Shapefile for GTM: T_c for period 23 of year 2016 has been saved as SHP_GTM_T_c_2016_23.shp
# Number of data rows for GTM, T_c, 24: 4
# Shapefile for GTM: T_c for period 24 of year 2016 has been saved as SHP_GTM_T_c_2016_24.shp
# Number of data rows for GTM, T_c, 25: 4
# Shapefile for GTM: T_c for period 25 of year 2016 has been saved as SHP_GTM_T_c_2016_25.shp
# Number of data rows for GTM, T_c, 26: 4
# Shapefile for GTM: T_c for period 26 of year 2016 has been saved as SHP_GTM_T_c_2016_26.shp
# Number of data rows for GTM, T_c, 27: 4
# Shapefile for GTM: T_c for period 27 of year 2016 has been saved as SHP_GTM_T_c_2016_27.shp
# Number of data rows for GTM, T_c, 28: 4
# Shapefile for GTM: T_c for period 28 of year 2016 has been saved as SHP_GTM_T_c_2016_28.shp
# Number of data rows for GTM, T_c, 29: 4
# Shapefile for GTM: T_c for period 29 of year 2016 has been saved as SHP_GTM_T_c_2016_29.shp
# Number of data rows for GTM, T_c, 30: 4
# Shapefile for GTM: T_c for period 30 of year 2016 has been saved as SHP_GTM_T_c_2016_30.shp
# Number of data rows for GTM, T_c, 31: 3
# Shapefile for GTM: T_c for period 31 of year 2016 has been saved as SHP_GTM_T_c_2016_31.shp
# Number of data rows for GTM, T_c, 32: 4
# Shapefile for GTM: T_c for period 32 of year 2016 has been saved as SHP_GTM_T_c_2016_32.shp
# Number of data rows for GTM, T_c, 33: 4
# Shapefile for GTM: T_c for period 33 of year 2016 has been saved as SHP_GTM_T_c_2016_33.shp
# Number of data rows for GTM, T_c, 34: 4
# Shapefile for GTM: T_c for period 34 of year 2016 has been saved as SHP_GTM_T_c_2016_34.shp
# Number of data rows for GTM, T_c, 35: 8
# Shapefile for GTM: T_c for period 35 of year 2016 has been saved as SHP_GTM_T_c_2016_35.shp
# Number of data rows for GTM, T_c, 36: 4
# Shapefile for GTM: T_c for period 36 of year 2016 has been saved as SHP_GTM_T_c_2016_36.shp
# Number of data rows for GTM, T_c, 37: 4
# Shapefile for GTM: T_c for period 37 of year 2016 has been saved as SHP_GTM_T_c_2016_37.shp
# Number of data rows for GTM, T_c, 38: 4
# Shapefile for GTM: T_c for period 38 of year 2016 has been saved as SHP_GTM_T_c_2016_38.shp
# Number of data rows for GTM, T_c, 39: 8
# Shapefile for GTM: T_c for period 39 of year 2016 has been saved as SHP_GTM_T_c_2016_39.shp
# No valid data found for area: GTM, parameter: T_c, period: 40
# No valid data found for area: GTM, parameter: T_c, period: 41
# No valid data found for area: GTM, parameter: T_c, period: 42
# No valid data found for area: GTM, parameter: T_c, period: 43
# No valid data found for area: GTM, parameter: T_c, period: 44
# No valid data found for area: GTM, parameter: T_c, period: 45
# No valid data found for area: GTM, parameter: T_c, period: 46
# No valid data found for area: GTM, parameter: T_c, period: 47
# Number of data rows for GTM, T_c, 48: 4
# Shapefile for GTM: T_c for period 48 of year 2017 has been saved as SHP_GTM_T_c_2017_48.shp
# Number of data rows for GTM, T_c, 49: 4
# Shapefile for GTM: T_c for period 49 of year 2017 has been saved as SHP_GTM_T_c_2017_49.shp
# Number of data rows for GTM, T_c, 50: 4
# Shapefile for GTM: T_c for period 50 of year 2017 has been saved as SHP_GTM_T_c_2017_50.shp
# Number of data rows for GTM, T_c, 51: 4
# Shapefile for GTM: T_c for period 51 of year 2017 has been saved as SHP_GTM_T_c_2017_51.shp
# Number of data rows for GTM, T_c, 52: 4
# Shapefile for GTM: T_c for period 52 of year 2017 has been saved as SHP_GTM_T_c_2017_52.shp

# %% [markdown]
# # 3. Run IDW for weeks <a class="anchor" id="reg_cv_idw"></a>

# %%
# Empty the shapefile folder
idw_rk_x.delete_all_files(idwCon_folder)

df_week_table
# Out:
#                     WaterBody          Parameter  Period Filename  \
# 0         Big Bend Seagrasses   Dissolved Oxygen       1
# 1         Big Bend Seagrasses   Dissolved Oxygen       2
# 2         Big Bend Seagrasses   Dissolved Oxygen       3
# 3         Big Bend Seagrasses   Dissolved Oxygen       4
# 4         Big Bend Seagrasses   Dissolved Oxygen       5
# ...                       ...                ...     ...      ...
# 1035  Guana Tolomato Matanzas  Water Temperature      48
# 1036  Guana Tolomato Matanzas  Water Temperature      49
# 1037  Guana Tolomato Matanzas  Water Temperature      50
# 1038  Guana Tolomato Matanzas  Water Temperature      51
# 1039  Guana Tolomato Matanzas  Water Temperature      52
#
#      NumDataPoints RMSE ME WbodyAcronym  startDate    endDate  Year
# 0                                   BBS 2021-01-06 2021-01-12  2021
# 1                                   BBS 2021-01-13 2021-01-19  2021
# 2                                   BBS 2021-01-20 2021-01-26  2021
# 3                                   BBS 2021-01-27 2021-02-02  2021
# 4                                   BBS 2021-02-03 2021-02-09  2021
# ...            ...  ... ..          ...        ...        ...   ...
# 1035                                GTM 2017-03-04 2017-03-11  2017
# 1036                                GTM 2017-03-11 2017-03-18  2017
# 1037                                GTM 2017-03-18 2017-03-25  2017
# 1038                                GTM 2017-03-25 2017-04-01  2017
# 1039                                GTM 2017-04-01 2017-04-08  2017
#
# [1040 rows x 11 columns]

# %%
# If the number of data points is less than 3，skipping calculate IDW
idw_rk_x.idw_interpolation1(df_week_table, shpCon_folder, idwCon_folder, waterbody_extent, barrier_folder)
# Out:
# Processing file: SHP_BBS_DO_mgl_2021_1.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_1.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_2.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_2.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_3.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_3.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_4.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_4.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_5.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_5.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_6.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_6.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_7.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_7.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_8.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_8.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_9.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_9.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_10.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_10.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_11.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_11.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_12.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_12.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_13.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_13.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_14.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_14.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_15.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_15.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_16.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_16.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_17.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_17.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_18.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_18.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_19.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_19.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_20.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_20.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_21.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_21.shp, skipping
# Shapefile not found for: SHP_BBS_DO_mgl_2021_22.shp
# Shapefile not found for: SHP_BBS_DO_mgl_2021_23.shp
# Shapefile not found for: SHP_BBS_DO_mgl_2021_24.shp
# Processing file: SHP_BBS_DO_mgl_2021_25.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_25.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_26.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_26.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_27.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_27.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_28.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_28.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_29.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_29.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_30.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_30.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_31.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_31.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_32.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_32.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_33.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_33.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_34.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_34.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_35.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_35.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_36.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_36.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_37.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_37.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_38.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_38.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_39.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_39.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_40.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_40.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_41.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_41.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_42.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_42.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_43.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_43.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_44.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_44.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_45.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_45.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_46.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_46.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_47.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_47.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_48.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_48.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_49.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_49.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_50.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_50.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_51.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_51.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_52.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_52.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_1.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_1.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_2.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_2.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_3.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_3.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_4.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_4.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_5.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_5.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_6.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_6.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_7.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_7.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_8.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_8.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_9.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_9.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_10.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_10.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_11.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_11.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_12.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_12.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_13.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_13.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_14.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_14.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_15.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_15.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_16.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_16.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_17.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_17.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_18.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_18.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_19.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_19.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_20.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_20.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_21.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_21.shp, skipping
# Shapefile not found for: SHP_BBS_Sal_ppt_2021_22.shp
# Shapefile not found for: SHP_BBS_Sal_ppt_2021_23.shp
# Shapefile not found for: SHP_BBS_Sal_ppt_2021_24.shp
# Processing file: SHP_BBS_Sal_ppt_2021_25.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_25.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_26.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_26.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_27.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_27.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_28.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_28.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_29.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_29.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_30.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_30.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_31.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_31.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_32.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_32.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_33.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_33.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_34.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_34.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_35.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_35.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_36.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_36.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_37.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_37.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_38.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_38.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_39.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_39.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_40.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_40.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_41.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_41.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_42.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_42.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_43.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_43.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_44.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_44.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_45.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_45.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_46.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_46.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_47.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_47.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_48.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_48.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_49.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_49.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_50.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_50.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_51.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_51.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_52.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_52.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_1.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_1.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_2.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_2.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_3.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_3.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_4.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_4.shp, skipping
# Shapefile not found for: SHP_BBS_Turb_ntu_2021_5.shp
# Processing file: SHP_BBS_Turb_ntu_2021_6.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_6.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_7.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_7.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_8.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_8.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_9.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_9.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_10.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_10.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_11.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_11.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_12.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_12.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_13.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_13.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_14.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_14.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_15.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_15.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_16.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_16.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_17.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_17.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_18.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_18.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_19.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_19.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_20.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_20.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_21.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_21.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_22.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_22.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_23.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_23.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_24.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_24.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_25.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_25.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_26.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_26.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_27.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_27.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_28.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_28.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_29.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_29.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_30.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_30.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_31.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_31.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_32.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_32.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_33.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_33.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_34.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_34.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_35.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_35.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_36.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_36.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_37.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_37.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_38.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_38.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_39.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_39.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_40.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_40.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_41.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_41.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_42.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_42.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_43.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_43.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_44.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_44.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_45.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_45.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_46.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_46.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_47.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_47.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_48.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_48.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_49.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_49.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_50.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_50.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_51.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_51.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_52.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_52.shp, skipping
# Processing file: SHP_BBS_T_c_2021_1.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_1.shp, skipping
# Processing file: SHP_BBS_T_c_2021_2.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_2.shp, skipping
# Processing file: SHP_BBS_T_c_2021_3.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_3.shp, skipping
# Processing file: SHP_BBS_T_c_2021_4.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_4.shp, skipping
# Processing file: SHP_BBS_T_c_2021_5.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_5.shp, skipping
# Processing file: SHP_BBS_T_c_2021_6.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_6.shp, skipping
# Processing file: SHP_BBS_T_c_2021_7.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_7.shp, skipping
# Processing file: SHP_BBS_T_c_2021_8.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_8.shp, skipping
# Processing file: SHP_BBS_T_c_2021_9.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_9.shp, skipping
# Processing file: SHP_BBS_T_c_2021_10.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_10.shp, skipping
# Processing file: SHP_BBS_T_c_2021_11.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_11.shp, skipping
# Processing file: SHP_BBS_T_c_2021_12.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_12.shp, skipping
# Processing file: SHP_BBS_T_c_2021_13.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_13.shp, skipping
# Processing file: SHP_BBS_T_c_2021_14.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_14.shp, skipping
# Processing file: SHP_BBS_T_c_2021_15.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_15.shp, skipping
# Processing file: SHP_BBS_T_c_2021_16.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_16.shp, skipping
# Processing file: SHP_BBS_T_c_2021_17.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_17.shp, skipping
# Processing file: SHP_BBS_T_c_2021_18.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_18.shp, skipping
# Processing file: SHP_BBS_T_c_2021_19.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_19.shp, skipping
# Processing file: SHP_BBS_T_c_2021_20.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_20.shp, skipping
# Processing file: SHP_BBS_T_c_2021_21.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_21.shp, skipping
# Processing file: SHP_BBS_T_c_2021_22.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_22.shp, skipping
# Processing file: SHP_BBS_T_c_2021_23.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_23.shp, skipping
# Processing file: SHP_BBS_T_c_2021_24.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_24.shp, skipping
# Processing file: SHP_BBS_T_c_2021_25.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_25.shp, skipping
# Processing file: SHP_BBS_T_c_2021_26.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_26.shp, skipping
# Processing file: SHP_BBS_T_c_2021_27.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_27.shp, skipping
# Processing file: SHP_BBS_T_c_2021_28.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_28.shp, skipping
# Processing file: SHP_BBS_T_c_2021_29.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_29.shp, skipping
# Processing file: SHP_BBS_T_c_2021_30.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_30.shp, skipping
# Processing file: SHP_BBS_T_c_2021_31.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_31.shp, skipping
# Processing file: SHP_BBS_T_c_2021_32.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_32.shp, skipping
# Processing file: SHP_BBS_T_c_2021_33.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_33.shp, skipping
# Processing file: SHP_BBS_T_c_2021_34.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_34.shp, skipping
# Processing file: SHP_BBS_T_c_2021_35.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_35.shp, skipping
# Processing file: SHP_BBS_T_c_2021_36.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_36.shp, skipping
# Processing file: SHP_BBS_T_c_2021_37.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_37.shp, skipping
# Processing file: SHP_BBS_T_c_2021_38.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_38.shp, skipping
# Processing file: SHP_BBS_T_c_2021_39.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_39.shp, skipping
# Processing file: SHP_BBS_T_c_2021_40.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_40.shp, skipping
# Processing file: SHP_BBS_T_c_2021_41.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_41.shp, skipping
# Processing file: SHP_BBS_T_c_2021_42.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_42.shp, skipping
# Processing file: SHP_BBS_T_c_2021_43.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_43.shp, skipping
# Processing file: SHP_BBS_T_c_2021_44.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_44.shp, skipping
# Processing file: SHP_BBS_T_c_2021_45.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_45.shp, skipping
# Processing file: SHP_BBS_T_c_2021_46.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_46.shp, skipping
# Processing file: SHP_BBS_T_c_2021_47.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_47.shp, skipping
# Processing file: SHP_BBS_T_c_2021_48.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_48.shp, skipping
# Processing file: SHP_BBS_T_c_2021_49.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_49.shp, skipping
# Processing file: SHP_BBS_T_c_2021_50.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_50.shp, skipping
# Processing file: SHP_BBS_T_c_2021_51.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_51.shp, skipping
# Processing file: SHP_BBS_T_c_2021_52.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_52.shp, skipping
# Processing file: SHP_BB_DO_mgl_2022_1.shp
# File SHP_BB_DO_mgl_2022_1.shp has completed 4 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_2.shp
# File SHP_BB_DO_mgl_2022_2.shp has completed 4 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_3.shp
# File SHP_BB_DO_mgl_2022_3.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_4.shp
# File SHP_BB_DO_mgl_2022_4.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_5.shp
# File SHP_BB_DO_mgl_2022_5.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_6.shp
# File SHP_BB_DO_mgl_2022_6.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_7.shp
# File SHP_BB_DO_mgl_2022_7.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_8.shp
# File SHP_BB_DO_mgl_2022_8.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_9.shp
# File SHP_BB_DO_mgl_2022_9.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_10.shp
# File SHP_BB_DO_mgl_2022_10.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_11.shp
# File SHP_BB_DO_mgl_2022_11.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_12.shp
# File SHP_BB_DO_mgl_2022_12.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_13.shp
# File SHP_BB_DO_mgl_2022_13.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_14.shp
# File SHP_BB_DO_mgl_2022_14.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_15.shp
# File SHP_BB_DO_mgl_2022_15.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_16.shp
# File SHP_BB_DO_mgl_2022_16.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_17.shp
# File SHP_BB_DO_mgl_2022_17.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_18.shp
# File SHP_BB_DO_mgl_2022_18.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_19.shp
# File SHP_BB_DO_mgl_2022_19.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_20.shp
# File SHP_BB_DO_mgl_2022_20.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_21.shp
# File SHP_BB_DO_mgl_2022_21.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_22.shp
# File SHP_BB_DO_mgl_2022_22.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_23.shp
# File SHP_BB_DO_mgl_2022_23.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_24.shp
# File SHP_BB_DO_mgl_2022_24.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_25.shp
# File SHP_BB_DO_mgl_2022_25.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_26.shp
# File SHP_BB_DO_mgl_2022_26.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_27.shp
# File SHP_BB_DO_mgl_2022_27.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_28.shp
# File SHP_BB_DO_mgl_2022_28.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_29.shp
# File SHP_BB_DO_mgl_2022_29.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_30.shp
# File SHP_BB_DO_mgl_2022_30.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_31.shp
# File SHP_BB_DO_mgl_2022_31.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_32.shp
# File SHP_BB_DO_mgl_2022_32.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_33.shp
# File SHP_BB_DO_mgl_2022_33.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_34.shp
# File SHP_BB_DO_mgl_2022_34.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_35.shp
# File SHP_BB_DO_mgl_2022_35.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_36.shp
# File SHP_BB_DO_mgl_2022_36.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_37.shp
# File SHP_BB_DO_mgl_2022_37.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_38.shp
# File SHP_BB_DO_mgl_2022_38.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_39.shp
# File SHP_BB_DO_mgl_2022_39.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_40.shp
# File SHP_BB_DO_mgl_2022_40.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_41.shp
# File SHP_BB_DO_mgl_2022_41.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_42.shp
# File SHP_BB_DO_mgl_2022_42.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_43.shp
# File SHP_BB_DO_mgl_2022_43.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_44.shp
# File SHP_BB_DO_mgl_2022_44.shp has completed 10 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2023_45.shp
# File SHP_BB_DO_mgl_2023_45.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2023_46.shp
# File SHP_BB_DO_mgl_2023_46.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2023_47.shp
# File SHP_BB_DO_mgl_2023_47.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2023_48.shp
# File SHP_BB_DO_mgl_2023_48.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2023_49.shp
# File SHP_BB_DO_mgl_2023_49.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2023_50.shp
# File SHP_BB_DO_mgl_2023_50.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2023_51.shp
# File SHP_BB_DO_mgl_2023_51.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2023_52.shp
# File SHP_BB_DO_mgl_2023_52.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_1.shp
# File SHP_BB_Sal_ppt_2022_1.shp has completed 4 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_2.shp
# File SHP_BB_Sal_ppt_2022_2.shp has completed 4 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_3.shp
# File SHP_BB_Sal_ppt_2022_3.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_4.shp
# File SHP_BB_Sal_ppt_2022_4.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_5.shp
# File SHP_BB_Sal_ppt_2022_5.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_6.shp
# File SHP_BB_Sal_ppt_2022_6.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_7.shp
# File SHP_BB_Sal_ppt_2022_7.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_8.shp
# File SHP_BB_Sal_ppt_2022_8.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_9.shp
# File SHP_BB_Sal_ppt_2022_9.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_10.shp
# File SHP_BB_Sal_ppt_2022_10.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_11.shp
# File SHP_BB_Sal_ppt_2022_11.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_12.shp
# File SHP_BB_Sal_ppt_2022_12.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_13.shp
# File SHP_BB_Sal_ppt_2022_13.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_14.shp
# File SHP_BB_Sal_ppt_2022_14.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_15.shp
# File SHP_BB_Sal_ppt_2022_15.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_16.shp
# File SHP_BB_Sal_ppt_2022_16.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_17.shp
# File SHP_BB_Sal_ppt_2022_17.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_18.shp
# File SHP_BB_Sal_ppt_2022_18.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_19.shp
# File SHP_BB_Sal_ppt_2022_19.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_20.shp
# File SHP_BB_Sal_ppt_2022_20.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_21.shp
# File SHP_BB_Sal_ppt_2022_21.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_22.shp
# File SHP_BB_Sal_ppt_2022_22.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_23.shp
# File SHP_BB_Sal_ppt_2022_23.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_24.shp
# File SHP_BB_Sal_ppt_2022_24.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_25.shp
# File SHP_BB_Sal_ppt_2022_25.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_26.shp
# File SHP_BB_Sal_ppt_2022_26.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_27.shp
# File SHP_BB_Sal_ppt_2022_27.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_28.shp
# File SHP_BB_Sal_ppt_2022_28.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_29.shp
# File SHP_BB_Sal_ppt_2022_29.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_30.shp
# File SHP_BB_Sal_ppt_2022_30.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_31.shp
# File SHP_BB_Sal_ppt_2022_31.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_32.shp
# File SHP_BB_Sal_ppt_2022_32.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_33.shp
# File SHP_BB_Sal_ppt_2022_33.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_34.shp
# File SHP_BB_Sal_ppt_2022_34.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_35.shp
# File SHP_BB_Sal_ppt_2022_35.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_36.shp
# File SHP_BB_Sal_ppt_2022_36.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_37.shp
# File SHP_BB_Sal_ppt_2022_37.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_38.shp
# File SHP_BB_Sal_ppt_2022_38.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_39.shp
# File SHP_BB_Sal_ppt_2022_39.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_40.shp
# File SHP_BB_Sal_ppt_2022_40.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_41.shp
# File SHP_BB_Sal_ppt_2022_41.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_42.shp
# File SHP_BB_Sal_ppt_2022_42.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_43.shp
# File SHP_BB_Sal_ppt_2022_43.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_44.shp
# File SHP_BB_Sal_ppt_2022_44.shp has completed 10 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2023_45.shp
# File SHP_BB_Sal_ppt_2023_45.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2023_46.shp
# File SHP_BB_Sal_ppt_2023_46.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2023_47.shp
# File SHP_BB_Sal_ppt_2023_47.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2023_48.shp
# File SHP_BB_Sal_ppt_2023_48.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2023_49.shp
# File SHP_BB_Sal_ppt_2023_49.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2023_50.shp
# File SHP_BB_Sal_ppt_2023_50.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2023_51.shp
# File SHP_BB_Sal_ppt_2023_51.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2023_52.shp
# File SHP_BB_Sal_ppt_2023_52.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_1.shp
# File SHP_BB_Turb_ntu_2022_1.shp has completed 4 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_2.shp
# File SHP_BB_Turb_ntu_2022_2.shp has completed 4 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_3.shp
# File SHP_BB_Turb_ntu_2022_3.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_4.shp
# File SHP_BB_Turb_ntu_2022_4.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_5.shp
# File SHP_BB_Turb_ntu_2022_5.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_6.shp
# File SHP_BB_Turb_ntu_2022_6.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_7.shp
# File SHP_BB_Turb_ntu_2022_7.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_8.shp
# File SHP_BB_Turb_ntu_2022_8.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_9.shp
# File SHP_BB_Turb_ntu_2022_9.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_10.shp
# File SHP_BB_Turb_ntu_2022_10.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_11.shp
# File SHP_BB_Turb_ntu_2022_11.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_12.shp
# File SHP_BB_Turb_ntu_2022_12.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_13.shp
# File SHP_BB_Turb_ntu_2022_13.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_14.shp
# File SHP_BB_Turb_ntu_2022_14.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_15.shp
# File SHP_BB_Turb_ntu_2022_15.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_16.shp
# File SHP_BB_Turb_ntu_2022_16.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_17.shp
# File SHP_BB_Turb_ntu_2022_17.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_18.shp
# File SHP_BB_Turb_ntu_2022_18.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_19.shp
# File SHP_BB_Turb_ntu_2022_19.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_20.shp
# File SHP_BB_Turb_ntu_2022_20.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_21.shp
# File SHP_BB_Turb_ntu_2022_21.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_22.shp
# File SHP_BB_Turb_ntu_2022_22.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_23.shp
# File SHP_BB_Turb_ntu_2022_23.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_24.shp
# File SHP_BB_Turb_ntu_2022_24.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_25.shp
# File SHP_BB_Turb_ntu_2022_25.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_26.shp
# File SHP_BB_Turb_ntu_2022_26.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_27.shp
# File SHP_BB_Turb_ntu_2022_27.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_28.shp
# File SHP_BB_Turb_ntu_2022_28.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_29.shp
# File SHP_BB_Turb_ntu_2022_29.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_30.shp
# File SHP_BB_Turb_ntu_2022_30.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_31.shp
# File SHP_BB_Turb_ntu_2022_31.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_32.shp
# File SHP_BB_Turb_ntu_2022_32.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_33.shp
# File SHP_BB_Turb_ntu_2022_33.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_34.shp
# File SHP_BB_Turb_ntu_2022_34.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_35.shp
# File SHP_BB_Turb_ntu_2022_35.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_36.shp
# File SHP_BB_Turb_ntu_2022_36.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_37.shp
# File SHP_BB_Turb_ntu_2022_37.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_38.shp
# File SHP_BB_Turb_ntu_2022_38.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_39.shp
# File SHP_BB_Turb_ntu_2022_39.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_40.shp
# File SHP_BB_Turb_ntu_2022_40.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_41.shp
# File SHP_BB_Turb_ntu_2022_41.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_42.shp
# File SHP_BB_Turb_ntu_2022_42.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_43.shp
# File SHP_BB_Turb_ntu_2022_43.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_44.shp
# File SHP_BB_Turb_ntu_2022_44.shp has completed 10 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2023_45.shp
# File SHP_BB_Turb_ntu_2023_45.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2023_46.shp
# File SHP_BB_Turb_ntu_2023_46.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2023_47.shp
# File SHP_BB_Turb_ntu_2023_47.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2023_48.shp
# File SHP_BB_Turb_ntu_2023_48.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2023_49.shp
# File SHP_BB_Turb_ntu_2023_49.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2023_50.shp
# File SHP_BB_Turb_ntu_2023_50.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2023_51.shp
# File SHP_BB_Turb_ntu_2023_51.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2023_52.shp
# File SHP_BB_Turb_ntu_2023_52.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_1.shp
# File SHP_BB_T_c_2022_1.shp has completed 4 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_2.shp
# File SHP_BB_T_c_2022_2.shp has completed 4 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_3.shp
# File SHP_BB_T_c_2022_3.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_4.shp
# File SHP_BB_T_c_2022_4.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_5.shp
# File SHP_BB_T_c_2022_5.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_6.shp
# File SHP_BB_T_c_2022_6.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_7.shp
# File SHP_BB_T_c_2022_7.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_8.shp
# File SHP_BB_T_c_2022_8.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_9.shp
# File SHP_BB_T_c_2022_9.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_10.shp
# File SHP_BB_T_c_2022_10.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_11.shp
# File SHP_BB_T_c_2022_11.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_12.shp
# File SHP_BB_T_c_2022_12.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_13.shp
# File SHP_BB_T_c_2022_13.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_14.shp
# File SHP_BB_T_c_2022_14.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_15.shp
# File SHP_BB_T_c_2022_15.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_16.shp
# File SHP_BB_T_c_2022_16.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_17.shp
# File SHP_BB_T_c_2022_17.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_18.shp
# File SHP_BB_T_c_2022_18.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_19.shp
# File SHP_BB_T_c_2022_19.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_20.shp
# File SHP_BB_T_c_2022_20.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_21.shp
# File SHP_BB_T_c_2022_21.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_22.shp
# File SHP_BB_T_c_2022_22.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_23.shp
# File SHP_BB_T_c_2022_23.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_24.shp
# File SHP_BB_T_c_2022_24.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_25.shp
# File SHP_BB_T_c_2022_25.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_26.shp
# File SHP_BB_T_c_2022_26.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_27.shp
# File SHP_BB_T_c_2022_27.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_28.shp
# File SHP_BB_T_c_2022_28.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_29.shp
# File SHP_BB_T_c_2022_29.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_30.shp
# File SHP_BB_T_c_2022_30.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_31.shp
# File SHP_BB_T_c_2022_31.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_32.shp
# File SHP_BB_T_c_2022_32.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_33.shp
# File SHP_BB_T_c_2022_33.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_34.shp
# File SHP_BB_T_c_2022_34.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_35.shp
# File SHP_BB_T_c_2022_35.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_36.shp
# File SHP_BB_T_c_2022_36.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_37.shp
# File SHP_BB_T_c_2022_37.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_38.shp
# File SHP_BB_T_c_2022_38.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_39.shp
# ...
# Processing file: SHP_GTM_Sal_ppt_2016_12.shp
# File SHP_GTM_Sal_ppt_2016_12.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_13.shp
# File SHP_GTM_Sal_ppt_2016_13.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_14.shp
# File SHP_GTM_Sal_ppt_2016_14.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_15.shp
# File SHP_GTM_Sal_ppt_2016_15.shp has completed 3 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_16.shp
# File SHP_GTM_Sal_ppt_2016_16.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_17.shp
# File SHP_GTM_Sal_ppt_2016_17.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_18.shp
# File SHP_GTM_Sal_ppt_2016_18.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_19.shp
# File SHP_GTM_Sal_ppt_2016_19.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_20.shp
# File SHP_GTM_Sal_ppt_2016_20.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_21.shp
# File SHP_GTM_Sal_ppt_2016_21.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_22.shp
# File SHP_GTM_Sal_ppt_2016_22.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_23.shp
# File SHP_GTM_Sal_ppt_2016_23.shp has completed 8 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_24.shp
# File SHP_GTM_Sal_ppt_2016_24.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_25.shp
# Not enough data for IDW interpolation in SHP_GTM_Sal_ppt_2016_25.shp, skipping
# Processing file: SHP_GTM_Sal_ppt_2016_26.shp
# Not enough data for IDW interpolation in SHP_GTM_Sal_ppt_2016_26.shp, skipping
# Processing file: SHP_GTM_Sal_ppt_2016_27.shp
# Not enough data for IDW interpolation in SHP_GTM_Sal_ppt_2016_27.shp, skipping
# Processing file: SHP_GTM_Sal_ppt_2016_28.shp
# File SHP_GTM_Sal_ppt_2016_28.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_29.shp
# File SHP_GTM_Sal_ppt_2016_29.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_30.shp
# File SHP_GTM_Sal_ppt_2016_30.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_31.shp
# File SHP_GTM_Sal_ppt_2016_31.shp has completed 3 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_32.shp
# File SHP_GTM_Sal_ppt_2016_32.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_33.shp
# File SHP_GTM_Sal_ppt_2016_33.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_34.shp
# File SHP_GTM_Sal_ppt_2016_34.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_35.shp
# File SHP_GTM_Sal_ppt_2016_35.shp has completed 8 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_36.shp
# File SHP_GTM_Sal_ppt_2016_36.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_37.shp
# File SHP_GTM_Sal_ppt_2016_37.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_38.shp
# File SHP_GTM_Sal_ppt_2016_38.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_39.shp
# File SHP_GTM_Sal_ppt_2016_39.shp has completed 8 cross-validation iterations.
# Shapefile not found for: SHP_GTM_Sal_ppt_2017_40.shp
# Shapefile not found for: SHP_GTM_Sal_ppt_2017_41.shp
# Shapefile not found for: SHP_GTM_Sal_ppt_2017_42.shp
# Shapefile not found for: SHP_GTM_Sal_ppt_2017_43.shp
# Shapefile not found for: SHP_GTM_Sal_ppt_2017_44.shp
# Shapefile not found for: SHP_GTM_Sal_ppt_2017_45.shp
# Shapefile not found for: SHP_GTM_Sal_ppt_2017_46.shp
# Shapefile not found for: SHP_GTM_Sal_ppt_2017_47.shp
# Processing file: SHP_GTM_Sal_ppt_2017_48.shp
# File SHP_GTM_Sal_ppt_2017_48.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2017_49.shp
# File SHP_GTM_Sal_ppt_2017_49.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2017_50.shp
# File SHP_GTM_Sal_ppt_2017_50.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2017_51.shp
# File SHP_GTM_Sal_ppt_2017_51.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2017_52.shp
# File SHP_GTM_Sal_ppt_2017_52.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_1.shp
# File SHP_GTM_Turb_ntu_2016_1.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_2.shp
# File SHP_GTM_Turb_ntu_2016_2.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_3.shp
# File SHP_GTM_Turb_ntu_2016_3.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_4.shp
# File SHP_GTM_Turb_ntu_2016_4.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_5.shp
# File SHP_GTM_Turb_ntu_2016_5.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_6.shp
# File SHP_GTM_Turb_ntu_2016_6.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_7.shp
# File SHP_GTM_Turb_ntu_2016_7.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_8.shp
# File SHP_GTM_Turb_ntu_2016_8.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_9.shp
# File SHP_GTM_Turb_ntu_2016_9.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_10.shp
# File SHP_GTM_Turb_ntu_2016_10.shp has completed 8 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_11.shp
# File SHP_GTM_Turb_ntu_2016_11.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_12.shp
# File SHP_GTM_Turb_ntu_2016_12.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_13.shp
# File SHP_GTM_Turb_ntu_2016_13.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_14.shp
# File SHP_GTM_Turb_ntu_2016_14.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_15.shp
# File SHP_GTM_Turb_ntu_2016_15.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_16.shp
# File SHP_GTM_Turb_ntu_2016_16.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_17.shp
# File SHP_GTM_Turb_ntu_2016_17.shp has completed 3 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_18.shp
# File SHP_GTM_Turb_ntu_2016_18.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_19.shp
# File SHP_GTM_Turb_ntu_2016_19.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_20.shp
# File SHP_GTM_Turb_ntu_2016_20.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_21.shp
# File SHP_GTM_Turb_ntu_2016_21.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_22.shp
# File SHP_GTM_Turb_ntu_2016_22.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_23.shp
# File SHP_GTM_Turb_ntu_2016_23.shp has completed 8 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_24.shp
# File SHP_GTM_Turb_ntu_2016_24.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_25.shp
# File SHP_GTM_Turb_ntu_2016_25.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_26.shp
# File SHP_GTM_Turb_ntu_2016_26.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_27.shp
# File SHP_GTM_Turb_ntu_2016_27.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_28.shp
# File SHP_GTM_Turb_ntu_2016_28.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_29.shp
# File SHP_GTM_Turb_ntu_2016_29.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_30.shp
# File SHP_GTM_Turb_ntu_2016_30.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_31.shp
# File SHP_GTM_Turb_ntu_2016_31.shp has completed 3 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_32.shp
# File SHP_GTM_Turb_ntu_2016_32.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_33.shp
# File SHP_GTM_Turb_ntu_2016_33.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_34.shp
# File SHP_GTM_Turb_ntu_2016_34.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_35.shp
# File SHP_GTM_Turb_ntu_2016_35.shp has completed 8 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_36.shp
# File SHP_GTM_Turb_ntu_2016_36.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_37.shp
# File SHP_GTM_Turb_ntu_2016_37.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_38.shp
# File SHP_GTM_Turb_ntu_2016_38.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_39.shp
# File SHP_GTM_Turb_ntu_2016_39.shp has completed 8 cross-validation iterations.
# Shapefile not found for: SHP_GTM_Turb_ntu_2017_40.shp
# Shapefile not found for: SHP_GTM_Turb_ntu_2017_41.shp
# Shapefile not found for: SHP_GTM_Turb_ntu_2017_42.shp
# Shapefile not found for: SHP_GTM_Turb_ntu_2017_43.shp
# Shapefile not found for: SHP_GTM_Turb_ntu_2017_44.shp
# Shapefile not found for: SHP_GTM_Turb_ntu_2017_45.shp
# Shapefile not found for: SHP_GTM_Turb_ntu_2017_46.shp
# Shapefile not found for: SHP_GTM_Turb_ntu_2017_47.shp
# Processing file: SHP_GTM_Turb_ntu_2017_48.shp
# File SHP_GTM_Turb_ntu_2017_48.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2017_49.shp
# File SHP_GTM_Turb_ntu_2017_49.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2017_50.shp
# File SHP_GTM_Turb_ntu_2017_50.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2017_51.shp
# File SHP_GTM_Turb_ntu_2017_51.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2017_52.shp
# File SHP_GTM_Turb_ntu_2017_52.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_1.shp
# File SHP_GTM_T_c_2016_1.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_2.shp
# File SHP_GTM_T_c_2016_2.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_3.shp
# File SHP_GTM_T_c_2016_3.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_4.shp
# File SHP_GTM_T_c_2016_4.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_5.shp
# File SHP_GTM_T_c_2016_5.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_6.shp
# File SHP_GTM_T_c_2016_6.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_7.shp
# File SHP_GTM_T_c_2016_7.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_8.shp
# File SHP_GTM_T_c_2016_8.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_9.shp
# File SHP_GTM_T_c_2016_9.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_10.shp
# File SHP_GTM_T_c_2016_10.shp has completed 8 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_11.shp
# File SHP_GTM_T_c_2016_11.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_12.shp
# File SHP_GTM_T_c_2016_12.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_13.shp
# File SHP_GTM_T_c_2016_13.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_14.shp
# File SHP_GTM_T_c_2016_14.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_15.shp
# File SHP_GTM_T_c_2016_15.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_16.shp
# File SHP_GTM_T_c_2016_16.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_17.shp
# File SHP_GTM_T_c_2016_17.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_18.shp
# File SHP_GTM_T_c_2016_18.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_19.shp
# File SHP_GTM_T_c_2016_19.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_20.shp
# File SHP_GTM_T_c_2016_20.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_21.shp
# File SHP_GTM_T_c_2016_21.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_22.shp
# File SHP_GTM_T_c_2016_22.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_23.shp
# File SHP_GTM_T_c_2016_23.shp has completed 8 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_24.shp
# File SHP_GTM_T_c_2016_24.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_25.shp
# File SHP_GTM_T_c_2016_25.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_26.shp
# File SHP_GTM_T_c_2016_26.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_27.shp
# File SHP_GTM_T_c_2016_27.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_28.shp
# File SHP_GTM_T_c_2016_28.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_29.shp
# File SHP_GTM_T_c_2016_29.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_30.shp
# File SHP_GTM_T_c_2016_30.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_31.shp
# File SHP_GTM_T_c_2016_31.shp has completed 3 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_32.shp
# File SHP_GTM_T_c_2016_32.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_33.shp
# File SHP_GTM_T_c_2016_33.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_34.shp
# File SHP_GTM_T_c_2016_34.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_35.shp
# File SHP_GTM_T_c_2016_35.shp has completed 8 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_36.shp
# File SHP_GTM_T_c_2016_36.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_37.shp
# File SHP_GTM_T_c_2016_37.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_38.shp
# File SHP_GTM_T_c_2016_38.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_39.shp
# File SHP_GTM_T_c_2016_39.shp has completed 8 cross-validation iterations.
# Shapefile not found for: SHP_GTM_T_c_2017_40.shp
# Shapefile not found for: SHP_GTM_T_c_2017_41.shp
# Shapefile not found for: SHP_GTM_T_c_2017_42.shp
# Shapefile not found for: SHP_GTM_T_c_2017_43.shp
# Shapefile not found for: SHP_GTM_T_c_2017_44.shp
# Shapefile not found for: SHP_GTM_T_c_2017_45.shp
# Shapefile not found for: SHP_GTM_T_c_2017_46.shp
# Shapefile not found for: SHP_GTM_T_c_2017_47.shp
# Processing file: SHP_GTM_T_c_2017_48.shp
# File SHP_GTM_T_c_2017_48.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2017_49.shp
# File SHP_GTM_T_c_2017_49.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2017_50.shp
# File SHP_GTM_T_c_2017_50.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2017_51.shp
# File SHP_GTM_T_c_2017_51.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2017_52.shp
# File SHP_GTM_T_c_2017_52.shp has completed 4 cross-validation iterations.
# Calculated RMSE: 1.937383708062512, ME: -0.46532336674999986 for file: SHP_GTM_T_c_2017_52.shp. Time used: 110808.00088238716

# %% [markdown]
# # 4. Monthly Results <a class="anchor" id="month"></a>

# %% [markdown]
# ### Set the folder path for weekly result

# %%
shpCon_folder = gis_path + r"shapefiles/idw_month"
idwCon_folder = gis_path + r"raster_output/idw_month"

# shpCon_folder = gis_path + r"shapefiles_Con/month"
# idwCon_folder = gis_path + r"idw_Con/month"

# %%
area_ab = ["GTM","EB","CH","BB","BBS"]
period_type = [" 52 week"," Month"]
dfConTime["Period"] = ""
def select_data_period1(df,area,period):
    sheet_name = str(area) + str(period)
    df_period_table = pd.read_excel(gis_path + "All_Waterbodies_Season_Month_Week_Definitions.xlsx",sheet_name=sheet_name)
    df_select_area = df[df["WbodyAcronym"]==str(area)]
    df_period_table['Start Date'] = pd.to_datetime(df_period_table['Start Date'])
    df_period_table['End Date']   = pd.to_datetime(df_period_table['End Date'])
    sub_dfs = []

    for index, row in df_period_table.iterrows():
        start_date = row['Start Date']
        end_date   = row['End Date']
        sub_df = df_select_area[(df_select_area['SampleDate'] >= start_date) & (df_select_area['SampleDate'] < end_date)]
        sub_df['Period'] = row["Month"]
        sub_dfs.append(sub_df)
        
    df_period = pd.concat(sub_dfs,ignore_index=True)
    return df_period

# %%
sel_month_temp = []
for each in area_ab:
    df_month_temp = select_data_period1(dfConTime,str(each)," Month")
    df_month_temp_group = df_month_temp.groupby(['WaterBody','ParameterName','ParameterUnits',
                                          'Year','Season','Latitude_DD','Longitude_DD','WbodyAcronym',"Period"])["ResultValue"].agg("mean").reset_index()
    sel_month_temp.append(df_month_temp_group)
df_month_select_Mean = pd.concat(sel_month_temp,ignore_index=True)

# %%
# Define the EPSG codes for source (EPSG:4326) and target (EPSG:3086) coordinate systems
source_epsg = 'EPSG:4326'
target_epsg = 'EPSG:3086'

# Create a PyProj Transformer for the conversion
transformer = pyproj.Transformer.from_crs(source_epsg, target_epsg, always_xy=True)

# Define a function to apply the transformation to each row of the DataFrame
def transform_coordinates(row):
    x, y = transformer.transform(row['Longitude_DD'], row['Latitude_DD'])
    return pd.Series({'x': x, 'y': y})

# Apply the transformation function to the DataFrame and create new columns for the converted coordinates
df_month_select_Mean[['x', 'y']] = df_month_select_Mean.apply(transform_coordinates, axis=1)

# %%
df_month_select_Mean
# Out:
#                     WaterBody      ParameterName ParameterUnits  Year  Season  \
# 0     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 1     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 2     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 3     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 4     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# ...                       ...                ...            ...   ...     ...
# 1057      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Summer
# 1058      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 1059      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 1060      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 1061      Big Bend Seagrasses  Water Temperature      Degrees C  2022  Winter
#
#       Latitude_DD  Longitude_DD WbodyAcronym  Period  ResultValue  \
# 0       29.667071    -81.257403          GTM       6     5.102863
# 1       29.667071    -81.257403          GTM       7     3.726113
# 2       29.667071    -81.257403          GTM       8     6.593228
# 3       29.737041    -81.245953          GTM       6     5.625239
# 4       29.737041    -81.245953          GTM       7     6.366585
# ...           ...           ...          ...     ...          ...
# 1057    29.647203    -83.421196          BBS       9    29.299187
# 1058    29.647203    -83.421196          BBS       1    13.390917
# 1059    29.647203    -83.421196          BBS       2    17.093293
# 1060    29.647203    -83.421196          BBS      12    19.026045
# 1061    29.647203    -83.421196          BBS      12    21.929268
#
#                   x              y
# 0     665054.640076  631868.177645
# 1     665054.640076  631868.177645
# 2     665054.640076  631868.177645
# 3     665987.547779  639659.183554
# 4     665987.547779  639659.183554
# ...             ...            ...
# 1057  455952.502950  626846.023588
# 1058  455952.502950  626846.023588
# 1059  455952.502950  626846.023588
# 1060  455952.502950  626846.023588
# 1061  455952.502950  626846.023588
#
# [1062 rows x 12 columns]

# %%
waterBody = ['Big Bend Seagrasses', 'Biscayne Bay', 'Charlotte Harbor', 'Estero Bay', 'Guana Tolomato Matanzas']
parameter = ['Dissolved Oxygen', 'Salinity', 'Turbidity', 'Water Temperature']
waterBody_list = []
parameter_list= []
month_list = []
for i in waterBody:
    for j in parameter:
        for k in range(1,13):
            waterBody_list.append(i)
            parameter_list.append(j)
            month_list.append(k)

# %%
df_month_table = pd.DataFrame({
    "WaterBody":waterBody_list,
    "Parameter":parameter_list,
    "Period":month_list
})
df_month_table["Filename"] = ""
df_month_table["NumDataPoints"] = ""
df_month_table["RMSE"] = ""
df_month_table["ME"] = ""
df_month_table["WbodyAcronym"] = df_month_table["WaterBody"].map(area_shortnames)

# %%
name_ab = df_month_table["WbodyAcronym"].unique()
para_list = df_month_table["Parameter"].unique()
dfs_sub = []
for each in name_ab:
    sheet_name_use = str(each) + " Month"
    df_period_table_used = pd.read_excel(gis_path + "All_Waterbodies_Season_Month_Week_Definitions.xlsx",sheet_name=sheet_name_use)
    startDate = list(df_period_table_used["Start Date"])
    endDate   = list(df_period_table_used["End Date"])
    for para in para_list:
        df_temp_use = df_month_table[(df_month_table["WbodyAcronym"]==str(each))&(df_month_table["Parameter"]==str(para))]
        df_temp_use["startDate"] = startDate
        df_temp_use["endDate"]   = endDate
        dfs_sub.append(df_temp_use)
df_month_table = pd.concat(dfs_sub)
df_month_table["Year"] = df_month_table["startDate"].dt.year
df_month_table.to_csv(gis_path + 'month_table.csv')

# %%
idw_rk_x.fill_nan_rowids(df_month_select_Mean, 'RowID')

df_month_select_Mean['RowID'] = df_month_select_Mean['RowID'].astype(int)
df_month_select_Mean
# Out:
#                     WaterBody      ParameterName ParameterUnits  Year  Season  \
# 0     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 1     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 2     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 3     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 4     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# ...                       ...                ...            ...   ...     ...
# 1057      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Summer
# 1058      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 1059      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 1060      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 1061      Big Bend Seagrasses  Water Temperature      Degrees C  2022  Winter
#
#       Latitude_DD  Longitude_DD WbodyAcronym  Period  ResultValue  \
# 0       29.667071    -81.257403          GTM       6     5.102863
# 1       29.667071    -81.257403          GTM       7     3.726113
# 2       29.667071    -81.257403          GTM       8     6.593228
# 3       29.737041    -81.245953          GTM       6     5.625239
# 4       29.737041    -81.245953          GTM       7     6.366585
# ...           ...           ...          ...     ...          ...
# 1057    29.647203    -83.421196          BBS       9    29.299187
# 1058    29.647203    -83.421196          BBS       1    13.390917
# 1059    29.647203    -83.421196          BBS       2    17.093293
# 1060    29.647203    -83.421196          BBS      12    19.026045
# 1061    29.647203    -83.421196          BBS      12    21.929268
#
#                   x              y  RowID
# 0     665054.640076  631868.177645      1
# 1     665054.640076  631868.177645      2
# 2     665054.640076  631868.177645      3
# 3     665987.547779  639659.183554      4
# 4     665987.547779  639659.183554      5
# ...             ...            ...    ...
# 1057  455952.502950  626846.023588   1058
# 1058  455952.502950  626846.023588   1059
# 1059  455952.502950  626846.023588   1060
# 1060  455952.502950  626846.023588   1061
# 1061  455952.502950  626846.023588   1062
#
# [1062 rows x 13 columns]

# %%
idw_rk_x.delete_all_files(shpCon_folder)

# %%
# Merge interested with latitude and longitude columns
seasons_con_coord = idw_rk_x.merge_with_lat_long1(df_month_table, df_month_select_Mean)
seasons_con_coord
# Out:
#                     WaterBody          Parameter  Period Filename  \
# 0         Big Bend Seagrasses   Dissolved Oxygen       1
# 1         Big Bend Seagrasses   Dissolved Oxygen       2
# 2         Big Bend Seagrasses   Dissolved Oxygen       2
# 3         Big Bend Seagrasses   Dissolved Oxygen       3
# 4         Big Bend Seagrasses   Dissolved Oxygen       4
# ...                       ...                ...     ...      ...
# 1061  Guana Tolomato Matanzas  Water Temperature      11
# 1062  Guana Tolomato Matanzas  Water Temperature      12
# 1063  Guana Tolomato Matanzas  Water Temperature      12
# 1064  Guana Tolomato Matanzas  Water Temperature      12
# 1065  Guana Tolomato Matanzas  Water Temperature      12
#
#      NumDataPoints RMSE ME WbodyAcronym  startDate    endDate  Year  \
# 0                                   BBS 2021-01-08 2021-02-06  2021
# 1                                   BBS 2021-02-07 2021-03-08  2021
# 2                                   BBS 2021-02-07 2021-03-08  2021
# 3                                   BBS 2021-03-09 2021-04-07  2021
# 4                                   BBS 2021-04-08 2021-05-07  2021
# ...            ...  ... ..          ...        ...        ...   ...
# 1061                                GTM 2017-02-05 2017-03-07  2017
# 1062                                GTM 2017-03-07 2017-04-06  2017
# 1063                                GTM 2017-03-07 2017-04-06  2017
# 1064                                GTM 2017-03-07 2017-04-06  2017
# 1065                                GTM 2017-03-07 2017-04-06  2017
#
#                   x              y  RowID  ResultValue
# 0     455952.502950  626846.023588   1012     8.339361
# 1     455952.502950  626846.023588   1004     7.416098
# 2     455952.502950  626846.023588   1013     7.686687
# 3     455952.502950  626846.023588   1005     7.447603
# 4     455952.502950  626846.023588   1006     6.823886
# ...             ...            ...    ...          ...
# 1061  653510.005839  674232.563906    234    18.690244
# 1062  665054.640076  631868.177645    229    21.544634
# 1063  665987.547779  639659.183554    231    20.056179
# 1064  659731.716683  654157.848803    233    20.105777
# 1065  653510.005839  674232.563906    235    20.596098
#
# [1066 rows x 15 columns]

# %%
idw_rk_x.create_shp_season1(seasons_con_coord, shpCon_folder)
# Out:
# Number of data rows for BBS, DO_mgl, 1: 1
# Shapefile for BBS: DO_mgl for period 1 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_1.shp
# Number of data rows for BBS, DO_mgl, 2: 2
# Shapefile for BBS: DO_mgl for period 2 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_2.shp
# Number of data rows for BBS, DO_mgl, 3: 1
# Shapefile for BBS: DO_mgl for period 3 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_3.shp
# Number of data rows for BBS, DO_mgl, 4: 1
# Shapefile for BBS: DO_mgl for period 4 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_4.shp
# Number of data rows for BBS, DO_mgl, 5: 1
# Shapefile for BBS: DO_mgl for period 5 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_5.shp
# Number of data rows for BBS, DO_mgl, 6: 1
# Shapefile for BBS: DO_mgl for period 6 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_6.shp
# Number of data rows for BBS, DO_mgl, 7: 1
# Shapefile for BBS: DO_mgl for period 7 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_7.shp
# Number of data rows for BBS, DO_mgl, 8: 1
# Shapefile for BBS: DO_mgl for period 8 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_8.shp
# Number of data rows for BBS, DO_mgl, 9: 2
# Shapefile for BBS: DO_mgl for period 9 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_9.shp
# Number of data rows for BBS, DO_mgl, 10: 1
# Shapefile for BBS: DO_mgl for period 10 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_10.shp
# Number of data rows for BBS, DO_mgl, 11: 1
# Shapefile for BBS: DO_mgl for period 11 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_11.shp
# Number of data rows for BBS, DO_mgl, 12: 2
# Shapefile for BBS: DO_mgl for period 12 of year 2021 has been saved as SHP_BBS_DO_mgl_2021_12.shp
# Number of data rows for BBS, Sal_ppt, 1: 1
# Shapefile for BBS: Sal_ppt for period 1 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_1.shp
# Number of data rows for BBS, Sal_ppt, 2: 2
# Shapefile for BBS: Sal_ppt for period 2 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_2.shp
# Number of data rows for BBS, Sal_ppt, 3: 1
# Shapefile for BBS: Sal_ppt for period 3 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_3.shp
# Number of data rows for BBS, Sal_ppt, 4: 1
# Shapefile for BBS: Sal_ppt for period 4 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_4.shp
# Number of data rows for BBS, Sal_ppt, 5: 1
# Shapefile for BBS: Sal_ppt for period 5 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_5.shp
# Number of data rows for BBS, Sal_ppt, 6: 1
# Shapefile for BBS: Sal_ppt for period 6 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_6.shp
# Number of data rows for BBS, Sal_ppt, 7: 1
# Shapefile for BBS: Sal_ppt for period 7 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_7.shp
# Number of data rows for BBS, Sal_ppt, 8: 1
# Shapefile for BBS: Sal_ppt for period 8 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_8.shp
# Number of data rows for BBS, Sal_ppt, 9: 2
# Shapefile for BBS: Sal_ppt for period 9 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_9.shp
# Number of data rows for BBS, Sal_ppt, 10: 1
# Shapefile for BBS: Sal_ppt for period 10 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_10.shp
# Number of data rows for BBS, Sal_ppt, 11: 1
# Shapefile for BBS: Sal_ppt for period 11 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_11.shp
# Number of data rows for BBS, Sal_ppt, 12: 2
# Shapefile for BBS: Sal_ppt for period 12 of year 2021 has been saved as SHP_BBS_Sal_ppt_2021_12.shp
# Number of data rows for BBS, Turb_ntu, 1: 1
# Shapefile for BBS: Turb_ntu for period 1 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_1.shp
# Number of data rows for BBS, Turb_ntu, 2: 2
# Shapefile for BBS: Turb_ntu for period 2 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_2.shp
# Number of data rows for BBS, Turb_ntu, 3: 1
# Shapefile for BBS: Turb_ntu for period 3 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_3.shp
# Number of data rows for BBS, Turb_ntu, 4: 1
# Shapefile for BBS: Turb_ntu for period 4 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_4.shp
# Number of data rows for BBS, Turb_ntu, 5: 1
# Shapefile for BBS: Turb_ntu for period 5 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_5.shp
# Number of data rows for BBS, Turb_ntu, 6: 2
# Shapefile for BBS: Turb_ntu for period 6 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_6.shp
# Number of data rows for BBS, Turb_ntu, 7: 1
# Shapefile for BBS: Turb_ntu for period 7 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_7.shp
# Number of data rows for BBS, Turb_ntu, 8: 1
# Shapefile for BBS: Turb_ntu for period 8 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_8.shp
# Number of data rows for BBS, Turb_ntu, 9: 2
# Shapefile for BBS: Turb_ntu for period 9 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_9.shp
# Number of data rows for BBS, Turb_ntu, 10: 1
# Shapefile for BBS: Turb_ntu for period 10 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_10.shp
# Number of data rows for BBS, Turb_ntu, 11: 1
# Shapefile for BBS: Turb_ntu for period 11 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_11.shp
# Number of data rows for BBS, Turb_ntu, 12: 2
# Shapefile for BBS: Turb_ntu for period 12 of year 2021 has been saved as SHP_BBS_Turb_ntu_2021_12.shp
# Number of data rows for BBS, T_c, 1: 1
# Shapefile for BBS: T_c for period 1 of year 2021 has been saved as SHP_BBS_T_c_2021_1.shp
# Number of data rows for BBS, T_c, 2: 2
# Shapefile for BBS: T_c for period 2 of year 2021 has been saved as SHP_BBS_T_c_2021_2.shp
# Number of data rows for BBS, T_c, 3: 1
# Shapefile for BBS: T_c for period 3 of year 2021 has been saved as SHP_BBS_T_c_2021_3.shp
# Number of data rows for BBS, T_c, 4: 1
# Shapefile for BBS: T_c for period 4 of year 2021 has been saved as SHP_BBS_T_c_2021_4.shp
# Number of data rows for BBS, T_c, 5: 1
# Shapefile for BBS: T_c for period 5 of year 2021 has been saved as SHP_BBS_T_c_2021_5.shp
# Number of data rows for BBS, T_c, 6: 2
# Shapefile for BBS: T_c for period 6 of year 2021 has been saved as SHP_BBS_T_c_2021_6.shp
# Number of data rows for BBS, T_c, 7: 1
# Shapefile for BBS: T_c for period 7 of year 2021 has been saved as SHP_BBS_T_c_2021_7.shp
# Number of data rows for BBS, T_c, 8: 1
# Shapefile for BBS: T_c for period 8 of year 2021 has been saved as SHP_BBS_T_c_2021_8.shp
# Number of data rows for BBS, T_c, 9: 2
# Shapefile for BBS: T_c for period 9 of year 2021 has been saved as SHP_BBS_T_c_2021_9.shp
# Number of data rows for BBS, T_c, 10: 1
# Shapefile for BBS: T_c for period 10 of year 2021 has been saved as SHP_BBS_T_c_2021_10.shp
# Number of data rows for BBS, T_c, 11: 1
# Shapefile for BBS: T_c for period 11 of year 2021 has been saved as SHP_BBS_T_c_2021_11.shp
# Number of data rows for BBS, T_c, 12: 2
# Shapefile for BBS: T_c for period 12 of year 2021 has been saved as SHP_BBS_T_c_2021_12.shp
# Number of data rows for BB, DO_mgl, 1: 6
# Shapefile for BB: DO_mgl for period 1 of year 2022 has been saved as SHP_BB_DO_mgl_2022_1.shp
# Number of data rows for BB, DO_mgl, 2: 6
# Shapefile for BB: DO_mgl for period 2 of year 2022 has been saved as SHP_BB_DO_mgl_2022_2.shp
# Number of data rows for BB, DO_mgl, 3: 6
# Shapefile for BB: DO_mgl for period 3 of year 2022 has been saved as SHP_BB_DO_mgl_2022_3.shp
# Number of data rows for BB, DO_mgl, 4: 12
# Shapefile for BB: DO_mgl for period 4 of year 2022 has been saved as SHP_BB_DO_mgl_2022_4.shp
# Number of data rows for BB, DO_mgl, 5: 5
# Shapefile for BB: DO_mgl for period 5 of year 2022 has been saved as SHP_BB_DO_mgl_2022_5.shp
# Number of data rows for BB, DO_mgl, 6: 6
# Shapefile for BB: DO_mgl for period 6 of year 2022 has been saved as SHP_BB_DO_mgl_2022_6.shp
# Number of data rows for BB, DO_mgl, 7: 12
# Shapefile for BB: DO_mgl for period 7 of year 2022 has been saved as SHP_BB_DO_mgl_2022_7.shp
# Number of data rows for BB, DO_mgl, 8: 6
# Shapefile for BB: DO_mgl for period 8 of year 2022 has been saved as SHP_BB_DO_mgl_2022_8.shp
# Number of data rows for BB, DO_mgl, 9: 12
# Shapefile for BB: DO_mgl for period 9 of year 2022 has been saved as SHP_BB_DO_mgl_2022_9.shp
# Number of data rows for BB, DO_mgl, 10: 6
# Shapefile for BB: DO_mgl for period 10 of year 2022 has been saved as SHP_BB_DO_mgl_2022_10.shp
# Number of data rows for BB, DO_mgl, 11: 6
# Shapefile for BB: DO_mgl for period 11 of year 2023 has been saved as SHP_BB_DO_mgl_2023_11.shp
# Number of data rows for BB, DO_mgl, 12: 12
# Shapefile for BB: DO_mgl for period 12 of year 2023 has been saved as SHP_BB_DO_mgl_2023_12.shp
# Number of data rows for BB, Sal_ppt, 1: 6
# Shapefile for BB: Sal_ppt for period 1 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_1.shp
# Number of data rows for BB, Sal_ppt, 2: 6
# Shapefile for BB: Sal_ppt for period 2 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_2.shp
# Number of data rows for BB, Sal_ppt, 3: 6
# Shapefile for BB: Sal_ppt for period 3 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_3.shp
# Number of data rows for BB, Sal_ppt, 4: 12
# Shapefile for BB: Sal_ppt for period 4 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_4.shp
# Number of data rows for BB, Sal_ppt, 5: 5
# Shapefile for BB: Sal_ppt for period 5 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_5.shp
# Number of data rows for BB, Sal_ppt, 6: 6
# Shapefile for BB: Sal_ppt for period 6 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_6.shp
# Number of data rows for BB, Sal_ppt, 7: 12
# Shapefile for BB: Sal_ppt for period 7 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_7.shp
# Number of data rows for BB, Sal_ppt, 8: 6
# Shapefile for BB: Sal_ppt for period 8 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_8.shp
# Number of data rows for BB, Sal_ppt, 9: 12
# Shapefile for BB: Sal_ppt for period 9 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_9.shp
# Number of data rows for BB, Sal_ppt, 10: 6
# Shapefile for BB: Sal_ppt for period 10 of year 2022 has been saved as SHP_BB_Sal_ppt_2022_10.shp
# Number of data rows for BB, Sal_ppt, 11: 6
# Shapefile for BB: Sal_ppt for period 11 of year 2023 has been saved as SHP_BB_Sal_ppt_2023_11.shp
# Number of data rows for BB, Sal_ppt, 12: 12
# Shapefile for BB: Sal_ppt for period 12 of year 2023 has been saved as SHP_BB_Sal_ppt_2023_12.shp
# Number of data rows for BB, Turb_ntu, 1: 6
# Shapefile for BB: Turb_ntu for period 1 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_1.shp
# Number of data rows for BB, Turb_ntu, 2: 6
# Shapefile for BB: Turb_ntu for period 2 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_2.shp
# Number of data rows for BB, Turb_ntu, 3: 6
# Shapefile for BB: Turb_ntu for period 3 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_3.shp
# Number of data rows for BB, Turb_ntu, 4: 12
# Shapefile for BB: Turb_ntu for period 4 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_4.shp
# Number of data rows for BB, Turb_ntu, 5: 5
# Shapefile for BB: Turb_ntu for period 5 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_5.shp
# Number of data rows for BB, Turb_ntu, 6: 6
# Shapefile for BB: Turb_ntu for period 6 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_6.shp
# Number of data rows for BB, Turb_ntu, 7: 12
# Shapefile for BB: Turb_ntu for period 7 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_7.shp
# Number of data rows for BB, Turb_ntu, 8: 6
# Shapefile for BB: Turb_ntu for period 8 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_8.shp
# Number of data rows for BB, Turb_ntu, 9: 12
# Shapefile for BB: Turb_ntu for period 9 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_9.shp
# Number of data rows for BB, Turb_ntu, 10: 6
# Shapefile for BB: Turb_ntu for period 10 of year 2022 has been saved as SHP_BB_Turb_ntu_2022_10.shp
# Number of data rows for BB, Turb_ntu, 11: 6
# Shapefile for BB: Turb_ntu for period 11 of year 2023 has been saved as SHP_BB_Turb_ntu_2023_11.shp
# Number of data rows for BB, Turb_ntu, 12: 12
# Shapefile for BB: Turb_ntu for period 12 of year 2023 has been saved as SHP_BB_Turb_ntu_2023_12.shp
# Number of data rows for BB, T_c, 1: 6
# Shapefile for BB: T_c for period 1 of year 2022 has been saved as SHP_BB_T_c_2022_1.shp
# Number of data rows for BB, T_c, 2: 6
# Shapefile for BB: T_c for period 2 of year 2022 has been saved as SHP_BB_T_c_2022_2.shp
# Number of data rows for BB, T_c, 3: 6
# Shapefile for BB: T_c for period 3 of year 2022 has been saved as SHP_BB_T_c_2022_3.shp
# Number of data rows for BB, T_c, 4: 12
# Shapefile for BB: T_c for period 4 of year 2022 has been saved as SHP_BB_T_c_2022_4.shp
# Number of data rows for BB, T_c, 5: 5
# Shapefile for BB: T_c for period 5 of year 2022 has been saved as SHP_BB_T_c_2022_5.shp
# Number of data rows for BB, T_c, 6: 6
# Shapefile for BB: T_c for period 6 of year 2022 has been saved as SHP_BB_T_c_2022_6.shp
# Number of data rows for BB, T_c, 7: 12
# Shapefile for BB: T_c for period 7 of year 2022 has been saved as SHP_BB_T_c_2022_7.shp
# Number of data rows for BB, T_c, 8: 6
# Shapefile for BB: T_c for period 8 of year 2022 has been saved as SHP_BB_T_c_2022_8.shp
# Number of data rows for BB, T_c, 9: 12
# Shapefile for BB: T_c for period 9 of year 2022 has been saved as SHP_BB_T_c_2022_9.shp
# Number of data rows for BB, T_c, 10: 6
# Shapefile for BB: T_c for period 10 of year 2022 has been saved as SHP_BB_T_c_2022_10.shp
# Number of data rows for BB, T_c, 11: 6
# Shapefile for BB: T_c for period 11 of year 2023 has been saved as SHP_BB_T_c_2023_11.shp
# Number of data rows for BB, T_c, 12: 12
# Shapefile for BB: T_c for period 12 of year 2023 has been saved as SHP_BB_T_c_2023_12.shp
# Number of data rows for CH, DO_mgl, 1: 3
# Shapefile for CH: DO_mgl for period 1 of year 2017 has been saved as SHP_CH_DO_mgl_2017_1.shp
# Number of data rows for CH, DO_mgl, 2: 3
# Shapefile for CH: DO_mgl for period 2 of year 2017 has been saved as SHP_CH_DO_mgl_2017_2.shp
# Number of data rows for CH, DO_mgl, 3: 3
# Shapefile for CH: DO_mgl for period 3 of year 2017 has been saved as SHP_CH_DO_mgl_2017_3.shp
# Number of data rows for CH, DO_mgl, 4: 3
# Shapefile for CH: DO_mgl for period 4 of year 2017 has been saved as SHP_CH_DO_mgl_2017_4.shp
# Number of data rows for CH, DO_mgl, 5: 3
# Shapefile for CH: DO_mgl for period 5 of year 2017 has been saved as SHP_CH_DO_mgl_2017_5.shp
# Number of data rows for CH, DO_mgl, 6: 3
# Shapefile for CH: DO_mgl for period 6 of year 2017 has been saved as SHP_CH_DO_mgl_2017_6.shp
# Number of data rows for CH, DO_mgl, 7: 6
# Shapefile for CH: DO_mgl for period 7 of year 2017 has been saved as SHP_CH_DO_mgl_2017_7.shp
# Number of data rows for CH, DO_mgl, 8: 3
# Shapefile for CH: DO_mgl for period 8 of year 2017 has been saved as SHP_CH_DO_mgl_2017_8.shp
# Number of data rows for CH, DO_mgl, 9: 6
# Shapefile for CH: DO_mgl for period 9 of year 2017 has been saved as SHP_CH_DO_mgl_2017_9.shp
# Number of data rows for CH, DO_mgl, 10: 5
# Shapefile for CH: DO_mgl for period 10 of year 2017 has been saved as SHP_CH_DO_mgl_2017_10.shp
# Number of data rows for CH, DO_mgl, 11: 3
# Shapefile for CH: DO_mgl for period 11 of year 2018 has been saved as SHP_CH_DO_mgl_2018_11.shp
# Number of data rows for CH, DO_mgl, 12: 4
# Shapefile for CH: DO_mgl for period 12 of year 2018 has been saved as SHP_CH_DO_mgl_2018_12.shp
# Number of data rows for CH, Sal_ppt, 1: 3
# Shapefile for CH: Sal_ppt for period 1 of year 2017 has been saved as SHP_CH_Sal_ppt_2017_1.shp
# Number of data rows for CH, Sal_ppt, 2: 3
# Shapefile for CH: Sal_ppt for period 2 of year 2017 has been saved as SHP_CH_Sal_ppt_2017_2.shp
# Number of data rows for CH, Sal_ppt, 3: 3
# Shapefile for CH: Sal_ppt for period 3 of year 2017 has been saved as SHP_CH_Sal_ppt_2017_3.shp
# Number of data rows for CH, Sal_ppt, 4: 3
# Shapefile for CH: Sal_ppt for period 4 of year 2017 has been saved as SHP_CH_Sal_ppt_2017_4.shp
# Number of data rows for CH, Sal_ppt, 5: 3
# Shapefile for CH: Sal_ppt for period 5 of year 2017 has been saved as SHP_CH_Sal_ppt_2017_5.shp
# Number of data rows for CH, Sal_ppt, 6: 3
# Shapefile for CH: Sal_ppt for period 6 of year 2017 has been saved as SHP_CH_Sal_ppt_2017_6.shp
# Number of data rows for CH, Sal_ppt, 7: 6
# Shapefile for CH: Sal_ppt for period 7 of year 2017 has been saved as SHP_CH_Sal_ppt_2017_7.shp
# Number of data rows for CH, Sal_ppt, 8: 3
# Shapefile for CH: Sal_ppt for period 8 of year 2017 has been saved as SHP_CH_Sal_ppt_2017_8.shp
# Number of data rows for CH, Sal_ppt, 9: 6
# Shapefile for CH: Sal_ppt for period 9 of year 2017 has been saved as SHP_CH_Sal_ppt_2017_9.shp
# Number of data rows for CH, Sal_ppt, 10: 6
# Shapefile for CH: Sal_ppt for period 10 of year 2017 has been saved as SHP_CH_Sal_ppt_2017_10.shp
# Number of data rows for CH, Sal_ppt, 11: 3
# Shapefile for CH: Sal_ppt for period 11 of year 2018 has been saved as SHP_CH_Sal_ppt_2018_11.shp
# Number of data rows for CH, Sal_ppt, 12: 5
# Shapefile for CH: Sal_ppt for period 12 of year 2018 has been saved as SHP_CH_Sal_ppt_2018_12.shp
# Number of data rows for CH, Turb_ntu, 1: 3
# Shapefile for CH: Turb_ntu for period 1 of year 2017 has been saved as SHP_CH_Turb_ntu_2017_1.shp
# Number of data rows for CH, Turb_ntu, 2: 3
# Shapefile for CH: Turb_ntu for period 2 of year 2017 has been saved as SHP_CH_Turb_ntu_2017_2.shp
# Number of data rows for CH, Turb_ntu, 3: 3
# Shapefile for CH: Turb_ntu for period 3 of year 2017 has been saved as SHP_CH_Turb_ntu_2017_3.shp
# Number of data rows for CH, Turb_ntu, 4: 3
# Shapefile for CH: Turb_ntu for period 4 of year 2017 has been saved as SHP_CH_Turb_ntu_2017_4.shp
# Number of data rows for CH, Turb_ntu, 5: 3
# Shapefile for CH: Turb_ntu for period 5 of year 2017 has been saved as SHP_CH_Turb_ntu_2017_5.shp
# Number of data rows for CH, Turb_ntu, 6: 3
# Shapefile for CH: Turb_ntu for period 6 of year 2017 has been saved as SHP_CH_Turb_ntu_2017_6.shp
# Number of data rows for CH, Turb_ntu, 7: 5
# Shapefile for CH: Turb_ntu for period 7 of year 2017 has been saved as SHP_CH_Turb_ntu_2017_7.shp
# Number of data rows for CH, Turb_ntu, 8: 3
# Shapefile for CH: Turb_ntu for period 8 of year 2017 has been saved as SHP_CH_Turb_ntu_2017_8.shp
# Number of data rows for CH, Turb_ntu, 9: 6
# Shapefile for CH: Turb_ntu for period 9 of year 2017 has been saved as SHP_CH_Turb_ntu_2017_9.shp
# Number of data rows for CH, Turb_ntu, 10: 5
# Shapefile for CH: Turb_ntu for period 10 of year 2017 has been saved as SHP_CH_Turb_ntu_2017_10.shp
# Number of data rows for CH, Turb_ntu, 11: 3
# Shapefile for CH: Turb_ntu for period 11 of year 2018 has been saved as SHP_CH_Turb_ntu_2018_11.shp
# Number of data rows for CH, Turb_ntu, 12: 5
# Shapefile for CH: Turb_ntu for period 12 of year 2018 has been saved as SHP_CH_Turb_ntu_2018_12.shp
# Number of data rows for CH, T_c, 1: 3
# Shapefile for CH: T_c for period 1 of year 2017 has been saved as SHP_CH_T_c_2017_1.shp
# Number of data rows for CH, T_c, 2: 3
# Shapefile for CH: T_c for period 2 of year 2017 has been saved as SHP_CH_T_c_2017_2.shp
# Number of data rows for CH, T_c, 3: 3
# Shapefile for CH: T_c for period 3 of year 2017 has been saved as SHP_CH_T_c_2017_3.shp
# Number of data rows for CH, T_c, 4: 3
# Shapefile for CH: T_c for period 4 of year 2017 has been saved as SHP_CH_T_c_2017_4.shp
# Number of data rows for CH, T_c, 5: 3
# Shapefile for CH: T_c for period 5 of year 2017 has been saved as SHP_CH_T_c_2017_5.shp
# Number of data rows for CH, T_c, 6: 3
# Shapefile for CH: T_c for period 6 of year 2017 has been saved as SHP_CH_T_c_2017_6.shp
# Number of data rows for CH, T_c, 7: 6
# Shapefile for CH: T_c for period 7 of year 2017 has been saved as SHP_CH_T_c_2017_7.shp
# Number of data rows for CH, T_c, 8: 3
# Shapefile for CH: T_c for period 8 of year 2017 has been saved as SHP_CH_T_c_2017_8.shp
# Number of data rows for CH, T_c, 9: 6
# Shapefile for CH: T_c for period 9 of year 2017 has been saved as SHP_CH_T_c_2017_9.shp
# Number of data rows for CH, T_c, 10: 6
# Shapefile for CH: T_c for period 10 of year 2017 has been saved as SHP_CH_T_c_2017_10.shp
# Number of data rows for CH, T_c, 11: 3
# Shapefile for CH: T_c for period 11 of year 2018 has been saved as SHP_CH_T_c_2018_11.shp
# Number of data rows for CH, T_c, 12: 6
# Shapefile for CH: T_c for period 12 of year 2018 has been saved as SHP_CH_T_c_2018_12.shp
# Number of data rows for EB, DO_mgl, 1: 3
# Shapefile for EB: DO_mgl for period 1 of year 2017 has been saved as SHP_EB_DO_mgl_2017_1.shp
# Number of data rows for EB, DO_mgl, 2: 3
# Shapefile for EB: DO_mgl for period 2 of year 2017 has been saved as SHP_EB_DO_mgl_2017_2.shp
# Number of data rows for EB, DO_mgl, 3: 3
# Shapefile for EB: DO_mgl for period 3 of year 2017 has been saved as SHP_EB_DO_mgl_2017_3.shp
# Number of data rows for EB, DO_mgl, 4: 5
# Shapefile for EB: DO_mgl for period 4 of year 2017 has been saved as SHP_EB_DO_mgl_2017_4.shp
# Number of data rows for EB, DO_mgl, 5: 3
# Shapefile for EB: DO_mgl for period 5 of year 2017 has been saved as SHP_EB_DO_mgl_2017_5.shp
# Number of data rows for EB, DO_mgl, 6: 3
# Shapefile for EB: DO_mgl for period 6 of year 2017 has been saved as SHP_EB_DO_mgl_2017_6.shp
# Number of data rows for EB, DO_mgl, 7: 6
# Shapefile for EB: DO_mgl for period 7 of year 2017 has been saved as SHP_EB_DO_mgl_2017_7.shp
# Number of data rows for EB, DO_mgl, 8: 3
# Shapefile for EB: DO_mgl for period 8 of year 2017 has been saved as SHP_EB_DO_mgl_2017_8.shp
# Number of data rows for EB, DO_mgl, 9: 5
# Shapefile for EB: DO_mgl for period 9 of year 2017 has been saved as SHP_EB_DO_mgl_2017_9.shp
# Number of data rows for EB, DO_mgl, 10: 6
# Shapefile for EB: DO_mgl for period 10 of year 2017 has been saved as SHP_EB_DO_mgl_2017_10.shp
# Number of data rows for EB, DO_mgl, 11: 3
# Shapefile for EB: DO_mgl for period 11 of year 2018 has been saved as SHP_EB_DO_mgl_2018_11.shp
# Number of data rows for EB, DO_mgl, 12: 6
# Shapefile for EB: DO_mgl for period 12 of year 2018 has been saved as SHP_EB_DO_mgl_2018_12.shp
# Number of data rows for EB, Sal_ppt, 1: 3
# Shapefile for EB: Sal_ppt for period 1 of year 2017 has been saved as SHP_EB_Sal_ppt_2017_1.shp
# Number of data rows for EB, Sal_ppt, 2: 3
# Shapefile for EB: Sal_ppt for period 2 of year 2017 has been saved as SHP_EB_Sal_ppt_2017_2.shp
# Number of data rows for EB, Sal_ppt, 3: 3
# Shapefile for EB: Sal_ppt for period 3 of year 2017 has been saved as SHP_EB_Sal_ppt_2017_3.shp
# Number of data rows for EB, Sal_ppt, 4: 6
# Shapefile for EB: Sal_ppt for period 4 of year 2017 has been saved as SHP_EB_Sal_ppt_2017_4.shp
# Number of data rows for EB, Sal_ppt, 5: 3
# Shapefile for EB: Sal_ppt for period 5 of year 2017 has been saved as SHP_EB_Sal_ppt_2017_5.shp
# Number of data rows for EB, Sal_ppt, 6: 3
# Shapefile for EB: Sal_ppt for period 6 of year 2017 has been saved as SHP_EB_Sal_ppt_2017_6.shp
# Number of data rows for EB, Sal_ppt, 7: 6
# Shapefile for EB: Sal_ppt for period 7 of year 2017 has been saved as SHP_EB_Sal_ppt_2017_7.shp
# Number of data rows for EB, Sal_ppt, 8: 3
# Shapefile for EB: Sal_ppt for period 8 of year 2017 has been saved as SHP_EB_Sal_ppt_2017_8.shp
# Number of data rows for EB, Sal_ppt, 9: 5
# Shapefile for EB: Sal_ppt for period 9 of year 2017 has been saved as SHP_EB_Sal_ppt_2017_9.shp
# Number of data rows for EB, Sal_ppt, 10: 6
# Shapefile for EB: Sal_ppt for period 10 of year 2017 has been saved as SHP_EB_Sal_ppt_2017_10.shp
# Number of data rows for EB, Sal_ppt, 11: 3
# Shapefile for EB: Sal_ppt for period 11 of year 2018 has been saved as SHP_EB_Sal_ppt_2018_11.shp
# Number of data rows for EB, Sal_ppt, 12: 6
# Shapefile for EB: Sal_ppt for period 12 of year 2018 has been saved as SHP_EB_Sal_ppt_2018_12.shp
# Number of data rows for EB, Turb_ntu, 1: 3
# Shapefile for EB: Turb_ntu for period 1 of year 2017 has been saved as SHP_EB_Turb_ntu_2017_1.shp
# Number of data rows for EB, Turb_ntu, 2: 3
# Shapefile for EB: Turb_ntu for period 2 of year 2017 has been saved as SHP_EB_Turb_ntu_2017_2.shp
# Number of data rows for EB, Turb_ntu, 3: 3
# Shapefile for EB: Turb_ntu for period 3 of year 2017 has been saved as SHP_EB_Turb_ntu_2017_3.shp
# Number of data rows for EB, Turb_ntu, 4: 5
# Shapefile for EB: Turb_ntu for period 4 of year 2017 has been saved as SHP_EB_Turb_ntu_2017_4.shp
# Number of data rows for EB, Turb_ntu, 5: 2
# Shapefile for EB: Turb_ntu for period 5 of year 2017 has been saved as SHP_EB_Turb_ntu_2017_5.shp
# Number of data rows for EB, Turb_ntu, 6: 3
# Shapefile for EB: Turb_ntu for period 6 of year 2017 has been saved as SHP_EB_Turb_ntu_2017_6.shp
# Number of data rows for EB, Turb_ntu, 7: 6
# Shapefile for EB: Turb_ntu for period 7 of year 2017 has been saved as SHP_EB_Turb_ntu_2017_7.shp
# Number of data rows for EB, Turb_ntu, 8: 3
# Shapefile for EB: Turb_ntu for period 8 of year 2017 has been saved as SHP_EB_Turb_ntu_2017_8.shp
# Number of data rows for EB, Turb_ntu, 9: 4
# Shapefile for EB: Turb_ntu for period 9 of year 2017 has been saved as SHP_EB_Turb_ntu_2017_9.shp
# Number of data rows for EB, Turb_ntu, 10: 6
# Shapefile for EB: Turb_ntu for period 10 of year 2017 has been saved as SHP_EB_Turb_ntu_2017_10.shp
# Number of data rows for EB, Turb_ntu, 11: 3
# Shapefile for EB: Turb_ntu for period 11 of year 2018 has been saved as SHP_EB_Turb_ntu_2018_11.shp
# Number of data rows for EB, Turb_ntu, 12: 5
# Shapefile for EB: Turb_ntu for period 12 of year 2018 has been saved as SHP_EB_Turb_ntu_2018_12.shp
# Number of data rows for EB, T_c, 1: 3
# Shapefile for EB: T_c for period 1 of year 2017 has been saved as SHP_EB_T_c_2017_1.shp
# Number of data rows for EB, T_c, 2: 3
# Shapefile for EB: T_c for period 2 of year 2017 has been saved as SHP_EB_T_c_2017_2.shp
# Number of data rows for EB, T_c, 3: 3
# Shapefile for EB: T_c for period 3 of year 2017 has been saved as SHP_EB_T_c_2017_3.shp
# Number of data rows for EB, T_c, 4: 6
# Shapefile for EB: T_c for period 4 of year 2017 has been saved as SHP_EB_T_c_2017_4.shp
# Number of data rows for EB, T_c, 5: 3
# Shapefile for EB: T_c for period 5 of year 2017 has been saved as SHP_EB_T_c_2017_5.shp
# Number of data rows for EB, T_c, 6: 3
# Shapefile for EB: T_c for period 6 of year 2017 has been saved as SHP_EB_T_c_2017_6.shp
# Number of data rows for EB, T_c, 7: 6
# Shapefile for EB: T_c for period 7 of year 2017 has been saved as SHP_EB_T_c_2017_7.shp
# Number of data rows for EB, T_c, 8: 3
# Shapefile for EB: T_c for period 8 of year 2017 has been saved as SHP_EB_T_c_2017_8.shp
# Number of data rows for EB, T_c, 9: 6
# Shapefile for EB: T_c for period 9 of year 2017 has been saved as SHP_EB_T_c_2017_9.shp
# Number of data rows for EB, T_c, 10: 6
# Shapefile for EB: T_c for period 10 of year 2017 has been saved as SHP_EB_T_c_2017_10.shp
# Number of data rows for EB, T_c, 11: 3
# Shapefile for EB: T_c for period 11 of year 2018 has been saved as SHP_EB_T_c_2018_11.shp
# Number of data rows for EB, T_c, 12: 6
# Shapefile for EB: T_c for period 12 of year 2018 has been saved as SHP_EB_T_c_2018_12.shp
# Number of data rows for GTM, DO_mgl, 1: 4
# Shapefile for GTM: DO_mgl for period 1 of year 2016 has been saved as SHP_GTM_DO_mgl_2016_1.shp
# Number of data rows for GTM, DO_mgl, 2: 4
# Shapefile for GTM: DO_mgl for period 2 of year 2016 has been saved as SHP_GTM_DO_mgl_2016_2.shp
# Number of data rows for GTM, DO_mgl, 3: 8
# Shapefile for GTM: DO_mgl for period 3 of year 2016 has been saved as SHP_GTM_DO_mgl_2016_3.shp
# Number of data rows for GTM, DO_mgl, 4: 4
# Shapefile for GTM: DO_mgl for period 4 of year 2016 has been saved as SHP_GTM_DO_mgl_2016_4.shp
# Number of data rows for GTM, DO_mgl, 5: 4
# Shapefile for GTM: DO_mgl for period 5 of year 2016 has been saved as SHP_GTM_DO_mgl_2016_5.shp
# Number of data rows for GTM, DO_mgl, 6: 8
# Shapefile for GTM: DO_mgl for period 6 of year 2016 has been saved as SHP_GTM_DO_mgl_2016_6.shp
# Number of data rows for GTM, DO_mgl, 7: 4
# Shapefile for GTM: DO_mgl for period 7 of year 2016 has been saved as SHP_GTM_DO_mgl_2016_7.shp
# Number of data rows for GTM, DO_mgl, 8: 8
# Shapefile for GTM: DO_mgl for period 8 of year 2016 has been saved as SHP_GTM_DO_mgl_2016_8.shp
# Number of data rows for GTM, DO_mgl, 9: 8
# Shapefile for GTM: DO_mgl for period 9 of year 2016 has been saved as SHP_GTM_DO_mgl_2016_9.shp
# No valid data found for area: GTM, parameter: DO_mgl, period: 10
# Number of data rows for GTM, DO_mgl, 11: 4
# Shapefile for GTM: DO_mgl for period 11 of year 2017 has been saved as SHP_GTM_DO_mgl_2017_11.shp
# Number of data rows for GTM, DO_mgl, 12: 4
# Shapefile for GTM: DO_mgl for period 12 of year 2017 has been saved as SHP_GTM_DO_mgl_2017_12.shp
# Number of data rows for GTM, Sal_ppt, 1: 4
# Shapefile for GTM: Sal_ppt for period 1 of year 2016 has been saved as SHP_GTM_Sal_ppt_2016_1.shp
# Number of data rows for GTM, Sal_ppt, 2: 4
# Shapefile for GTM: Sal_ppt for period 2 of year 2016 has been saved as SHP_GTM_Sal_ppt_2016_2.shp
# Number of data rows for GTM, Sal_ppt, 3: 8
# Shapefile for GTM: Sal_ppt for period 3 of year 2016 has been saved as SHP_GTM_Sal_ppt_2016_3.shp
# Number of data rows for GTM, Sal_ppt, 4: 4
# Shapefile for GTM: Sal_ppt for period 4 of year 2016 has been saved as SHP_GTM_Sal_ppt_2016_4.shp
# Number of data rows for GTM, Sal_ppt, 5: 4
# Shapefile for GTM: Sal_ppt for period 5 of year 2016 has been saved as SHP_GTM_Sal_ppt_2016_5.shp
# Number of data rows for GTM, Sal_ppt, 6: 8
# Shapefile for GTM: Sal_ppt for period 6 of year 2016 has been saved as SHP_GTM_Sal_ppt_2016_6.shp
# Number of data rows for GTM, Sal_ppt, 7: 4
# Shapefile for GTM: Sal_ppt for period 7 of year 2016 has been saved as SHP_GTM_Sal_ppt_2016_7.shp
# Number of data rows for GTM, Sal_ppt, 8: 8
# Shapefile for GTM: Sal_ppt for period 8 of year 2016 has been saved as SHP_GTM_Sal_ppt_2016_8.shp
# Number of data rows for GTM, Sal_ppt, 9: 8
# Shapefile for GTM: Sal_ppt for period 9 of year 2016 has been saved as SHP_GTM_Sal_ppt_2016_9.shp
# No valid data found for area: GTM, parameter: Sal_ppt, period: 10
# Number of data rows for GTM, Sal_ppt, 11: 3
# Shapefile for GTM: Sal_ppt for period 11 of year 2017 has been saved as SHP_GTM_Sal_ppt_2017_11.shp
# Number of data rows for GTM, Sal_ppt, 12: 4
# Shapefile for GTM: Sal_ppt for period 12 of year 2017 has been saved as SHP_GTM_Sal_ppt_2017_12.shp
# Number of data rows for GTM, Turb_ntu, 1: 4
# Shapefile for GTM: Turb_ntu for period 1 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_1.shp
# Number of data rows for GTM, Turb_ntu, 2: 4
# Shapefile for GTM: Turb_ntu for period 2 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_2.shp
# Number of data rows for GTM, Turb_ntu, 3: 8
# Shapefile for GTM: Turb_ntu for period 3 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_3.shp
# Number of data rows for GTM, Turb_ntu, 4: 4
# Shapefile for GTM: Turb_ntu for period 4 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_4.shp
# Number of data rows for GTM, Turb_ntu, 5: 4
# Shapefile for GTM: Turb_ntu for period 5 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_5.shp
# Number of data rows for GTM, Turb_ntu, 6: 8
# Shapefile for GTM: Turb_ntu for period 6 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_6.shp
# Number of data rows for GTM, Turb_ntu, 7: 4
# Shapefile for GTM: Turb_ntu for period 7 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_7.shp
# Number of data rows for GTM, Turb_ntu, 8: 8
# Shapefile for GTM: Turb_ntu for period 8 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_8.shp
# Number of data rows for GTM, Turb_ntu, 9: 8
# Shapefile for GTM: Turb_ntu for period 9 of year 2016 has been saved as SHP_GTM_Turb_ntu_2016_9.shp
# No valid data found for area: GTM, parameter: Turb_ntu, period: 10
# Number of data rows for GTM, Turb_ntu, 11: 4
# Shapefile for GTM: Turb_ntu for period 11 of year 2017 has been saved as SHP_GTM_Turb_ntu_2017_11.shp
# Number of data rows for GTM, Turb_ntu, 12: 4
# Shapefile for GTM: Turb_ntu for period 12 of year 2017 has been saved as SHP_GTM_Turb_ntu_2017_12.shp
# Number of data rows for GTM, T_c, 1: 4
# Shapefile for GTM: T_c for period 1 of year 2016 has been saved as SHP_GTM_T_c_2016_1.shp
# Number of data rows for GTM, T_c, 2: 4
# Shapefile for GTM: T_c for period 2 of year 2016 has been saved as SHP_GTM_T_c_2016_2.shp
# Number of data rows for GTM, T_c, 3: 8
# Shapefile for GTM: T_c for period 3 of year 2016 has been saved as SHP_GTM_T_c_2016_3.shp
# Number of data rows for GTM, T_c, 4: 4
# Shapefile for GTM: T_c for period 4 of year 2016 has been saved as SHP_GTM_T_c_2016_4.shp
# Number of data rows for GTM, T_c, 5: 4
# Shapefile for GTM: T_c for period 5 of year 2016 has been saved as SHP_GTM_T_c_2016_5.shp
# Number of data rows for GTM, T_c, 6: 8
# Shapefile for GTM: T_c for period 6 of year 2016 has been saved as SHP_GTM_T_c_2016_6.shp
# Number of data rows for GTM, T_c, 7: 4
# Shapefile for GTM: T_c for period 7 of year 2016 has been saved as SHP_GTM_T_c_2016_7.shp
# Number of data rows for GTM, T_c, 8: 8
# Shapefile for GTM: T_c for period 8 of year 2016 has been saved as SHP_GTM_T_c_2016_8.shp
# Number of data rows for GTM, T_c, 9: 8
# Shapefile for GTM: T_c for period 9 of year 2016 has been saved as SHP_GTM_T_c_2016_9.shp
# No valid data found for area: GTM, parameter: T_c, period: 10
# Number of data rows for GTM, T_c, 11: 4
# Shapefile for GTM: T_c for period 11 of year 2017 has been saved as SHP_GTM_T_c_2017_11.shp
# Number of data rows for GTM, T_c, 12: 4
# Shapefile for GTM: T_c for period 12 of year 2017 has been saved as SHP_GTM_T_c_2017_12.shp

# %%
# Empty the shapefile folder
idw_rk_x.delete_all_files(idwCon_folder)

# %%
importlib.reload(idw_rk_x)


# If the number of data points is less than 3，skipping calculate IDW
idw_rk_x.idw_interpolation1(df_month_table, shpCon_folder, idwCon_folder, waterbody_extent, barrier_folder)
# Out:
# Processing file: SHP_BBS_DO_mgl_2021_1.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_DO_mgl_2021_1.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_1.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_2.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_DO_mgl_2021_2.shp
# 2
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_2.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_3.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_DO_mgl_2021_3.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_3.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_4.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_DO_mgl_2021_4.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_4.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_5.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_DO_mgl_2021_5.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_5.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_6.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_DO_mgl_2021_6.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_6.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_7.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_DO_mgl_2021_7.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_7.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_8.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_DO_mgl_2021_8.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_8.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_9.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_DO_mgl_2021_9.shp
# 2
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_9.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_10.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_DO_mgl_2021_10.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_10.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_11.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_DO_mgl_2021_11.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_11.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_12.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_DO_mgl_2021_12.shp
# 2
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_12.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_1.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Sal_ppt_2021_1.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_1.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_2.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Sal_ppt_2021_2.shp
# 2
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_2.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_3.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Sal_ppt_2021_3.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_3.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_4.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Sal_ppt_2021_4.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_4.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_5.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Sal_ppt_2021_5.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_5.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_6.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Sal_ppt_2021_6.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_6.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_7.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Sal_ppt_2021_7.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_7.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_8.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Sal_ppt_2021_8.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_8.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_9.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Sal_ppt_2021_9.shp
# 2
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_9.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_10.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Sal_ppt_2021_10.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_10.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_11.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Sal_ppt_2021_11.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_11.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_12.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Sal_ppt_2021_12.shp
# 2
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_12.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_1.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Turb_ntu_2021_1.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_1.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_2.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Turb_ntu_2021_2.shp
# 2
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_2.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_3.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Turb_ntu_2021_3.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_3.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_4.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Turb_ntu_2021_4.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_4.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_5.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Turb_ntu_2021_5.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_5.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_6.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Turb_ntu_2021_6.shp
# 2
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_6.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_7.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Turb_ntu_2021_7.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_7.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_8.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Turb_ntu_2021_8.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_8.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_9.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Turb_ntu_2021_9.shp
# 2
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_9.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_10.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Turb_ntu_2021_10.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_10.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_11.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Turb_ntu_2021_11.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_11.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_12.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_Turb_ntu_2021_12.shp
# 2
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_12.shp, skipping
# Processing file: SHP_BBS_T_c_2021_1.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_T_c_2021_1.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_1.shp, skipping
# Processing file: SHP_BBS_T_c_2021_2.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_T_c_2021_2.shp
# 2
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_2.shp, skipping
# Processing file: SHP_BBS_T_c_2021_3.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_T_c_2021_3.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_3.shp, skipping
# Processing file: SHP_BBS_T_c_2021_4.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_T_c_2021_4.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_4.shp, skipping
# Processing file: SHP_BBS_T_c_2021_5.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_T_c_2021_5.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_5.shp, skipping
# Processing file: SHP_BBS_T_c_2021_6.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_T_c_2021_6.shp
# 2
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_6.shp, skipping
# Processing file: SHP_BBS_T_c_2021_7.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_T_c_2021_7.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_7.shp, skipping
# Processing file: SHP_BBS_T_c_2021_8.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_T_c_2021_8.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_8.shp, skipping
# Processing file: SHP_BBS_T_c_2021_9.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_T_c_2021_9.shp
# 2
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_9.shp, skipping
# Processing file: SHP_BBS_T_c_2021_10.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_T_c_2021_10.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_10.shp, skipping
# Processing file: SHP_BBS_T_c_2021_11.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_T_c_2021_11.shp
# 1
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_11.shp, skipping
# Processing file: SHP_BBS_T_c_2021_12.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BBS_T_c_2021_12.shp
# 2
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_12.shp, skipping
# Processing file: SHP_BB_DO_mgl_2022_1.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_DO_mgl_2022_1.shp
# 6
# File SHP_BB_DO_mgl_2022_1.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_2.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_DO_mgl_2022_2.shp
# 6
# File SHP_BB_DO_mgl_2022_2.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_3.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_DO_mgl_2022_3.shp
# 6
# File SHP_BB_DO_mgl_2022_3.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_4.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_DO_mgl_2022_4.shp
# 12
# File SHP_BB_DO_mgl_2022_4.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_5.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_DO_mgl_2022_5.shp
# 5
# File SHP_BB_DO_mgl_2022_5.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_6.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_DO_mgl_2022_6.shp
# 6
# File SHP_BB_DO_mgl_2022_6.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_7.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_DO_mgl_2022_7.shp
# 12
# File SHP_BB_DO_mgl_2022_7.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_8.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_DO_mgl_2022_8.shp
# 6
# File SHP_BB_DO_mgl_2022_8.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_9.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_DO_mgl_2022_9.shp
# 12
# File SHP_BB_DO_mgl_2022_9.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_10.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_DO_mgl_2022_10.shp
# 6
# File SHP_BB_DO_mgl_2022_10.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2023_11.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_DO_mgl_2023_11.shp
# 6
# File SHP_BB_DO_mgl_2023_11.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2023_12.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_DO_mgl_2023_12.shp
# 12
# File SHP_BB_DO_mgl_2023_12.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_1.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Sal_ppt_2022_1.shp
# 6
# File SHP_BB_Sal_ppt_2022_1.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_2.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Sal_ppt_2022_2.shp
# 6
# File SHP_BB_Sal_ppt_2022_2.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_3.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Sal_ppt_2022_3.shp
# 6
# File SHP_BB_Sal_ppt_2022_3.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_4.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Sal_ppt_2022_4.shp
# 12
# File SHP_BB_Sal_ppt_2022_4.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_5.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Sal_ppt_2022_5.shp
# 5
# File SHP_BB_Sal_ppt_2022_5.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_6.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Sal_ppt_2022_6.shp
# 6
# File SHP_BB_Sal_ppt_2022_6.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_7.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Sal_ppt_2022_7.shp
# 12
# File SHP_BB_Sal_ppt_2022_7.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_8.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Sal_ppt_2022_8.shp
# 6
# File SHP_BB_Sal_ppt_2022_8.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_9.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Sal_ppt_2022_9.shp
# 12
# File SHP_BB_Sal_ppt_2022_9.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_10.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Sal_ppt_2022_10.shp
# 6
# File SHP_BB_Sal_ppt_2022_10.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2023_11.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Sal_ppt_2023_11.shp
# 6
# File SHP_BB_Sal_ppt_2023_11.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2023_12.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Sal_ppt_2023_12.shp
# 12
# File SHP_BB_Sal_ppt_2023_12.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_1.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Turb_ntu_2022_1.shp
# 6
# File SHP_BB_Turb_ntu_2022_1.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_2.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Turb_ntu_2022_2.shp
# 6
# File SHP_BB_Turb_ntu_2022_2.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_3.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Turb_ntu_2022_3.shp
# 6
# File SHP_BB_Turb_ntu_2022_3.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_4.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Turb_ntu_2022_4.shp
# 12
# File SHP_BB_Turb_ntu_2022_4.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_5.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Turb_ntu_2022_5.shp
# 5
# File SHP_BB_Turb_ntu_2022_5.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_6.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Turb_ntu_2022_6.shp
# 6
# File SHP_BB_Turb_ntu_2022_6.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_7.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Turb_ntu_2022_7.shp
# 12
# File SHP_BB_Turb_ntu_2022_7.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_8.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Turb_ntu_2022_8.shp
# 6
# File SHP_BB_Turb_ntu_2022_8.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_9.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Turb_ntu_2022_9.shp
# 12
# File SHP_BB_Turb_ntu_2022_9.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_10.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Turb_ntu_2022_10.shp
# 6
# File SHP_BB_Turb_ntu_2022_10.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2023_11.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Turb_ntu_2023_11.shp
# 6
# File SHP_BB_Turb_ntu_2023_11.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2023_12.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_Turb_ntu_2023_12.shp
# 12
# File SHP_BB_Turb_ntu_2023_12.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_1.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_T_c_2022_1.shp
# 6
# File SHP_BB_T_c_2022_1.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_2.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_T_c_2022_2.shp
# 6
# File SHP_BB_T_c_2022_2.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_3.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_T_c_2022_3.shp
# 6
# File SHP_BB_T_c_2022_3.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_4.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_T_c_2022_4.shp
# 12
# File SHP_BB_T_c_2022_4.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_5.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_T_c_2022_5.shp
# 5
# File SHP_BB_T_c_2022_5.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_6.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_T_c_2022_6.shp
# 6
# File SHP_BB_T_c_2022_6.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_7.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_T_c_2022_7.shp
# 12
# File SHP_BB_T_c_2022_7.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_8.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_T_c_2022_8.shp
# 6
# File SHP_BB_T_c_2022_8.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_9.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_T_c_2022_9.shp
# 12
# File SHP_BB_T_c_2022_9.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_10.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_T_c_2022_10.shp
# 6
# File SHP_BB_T_c_2022_10.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2023_11.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_T_c_2023_11.shp
# 6
# File SHP_BB_T_c_2023_11.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2023_12.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_BB_T_c_2023_12.shp
# 12
# File SHP_BB_T_c_2023_12.shp has completed 12 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_2017_1.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_DO_mgl_2017_1.shp
# 3
# File SHP_CH_DO_mgl_2017_1.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_2017_2.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_DO_mgl_2017_2.shp
# 3
# File SHP_CH_DO_mgl_2017_2.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_2017_3.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_DO_mgl_2017_3.shp
# 3
# File SHP_CH_DO_mgl_2017_3.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_2017_4.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_DO_mgl_2017_4.shp
# 3
# File SHP_CH_DO_mgl_2017_4.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_2017_5.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_DO_mgl_2017_5.shp
# 3
# File SHP_CH_DO_mgl_2017_5.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_2017_6.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_DO_mgl_2017_6.shp
# 3
# File SHP_CH_DO_mgl_2017_6.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_2017_7.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_DO_mgl_2017_7.shp
# 6
# File SHP_CH_DO_mgl_2017_7.shp has completed 6 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_2017_8.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_DO_mgl_2017_8.shp
# 3
# File SHP_CH_DO_mgl_2017_8.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_2017_9.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_DO_mgl_2017_9.shp
# 6
# File SHP_CH_DO_mgl_2017_9.shp has completed 6 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_2017_10.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_DO_mgl_2017_10.shp
# 5
# File SHP_CH_DO_mgl_2017_10.shp has completed 5 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_2018_11.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_DO_mgl_2018_11.shp
# 3
# File SHP_CH_DO_mgl_2018_11.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_2018_12.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_DO_mgl_2018_12.shp
# 4
# File SHP_CH_DO_mgl_2018_12.shp has completed 4 cross-validation iterations.
# Processing file: SHP_CH_Sal_ppt_2017_1.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Sal_ppt_2017_1.shp
# 3
# File SHP_CH_Sal_ppt_2017_1.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Sal_ppt_2017_2.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Sal_ppt_2017_2.shp
# 3
# File SHP_CH_Sal_ppt_2017_2.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Sal_ppt_2017_3.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Sal_ppt_2017_3.shp
# 3
# File SHP_CH_Sal_ppt_2017_3.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Sal_ppt_2017_4.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Sal_ppt_2017_4.shp
# 3
# File SHP_CH_Sal_ppt_2017_4.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Sal_ppt_2017_5.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Sal_ppt_2017_5.shp
# 3
# File SHP_CH_Sal_ppt_2017_5.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Sal_ppt_2017_6.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Sal_ppt_2017_6.shp
# 3
# File SHP_CH_Sal_ppt_2017_6.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Sal_ppt_2017_7.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Sal_ppt_2017_7.shp
# 6
# File SHP_CH_Sal_ppt_2017_7.shp has completed 6 cross-validation iterations.
# Processing file: SHP_CH_Sal_ppt_2017_8.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Sal_ppt_2017_8.shp
# 3
# File SHP_CH_Sal_ppt_2017_8.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Sal_ppt_2017_9.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Sal_ppt_2017_9.shp
# 6
# File SHP_CH_Sal_ppt_2017_9.shp has completed 6 cross-validation iterations.
# Processing file: SHP_CH_Sal_ppt_2017_10.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Sal_ppt_2017_10.shp
# 6
# File SHP_CH_Sal_ppt_2017_10.shp has completed 6 cross-validation iterations.
# Processing file: SHP_CH_Sal_ppt_2018_11.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Sal_ppt_2018_11.shp
# 3
# File SHP_CH_Sal_ppt_2018_11.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Sal_ppt_2018_12.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Sal_ppt_2018_12.shp
# 5
# File SHP_CH_Sal_ppt_2018_12.shp has completed 5 cross-validation iterations.
# Processing file: SHP_CH_Turb_ntu_2017_1.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Turb_ntu_2017_1.shp
# 3
# File SHP_CH_Turb_ntu_2017_1.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Turb_ntu_2017_2.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Turb_ntu_2017_2.shp
# 3
# File SHP_CH_Turb_ntu_2017_2.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Turb_ntu_2017_3.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Turb_ntu_2017_3.shp
# 3
# File SHP_CH_Turb_ntu_2017_3.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Turb_ntu_2017_4.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Turb_ntu_2017_4.shp
# 3
# File SHP_CH_Turb_ntu_2017_4.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Turb_ntu_2017_5.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Turb_ntu_2017_5.shp
# 3
# File SHP_CH_Turb_ntu_2017_5.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Turb_ntu_2017_6.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Turb_ntu_2017_6.shp
# 3
# File SHP_CH_Turb_ntu_2017_6.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Turb_ntu_2017_7.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Turb_ntu_2017_7.shp
# 5
# File SHP_CH_Turb_ntu_2017_7.shp has completed 5 cross-validation iterations.
# Processing file: SHP_CH_Turb_ntu_2017_8.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Turb_ntu_2017_8.shp
# 3
# File SHP_CH_Turb_ntu_2017_8.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Turb_ntu_2017_9.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Turb_ntu_2017_9.shp
# 6
# File SHP_CH_Turb_ntu_2017_9.shp has completed 6 cross-validation iterations.
# Processing file: SHP_CH_Turb_ntu_2017_10.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Turb_ntu_2017_10.shp
# 5
# File SHP_CH_Turb_ntu_2017_10.shp has completed 5 cross-validation iterations.
# Processing file: SHP_CH_Turb_ntu_2018_11.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Turb_ntu_2018_11.shp
# 3
# File SHP_CH_Turb_ntu_2018_11.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Turb_ntu_2018_12.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_Turb_ntu_2018_12.shp
# 5
# File SHP_CH_Turb_ntu_2018_12.shp has completed 5 cross-validation iterations.
# Processing file: SHP_CH_T_c_2017_1.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_T_c_2017_1.shp
# 3
# File SHP_CH_T_c_2017_1.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_T_c_2017_2.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_T_c_2017_2.shp
# 3
# File SHP_CH_T_c_2017_2.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_T_c_2017_3.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_T_c_2017_3.shp
# 3
# File SHP_CH_T_c_2017_3.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_T_c_2017_4.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_T_c_2017_4.shp
# 3
# File SHP_CH_T_c_2017_4.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_T_c_2017_5.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_T_c_2017_5.shp
# 3
# File SHP_CH_T_c_2017_5.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_T_c_2017_6.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_T_c_2017_6.shp
# 3
# File SHP_CH_T_c_2017_6.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_T_c_2017_7.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_T_c_2017_7.shp
# 6
# File SHP_CH_T_c_2017_7.shp has completed 6 cross-validation iterations.
# Processing file: SHP_CH_T_c_2017_8.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_T_c_2017_8.shp
# 3
# File SHP_CH_T_c_2017_8.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_T_c_2017_9.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_T_c_2017_9.shp
# 6
# File SHP_CH_T_c_2017_9.shp has completed 6 cross-validation iterations.
# Processing file: SHP_CH_T_c_2017_10.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_T_c_2017_10.shp
# 6
# File SHP_CH_T_c_2017_10.shp has completed 6 cross-validation iterations.
# Processing file: SHP_CH_T_c_2018_11.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_T_c_2018_11.shp
# 3
# File SHP_CH_T_c_2018_11.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_T_c_2018_12.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_CH_T_c_2018_12.shp
# 6
# File SHP_CH_T_c_2018_12.shp has completed 6 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2017_1.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_DO_mgl_2017_1.shp
# 3
# File SHP_EB_DO_mgl_2017_1.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2017_2.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_DO_mgl_2017_2.shp
# 3
# File SHP_EB_DO_mgl_2017_2.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2017_3.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_DO_mgl_2017_3.shp
# 3
# File SHP_EB_DO_mgl_2017_3.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2017_4.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_DO_mgl_2017_4.shp
# 5
# File SHP_EB_DO_mgl_2017_4.shp has completed 5 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2017_5.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_DO_mgl_2017_5.shp
# 3
# File SHP_EB_DO_mgl_2017_5.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2017_6.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_DO_mgl_2017_6.shp
# 3
# File SHP_EB_DO_mgl_2017_6.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2017_7.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_DO_mgl_2017_7.shp
# 6
# File SHP_EB_DO_mgl_2017_7.shp has completed 6 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2017_8.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_DO_mgl_2017_8.shp
# 3
# File SHP_EB_DO_mgl_2017_8.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2017_9.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_DO_mgl_2017_9.shp
# 5
# File SHP_EB_DO_mgl_2017_9.shp has completed 5 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2017_10.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_DO_mgl_2017_10.shp
# 6
# File SHP_EB_DO_mgl_2017_10.shp has completed 6 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2018_11.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_DO_mgl_2018_11.shp
# 3
# File SHP_EB_DO_mgl_2018_11.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2018_12.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_DO_mgl_2018_12.shp
# 6
# File SHP_EB_DO_mgl_2018_12.shp has completed 6 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_1.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Sal_ppt_2017_1.shp
# 3
# File SHP_EB_Sal_ppt_2017_1.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_2.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Sal_ppt_2017_2.shp
# 3
# File SHP_EB_Sal_ppt_2017_2.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_3.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Sal_ppt_2017_3.shp
# 3
# File SHP_EB_Sal_ppt_2017_3.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_4.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Sal_ppt_2017_4.shp
# 6
# File SHP_EB_Sal_ppt_2017_4.shp has completed 6 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_5.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Sal_ppt_2017_5.shp
# 3
# File SHP_EB_Sal_ppt_2017_5.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_6.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Sal_ppt_2017_6.shp
# 3
# File SHP_EB_Sal_ppt_2017_6.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_7.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Sal_ppt_2017_7.shp
# 6
# File SHP_EB_Sal_ppt_2017_7.shp has completed 6 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_8.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Sal_ppt_2017_8.shp
# 3
# File SHP_EB_Sal_ppt_2017_8.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_9.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Sal_ppt_2017_9.shp
# 5
# File SHP_EB_Sal_ppt_2017_9.shp has completed 5 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_10.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Sal_ppt_2017_10.shp
# 6
# File SHP_EB_Sal_ppt_2017_10.shp has completed 6 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2018_11.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Sal_ppt_2018_11.shp
# 3
# File SHP_EB_Sal_ppt_2018_11.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2018_12.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Sal_ppt_2018_12.shp
# 6
# File SHP_EB_Sal_ppt_2018_12.shp has completed 6 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_1.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Turb_ntu_2017_1.shp
# 3
# File SHP_EB_Turb_ntu_2017_1.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_2.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Turb_ntu_2017_2.shp
# 3
# File SHP_EB_Turb_ntu_2017_2.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_3.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Turb_ntu_2017_3.shp
# 3
# File SHP_EB_Turb_ntu_2017_3.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_4.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Turb_ntu_2017_4.shp
# 5
# File SHP_EB_Turb_ntu_2017_4.shp has completed 5 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_5.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Turb_ntu_2017_5.shp
# 2
# Not enough data for IDW interpolation in SHP_EB_Turb_ntu_2017_5.shp, skipping
# Processing file: SHP_EB_Turb_ntu_2017_6.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Turb_ntu_2017_6.shp
# 3
# File SHP_EB_Turb_ntu_2017_6.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_7.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Turb_ntu_2017_7.shp
# 6
# File SHP_EB_Turb_ntu_2017_7.shp has completed 6 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_8.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Turb_ntu_2017_8.shp
# 3
# File SHP_EB_Turb_ntu_2017_8.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_9.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Turb_ntu_2017_9.shp
# 4
# File SHP_EB_Turb_ntu_2017_9.shp has completed 4 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_10.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Turb_ntu_2017_10.shp
# 6
# File SHP_EB_Turb_ntu_2017_10.shp has completed 6 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2018_11.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Turb_ntu_2018_11.shp
# 3
# File SHP_EB_Turb_ntu_2018_11.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2018_12.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_Turb_ntu_2018_12.shp
# 5
# File SHP_EB_Turb_ntu_2018_12.shp has completed 5 cross-validation iterations.
# Processing file: SHP_EB_T_c_2017_1.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_T_c_2017_1.shp
# 3
# File SHP_EB_T_c_2017_1.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_T_c_2017_2.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_T_c_2017_2.shp
# 3
# File SHP_EB_T_c_2017_2.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_T_c_2017_3.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_T_c_2017_3.shp
# 3
# File SHP_EB_T_c_2017_3.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_T_c_2017_4.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_T_c_2017_4.shp
# 6
# File SHP_EB_T_c_2017_4.shp has completed 6 cross-validation iterations.
# Processing file: SHP_EB_T_c_2017_5.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_T_c_2017_5.shp
# 3
# File SHP_EB_T_c_2017_5.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_T_c_2017_6.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_T_c_2017_6.shp
# 3
# File SHP_EB_T_c_2017_6.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_T_c_2017_7.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_T_c_2017_7.shp
# 6
# File SHP_EB_T_c_2017_7.shp has completed 6 cross-validation iterations.
# Processing file: SHP_EB_T_c_2017_8.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_T_c_2017_8.shp
# 3
# File SHP_EB_T_c_2017_8.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_T_c_2017_9.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_T_c_2017_9.shp
# 6
# File SHP_EB_T_c_2017_9.shp has completed 6 cross-validation iterations.
# Processing file: SHP_EB_T_c_2017_10.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_T_c_2017_10.shp
# 6
# File SHP_EB_T_c_2017_10.shp has completed 6 cross-validation iterations.
# Processing file: SHP_EB_T_c_2018_11.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_T_c_2018_11.shp
# 3
# File SHP_EB_T_c_2018_11.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_T_c_2018_12.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_EB_T_c_2018_12.shp
# 6
# File SHP_EB_T_c_2018_12.shp has completed 6 cross-validation iterations.
# Processing file: SHP_GTM_DO_mgl_2016_1.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_DO_mgl_2016_1.shp
# 4
# File SHP_GTM_DO_mgl_2016_1.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_DO_mgl_2016_2.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_DO_mgl_2016_2.shp
# 4
# File SHP_GTM_DO_mgl_2016_2.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_DO_mgl_2016_3.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_DO_mgl_2016_3.shp
# 8
# File SHP_GTM_DO_mgl_2016_3.shp has completed 8 cross-validation iterations.
# Processing file: SHP_GTM_DO_mgl_2016_4.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_DO_mgl_2016_4.shp
# 4
# File SHP_GTM_DO_mgl_2016_4.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_DO_mgl_2016_5.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_DO_mgl_2016_5.shp
# 4
# File SHP_GTM_DO_mgl_2016_5.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_DO_mgl_2016_6.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_DO_mgl_2016_6.shp
# 8
# File SHP_GTM_DO_mgl_2016_6.shp has completed 8 cross-validation iterations.
# Processing file: SHP_GTM_DO_mgl_2016_7.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_DO_mgl_2016_7.shp
# 4
# File SHP_GTM_DO_mgl_2016_7.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_DO_mgl_2016_8.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_DO_mgl_2016_8.shp
# 8
# File SHP_GTM_DO_mgl_2016_8.shp has completed 8 cross-validation iterations.
# Processing file: SHP_GTM_DO_mgl_2016_9.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_DO_mgl_2016_9.shp
# 8
# File SHP_GTM_DO_mgl_2016_9.shp has completed 8 cross-validation iterations.
# Shapefile not found for: SHP_GTM_DO_mgl_2017_10.shp
# Processing file: SHP_GTM_DO_mgl_2017_11.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_DO_mgl_2017_11.shp
# 4
# File SHP_GTM_DO_mgl_2017_11.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_DO_mgl_2017_12.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_DO_mgl_2017_12.shp
# 4
# File SHP_GTM_DO_mgl_2017_12.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_1.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_Sal_ppt_2016_1.shp
# 4
# File SHP_GTM_Sal_ppt_2016_1.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_2.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_Sal_ppt_2016_2.shp
# 4
# File SHP_GTM_Sal_ppt_2016_2.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_3.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_Sal_ppt_2016_3.shp
# 8
# File SHP_GTM_Sal_ppt_2016_3.shp has completed 8 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_4.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_Sal_ppt_2016_4.shp
# 4
# File SHP_GTM_Sal_ppt_2016_4.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_5.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_Sal_ppt_2016_5.shp
# 4
# File SHP_GTM_Sal_ppt_2016_5.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_6.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_Sal_ppt_2016_6.shp
# 8
# File SHP_GTM_Sal_ppt_2016_6.shp has completed 8 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_7.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_Sal_ppt_2016_7.shp
# 4
# File SHP_GTM_Sal_ppt_2016_7.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_8.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_Sal_ppt_2016_8.shp
# 8
# File SHP_GTM_Sal_ppt_2016_8.shp has completed 8 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_9.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_Sal_ppt_2016_9.shp
# 8
# File SHP_GTM_Sal_ppt_2016_9.shp has completed 8 cross-validation iterations.
# Shapefile not found for: SHP_GTM_Sal_ppt_2017_10.shp
# Processing file: SHP_GTM_Sal_ppt_2017_11.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_Sal_ppt_2017_11.shp
# 3
# File SHP_GTM_Sal_ppt_2017_11.shp has completed 3 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2017_12.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_Sal_ppt_2017_12.shp
# 4
# File SHP_GTM_Sal_ppt_2017_12.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_1.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_Turb_ntu_2016_1.shp
# 4
# File SHP_GTM_Turb_ntu_2016_1.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_2.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_Turb_ntu_2016_2.shp
# 4
# File SHP_GTM_Turb_ntu_2016_2.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_3.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_Turb_ntu_2016_3.shp
# 8
# File SHP_GTM_Turb_ntu_2016_3.shp has completed 8 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_4.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_Turb_ntu_2016_4.shp
# 4
# File SHP_GTM_Turb_ntu_2016_4.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_5.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_Turb_ntu_2016_5.shp
# 4
# File SHP_GTM_Turb_ntu_2016_5.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_6.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_Turb_ntu_2016_6.shp
# 8
# File SHP_GTM_Turb_ntu_2016_6.shp has completed 8 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_7.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_Turb_ntu_2016_7.shp
# 4
# File SHP_GTM_Turb_ntu_2016_7.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_8.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_Turb_ntu_2016_8.shp
# 8
# File SHP_GTM_Turb_ntu_2016_8.shp has completed 8 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_9.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_Turb_ntu_2016_9.shp
# 8
# File SHP_GTM_Turb_ntu_2016_9.shp has completed 8 cross-validation iterations.
# Shapefile not found for: SHP_GTM_Turb_ntu_2017_10.shp
# Processing file: SHP_GTM_Turb_ntu_2017_11.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_Turb_ntu_2017_11.shp
# 4
# File SHP_GTM_Turb_ntu_2017_11.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2017_12.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_Turb_ntu_2017_12.shp
# 4
# File SHP_GTM_Turb_ntu_2017_12.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_1.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_T_c_2016_1.shp
# 4
# File SHP_GTM_T_c_2016_1.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_2.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_T_c_2016_2.shp
# 4
# File SHP_GTM_T_c_2016_2.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_3.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_T_c_2016_3.shp
# 8
# File SHP_GTM_T_c_2016_3.shp has completed 8 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_4.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_T_c_2016_4.shp
# 4
# File SHP_GTM_T_c_2016_4.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_5.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_T_c_2016_5.shp
# 4
# File SHP_GTM_T_c_2016_5.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_6.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_T_c_2016_6.shp
# 8
# File SHP_GTM_T_c_2016_6.shp has completed 8 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_7.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_T_c_2016_7.shp
# 4
# File SHP_GTM_T_c_2016_7.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_8.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_T_c_2016_8.shp
# 8
# File SHP_GTM_T_c_2016_8.shp has completed 8 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_9.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_T_c_2016_9.shp
# 8
# File SHP_GTM_T_c_2016_9.shp has completed 8 cross-validation iterations.
# Shapefile not found for: SHP_GTM_T_c_2017_10.shp
# Processing file: SHP_GTM_T_c_2017_11.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_T_c_2017_11.shp
# 4
# File SHP_GTM_T_c_2017_11.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2017_12.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/idw_month\SHP_GTM_T_c_2017_12.shp
# 4
# File SHP_GTM_T_c_2017_12.shp has completed 4 cross-validation iterations.
# Calculated RMSE: 0.985748851593547, ME: -0.16593440589999986 for file: SHP_GTM_T_c_2017_12.shp. Time used: 71757.52893733978
