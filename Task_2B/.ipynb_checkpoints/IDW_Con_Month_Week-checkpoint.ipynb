# %% [markdown]
# # IDW Interpolation for weekly intervals
# ## Task 2B
#
# This document includes Python codes that conduct cross validation (CV) for Inverse Distance Weighting (IDW) Interpolation on water quality parameters, including 4 water quality parameters in arcpy environment:
# - Dissolved oxygen (DO_mgl)
# - Salinity (Sal_ppt)
# - Turbidity (Turb_ntu)
# - Temperature (T_c)
#
# The analysis is conducted in the separate water bodies:
# - Guana Tolomato Matanzas (GTM)
# - Estero Bay (EB)
# - Charlotte Harbor (CH)
# - Biscayne Bay (BB)
# - Big Bend Seagrasses (BBS)
#
# **Tasks:**
#
# - Task 2A Calculate the RMSE and Mean Error (ME) for IDW results using both continuous and discrete data
#
# - **Task 2B Calculate the RMSE and Mean Error (ME) for IDW results using continuous data.**
#
#
# **Monthly: The SEACAR team would like the USF team to define their months as six 30-day
# increments prior to the storm day, and then six 30-day increments following the storm day.**
#
# **Weekly: The SEACAR team would like the USF team to define their weeks as 26 7-day
# increments prior to the storm day, and then 26 7-day increments following the storm day**
#
# **Contents:**
# * [1. Data Preprocess](#reg_preprocessing)
#     * [1.1 Subsetting Dataset](#reg_subset)
#     * [1.2 Preview Dataset](#reg_preview)
#     * [1.3 Fill Unique ID](#reg_id)
# * [2. Create Shapefile](#reg_create_shp)
# * [3. Cross Validation for IDW](#reg_cv_idw)
# * [4. Monthly Results](#month)

# %%
import pandas as pd
import numpy as np
import arcpy
from arcpy.sa import *
import os
import math
import warnings

import importlib
import sys
#path = r'F:\SEACAR_WQ_2024\git\misc'
path = r'E:\Projects\SEACAR_WQ_2024\git\misc'

sys.path.insert(0, path)
# import idw_rk
import idw_rk
# importlib.reload(idw_rk)
importlib.reload(idw_rk)

import pyproj

# define scratch folder to avoid overwritting from parallel threats

arcpy.env.scratchWorkspace = r"E:\Projects\SEACAR_WQ_2024\scratch/IDW_week"

warnings.filterwarnings('ignore')
arcpy.env.overwriteOutput = True

# %% [markdown]
# ## 1. Data Preprocessing <a class="anchor" id="reg_preprocessing"></a>
# ### 1.1 Load csv files

# %%
#gis_path = r'F:\SEACAR_WQ_2024/GIS_Data/'
gis_path = r'E:\Projects\SEACAR_WQ_2024/GIS_Data/'
dfCon = pd.read_csv(gis_path + 'OEAT_Continuous_WQ-2024-Feb-21.csv', low_memory=False)

# %% [markdown]
# ### Define output folder. Here is the folder setting for week.

# %%
# shpCon_folder = gis_path + r"shapefiles_Con/week"
# idwCon_folder = gis_path + r"idw_Con/week"

shpCon_folder = gis_path + r"shapefiles/IDW_Week"
idwCon_folder = gis_path + r"raster_output/IDW_Week"

# %% [markdown]
# ### 1.2 Subsetting Data <a class="anchor" id="reg_subset"></a>
#
# #### Include the time period from 8 am to 18 pm in a day

# %%
dfCon['SampleDate'] = pd.to_datetime(dfCon['SampleDate'], format='%Y-%m-%d %H:%M:%S.%f')

# Include date from 8:00 am to 18:00 pm
start_time = '08:00'
end_time = '18:00'

dfConTime = dfCon[dfCon['SampleDate'].dt.time.between(pd.to_datetime(start_time).time(), pd.to_datetime(end_time).time())]
dfConTime["SampleDate"] = pd.to_datetime(dfConTime['SampleDate'])
dfConTime.head()
# Out:
#    RowID  ProgramID      ParameterName ParameterUnits ProgramLocationID  \
# 0      1        512  Water Temperature      Degrees C             CHWW1
# 1      2        512  Water Temperature      Degrees C             CHWW1
# 2      3        512  Water Temperature      Degrees C             CHWW1
# 3      4        512  Water Temperature      Degrees C             CHWW1
# 4      5        512  Water Temperature      Degrees C             CHWW1
#
#    ActivityType          SampleDate  Year  Month RelativeDepth  ResultValue  \
# 0           NaN 2021-11-25 11:45:00  2021     11        bottom         19.2
# 1           NaN 2021-11-13 16:15:00  2021     11        bottom         22.3
# 2           NaN 2021-10-26 14:15:00  2021     10        bottom         28.3
# 3           NaN 2022-09-16 12:45:00  2022      9        bottom         29.7
# 4           NaN 2022-09-20 10:30:00  2022      9        bottom         29.3
#
#    Latitude_DD  Longitude_DD             ManagedAreaName  AreaID  \
# 0      26.8325     -82.14805  Cape Haze Aquatic Preserve       9
# 1      26.8325     -82.14805  Cape Haze Aquatic Preserve       9
# 2      26.8325     -82.14805  Cape Haze Aquatic Preserve       9
# 3      26.8325     -82.14805  Cape Haze Aquatic Preserve       9
# 4      26.8325     -82.14805  Cape Haze Aquatic Preserve       9
#
#   SEACAR_QAQCFlagCode         WaterBody WbodyAcronym Season
# 0                  6Q  Charlotte Harbor           CH   Fall
# 1                  6Q  Charlotte Harbor           CH   Fall
# 2                  6Q  Charlotte Harbor           CH   Fall
# 3                  6Q  Charlotte Harbor           CH   Fall
# 4                  6Q  Charlotte Harbor           CH   Fall

# %% [markdown]
# ### 1.3 Select the data based on the 52 weeks excel file.

# %%
area_ab = ["GTM","EB","CH","BB","BBS"]
period_type = [" 52 week"," Month"]
dfConTime["Period"] = ""
def select_data_period(df,area,period):
    sheet_name = str(area) + str(period)
    df_period_table = pd.read_excel(gis_path + "All_Waterbodies_Season_Month_Week_Definitions.xlsx",sheet_name=sheet_name)
    df_select_area = df[df["WbodyAcronym"]==str(area)]
    df_period_table['Start Date'] = pd.to_datetime(df_period_table['Start Date'])
    df_period_table['End Date']   = pd.to_datetime(df_period_table['End Date'])
    sub_dfs = []

    for index, row in df_period_table.iterrows():
        start_date = row['Start Date']
        end_date   = row['End Date']
        sub_df = df_select_area[(df_select_area['SampleDate'] >= start_date) & (df_select_area['SampleDate'] < end_date)]
        sub_df['Period'] = row["Week"]
        sub_dfs.append(sub_df)
        
    df_period = pd.concat(sub_dfs,ignore_index=True)
    return df_period

# %% [markdown]
# ### 1.4 Generate the aggregated mean value for weekly data.

# %%
sel_week_temp = []
for each in area_ab:
    df_week_temp = select_data_period(dfConTime,str(each)," 52 week")
    df_week_temp_group = df_week_temp.groupby(['WaterBody','ParameterName','ParameterUnits',
                                               'Latitude_DD','Longitude_DD','WbodyAcronym',"Period"])["ResultValue"].agg("mean").reset_index()
    sel_week_temp.append(df_week_temp_group)
df_week_select_Mean = pd.concat(sel_week_temp,ignore_index=True)

# %%
df_week_select_Mean.shape
# Out:
# (3236, 8)

# %%
df_week_select_Mean.head(50)
# Out:
#                   WaterBody     ParameterName ParameterUnits  Latitude_DD  \
# 0   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 1   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 2   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 3   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 4   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 5   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 6   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 7   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 8   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 9   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 10  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 11  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 12  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 13  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 14  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 15  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 16  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 17  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 18  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 19  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 20  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 21  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 22  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 23  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 24  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 25  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 26  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 27  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 28  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 29  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 30  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 31  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 32  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 33  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 34  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 35  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 36  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 37  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 38  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 39  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 40  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 41  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 42  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 43  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.737041
# 44  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.737041
# 45  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.737041
# 46  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.737041
# 47  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.737041
# 48  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.737041
# 49  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.737041
#
#     Longitude_DD WbodyAcronym  Period  ResultValue
# 0     -81.257403          GTM       1     5.624042
# 1     -81.257403          GTM       2     4.712892
# 2     -81.257403          GTM       3     4.316725
# 3     -81.257403          GTM       4     4.729592
# 4     -81.257403          GTM       5     5.155749
# 5     -81.257403          GTM       6     3.796167
# 6     -81.257403          GTM       7     4.293380
# 7     -81.257403          GTM       8     4.409059
# 8     -81.257403          GTM       9     4.025436
# 9     -81.257403          GTM      10     3.111498
# 10    -81.257403          GTM      11     3.617422
# 11    -81.257403          GTM      12     3.631707
# 12    -81.257403          GTM      13     3.416725
# 13    -81.257403          GTM      14     4.003484
# 14    -81.257403          GTM      15     3.051626
# 15    -81.257403          GTM      16     4.319310
# 16    -81.257403          GTM      17     3.404878
# 17    -81.257403          GTM      18     4.757491
# 18    -81.257403          GTM      19     3.314634
# 19    -81.257403          GTM      20     5.446341
# 20    -81.257403          GTM      21     4.838328
# 21    -81.257403          GTM      22     5.792334
# 22    -81.257403          GTM      23     4.788153
# 23    -81.257403          GTM      24     5.028920
# 24    -81.257403          GTM      25     4.721951
# 25    -81.257403          GTM      26     5.433798
# 26    -81.257403          GTM      27     3.042509
# 27    -81.257403          GTM      28     3.554704
# 28    -81.257403          GTM      29     4.092683
# 29    -81.257403          GTM      30     4.660667
# 30    -81.257403          GTM      32     5.649735
# 31    -81.257403          GTM      33     6.990244
# 32    -81.257403          GTM      34     6.492334
# 33    -81.257403          GTM      35     7.022997
# 34    -81.257403          GTM      36     6.835889
# 35    -81.257403          GTM      37     6.761324
# 36    -81.257403          GTM      38     6.585366
# 37    -81.257403          GTM      39     7.393496
# 38    -81.257403          GTM      48     5.937561
# 39    -81.257403          GTM      49     6.555749
# 40    -81.257403          GTM      50     6.351916
# 41    -81.257403          GTM      51     5.490592
# 42    -81.257403          GTM      52     5.486760
# 43    -81.245953          GTM       1     6.511498
# 44    -81.245953          GTM       2     6.605575
# 45    -81.245953          GTM       3     5.824739
# 46    -81.245953          GTM       4     5.827875
# 47    -81.245953          GTM       5     6.051220
# 48    -81.245953          GTM       6     5.721951
# 49    -81.245953          GTM       7     6.112892

# %% [markdown]
# ### 1.5 Convert coordinate system to EPSG: 3086<a class="anchor" id="reg_coordinate"></a>

# %%
# Define the EPSG codes for source (EPSG:4326) and target (EPSG:3086) coordinate systems
source_epsg = 'EPSG:4326'
target_epsg = 'EPSG:3086'

# Create a PyProj Transformer for the conversion
transformer = pyproj.Transformer.from_crs(source_epsg, target_epsg, always_xy=True)

# Define a function to apply the transformation to each row of the DataFrame
def transform_coordinates(row):
    x, y = transformer.transform(row['Longitude_DD'], row['Latitude_DD'])
    return pd.Series({'x': x, 'y': y})

# Apply the transformation function to the DataFrame and create new columns for the converted coordinates
df_week_select_Mean[['x', 'y']] = df_week_select_Mean.apply(transform_coordinates, axis=1)

# %% [markdown]
# ## 2. Prepare for batch interpolation<a class="anchor" id="reg_batch"></a>

# %%
area_shortnames = {
    'Guana Tolomato Matanzas': 'GTM',
    'Estero Bay': 'EB',
    'Charlotte Harbor': 'CH',
    'Biscayne Bay': 'BB',
    'Big Bend Seagrasses':'BBS'
}

param_shortnames = {
    'Salinity': 'Sal_ppt',
    'Total Nitrogen': 'TN_mgl',
    'Dissolved Oxygen': 'DO_mgl',
    'Turbidity':'Turb_ntu',
    'Secchi Depth':'Secc_m',
    'Water Temperature':'T_c'
}

# %% [markdown]
# ### 2.2 Define the barrier files

# %%
barrier_folder = os.path.join(gis_path, 'Barriers')
barrier_folder

barriers = []
for file in os.listdir(barrier_folder):
    if file.endswith(".shp"):
        barriers.append(os.path.join(barrier_folder, file))

for barrier in barriers:
    print(barrier)
# Out:
# E:\Projects\SEACAR_WQ_2024/GIS_Data/Barriers\BBS_Barriers.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/Barriers\BB_Barriers.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/Barriers\CH_Barriers.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/Barriers\EB_Barriers.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/Barriers\GTM_Barriers.shp

# %% [markdown]
# ### 2.3 Define waterbody boundary for spatial extent and masking

# %%
waterbody_extent = os.path.join(gis_path, 'OEAT_Waterbody_Boundaries', 'OEAT_Waterbody_Boundary.shp')

unique_waterbodies = []
with arcpy.da.SearchCursor(waterbody_extent, ['WaterbodyA']) as cursor:
    for row in cursor:
        unique_waterbodies.append(row[0])

print("Unique Waterbodies:", unique_waterbodies)
# Out:
# Unique Waterbodies: ['BBS', 'BB', 'CH', 'EB', 'GTM']

# %% [markdown]
# ### 2.4 Define and generate weekly table.

# %%
waterBody = ['Big Bend Seagrasses', 'Biscayne Bay', 'Charlotte Harbor', 'Estero Bay', 'Guana Tolomato Matanzas']
parameter = ['Dissolved Oxygen', 'Salinity', 'Turbidity', 'Water Temperature']
waterBody_list = []
parameter_list= []
week_list = []
for i in waterBody:
    for j in parameter:
        for k in range(1,53):
            waterBody_list.append(i)
            parameter_list.append(j)
            week_list.append(k)

# %%
df_week_table = pd.DataFrame({
    "WaterBody":waterBody_list,
    "Parameter":parameter_list,
    "Period":week_list
})
df_week_table["Filename"] = ""
df_week_table["NumDataPoints"] = ""
df_week_table["RMSE"] = ""
df_week_table["ME"] = ""
df_week_table["WbodyAcronym"] = df_week_table["WaterBody"].map(area_shortnames)

# %%
name_ab = df_week_table["WbodyAcronym"].unique()
para_list = df_week_table["Parameter"].unique()
dfs_sub = []
for each in name_ab:
    sheet_name_use = str(each) + " 52 week"
    df_period_table_used = pd.read_excel(gis_path + "All_Waterbodies_Season_Month_Week_Definitions.xlsx",sheet_name=sheet_name_use)
    startDate = list(df_period_table_used["Start Date"])
    endDate   = list(df_period_table_used["End Date"])
    for para in para_list:
        df_temp_use = df_week_table[(df_week_table["WbodyAcronym"]==str(each))&(df_week_table["Parameter"]==str(para))]
        df_temp_use["startDate"] = startDate
        df_temp_use["endDate"]   = endDate
        dfs_sub.append(df_temp_use)
df_week_table = pd.concat(dfs_sub)
df_week_table["Year"] = df_week_table["startDate"].dt.year
df_week_table.to_csv(gis_path + 'week_table.csv')

# %% [markdown]
# # 1.2 Preview Dataset <a class="anchor" id="reg_preview"></a>

# %%
df_week_select_Mean.head(50)
# Out:
#                   WaterBody     ParameterName ParameterUnits  Latitude_DD  \
# 0   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 1   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 2   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 3   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 4   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 5   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 6   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 7   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 8   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 9   Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 10  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 11  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 12  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 13  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 14  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 15  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 16  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 17  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 18  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 19  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 20  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 21  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 22  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 23  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 24  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 25  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 26  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 27  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 28  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 29  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 30  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 31  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 32  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 33  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 34  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 35  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 36  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 37  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 38  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 39  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 40  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 41  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 42  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.667071
# 43  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.737041
# 44  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.737041
# 45  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.737041
# 46  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.737041
# 47  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.737041
# 48  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.737041
# 49  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L    29.737041
#
#     Longitude_DD WbodyAcronym  Period  ResultValue             x             y
# 0     -81.257403          GTM       1     5.624042           inf           inf
# 1     -81.257403          GTM       2     4.712892  6.650546e+05  6.318682e+05
# 2     -81.257403          GTM       3     4.316725  6.650546e+05  6.318682e+05
# 3     -81.257403          GTM       4     4.729592  6.650546e+05  6.318682e+05
# 4     -81.257403          GTM       5     5.155749  6.650546e+05  6.318682e+05
# 5     -81.257403          GTM       6     3.796167  6.650546e+05  6.318682e+05
# 6     -81.257403          GTM       7     4.293380  6.650546e+05  6.318682e+05
# 7     -81.257403          GTM       8     4.409059  6.650546e+05  6.318682e+05
# 8     -81.257403          GTM       9     4.025436  6.650546e+05  6.318682e+05
# 9     -81.257403          GTM      10     3.111498  6.650546e+05  6.318682e+05
# 10    -81.257403          GTM      11     3.617422  6.650546e+05  6.318682e+05
# 11    -81.257403          GTM      12     3.631707  6.650546e+05  6.318682e+05
# 12    -81.257403          GTM      13     3.416725  6.650546e+05  6.318682e+05
# 13    -81.257403          GTM      14     4.003484  6.650546e+05  6.318682e+05
# 14    -81.257403          GTM      15     3.051626  6.650546e+05  6.318682e+05
# 15    -81.257403          GTM      16     4.319310  6.650546e+05  6.318682e+05
# 16    -81.257403          GTM      17     3.404878  6.650546e+05  6.318682e+05
# 17    -81.257403          GTM      18     4.757491  6.650546e+05  6.318682e+05
# 18    -81.257403          GTM      19     3.314634  6.650546e+05  6.318682e+05
# 19    -81.257403          GTM      20     5.446341  6.650546e+05  6.318682e+05
# 20    -81.257403          GTM      21     4.838328  6.650546e+05  6.318682e+05
# 21    -81.257403          GTM      22     5.792334  6.650546e+05  6.318682e+05
# 22    -81.257403          GTM      23     4.788153  6.650546e+05  6.318682e+05
# 23    -81.257403          GTM      24     5.028920  6.650546e+05  6.318682e+05
# 24    -81.257403          GTM      25     4.721951  6.650546e+05  6.318682e+05
# 25    -81.257403          GTM      26     5.433798  6.650546e+05  6.318682e+05
# 26    -81.257403          GTM      27     3.042509  6.650546e+05  6.318682e+05
# 27    -81.257403          GTM      28     3.554704  6.650546e+05  6.318682e+05
# 28    -81.257403          GTM      29     4.092683  6.650546e+05  6.318682e+05
# 29    -81.257403          GTM      30     4.660667  6.650546e+05  6.318682e+05
# 30    -81.257403          GTM      32     5.649735  6.650546e+05  6.318682e+05
# 31    -81.257403          GTM      33     6.990244  6.650546e+05  6.318682e+05
# 32    -81.257403          GTM      34     6.492334  6.650546e+05  6.318682e+05
# 33    -81.257403          GTM      35     7.022997  6.650546e+05  6.318682e+05
# 34    -81.257403          GTM      36     6.835889  6.650546e+05  6.318682e+05
# 35    -81.257403          GTM      37     6.761324  6.650546e+05  6.318682e+05
# 36    -81.257403          GTM      38     6.585366  6.650546e+05  6.318682e+05
# 37    -81.257403          GTM      39     7.393496  6.650546e+05  6.318682e+05
# 38    -81.257403          GTM      48     5.937561  6.650546e+05  6.318682e+05
# 39    -81.257403          GTM      49     6.555749  6.650546e+05  6.318682e+05
# 40    -81.257403          GTM      50     6.351916  6.650546e+05  6.318682e+05
# 41    -81.257403          GTM      51     5.490592  6.650546e+05  6.318682e+05
# 42    -81.257403          GTM      52     5.486760  6.650546e+05  6.318682e+05
# 43    -81.245953          GTM       1     6.511498  6.659875e+05  6.396592e+05
# 44    -81.245953          GTM       2     6.605575  6.659875e+05  6.396592e+05
# 45    -81.245953          GTM       3     5.824739  6.659875e+05  6.396592e+05
# 46    -81.245953          GTM       4     5.827875  6.659875e+05  6.396592e+05
# 47    -81.245953          GTM       5     6.051220  6.659875e+05  6.396592e+05
# 48    -81.245953          GTM       6     5.721951  6.659875e+05  6.396592e+05
# 49    -81.245953          GTM       7     6.112892  6.659875e+05  6.396592e+05

# %% [markdown]
# ## 1.3 Fill NaN RowID with unique ID, IDW function needs unique ID <a class="anchor" id="reg_id"></a>

# %%
idw_rk.fill_nan_rowids(df_week_select_Mean, 'RowID')

df_week_select_Mean['RowID'] = df_week_select_Mean['RowID'].astype(int)
df_week_select_Mean
# Out:
#                     WaterBody      ParameterName ParameterUnits  Latitude_DD  \
# 0     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L    29.667071
# 1     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L    29.667071
# 2     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L    29.667071
# 3     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L    29.667071
# 4     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L    29.667071
# ...                       ...                ...            ...          ...
# 3231      Big Bend Seagrasses  Water Temperature      Degrees C    29.647203
# 3232      Big Bend Seagrasses  Water Temperature      Degrees C    29.647203
# 3233      Big Bend Seagrasses  Water Temperature      Degrees C    29.647203
# 3234      Big Bend Seagrasses  Water Temperature      Degrees C    29.647203
# 3235      Big Bend Seagrasses  Water Temperature      Degrees C    29.647203
#
#       Longitude_DD WbodyAcronym  Period  ResultValue             x  \
# 0       -81.257403          GTM       1     5.624042           inf
# 1       -81.257403          GTM       2     4.712892  6.650546e+05
# 2       -81.257403          GTM       3     4.316725  6.650546e+05
# 3       -81.257403          GTM       4     4.729592  6.650546e+05
# 4       -81.257403          GTM       5     5.155749  6.650546e+05
# ...            ...          ...     ...          ...           ...
# 3231    -83.421196          BBS      48    16.659756  4.559525e+05
# 3232    -83.421196          BBS      49    20.009756  4.559525e+05
# 3233    -83.421196          BBS      50    20.522764  4.559525e+05
# 3234    -83.421196          BBS      51    16.418699  4.559525e+05
# 3235    -83.421196          BBS      52    21.246748  4.559525e+05
#
#                  y  RowID
# 0              inf      1
# 1     6.318682e+05      2
# 2     6.318682e+05      3
# 3     6.318682e+05      4
# 4     6.318682e+05      5
# ...            ...    ...
# 3231  6.268460e+05   3232
# 3232  6.268460e+05   3233
# 3233  6.268460e+05   3234
# 3234  6.268460e+05   3235
# 3235  6.268460e+05   3236
#
# [3236 rows x 11 columns]

# %% [markdown]
# # 2. Create Shapefile <a class="anchor" id="reg_create_shp"></a>

# %%
# Merge interested with latitude and longitude columns
seasons_con_coord = idw_rk.merge_with_lat_long1(df_week_table, df_week_select_Mean)

seasons_con_coord
# Out:
#                     WaterBody          Parameter  Period Filename  \
# 0         Big Bend Seagrasses   Dissolved Oxygen       1
# 1         Big Bend Seagrasses   Dissolved Oxygen       2
# 2         Big Bend Seagrasses   Dissolved Oxygen       3
# 3         Big Bend Seagrasses   Dissolved Oxygen       4
# 4         Big Bend Seagrasses   Dissolved Oxygen       5
# ...                       ...                ...     ...      ...
# 3270  Guana Tolomato Matanzas  Water Temperature      51
# 3271  Guana Tolomato Matanzas  Water Temperature      52
# 3272  Guana Tolomato Matanzas  Water Temperature      52
# 3273  Guana Tolomato Matanzas  Water Temperature      52
# 3274  Guana Tolomato Matanzas  Water Temperature      52
#
#      NumDataPoints RMSE ME WbodyAcronym  startDate    endDate  Year  \
# 0                                   BBS 2021-01-06 2021-01-12  2021
# 1                                   BBS 2021-01-13 2021-01-19  2021
# 2                                   BBS 2021-01-20 2021-01-26  2021
# 3                                   BBS 2021-01-27 2021-02-02  2021
# 4                                   BBS 2021-02-03 2021-02-09  2021
# ...            ...  ... ..          ...        ...        ...   ...
# 3270                                GTM 2017-03-25 2017-04-01  2017
# 3271                                GTM 2017-04-01 2017-04-08  2017
# 3272                                GTM 2017-04-01 2017-04-08  2017
# 3273                                GTM 2017-04-01 2017-04-08  2017
# 3274                                GTM 2017-04-01 2017-04-08  2017
#
#                   x              y  RowID  ResultValue
# 0     455952.502950  626846.023588   3036     8.334146
# 1     455952.502950  626846.023588   3037     8.486992
# 2     455952.502950  626846.023588   3038     8.124390
# 3     455952.502950  626846.023588   3039     7.903659
# 4     455952.502950  626846.023588   3040     8.734146
# ...             ...            ...    ...          ...
# 3270  653510.005839  674232.563906    687    22.810801
# 3271  665054.640076  631868.177645    556    24.600348
# 3272  665987.547779  639659.183554    600    21.855401
# 3273  659731.716683  654157.848803    644    22.620557
# 3274  653510.005839  674232.563906    688    23.841812
#
# [3275 rows x 15 columns]

# %%
idw_rk.create_shp_season1(seasons_con_coord, shpCon_folder)

# %% [markdown]
# # 3. Run IDW for weeks <a class="anchor" id="reg_cv_idw"></a>

# %%
# Empty the shapefile folder
# idw_rk_x.delete_all_files(idwCon_folder)

df_week_table[0:665]
# Out:
#                WaterBody         Parameter  Period                   Filename  \
# 0    Big Bend Seagrasses  Dissolved Oxygen       1  SHP_BBS_DO_mgl_2021_1.shp
# 1    Big Bend Seagrasses  Dissolved Oxygen       2  SHP_BBS_DO_mgl_2021_2.shp
# 2    Big Bend Seagrasses  Dissolved Oxygen       3  SHP_BBS_DO_mgl_2021_3.shp
# 3    Big Bend Seagrasses  Dissolved Oxygen       4  SHP_BBS_DO_mgl_2021_4.shp
# 4    Big Bend Seagrasses  Dissolved Oxygen       5  SHP_BBS_DO_mgl_2021_5.shp
# ..                   ...               ...     ...                        ...
# 660           Estero Bay  Dissolved Oxygen      37  SHP_EB_DO_mgl_2017_37.shp
# 661           Estero Bay  Dissolved Oxygen      38  SHP_EB_DO_mgl_2017_38.shp
# 662           Estero Bay  Dissolved Oxygen      39  SHP_EB_DO_mgl_2017_39.shp
# 663           Estero Bay  Dissolved Oxygen      40  SHP_EB_DO_mgl_2017_40.shp
# 664           Estero Bay  Dissolved Oxygen      41  SHP_EB_DO_mgl_2017_41.shp
#
#     NumDataPoints      RMSE        ME WbodyAcronym  startDate    endDate  Year
# 0               1       NaN       NaN          BBS 2021-01-06 2021-01-12  2021
# 1               1       NaN       NaN          BBS 2021-01-13 2021-01-19  2021
# 2               1       NaN       NaN          BBS 2021-01-20 2021-01-26  2021
# 3               1       NaN       NaN          BBS 2021-01-27 2021-02-02  2021
# 4               1       NaN       NaN          BBS 2021-02-03 2021-02-09  2021
# ..            ...       ...       ...          ...        ...        ...   ...
# 660             3  0.219432 -0.012975           EB 2017-11-19 2017-11-25  2017
# 661             2       NaN       NaN           EB 2017-11-26 2017-12-02  2017
# 662             2       NaN       NaN           EB 2017-12-03 2017-12-09  2017
# 663             3  0.605878 -0.059142           EB 2017-12-10 2017-12-16  2017
# 664             3   0.08516 -0.009179           EB 2017-12-17 2017-12-23  2017
#
# [665 rows x 11 columns]

# %%
# If the number of data points is less than 3，skipping calculate IDW
idw_rk_x.idw_interpolation1(df_week_table[665:], shpCon_folder, idwCon_folder, waterbody_extent, barrier_folder)
# Out:
# Processing file: SHP_EB_DO_mgl_2017_42.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_DO_mgl_2017_42.shp
# 3
# File SHP_EB_DO_mgl_2017_42.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2017_43.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_DO_mgl_2017_43.shp
# 3
# File SHP_EB_DO_mgl_2017_43.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2018_44.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_DO_mgl_2018_44.shp
# 3
# File SHP_EB_DO_mgl_2018_44.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2018_45.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_DO_mgl_2018_45.shp
# 3
# File SHP_EB_DO_mgl_2018_45.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2018_46.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_DO_mgl_2018_46.shp
# 3
# File SHP_EB_DO_mgl_2018_46.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2018_47.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_DO_mgl_2018_47.shp
# 3
# File SHP_EB_DO_mgl_2018_47.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2018_48.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_DO_mgl_2018_48.shp
# 3
# File SHP_EB_DO_mgl_2018_48.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2018_49.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_DO_mgl_2018_49.shp
# 3
# File SHP_EB_DO_mgl_2018_49.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2018_50.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_DO_mgl_2018_50.shp
# 3
# File SHP_EB_DO_mgl_2018_50.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2018_51.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_DO_mgl_2018_51.shp
# 3
# File SHP_EB_DO_mgl_2018_51.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2018_52.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_DO_mgl_2018_52.shp
# 3
# File SHP_EB_DO_mgl_2018_52.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_1.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_1.shp
# 3
# File SHP_EB_Sal_ppt_2017_1.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_2.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_2.shp
# 3
# File SHP_EB_Sal_ppt_2017_2.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_3.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_3.shp
# 3
# File SHP_EB_Sal_ppt_2017_3.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_4.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_4.shp
# 3
# File SHP_EB_Sal_ppt_2017_4.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_5.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_5.shp
# 3
# File SHP_EB_Sal_ppt_2017_5.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_6.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_6.shp
# 3
# File SHP_EB_Sal_ppt_2017_6.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_7.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_7.shp
# 3
# File SHP_EB_Sal_ppt_2017_7.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_8.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_8.shp
# 3
# File SHP_EB_Sal_ppt_2017_8.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_9.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_9.shp
# 3
# File SHP_EB_Sal_ppt_2017_9.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_10.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_10.shp
# 3
# File SHP_EB_Sal_ppt_2017_10.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_11.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_11.shp
# 3
# File SHP_EB_Sal_ppt_2017_11.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_12.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_12.shp
# 3
# File SHP_EB_Sal_ppt_2017_12.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_13.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_13.shp
# 3
# File SHP_EB_Sal_ppt_2017_13.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_14.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_14.shp
# 3
# File SHP_EB_Sal_ppt_2017_14.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_15.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_15.shp
# 3
# File SHP_EB_Sal_ppt_2017_15.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_16.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_16.shp
# 3
# File SHP_EB_Sal_ppt_2017_16.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_17.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_17.shp
# 3
# File SHP_EB_Sal_ppt_2017_17.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_18.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_18.shp
# 3
# File SHP_EB_Sal_ppt_2017_18.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_19.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_19.shp
# 3
# File SHP_EB_Sal_ppt_2017_19.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_20.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_20.shp
# 3
# File SHP_EB_Sal_ppt_2017_20.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_21.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_21.shp
# 3
# File SHP_EB_Sal_ppt_2017_21.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_22.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_22.shp
# 3
# File SHP_EB_Sal_ppt_2017_22.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_23.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_23.shp
# 3
# File SHP_EB_Sal_ppt_2017_23.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_24.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_24.shp
# 3
# File SHP_EB_Sal_ppt_2017_24.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_25.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_25.shp
# 3
# File SHP_EB_Sal_ppt_2017_25.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_26.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_26.shp
# 3
# File SHP_EB_Sal_ppt_2017_26.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_27.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_27.shp
# 3
# File SHP_EB_Sal_ppt_2017_27.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_28.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_28.shp
# 3
# File SHP_EB_Sal_ppt_2017_28.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_29.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_29.shp
# 3
# File SHP_EB_Sal_ppt_2017_29.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_30.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_30.shp
# 3
# File SHP_EB_Sal_ppt_2017_30.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_31.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_31.shp
# 3
# File SHP_EB_Sal_ppt_2017_31.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_32.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_32.shp
# 2
# Not enough data for IDW interpolation in SHP_EB_Sal_ppt_2017_32.shp, skipping
# Processing file: SHP_EB_Sal_ppt_2017_33.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_33.shp
# 2
# Not enough data for IDW interpolation in SHP_EB_Sal_ppt_2017_33.shp, skipping
# Processing file: SHP_EB_Sal_ppt_2017_34.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_34.shp
# 3
# File SHP_EB_Sal_ppt_2017_34.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_35.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_35.shp
# 3
# File SHP_EB_Sal_ppt_2017_35.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_36.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_36.shp
# 3
# File SHP_EB_Sal_ppt_2017_36.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_37.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_37.shp
# 3
# File SHP_EB_Sal_ppt_2017_37.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_38.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_38.shp
# 2
# Not enough data for IDW interpolation in SHP_EB_Sal_ppt_2017_38.shp, skipping
# Processing file: SHP_EB_Sal_ppt_2017_39.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_39.shp
# 2
# Not enough data for IDW interpolation in SHP_EB_Sal_ppt_2017_39.shp, skipping
# Processing file: SHP_EB_Sal_ppt_2017_40.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_40.shp
# 3
# File SHP_EB_Sal_ppt_2017_40.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_41.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_41.shp
# 3
# File SHP_EB_Sal_ppt_2017_41.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_42.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_42.shp
# 3
# File SHP_EB_Sal_ppt_2017_42.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_43.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2017_43.shp
# 3
# File SHP_EB_Sal_ppt_2017_43.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2018_44.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2018_44.shp
# 3
# File SHP_EB_Sal_ppt_2018_44.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2018_45.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2018_45.shp
# 3
# File SHP_EB_Sal_ppt_2018_45.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2018_46.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2018_46.shp
# 3
# File SHP_EB_Sal_ppt_2018_46.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2018_47.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2018_47.shp
# 3
# File SHP_EB_Sal_ppt_2018_47.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2018_48.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2018_48.shp
# 3
# File SHP_EB_Sal_ppt_2018_48.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2018_49.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2018_49.shp
# 3
# File SHP_EB_Sal_ppt_2018_49.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2018_50.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2018_50.shp
# 3
# File SHP_EB_Sal_ppt_2018_50.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2018_51.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2018_51.shp
# 3
# File SHP_EB_Sal_ppt_2018_51.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2018_52.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Sal_ppt_2018_52.shp
# 3
# File SHP_EB_Sal_ppt_2018_52.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_1.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_1.shp
# 2
# Not enough data for IDW interpolation in SHP_EB_Turb_ntu_2017_1.shp, skipping
# Processing file: SHP_EB_Turb_ntu_2017_2.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_2.shp
# 3
# File SHP_EB_Turb_ntu_2017_2.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_3.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_3.shp
# 2
# Not enough data for IDW interpolation in SHP_EB_Turb_ntu_2017_3.shp, skipping
# Processing file: SHP_EB_Turb_ntu_2017_4.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_4.shp
# 2
# Not enough data for IDW interpolation in SHP_EB_Turb_ntu_2017_4.shp, skipping
# Processing file: SHP_EB_Turb_ntu_2017_5.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_5.shp
# 2
# Not enough data for IDW interpolation in SHP_EB_Turb_ntu_2017_5.shp, skipping
# Processing file: SHP_EB_Turb_ntu_2017_6.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_6.shp
# 2
# Not enough data for IDW interpolation in SHP_EB_Turb_ntu_2017_6.shp, skipping
# Processing file: SHP_EB_Turb_ntu_2017_7.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_7.shp
# 2
# Not enough data for IDW interpolation in SHP_EB_Turb_ntu_2017_7.shp, skipping
# Processing file: SHP_EB_Turb_ntu_2017_8.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_8.shp
# 2
# Not enough data for IDW interpolation in SHP_EB_Turb_ntu_2017_8.shp, skipping
# Processing file: SHP_EB_Turb_ntu_2017_9.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_9.shp
# 3
# File SHP_EB_Turb_ntu_2017_9.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_10.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_10.shp
# 1
# Not enough data for IDW interpolation in SHP_EB_Turb_ntu_2017_10.shp, skipping
# Processing file: SHP_EB_Turb_ntu_2017_11.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_11.shp
# 1
# Not enough data for IDW interpolation in SHP_EB_Turb_ntu_2017_11.shp, skipping
# Processing file: SHP_EB_Turb_ntu_2017_12.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_12.shp
# 3
# File SHP_EB_Turb_ntu_2017_12.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_13.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_13.shp
# 2
# Not enough data for IDW interpolation in SHP_EB_Turb_ntu_2017_13.shp, skipping
# Processing file: SHP_EB_Turb_ntu_2017_14.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_14.shp
# 2
# Not enough data for IDW interpolation in SHP_EB_Turb_ntu_2017_14.shp, skipping
# Processing file: SHP_EB_Turb_ntu_2017_15.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_15.shp
# 3
# File SHP_EB_Turb_ntu_2017_15.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_16.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_16.shp
# 2
# Not enough data for IDW interpolation in SHP_EB_Turb_ntu_2017_16.shp, skipping
# Processing file: SHP_EB_Turb_ntu_2017_17.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_17.shp
# 3
# File SHP_EB_Turb_ntu_2017_17.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_18.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_18.shp
# 2
# Not enough data for IDW interpolation in SHP_EB_Turb_ntu_2017_18.shp, skipping
# Processing file: SHP_EB_Turb_ntu_2017_19.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_19.shp
# 2
# Not enough data for IDW interpolation in SHP_EB_Turb_ntu_2017_19.shp, skipping
# Processing file: SHP_EB_Turb_ntu_2017_20.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_20.shp
# 2
# Not enough data for IDW interpolation in SHP_EB_Turb_ntu_2017_20.shp, skipping
# Processing file: SHP_EB_Turb_ntu_2017_21.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_21.shp
# 2
# Not enough data for IDW interpolation in SHP_EB_Turb_ntu_2017_21.shp, skipping
# Processing file: SHP_EB_Turb_ntu_2017_22.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_22.shp
# 2
# Not enough data for IDW interpolation in SHP_EB_Turb_ntu_2017_22.shp, skipping
# Processing file: SHP_EB_Turb_ntu_2017_23.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_23.shp
# 3
# File SHP_EB_Turb_ntu_2017_23.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_24.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_24.shp
# 3
# File SHP_EB_Turb_ntu_2017_24.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_25.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_25.shp
# 3
# File SHP_EB_Turb_ntu_2017_25.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_26.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_26.shp
# 3
# File SHP_EB_Turb_ntu_2017_26.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_27.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/shapefiles/IDW_Week\SHP_EB_Turb_ntu_2017_27.shp
# 3
# File SHP_EB_Turb_ntu_2017_27.shp has completed 3 cross-validation iterations.

# %% [markdown]
# # 4. Monthly Results <a class="anchor" id="month"></a>

# %% [markdown]
# ### Set the folder path for weekly result

# %%
shpCon_folder = gis_path + r"shapefiles/IDW_Month"
idwCon_folder = gis_path + r"raster_output/IDW_Month"

# shpCon_folder = gis_path + r"shapefiles_Con/month"
# idwCon_folder = gis_path + r"idw_Con/month"

# %%
area_ab = ["GTM","EB","CH","BB","BBS"]
period_type = [" 52 week"," Month"]
dfConTime["Period"] = ""
def select_data_period1(df,area,period):
    sheet_name = str(area) + str(period)
    df_period_table = pd.read_excel(gis_path + "All_Waterbodies_Season_Month_Week_Definitions.xlsx",sheet_name=sheet_name)
    df_select_area = df[df["WbodyAcronym"]==str(area)]
    df_period_table['Start Date'] = pd.to_datetime(df_period_table['Start Date'])
    df_period_table['End Date']   = pd.to_datetime(df_period_table['End Date'])
    sub_dfs = []

    for index, row in df_period_table.iterrows():
        start_date = row['Start Date']
        end_date   = row['End Date']
        sub_df = df_select_area[(df_select_area['SampleDate'] >= start_date) & (df_select_area['SampleDate'] < end_date)]
        sub_df['Period'] = row["Month"]
        sub_dfs.append(sub_df)
        
    df_period = pd.concat(sub_dfs,ignore_index=True)
    return df_period

# %%
sel_month_temp = []
for each in area_ab:
    df_month_temp = select_data_period1(dfConTime,str(each)," Month")
    df_month_temp_group = df_month_temp.groupby(['WaterBody','ParameterName','ParameterUnits',
                                          'Latitude_DD','Longitude_DD','WbodyAcronym',"Period"])["ResultValue"].agg("mean").reset_index()
    sel_month_temp.append(df_month_temp_group)
df_month_select_Mean = pd.concat(sel_month_temp,ignore_index=True)

# %%
# Define the EPSG codes for source (EPSG:4326) and target (EPSG:3086) coordinate systems
source_epsg = 'EPSG:4326'
target_epsg = 'EPSG:3086'

# Create a PyProj Transformer for the conversion
transformer = pyproj.Transformer.from_crs(source_epsg, target_epsg, always_xy=True)

# Define a function to apply the transformation to each row of the DataFrame
def transform_coordinates(row):
    x, y = transformer.transform(row['Longitude_DD'], row['Latitude_DD'])
    return pd.Series({'x': x, 'y': y})

# Apply the transformation function to the DataFrame and create new columns for the converted coordinates
df_month_select_Mean[['x', 'y']] = df_month_select_Mean.apply(transform_coordinates, axis=1)

# %%
df_month_select_Mean

# %%
df_month_select_Mean[(df_month_select_Mean['WbodyAcronym'] == 'GTM') & 
(df_month_select_Mean['ParameterName'] == 'Turbidity') & 
(df_month_select_Mean['Period'] == 9)]

# %%
waterBody = ['Big Bend Seagrasses', 'Biscayne Bay', 'Charlotte Harbor', 'Estero Bay', 'Guana Tolomato Matanzas']
parameter = ['Dissolved Oxygen', 'Salinity', 'Turbidity', 'Water Temperature']
waterBody_list = []
parameter_list= []
month_list = []
for i in waterBody:
    for j in parameter:
        for k in range(1,13):
            waterBody_list.append(i)
            parameter_list.append(j)
            month_list.append(k)

# %%
df_month_table = pd.DataFrame({
    "WaterBody":waterBody_list,
    "Parameter":parameter_list,
    "Period":month_list
})
df_month_table["Filename"] = ""
df_month_table["NumDataPoints"] = ""
df_month_table["RMSE"] = ""
df_month_table["ME"] = ""
df_month_table["WbodyAcronym"] = df_month_table["WaterBody"].map(area_shortnames)

# %%
name_ab = df_month_table["WbodyAcronym"].unique()
para_list = df_month_table["Parameter"].unique()
dfs_sub = []
for each in name_ab:
    sheet_name_use = str(each) + " Month"
    df_period_table_used = pd.read_excel(gis_path + "All_Waterbodies_Season_Month_Week_Definitions.xlsx",sheet_name=sheet_name_use)
    startDate = list(df_period_table_used["Start Date"])
    endDate   = list(df_period_table_used["End Date"])
    for para in para_list:
        df_temp_use = df_month_table[(df_month_table["WbodyAcronym"]==str(each))&(df_month_table["Parameter"]==str(para))]
        df_temp_use["startDate"] = startDate
        df_temp_use["endDate"]   = endDate
        dfs_sub.append(df_temp_use)
df_month_table = pd.concat(dfs_sub)
df_month_table["Year"] = df_month_table["startDate"].dt.year
df_month_table.to_csv(gis_path + 'month_table.csv')

# %%
idw_rk_x.fill_nan_rowids(df_month_select_Mean, 'RowID')

df_month_select_Mean['RowID'] = df_month_select_Mean['RowID'].astype(int)
df_month_select_Mean

# %%
# idw_rk_x.delete_all_files(shpCon_folder)

# %%
# Merge interested with latitude and longitude columns
seasons_con_coord = idw_rk_x.merge_with_lat_long1(df_month_table, df_month_select_Mean)
seasons_con_coord

# %%
seasons_con_coord

# %%
# seasons_con_coord[(seasons_con_coord['WbodyAcronym'] == 'GTM') & 
# (seasons_con_coord['Parameter'] == 'Turbidity') & (seasons_con_coord['Period'] == 9)]

# %%
idw_rk_x.create_shp_season1(seasons_con_coord, shpCon_folder)

# %%
# Empty the shapefile folder
# idw_rk_x.delete_all_files(idwCon_folder)

# %%
importlib.reload(idw_rk_x)


# If the number of data points is less than 3，skipping calculate IDW
idw_rk_x.idw_interpolation1(df_month_table, shpCon_folder, idwCon_folder, waterbody_extent, barrier_folder)
