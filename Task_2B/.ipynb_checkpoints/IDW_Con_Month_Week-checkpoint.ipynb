# %% [markdown]
# # Cross Validation for IDW Interpolation
# ## Task 2A (continuous)
#
# This document includes Python codes that conduct cross validation (CV) for Inverse Distance Weighting (IDW) Interpolation on water quality parameters, including 4 water quality parameters in arcpy environment:
# - Dissolved oxygen (DO_mgl)
# - Salinity (Sal_ppt)
# - Turbidity (Turb_ntu)
# - Temperature (T_c)
#
# The analysis is conducted in the separate water bodies:
# - Guana Tolomato Matanzas (GTM)
# - Estero Bay (EB)
# - Charlotte Harbor (CH)
# - Biscayne Bay (BB)
# - Big Bend Seagrasses (BBS)
#
# **Tasks:**
#
# - Task 2A Calculate the RMSE and Mean Error (ME) for IDW results using both continuous and discrete data
#
# - **Task 2B Calculate the RMSE and Mean Error (ME) for IDW results using continuous data.**
#
#
# **Monthly: The SEACAR team would like the USF team to define their months as six 30-day
# increments prior to the storm day, and then six 30-day increments following the storm day.**
#
# **Weekly: The SEACAR team would like the USF team to define their weeks as 26 7-day
# increments prior to the storm day, and then 26 7-day increments following the storm day**
#
# **Contents:**
# * [1. Data Preprocess](#reg_preprocessing)
#     * [1.1 Subsetting Dataset](#reg_subset)
#     * [1.2 Preview Dataset](#reg_preview)
#     * [1.3 Fill Unique ID](#reg_id)
# * [2. Create Shapefile](#reg_create_shp)
# * [3. Cross Validation for IDW](#reg_cv_idw)
# * [4. Monthly Results](#month)

# %%
import pandas as pd
import numpy as np
import arcpy
from arcpy.sa import *
import os
import math
import warnings

import importlib
import sys
#path = r'F:\SEACAR_WQ_2024\git\misc'
path = r'E:\Projects\SEACAR_WQ_2024\git\misc'

sys.path.insert(0, path)
# import idw_rk
import idw_rk_x
# importlib.reload(idw_rk)
importlib.reload(idw_rk_x)

import pyproj

# define scratch folder to avoid overwritting from parallel threats
arcpy.env.scratchWorkspace = r"F:\SEACAR_WQ_2024\scratch/IDW_con"
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Data Preprocessing <a class="anchor" id="reg_preprocessing"></a>
# ### 1.1 Load csv files

# %%
# gis_path = r'F:\SEACAR_WQ_2024/GIS_Data/'
gis_path = r'E:\Projects\SEACAR_WQ_2024/GIS_Data/'
dfCon = pd.read_csv(gis_path + 'OEAT_Continuous_WQ-2024-Feb-21.csv', low_memory=False)

# %% [markdown]
# ### Define output folder. Here is the folder setting for week.

# %%
# shpCon_folder = gis_path + r"shapefiles_Con/week"
# idwCon_folder = gis_path + r"idw_Con/week"

shpCon_folder = gis_path + r"shapefiles/week"
idwCon_folder = gis_path + r"raster_output/week"

# %% [markdown]
# ### 1.2 Subsetting Data <a class="anchor" id="reg_subset"></a>
#
# #### Include the time period from 9 am to 17 pm in a day

# %%
dfCon['SampleDate'] = pd.to_datetime(dfCon['SampleDate'], format='%Y-%m-%d %H:%M:%S.%f')

# Include date from 9:00 am to 17:00 pm
start_time = '09:00'
end_time = '17:00'

dfConTime = dfCon[dfCon['SampleDate'].dt.time.between(pd.to_datetime(start_time).time(), pd.to_datetime(end_time).time())]
dfConTime["SampleDate"] = pd.to_datetime(dfConTime['SampleDate'])
dfConTime.head()
# Out:
#    RowID  ProgramID      ParameterName ParameterUnits ProgramLocationID  \
# 0      1        512  Water Temperature      Degrees C             CHWW1
# 1      2        512  Water Temperature      Degrees C             CHWW1
# 2      3        512  Water Temperature      Degrees C             CHWW1
# 3      4        512  Water Temperature      Degrees C             CHWW1
# 4      5        512  Water Temperature      Degrees C             CHWW1
#
#    ActivityType          SampleDate  Year  Month RelativeDepth  ResultValue  \
# 0           NaN 2021-11-25 11:45:00  2021     11        bottom         19.2
# 1           NaN 2021-11-13 16:15:00  2021     11        bottom         22.3
# 2           NaN 2021-10-26 14:15:00  2021     10        bottom         28.3
# 3           NaN 2022-09-16 12:45:00  2022      9        bottom         29.7
# 4           NaN 2022-09-20 10:30:00  2022      9        bottom         29.3
#
#    Latitude_DD  Longitude_DD             ManagedAreaName  AreaID  \
# 0      26.8325     -82.14805  Cape Haze Aquatic Preserve       9
# 1      26.8325     -82.14805  Cape Haze Aquatic Preserve       9
# 2      26.8325     -82.14805  Cape Haze Aquatic Preserve       9
# 3      26.8325     -82.14805  Cape Haze Aquatic Preserve       9
# 4      26.8325     -82.14805  Cape Haze Aquatic Preserve       9
#
#   SEACAR_QAQCFlagCode         WaterBody WbodyAcronym Season
# 0                  6Q  Charlotte Harbor           CH   Fall
# 1                  6Q  Charlotte Harbor           CH   Fall
# 2                  6Q  Charlotte Harbor           CH   Fall
# 3                  6Q  Charlotte Harbor           CH   Fall
# 4                  6Q  Charlotte Harbor           CH   Fall

# %% [markdown]
# ### 1.3 Select the data based on the 52 weeks excel file.

# %%
area_ab = ["GTM","EB","CH","BB","BBS"]
period_type = [" 52 week"," Month"]
dfConTime["Period"] = ""
def select_data_period(df,area,period):
    sheet_name = str(area) + str(period)
    df_period_table = pd.read_excel(gis_path + "All_Waterbodies_Season_Month_Week_Definitions.xlsx",sheet_name=sheet_name)
    df_select_area = df[df["WbodyAcronym"]==str(area)]
    df_period_table['Start Date'] = pd.to_datetime(df_period_table['Start Date'])
    df_period_table['End Date']   = pd.to_datetime(df_period_table['End Date'])
    sub_dfs = []

    for index, row in df_period_table.iterrows():
        start_date = row['Start Date']
        end_date   = row['End Date']
        sub_df = df_select_area[(df_select_area['SampleDate'] >= start_date) & (df_select_area['SampleDate'] < end_date)]
        sub_df['Period'] = row["Week"]
        sub_dfs.append(sub_df)
        
    df_period = pd.concat(sub_dfs,ignore_index=True)
    return df_period

# %% [markdown]
# ### 1.4 Generate the aggregated mean value for weekly data.

# %%
sel_week_temp = []
for each in area_ab:
    df_week_temp = select_data_period(dfConTime,str(each)," 52 week")
    df_week_temp_group = df_week_temp.groupby(['WaterBody','ParameterName','ParameterUnits',
                                          'Year','Season','Latitude_DD','Longitude_DD','WbodyAcronym',"Period"])["ResultValue"].agg("mean").reset_index()
    sel_week_temp.append(df_week_temp_group)
df_week_select_Mean = pd.concat(sel_week_temp,ignore_index=True)

# %%
df_week_select_Mean
# Out:
#                     WaterBody      ParameterName ParameterUnits  Year  Season  \
# 0     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 1     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 2     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 3     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 4     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# ...                       ...                ...            ...   ...     ...
# 3452      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 3453      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 3454      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 3455      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 3456      Big Bend Seagrasses  Water Temperature      Degrees C  2022  Winter
#
#       Latitude_DD  Longitude_DD WbodyAcronym  Period  ResultValue
# 0       29.667071    -81.257403          GTM      23     5.566667
# 1       29.667071    -81.257403          GTM      24     5.106926
# 2       29.667071    -81.257403          GTM      25     4.686580
# 3       29.667071    -81.257403          GTM      26     5.511688
# 4       29.667071    -81.257403          GTM      27     2.891775
# ...           ...           ...          ...     ...          ...
# 3452    29.647203    -83.421196          BBS      49    20.032828
# 3453    29.647203    -83.421196          BBS      50    20.496970
# 3454    29.647203    -83.421196          BBS      51    16.403535
# 3455    29.647203    -83.421196          BBS      52    21.236364
# 3456    29.647203    -83.421196          BBS      52    21.214141
#
# [3457 rows x 10 columns]

# %% [markdown]
# ### 1.5 Convert coordinate system to EPSG: 3086<a class="anchor" id="reg_coordinate"></a>

# %%
# Define the EPSG codes for source (EPSG:4326) and target (EPSG:3086) coordinate systems
source_epsg = 'EPSG:4326'
target_epsg = 'EPSG:3086'

# Create a PyProj Transformer for the conversion
transformer = pyproj.Transformer.from_crs(source_epsg, target_epsg, always_xy=True)

# Define a function to apply the transformation to each row of the DataFrame
def transform_coordinates(row):
    x, y = transformer.transform(row['Longitude_DD'], row['Latitude_DD'])
    return pd.Series({'x': x, 'y': y})

# Apply the transformation function to the DataFrame and create new columns for the converted coordinates
df_week_select_Mean[['x', 'y']] = df_week_select_Mean.apply(transform_coordinates, axis=1)

# %% [markdown]
# ## 2. Prepare for batch interpolation<a class="anchor" id="reg_batch"></a>

# %%
area_shortnames = {
    'Guana Tolomato Matanzas': 'GTM',
    'Estero Bay': 'EB',
    'Charlotte Harbor': 'CH',
    'Biscayne Bay': 'BB',
    'Big Bend Seagrasses':'BBS'
}

param_shortnames = {
    'Salinity': 'Sal_ppt',
    'Total Nitrogen': 'TN_mgl',
    'Dissolved Oxygen': 'DO_mgl',
    'Turbidity':'Turb_ntu',
    'Secchi Depth':'Secc_m',
    'Water Temperature':'T_c'
}

# %% [markdown]
# ### 2.2 Define the barrier files

# %%
barrier_folder = os.path.join(gis_path, 'Barriers')
barrier_folder

barriers = []
for file in os.listdir(barrier_folder):
    if file.endswith(".shp"):
        barriers.append(os.path.join(barrier_folder, file))

for barrier in barriers:
    print(barrier)
# Out:
# E:\Projects\SEACAR_WQ_2024/GIS_Data/Barriers\BBS_Barriers.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/Barriers\BB_Barriers.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/Barriers\CH_Barriers.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/Barriers\EB_Barriers.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/Barriers\GTM_Barriers.shp

# %% [markdown]
# ### 2.3 Define waterbody boundary for spatial extent and masking

# %%
waterbody_extent = os.path.join(gis_path, 'OEAT_Waterbody_Boundaries', 'OEAT_Waterbody_Boundary.shp')

unique_waterbodies = []
with arcpy.da.SearchCursor(waterbody_extent, ['WaterbodyA']) as cursor:
    for row in cursor:
        unique_waterbodies.append(row[0])

print("Unique Waterbodies:", unique_waterbodies)
# Out:
# Unique Waterbodies: ['BBS', 'BB', 'CH', 'EB', 'GTM']

# %% [markdown]
# ### 2.4 Define and generate weekly table.

# %%
waterBody = ['Big Bend Seagrasses', 'Biscayne Bay', 'Charlotte Harbor', 'Estero Bay', 'Guana Tolomato Matanzas']
parameter = ['Dissolved Oxygen', 'Salinity', 'Turbidity', 'Water Temperature']
waterBody_list = []
parameter_list= []
week_list = []
for i in waterBody:
    for j in parameter:
        for k in range(1,53):
            waterBody_list.append(i)
            parameter_list.append(j)
            week_list.append(k)

# %%
df_week_table = pd.DataFrame({
    "WaterBody":waterBody_list,
    "Parameter":parameter_list,
    "Period":week_list
})
df_week_table["Filename"] = ""
df_week_table["NumDataPoints"] = ""
df_week_table["RMSE"] = ""
df_week_table["ME"] = ""
df_week_table["WbodyAcronym"] = df_week_table["WaterBody"].map(area_shortnames)

# %%
name_ab = df_week_table["WbodyAcronym"].unique()
para_list = df_week_table["Parameter"].unique()
dfs_sub = []
for each in name_ab:
    sheet_name_use = str(each) + " 52 week"
    df_period_table_used = pd.read_excel(gis_path + "All_Waterbodies_Season_Month_Week_Definitions.xlsx",sheet_name=sheet_name_use)
    startDate = list(df_period_table_used["Start Date"])
    endDate   = list(df_period_table_used["End Date"])
    for para in para_list:
        df_temp_use = df_week_table[(df_week_table["WbodyAcronym"]==str(each))&(df_week_table["Parameter"]==str(para))]
        df_temp_use["startDate"] = startDate
        df_temp_use["endDate"]   = endDate
        dfs_sub.append(df_temp_use)
df_week_table = pd.concat(dfs_sub)
df_week_table.to_csv(gis_path + 'week_table.csv')

# %%
df_week_table
# Out:
#                     WaterBody          Parameter  Period Filename  \
# 0         Big Bend Seagrasses   Dissolved Oxygen       1
# 1         Big Bend Seagrasses   Dissolved Oxygen       2
# 2         Big Bend Seagrasses   Dissolved Oxygen       3
# 3         Big Bend Seagrasses   Dissolved Oxygen       4
# 4         Big Bend Seagrasses   Dissolved Oxygen       5
# ...                       ...                ...     ...      ...
# 1035  Guana Tolomato Matanzas  Water Temperature      48
# 1036  Guana Tolomato Matanzas  Water Temperature      49
# 1037  Guana Tolomato Matanzas  Water Temperature      50
# 1038  Guana Tolomato Matanzas  Water Temperature      51
# 1039  Guana Tolomato Matanzas  Water Temperature      52
#
#      NumDataPoints RMSE ME WbodyAcronym  startDate    endDate
# 0                                   BBS 2021-01-06 2021-01-12
# 1                                   BBS 2021-01-13 2021-01-19
# 2                                   BBS 2021-01-20 2021-01-26
# 3                                   BBS 2021-01-27 2021-02-02
# 4                                   BBS 2021-02-03 2021-02-09
# ...            ...  ... ..          ...        ...        ...
# 1035                                GTM 2017-03-04 2017-03-11
# 1036                                GTM 2017-03-11 2017-03-18
# 1037                                GTM 2017-03-18 2017-03-25
# 1038                                GTM 2017-03-25 2017-04-01
# 1039                                GTM 2017-04-01 2017-04-08
#
# [1040 rows x 10 columns]

# %% [markdown]
# # 1.2 Preview Dataset <a class="anchor" id="reg_preview"></a>

# %%
df_week_select_Mean.head()
# Out:
#                  WaterBody     ParameterName ParameterUnits  Year Season  \
# 0  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 1  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 2  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 3  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
# 4  Guana Tolomato Matanzas  Dissolved Oxygen           mg/L  2016   Fall
#
#    Latitude_DD  Longitude_DD WbodyAcronym  Period  ResultValue              x  \
# 0    29.667071    -81.257403          GTM      23     5.566667  665054.340859
# 1    29.667071    -81.257403          GTM      24     5.106926  665054.340859
# 2    29.667071    -81.257403          GTM      25     4.686580  665054.340859
# 3    29.667071    -81.257403          GTM      26     5.511688  665054.340859
# 4    29.667071    -81.257403          GTM      27     2.891775  665054.340859
#
#                y
# 0  631868.366218
# 1  631868.366218
# 2  631868.366218
# 3  631868.366218
# 4  631868.366218

# %% [markdown]
# ## 1.3 Fill NaN RowID with unique ID, IDW function needs unique ID <a class="anchor" id="reg_id"></a>

# %%
idw_rk_x.fill_nan_rowids(df_week_select_Mean, 'RowID')

df_week_select_Mean['RowID'] = df_week_select_Mean['RowID'].astype(int)
df_week_select_Mean
# Out:
#                     WaterBody      ParameterName ParameterUnits  Year  Season  \
# 0     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 1     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 2     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 3     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 4     Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# ...                       ...                ...            ...   ...     ...
# 3452      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 3453      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 3454      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 3455      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 3456      Big Bend Seagrasses  Water Temperature      Degrees C  2022  Winter
#
#       Latitude_DD  Longitude_DD WbodyAcronym  Period  ResultValue  \
# 0       29.667071    -81.257403          GTM      23     5.566667
# 1       29.667071    -81.257403          GTM      24     5.106926
# 2       29.667071    -81.257403          GTM      25     4.686580
# 3       29.667071    -81.257403          GTM      26     5.511688
# 4       29.667071    -81.257403          GTM      27     2.891775
# ...           ...           ...          ...     ...          ...
# 3452    29.647203    -83.421196          BBS      49    20.032828
# 3453    29.647203    -83.421196          BBS      50    20.496970
# 3454    29.647203    -83.421196          BBS      51    16.403535
# 3455    29.647203    -83.421196          BBS      52    21.236364
# 3456    29.647203    -83.421196          BBS      52    21.214141
#
#                   x              y  RowID
# 0     665054.340859  631868.366218      1
# 1     665054.340859  631868.366218      2
# 2     665054.340859  631868.366218      3
# 3     665054.340859  631868.366218      4
# 4     665054.340859  631868.366218      5
# ...             ...            ...    ...
# 3452  455952.242067  626846.365120   3453
# 3453  455952.242067  626846.365120   3454
# 3454  455952.242067  626846.365120   3455
# 3455  455952.242067  626846.365120   3456
# 3456  455952.242067  626846.365120   3457
#
# [3457 rows x 13 columns]

# %% [markdown]
# # 2. Create Shapefile <a class="anchor" id="reg_create_shp"></a>

# %%
idw_rk_x.delete_all_files(shpCon_folder)

# %%
# Merge interested with latitude and longitude columns
seasons_con_coord = idw_rk_x.merge_with_lat_long1(df_week_table, df_week_select_Mean)

# %%
seasons_con_coord
# Out:
#                     WaterBody          Parameter  Period Filename  \
# 0         Big Bend Seagrasses   Dissolved Oxygen       1
# 1         Big Bend Seagrasses   Dissolved Oxygen       2
# 2         Big Bend Seagrasses   Dissolved Oxygen       3
# 3         Big Bend Seagrasses   Dissolved Oxygen       4
# 4         Big Bend Seagrasses   Dissolved Oxygen       5
# ...                       ...                ...     ...      ...
# 3491  Guana Tolomato Matanzas  Water Temperature      51
# 3492  Guana Tolomato Matanzas  Water Temperature      52
# 3493  Guana Tolomato Matanzas  Water Temperature      52
# 3494  Guana Tolomato Matanzas  Water Temperature      52
# 3495  Guana Tolomato Matanzas  Water Temperature      52
#
#      NumDataPoints RMSE ME WbodyAcronym  startDate    endDate              x  \
# 0                                   BBS 2021-01-06 2021-01-12  455952.242067
# 1                                   BBS 2021-01-13 2021-01-19  455952.242067
# 2                                   BBS 2021-01-20 2021-01-26  455952.242067
# 3                                   BBS 2021-01-27 2021-02-02  455952.242067
# 4                                   BBS 2021-02-03 2021-02-09  455952.242067
# ...            ...  ... ..          ...        ...        ...            ...
# 3491                                GTM 2017-03-25 2017-04-01  653509.737698
# 3492                                GTM 2017-04-01 2017-04-08  665054.340859
# 3493                                GTM 2017-04-01 2017-04-08  665987.248566
# 3494                                GTM 2017-04-01 2017-04-08  659731.434296
# 3495                                GTM 2017-04-01 2017-04-08  653509.737698
#
#                   y  RowID  ResultValue
# 0     626846.365120   3286     8.345960
# 1     626846.365120   3287     8.507576
# 2     626846.365120   3288     8.120202
# 3     626846.365120   3289     7.933838
# 4     626846.365120   3290     8.726263
# ...             ...    ...          ...
# 3491  674232.732990    747    22.775325
# 3492  631868.366218    733    24.606061
# 3493  639659.363097    738    21.770996
# 3494  654158.019057    743    22.544156
# 3495  674232.732990    748    23.817749
#
# [3496 rows x 14 columns]

# %%
seasons_con_coord
# Out:
#                     WaterBody          Parameter  Period Filename  \
# 0         Big Bend Seagrasses   Dissolved Oxygen       1
# 1         Big Bend Seagrasses   Dissolved Oxygen       2
# 2         Big Bend Seagrasses   Dissolved Oxygen       3
# 3         Big Bend Seagrasses   Dissolved Oxygen       4
# 4         Big Bend Seagrasses   Dissolved Oxygen       5
# ...                       ...                ...     ...      ...
# 3491  Guana Tolomato Matanzas  Water Temperature      51
# 3492  Guana Tolomato Matanzas  Water Temperature      52
# 3493  Guana Tolomato Matanzas  Water Temperature      52
# 3494  Guana Tolomato Matanzas  Water Temperature      52
# 3495  Guana Tolomato Matanzas  Water Temperature      52
#
#      NumDataPoints RMSE ME WbodyAcronym  startDate    endDate              x  \
# 0                                   BBS 2021-01-06 2021-01-12  455952.242067
# 1                                   BBS 2021-01-13 2021-01-19  455952.242067
# 2                                   BBS 2021-01-20 2021-01-26  455952.242067
# 3                                   BBS 2021-01-27 2021-02-02  455952.242067
# 4                                   BBS 2021-02-03 2021-02-09  455952.242067
# ...            ...  ... ..          ...        ...        ...            ...
# 3491                                GTM 2017-03-25 2017-04-01  653509.737698
# 3492                                GTM 2017-04-01 2017-04-08  665054.340859
# 3493                                GTM 2017-04-01 2017-04-08  665987.248566
# 3494                                GTM 2017-04-01 2017-04-08  659731.434296
# 3495                                GTM 2017-04-01 2017-04-08  653509.737698
#
#                   y  RowID  ResultValue
# 0     626846.365120   3286     8.345960
# 1     626846.365120   3287     8.507576
# 2     626846.365120   3288     8.120202
# 3     626846.365120   3289     7.933838
# 4     626846.365120   3290     8.726263
# ...             ...    ...          ...
# 3491  674232.732990    747    22.775325
# 3492  631868.366218    733    24.606061
# 3493  639659.363097    738    21.770996
# 3494  654158.019057    743    22.544156
# 3495  674232.732990    748    23.817749
#
# [3496 rows x 14 columns]

# %%
shpCon_folder
# Out:
# 'E:\\Projects\\SEACAR_WQ_2024/GIS_Data/shapefiles/week'

# %%
idw_rk_x.create_shp_season1(seasons_con_coord, shpCon_folder)
# Out:
# Number of data rows for BBS, DO_mgl, 1: 1
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BBS_DO_mgl_1.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BBS, DO_mgl, 2: 1
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BBS_DO_mgl_2.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BBS, DO_mgl, 3: 1
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BBS_DO_mgl_3.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BBS, DO_mgl, 4: 1
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BBS_DO_mgl_4.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BBS, DO_mgl, 5: 1
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BBS_DO_mgl_5.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BBS, DO_mgl, 6: 1
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BBS_DO_mgl_6.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BBS, DO_mgl, 7: 1
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BBS_DO_mgl_7.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BBS, DO_mgl, 8: 1
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BBS_DO_mgl_8.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BBS, DO_mgl, 9: 1
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BBS_DO_mgl_9.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BBS, DO_mgl, 10: 1
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BBS_DO_mgl_10.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BBS, DO_mgl, 11: 1
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BBS_DO_mgl_11.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BBS, DO_mgl, 12: 1
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BBS_DO_mgl_12.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BBS, DO_mgl, 13: 1
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BBS_DO_mgl_13.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BBS, DO_mgl, 14: 1
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BBS_DO_mgl_14.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BBS, DO_mgl, 15: 1
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BBS_DO_mgl_15.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BBS, DO_mgl, 16: 1
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BBS_DO_mgl_16.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BBS, DO_mgl, 17: 1
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BBS_DO_mgl_17.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BBS, DO_mgl, 18: 1
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BBS_DO_mgl_18.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BBS, DO_mgl, 19: 1
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BBS_DO_mgl_19.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BBS, DO_mgl, 20: 1
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
# ...
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BB_Turb_ntu_29.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BB, Turb_ntu, 30: 6
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BB_Turb_ntu_30.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BB, Turb_ntu, 31: 6
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BB_Turb_ntu_31.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BB, Turb_ntu, 32: 6
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BB_Turb_ntu_32.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
#
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# KeyboardInterrupt:
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BB, Turb_ntu, 33: 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     134         if outputCS_env_name != input_sr.name:
#     135             transformation = arcpy.ListTransformations(input_sr, arcpy.env.outputCoordinateSystem)
# --> 136             transformation = transformation[0] if transformation else None
#     137     if out_fd:
#     138         createfc_sr = arcpy.Describe(os.path.dirname(output_fc)).spatialReference
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CreateTable(out_path, out_name, template, config_keyword, out_alias, oid_type)
#   20692     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#   20693     try:
# > 20694         retval = convertArcObjectToPythonObject(gp.CreateTable_management(*gp_fixargs((out_path, out_name, template, config_keyword, out_alias, oid_type), True)))
#   20695         return retval
#   20696     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# KeyboardInterrupt:
# Error occurred: ERROR 000582: Error occurred during execution.
#
# Number of data rows for BB, Turb_ntu, 34: 6
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in <module>
#     283         arcpy.AddIDMessage("WARNING", 100160)
#     284         arcpy.AddIDMessage("WARNING", 192, "{}: {}".format(str(arcpy.GetIDMessage(84526)).lower(),
# --> 285                                            ", ".join(empty_out_bounds)))
#     286
#     287     if nulls:
#
# c:\program files\arcgis\pro\Resources\ArcToolbox\scripts\XYTableToPoint.py in xy_table_to_points(in_table, output_fc, x_field, y_field, z_field, coordinate_system)
#     269                 except Exception as e:
#     270                     if str(e).find("nullable")>-1:
# --> 271                         arcpy.AddIDMessage("WARNING", 1086, str(e).split("[")[1][:-1])
#     272                     elif type(e) is RuntimeError:
#     273                         runtime.append(str(e))
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4201         return retval
#    4202     except Exception as e:
# -> 4203         raise e
#    4204
#    4205 @gptooldoc('DeleteFeatures_management', None)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    4198     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4199     try:
# -> 4200         retval = convertArcObjectToPythonObject(gp.CopyFeatures_management(*gp_fixargs((in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3), True)))
#    4201         return retval
#    4202     except Exception as e:
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     518         val = getattr(self._gp, attr)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#     522             return convertArcObjectToPythonObject(val)
#
# ExecuteError: ERROR 000210: Cannot create output E:\Projects\SEACAR_WQ_2024\GIS_Data\shapefiles\week\SHP_BB_Turb_ntu_34.shp
# ERROR 000308: Invalid field type
# Failed to execute (CopyFeatures).
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in XYTableToPoint(in_table, out_feature_class, x_field, y_field, z_field, coordinate_system)
#    4978     try:
# -> 4979         retval = convertArcObjectToPythonObject(gp.XYTableToPoint_management(*gp_fixargs((in_table, out_feature_class, x_field, y_field, z_field, coordinate_system), True)))
#    4980         return retval
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py in <lambda>(*args)
#     519         if callable(val):
# --> 520             return lambda *args: val(*gp_fixargs(args, True))
#     521         else:
#
# ExecuteError: ERROR 000582: Error occurred during execution.
#
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_244160\2857575790.py in <cell line: 1>()
# ----> 1 idw_rk_x.create_shp_season1(seasons_con_coord, shpCon_folder)
#
# E:\Projects\SEACAR_WQ_2024\git\misc\idw_rk_x.py in create_shp_season1(df, output_folder)
#     134             if arcpy.Exists(feature_class_path):
#     135                 arcpy.Delete_management(feature_class_path)
# --> 136             arcpy.management.XYTableToPoint(temp_csv_path, feature_class_path, "x", "y", coordinate_system=spatial_reference)
#     137
#     138             os.remove(temp_csv_path)
#
# C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py in XYTableToPoint(in_table, out_feature_class, x_field, y_field, z_field, coordinate_system)
#    4977     from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    4978     try:
# -> 4979         retval = convertArcObjectToPythonObject(gp.XYTableToPoint_management(*gp_fixargs((in_table, out_feature_class, x_field, y_field, z_field, coordinate_system), True)))
#    4980         return retval
#    4981     except Exception as e:
#
# KeyboardInterrupt:

# %% [markdown]
# # 3. Cross Validation for IDW <a class="anchor" id="reg_cv_idw"></a>

# %%
# Empty the shapefile folder
idw_rk.delete_all_files(idwCon_folder)

# %%
df_week_table
# Out:
#                     WaterBody          Parameter  Period Filename  \
# 0         Big Bend Seagrasses   Dissolved Oxygen       1
# 1         Big Bend Seagrasses   Dissolved Oxygen       2
# 2         Big Bend Seagrasses   Dissolved Oxygen       3
# 3         Big Bend Seagrasses   Dissolved Oxygen       4
# 4         Big Bend Seagrasses   Dissolved Oxygen       5
# ...                       ...                ...     ...      ...
# 1035  Guana Tolomato Matanzas  Water Temperature      48
# 1036  Guana Tolomato Matanzas  Water Temperature      49
# 1037  Guana Tolomato Matanzas  Water Temperature      50
# 1038  Guana Tolomato Matanzas  Water Temperature      51
# 1039  Guana Tolomato Matanzas  Water Temperature      52
#
#      NumDataPoints RMSE ME WbodyAcronym  startDate    endDate
# 0                                   BBS 2021-01-06 2021-01-12
# 1                                   BBS 2021-01-13 2021-01-19
# 2                                   BBS 2021-01-20 2021-01-26
# 3                                   BBS 2021-01-27 2021-02-02
# 4                                   BBS 2021-02-03 2021-02-09
# ...            ...  ... ..          ...        ...        ...
# 1035                                GTM 2017-03-04 2017-03-11
# 1036                                GTM 2017-03-11 2017-03-18
# 1037                                GTM 2017-03-18 2017-03-25
# 1038                                GTM 2017-03-25 2017-04-01
# 1039                                GTM 2017-04-01 2017-04-08
#
# [1040 rows x 10 columns]

# %%
# If the number of data points is less than 3，skipping calculate IDW
idw_rk.idw_interpolation1(df_week_table, shpCon_folder, idwCon_folder, waterbody_extent, barrier_folder)

# %% [markdown]
# # 4. Monthly Results <a class="anchor" id="month"></a>

# %% [markdown]
# ### Set the folder path for weekly result

# %%
shpCon_folder = gis_path + r"shapefiles_Con/month"
idwCon_folder = gis_path + r"idw_Con/month"

# %%
area_ab = ["GTM","EB","CH","BB","BBS"]
period_type = [" 52 week"," Month"]
dfConTime["Period"] = ""
def select_data_period1(df,area,period):
    sheet_name = str(area) + str(period)
    df_period_table = pd.read_excel(gis_path + "All_Waterbodies_Season_Month_Week_Definitions.xlsx",sheet_name=sheet_name)
    df_select_area = df[df["WbodyAcronym"]==str(area)]
    df_period_table['Start Date'] = pd.to_datetime(df_period_table['Start Date'])
    df_period_table['End Date']   = pd.to_datetime(df_period_table['End Date'])
    sub_dfs = []

    for index, row in df_period_table.iterrows():
        start_date = row['Start Date']
        end_date   = row['End Date']
        sub_df = df_select_area[(df_select_area['SampleDate'] >= start_date) & (df_select_area['SampleDate'] < end_date)]
        sub_df['Period'] = row["Month"]
        sub_dfs.append(sub_df)
        
    df_period = pd.concat(sub_dfs,ignore_index=True)
    return df_period

# %%
sel_month_temp = []
for each in area_ab:
    df_month_temp = select_data_period1(dfConTime,str(each)," Month")
    df_month_temp_group = df_month_temp.groupby(['WaterBody','ParameterName','ParameterUnits',
                                          'Year','Season','Latitude_DD','Longitude_DD','WbodyAcronym',"Period"])["ResultValue"].agg("mean").reset_index()
    sel_month_temp.append(df_month_temp_group)
df_month_select_Mean = pd.concat(sel_month_temp,ignore_index=True)

# %%
# Define the EPSG codes for source (EPSG:4326) and target (EPSG:3086) coordinate systems
source_epsg = 'EPSG:4326'
target_epsg = 'EPSG:3086'

# Create a PyProj Transformer for the conversion
transformer = pyproj.Transformer.from_crs(source_epsg, target_epsg, always_xy=True)

# Define a function to apply the transformation to each row of the DataFrame
def transform_coordinates(row):
    x, y = transformer.transform(row['Longitude_DD'], row['Latitude_DD'])
    return pd.Series({'x': x, 'y': y})

# Apply the transformation function to the DataFrame and create new columns for the converted coordinates
df_month_select_Mean[['x', 'y']] = df_month_select_Mean.apply(transform_coordinates, axis=1)

# %%
waterBody = ['Big Bend Seagrasses', 'Biscayne Bay', 'Charlotte Harbor', 'Estero Bay', 'Guana Tolomato Matanzas']
parameter = ['Dissolved Oxygen', 'Salinity', 'Turbidity', 'Water Temperature']
waterBody_list = []
parameter_list= []
month_list = []
for i in waterBody:
    for j in parameter:
        for k in range(1,13):
            waterBody_list.append(i)
            parameter_list.append(j)
            month_list.append(k)

# %%
df_month_table = pd.DataFrame({
    "WaterBody":waterBody_list,
    "Parameter":parameter_list,
    "Period":month_list
})
df_month_table["Filename"] = ""
df_month_table["NumDataPoints"] = ""
df_month_table["RMSE"] = ""
df_month_table["ME"] = ""
df_month_table["WbodyAcronym"] = df_month_table["WaterBody"].map(area_shortnames)

# %%
name_ab = df_month_table["WbodyAcronym"].unique()
para_list = df_month_table["Parameter"].unique()
dfs_sub = []
for each in name_ab:
    sheet_name_use = str(each) + " Month"
    df_period_table_used = pd.read_excel(gis_path + "All_Waterbodies_Season_Month_Week_Definitions.xlsx",sheet_name=sheet_name_use)
    startDate = list(df_period_table_used["Start Date"])
    endDate   = list(df_period_table_used["End Date"])
    for para in para_list:
        df_temp_use = df_month_table[(df_month_table["WbodyAcronym"]==str(each))&(df_month_table["Parameter"]==str(para))]
        df_temp_use["startDate"] = startDate
        df_temp_use["endDate"]   = endDate
        dfs_sub.append(df_temp_use)
df_month_table = pd.concat(dfs_sub)
df_month_table.to_csv(gis_path + 'month_table.csv')

# %%
df_month_table
# Out:
#                    WaterBody          Parameter  Period Filename  \
# 0        Big Bend Seagrasses   Dissolved Oxygen       1
# 1        Big Bend Seagrasses   Dissolved Oxygen       2
# 2        Big Bend Seagrasses   Dissolved Oxygen       3
# 3        Big Bend Seagrasses   Dissolved Oxygen       4
# 4        Big Bend Seagrasses   Dissolved Oxygen       5
# ..                       ...                ...     ...      ...
# 235  Guana Tolomato Matanzas  Water Temperature       8
# 236  Guana Tolomato Matanzas  Water Temperature       9
# 237  Guana Tolomato Matanzas  Water Temperature      10
# 238  Guana Tolomato Matanzas  Water Temperature      11
# 239  Guana Tolomato Matanzas  Water Temperature      12
#
#     NumDataPoints RMSE ME WbodyAcronym  startDate    endDate
# 0                                  BBS 2021-01-08 2021-02-06
# 1                                  BBS 2021-02-07 2021-03-08
# 2                                  BBS 2021-03-09 2021-04-07
# 3                                  BBS 2021-04-08 2021-05-07
# 4                                  BBS 2021-05-08 2021-06-06
# ..            ...  ... ..          ...        ...        ...
# 235                                GTM 2016-11-07 2016-12-07
# 236                                GTM 2016-12-07 2017-01-06
# 237                                GTM 2017-01-06 2017-02-05
# 238                                GTM 2017-02-05 2017-03-07
# 239                                GTM 2017-03-07 2017-04-06
#
# [240 rows x 10 columns]

# %%
idw_rk.fill_nan_rowids(df_month_select_Mean, 'RowID')

df_month_select_Mean['RowID'] = df_month_select_Mean['RowID'].astype(int)
df_month_select_Mean
# Out:
#                    WaterBody      ParameterName ParameterUnits  Year  Season  \
# 0    Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 1    Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 2    Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 3    Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# 4    Guana Tolomato Matanzas   Dissolved Oxygen           mg/L  2016    Fall
# ..                       ...                ...            ...   ...     ...
# 989      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Summer
# 990      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 991      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 992      Big Bend Seagrasses  Water Temperature      Degrees C  2021  Winter
# 993      Big Bend Seagrasses  Water Temperature      Degrees C  2022  Winter
#
#      Latitude_DD  Longitude_DD WbodyAcronym  Period  ResultValue  \
# 0      29.667071    -81.257403          GTM       6     5.142161
# 1      29.667071    -81.257403          GTM       7     3.728834
# 2      29.667071    -81.257403          GTM       8     6.632493
# 3      29.737041    -81.245953          GTM       6     5.606851
# 4      29.737041    -81.245953          GTM       7     6.354141
# ..           ...           ...          ...     ...          ...
# 989    29.647203    -83.421196          BBS       9    29.325253
# 990    29.647203    -83.421196          BBS       1    13.373354
# 991    29.647203    -83.421196          BBS       2    17.077020
# 992    29.647203    -83.421196          BBS      12    19.022835
# 993    29.647203    -83.421196          BBS      12    21.878788
#
#                  x              y  RowID
# 0    665054.340859  631868.366218      1
# 1    665054.340859  631868.366218      2
# 2    665054.340859  631868.366218      3
# 3    665987.248566  639659.363097      4
# 4    665987.248566  639659.363097      5
# ..             ...            ...    ...
# 989  455952.242067  626846.365120    990
# 990  455952.242067  626846.365120    991
# 991  455952.242067  626846.365120    992
# 992  455952.242067  626846.365120    993
# 993  455952.242067  626846.365120    994
#
# [994 rows x 13 columns]

# %%
# Merge interested with latitude and longitude columns
seasons_con_coord = idw_rk.merge_with_lat_long1(df_month_table, df_month_select_Mean)
seasons_con_coord
# Out:
#                     WaterBody          Parameter  Period Filename  \
# 0         Big Bend Seagrasses   Dissolved Oxygen       1
# 1         Big Bend Seagrasses   Dissolved Oxygen       2
# 2         Big Bend Seagrasses   Dissolved Oxygen       2
# 3         Big Bend Seagrasses   Dissolved Oxygen       3
# 4         Big Bend Seagrasses   Dissolved Oxygen       4
# ...                       ...                ...     ...      ...
# 997   Guana Tolomato Matanzas  Water Temperature      11
# 998   Guana Tolomato Matanzas  Water Temperature      12
# 999   Guana Tolomato Matanzas  Water Temperature      12
# 1000  Guana Tolomato Matanzas  Water Temperature      12
# 1001  Guana Tolomato Matanzas  Water Temperature      12
#
#      NumDataPoints RMSE ME WbodyAcronym  startDate    endDate              x  \
# 0                                   BBS 2021-01-08 2021-02-06  455952.242067
# 1                                   BBS 2021-02-07 2021-03-08  455952.242067
# 2                                   BBS 2021-02-07 2021-03-08  455952.242067
# 3                                   BBS 2021-03-09 2021-04-07  455952.242067
# 4                                   BBS 2021-04-08 2021-05-07  455952.242067
# ...            ...  ... ..          ...        ...        ...            ...
# 997                                 GTM 2017-02-05 2017-03-07  653509.737698
# 998                                 GTM 2017-03-07 2017-04-06  665054.340859
# 999                                 GTM 2017-03-07 2017-04-06  665987.248566
# 1000                                GTM 2017-03-07 2017-04-06  659731.434296
# 1001                                GTM 2017-03-07 2017-04-06  653509.737698
#
#                   y  RowID  ResultValue
# 0     626846.365120    944     8.356844
# 1     626846.365120    936     7.433333
# 2     626846.365120    945     7.730177
# 3     626846.365120    937     7.490700
# 4     626846.365120    938     6.859352
# ...             ...    ...          ...
# 997   674232.732990    234    18.666667
# 998   631868.366218    229    21.517071
# 999   639659.363097    231    20.061616
# 1000  654158.019057    233    20.107685
# 1001  674232.732990    235    20.587475
#
# [1002 rows x 14 columns]

# %%
idw_rk.create_shp_season1(seasons_con_coord, shpCon_folder)
# Out:
# Number of data rows for BBS, DO_mgl, 1: 1
# Shapefile for BBS: DO_mgl for period 1 has been saved as SHP_BBS_DO_mgl_1.shp
# Number of data rows for BBS, DO_mgl, 2: 2
# Shapefile for BBS: DO_mgl for period 2 has been saved as SHP_BBS_DO_mgl_2.shp
# Number of data rows for BBS, DO_mgl, 3: 1
# Shapefile for BBS: DO_mgl for period 3 has been saved as SHP_BBS_DO_mgl_3.shp
# Number of data rows for BBS, DO_mgl, 4: 1
# Shapefile for BBS: DO_mgl for period 4 has been saved as SHP_BBS_DO_mgl_4.shp
# Number of data rows for BBS, DO_mgl, 5: 1
# Shapefile for BBS: DO_mgl for period 5 has been saved as SHP_BBS_DO_mgl_5.shp
# Number of data rows for BBS, DO_mgl, 6: 1
# Shapefile for BBS: DO_mgl for period 6 has been saved as SHP_BBS_DO_mgl_6.shp
# Number of data rows for BBS, DO_mgl, 7: 1
# Shapefile for BBS: DO_mgl for period 7 has been saved as SHP_BBS_DO_mgl_7.shp
# Number of data rows for BBS, DO_mgl, 8: 1
# Shapefile for BBS: DO_mgl for period 8 has been saved as SHP_BBS_DO_mgl_8.shp
# Number of data rows for BBS, DO_mgl, 9: 2
# Shapefile for BBS: DO_mgl for period 9 has been saved as SHP_BBS_DO_mgl_9.shp
# Number of data rows for BBS, DO_mgl, 10: 1
# Shapefile for BBS: DO_mgl for period 10 has been saved as SHP_BBS_DO_mgl_10.shp
# Number of data rows for BBS, DO_mgl, 11: 1
# Shapefile for BBS: DO_mgl for period 11 has been saved as SHP_BBS_DO_mgl_11.shp
# Number of data rows for BBS, DO_mgl, 12: 2
# Shapefile for BBS: DO_mgl for period 12 has been saved as SHP_BBS_DO_mgl_12.shp
# Number of data rows for BBS, Sal_ppt, 1: 1
# Shapefile for BBS: Sal_ppt for period 1 has been saved as SHP_BBS_Sal_ppt_1.shp
# Number of data rows for BBS, Sal_ppt, 2: 2
# Shapefile for BBS: Sal_ppt for period 2 has been saved as SHP_BBS_Sal_ppt_2.shp
# Number of data rows for BBS, Sal_ppt, 3: 1
# Shapefile for BBS: Sal_ppt for period 3 has been saved as SHP_BBS_Sal_ppt_3.shp
# Number of data rows for BBS, Sal_ppt, 4: 1
# Shapefile for BBS: Sal_ppt for period 4 has been saved as SHP_BBS_Sal_ppt_4.shp
# Number of data rows for BBS, Sal_ppt, 5: 1
# Shapefile for BBS: Sal_ppt for period 5 has been saved as SHP_BBS_Sal_ppt_5.shp
# Number of data rows for BBS, Sal_ppt, 6: 1
# Shapefile for BBS: Sal_ppt for period 6 has been saved as SHP_BBS_Sal_ppt_6.shp
# Number of data rows for BBS, Sal_ppt, 7: 1
# Shapefile for BBS: Sal_ppt for period 7 has been saved as SHP_BBS_Sal_ppt_7.shp
# Number of data rows for BBS, Sal_ppt, 8: 1
# Shapefile for BBS: Sal_ppt for period 8 has been saved as SHP_BBS_Sal_ppt_8.shp
# Number of data rows for BBS, Sal_ppt, 9: 2
# Shapefile for BBS: Sal_ppt for period 9 has been saved as SHP_BBS_Sal_ppt_9.shp
# Number of data rows for BBS, Sal_ppt, 10: 1
# Shapefile for BBS: Sal_ppt for period 10 has been saved as SHP_BBS_Sal_ppt_10.shp
# Number of data rows for BBS, Sal_ppt, 11: 1
# Shapefile for BBS: Sal_ppt for period 11 has been saved as SHP_BBS_Sal_ppt_11.shp
# Number of data rows for BBS, Sal_ppt, 12: 2
# Shapefile for BBS: Sal_ppt for period 12 has been saved as SHP_BBS_Sal_ppt_12.shp
# Number of data rows for BBS, Turb_ntu, 1: 1
# Shapefile for BBS: Turb_ntu for period 1 has been saved as SHP_BBS_Turb_ntu_1.shp
# Number of data rows for BBS, Turb_ntu, 2: 2
# Shapefile for BBS: Turb_ntu for period 2 has been saved as SHP_BBS_Turb_ntu_2.shp
# Number of data rows for BBS, Turb_ntu, 3: 1
# Shapefile for BBS: Turb_ntu for period 3 has been saved as SHP_BBS_Turb_ntu_3.shp
# Number of data rows for BBS, Turb_ntu, 4: 1
# Shapefile for BBS: Turb_ntu for period 4 has been saved as SHP_BBS_Turb_ntu_4.shp
# Number of data rows for BBS, Turb_ntu, 5: 1
# Shapefile for BBS: Turb_ntu for period 5 has been saved as SHP_BBS_Turb_ntu_5.shp
# Number of data rows for BBS, Turb_ntu, 6: 2
# Shapefile for BBS: Turb_ntu for period 6 has been saved as SHP_BBS_Turb_ntu_6.shp
# Number of data rows for BBS, Turb_ntu, 7: 1
# Shapefile for BBS: Turb_ntu for period 7 has been saved as SHP_BBS_Turb_ntu_7.shp
# Number of data rows for BBS, Turb_ntu, 8: 1
# Shapefile for BBS: Turb_ntu for period 8 has been saved as SHP_BBS_Turb_ntu_8.shp
# Number of data rows for BBS, Turb_ntu, 9: 2
# Shapefile for BBS: Turb_ntu for period 9 has been saved as SHP_BBS_Turb_ntu_9.shp
# Number of data rows for BBS, Turb_ntu, 10: 1
# Shapefile for BBS: Turb_ntu for period 10 has been saved as SHP_BBS_Turb_ntu_10.shp
# Number of data rows for BBS, Turb_ntu, 11: 1
# Shapefile for BBS: Turb_ntu for period 11 has been saved as SHP_BBS_Turb_ntu_11.shp
# Number of data rows for BBS, Turb_ntu, 12: 2
# Shapefile for BBS: Turb_ntu for period 12 has been saved as SHP_BBS_Turb_ntu_12.shp
# Number of data rows for BBS, T_c, 1: 1
# Shapefile for BBS: T_c for period 1 has been saved as SHP_BBS_T_c_1.shp
# Number of data rows for BBS, T_c, 2: 2
# Shapefile for BBS: T_c for period 2 has been saved as SHP_BBS_T_c_2.shp
# Number of data rows for BBS, T_c, 3: 1
# Shapefile for BBS: T_c for period 3 has been saved as SHP_BBS_T_c_3.shp
# Number of data rows for BBS, T_c, 4: 1
# Shapefile for BBS: T_c for period 4 has been saved as SHP_BBS_T_c_4.shp
# Number of data rows for BBS, T_c, 5: 1
# Shapefile for BBS: T_c for period 5 has been saved as SHP_BBS_T_c_5.shp
# Number of data rows for BBS, T_c, 6: 2
# Shapefile for BBS: T_c for period 6 has been saved as SHP_BBS_T_c_6.shp
# Number of data rows for BBS, T_c, 7: 1
# Shapefile for BBS: T_c for period 7 has been saved as SHP_BBS_T_c_7.shp
# Number of data rows for BBS, T_c, 8: 1
# Shapefile for BBS: T_c for period 8 has been saved as SHP_BBS_T_c_8.shp
# Number of data rows for BBS, T_c, 9: 2
# Shapefile for BBS: T_c for period 9 has been saved as SHP_BBS_T_c_9.shp
# Number of data rows for BBS, T_c, 10: 1
# Shapefile for BBS: T_c for period 10 has been saved as SHP_BBS_T_c_10.shp
# Number of data rows for BBS, T_c, 11: 1
# Shapefile for BBS: T_c for period 11 has been saved as SHP_BBS_T_c_11.shp
# Number of data rows for BBS, T_c, 12: 2
# Shapefile for BBS: T_c for period 12 has been saved as SHP_BBS_T_c_12.shp
# Number of data rows for BB, DO_mgl, 1: 6
# Shapefile for BB: DO_mgl for period 1 has been saved as SHP_BB_DO_mgl_1.shp
# Number of data rows for BB, DO_mgl, 2: 6
# Shapefile for BB: DO_mgl for period 2 has been saved as SHP_BB_DO_mgl_2.shp
# Number of data rows for BB, DO_mgl, 3: 6
# Shapefile for BB: DO_mgl for period 3 has been saved as SHP_BB_DO_mgl_3.shp
# Number of data rows for BB, DO_mgl, 4: 12
# Shapefile for BB: DO_mgl for period 4 has been saved as SHP_BB_DO_mgl_4.shp
# Number of data rows for BB, DO_mgl, 5: 5
# Shapefile for BB: DO_mgl for period 5 has been saved as SHP_BB_DO_mgl_5.shp
# Number of data rows for BB, DO_mgl, 6: 6
# Shapefile for BB: DO_mgl for period 6 has been saved as SHP_BB_DO_mgl_6.shp
# Number of data rows for BB, DO_mgl, 7: 12
# Shapefile for BB: DO_mgl for period 7 has been saved as SHP_BB_DO_mgl_7.shp
# Number of data rows for BB, DO_mgl, 8: 6
# Shapefile for BB: DO_mgl for period 8 has been saved as SHP_BB_DO_mgl_8.shp
# Number of data rows for BB, DO_mgl, 9: 12
# Shapefile for BB: DO_mgl for period 9 has been saved as SHP_BB_DO_mgl_9.shp
# Number of data rows for BB, DO_mgl, 10: 6
# Shapefile for BB: DO_mgl for period 10 has been saved as SHP_BB_DO_mgl_10.shp
# Number of data rows for BB, DO_mgl, 11: 1
# Shapefile for BB: DO_mgl for period 11 has been saved as SHP_BB_DO_mgl_11.shp
# No valid data found for area: BB, parameter: DO_mgl, period: 12
# Number of data rows for BB, Sal_ppt, 1: 6
# Shapefile for BB: Sal_ppt for period 1 has been saved as SHP_BB_Sal_ppt_1.shp
# Number of data rows for BB, Sal_ppt, 2: 6
# Shapefile for BB: Sal_ppt for period 2 has been saved as SHP_BB_Sal_ppt_2.shp
# Number of data rows for BB, Sal_ppt, 3: 6
# Shapefile for BB: Sal_ppt for period 3 has been saved as SHP_BB_Sal_ppt_3.shp
# Number of data rows for BB, Sal_ppt, 4: 12
# Shapefile for BB: Sal_ppt for period 4 has been saved as SHP_BB_Sal_ppt_4.shp
# Number of data rows for BB, Sal_ppt, 5: 5
# Shapefile for BB: Sal_ppt for period 5 has been saved as SHP_BB_Sal_ppt_5.shp
# Number of data rows for BB, Sal_ppt, 6: 6
# Shapefile for BB: Sal_ppt for period 6 has been saved as SHP_BB_Sal_ppt_6.shp
# Number of data rows for BB, Sal_ppt, 7: 12
# Shapefile for BB: Sal_ppt for period 7 has been saved as SHP_BB_Sal_ppt_7.shp
# Number of data rows for BB, Sal_ppt, 8: 6
# Shapefile for BB: Sal_ppt for period 8 has been saved as SHP_BB_Sal_ppt_8.shp
# Number of data rows for BB, Sal_ppt, 9: 12
# Shapefile for BB: Sal_ppt for period 9 has been saved as SHP_BB_Sal_ppt_9.shp
# Number of data rows for BB, Sal_ppt, 10: 6
# Shapefile for BB: Sal_ppt for period 10 has been saved as SHP_BB_Sal_ppt_10.shp
# Number of data rows for BB, Sal_ppt, 11: 1
# Shapefile for BB: Sal_ppt for period 11 has been saved as SHP_BB_Sal_ppt_11.shp
# No valid data found for area: BB, parameter: Sal_ppt, period: 12
# Number of data rows for BB, Turb_ntu, 1: 6
# Shapefile for BB: Turb_ntu for period 1 has been saved as SHP_BB_Turb_ntu_1.shp
# Number of data rows for BB, Turb_ntu, 2: 6
# Shapefile for BB: Turb_ntu for period 2 has been saved as SHP_BB_Turb_ntu_2.shp
# Number of data rows for BB, Turb_ntu, 3: 6
# Shapefile for BB: Turb_ntu for period 3 has been saved as SHP_BB_Turb_ntu_3.shp
# Number of data rows for BB, Turb_ntu, 4: 12
# Shapefile for BB: Turb_ntu for period 4 has been saved as SHP_BB_Turb_ntu_4.shp
# Number of data rows for BB, Turb_ntu, 5: 5
# Shapefile for BB: Turb_ntu for period 5 has been saved as SHP_BB_Turb_ntu_5.shp
# Number of data rows for BB, Turb_ntu, 6: 6
# Shapefile for BB: Turb_ntu for period 6 has been saved as SHP_BB_Turb_ntu_6.shp
# Number of data rows for BB, Turb_ntu, 7: 12
# Shapefile for BB: Turb_ntu for period 7 has been saved as SHP_BB_Turb_ntu_7.shp
# Number of data rows for BB, Turb_ntu, 8: 6
# Shapefile for BB: Turb_ntu for period 8 has been saved as SHP_BB_Turb_ntu_8.shp
# Number of data rows for BB, Turb_ntu, 9: 12
# Shapefile for BB: Turb_ntu for period 9 has been saved as SHP_BB_Turb_ntu_9.shp
# Number of data rows for BB, Turb_ntu, 10: 6
# Shapefile for BB: Turb_ntu for period 10 has been saved as SHP_BB_Turb_ntu_10.shp
# Number of data rows for BB, Turb_ntu, 11: 1
# Shapefile for BB: Turb_ntu for period 11 has been saved as SHP_BB_Turb_ntu_11.shp
# No valid data found for area: BB, parameter: Turb_ntu, period: 12
# Number of data rows for BB, T_c, 1: 6
# Shapefile for BB: T_c for period 1 has been saved as SHP_BB_T_c_1.shp
# Number of data rows for BB, T_c, 2: 6
# Shapefile for BB: T_c for period 2 has been saved as SHP_BB_T_c_2.shp
# Number of data rows for BB, T_c, 3: 6
# Shapefile for BB: T_c for period 3 has been saved as SHP_BB_T_c_3.shp
# Number of data rows for BB, T_c, 4: 12
# Shapefile for BB: T_c for period 4 has been saved as SHP_BB_T_c_4.shp
# Number of data rows for BB, T_c, 5: 5
# Shapefile for BB: T_c for period 5 has been saved as SHP_BB_T_c_5.shp
# Number of data rows for BB, T_c, 6: 6
# Shapefile for BB: T_c for period 6 has been saved as SHP_BB_T_c_6.shp
# Number of data rows for BB, T_c, 7: 12
# Shapefile for BB: T_c for period 7 has been saved as SHP_BB_T_c_7.shp
# Number of data rows for BB, T_c, 8: 6
# Shapefile for BB: T_c for period 8 has been saved as SHP_BB_T_c_8.shp
# Number of data rows for BB, T_c, 9: 12
# Shapefile for BB: T_c for period 9 has been saved as SHP_BB_T_c_9.shp
# Number of data rows for BB, T_c, 10: 6
# Shapefile for BB: T_c for period 10 has been saved as SHP_BB_T_c_10.shp
# Number of data rows for BB, T_c, 11: 1
# Shapefile for BB: T_c for period 11 has been saved as SHP_BB_T_c_11.shp
# No valid data found for area: BB, parameter: T_c, period: 12
# Number of data rows for CH, DO_mgl, 1: 3
# Shapefile for CH: DO_mgl for period 1 has been saved as SHP_CH_DO_mgl_1.shp
# Number of data rows for CH, DO_mgl, 2: 3
# Shapefile for CH: DO_mgl for period 2 has been saved as SHP_CH_DO_mgl_2.shp
# Number of data rows for CH, DO_mgl, 3: 3
# Shapefile for CH: DO_mgl for period 3 has been saved as SHP_CH_DO_mgl_3.shp
# Number of data rows for CH, DO_mgl, 4: 3
# Shapefile for CH: DO_mgl for period 4 has been saved as SHP_CH_DO_mgl_4.shp
# Number of data rows for CH, DO_mgl, 5: 3
# Shapefile for CH: DO_mgl for period 5 has been saved as SHP_CH_DO_mgl_5.shp
# Number of data rows for CH, DO_mgl, 6: 3
# Shapefile for CH: DO_mgl for period 6 has been saved as SHP_CH_DO_mgl_6.shp
# Number of data rows for CH, DO_mgl, 7: 6
# Shapefile for CH: DO_mgl for period 7 has been saved as SHP_CH_DO_mgl_7.shp
# Number of data rows for CH, DO_mgl, 8: 3
# Shapefile for CH: DO_mgl for period 8 has been saved as SHP_CH_DO_mgl_8.shp
# Number of data rows for CH, DO_mgl, 9: 6
# Shapefile for CH: DO_mgl for period 9 has been saved as SHP_CH_DO_mgl_9.shp
# Number of data rows for CH, DO_mgl, 10: 5
# Shapefile for CH: DO_mgl for period 10 has been saved as SHP_CH_DO_mgl_10.shp
# Number of data rows for CH, DO_mgl, 11: 3
# Shapefile for CH: DO_mgl for period 11 has been saved as SHP_CH_DO_mgl_11.shp
# Number of data rows for CH, DO_mgl, 12: 4
# Shapefile for CH: DO_mgl for period 12 has been saved as SHP_CH_DO_mgl_12.shp
# Number of data rows for CH, Sal_ppt, 1: 3
# Shapefile for CH: Sal_ppt for period 1 has been saved as SHP_CH_Sal_ppt_1.shp
# Number of data rows for CH, Sal_ppt, 2: 3
# Shapefile for CH: Sal_ppt for period 2 has been saved as SHP_CH_Sal_ppt_2.shp
# Number of data rows for CH, Sal_ppt, 3: 3
# Shapefile for CH: Sal_ppt for period 3 has been saved as SHP_CH_Sal_ppt_3.shp
# Number of data rows for CH, Sal_ppt, 4: 3
# Shapefile for CH: Sal_ppt for period 4 has been saved as SHP_CH_Sal_ppt_4.shp
# Number of data rows for CH, Sal_ppt, 5: 3
# Shapefile for CH: Sal_ppt for period 5 has been saved as SHP_CH_Sal_ppt_5.shp
# Number of data rows for CH, Sal_ppt, 6: 3
# Shapefile for CH: Sal_ppt for period 6 has been saved as SHP_CH_Sal_ppt_6.shp
# Number of data rows for CH, Sal_ppt, 7: 6
# Shapefile for CH: Sal_ppt for period 7 has been saved as SHP_CH_Sal_ppt_7.shp
# Number of data rows for CH, Sal_ppt, 8: 3
# Shapefile for CH: Sal_ppt for period 8 has been saved as SHP_CH_Sal_ppt_8.shp
# Number of data rows for CH, Sal_ppt, 9: 6
# Shapefile for CH: Sal_ppt for period 9 has been saved as SHP_CH_Sal_ppt_9.shp
# Number of data rows for CH, Sal_ppt, 10: 6
# Shapefile for CH: Sal_ppt for period 10 has been saved as SHP_CH_Sal_ppt_10.shp
# Number of data rows for CH, Sal_ppt, 11: 3
# Shapefile for CH: Sal_ppt for period 11 has been saved as SHP_CH_Sal_ppt_11.shp
# Number of data rows for CH, Sal_ppt, 12: 5
# Shapefile for CH: Sal_ppt for period 12 has been saved as SHP_CH_Sal_ppt_12.shp
# Number of data rows for CH, Turb_ntu, 1: 3
# Shapefile for CH: Turb_ntu for period 1 has been saved as SHP_CH_Turb_ntu_1.shp
# Number of data rows for CH, Turb_ntu, 2: 3
# Shapefile for CH: Turb_ntu for period 2 has been saved as SHP_CH_Turb_ntu_2.shp
# Number of data rows for CH, Turb_ntu, 3: 3
# Shapefile for CH: Turb_ntu for period 3 has been saved as SHP_CH_Turb_ntu_3.shp
# Number of data rows for CH, Turb_ntu, 4: 3
# Shapefile for CH: Turb_ntu for period 4 has been saved as SHP_CH_Turb_ntu_4.shp
# Number of data rows for CH, Turb_ntu, 5: 3
# Shapefile for CH: Turb_ntu for period 5 has been saved as SHP_CH_Turb_ntu_5.shp
# Number of data rows for CH, Turb_ntu, 6: 3
# Shapefile for CH: Turb_ntu for period 6 has been saved as SHP_CH_Turb_ntu_6.shp
# Number of data rows for CH, Turb_ntu, 7: 5
# Shapefile for CH: Turb_ntu for period 7 has been saved as SHP_CH_Turb_ntu_7.shp
# Number of data rows for CH, Turb_ntu, 8: 3
# Shapefile for CH: Turb_ntu for period 8 has been saved as SHP_CH_Turb_ntu_8.shp
# Number of data rows for CH, Turb_ntu, 9: 6
# Shapefile for CH: Turb_ntu for period 9 has been saved as SHP_CH_Turb_ntu_9.shp
# Number of data rows for CH, Turb_ntu, 10: 5
# Shapefile for CH: Turb_ntu for period 10 has been saved as SHP_CH_Turb_ntu_10.shp
# Number of data rows for CH, Turb_ntu, 11: 3
# Shapefile for CH: Turb_ntu for period 11 has been saved as SHP_CH_Turb_ntu_11.shp
# Number of data rows for CH, Turb_ntu, 12: 5
# Shapefile for CH: Turb_ntu for period 12 has been saved as SHP_CH_Turb_ntu_12.shp
# Number of data rows for CH, T_c, 1: 3
# Shapefile for CH: T_c for period 1 has been saved as SHP_CH_T_c_1.shp
# Number of data rows for CH, T_c, 2: 3
# Shapefile for CH: T_c for period 2 has been saved as SHP_CH_T_c_2.shp
# Number of data rows for CH, T_c, 3: 3
# Shapefile for CH: T_c for period 3 has been saved as SHP_CH_T_c_3.shp
# Number of data rows for CH, T_c, 4: 3
# Shapefile for CH: T_c for period 4 has been saved as SHP_CH_T_c_4.shp
# Number of data rows for CH, T_c, 5: 3
# Shapefile for CH: T_c for period 5 has been saved as SHP_CH_T_c_5.shp
# Number of data rows for CH, T_c, 6: 3
# Shapefile for CH: T_c for period 6 has been saved as SHP_CH_T_c_6.shp
# Number of data rows for CH, T_c, 7: 6
# Shapefile for CH: T_c for period 7 has been saved as SHP_CH_T_c_7.shp
# Number of data rows for CH, T_c, 8: 3
# Shapefile for CH: T_c for period 8 has been saved as SHP_CH_T_c_8.shp
# Number of data rows for CH, T_c, 9: 6
# Shapefile for CH: T_c for period 9 has been saved as SHP_CH_T_c_9.shp
# Number of data rows for CH, T_c, 10: 6
# Shapefile for CH: T_c for period 10 has been saved as SHP_CH_T_c_10.shp
# Number of data rows for CH, T_c, 11: 3
# Shapefile for CH: T_c for period 11 has been saved as SHP_CH_T_c_11.shp
# Number of data rows for CH, T_c, 12: 6
# Shapefile for CH: T_c for period 12 has been saved as SHP_CH_T_c_12.shp
# Number of data rows for EB, DO_mgl, 1: 3
# Shapefile for EB: DO_mgl for period 1 has been saved as SHP_EB_DO_mgl_1.shp
# Number of data rows for EB, DO_mgl, 2: 3
# Shapefile for EB: DO_mgl for period 2 has been saved as SHP_EB_DO_mgl_2.shp
# Number of data rows for EB, DO_mgl, 3: 3
# Shapefile for EB: DO_mgl for period 3 has been saved as SHP_EB_DO_mgl_3.shp
# Number of data rows for EB, DO_mgl, 4: 5
# Shapefile for EB: DO_mgl for period 4 has been saved as SHP_EB_DO_mgl_4.shp
# Number of data rows for EB, DO_mgl, 5: 3
# Shapefile for EB: DO_mgl for period 5 has been saved as SHP_EB_DO_mgl_5.shp
# Number of data rows for EB, DO_mgl, 6: 3
# Shapefile for EB: DO_mgl for period 6 has been saved as SHP_EB_DO_mgl_6.shp
# Number of data rows for EB, DO_mgl, 7: 6
# Shapefile for EB: DO_mgl for period 7 has been saved as SHP_EB_DO_mgl_7.shp
# Number of data rows for EB, DO_mgl, 8: 3
# Shapefile for EB: DO_mgl for period 8 has been saved as SHP_EB_DO_mgl_8.shp
# Number of data rows for EB, DO_mgl, 9: 5
# Shapefile for EB: DO_mgl for period 9 has been saved as SHP_EB_DO_mgl_9.shp
# Number of data rows for EB, DO_mgl, 10: 6
# Shapefile for EB: DO_mgl for period 10 has been saved as SHP_EB_DO_mgl_10.shp
# Number of data rows for EB, DO_mgl, 11: 3
# Shapefile for EB: DO_mgl for period 11 has been saved as SHP_EB_DO_mgl_11.shp
# Number of data rows for EB, DO_mgl, 12: 6
# Shapefile for EB: DO_mgl for period 12 has been saved as SHP_EB_DO_mgl_12.shp
# Number of data rows for EB, Sal_ppt, 1: 3
# Shapefile for EB: Sal_ppt for period 1 has been saved as SHP_EB_Sal_ppt_1.shp
# Number of data rows for EB, Sal_ppt, 2: 3
# Shapefile for EB: Sal_ppt for period 2 has been saved as SHP_EB_Sal_ppt_2.shp
# Number of data rows for EB, Sal_ppt, 3: 3
# Shapefile for EB: Sal_ppt for period 3 has been saved as SHP_EB_Sal_ppt_3.shp
# Number of data rows for EB, Sal_ppt, 4: 6
# Shapefile for EB: Sal_ppt for period 4 has been saved as SHP_EB_Sal_ppt_4.shp
# Number of data rows for EB, Sal_ppt, 5: 3
# Shapefile for EB: Sal_ppt for period 5 has been saved as SHP_EB_Sal_ppt_5.shp
# Number of data rows for EB, Sal_ppt, 6: 3
# Shapefile for EB: Sal_ppt for period 6 has been saved as SHP_EB_Sal_ppt_6.shp
# Number of data rows for EB, Sal_ppt, 7: 6
# Shapefile for EB: Sal_ppt for period 7 has been saved as SHP_EB_Sal_ppt_7.shp
# Number of data rows for EB, Sal_ppt, 8: 3
# Shapefile for EB: Sal_ppt for period 8 has been saved as SHP_EB_Sal_ppt_8.shp
# Number of data rows for EB, Sal_ppt, 9: 5
# Shapefile for EB: Sal_ppt for period 9 has been saved as SHP_EB_Sal_ppt_9.shp
# Number of data rows for EB, Sal_ppt, 10: 6
# Shapefile for EB: Sal_ppt for period 10 has been saved as SHP_EB_Sal_ppt_10.shp
# Number of data rows for EB, Sal_ppt, 11: 3
# Shapefile for EB: Sal_ppt for period 11 has been saved as SHP_EB_Sal_ppt_11.shp
# Number of data rows for EB, Sal_ppt, 12: 6
# Shapefile for EB: Sal_ppt for period 12 has been saved as SHP_EB_Sal_ppt_12.shp
# Number of data rows for EB, Turb_ntu, 1: 3
# Shapefile for EB: Turb_ntu for period 1 has been saved as SHP_EB_Turb_ntu_1.shp
# Number of data rows for EB, Turb_ntu, 2: 3
# Shapefile for EB: Turb_ntu for period 2 has been saved as SHP_EB_Turb_ntu_2.shp
# Number of data rows for EB, Turb_ntu, 3: 3
# Shapefile for EB: Turb_ntu for period 3 has been saved as SHP_EB_Turb_ntu_3.shp
# Number of data rows for EB, Turb_ntu, 4: 5
# Shapefile for EB: Turb_ntu for period 4 has been saved as SHP_EB_Turb_ntu_4.shp
# Number of data rows for EB, Turb_ntu, 5: 2
# Shapefile for EB: Turb_ntu for period 5 has been saved as SHP_EB_Turb_ntu_5.shp
# Number of data rows for EB, Turb_ntu, 6: 3
# Shapefile for EB: Turb_ntu for period 6 has been saved as SHP_EB_Turb_ntu_6.shp
# Number of data rows for EB, Turb_ntu, 7: 6
# Shapefile for EB: Turb_ntu for period 7 has been saved as SHP_EB_Turb_ntu_7.shp
# Number of data rows for EB, Turb_ntu, 8: 3
# Shapefile for EB: Turb_ntu for period 8 has been saved as SHP_EB_Turb_ntu_8.shp
# Number of data rows for EB, Turb_ntu, 9: 4
# Shapefile for EB: Turb_ntu for period 9 has been saved as SHP_EB_Turb_ntu_9.shp
# Number of data rows for EB, Turb_ntu, 10: 6
# Shapefile for EB: Turb_ntu for period 10 has been saved as SHP_EB_Turb_ntu_10.shp
# Number of data rows for EB, Turb_ntu, 11: 3
# Shapefile for EB: Turb_ntu for period 11 has been saved as SHP_EB_Turb_ntu_11.shp
# Number of data rows for EB, Turb_ntu, 12: 5
# Shapefile for EB: Turb_ntu for period 12 has been saved as SHP_EB_Turb_ntu_12.shp
# Number of data rows for EB, T_c, 1: 3
# Shapefile for EB: T_c for period 1 has been saved as SHP_EB_T_c_1.shp
# Number of data rows for EB, T_c, 2: 3
# Shapefile for EB: T_c for period 2 has been saved as SHP_EB_T_c_2.shp
# Number of data rows for EB, T_c, 3: 3
# Shapefile for EB: T_c for period 3 has been saved as SHP_EB_T_c_3.shp
# Number of data rows for EB, T_c, 4: 6
# Shapefile for EB: T_c for period 4 has been saved as SHP_EB_T_c_4.shp
# Number of data rows for EB, T_c, 5: 3
# Shapefile for EB: T_c for period 5 has been saved as SHP_EB_T_c_5.shp
# Number of data rows for EB, T_c, 6: 3
# Shapefile for EB: T_c for period 6 has been saved as SHP_EB_T_c_6.shp
# Number of data rows for EB, T_c, 7: 6
# Shapefile for EB: T_c for period 7 has been saved as SHP_EB_T_c_7.shp
# Number of data rows for EB, T_c, 8: 3
# Shapefile for EB: T_c for period 8 has been saved as SHP_EB_T_c_8.shp
# Number of data rows for EB, T_c, 9: 6
# Shapefile for EB: T_c for period 9 has been saved as SHP_EB_T_c_9.shp
# Number of data rows for EB, T_c, 10: 6
# Shapefile for EB: T_c for period 10 has been saved as SHP_EB_T_c_10.shp
# Number of data rows for EB, T_c, 11: 3
# Shapefile for EB: T_c for period 11 has been saved as SHP_EB_T_c_11.shp
# Number of data rows for EB, T_c, 12: 6
# Shapefile for EB: T_c for period 12 has been saved as SHP_EB_T_c_12.shp
# Number of data rows for GTM, DO_mgl, 1: 4
# Shapefile for GTM: DO_mgl for period 1 has been saved as SHP_GTM_DO_mgl_1.shp
# Number of data rows for GTM, DO_mgl, 2: 4
# Shapefile for GTM: DO_mgl for period 2 has been saved as SHP_GTM_DO_mgl_2.shp
# Number of data rows for GTM, DO_mgl, 3: 8
# Shapefile for GTM: DO_mgl for period 3 has been saved as SHP_GTM_DO_mgl_3.shp
# Number of data rows for GTM, DO_mgl, 4: 4
# Shapefile for GTM: DO_mgl for period 4 has been saved as SHP_GTM_DO_mgl_4.shp
# Number of data rows for GTM, DO_mgl, 5: 4
# Shapefile for GTM: DO_mgl for period 5 has been saved as SHP_GTM_DO_mgl_5.shp
# Number of data rows for GTM, DO_mgl, 6: 8
# Shapefile for GTM: DO_mgl for period 6 has been saved as SHP_GTM_DO_mgl_6.shp
# Number of data rows for GTM, DO_mgl, 7: 4
# Shapefile for GTM: DO_mgl for period 7 has been saved as SHP_GTM_DO_mgl_7.shp
# Number of data rows for GTM, DO_mgl, 8: 8
# Shapefile for GTM: DO_mgl for period 8 has been saved as SHP_GTM_DO_mgl_8.shp
# Number of data rows for GTM, DO_mgl, 9: 8
# Shapefile for GTM: DO_mgl for period 9 has been saved as SHP_GTM_DO_mgl_9.shp
# No valid data found for area: GTM, parameter: DO_mgl, period: 10
# Number of data rows for GTM, DO_mgl, 11: 4
# Shapefile for GTM: DO_mgl for period 11 has been saved as SHP_GTM_DO_mgl_11.shp
# Number of data rows for GTM, DO_mgl, 12: 4
# Shapefile for GTM: DO_mgl for period 12 has been saved as SHP_GTM_DO_mgl_12.shp
# Number of data rows for GTM, Sal_ppt, 1: 4
# Shapefile for GTM: Sal_ppt for period 1 has been saved as SHP_GTM_Sal_ppt_1.shp
# Number of data rows for GTM, Sal_ppt, 2: 4
# Shapefile for GTM: Sal_ppt for period 2 has been saved as SHP_GTM_Sal_ppt_2.shp
# Number of data rows for GTM, Sal_ppt, 3: 8
# Shapefile for GTM: Sal_ppt for period 3 has been saved as SHP_GTM_Sal_ppt_3.shp
# Number of data rows for GTM, Sal_ppt, 4: 4
# Shapefile for GTM: Sal_ppt for period 4 has been saved as SHP_GTM_Sal_ppt_4.shp
# Number of data rows for GTM, Sal_ppt, 5: 4
# Shapefile for GTM: Sal_ppt for period 5 has been saved as SHP_GTM_Sal_ppt_5.shp
# Number of data rows for GTM, Sal_ppt, 6: 8
# Shapefile for GTM: Sal_ppt for period 6 has been saved as SHP_GTM_Sal_ppt_6.shp
# Number of data rows for GTM, Sal_ppt, 7: 4
# Shapefile for GTM: Sal_ppt for period 7 has been saved as SHP_GTM_Sal_ppt_7.shp
# Number of data rows for GTM, Sal_ppt, 8: 8
# Shapefile for GTM: Sal_ppt for period 8 has been saved as SHP_GTM_Sal_ppt_8.shp
# Number of data rows for GTM, Sal_ppt, 9: 8
# Shapefile for GTM: Sal_ppt for period 9 has been saved as SHP_GTM_Sal_ppt_9.shp
# No valid data found for area: GTM, parameter: Sal_ppt, period: 10
# Number of data rows for GTM, Sal_ppt, 11: 3
# Shapefile for GTM: Sal_ppt for period 11 has been saved as SHP_GTM_Sal_ppt_11.shp
# Number of data rows for GTM, Sal_ppt, 12: 4
# Shapefile for GTM: Sal_ppt for period 12 has been saved as SHP_GTM_Sal_ppt_12.shp
# Number of data rows for GTM, Turb_ntu, 1: 4
# Shapefile for GTM: Turb_ntu for period 1 has been saved as SHP_GTM_Turb_ntu_1.shp
# Number of data rows for GTM, Turb_ntu, 2: 4
# Shapefile for GTM: Turb_ntu for period 2 has been saved as SHP_GTM_Turb_ntu_2.shp
# Number of data rows for GTM, Turb_ntu, 3: 8
# Shapefile for GTM: Turb_ntu for period 3 has been saved as SHP_GTM_Turb_ntu_3.shp
# Number of data rows for GTM, Turb_ntu, 4: 4
# Shapefile for GTM: Turb_ntu for period 4 has been saved as SHP_GTM_Turb_ntu_4.shp
# Number of data rows for GTM, Turb_ntu, 5: 4
# Shapefile for GTM: Turb_ntu for period 5 has been saved as SHP_GTM_Turb_ntu_5.shp
# Number of data rows for GTM, Turb_ntu, 6: 8
# Shapefile for GTM: Turb_ntu for period 6 has been saved as SHP_GTM_Turb_ntu_6.shp
# Number of data rows for GTM, Turb_ntu, 7: 4
# Shapefile for GTM: Turb_ntu for period 7 has been saved as SHP_GTM_Turb_ntu_7.shp
# Number of data rows for GTM, Turb_ntu, 8: 8
# Shapefile for GTM: Turb_ntu for period 8 has been saved as SHP_GTM_Turb_ntu_8.shp
# Number of data rows for GTM, Turb_ntu, 9: 8
# Shapefile for GTM: Turb_ntu for period 9 has been saved as SHP_GTM_Turb_ntu_9.shp
# No valid data found for area: GTM, parameter: Turb_ntu, period: 10
# Number of data rows for GTM, Turb_ntu, 11: 4
# Shapefile for GTM: Turb_ntu for period 11 has been saved as SHP_GTM_Turb_ntu_11.shp
# Number of data rows for GTM, Turb_ntu, 12: 4
# Shapefile for GTM: Turb_ntu for period 12 has been saved as SHP_GTM_Turb_ntu_12.shp
# Number of data rows for GTM, T_c, 1: 4
# Shapefile for GTM: T_c for period 1 has been saved as SHP_GTM_T_c_1.shp
# Number of data rows for GTM, T_c, 2: 4
# Shapefile for GTM: T_c for period 2 has been saved as SHP_GTM_T_c_2.shp
# Number of data rows for GTM, T_c, 3: 8
# Shapefile for GTM: T_c for period 3 has been saved as SHP_GTM_T_c_3.shp
# Number of data rows for GTM, T_c, 4: 4
# Shapefile for GTM: T_c for period 4 has been saved as SHP_GTM_T_c_4.shp
# Number of data rows for GTM, T_c, 5: 4
# Shapefile for GTM: T_c for period 5 has been saved as SHP_GTM_T_c_5.shp
# Number of data rows for GTM, T_c, 6: 8
# Shapefile for GTM: T_c for period 6 has been saved as SHP_GTM_T_c_6.shp
# Number of data rows for GTM, T_c, 7: 4
# Shapefile for GTM: T_c for period 7 has been saved as SHP_GTM_T_c_7.shp
# Number of data rows for GTM, T_c, 8: 8
# Shapefile for GTM: T_c for period 8 has been saved as SHP_GTM_T_c_8.shp
# Number of data rows for GTM, T_c, 9: 8
# Shapefile for GTM: T_c for period 9 has been saved as SHP_GTM_T_c_9.shp
# No valid data found for area: GTM, parameter: T_c, period: 10
# Number of data rows for GTM, T_c, 11: 4
# Shapefile for GTM: T_c for period 11 has been saved as SHP_GTM_T_c_11.shp
# Number of data rows for GTM, T_c, 12: 4
# Shapefile for GTM: T_c for period 12 has been saved as SHP_GTM_T_c_12.shp

# %%
# If the number of data points is less than 3，skipping calculate IDW
idw_rk.idw_interpolation1(df_month_table, shpCon_folder, idwCon_folder, waterbody_extent, barrier_folder)
# Out:
# Processing file: SHP_BBS_DO_mgl_1.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_1.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2.shp, skipping
# Processing file: SHP_BBS_DO_mgl_3.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_3.shp, skipping
# Processing file: SHP_BBS_DO_mgl_4.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_4.shp, skipping
# Processing file: SHP_BBS_DO_mgl_5.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_5.shp, skipping
# Processing file: SHP_BBS_DO_mgl_6.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_6.shp, skipping
# Processing file: SHP_BBS_DO_mgl_7.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_7.shp, skipping
# Processing file: SHP_BBS_DO_mgl_8.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_8.shp, skipping
# Processing file: SHP_BBS_DO_mgl_9.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_9.shp, skipping
# Processing file: SHP_BBS_DO_mgl_10.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_10.shp, skipping
# Processing file: SHP_BBS_DO_mgl_11.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_11.shp, skipping
# Processing file: SHP_BBS_DO_mgl_12.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_12.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_1.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_1.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_3.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_3.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_4.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_4.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_5.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_5.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_6.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_6.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_7.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_7.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_8.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_8.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_9.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_9.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_10.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_10.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_11.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_11.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_12.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_12.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_1.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_1.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_3.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_3.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_4.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_4.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_5.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_5.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_6.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_6.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_7.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_7.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_8.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_8.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_9.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_9.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_10.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_10.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_11.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_11.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_12.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_12.shp, skipping
# Processing file: SHP_BBS_T_c_1.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_1.shp, skipping
# Processing file: SHP_BBS_T_c_2.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2.shp, skipping
# Processing file: SHP_BBS_T_c_3.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_3.shp, skipping
# Processing file: SHP_BBS_T_c_4.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_4.shp, skipping
# Processing file: SHP_BBS_T_c_5.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_5.shp, skipping
# Processing file: SHP_BBS_T_c_6.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_6.shp, skipping
# Processing file: SHP_BBS_T_c_7.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_7.shp, skipping
# Processing file: SHP_BBS_T_c_8.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_8.shp, skipping
# Processing file: SHP_BBS_T_c_9.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_9.shp, skipping
# Processing file: SHP_BBS_T_c_10.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_10.shp, skipping
# Processing file: SHP_BBS_T_c_11.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_11.shp, skipping
# Processing file: SHP_BBS_T_c_12.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_12.shp, skipping
# Processing file: SHP_BB_DO_mgl_1.shp
# File SHP_BB_DO_mgl_1.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2.shp
# File SHP_BB_DO_mgl_2.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_3.shp
# File SHP_BB_DO_mgl_3.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_4.shp
# File SHP_BB_DO_mgl_4.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_5.shp
# File SHP_BB_DO_mgl_5.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_6.shp
# File SHP_BB_DO_mgl_6.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_7.shp
# File SHP_BB_DO_mgl_7.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_8.shp
# File SHP_BB_DO_mgl_8.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_9.shp
# File SHP_BB_DO_mgl_9.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_10.shp
# File SHP_BB_DO_mgl_10.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_11.shp
# Not enough data for IDW interpolation in SHP_BB_DO_mgl_11.shp, skipping
# Shapefile not found for: SHP_BB_DO_mgl_12.shp
# Processing file: SHP_BB_Sal_ppt_1.shp
# File SHP_BB_Sal_ppt_1.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2.shp
# File SHP_BB_Sal_ppt_2.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_3.shp
# File SHP_BB_Sal_ppt_3.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_4.shp
# File SHP_BB_Sal_ppt_4.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_5.shp
# File SHP_BB_Sal_ppt_5.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_6.shp
# File SHP_BB_Sal_ppt_6.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_7.shp
# File SHP_BB_Sal_ppt_7.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_8.shp
# File SHP_BB_Sal_ppt_8.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_9.shp
# File SHP_BB_Sal_ppt_9.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_10.shp
# File SHP_BB_Sal_ppt_10.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_11.shp
# Not enough data for IDW interpolation in SHP_BB_Sal_ppt_11.shp, skipping
# Shapefile not found for: SHP_BB_Sal_ppt_12.shp
# Processing file: SHP_BB_Turb_ntu_1.shp
# File SHP_BB_Turb_ntu_1.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2.shp
# File SHP_BB_Turb_ntu_2.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_3.shp
# File SHP_BB_Turb_ntu_3.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_4.shp
# File SHP_BB_Turb_ntu_4.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_5.shp
# File SHP_BB_Turb_ntu_5.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_6.shp
# File SHP_BB_Turb_ntu_6.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_7.shp
# File SHP_BB_Turb_ntu_7.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_8.shp
# File SHP_BB_Turb_ntu_8.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_9.shp
# File SHP_BB_Turb_ntu_9.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_10.shp
# File SHP_BB_Turb_ntu_10.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_11.shp
# Not enough data for IDW interpolation in SHP_BB_Turb_ntu_11.shp, skipping
# Shapefile not found for: SHP_BB_Turb_ntu_12.shp
# Processing file: SHP_BB_T_c_1.shp
# File SHP_BB_T_c_1.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2.shp
# File SHP_BB_T_c_2.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_3.shp
# File SHP_BB_T_c_3.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_4.shp
# File SHP_BB_T_c_4.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_T_c_5.shp
# File SHP_BB_T_c_5.shp has completed 5 cross-validation iterations.
# Processing file: SHP_BB_T_c_6.shp
# File SHP_BB_T_c_6.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_7.shp
# File SHP_BB_T_c_7.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_T_c_8.shp
# File SHP_BB_T_c_8.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_9.shp
# File SHP_BB_T_c_9.shp has completed 12 cross-validation iterations.
# Processing file: SHP_BB_T_c_10.shp
# File SHP_BB_T_c_10.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_11.shp
# Not enough data for IDW interpolation in SHP_BB_T_c_11.shp, skipping
# Shapefile not found for: SHP_BB_T_c_12.shp
# Processing file: SHP_CH_DO_mgl_1.shp
# File SHP_CH_DO_mgl_1.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_2.shp
# File SHP_CH_DO_mgl_2.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_3.shp
# File SHP_CH_DO_mgl_3.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_4.shp
# File SHP_CH_DO_mgl_4.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_5.shp
# File SHP_CH_DO_mgl_5.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_6.shp
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 2
#       1 # If the number of data points is less than 3，skipping calculate IDW
# ----> 2 idw_rk.idw_interpolation1(df_month_table, shpCon_folder, idwCon_folder, waterbody_extent, barrier_folder)
#
# File F:\SEACAR_WQ_2024\git\misc\idw_rk.py:515, in idw_interpolation1(df, folder_path, output_folder, boundary_path, barrier_folder_path)
#     512 query = f"RowID_ <> {test_point[0]}"
#     513 arcpy.Select_analysis(filepath, temp_dataset, query)
# --> 515 idw_result = arcpy.sa.Idw(temp_dataset, z_field,in_barrier_polyline_features=barrier_file_path)
#     517 point_geometry = test_point[1]  # Get PointGeometry
#     518 point = point_geometry.firstPoint  # Get Point
#
# File E:\Program Files (x86)\ArcgisPro\Resources\ArcPy\arcpy\sa\Functions.py:5385, in Idw(in_point_features, z_field, cell_size, power, search_radius, in_barrier_polyline_features)
#    5376     result = arcpy.gp.Idw_sa(
#    5377         in_point_features,
#    5378         z_field,
#    (...)
#    5382         search_radius,
#    5383         in_barrier_polyline_features)
#    5384     return _wrapToolRaster(u"Idw_sa", unicode(result.getOutput(0)))
# -> 5385 return Wrapper(
#    5386     in_point_features,
#    5387     z_field,
#    5388     cell_size,
#    5389     power,
#    5390     search_radius,
#    5391     in_barrier_polyline_features)
#
# File E:\Program Files (x86)\ArcgisPro\Resources\ArcPy\arcpy\sa\Utils.py:55, in StateSwapper.__call__.<locals>.swapper(*args, **kwargs)
#      52 result = None
#      54 try:
# ---> 55     result = wrapper(*args, **kwargs)
#      56 finally:
#      57     # Reset the geoprocessor state to the original setting.
#      58     # Whatever the result of calling the wrapper function, this
#      59     # code will run.
#      60     gp._gp.AddOutputsToMap = addToResultState
#
# File E:\Program Files (x86)\ArcgisPro\Resources\ArcPy\arcpy\sa\Functions.py:5376, in Idw.<locals>.Wrapper(in_point_features, z_field, cell_size, power, search_radius, in_barrier_polyline_features)
#    5374 search_radius = Utils.compoundParameterToString(search_radius, ParameterClasses._Radius)
#    5375 out_raster = "#"
# -> 5376 result = arcpy.gp.Idw_sa(
#    5377     in_point_features,
#    5378     z_field,
#    5379     out_raster,
#    5380     cell_size,
#    5381     power,
#    5382     search_radius,
#    5383     in_barrier_polyline_features)
#    5384 return _wrapToolRaster(u"Idw_sa", unicode(result.getOutput(0)))
#
# File E:\Program Files (x86)\ArcgisPro\Resources\ArcPy\arcpy\geoprocessing\_base.py:512, in Geoprocessor.__getattr__.<locals>.<lambda>(*args)
#     510 val = getattr(self._gp, attr)
#     511 if callable(val):
# --> 512     return lambda *args: val(*gp_fixargs(args, True))
#     513 else:
#     514     return convertArcObjectToPythonObject(val)
#
# KeyboardInterrupt:
