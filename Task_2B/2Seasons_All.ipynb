# %% [markdown]
# # Cross Validation for IDW & RK Interpolation
# ## Task 2 (continuous & discrete) for wet & dry seasons
#
# This document includes Python codes that conduct cross validation (CV) for Inverse Distance Weighting (IDW) Interpolation and RK on water quality parameters, including 6 water quality parameters in arcpy environment:
# - Dissolved oxygen (DO_mgl)
# - Salinity (Sal_ppt)
# - Turbidity (Turb_ntu)
# - Temperature (T_c)
# - Secchi (Secc_m)
# - Total Nitrogen (TN_mgl)
#
# The analysis is conducted in the separate water bodies:
# - Guana Tolomato Matanzas (GTM)
# - Estero Bay (EB)
# - Charlotte Harbor (CH)
# - Biscayne Bay (BB)
# - Big Bend Seagrasses (BBS)
#
# **Tasks:**
#
# - **Task 2.1 Calculate the RMSE and Mean Error (ME) for IDW & RK results using both continuous and discrete data**
#
# - Task 2.2 Calculate the RMSE and Mean Error (ME) for IDW results using continuous data.
#
# <br>
# <div style="text-align: left;">
#     <img src="../misc/TwoSeasons.png" style="display: block; margin-left: 0; margin-right: auto; width: 850px;"/>
# </div>
#
#
# **Contents:**
# * [1. Data Preprocess](#reg_preprocessing)
#     * [1.1 Load csv files](#reg_subset)
#     * [1.2 Subsetting data](#reg_preview)
#     * [1.3 Define the wet and dry seasons](#reg_wetndry)
#     * [1.4 Calculating average values](#reg_average)
#     * [1.5 Convert coordinate system](#reg_coordinate)
# * [2. Prepare for batch interpolation](#reg_batch)
#     * [2.1 Preset abbreviation](#reg_preset)
#     * [2.2 Define the barrier files](#reg_barrier)
#     * [2.3 Define waterbody boundary](#reg_boundary)
#     * [2.4 Load the table of study periods,  parameters, and seasons](#reg_study)
#     * [2.5 Define output folders](#reg_output)
#     * [2.6 Fill NaN RowID with unique ID](#reg_id)
# * [3. Create Shapefiles](#reg_create_shp)
# * [4. Cross Validation for IDW](#reg_cv_idw)
# * [5. RK Interpolation](#reg_rk)

# %% [markdown]
# ## 1. Loading packages

# %%
import pandas as pd
import numpy as np
import arcpy
from arcpy.sa import *
import os
import math
import csv

import importlib
import sys
# path = r'C:/Users/cong1/WQ/IDW/git/misc'
path = r'E:\Projects\SEACAR_WQ_2024\git\misc'

sys.path.insert(0, path)
import idw_rk
importlib.reload(idw_rk)

import pyproj

# define scratch folder to avoid overwritting from parallel threats
arcpy.env.scratchWorkspace = r"E:\Projects\SEACAR_WQ_2024\scratch/IDW_2s"

arcpy.env.overwriteOutput = True

# %% [markdown]
# ## 1. Data Preprocessing <a class="anchor" id="reg_preprocessing"></a>
# ### 1.1 Load csv files

# %%
gis_path = r'E:/Projects/SEACAR_WQ_2024/GIS_Data/'

dfDis = pd.read_csv(gis_path + 'OEAT_Discrete_WQ-2024-May-06.csv', low_memory=False)
dfCon = pd.read_csv(gis_path + 'OEAT_Continuous_WQ-2024-Feb-21.csv', low_memory=False)

# %% [markdown]
# ## 1.2 Subsetting Data <a class="anchor" id="reg_subset"></a>
# ### Selecting data from 8 am to 18 pm (daytime)

# %%
# Convert string to datetime
dfCon['SampleDate'] = pd.to_datetime(dfCon['SampleDate'], format='%Y-%m-%d %H:%M:%S.%f')
dfDis['SampleDate'] = pd.to_datetime(dfDis['SampleDate'], format='%Y-%m-%d %H:%M:%S.%f')

# Include date from 8:00 am to 18:00 pm
start_time = '08:00'
end_time = '18:00'

dfCon = dfCon[dfCon['SampleDate'].dt.time.between(pd.to_datetime(start_time).time(), pd.to_datetime(end_time).time())]

dfAll = pd.concat([dfDis, dfCon], ignore_index=True)

dfAll.head()
# Out:
#    RowID  ProgramID ParameterName ParameterUnits ProgramLocationID  \
# 0      1         69  Secchi Depth              m     CKM2017100405
# 1      2         69  Secchi Depth              m     CKM2017080401
# 2      3         69  Secchi Depth              m     CKM2017060703
# 3      4         69  Secchi Depth              m     CKM2017060202
# 4      5         69  Secchi Depth              m     CKM2017110804
#
#   ActivityType SampleDate  Year  Month RelativeDepth  ResultValue  \
# 0        Field 2017-10-06  2017     10           NaN          0.3
# 1        Field 2017-08-08  2017      8       Surface          0.6
# 2        Field 2017-06-19  2017      6       Surface          0.4
# 3        Field 2017-06-06  2017      6       Surface          0.4
# 4        Field 2017-11-14  2017     11       Surface          0.4
#
#    Latitude_DD  Longitude_DD                       ManagedAreaName  AreaID  \
# 0    29.322100    -83.129866  Big Bend Seagrasses Aquatic Preserve       5
# 1    29.145966    -83.072250  Big Bend Seagrasses Aquatic Preserve       5
# 2    29.294516    -83.155316  Big Bend Seagrasses Aquatic Preserve       5
# 3    29.140400    -83.017050  Big Bend Seagrasses Aquatic Preserve       5
# 4    29.269566    -83.107283  Big Bend Seagrasses Aquatic Preserve       5
#
#   SEACAR_QAQCFlagCode            WaterBody WbodyAcronym  Season
# 0                  6Q  Big Bend Seagrasses          BBS    Fall
# 1               6Q/9Q  Big Bend Seagrasses          BBS  Summer
# 2               9Q/6Q  Big Bend Seagrasses          BBS  Summer
# 3               6Q/9Q  Big Bend Seagrasses          BBS  Spring
# 4               9Q/6Q  Big Bend Seagrasses          BBS    Fall

# %% [markdown]
# ### 1.3 Define the wet and dry seasons<a class="anchor" id="reg_wetndry"></a>

# %%
# Load the table of wet and dry seasons definitions
seasons2 = pd.read_csv(gis_path + 'season_def/2 seasons.csv', low_memory=False)
seasons2
# Out:
#                  WaterBody  Start Year  Start Month   Start Day  End Year  \
# 0         Charlotte Harbor        2017             5          1      2017
# 1         Charlotte Harbor        2017            11          1      2018
# 2      Big Bend Seagrasses        2021             5          1      2021
# 3      Big Bend Seagrasses        2021            11          1      2022
# 4               Estero Bay        2017             5          1      2017
# 5               Estero Bay        2017            11          1      2018
# 6  Guana Tolomato Matanzas        2016             5          1      2016
# 7  Guana Tolomato Matanzas        2016            11          1      2017
# 8             Biscayne Bay        2022             5          1      2022
# 9             Biscayne Bay        2022            11          1      2023
#
#    End Month   End Day Start Date    End Date Seasons
# 0          10       31   5/1/2017  10/31/2017     Wet
# 1           4       30  11/1/2017   4/30/2018     Dry
# 2          10       31   5/1/2021  10/31/2021     Wet
# 3           4       30  11/1/2021   4/30/2022     Dry
# 4          10       31   5/1/2017  10/31/2017     Wet
# 5           4       30  11/1/2017   4/30/2018     Dry
# 6          10       31   5/1/2016  10/31/2016     Wet
# 7           4       30  11/1/2016   4/30/2017     Dry
# 8          10       31   5/1/2022  10/31/2022     Wet
# 9           4       30  11/1/2022   4/30/2023     Dry

# %%
# Function to filters the year range
filtered_dfAllTime = idw_rk.filter_data(dfAll, seasons2)
filtered_dfAllTime.head()
# Out:
#    RowID  ProgramID ParameterName ParameterUnits ProgramLocationID  \
# 0    458         69  Secchi Depth              m     CHM2017091705
# 1    458         69  Secchi Depth              m     CHM2017091705
# 2    599         69  Secchi Depth              m     CHM2017111102
# 3    599         69  Secchi Depth              m     CHM2017111102
# 4    638         69  Secchi Depth              m     CHM2017070702
#
#   ActivityType SampleDate  Year  Month RelativeDepth  ResultValue  \
# 0        Field 2017-09-22  2017      9       Surface          1.0
# 1        Field 2017-09-22  2017      9       Surface          1.0
# 2        Field 2017-11-01  2017     11       Surface          0.3
# 3        Field 2017-11-01  2017     11       Surface          0.3
# 4        Field 2017-07-12  2017      7       Surface          0.4
#
#    Latitude_DD  Longitude_DD  \
# 0    26.598450    -82.129733
# 1    26.598450    -82.129733
# 2    26.840333    -82.269916
# 3    26.840333    -82.269916
# 4    26.793850    -82.153633
#
#                                      ManagedAreaName  AreaID  \
# 0                 Pine Island Sound Aquatic Preserve      34
# 1                 Pine Island Sound Aquatic Preserve      34
# 2  Gasparilla Sound-Charlotte Harbor Aquatic Pres...      18
# 3  Gasparilla Sound-Charlotte Harbor Aquatic Pres...      18
# 4                         Cape Haze Aquatic Preserve       9
#
#   SEACAR_QAQCFlagCode         WaterBody WbodyAcronym  Season
# 0               9Q/6Q  Charlotte Harbor           CH    Fall
# 1               9Q/6Q  Charlotte Harbor           CH    Fall
# 2               6Q/9Q  Charlotte Harbor           CH    Fall
# 3               6Q/9Q  Charlotte Harbor           CH    Fall
# 4               6Q/9Q  Charlotte Harbor           CH  Summer

# %%
# Check the filtered results
unique_years = filtered_dfAllTime.groupby('WaterBody')['Year'].unique().reset_index()
unique_years.columns = ['WaterBody', 'Unique Years']
unique_years
# Out:
#                  WaterBody  Unique Years
# 0      Big Bend Seagrasses  [2021, 2022]
# 1             Biscayne Bay  [2022, 2023]
# 2         Charlotte Harbor  [2017, 2018]
# 3               Estero Bay  [2018, 2017]
# 4  Guana Tolomato Matanzas  [2016, 2017]

# %%
# Assign wet and dry season
updated_dfAllTime = idw_rk.assign_seasons(filtered_dfAllTime, seasons2)
updated_dfAllTime.head()
# Out:
#    RowID  ProgramID ParameterName ParameterUnits ProgramLocationID  \
# 0    458         69  Secchi Depth              m     CHM2017091705
# 2    458         69  Secchi Depth              m     CHM2017091705
# 5    599         69  Secchi Depth              m     CHM2017111102
# 7    599         69  Secchi Depth              m     CHM2017111102
# 8    638         69  Secchi Depth              m     CHM2017070702
#
#   ActivityType SampleDate  Year  Month RelativeDepth  ...  Longitude_DD  \
# 0        Field 2017-09-22  2017      9       Surface  ...    -82.129733
# 2        Field 2017-09-22  2017      9       Surface  ...    -82.129733
# 5        Field 2017-11-01  2017     11       Surface  ...    -82.269916
# 7        Field 2017-11-01  2017     11       Surface  ...    -82.269916
# 8        Field 2017-07-12  2017      7       Surface  ...    -82.153633
#
#                                      ManagedAreaName  AreaID  \
# 0                 Pine Island Sound Aquatic Preserve      34
# 2                 Pine Island Sound Aquatic Preserve      34
# 5  Gasparilla Sound-Charlotte Harbor Aquatic Pres...      18
# 7  Gasparilla Sound-Charlotte Harbor Aquatic Pres...      18
# 8                         Cape Haze Aquatic Preserve       9
#
#   SEACAR_QAQCFlagCode         WaterBody WbodyAcronym  Season Start Date  \
# 0               9Q/6Q  Charlotte Harbor           CH    Fall 2017-05-01
# 2               9Q/6Q  Charlotte Harbor           CH    Fall 2017-05-01
# 5               6Q/9Q  Charlotte Harbor           CH    Fall 2017-11-01
# 7               6Q/9Q  Charlotte Harbor           CH    Fall 2017-11-01
# 8               6Q/9Q  Charlotte Harbor           CH  Summer 2017-05-01
#
#     End Date Seasons
# 0 2017-10-31     Wet
# 2 2017-10-31     Wet
# 5 2018-04-30     Dry
# 7 2018-04-30     Dry
# 8 2017-10-31     Wet
#
# [5 rows x 22 columns]

# %% [markdown]
# ### 1.4 Calculating average values at unique observation points<a class="anchor" id="reg_average"></a>

# %%
dfAll_Mean = updated_dfAllTime.groupby(['WaterBody','ParameterName','ParameterUnits','Seasons','Latitude_DD','Longitude_DD','WbodyAcronym'])["ResultValue"].agg("mean").reset_index()
dfAll = dfAll_Mean

# %% [markdown]
# ### 1.5 Convert coordinate system to EPSG: 3086<a class="anchor" id="reg_coordinate"></a>

# %%
# Define the EPSG codes for source (EPSG:4326) and target (EPSG:3086) coordinate systems
source_epsg = 'EPSG:4326'
target_epsg = 'EPSG:3086'

# Create a PyProj Transformer for the conversion
transformer = pyproj.Transformer.from_crs(source_epsg, target_epsg, always_xy=True)

# Define a function to apply the transformation to each row of the DataFrame
def transform_coordinates(row):
    x, y = transformer.transform(row['Longitude_DD'], row['Latitude_DD'])
    return pd.Series({'x': x, 'y': y})

# Apply the transformation function to the DataFrame and create new columns for the converted coordinates
dfAll[['x', 'y']] = dfAll.apply(transform_coordinates, axis=1)

# %% [markdown]
# #### Save aggregated data to csv file

# %%
dfAll.to_csv(gis_path + 'OEAT_2Seasons_All_WQ-2024-May-02.csv', index=False)

# %% [markdown]
# ## 2. Prepare for batch interpolation<a class="anchor" id="reg_batch"></a>
# ### 2.1 Preset abbreviation for waterbody and parameter name<a class="anchor" id="reg_preset"></a>

# %%
area_shortnames = {
    'Guana Tolomato Matanzas': 'GTM',
    'Estero Bay': 'EB',
    'Charlotte Harbor': 'CH',
    'Biscayne Bay': 'BB',
    'Big Bend Seagrasses':'BBS'
}

param_shortnames = {
    'Salinity': 'Sal_ppt',
    'Total Nitrogen': 'TN_mgl',
    'Dissolved Oxygen': 'DO_mgl',
    'Turbidity':'Turb_ntu',
    'Secchi Depth':'Secc_m',
    'Water Temperature':'T_c'
}

covariates_dict = {
    "GTM":"LDI",
    "EB":"bathymetry+LDI+popden",
    "CH":"bathymetry+LDI+popden+water_flow_wet",
    "BB":"bathymetry+LDI+popden",
    "BBS":"bathymetry+LDI"
}

# %% [markdown]
# ### 2.2 Load the barrier files<a class="anchor" id="reg_barrier"></a>

# %%
barrier_folder = os.path.join(gis_path, 'Barriers')
barrier_folder

barriers = []
for file in os.listdir(barrier_folder):
    if file.endswith(".shp"):
        barriers.append(os.path.join(barrier_folder, file))

for barrier in barriers:
    print(barrier)
# Out:
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\BBS_Barriers.shp
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\BB_Barriers.shp
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\CH_Barriers.shp
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\EB_Barriers.shp
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\GTM_Barriers.shp

# %% [markdown]
# ### 2.3 Define waterbody boundary for spatial extent and masking<a class="anchor" id="reg_boundary"></a>

# %%
waterbody_extent = os.path.join(gis_path, 'OEAT_Waterbody_Boundaries', 'OEAT_Waterbody_Boundary.shp')

unique_waterbodies = []
with arcpy.da.SearchCursor(waterbody_extent, ['WaterbodyA']) as cursor:
    for row in cursor:
        unique_waterbodies.append(row[0])

print("Unique Waterbodies:", unique_waterbodies)
# Out:
# Unique Waterbodies: ['BBS', 'BB', 'CH', 'EB', 'GTM']

# %% [markdown]
# ### 2.4 Load the table of study periods,  parameters, and seasons<a class="anchor" id="reg_study"></a>

# %%
seasons_all = pd.read_csv(gis_path + 'season_def/TwoSeasons_all.csv', low_memory=False)
seasons_all.head(10)
# Out:
#                  WaterBody  Start Year  End Year Seasons       Parameter  \
# 0         Charlotte Harbor        2017      2017     Wet  Total Nitrogen
# 1         Charlotte Harbor        2017      2018     Dry  Total Nitrogen
# 2      Big Bend Seagrasses        2021      2021     Wet  Total Nitrogen
# 3      Big Bend Seagrasses        2021      2022     Dry  Total Nitrogen
# 4               Estero Bay        2017      2017     Wet  Total Nitrogen
# 5               Estero Bay        2017      2018     Dry  Total Nitrogen
# 6  Guana Tolomato Matanzas        2016      2016     Wet  Total Nitrogen
# 7  Guana Tolomato Matanzas        2016      2017     Dry  Total Nitrogen
# 8             Biscayne Bay        2022      2022     Wet  Total Nitrogen
# 9             Biscayne Bay        2022      2023     Dry  Total Nitrogen
#
#    Filename  NumDataPoints  RMSE  ME
# 0       NaN            NaN   NaN NaN
# 1       NaN            NaN   NaN NaN
# 2       NaN            NaN   NaN NaN
# 3       NaN            NaN   NaN NaN
# 4       NaN            NaN   NaN NaN
# 5       NaN            NaN   NaN NaN
# 6       NaN            NaN   NaN NaN
# 7       NaN            NaN   NaN NaN
# 8       NaN            NaN   NaN NaN
# 9       NaN            NaN   NaN NaN

# %% [markdown]
# ### 2.5 Define output folders<a class="anchor" id="reg_output"></a>

# %%
# shpAll_folder = gis_path + r"shapefiles_2seasons" 
# idwAll_folder = gis_path + r"raster_idw_2seasons"

shpAll_folder = gis_path + r"shapefiles/TwoSeasons_All" 
idwAll_folder = gis_path + r"raster_output/TwoSeasons_IDW_All"

# Preview dataset
dfAll
# Out:
#                     WaterBody      ParameterName ParameterUnits Seasons  \
# 0         Big Bend Seagrasses   Dissolved Oxygen           mg/L     Dry
# 1         Big Bend Seagrasses   Dissolved Oxygen           mg/L     Dry
# 2         Big Bend Seagrasses   Dissolved Oxygen           mg/L     Dry
# 3         Big Bend Seagrasses   Dissolved Oxygen           mg/L     Dry
# 4         Big Bend Seagrasses   Dissolved Oxygen           mg/L     Dry
# ...                       ...                ...            ...     ...
# 7111  Guana Tolomato Matanzas  Water Temperature      Degrees C     Wet
# 7112  Guana Tolomato Matanzas  Water Temperature      Degrees C     Wet
# 7113  Guana Tolomato Matanzas  Water Temperature      Degrees C     Wet
# 7114  Guana Tolomato Matanzas  Water Temperature      Degrees C     Wet
# 7115  Guana Tolomato Matanzas  Water Temperature      Degrees C     Wet
#
#       Latitude_DD  Longitude_DD WbodyAcronym  ResultValue              x  \
# 0       29.008300    -82.825250          BBS     8.245000  514236.629541
# 1       29.080840    -83.053090          BBS     6.630000  492019.336544
# 2       29.085830    -83.068570          BBS     6.480000  490510.856107
# 3       29.095770    -83.028650          BBS     6.930000  494381.272368
# 4       29.095800    -83.069580          BBS     6.720000  490404.358820
# ...           ...           ...          ...          ...            ...
# 7111    30.053833    -81.375833          GTM     3.100000  652697.269107
# 7112    30.061167    -81.356167          GTM     3.110000  654573.328167
# 7113    30.062167    -81.370333          GTM     3.100000  653207.093339
# 7114    30.062183    -81.369175          GTM    27.594455  653318.539140
# 7115    30.116880    -81.344440          GTM    27.440000  655569.134836
#
#                   y
# 0     556316.261436
# 1     564180.798088
# 2     564723.446382
# 3     565857.139054
# 4     565829.803709
# ...             ...
# 7111  674545.694392
# 7112  675399.981470
# 7113  675481.792443
# 7114  675486.024073
# 7115  681607.088543
#
# [7116 rows x 10 columns]

# %% [markdown]
# ### 2.6 Fill NaN RowID with unique ID (IDW function needs unique ID) <a class="anchor" id="reg_id"></a>

# %%
idw_rk.fill_nan_rowids(dfAll, 'RowID')

# Keep RowID as integer
dfAll['RowID'] = dfAll['RowID'].astype(int)
dfAll
# Out:
#                     WaterBody      ParameterName ParameterUnits Seasons  \
# 0         Big Bend Seagrasses   Dissolved Oxygen           mg/L     Dry
# 1         Big Bend Seagrasses   Dissolved Oxygen           mg/L     Dry
# 2         Big Bend Seagrasses   Dissolved Oxygen           mg/L     Dry
# 3         Big Bend Seagrasses   Dissolved Oxygen           mg/L     Dry
# 4         Big Bend Seagrasses   Dissolved Oxygen           mg/L     Dry
# ...                       ...                ...            ...     ...
# 7111  Guana Tolomato Matanzas  Water Temperature      Degrees C     Wet
# 7112  Guana Tolomato Matanzas  Water Temperature      Degrees C     Wet
# 7113  Guana Tolomato Matanzas  Water Temperature      Degrees C     Wet
# 7114  Guana Tolomato Matanzas  Water Temperature      Degrees C     Wet
# 7115  Guana Tolomato Matanzas  Water Temperature      Degrees C     Wet
#
#       Latitude_DD  Longitude_DD WbodyAcronym  ResultValue              x  \
# 0       29.008300    -82.825250          BBS     8.245000  514236.629541
# 1       29.080840    -83.053090          BBS     6.630000  492019.336544
# 2       29.085830    -83.068570          BBS     6.480000  490510.856107
# 3       29.095770    -83.028650          BBS     6.930000  494381.272368
# 4       29.095800    -83.069580          BBS     6.720000  490404.358820
# ...           ...           ...          ...          ...            ...
# 7111    30.053833    -81.375833          GTM     3.100000  652697.269107
# 7112    30.061167    -81.356167          GTM     3.110000  654573.328167
# 7113    30.062167    -81.370333          GTM     3.100000  653207.093339
# 7114    30.062183    -81.369175          GTM    27.594455  653318.539140
# 7115    30.116880    -81.344440          GTM    27.440000  655569.134836
#
#                   y  RowID
# 0     556316.261436      1
# 1     564180.798088      2
# 2     564723.446382      3
# 3     565857.139054      4
# 4     565829.803709      5
# ...             ...    ...
# 7111  674545.694392   7112
# 7112  675399.981470   7113
# 7113  675481.792443   7114
# 7114  675486.024073   7115
# 7115  681607.088543   7116
#
# [7116 rows x 11 columns]

# %% [markdown]
# ## 3. Create Shapefiles <a class="anchor" id="reg_create_shp"></a>

# %%
# Merge interested with latitude and longitude columns
seasons_all_coord = idw_rk.merge_with_lat_long_new(seasons_all, dfAll, "Seasons")
seasons_all_coord
# Out:
#              WaterBody  Start Year  End Year Seasons          Parameter  \
# 0     Charlotte Harbor        2017      2017     Wet     Total Nitrogen
# 1     Charlotte Harbor        2017      2017     Wet     Total Nitrogen
# 2     Charlotte Harbor        2017      2017     Wet     Total Nitrogen
# 3     Charlotte Harbor        2017      2017     Wet     Total Nitrogen
# 4     Charlotte Harbor        2017      2017     Wet     Total Nitrogen
# ...                ...         ...       ...     ...                ...
# 7113      Biscayne Bay        2022      2023     Dry  Water Temperature
# 7114      Biscayne Bay        2022      2023     Dry  Water Temperature
# 7115      Biscayne Bay        2022      2023     Dry  Water Temperature
# 7116      Biscayne Bay        2022      2023     Dry  Water Temperature
# 7117      Biscayne Bay        2022      2023     Dry  Water Temperature
#
#       Filename  NumDataPoints  RMSE  ME              x              y  RowID  \
# 0          NaN            NaN   NaN NaN  591484.839075  272735.047067   4666
# 1          NaN            NaN   NaN NaN  589588.413455  274006.691366   4667
# 2          NaN            NaN   NaN NaN  591623.331894  274259.212418   4668
# 3          NaN            NaN   NaN NaN  589465.802362  275500.164081   4669
# 4          NaN            NaN   NaN NaN  588236.919040  276249.476798   4670
# ...        ...            ...   ...  ..            ...            ...    ...
# 7113       NaN            NaN   NaN NaN  784697.376005  213473.546119   1343
# 7114       NaN            NaN   NaN NaN  785872.039658  216879.318151   1344
# 7115       NaN            NaN   NaN NaN  787466.428428  218699.961879   1345
# 7116       NaN            NaN   NaN NaN  784434.233710  221871.479681   1346
# 7117       NaN            NaN   NaN NaN  784864.118846  223729.280777   1347
#
#       ResultValue
# 0        0.870000
# 1        0.850000
# 2        0.940000
# 3        0.780000
# 4        0.830000
# ...           ...
# 7113    25.176294
# 7114    25.423244
# 7115    25.730076
# 7116    25.338482
# 7117    25.261169
#
# [7118 rows x 13 columns]

# %%
idw_rk.create_shp_season_new(seasons_all_coord, "Seasons", shpAll_folder, start_year_included=True)
# Out:
# Number of data rows for BBS, DO_mgl, 2021, Dry: 141
# Shapefile for BBS, DO_mgl for 2021 and season Dry has been saved as SHP_BBS_DO_mgl_2021_Dry.shp
# Number of data rows for BBS, Sal_ppt, 2021, Dry: 132
# Shapefile for BBS, Sal_ppt for 2021 and season Dry has been saved as SHP_BBS_Sal_ppt_2021_Dry.shp
# Number of data rows for BBS, Secc_m, 2021, Dry: 32
# Shapefile for BBS, Secc_m for 2021 and season Dry has been saved as SHP_BBS_Secc_m_2021_Dry.shp
# Number of data rows for BBS, TN_mgl, 2021, Dry: 41
# Shapefile for BBS, TN_mgl for 2021 and season Dry has been saved as SHP_BBS_TN_mgl_2021_Dry.shp
# Number of data rows for BBS, Turb_ntu, 2021, Dry: 42
# Shapefile for BBS, Turb_ntu for 2021 and season Dry has been saved as SHP_BBS_Turb_ntu_2021_Dry.shp
# Number of data rows for BBS, T_c, 2021, Dry: 141
# Shapefile for BBS, T_c for 2021 and season Dry has been saved as SHP_BBS_T_c_2021_Dry.shp
# Number of data rows for BBS, DO_mgl, 2021, Wet: 51
# Shapefile for BBS, DO_mgl for 2021 and season Wet has been saved as SHP_BBS_DO_mgl_2021_Wet.shp
# Number of data rows for BBS, Sal_ppt, 2021, Wet: 40
# Shapefile for BBS, Sal_ppt for 2021 and season Wet has been saved as SHP_BBS_Sal_ppt_2021_Wet.shp
# Number of data rows for BBS, Secc_m, 2021, Wet: 43
# Shapefile for BBS, Secc_m for 2021 and season Wet has been saved as SHP_BBS_Secc_m_2021_Wet.shp
# Number of data rows for BBS, TN_mgl, 2021, Wet: 39
# Shapefile for BBS, TN_mgl for 2021 and season Wet has been saved as SHP_BBS_TN_mgl_2021_Wet.shp
# Number of data rows for BBS, Turb_ntu, 2021, Wet: 40
# Shapefile for BBS, Turb_ntu for 2021 and season Wet has been saved as SHP_BBS_Turb_ntu_2021_Wet.shp
# Number of data rows for BBS, T_c, 2021, Wet: 51
# Shapefile for BBS, T_c for 2021 and season Wet has been saved as SHP_BBS_T_c_2021_Wet.shp
# Number of data rows for BB, DO_mgl, 2022, Dry: 70
# Shapefile for BB, DO_mgl for 2022 and season Dry has been saved as SHP_BB_DO_mgl_2022_Dry.shp
# Number of data rows for BB, Sal_ppt, 2022, Dry: 64
# Shapefile for BB, Sal_ppt for 2022 and season Dry has been saved as SHP_BB_Sal_ppt_2022_Dry.shp
# No valid data found for area: BB, parameter: Secc_m, year: 2022, and season: Dry
# Number of data rows for BB, TN_mgl, 2022, Dry: 60
# Shapefile for BB, TN_mgl for 2022 and season Dry has been saved as SHP_BB_TN_mgl_2022_Dry.shp
# Number of data rows for BB, Turb_ntu, 2022, Dry: 51
# Shapefile for BB, Turb_ntu for 2022 and season Dry has been saved as SHP_BB_Turb_ntu_2022_Dry.shp
# Number of data rows for BB, T_c, 2022, Dry: 72
# Shapefile for BB, T_c for 2022 and season Dry has been saved as SHP_BB_T_c_2022_Dry.shp
# Number of data rows for BB, DO_mgl, 2022, Wet: 71
# Shapefile for BB, DO_mgl for 2022 and season Wet has been saved as SHP_BB_DO_mgl_2022_Wet.shp
# Number of data rows for BB, Sal_ppt, 2022, Wet: 52
# Shapefile for BB, Sal_ppt for 2022 and season Wet has been saved as SHP_BB_Sal_ppt_2022_Wet.shp
# Number of data rows for BB, Secc_m, 2022, Wet: 1
# Shapefile for BB, Secc_m for 2022 and season Wet has been saved as SHP_BB_Secc_m_2022_Wet.shp
# Number of data rows for BB, TN_mgl, 2022, Wet: 60
# Shapefile for BB, TN_mgl for 2022 and season Wet has been saved as SHP_BB_TN_mgl_2022_Wet.shp
# Number of data rows for BB, Turb_ntu, 2022, Wet: 53
# Shapefile for BB, Turb_ntu for 2022 and season Wet has been saved as SHP_BB_Turb_ntu_2022_Wet.shp
# Number of data rows for BB, T_c, 2022, Wet: 73
# Shapefile for BB, T_c for 2022 and season Wet has been saved as SHP_BB_T_c_2022_Wet.shp
# Number of data rows for CH, DO_mgl, 2017, Dry: 352
# Shapefile for CH, DO_mgl for 2017 and season Dry has been saved as SHP_CH_DO_mgl_2017_Dry.shp
# Number of data rows for CH, Sal_ppt, 2017, Dry: 298
# Shapefile for CH, Sal_ppt for 2017 and season Dry has been saved as SHP_CH_Sal_ppt_2017_Dry.shp
# Number of data rows for CH, Secc_m, 2017, Dry: 223
# Shapefile for CH, Secc_m for 2017 and season Dry has been saved as SHP_CH_Secc_m_2017_Dry.shp
# Number of data rows for CH, TN_mgl, 2017, Dry: 91
# Shapefile for CH, TN_mgl for 2017 and season Dry has been saved as SHP_CH_TN_mgl_2017_Dry.shp
# Number of data rows for CH, Turb_ntu, 2017, Dry: 91
# Shapefile for CH, Turb_ntu for 2017 and season Dry has been saved as SHP_CH_Turb_ntu_2017_Dry.shp
# Number of data rows for CH, T_c, 2017, Dry: 354
# Shapefile for CH, T_c for 2017 and season Dry has been saved as SHP_CH_T_c_2017_Dry.shp
# Number of data rows for CH, DO_mgl, 2017, Wet: 833
# Shapefile for CH, DO_mgl for 2017 and season Wet has been saved as SHP_CH_DO_mgl_2017_Wet.shp
# Number of data rows for CH, Sal_ppt, 2017, Wet: 771
# Shapefile for CH, Sal_ppt for 2017 and season Wet has been saved as SHP_CH_Sal_ppt_2017_Wet.shp
# Number of data rows for CH, Secc_m, 2017, Wet: 677
# Shapefile for CH, Secc_m for 2017 and season Wet has been saved as SHP_CH_Secc_m_2017_Wet.shp
# Number of data rows for CH, TN_mgl, 2017, Wet: 91
# Shapefile for CH, TN_mgl for 2017 and season Wet has been saved as SHP_CH_TN_mgl_2017_Wet.shp
# Number of data rows for CH, Turb_ntu, 2017, Wet: 92
# Shapefile for CH, Turb_ntu for 2017 and season Wet has been saved as SHP_CH_Turb_ntu_2017_Wet.shp
# Number of data rows for CH, T_c, 2017, Wet: 836
# Shapefile for CH, T_c for 2017 and season Wet has been saved as SHP_CH_T_c_2017_Wet.shp
# Number of data rows for EB, DO_mgl, 2017, Dry: 80
# Shapefile for EB, DO_mgl for 2017 and season Dry has been saved as SHP_EB_DO_mgl_2017_Dry.shp
# Number of data rows for EB, Sal_ppt, 2017, Dry: 23
# Shapefile for EB, Sal_ppt for 2017 and season Dry has been saved as SHP_EB_Sal_ppt_2017_Dry.shp
# Number of data rows for EB, Secc_m, 2017, Dry: 5
# Shapefile for EB, Secc_m for 2017 and season Dry has been saved as SHP_EB_Secc_m_2017_Dry.shp
# Number of data rows for EB, TN_mgl, 2017, Dry: 65
# Shapefile for EB, TN_mgl for 2017 and season Dry has been saved as SHP_EB_TN_mgl_2017_Dry.shp
# Number of data rows for EB, Turb_ntu, 2017, Dry: 71
# Shapefile for EB, Turb_ntu for 2017 and season Dry has been saved as SHP_EB_Turb_ntu_2017_Dry.shp
# Number of data rows for EB, T_c, 2017, Dry: 80
# Shapefile for EB, T_c for 2017 and season Dry has been saved as SHP_EB_T_c_2017_Dry.shp
# Number of data rows for EB, DO_mgl, 2017, Wet: 63
# Shapefile for EB, DO_mgl for 2017 and season Wet has been saved as SHP_EB_DO_mgl_2017_Wet.shp
# Number of data rows for EB, Sal_ppt, 2017, Wet: 18
# Shapefile for EB, Sal_ppt for 2017 and season Wet has been saved as SHP_EB_Sal_ppt_2017_Wet.shp
# Number of data rows for EB, Secc_m, 2017, Wet: 10
# Shapefile for EB, Secc_m for 2017 and season Wet has been saved as SHP_EB_Secc_m_2017_Wet.shp
# Number of data rows for EB, TN_mgl, 2017, Wet: 55
# Shapefile for EB, TN_mgl for 2017 and season Wet has been saved as SHP_EB_TN_mgl_2017_Wet.shp
# Number of data rows for EB, Turb_ntu, 2017, Wet: 56
# Shapefile for EB, Turb_ntu for 2017 and season Wet has been saved as SHP_EB_Turb_ntu_2017_Wet.shp
# Number of data rows for EB, T_c, 2017, Wet: 65
# Shapefile for EB, T_c for 2017 and season Wet has been saved as SHP_EB_T_c_2017_Wet.shp
# Number of data rows for GTM, DO_mgl, 2016, Dry: 56
# Shapefile for GTM, DO_mgl for 2016 and season Dry has been saved as SHP_GTM_DO_mgl_2016_Dry.shp
# Number of data rows for GTM, Sal_ppt, 2016, Dry: 55
# Shapefile for GTM, Sal_ppt for 2016 and season Dry has been saved as SHP_GTM_Sal_ppt_2016_Dry.shp
# Number of data rows for GTM, Secc_m, 2016, Dry: 2
# Shapefile for GTM, Secc_m for 2016 and season Dry has been saved as SHP_GTM_Secc_m_2016_Dry.shp
# Number of data rows for GTM, TN_mgl, 2016, Dry: 6
# Shapefile for GTM, TN_mgl for 2016 and season Dry has been saved as SHP_GTM_TN_mgl_2016_Dry.shp
# Number of data rows for GTM, Turb_ntu, 2016, Dry: 10
# Shapefile for GTM, Turb_ntu for 2016 and season Dry has been saved as SHP_GTM_Turb_ntu_2016_Dry.shp
# Number of data rows for GTM, T_c, 2016, Dry: 21
# Shapefile for GTM, T_c for 2016 and season Dry has been saved as SHP_GTM_T_c_2016_Dry.shp
# Number of data rows for GTM, DO_mgl, 2016, Wet: 81
# Shapefile for GTM, DO_mgl for 2016 and season Wet has been saved as SHP_GTM_DO_mgl_2016_Wet.shp
# Number of data rows for GTM, Sal_ppt, 2016, Wet: 77
# Shapefile for GTM, Sal_ppt for 2016 and season Wet has been saved as SHP_GTM_Sal_ppt_2016_Wet.shp
# No valid data found for area: GTM, parameter: Secc_m, year: 2016, and season: Wet
# Number of data rows for GTM, TN_mgl, 2016, Wet: 5
# Shapefile for GTM, TN_mgl for 2016 and season Wet has been saved as SHP_GTM_TN_mgl_2016_Wet.shp
# Number of data rows for GTM, Turb_ntu, 2016, Wet: 9
# Shapefile for GTM, Turb_ntu for 2016 and season Wet has been saved as SHP_GTM_Turb_ntu_2016_Wet.shp
# Number of data rows for GTM, T_c, 2016, Wet: 74
# Shapefile for GTM, T_c for 2016 and season Wet has been saved as SHP_GTM_T_c_2016_Wet.shp

# %% [markdown]
# ## 4. Cross Validation for IDW <a class="anchor" id="reg_cv_idw"></a>

# %%
# Empty the shapefile folder
# idw_rk.delete_all_files(idwAll_folder)

# %%
# Select a section of table to process
seasons_slct = seasons_all.iloc[:]
seasons_slct.drop(seasons_slct[seasons_slct['WaterBody'] != 'Charlotte Harbor'].index, inplace=True)
seasons_slct = seasons_slct.reset_index()
seasons_slct
# Out:
#     index         WaterBody  Start Year  End Year Seasons          Parameter  \
# 0       0  Charlotte Harbor        2017      2017     Wet     Total Nitrogen
# 1       1  Charlotte Harbor        2017      2018     Dry     Total Nitrogen
# 2      10  Charlotte Harbor        2017      2017     Wet           Salinity
# 3      11  Charlotte Harbor        2017      2018     Dry           Salinity
# 4      20  Charlotte Harbor        2017      2017     Wet   Dissolved Oxygen
# 5      21  Charlotte Harbor        2017      2018     Dry   Dissolved Oxygen
# 6      30  Charlotte Harbor        2017      2017     Wet          Turbidity
# 7      31  Charlotte Harbor        2017      2018     Dry          Turbidity
# 8      40  Charlotte Harbor        2017      2017     Wet       Secchi Depth
# 9      41  Charlotte Harbor        2017      2018     Dry       Secchi Depth
# 10     50  Charlotte Harbor        2017      2017     Wet  Water Temperature
# 11     51  Charlotte Harbor        2017      2018     Dry  Water Temperature
#
#     Filename  NumDataPoints  RMSE  ME         covariates
# 0        NaN            NaN   NaN NaN  default_covariate
# 1        NaN            NaN   NaN NaN  default_covariate
# 2        NaN            NaN   NaN NaN  default_covariate
# 3        NaN            NaN   NaN NaN  default_covariate
# 4        NaN            NaN   NaN NaN  default_covariate
# 5        NaN            NaN   NaN NaN  default_covariate
# 6        NaN            NaN   NaN NaN  default_covariate
# 7        NaN            NaN   NaN NaN  default_covariate
# 8        NaN            NaN   NaN NaN  default_covariate
# 9        NaN            NaN   NaN NaN  default_covariate
# 10       NaN            NaN   NaN NaN  default_covariate
# 11       NaN            NaN   NaN NaN  default_covariate

# %%
importlib.reload(idw_rk)

# If the number of data points is less than 3，skipping calculate IDW
idw_rk.idw_interpolation_sampled(seasons_slct, shpAll_folder, idwAll_folder, waterbody_extent, barrier_folder, "Seasons", percentage = 10)
# Out:
# Processing file: SHP_CH_TN_mgl_2017_Wet.shp
# File SHP_CH_TN_mgl_2017_Wet.shp has completed 91 cross-validation iterations using 100% samples.
# Processing file: SHP_CH_TN_mgl_2017_Dry.shp
# File SHP_CH_TN_mgl_2017_Dry.shp has completed 91 cross-validation iterations using 100% samples.
# Processing file: SHP_CH_Sal_ppt_2017_Wet.shp
# File SHP_CH_Sal_ppt_2017_Wet.shp has completed 77 cross-validation iterations using 10% samples.
# Processing file: SHP_CH_Sal_ppt_2017_Dry.shp
# File SHP_CH_Sal_ppt_2017_Dry.shp has completed 30 cross-validation iterations using 10% samples.
# Processing file: SHP_CH_DO_mgl_2017_Wet.shp
# File SHP_CH_DO_mgl_2017_Wet.shp has completed 83 cross-validation iterations using 10% samples.
# Processing file: SHP_CH_DO_mgl_2017_Dry.shp
# File SHP_CH_DO_mgl_2017_Dry.shp has completed 35 cross-validation iterations using 10% samples.
# Processing file: SHP_CH_Turb_ntu_2017_Wet.shp
# File SHP_CH_Turb_ntu_2017_Wet.shp has completed 92 cross-validation iterations using 100% samples.
# Processing file: SHP_CH_Turb_ntu_2017_Dry.shp
# File SHP_CH_Turb_ntu_2017_Dry.shp has completed 91 cross-validation iterations using 100% samples.
# Processing file: SHP_CH_Secc_m_2017_Wet.shp
# File SHP_CH_Secc_m_2017_Wet.shp has completed 68 cross-validation iterations using 10% samples.
# Processing file: SHP_CH_Secc_m_2017_Dry.shp
# File SHP_CH_Secc_m_2017_Dry.shp has completed 22 cross-validation iterations using 10% samples.
# Processing file: SHP_CH_T_c_2017_Wet.shp
# File SHP_CH_T_c_2017_Wet.shp has completed 84 cross-validation iterations using 10% samples.
# Processing file: SHP_CH_T_c_2017_Dry.shp
# File SHP_CH_T_c_2017_Dry.shp has completed 35 cross-validation iterations using 10% samples.
# Calculated RMSE: 2.958621560679572, ME: 0.28318549549714295 for file: SHP_CH_T_c_2017_Dry.shp. Time used: 23185.214866876602

# %% [markdown]
# ## 5. RK Interpolation<a class="anchor" id="reg_rk"></a>
#
# ### Define output folder

# %%
# out_raster_folder = gis_path + r"rk_folder/TwoSeasons_RK_all/"
# out_ga_folder     = gis_path + r"rk_folder/ga_output_rk_2s/"
# diagnostic_folder = gis_path + r"rk_folder/diagnostic_rk_2s/"
# std_error_folder  = gis_path + r"rk_folder/std_error_pred_2s/std_error_rk/"

out_raster_folder = gis_path + r"raster_output/TwoSeasons_RK_all/"
out_ga_folder     = gis_path + r"ga_output_rk/"
diagnostic_folder = gis_path + r"diagnostic_rk/"
std_error_folder  = gis_path + r"std_error_pred/std_error_rk_4s/"

# Clean existing files in folders
# idw_rk.delete_all_files(out_raster_folder)
# idw_rk.delete_all_files(out_ga_folder)
# idw_rk.delete_all_files(diagnostic_folder)
# idw_rk.delete_all_files(std_error_folder)

# %%
seasons_all['covariates'] = seasons_all['WaterBody'].apply(lambda x: covariates_dict.get(x, 'default_covariate'))

rk_csv = gis_path + "rk_2s.csv" 
seasons_all.to_csv(rk_csv, index=False, encoding='utf-8-sig')

# %%
with open(gis_path + "rk_2s.csv", 'w', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    # Determine if year should be included in the output based on a condition
    start_year_included = True

    # Write the header line based on whether the year is included
    cols = list(seasons_all.columns)
    if not start_year_included:
        cols.remove('Start Year')
        cols.remove('End Year')
    csv_writer.writerow(cols)
    
    for i in seasons_all.index:
        s_time = time.time()
        process, rmse, me, count, file_loc = idw_rk.rk_interpolation_new(
            method="rk",
            radius=50000,
            folder_path=gis_path,
            waterbody=area_shortnames[seasons_all.iloc[i]["WaterBody"]],
            parameter=param_shortnames[seasons_all.iloc[i]["Parameter"]],
            year=seasons_all.iloc[i]["Start Year"],
            season=seasons_all.iloc[i]['Seasons'],
            covariates=covariates_dict[area_shortnames[seasons_all.iloc[i]["WaterBody"]]],
            out_raster_folder=out_raster_folder,
            out_ga_folder=out_ga_folder,
            std_error_folder=std_error_folder,
            diagnostic_folder=diagnostic_folder,
            shapefile_folder_name=shpAll_folder,
            start_year_included=start_year_included  # Pass the variable to the function
        )
        e_time = time.time()

        # Write data row, conditionally include year based on the setting
        data_row = [
            seasons_all.iloc[i]["WaterBody"], 
            seasons_all.iloc[i]['Seasons'],
            seasons_all.iloc[i]["Parameter"],
            file_loc, count, rmse, me,
            covariates_dict[area_shortnames[seasons_all.iloc[i]["WaterBody"]]]
        ]
        if start_year_included:
            data_row.insert(1, seasons_all.iloc[i]["Start Year"])
            data_row.insert(2, seasons_all.iloc[i]["End Year"])

        print(f"{int(e_time - s_time)} seconds elapsed for processing {count} points in {i}th row: RMSE: {rmse}, ME: {me}, file exported to {file_loc}")
        csv_writer.writerow(data_row)
        if i % 10 == 0:
            csvfile.flush()  # Flush the csv file every 10 rows.
# Out:
# Processing file: SHP_CH_TN_mgl_2017_Wet.shp
# --- Time lapse: 1738.9533660411835 seconds ---
# 1739 seconds elapsed for processing 91 points in 0th row: RMSE: 0.518503292409, ME: -0.00548043251879, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/CH_TN_mgl_2017_Wet_RK.tif
# Processing file: SHP_CH_TN_mgl_2017_Dry.shp
# --- Time lapse: 2704.7894995212555 seconds ---
# 2705 seconds elapsed for processing 91 points in 1th row: RMSE: 0.146277379864, ME: 0.000458913001099, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/CH_TN_mgl_2017_Dry_RK.tif
# Processing file: SHP_BBS_TN_mgl_2021_Wet.shp
# --- Time lapse: 2548.784058570862 seconds ---
# 2548 seconds elapsed for processing 39 points in 2th row: RMSE: 0.177156170228, ME: 0.000178653472476, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/BBS_TN_mgl_2021_Wet_RK.tif
# Processing file: SHP_BBS_TN_mgl_2021_Dry.shp
# --- Time lapse: 2806.0260152816772 seconds ---
# 2806 seconds elapsed for processing 41 points in 3th row: RMSE: 0.165579659935, ME: -0.00682298377104, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/BBS_TN_mgl_2021_Dry_RK.tif
# Processing file: SHP_EB_TN_mgl_2017_Wet.shp
# --- Time lapse: 145.24462509155273 seconds ---
# 145 seconds elapsed for processing 55 points in 4th row: RMSE: 0.203446979204, ME: -0.00084781804922, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/EB_TN_mgl_2017_Wet_RK.tif
# Processing file: SHP_EB_TN_mgl_2017_Dry.shp
# --- Time lapse: 164.73847770690918 seconds ---
# 164 seconds elapsed for processing 65 points in 5th row: RMSE: 0.143564112877, ME: 0.00181758480929, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/EB_TN_mgl_2017_Dry_RK.tif
# TN_mgl in 2016 Wet caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 5 points in 6th row: RMSE: nan, ME: nan, file exported to nan
# TN_mgl in 2016 Dry caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 6 points in 7th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_BB_TN_mgl_2022_Wet.shp
# --- Time lapse: 761.2186529636383 seconds ---
# 761 seconds elapsed for processing 60 points in 8th row: RMSE: 0.134765689675, ME: -0.00733955086897, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/BB_TN_mgl_2022_Wet_RK.tif
# Processing file: SHP_BB_TN_mgl_2022_Dry.shp
# --- Time lapse: 753.645834684372 seconds ---
# 753 seconds elapsed for processing 60 points in 9th row: RMSE: 0.112936919716, ME: -0.00759228199274, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/BB_TN_mgl_2022_Dry_RK.tif
# Processing file: SHP_CH_Sal_ppt_2017_Wet.shp
# --- Time lapse: 6125.402295589447 seconds ---
# 6125 seconds elapsed for processing 771 points in 10th row: RMSE: 9.70859064107, ME: 0.0670062026047, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/CH_Sal_ppt_2017_Wet_RK.tif
# Processing file: SHP_CH_Sal_ppt_2017_Dry.shp
# --- Time lapse: 4593.120333433151 seconds ---
# 4593 seconds elapsed for processing 298 points in 11th row: RMSE: 2.72295278468, ME: -0.0358025291576, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/CH_Sal_ppt_2017_Dry_RK.tif
# Processing file: SHP_BBS_Sal_ppt_2021_Wet.shp
# --- Time lapse: 2942.323892593384 seconds ---
# 2942 seconds elapsed for processing 40 points in 12th row: RMSE: 4.2929166515, ME: -0.738662966386, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/BBS_Sal_ppt_2021_Wet_RK.tif
# Processing file: SHP_BBS_Sal_ppt_2021_Dry.shp
# --- Time lapse: 7025.871169090271 seconds ---
# 7026 seconds elapsed for processing 132 points in 13th row: RMSE: 2.6455959696, ME: 0.00239280679347, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/BBS_Sal_ppt_2021_Dry_RK.tif
# Processing file: SHP_EB_Sal_ppt_2017_Wet.shp
# --- Time lapse: 49.82963252067566 seconds ---
# 50 seconds elapsed for processing 18 points in 14th row: RMSE: 4.92042613469, ME: -0.117601308019, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/EB_Sal_ppt_2017_Wet_RK.tif
# Processing file: SHP_EB_Sal_ppt_2017_Dry.shp
# --- Time lapse: 55.32083702087402 seconds ---
# 55 seconds elapsed for processing 23 points in 15th row: RMSE: 2.34165220579, ME: -0.486709126098, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/EB_Sal_ppt_2017_Dry_RK.tif
# Processing file: SHP_GTM_Sal_ppt_2016_Wet.shp
# --- Time lapse: 511.3508725166321 seconds ---
# 511 seconds elapsed for processing 77 points in 16th row: RMSE: 10.319014598, ME: -0.536699339702, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/GTM_Sal_ppt_2016_Wet_RK.tif
# Processing file: SHP_GTM_Sal_ppt_2016_Dry.shp
# --- Time lapse: 363.16937732696533 seconds ---
# 363 seconds elapsed for processing 55 points in 17th row: RMSE: 10.7701598472, ME: -1.26574496658, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/GTM_Sal_ppt_2016_Dry_RK.tif
# Processing file: SHP_BB_Sal_ppt_2022_Wet.shp
# --- Time lapse: 388.3454020023346 seconds ---
# 388 seconds elapsed for processing 52 points in 18th row: RMSE: 3.90500671313, ME: 0.245849052406, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/BB_Sal_ppt_2022_Wet_RK.tif
# Processing file: SHP_BB_Sal_ppt_2022_Dry.shp
# --- Time lapse: 786.4055755138397 seconds ---
# 786 seconds elapsed for processing 64 points in 19th row: RMSE: 3.28502625009, ME: 0.01453134773, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/BB_Sal_ppt_2022_Dry_RK.tif
# Processing file: SHP_CH_DO_mgl_2017_Wet.shp
# --- Time lapse: 6994.436315536499 seconds ---
# 6994 seconds elapsed for processing 833 points in 20th row: RMSE: 1.59819159939, ME: 0.190061263559, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/CH_DO_mgl_2017_Wet_RK.tif
# Processing file: SHP_CH_DO_mgl_2017_Dry.shp
# --- Time lapse: 5390.391838550568 seconds ---
# 5390 seconds elapsed for processing 352 points in 21th row: RMSE: 1.42373288814, ME: 0.0225976858977, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/CH_DO_mgl_2017_Dry_RK.tif
# Processing file: SHP_BBS_DO_mgl_2021_Wet.shp
# --- Time lapse: 3442.217703819275 seconds ---
# 3442 seconds elapsed for processing 51 points in 22th row: RMSE: 0.77758348937, ME: -0.163984020401, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/BBS_DO_mgl_2021_Wet_RK.tif
# Processing file: SHP_BBS_DO_mgl_2021_Dry.shp
# --- Time lapse: 10542.8672311306 seconds ---
# 10543 seconds elapsed for processing 141 points in 23th row: RMSE: 0.839500931841, ME: -0.053352541644, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/BBS_DO_mgl_2021_Dry_RK.tif
# Processing file: SHP_EB_DO_mgl_2017_Wet.shp
# --- Time lapse: 166.26899337768555 seconds ---
# 166 seconds elapsed for processing 63 points in 24th row: RMSE: 0.81485709662, ME: 0.00623546831473, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/EB_DO_mgl_2017_Wet_RK.tif
# Processing file: SHP_EB_DO_mgl_2017_Dry.shp
# --- Time lapse: 169.42984414100647 seconds ---
# 169 seconds elapsed for processing 80 points in 25th row: RMSE: 1.12071048999, ME: 0.00172830533117, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/EB_DO_mgl_2017_Dry_RK.tif
# Processing file: SHP_GTM_DO_mgl_2016_Wet.shp
# --- Time lapse: 538.6530165672302 seconds ---
# 538 seconds elapsed for processing 81 points in 26th row: RMSE: 1.84337862927, ME: -0.156485426163, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/GTM_DO_mgl_2016_Wet_RK.tif
# Processing file: SHP_GTM_DO_mgl_2016_Dry.shp
# --- Time lapse: 390.140878200531 seconds ---
# 390 seconds elapsed for processing 56 points in 27th row: RMSE: 2.08146071419, ME: -0.574783860422, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/GTM_DO_mgl_2016_Dry_RK.tif
# Processing file: SHP_BB_DO_mgl_2022_Wet.shp
# --- Time lapse: 829.6033291816711 seconds ---
# 829 seconds elapsed for processing 71 points in 28th row: RMSE: 0.721138352723, ME: -0.0118049358089, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/BB_DO_mgl_2022_Wet_RK.tif
# Processing file: SHP_BB_DO_mgl_2022_Dry.shp
# --- Time lapse: 817.4514186382294 seconds ---
# 817 seconds elapsed for processing 70 points in 29th row: RMSE: 0.721687128102, ME: 0.0106723490885, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/BB_DO_mgl_2022_Dry_RK.tif
# Processing file: SHP_CH_Turb_ntu_2017_Wet.shp
# --- Time lapse: 2719.5245490074158 seconds ---
# 2719 seconds elapsed for processing 92 points in 30th row: RMSE: 3.58760698325, ME: 0.0390725781281, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/CH_Turb_ntu_2017_Wet_RK.tif
# Processing file: SHP_CH_Turb_ntu_2017_Dry.shp
# --- Time lapse: 2663.27903008461 seconds ---
# 2663 seconds elapsed for processing 91 points in 31th row: RMSE: 1.42906874493, ME: -0.000778637472387, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/CH_Turb_ntu_2017_Dry_RK.tif
# Processing file: SHP_BBS_Turb_ntu_2021_Wet.shp
# --- Time lapse: 1949.1217300891876 seconds ---
# 1949 seconds elapsed for processing 40 points in 32th row: RMSE: 2.55772092809, ME: 0.080121143906, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/BBS_Turb_ntu_2021_Wet_RK.tif
# Processing file: SHP_BBS_Turb_ntu_2021_Dry.shp
# --- Time lapse: 2533.080240726471 seconds ---
# 2533 seconds elapsed for processing 42 points in 33th row: RMSE: 1.69959857638, ME: -0.00551732501717, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/BBS_Turb_ntu_2021_Dry_RK.tif
# Processing file: SHP_EB_Turb_ntu_2017_Wet.shp
# --- Time lapse: 141.81008386611938 seconds ---
# 141 seconds elapsed for processing 56 points in 34th row: RMSE: 2.75671164859, ME: 0.115837627975, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/EB_Turb_ntu_2017_Wet_RK.tif
# Processing file: SHP_EB_Turb_ntu_2017_Dry.shp
# --- Time lapse: 159.1324028968811 seconds ---
# 159 seconds elapsed for processing 71 points in 35th row: RMSE: 15.0847618622, ME: -0.101019686398, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/EB_Turb_ntu_2017_Dry_RK.tif
# Turb_ntu in 2016 Wet caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 9 points in 36th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_GTM_Turb_ntu_2016_Dry.shp
# --- Time lapse: 71.87199425697327 seconds ---
# 72 seconds elapsed for processing 10 points in 37th row: RMSE: 1.78331053726, ME: -0.114771696362, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/GTM_Turb_ntu_2016_Dry_RK.tif
# Processing file: SHP_BB_Turb_ntu_2022_Wet.shp
# --- Time lapse: 503.7021629810333 seconds ---
# 503 seconds elapsed for processing 53 points in 38th row: RMSE: 1.09024887111, ME: -0.00548859881268, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/BB_Turb_ntu_2022_Wet_RK.tif
# Processing file: SHP_BB_Turb_ntu_2022_Dry.shp
# --- Time lapse: 638.6962704658508 seconds ---
# 638 seconds elapsed for processing 51 points in 39th row: RMSE: 1.10413852403, ME: -0.00998224035901, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/BB_Turb_ntu_2022_Dry_RK.tif
# Processing file: SHP_CH_Secc_m_2017_Wet.shp
# --- Time lapse: 6288.536959648132 seconds ---
# 6288 seconds elapsed for processing 677 points in 40th row: RMSE: 0.348824660481, ME: -0.0014049644926, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/CH_Secc_m_2017_Wet_RK.tif
# Processing file: SHP_CH_Secc_m_2017_Dry.shp
# --- Time lapse: 6718.812705278397 seconds ---
# 6718 seconds elapsed for processing 223 points in 41th row: RMSE: 0.477796981644, ME: -0.0131050513074, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/CH_Secc_m_2017_Dry_RK.tif
# Processing file: SHP_BBS_Secc_m_2021_Wet.shp
# --- Time lapse: 1853.0678131580353 seconds ---
# 1853 seconds elapsed for processing 43 points in 42th row: RMSE: 0.870220118014, ME: 0.0125873289934, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/BBS_Secc_m_2021_Wet_RK.tif
# Processing file: SHP_BBS_Secc_m_2021_Dry.shp
# --- Time lapse: 1898.8277270793915 seconds ---
# 1899 seconds elapsed for processing 32 points in 43th row: RMSE: 1.18336792269, ME: 0.131440278037, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/BBS_Secc_m_2021_Dry_RK.tif
# Processing file: SHP_EB_Secc_m_2017_Wet.shp
# --- Time lapse: 32.4647331237793 seconds ---
# 32 seconds elapsed for processing 10 points in 44th row: RMSE: 0.441925280358, ME: 0.0750973529957, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/EB_Secc_m_2017_Wet_RK.tif
# Secc_m in 2017 Dry caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 5 points in 45th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_GTM_Secc_m_2016_Wet.shp, skipping
# 0 seconds elapsed for processing 0 points in 46th row: RMSE: nan, ME: nan, file exported to nan
# Secc_m in 2016 Dry caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 2 points in 47th row: RMSE: nan, ME: nan, file exported to nan
# Secc_m in 2022 Wet caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 3 seconds elapsed for processing 1 points in 48th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_BB_Secc_m_2022_Dry.shp, skipping
# 0 seconds elapsed for processing 0 points in 49th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_CH_T_c_2017_Wet.shp
# --- Time lapse: 7216.266669988632 seconds ---
# 7216 seconds elapsed for processing 836 points in 50th row: RMSE: 1.6408290526, ME: 0.0439923042572, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/CH_T_c_2017_Wet_RK.tif
# Processing file: SHP_CH_T_c_2017_Dry.shp
# --- Time lapse: 5480.464506387711 seconds ---
# 5480 seconds elapsed for processing 354 points in 51th row: RMSE: 2.19100143363, ME: -0.0516874892536, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/CH_T_c_2017_Dry_RK.tif
# Processing file: SHP_BBS_T_c_2021_Wet.shp
# --- Time lapse: 3179.466097354889 seconds ---
# 3179 seconds elapsed for processing 51 points in 52th row: RMSE: 0.538591569795, ME: -0.0331747249691, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/BBS_T_c_2021_Wet_RK.tif
# Processing file: SHP_BBS_T_c_2021_Dry.shp
# --- Time lapse: 8481.328758239746 seconds ---
# 8481 seconds elapsed for processing 141 points in 53th row: RMSE: 2.91162953956, ME: 0.242971480222, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/BBS_T_c_2021_Dry_RK.tif
# Processing file: SHP_EB_T_c_2017_Wet.shp
# --- Time lapse: 166.42768216133118 seconds ---
# 166 seconds elapsed for processing 65 points in 54th row: RMSE: 1.63691156605, ME: -0.0344773274254, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/EB_T_c_2017_Wet_RK.tif
# Processing file: SHP_EB_T_c_2017_Dry.shp
# --- Time lapse: 169.73741483688354 seconds ---
# 169 seconds elapsed for processing 80 points in 55th row: RMSE: 2.55275580698, ME: -0.0381524731749, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/EB_T_c_2017_Dry_RK.tif
# Processing file: SHP_GTM_T_c_2016_Wet.shp
# --- Time lapse: 517.2163178920746 seconds ---
# 517 seconds elapsed for processing 74 points in 56th row: RMSE: 7.58545698224, ME: 0.10331167247, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/GTM_T_c_2016_Wet_RK.tif
# Processing file: SHP_GTM_T_c_2016_Dry.shp
# --- Time lapse: 132.5718114376068 seconds ---
# 132 seconds elapsed for processing 21 points in 57th row: RMSE: 0.476977303124, ME: 0.0243198442045, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/GTM_T_c_2016_Dry_RK.tif
# Processing file: SHP_BB_T_c_2022_Wet.shp
# --- Time lapse: 819.4482908248901 seconds ---
# 819 seconds elapsed for processing 73 points in 58th row: RMSE: 0.827363749789, ME: 0.0249062772863, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/BB_T_c_2022_Wet_RK.tif
# Processing file: SHP_BB_T_c_2022_Dry.shp
# --- Time lapse: 805.2543451786041 seconds ---
# 805 seconds elapsed for processing 72 points in 59th row: RMSE: 0.573863624811, ME: 0.011426440778, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/TwoSeasons_RK_all/BB_T_c_2022_Dry_RK.tif
