# %% [markdown]
# # Cross Validation for IDW & RK Interpolation
# ## Task 2 (continuous & discrete) cross-year for the four seasons
#
# This document includes Python codes that conduct cross validation (CV) for Inverse Distance Weighting (IDW) Interpolation and RK on water quality parameters, including 6 water quality parameters in arcpy environment:
# - Dissolved oxygen (DO_mgl)
# - Salinity (Sal_ppt)
# - Turbidity (Turb_ntu)
# - Temperature (T_c)
# - Secchi (Secc_m)
# - Total Nitrogen (TN_mgl)
#
# The analysis is conducted in the separate water bodies:
# - Guana Tolomato Matanzas (GTM)
# - Estero Bay (EB)
# - Charlotte Harbor (CH)
# - Biscayne Bay (BB)
# - Big Bend Seagrasses (BBS)
#
# **Tasks:**
#
# **Calculate the RMSE and Mean Error (ME) for IDW and RK results using both continuous and discrete data across-year for four seasons**
#
#
# <br>
# <div style="text-align: left;">
#     <img src="../misc/CrossYear.png" style="display: block; margin-left: 0; margin-right: auto; width: 600px;"/>
# </div>
#
#
# **Contents:**
# * [1. Data Preprocess](#reg_preprocessing)
#     * [1.1 Load csv files](#reg_subset)
#     * [1.2 Subsetting data](#reg_preview)
#     * [1.3 Filter the data](#reg_studied)
#     * [1.4 Calculating average values](#reg_average)
#     * [1.5 Convert coordinate system](#reg_coordinate)
# * [2. Prepare for batch interpolation](#reg_batch)
#     * [2.1 Preset abbreviation](#reg_preset)
#     * [2.2 Define the barrier files](#reg_barrier)
#     * [2.3 Define waterbody boundary](#reg_boundary)
#     * [2.4 Load the table of study periods,  parameters, and seasons](#reg_study)
#     * [2.5 Define output folders](#reg_output)
#     * [2.6 Fill NaN RowID with unique ID](#reg_id)
# * [3. Create Shapefiles](#reg_create_shp)
# * [4. Cross Validation for IDW](#reg_cv_idw)
# * [5. RK Interpolation](#reg_rk)

# %% [markdown]
# ## 1. Loading packages

# %%
import pandas as pd
import numpy as np
import arcpy
from arcpy.sa import *
import os
import math
import csv
import random

import importlib
import sys
# path = r'C:/Users/cong1/WQ/IDW/git/misc'
path = r'E:\Projects\SEACAR_WQ_2024\git\misc'

sys.path.insert(0, path)
import idw_rk
importlib.reload(idw_rk)

import pyproj

# define scratch folder to avoid overwritting from parallel threats
arcpy.env.scratchWorkspace = r"E:\Projects\SEACAR_WQ_2024\scratch/IDW_crossyear"

arcpy.env.overwriteOutput = True

# %% [markdown]
# ## 1. Data Preprocessing <a class="anchor" id="reg_preprocessing"></a>
# ### 1.1 Load csv files

# %%
gis_path = r'E:/Projects/SEACAR_WQ_2024/GIS_Data/'

dfDis = pd.read_csv(gis_path + 'OEAT_Discrete_WQ-2024-May-06.csv', low_memory=False)
dfCon = pd.read_csv(gis_path + 'OEAT_Continuous_WQ-2024-Feb-21.csv', low_memory=False)

dfAll = pd.concat([dfDis, dfCon], ignore_index=True)

# %% [markdown]
# ## 1.2 Subsetting Data <a class="anchor" id="reg_subset"></a>
# ### Selecting data from 8 am to 18 pm (daytime)

# %%
# Convert string to datetime
dfCon['SampleDate'] = pd.to_datetime(dfCon['SampleDate'], format='%Y-%m-%d %H:%M:%S.%f')
dfDis['SampleDate'] = pd.to_datetime(dfDis['SampleDate'], format='%Y-%m-%d %H:%M:%S.%f')

# Include date from 8:00 am to 18:00 pm
start_time = '08:00'
end_time = '18:00'

dfCon = dfCon[dfCon['SampleDate'].dt.time.between(pd.to_datetime(start_time).time(), pd.to_datetime(end_time).time())]

dfAll = pd.concat([dfDis, dfCon], ignore_index=True)

dfAll.head()
# Out:
#    RowID  ProgramID ParameterName ParameterUnits ProgramLocationID  \
# 0      1         69  Secchi Depth              m     CKM2017100405
# 1      2         69  Secchi Depth              m     CKM2017080401
# 2      3         69  Secchi Depth              m     CKM2017060703
# 3      4         69  Secchi Depth              m     CKM2017060202
# 4      5         69  Secchi Depth              m     CKM2017110804
#
#   ActivityType SampleDate  Year  Month RelativeDepth  ResultValue  \
# 0        Field 2017-10-06  2017     10           NaN          0.3
# 1        Field 2017-08-08  2017      8       Surface          0.6
# 2        Field 2017-06-19  2017      6       Surface          0.4
# 3        Field 2017-06-06  2017      6       Surface          0.4
# 4        Field 2017-11-14  2017     11       Surface          0.4
#
#    Latitude_DD  Longitude_DD                       ManagedAreaName  AreaID  \
# 0    29.322100    -83.129866  Big Bend Seagrasses Aquatic Preserve       5
# 1    29.145966    -83.072250  Big Bend Seagrasses Aquatic Preserve       5
# 2    29.294516    -83.155316  Big Bend Seagrasses Aquatic Preserve       5
# 3    29.140400    -83.017050  Big Bend Seagrasses Aquatic Preserve       5
# 4    29.269566    -83.107283  Big Bend Seagrasses Aquatic Preserve       5
#
#   SEACAR_QAQCFlagCode            WaterBody WbodyAcronym  Season
# 0                  6Q  Big Bend Seagrasses          BBS    Fall
# 1               6Q/9Q  Big Bend Seagrasses          BBS  Summer
# 2               9Q/6Q  Big Bend Seagrasses          BBS  Summer
# 3               6Q/9Q  Big Bend Seagrasses          BBS  Spring
# 4               9Q/6Q  Big Bend Seagrasses          BBS    Fall

# %% [markdown]
# ### 1.3 Filter the data<a class="anchor" id="reg_studied"></a>

# %%
# Load the table of cross-year seasons definitions
cross_year = pd.read_csv(gis_path + 'season_def/CrossYear.csv', low_memory=False)
cross_year
# Out:
#                   WaterBody  Season  Year1  Year2   Year3
# 0          Charlotte Harbor  Spring   2017   2018     NaN
# 1          Charlotte Harbor  Summer   2016   2017     NaN
# 2          Charlotte Harbor    Fall   2016   2017     NaN
# 3          Charlotte Harbor  Winter   2016   2017  2018.0
# 4       Big Bend Seagrasses  Spring   2021   2022     NaN
# 5       Big Bend Seagrasses  Summer   2020   2021     NaN
# 6       Big Bend Seagrasses    Fall   2020   2021     NaN
# 7       Big Bend Seagrasses  Winter   2020   2021  2022.0
# 8                Estero Bay  Spring   2017   2018     NaN
# 9                Estero Bay  Summer   2016   2017     NaN
# 10               Estero Bay    Fall   2016   2017     NaN
# 11               Estero Bay  Winter   2016   2017  2018.0
# 12  Guana Tolomato Matanzas  Spring   2016   2017     NaN
# 13  Guana Tolomato Matanzas  Summer   2016   2017     NaN
# 14  Guana Tolomato Matanzas    Fall   2015   2016     NaN
# 15  Guana Tolomato Matanzas  Winter   2015   2016  2017.0
# 16             Biscayne Bay  Spring   2022   2023     NaN
# 17             Biscayne Bay  Summer   2021   2022     NaN
# 18             Biscayne Bay    Fall   2021   2022     NaN
# 19             Biscayne Bay  Winter   2021   2022  2023.0

# %%
filtered_dfAllTime = idw_rk.filter_data_crossyear(cross_year, dfAll)
filtered_dfAllTime.head()
# Out:
#    RowID  ProgramID ParameterName ParameterUnits ProgramLocationID  \
# 0    663         69  Secchi Depth              m     CHM2017050903
# 1    692         69  Secchi Depth              m     CHM2017041307
# 2    724         69  Secchi Depth              m     CHM2017031502
# 3    756         69  Secchi Depth              m     CHM2017040211
# 4    768         69  Secchi Depth              m     CHM2017040407
#
#   ActivityType SampleDate  Year  Month RelativeDepth  ResultValue  \
# 0        Field 2017-05-08  2017      5       Surface          0.7
# 1        Field 2017-04-13  2017      4       Surface          2.4
# 2        Field 2017-03-20  2017      3       Surface          0.8
# 3        Field 2017-04-03  2017      4       Surface          0.5
# 4        Field 2017-04-17  2017      4       Surface          1.0
#
#    Latitude_DD  Longitude_DD  \
# 0    26.711183    -82.134966
# 1    26.700716    -82.243783
# 2    26.614233    -82.167866
# 3    26.969566    -82.115250
# 4    26.904766    -82.179700
#
#                                      ManagedAreaName  AreaID  \
# 0  Gasparilla Sound-Charlotte Harbor Aquatic Pres...      18
# 1                 Pine Island Sound Aquatic Preserve      34
# 2                 Pine Island Sound Aquatic Preserve      34
# 3  Gasparilla Sound-Charlotte Harbor Aquatic Pres...      18
# 4  Gasparilla Sound-Charlotte Harbor Aquatic Pres...      18
#
#   SEACAR_QAQCFlagCode         WaterBody WbodyAcronym  Season
# 0               9Q/6Q  Charlotte Harbor           CH  Spring
# 1               6Q/9Q  Charlotte Harbor           CH  Spring
# 2               6Q/9Q  Charlotte Harbor           CH  Spring
# 3               6Q/9Q  Charlotte Harbor           CH  Spring
# 4               6Q/9Q  Charlotte Harbor           CH  Spring

# %%
# Check the filtered results
CH_Winter = filtered_dfAllTime[(filtered_dfAllTime['WaterBody'] == 'Charlotte Harbor') & (filtered_dfAllTime['Season'] == 'Winter')]['Year'].unique()
CH_Winter
# Out:
# array([2016, 2017, 2018], dtype=int64)

# %%
GTM_Fall = filtered_dfAllTime[(filtered_dfAllTime['WaterBody'] == 'Guana Tolomato Matanzas') & (filtered_dfAllTime['Season'] == 'Fall')]['Year'].unique()
GTM_Fall
# Out:
# array([2015, 2016], dtype=int64)

# %% [markdown]
# ### 1.4 Calculating average values at unique observation points<a class="anchor" id="reg_average"></a>

# %%
dfAll_Mean = filtered_dfAllTime.groupby(['WaterBody','ParameterName','ParameterUnits', 'Season','Latitude_DD','Longitude_DD','WbodyAcronym'])["ResultValue"].agg("mean").reset_index()
dfAll = dfAll_Mean

# %% [markdown]
# ### 1.5 Convert coordinate system to EPSG: 3086<a class="anchor" id="reg_coordinate"></a>

# %%
# Define the EPSG codes for source (EPSG:4326) and target (EPSG:3086) coordinate systems
source_epsg = 'EPSG:4326'
target_epsg = 'EPSG:3086'

# Create a PyProj Transformer for the conversion
transformer = pyproj.Transformer.from_crs(source_epsg, target_epsg, always_xy=True)

# Define a function to apply the transformation to each row of the DataFrame
def transform_coordinates(row):
    x, y = transformer.transform(row['Longitude_DD'], row['Latitude_DD'])
    return pd.Series({'x': x, 'y': y})

# Apply the transformation function to the DataFrame and create new columns for the converted coordinates
dfAll[['x', 'y']] = dfAll.apply(transform_coordinates, axis=1)

# %% [markdown]
# #### Save aggregated data to csv file

# %%
dfAll.to_csv(gis_path + 'OEAT_CrossYear_All_WQ-2024-May-2.csv', index=False)

# %% [markdown]
# ## 2. Prepare for batch interpolation<a class="anchor" id="reg_batch"></a>
# ### 2.1 Preset abbreviation for waterbody and parameter name<a class="anchor" id="reg_preset"></a>

# %%
area_shortnames = {
    'Guana Tolomato Matanzas': 'GTM',
    'Estero Bay': 'EB',
    'Charlotte Harbor': 'CH',
    'Biscayne Bay': 'BB',
    'Big Bend Seagrasses':'BBS'
}

param_shortnames = {
    'Salinity': 'Sal_ppt',
    'Total Nitrogen': 'TN_mgl',
    'Dissolved Oxygen': 'DO_mgl',
    'Turbidity':'Turb_ntu',
    'Secchi Depth':'Secc_m',
    'Water Temperature':'T_c'
}

covariates_dict = {
    "GTM":"LDI",
    "EB":"bathymetry+LDI+popden",
    "CH":"bathymetry+LDI+popden+water_flow_wet",
    "BB":"bathymetry+LDI+popden",
    "BBS":"bathymetry+LDI"
}

# %% [markdown]
# ### 2.2 Define the barrier files<a class="anchor" id="reg_barrier"></a>

# %%
barrier_folder = os.path.join(gis_path, 'Barriers')
barrier_folder

barriers = []
for file in os.listdir(barrier_folder):
    if file.endswith(".shp"):
        barriers.append(os.path.join(barrier_folder, file))

for barrier in barriers:
    print(barrier)
# Out:
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\BBS_Barriers.shp
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\BB_Barriers.shp
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\CH_Barriers.shp
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\EB_Barriers.shp
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\GTM_Barriers.shp

# %% [markdown]
# ### 2.3 Define waterbody boundary for spatial extent and masking<a class="anchor" id="reg_boundary"></a>

# %%
waterbody_extent = os.path.join(gis_path, 'OEAT_Waterbody_Boundaries', 'OEAT_Waterbody_Boundary.shp')

unique_waterbodies = []
with arcpy.da.SearchCursor(waterbody_extent, ['WaterbodyA']) as cursor:
    for row in cursor:
        unique_waterbodies.append(row[0])

print("Unique Waterbodies:", unique_waterbodies)
# Out:
# Unique Waterbodies: ['BBS', 'BB', 'CH', 'EB', 'GTM']

# %% [markdown]
# ### 2.4 Load the table of study periods,  parameters, and seasons<a class="anchor" id="reg_study"></a>

# %%
crossyear_all = pd.read_csv(gis_path + 'season_def/CrossYear_all.csv', low_memory=False)
crossyear_all
# Out:
#             WaterBody  Season  Year1  Year2   Year3          Parameter  \
# 0    Charlotte Harbor  Spring   2017   2018     NaN     Total Nitrogen
# 1    Charlotte Harbor  Summer   2016   2017     NaN     Total Nitrogen
# 2    Charlotte Harbor    Fall   2016   2017     NaN     Total Nitrogen
# 3    Charlotte Harbor  Winter   2016   2017  2018.0     Total Nitrogen
# 4    Charlotte Harbor  Spring   2017   2018     NaN           Salinity
# ..                ...     ...    ...    ...     ...                ...
# 115      Biscayne Bay  Winter   2021   2022  2023.0       Secchi Depth
# 116      Biscayne Bay  Spring   2022   2023     NaN  Water Temperature
# 117      Biscayne Bay  Summer   2021   2022     NaN  Water Temperature
# 118      Biscayne Bay    Fall   2021   2022     NaN  Water Temperature
# 119      Biscayne Bay  Winter   2021   2022  2023.0  Water Temperature
#
#      Filename  NumDataPoints  RMSE  ME
# 0         NaN            NaN   NaN NaN
# 1         NaN            NaN   NaN NaN
# 2         NaN            NaN   NaN NaN
# 3         NaN            NaN   NaN NaN
# 4         NaN            NaN   NaN NaN
# ..        ...            ...   ...  ..
# 115       NaN            NaN   NaN NaN
# 116       NaN            NaN   NaN NaN
# 117       NaN            NaN   NaN NaN
# 118       NaN            NaN   NaN NaN
# 119       NaN            NaN   NaN NaN
#
# [120 rows x 10 columns]

# %% [markdown]
# ### 2.5 Define output folders<a class="anchor" id="reg_output"></a>

# %%
shpAll_folder = gis_path + r"shapefiles/CrossYear_shapefiles_All/"
idwAll_folder = gis_path + r"raster_output/CrossYear_IDW_All/"

# Preview dataset
dfAll
# Out:
#                      WaterBody      ParameterName ParameterUnits  Season  \
# 0          Big Bend Seagrasses   Dissolved Oxygen           mg/L    Fall
# 1          Big Bend Seagrasses   Dissolved Oxygen           mg/L    Fall
# 2          Big Bend Seagrasses   Dissolved Oxygen           mg/L    Fall
# 3          Big Bend Seagrasses   Dissolved Oxygen           mg/L    Fall
# 4          Big Bend Seagrasses   Dissolved Oxygen           mg/L    Fall
# ...                        ...                ...            ...     ...
# 17399  Guana Tolomato Matanzas  Water Temperature      Degrees C  Winter
# 17400  Guana Tolomato Matanzas  Water Temperature      Degrees C  Winter
# 17401  Guana Tolomato Matanzas  Water Temperature      Degrees C  Winter
# 17402  Guana Tolomato Matanzas  Water Temperature      Degrees C  Winter
# 17403  Guana Tolomato Matanzas  Water Temperature      Degrees C  Winter
#
#        Latitude_DD  Longitude_DD WbodyAcronym  ResultValue              x  \
# 0        29.008300    -82.825250          BBS     6.873333  514236.421562
# 1        29.125000    -82.841666          BBS     6.976000  512518.355037
# 2        29.149500    -83.079500          BBS     7.225000  489395.665621
# 3        29.161167    -83.047333          BBS     7.110000  492509.553281
# 4        29.162167    -82.810500          BBS     6.350000  515505.865155
# ...            ...           ...          ...          ...            ...
# 17399    30.062183    -81.369175          GTM    19.712500  653318.271561
# 17400    30.083020    -81.342860          GTM    12.800000  655801.884635
# 17401    30.116880    -81.344440          GTM    17.000000  655568.871648
# 17402    30.160736    -81.360278          GTM    12.300000  653940.692803
# 17403    30.160791    -81.360414          GTM    12.300000  653927.485683
#
#                    y
# 0      556316.395208
# 1      569259.880703
# 2      571785.712589
# 3      573104.900093
# 4      573415.656435
# ...              ...
# 17399  675486.194857
# 17400  677852.911263
# 17401  681607.260977
# 17402  686441.390786
# 17403  686447.217640
#
# [17404 rows x 10 columns]

# %% [markdown]
# ### 2.6 Fill NaN RowID with unique ID, IDW function needs unique ID <a class="anchor" id="reg_id"></a>

# %%
idw_rk.fill_nan_rowids(dfAll, 'RowID')

# Keep RowID as integer
dfAll['RowID'] = dfAll['RowID'].astype(int)

# %% [markdown]
# ## 3. Create Shapefiles <a class="anchor" id="reg_create_shp"></a>

# %%
# Merge interested with latitude and longitude columns
crossyear_all_coord = idw_rk.merge_with_lat_long_new(crossyear_all, dfAll, "Season")
crossyear_all_coord
# Out:
#               WaterBody  Season  Year1  Year2   Year3          Parameter  \
# 0      Charlotte Harbor  Spring   2017   2018     NaN     Total Nitrogen
# 1      Charlotte Harbor  Spring   2017   2018     NaN     Total Nitrogen
# 2      Charlotte Harbor  Spring   2017   2018     NaN     Total Nitrogen
# 3      Charlotte Harbor  Spring   2017   2018     NaN     Total Nitrogen
# 4      Charlotte Harbor  Spring   2017   2018     NaN     Total Nitrogen
# ...                 ...     ...    ...    ...     ...                ...
# 17402      Biscayne Bay  Winter   2021   2022  2023.0  Water Temperature
# 17403      Biscayne Bay  Winter   2021   2022  2023.0  Water Temperature
# 17404      Biscayne Bay  Winter   2021   2022  2023.0  Water Temperature
# 17405      Biscayne Bay  Winter   2021   2022  2023.0  Water Temperature
# 17406      Biscayne Bay  Winter   2021   2022  2023.0  Water Temperature
#
#        Filename  NumDataPoints  RMSE  ME              x              y  RowID  \
# 0           NaN            NaN   NaN NaN  591267.325151  272548.455825  11341
# 1           NaN            NaN   NaN NaN  591484.455148  272735.013444  11342
# 2           NaN            NaN   NaN NaN  589465.414295  275500.131085  11343
# 3           NaN            NaN   NaN NaN  589338.150366  275567.884388  11344
# 4           NaN            NaN   NaN NaN  591931.122901  275878.152266  11345
# ...         ...            ...   ...  ..            ...            ...    ...
# 17402       NaN            NaN   NaN NaN  784697.277475  213473.642774   3035
# 17403       NaN            NaN   NaN NaN  785871.933987  216879.419467   3036
# 17404       NaN            NaN   NaN NaN  787466.319703  218700.069505   3037
# 17405       NaN            NaN   NaN NaN  784434.115885  221871.575426   3038
# 17406       NaN            NaN   NaN NaN  784863.997177  223729.378253   3039
#
#        ResultValue
# 0         0.790000
# 1         0.870000
# 2         0.780000
# 3         0.780000
# 4         0.800000
# ...            ...
# 17402    23.895922
# 17403    24.480743
# 17404    24.634917
# 17405    23.509827
# 17406    23.145820
#
# [17407 rows x 14 columns]

# %%
idw_rk.create_shp_season_new(crossyear_all_coord, "Season", shpAll_folder, start_year_included=False)
# Out:
# Number of data rows for BBS, DO_mgl, None, Fall: 42
# Shapefile for BBS, DO_mgl for season Fall has been saved as SHP_BBS_DO_mgl_Fall.shp
# Number of data rows for BBS, Sal_ppt, None, Fall: 34
# Shapefile for BBS, Sal_ppt for season Fall has been saved as SHP_BBS_Sal_ppt_Fall.shp
# Number of data rows for BBS, Secc_m, None, Fall: 33
# Shapefile for BBS, Secc_m for season Fall has been saved as SHP_BBS_Secc_m_Fall.shp
# Number of data rows for BBS, TN_mgl, None, Fall: 37
# Shapefile for BBS, TN_mgl for season Fall has been saved as SHP_BBS_TN_mgl_Fall.shp
# Number of data rows for BBS, Turb_ntu, None, Fall: 39
# Shapefile for BBS, Turb_ntu for season Fall has been saved as SHP_BBS_Turb_ntu_Fall.shp
# Number of data rows for BBS, T_c, None, Fall: 42
# Shapefile for BBS, T_c for season Fall has been saved as SHP_BBS_T_c_Fall.shp
# Number of data rows for BBS, DO_mgl, None, Spring: 55
# Shapefile for BBS, DO_mgl for season Spring has been saved as SHP_BBS_DO_mgl_Spring.shp
# Number of data rows for BBS, Sal_ppt, None, Spring: 40
# Shapefile for BBS, Sal_ppt for season Spring has been saved as SHP_BBS_Sal_ppt_Spring.shp
# Number of data rows for BBS, Secc_m, None, Spring: 45
# Shapefile for BBS, Secc_m for season Spring has been saved as SHP_BBS_Secc_m_Spring.shp
# Number of data rows for BBS, TN_mgl, None, Spring: 45
# Shapefile for BBS, TN_mgl for season Spring has been saved as SHP_BBS_TN_mgl_Spring.shp
# Number of data rows for BBS, Turb_ntu, None, Spring: 47
# Shapefile for BBS, Turb_ntu for season Spring has been saved as SHP_BBS_Turb_ntu_Spring.shp
# Number of data rows for BBS, T_c, None, Spring: 53
# Shapefile for BBS, T_c for season Spring has been saved as SHP_BBS_T_c_Spring.shp
# Number of data rows for BBS, DO_mgl, None, Summer: 54
# Shapefile for BBS, DO_mgl for season Summer has been saved as SHP_BBS_DO_mgl_Summer.shp
# Number of data rows for BBS, Sal_ppt, None, Summer: 44
# Shapefile for BBS, Sal_ppt for season Summer has been saved as SHP_BBS_Sal_ppt_Summer.shp
# Number of data rows for BBS, Secc_m, None, Summer: 40
# Shapefile for BBS, Secc_m for season Summer has been saved as SHP_BBS_Secc_m_Summer.shp
# Number of data rows for BBS, TN_mgl, None, Summer: 39
# Shapefile for BBS, TN_mgl for season Summer has been saved as SHP_BBS_TN_mgl_Summer.shp
# Number of data rows for BBS, Turb_ntu, None, Summer: 43
# Shapefile for BBS, Turb_ntu for season Summer has been saved as SHP_BBS_Turb_ntu_Summer.shp
# Number of data rows for BBS, T_c, None, Summer: 54
# Shapefile for BBS, T_c for season Summer has been saved as SHP_BBS_T_c_Summer.shp
# Number of data rows for BBS, DO_mgl, None, Winter: 150
# Shapefile for BBS, DO_mgl for season Winter has been saved as SHP_BBS_DO_mgl_Winter.shp
# Number of data rows for BBS, Sal_ppt, None, Winter: 144
# Shapefile for BBS, Sal_ppt for season Winter has been saved as SHP_BBS_Sal_ppt_Winter.shp
# Number of data rows for BBS, Secc_m, None, Winter: 38
# Shapefile for BBS, Secc_m for season Winter has been saved as SHP_BBS_Secc_m_Winter.shp
# Number of data rows for BBS, TN_mgl, None, Winter: 43
# Shapefile for BBS, TN_mgl for season Winter has been saved as SHP_BBS_TN_mgl_Winter.shp
# Number of data rows for BBS, Turb_ntu, None, Winter: 45
# Shapefile for BBS, Turb_ntu for season Winter has been saved as SHP_BBS_Turb_ntu_Winter.shp
# Number of data rows for BBS, T_c, None, Winter: 151
# Shapefile for BBS, T_c for season Winter has been saved as SHP_BBS_T_c_Winter.shp
# Number of data rows for BB, DO_mgl, None, Fall: 95
# Shapefile for BB, DO_mgl for season Fall has been saved as SHP_BB_DO_mgl_Fall.shp
# Number of data rows for BB, Sal_ppt, None, Fall: 77
# Shapefile for BB, Sal_ppt for season Fall has been saved as SHP_BB_Sal_ppt_Fall.shp
# No valid data found for area: BB, parameter: Secc_m, year: None, and season: Fall
# Number of data rows for BB, TN_mgl, None, Fall: 85
# Shapefile for BB, TN_mgl for season Fall has been saved as SHP_BB_TN_mgl_Fall.shp
# Number of data rows for BB, Turb_ntu, None, Fall: 77
# Shapefile for BB, Turb_ntu for season Fall has been saved as SHP_BB_Turb_ntu_Fall.shp
# Number of data rows for BB, T_c, None, Fall: 97
# Shapefile for BB, T_c for season Fall has been saved as SHP_BB_T_c_Fall.shp
# Number of data rows for BB, DO_mgl, None, Spring: 77
# Shapefile for BB, DO_mgl for season Spring has been saved as SHP_BB_DO_mgl_Spring.shp
# Number of data rows for BB, Sal_ppt, None, Spring: 71
# Shapefile for BB, Sal_ppt for season Spring has been saved as SHP_BB_Sal_ppt_Spring.shp
# No valid data found for area: BB, parameter: Secc_m, year: None, and season: Spring
# Number of data rows for BB, TN_mgl, None, Spring: 66
# Shapefile for BB, TN_mgl for season Spring has been saved as SHP_BB_TN_mgl_Spring.shp
# Number of data rows for BB, Turb_ntu, None, Spring: 57
# Shapefile for BB, Turb_ntu for season Spring has been saved as SHP_BB_Turb_ntu_Spring.shp
# Number of data rows for BB, T_c, None, Spring: 79
# Shapefile for BB, T_c for season Spring has been saved as SHP_BB_T_c_Spring.shp
# Number of data rows for BB, DO_mgl, None, Summer: 99
# Shapefile for BB, DO_mgl for season Summer has been saved as SHP_BB_DO_mgl_Summer.shp
# Number of data rows for BB, Sal_ppt, None, Summer: 76
# Shapefile for BB, Sal_ppt for season Summer has been saved as SHP_BB_Sal_ppt_Summer.shp
# Number of data rows for BB, Secc_m, None, Summer: 2
# Shapefile for BB, Secc_m for season Summer has been saved as SHP_BB_Secc_m_Summer.shp
# Number of data rows for BB, TN_mgl, None, Summer: 85
# Shapefile for BB, TN_mgl for season Summer has been saved as SHP_BB_TN_mgl_Summer.shp
# Number of data rows for BB, Turb_ntu, None, Summer: 78
# Shapefile for BB, Turb_ntu for season Summer has been saved as SHP_BB_Turb_ntu_Summer.shp
# Number of data rows for BB, T_c, None, Summer: 99
# Shapefile for BB, T_c for season Summer has been saved as SHP_BB_T_c_Summer.shp
# Number of data rows for BB, DO_mgl, None, Winter: 100
# Shapefile for BB, DO_mgl for season Winter has been saved as SHP_BB_DO_mgl_Winter.shp
# Number of data rows for BB, Sal_ppt, None, Winter: 78
# Shapefile for BB, Sal_ppt for season Winter has been saved as SHP_BB_Sal_ppt_Winter.shp
# No valid data found for area: BB, parameter: Secc_m, year: None, and season: Winter
# Number of data rows for BB, TN_mgl, None, Winter: 104
# Shapefile for BB, TN_mgl for season Winter has been saved as SHP_BB_TN_mgl_Winter.shp
# Number of data rows for BB, Turb_ntu, None, Winter: 78
# Shapefile for BB, Turb_ntu for season Winter has been saved as SHP_BB_Turb_ntu_Winter.shp
# Number of data rows for BB, T_c, None, Winter: 102
# Shapefile for BB, T_c for season Winter has been saved as SHP_BB_T_c_Winter.shp
# Number of data rows for CH, DO_mgl, None, Fall: 830
# Shapefile for CH, DO_mgl for season Fall has been saved as SHP_CH_DO_mgl_Fall.shp
# Number of data rows for CH, Sal_ppt, None, Fall: 804
# Shapefile for CH, Sal_ppt for season Fall has been saved as SHP_CH_Sal_ppt_Fall.shp
# Number of data rows for CH, Secc_m, None, Fall: 701
# Shapefile for CH, Secc_m for season Fall has been saved as SHP_CH_Secc_m_Fall.shp
# Number of data rows for CH, TN_mgl, None, Fall: 91
# Shapefile for CH, TN_mgl for season Fall has been saved as SHP_CH_TN_mgl_Fall.shp
# Number of data rows for CH, Turb_ntu, None, Fall: 88
# Shapefile for CH, Turb_ntu for season Fall has been saved as SHP_CH_Turb_ntu_Fall.shp
# Number of data rows for CH, T_c, None, Fall: 865
# Shapefile for CH, T_c for season Fall has been saved as SHP_CH_T_c_Fall.shp
# Number of data rows for CH, DO_mgl, None, Spring: 476
# Shapefile for CH, DO_mgl for season Spring has been saved as SHP_CH_DO_mgl_Spring.shp
# Number of data rows for CH, Sal_ppt, None, Spring: 410
# Shapefile for CH, Sal_ppt for season Spring has been saved as SHP_CH_Sal_ppt_Spring.shp
# Number of data rows for CH, Secc_m, None, Spring: 360
# Shapefile for CH, Secc_m for season Spring has been saved as SHP_CH_Secc_m_Spring.shp
# Number of data rows for CH, TN_mgl, None, Spring: 112
# Shapefile for CH, TN_mgl for season Spring has been saved as SHP_CH_TN_mgl_Spring.shp
# Number of data rows for CH, Turb_ntu, None, Spring: 112
# Shapefile for CH, Turb_ntu for season Spring has been saved as SHP_CH_Turb_ntu_Spring.shp
# Number of data rows for CH, T_c, None, Spring: 482
# Shapefile for CH, T_c for season Spring has been saved as SHP_CH_T_c_Spring.shp
# Number of data rows for CH, DO_mgl, None, Summer: 891
# Shapefile for CH, DO_mgl for season Summer has been saved as SHP_CH_DO_mgl_Summer.shp
# Number of data rows for CH, Sal_ppt, None, Summer: 837
# Shapefile for CH, Sal_ppt for season Summer has been saved as SHP_CH_Sal_ppt_Summer.shp
# Number of data rows for CH, Secc_m, None, Summer: 726
# Shapefile for CH, Secc_m for season Summer has been saved as SHP_CH_Secc_m_Summer.shp
# Number of data rows for CH, TN_mgl, None, Summer: 100
# Shapefile for CH, TN_mgl for season Summer has been saved as SHP_CH_TN_mgl_Summer.shp
# Number of data rows for CH, Turb_ntu, None, Summer: 88
# Shapefile for CH, Turb_ntu for season Summer has been saved as SHP_CH_Turb_ntu_Summer.shp
# Number of data rows for CH, T_c, None, Summer: 901
# Shapefile for CH, T_c for season Summer has been saved as SHP_CH_T_c_Summer.shp
# Number of data rows for CH, DO_mgl, None, Winter: 766
# Shapefile for CH, DO_mgl for season Winter has been saved as SHP_CH_DO_mgl_Winter.shp
# Number of data rows for CH, Sal_ppt, None, Winter: 743
# Shapefile for CH, Sal_ppt for season Winter has been saved as SHP_CH_Sal_ppt_Winter.shp
# Number of data rows for CH, Secc_m, None, Winter: 666
# Shapefile for CH, Secc_m for season Winter has been saved as SHP_CH_Secc_m_Winter.shp
# Number of data rows for CH, TN_mgl, None, Winter: 145
# Shapefile for CH, TN_mgl for season Winter has been saved as SHP_CH_TN_mgl_Winter.shp
# Number of data rows for CH, Turb_ntu, None, Winter: 141
# Shapefile for CH, Turb_ntu for season Winter has been saved as SHP_CH_Turb_ntu_Winter.shp
# Number of data rows for CH, T_c, None, Winter: 833
# Shapefile for CH, T_c for season Winter has been saved as SHP_CH_T_c_Winter.shp
# Number of data rows for EB, DO_mgl, None, Fall: 57
# Shapefile for EB, DO_mgl for season Fall has been saved as SHP_EB_DO_mgl_Fall.shp
# Number of data rows for EB, Sal_ppt, None, Fall: 17
# Shapefile for EB, Sal_ppt for season Fall has been saved as SHP_EB_Sal_ppt_Fall.shp
# Number of data rows for EB, Secc_m, None, Fall: 6
# Shapefile for EB, Secc_m for season Fall has been saved as SHP_EB_Secc_m_Fall.shp
# Number of data rows for EB, TN_mgl, None, Fall: 46
# Shapefile for EB, TN_mgl for season Fall has been saved as SHP_EB_TN_mgl_Fall.shp
# Number of data rows for EB, Turb_ntu, None, Fall: 51
# Shapefile for EB, Turb_ntu for season Fall has been saved as SHP_EB_Turb_ntu_Fall.shp
# Number of data rows for EB, T_c, None, Fall: 59
# Shapefile for EB, T_c for season Fall has been saved as SHP_EB_T_c_Fall.shp
# Number of data rows for EB, DO_mgl, None, Spring: 73
# Shapefile for EB, DO_mgl for season Spring has been saved as SHP_EB_DO_mgl_Spring.shp
# Number of data rows for EB, Sal_ppt, None, Spring: 18
# Shapefile for EB, Sal_ppt for season Spring has been saved as SHP_EB_Sal_ppt_Spring.shp
# Number of data rows for EB, Secc_m, None, Spring: 7
# Shapefile for EB, Secc_m for season Spring has been saved as SHP_EB_Secc_m_Spring.shp
# Number of data rows for EB, TN_mgl, None, Spring: 64
# Shapefile for EB, TN_mgl for season Spring has been saved as SHP_EB_TN_mgl_Spring.shp
# Number of data rows for EB, Turb_ntu, None, Spring: 69
# Shapefile for EB, Turb_ntu for season Spring has been saved as SHP_EB_Turb_ntu_Spring.shp
# Number of data rows for EB, T_c, None, Spring: 75
# Shapefile for EB, T_c for season Spring has been saved as SHP_EB_T_c_Spring.shp
# Number of data rows for EB, DO_mgl, None, Summer: 63
# Shapefile for EB, DO_mgl for season Summer has been saved as SHP_EB_DO_mgl_Summer.shp
# Number of data rows for EB, Sal_ppt, None, Summer: 17
# Shapefile for EB, Sal_ppt for season Summer has been saved as SHP_EB_Sal_ppt_Summer.shp
# Number of data rows for EB, Secc_m, None, Summer: 10
# Shapefile for EB, Secc_m for season Summer has been saved as SHP_EB_Secc_m_Summer.shp
# Number of data rows for EB, TN_mgl, None, Summer: 57
# Shapefile for EB, TN_mgl for season Summer has been saved as SHP_EB_TN_mgl_Summer.shp
# Number of data rows for EB, Turb_ntu, None, Summer: 57
# Shapefile for EB, Turb_ntu for season Summer has been saved as SHP_EB_Turb_ntu_Summer.shp
# Number of data rows for EB, T_c, None, Summer: 64
# Shapefile for EB, T_c for season Summer has been saved as SHP_EB_T_c_Summer.shp
# Number of data rows for EB, DO_mgl, None, Winter: 106
# Shapefile for EB, DO_mgl for season Winter has been saved as SHP_EB_DO_mgl_Winter.shp
# Number of data rows for EB, Sal_ppt, None, Winter: 27
# Shapefile for EB, Sal_ppt for season Winter has been saved as SHP_EB_Sal_ppt_Winter.shp
# Number of data rows for EB, Secc_m, None, Winter: 10
# Shapefile for EB, Secc_m for season Winter has been saved as SHP_EB_Secc_m_Winter.shp
# Number of data rows for EB, TN_mgl, None, Winter: 96
# Shapefile for EB, TN_mgl for season Winter has been saved as SHP_EB_TN_mgl_Winter.shp
# Number of data rows for EB, Turb_ntu, None, Winter: 98
# Shapefile for EB, Turb_ntu for season Winter has been saved as SHP_EB_Turb_ntu_Winter.shp
# Number of data rows for EB, T_c, None, Winter: 108
# Shapefile for EB, T_c for season Winter has been saved as SHP_EB_T_c_Winter.shp
# Number of data rows for GTM, DO_mgl, None, Fall: 81
# Shapefile for GTM, DO_mgl for season Fall has been saved as SHP_GTM_DO_mgl_Fall.shp
# Number of data rows for GTM, Sal_ppt, None, Fall: 81
# Shapefile for GTM, Sal_ppt for season Fall has been saved as SHP_GTM_Sal_ppt_Fall.shp
# Number of data rows for GTM, Secc_m, None, Fall: 6
# Shapefile for GTM, Secc_m for season Fall has been saved as SHP_GTM_Secc_m_Fall.shp
# Number of data rows for GTM, TN_mgl, None, Fall: 10
# Shapefile for GTM, TN_mgl for season Fall has been saved as SHP_GTM_TN_mgl_Fall.shp
# Number of data rows for GTM, Turb_ntu, None, Fall: 14
# Shapefile for GTM, Turb_ntu for season Fall has been saved as SHP_GTM_Turb_ntu_Fall.shp
# Number of data rows for GTM, T_c, None, Fall: 55
# Shapefile for GTM, T_c for season Fall has been saved as SHP_GTM_T_c_Fall.shp
# Number of data rows for GTM, DO_mgl, None, Spring: 76
# Shapefile for GTM, DO_mgl for season Spring has been saved as SHP_GTM_DO_mgl_Spring.shp
# Number of data rows for GTM, Sal_ppt, None, Spring: 75
# Shapefile for GTM, Sal_ppt for season Spring has been saved as SHP_GTM_Sal_ppt_Spring.shp
# Number of data rows for GTM, Secc_m, None, Spring: 2
# Shapefile for GTM, Secc_m for season Spring has been saved as SHP_GTM_Secc_m_Spring.shp
# Number of data rows for GTM, TN_mgl, None, Spring: 6
# Shapefile for GTM, TN_mgl for season Spring has been saved as SHP_GTM_TN_mgl_Spring.shp
# Number of data rows for GTM, Turb_ntu, None, Spring: 10
# Shapefile for GTM, Turb_ntu for season Spring has been saved as SHP_GTM_Turb_ntu_Spring.shp
# Number of data rows for GTM, T_c, None, Spring: 53
# Shapefile for GTM, T_c for season Spring has been saved as SHP_GTM_T_c_Spring.shp
# Number of data rows for GTM, DO_mgl, None, Summer: 87
# Shapefile for GTM, DO_mgl for season Summer has been saved as SHP_GTM_DO_mgl_Summer.shp
# Number of data rows for GTM, Sal_ppt, None, Summer: 90
# Shapefile for GTM, Sal_ppt for season Summer has been saved as SHP_GTM_Sal_ppt_Summer.shp
# Number of data rows for GTM, Secc_m, None, Summer: 9
# Shapefile for GTM, Secc_m for season Summer has been saved as SHP_GTM_Secc_m_Summer.shp
# Number of data rows for GTM, TN_mgl, None, Summer: 19
# Shapefile for GTM, TN_mgl for season Summer has been saved as SHP_GTM_TN_mgl_Summer.shp
# Number of data rows for GTM, Turb_ntu, None, Summer: 9
# Shapefile for GTM, Turb_ntu for season Summer has been saved as SHP_GTM_Turb_ntu_Summer.shp
# Number of data rows for GTM, T_c, None, Summer: 57
# Shapefile for GTM, T_c for season Summer has been saved as SHP_GTM_T_c_Summer.shp
# Number of data rows for GTM, DO_mgl, None, Winter: 54
# Shapefile for GTM, DO_mgl for season Winter has been saved as SHP_GTM_DO_mgl_Winter.shp
# Number of data rows for GTM, Sal_ppt, None, Winter: 56
# Shapefile for GTM, Sal_ppt for season Winter has been saved as SHP_GTM_Sal_ppt_Winter.shp
# Number of data rows for GTM, Secc_m, None, Winter: 7
# Shapefile for GTM, Secc_m for season Winter has been saved as SHP_GTM_Secc_m_Winter.shp
# Number of data rows for GTM, TN_mgl, None, Winter: 19
# Shapefile for GTM, TN_mgl for season Winter has been saved as SHP_GTM_TN_mgl_Winter.shp
# Number of data rows for GTM, Turb_ntu, None, Winter: 10
# Shapefile for GTM, Turb_ntu for season Winter has been saved as SHP_GTM_Turb_ntu_Winter.shp
# Number of data rows for GTM, T_c, None, Winter: 56
# Shapefile for GTM, T_c for season Winter has been saved as SHP_GTM_T_c_Winter.shp

# %% [markdown]
# ## 4. Cross Validation for IDW <a class="anchor" id="reg_cv_idw"></a>

# %%
# Empty the shapefile folder
# idw_rk.delete_all_files(idwAll_folder)

# %%
# Select a section of table to process
seasons_slct = crossyear_all.iloc[:]
seasons_slct.head()

# %%
# If the number of data points is less than 3，skipping calculate IDW
idw_rk.idw_interpolation_new2(seasons_slct, shpAll_folder, idwAll_folder, waterbody_extent, barrier_folder, "Season", include_start_year=False, percentage=10)

# %%
# If the number of data points is less than 3，skipping calculate IDW
# idw_rk.idw_interpolation_new(seasons_slct, shpAll_folder, idwAll_folder, waterbody_extent, barrier_folder, "Season", include_start_year=False)

# %% [markdown]
# ## 5. RK Interpolation<a class="anchor" id="reg_rk"></a>
#
# ### Define output folder

# %%
out_raster_folder = gis_path + r"raster_output/CrossYear_RK_All/"
out_ga_folder     = gis_path + r"ga_output_rk/CrossYear_RK_All/"
diagnostic_folder = gis_path + r"diagnostic_rk/CrossYear_RK_All/"
std_error_folder  = gis_path + r"std_error_pred/CrossYear_RK_All/"

# Clean existing files in folders
# idw_rk.delete_all_files(out_raster_folder)
# idw_rk.delete_all_files(out_ga_folder)
# idw_rk.delete_all_files(diagnostic_folder)
# idw_rk.delete_all_files(std_error_folder)

# %%
rk_crossyear_all = crossyear_all.copy()
rk_crossyear_all['covariates'] = rk_crossyear_all['WaterBody'].apply(lambda x: covariates_dict.get(x, 'default_covariate'))
# rk_crossyear_all.drop('Select_NumDataPoints', axis=1, inplace=True)

rk_csv = gis_path + "rk_crs.csv" 
rk_crossyear_all.to_csv(rk_csv, index=False, encoding='utf-8-sig') 
rk_crossyear_all.head()
# Out:
#           WaterBody  Season  Year1  Year2   Year3       Parameter  Filename  \
# 0  Charlotte Harbor  Spring   2017   2018     NaN  Total Nitrogen       NaN
# 1  Charlotte Harbor  Summer   2016   2017     NaN  Total Nitrogen       NaN
# 2  Charlotte Harbor    Fall   2016   2017     NaN  Total Nitrogen       NaN
# 3  Charlotte Harbor  Winter   2016   2017  2018.0  Total Nitrogen       NaN
# 4  Charlotte Harbor  Spring   2017   2018     NaN        Salinity       NaN
#
#    NumDataPoints  RMSE  ME         covariates
# 0            NaN   NaN NaN  default_covariate
# 1            NaN   NaN NaN  default_covariate
# 2            NaN   NaN NaN  default_covariate
# 3            NaN   NaN NaN  default_covariate
# 4            NaN   NaN NaN  default_covariate

# %% [markdown]
# ### Select rows to process

# %%
crossyear_slct = rk_crossyear_all.iloc[:]
crossyear_slct.drop(crossyear_slct[crossyear_slct['WaterBody'] != 'Big Bend Seagrasses'].index, inplace=True)
crossyear_slct.head()
# Out:
#               WaterBody  Season  Year1  Year2   Year3       Parameter  \
# 24  Big Bend Seagrasses  Spring   2021   2022     NaN  Total Nitrogen
# 25  Big Bend Seagrasses  Summer   2020   2021     NaN  Total Nitrogen
# 26  Big Bend Seagrasses    Fall   2020   2021     NaN  Total Nitrogen
# 27  Big Bend Seagrasses  Winter   2020   2021  2022.0  Total Nitrogen
# 28  Big Bend Seagrasses  Spring   2021   2022     NaN        Salinity
#
#     Filename  NumDataPoints  RMSE  ME         covariates
# 24       NaN            NaN   NaN NaN  default_covariate
# 25       NaN            NaN   NaN NaN  default_covariate
# 26       NaN            NaN   NaN NaN  default_covariate
# 27       NaN            NaN   NaN NaN  default_covariate
# 28       NaN            NaN   NaN NaN  default_covariate

# %%
importlib.reload(idw_rk)

with open(gis_path + "rk_crs.csv", 'w', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    # Determine if year should be included in the output based on a condition
    start_year_included = False

    # Write the header line based on whether the year is included
    cols = list(crossyear_slct.columns)
    csv_writer.writerow(cols)
    
    for i in crossyear_slct.index:
        s_time = time.time()
        process, rmse, me, count, file_loc = idw_rk.rk_interpolation_new(
            method="rk",
            radius=50000,
            folder_path=gis_path,
            waterbody=area_shortnames[crossyear_slct.loc[i]["WaterBody"]],
            parameter=param_shortnames[crossyear_slct.loc[i]["Parameter"]],
            year=crossyear_slct.loc[i]["Start Year"] if start_year_included else None,
            season=crossyear_slct.loc[i]['Season'],
            covariates=covariates_dict[area_shortnames[crossyear_slct.loc[i]["WaterBody"]]],
            out_raster_folder=out_raster_folder,
            out_ga_folder=out_ga_folder,
            std_error_folder=std_error_folder,
            diagnostic_folder=diagnostic_folder,
            shapefile_folder_name="shapefiles/CrossYear_shapefiles_All",
            start_year_included=start_year_included  # Pass the variable to the function
        )
        e_time = time.time()

        # Write data row, conditionally include year based on the setting
        data_row = [
            crossyear_slct.loc[i]["WaterBody"], 
            crossyear_slct.loc[i]['Season'],
            crossyear_slct.loc[i]["Parameter"],
            file_loc, count, rmse, me,
            covariates_dict[area_shortnames[rk_crossyear_all.loc[i]["WaterBody"]]]
        ]

        print(f"{int(e_time - s_time)} seconds elapsed for processing {count} points in {i}th row: RMSE: {rmse}, ME: {me}, file exported to {file_loc}")
        csv_writer.writerow(data_row)
        if i % 10 == 0:
            csvfile.flush()  # Flush the csv file every 10 rows.
# Out:
# Processing file: SHP_BBS_TN_mgl_Spring.shp
# --- Time lapse: 2836.783664226532 seconds ---
# 2837 seconds elapsed for processing 45 points in 24th row: RMSE: 0.163567188855, ME: 0.00223321449112, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_TN_mgl_Spring_RK.tif
# Processing file: SHP_BBS_TN_mgl_Summer.shp
# --- Time lapse: 2309.689077615738 seconds ---
# 2309 seconds elapsed for processing 39 points in 25th row: RMSE: 0.277711893993, ME: -0.00245978525315, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_TN_mgl_Summer_RK.tif
# Processing file: SHP_BBS_TN_mgl_Fall.shp
# --- Time lapse: 2601.6203858852386 seconds ---
# 2601 seconds elapsed for processing 37 points in 26th row: RMSE: 0.157620849573, ME: -0.0180831910025, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_TN_mgl_Fall_RK.tif
# Processing file: SHP_BBS_TN_mgl_Winter.shp
# --- Time lapse: 2870.2168202400208 seconds ---
# 2870 seconds elapsed for processing 43 points in 27th row: RMSE: 0.213565436152, ME: 0.00617747629523, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_TN_mgl_Winter_RK.tif
# Processing file: SHP_BBS_Sal_ppt_Spring.shp
# --- Time lapse: 3087.409536600113 seconds ---
# 3087 seconds elapsed for processing 40 points in 28th row: RMSE: 4.88249155071, ME: -0.313804326454, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_Sal_ppt_Spring_RK.tif
# Processing file: SHP_BBS_Sal_ppt_Summer.shp
# --- Time lapse: 3157.8477964401245 seconds ---
# 3157 seconds elapsed for processing 44 points in 29th row: RMSE: 5.27223394541, ME: -0.388569189893, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_Sal_ppt_Summer_RK.tif
# Processing file: SHP_BBS_Sal_ppt_Fall.shp
# --- Time lapse: 2550.194112300873 seconds ---
# 2550 seconds elapsed for processing 34 points in 30th row: RMSE: 4.40016466997, ME: -0.505503342931, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_Sal_ppt_Fall_RK.tif
# Processing file: SHP_BBS_Sal_ppt_Winter.shp
# --- Time lapse: 8577.962114572525 seconds ---
# 8578 seconds elapsed for processing 144 points in 31th row: RMSE: 3.73713125841, ME: -0.204220407527, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_Sal_ppt_Winter_RK.tif
# Processing file: SHP_BBS_DO_mgl_Spring.shp
# --- Time lapse: 3736.3334727287292 seconds ---
# 3736 seconds elapsed for processing 55 points in 32th row: RMSE: 1.09563883487, ME: -0.0973138650637, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_DO_mgl_Spring_RK.tif
# Processing file: SHP_BBS_DO_mgl_Summer.shp
# --- Time lapse: 3614.4547815322876 seconds ---
# 3614 seconds elapsed for processing 54 points in 33th row: RMSE: 1.01065259732, ME: -0.0650321659701, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_DO_mgl_Summer_RK.tif
# Processing file: SHP_BBS_DO_mgl_Fall.shp
# --- Time lapse: 2889.6937794685364 seconds ---
# 2889 seconds elapsed for processing 42 points in 34th row: RMSE: 0.876670644164, ME: -0.135310668452, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_DO_mgl_Fall_RK.tif
# Processing file: SHP_BBS_DO_mgl_Winter.shp
# --- Time lapse: 10602.851876735687 seconds ---
# 10602 seconds elapsed for processing 150 points in 35th row: RMSE: 0.769076478483, ME: -0.0304139860673, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_DO_mgl_Winter_RK.tif
# Processing file: SHP_BBS_Turb_ntu_Spring.shp
# --- Time lapse: 3275.1546280384064 seconds ---
# 3275 seconds elapsed for processing 47 points in 36th row: RMSE: 2.22816851518, ME: -0.0543443682964, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_Turb_ntu_Spring_RK.tif
# Processing file: SHP_BBS_Turb_ntu_Summer.shp
# --- Time lapse: 3019.3592891693115 seconds ---
# 3019 seconds elapsed for processing 43 points in 37th row: RMSE: 4.47173712765, ME: 0.218706378351, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_Turb_ntu_Summer_RK.tif
# Processing file: SHP_BBS_Turb_ntu_Fall.shp
# --- Time lapse: 2412.129311323166 seconds ---
# 2412 seconds elapsed for processing 39 points in 38th row: RMSE: 2.00373724112, ME: 0.0181958047755, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_Turb_ntu_Fall_RK.tif
# Processing file: SHP_BBS_Turb_ntu_Winter.shp
# --- Time lapse: 3166.293927192688 seconds ---
# 3166 seconds elapsed for processing 45 points in 39th row: RMSE: 2.02315727648, ME: -0.029443086751, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_Turb_ntu_Winter_RK.tif
# Processing file: SHP_BBS_Secc_m_Spring.shp
# --- Time lapse: 2531.076582670212 seconds ---
# 2531 seconds elapsed for processing 45 points in 40th row: RMSE: 1.22613643767, ME: 0.030933112549, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_Secc_m_Spring_RK.tif
# Processing file: SHP_BBS_Secc_m_Summer.shp
# --- Time lapse: 1440.7698593139648 seconds ---
# 1440 seconds elapsed for processing 40 points in 41th row: RMSE: 1.02035771417, ME: -0.00216919372164, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_Secc_m_Summer_RK.tif
# Processing file: SHP_BBS_Secc_m_Fall.shp
# --- Time lapse: 1665.474464893341 seconds ---
# 1665 seconds elapsed for processing 33 points in 42th row: RMSE: 0.748310332713, ME: 0.051864689076, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_Secc_m_Fall_RK.tif
# Processing file: SHP_BBS_Secc_m_Winter.shp
# --- Time lapse: 1719.1913709640503 seconds ---
# 1719 seconds elapsed for processing 38 points in 43th row: RMSE: 1.22746096849, ME: -0.0721972843205, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_Secc_m_Winter_RK.tif
# Processing file: SHP_BBS_T_c_Spring.shp
# --- Time lapse: 3738.2627522945404 seconds ---
# 3738 seconds elapsed for processing 53 points in 44th row: RMSE: 1.92255011405, ME: 0.000502104408273, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_T_c_Spring_RK.tif
# Processing file: SHP_BBS_T_c_Summer.shp
# --- Time lapse: 3418.3106293678284 seconds ---
# 3418 seconds elapsed for processing 54 points in 45th row: RMSE: 0.942318765918, ME: -0.00825230426604, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_T_c_Summer_RK.tif
# Processing file: SHP_BBS_T_c_Fall.shp
# --- Time lapse: 2967.8381428718567 seconds ---
# 2967 seconds elapsed for processing 42 points in 46th row: RMSE: 2.16028635008, ME: -0.107519138327, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_T_c_Fall_RK.tif
# Processing file: SHP_BBS_T_c_Winter.shp
# --- Time lapse: 8820.005196332932 seconds ---
# 8820 seconds elapsed for processing 151 points in 47th row: RMSE: 4.17238403205, ME: 0.476667570165, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/CrossYear_RK_All/BBS_T_c_Winter_RK.tif
