# %% [markdown]
# # Cross Validation for IDW & RK Interpolation
# ## Task 2 (continuous & discrete) for four seasons
#
# This document includes Python codes that conduct cross validation (CV) for Inverse Distance Weighting (IDW) Interpolation and RK on water quality parameters, including 6 water quality parameters in arcpy environment:
# - Dissolved oxygen (DO_mgl)
# - Salinity (Sal_ppt)
# - Turbidity (Turb_ntu)
# - Temperature (T_c)
# - Secchi (Secc_m)
# - Total Nitrogen (TN_mgl)
#
# The analysis is conducted in the separate water bodies:
# - Guana Tolomato Matanzas (GTM)
# - Estero Bay (EB)
# - Charlotte Harbor (CH)
# - Biscayne Bay (BB)
# - Big Bend Seagrasses (BBS)
#
# **Tasks:**
#
# **Calculate the RMSE and Mean Error (ME) for IDW and RK results, incorporating both continuous and discrete data across four seasons (spring, summer, fall, and winter).**
#
#
# <br>
# <div style="text-align: left;">
#     <img src="../misc/FourSeasons.png" style="display: block; margin-left: 0; margin-right: auto; width: 900px;"/>
# </div>
#
#
# **Contents:**
# * [1. Data Preprocess](#reg_preprocessing)
#     * [1.1 Load csv files](#reg_subset)
#     * [1.2 Subsetting data](#reg_preview)
#     * [1.3 Filter the data](#reg_studied)
#     * [1.4 Calculating average values](#reg_average)
#     * [1.5 Convert coordinate system](#reg_coordinate)
# * [2. Prepare for batch interpolation](#reg_batch)
#     * [2.1 Preset abbreviation](#reg_preset)
#     * [2.2 Define the barrier files](#reg_barrier)
#     * [2.3 Define waterbody boundary](#reg_boundary)
#     * [2.4 Load the table of study periods,  parameters, and seasons](#reg_study)
#     * [2.5 Define output folders](#reg_output)
#     * [2.6 Fill NaN RowID with unique ID](#reg_id)
# * [3. Create Shapefiles](#reg_create_shp)
# * [4. Cross Validation for IDW](#reg_cv_idw)
# * [5. RK Interpolation](#reg_rk)

# %% [markdown]
# ## 1. Loading packages

# %%
import pandas as pd
import numpy as np
import arcpy
from arcpy.sa import *
import os
import math
import csv

import importlib
import sys
# path = r'C:/Users/cong1/WQ/IDW/git/misc'
path = r'E:\Projects\SEACAR_WQ_2024\git\misc'

sys.path.insert(0, path)
import idw_rk
importlib.reload(idw_rk)

import pyproj

# define scratch folder to avoid overwritting from parallel threats
arcpy.env.scratchWorkspace = r"E:\Projects\SEACAR_WQ_2024\scratch/IDW_4s"

arcpy.env.overwriteOutput = True

# %% [markdown]
# ## 1. Data Preprocessing <a class="anchor" id="reg_preprocessing"></a>
# ### 1.1 Load csv files

# %%
gis_path = r'E:/Projects/SEACAR_WQ_2024/GIS_Data/'

dfDis = pd.read_csv(gis_path + 'OEAT_Discrete_WQ-2024-May-06.csv', low_memory=False)
dfCon = pd.read_csv(gis_path + 'OEAT_Continuous_WQ-2024-Feb-21.csv', low_memory=False)

dfAll = pd.concat([dfDis, dfCon], ignore_index=True)

# %% [markdown]
# ## 1.2 Subsetting Data <a class="anchor" id="reg_subset"></a>
# ### Selecting data from 8 am to 18 pm (daytime)

# %%
# Convert string to datetime
dfCon['SampleDate'] = pd.to_datetime(dfCon['SampleDate'], format='%Y-%m-%d %H:%M:%S.%f')
dfDis['SampleDate'] = pd.to_datetime(dfDis['SampleDate'], format='%Y-%m-%d %H:%M:%S.%f')

# Include date from 8:00 am to 18:00 pm
start_time = '08:00'
end_time = '18:00'

dfCon = dfCon[dfCon['SampleDate'].dt.time.between(pd.to_datetime(start_time).time(), pd.to_datetime(end_time).time())]

dfAll = pd.concat([dfDis, dfCon], ignore_index=True)

dfAll.head()
# Out:
#    RowID  ProgramID ParameterName ParameterUnits ProgramLocationID  \
# 0      1         69  Secchi Depth              m     CKM2017100405
# 1      2         69  Secchi Depth              m     CKM2017080401
# 2      3         69  Secchi Depth              m     CKM2017060703
# 3      4         69  Secchi Depth              m     CKM2017060202
# 4      5         69  Secchi Depth              m     CKM2017110804
#
#   ActivityType SampleDate  Year  Month RelativeDepth  ResultValue  \
# 0        Field 2017-10-06  2017     10           NaN          0.3
# 1        Field 2017-08-08  2017      8       Surface          0.6
# 2        Field 2017-06-19  2017      6       Surface          0.4
# 3        Field 2017-06-06  2017      6       Surface          0.4
# 4        Field 2017-11-14  2017     11       Surface          0.4
#
#    Latitude_DD  Longitude_DD                       ManagedAreaName  AreaID  \
# 0    29.322100    -83.129866  Big Bend Seagrasses Aquatic Preserve       5
# 1    29.145966    -83.072250  Big Bend Seagrasses Aquatic Preserve       5
# 2    29.294516    -83.155316  Big Bend Seagrasses Aquatic Preserve       5
# 3    29.140400    -83.017050  Big Bend Seagrasses Aquatic Preserve       5
# 4    29.269566    -83.107283  Big Bend Seagrasses Aquatic Preserve       5
#
#   SEACAR_QAQCFlagCode            WaterBody WbodyAcronym  Season
# 0                  6Q  Big Bend Seagrasses          BBS    Fall
# 1               6Q/9Q  Big Bend Seagrasses          BBS  Summer
# 2               9Q/6Q  Big Bend Seagrasses          BBS  Summer
# 3               6Q/9Q  Big Bend Seagrasses          BBS  Spring
# 4               9Q/6Q  Big Bend Seagrasses          BBS    Fall

# %% [markdown]
# ### 1.3 Filter the data<a class="anchor" id="reg_studied"></a>

# %%
# Load the table of four seasons definitions
seasons4 = pd.read_csv(gis_path + 'season_def/4 seasons.csv', low_memory=False)
seasons4
# Out:
#              WaterBody  SeasonNum  Season  Start Year  Start Month   \
# 0     Charlotte Harbor          1  Spring        2017             2
# 1     Charlotte Harbor          2  Summer        2017             6
# 2     Charlotte Harbor          3    Fall        2017             9
# 3     Charlotte Harbor          4  Winter        2017            11
# 4  Big Bend Seagrasses          1  Spring        2021             3
# 5  Big Bend Seagrasses          2  Summer        2021             6
# 6  Big Bend Seagrasses          3    Fall        2021             9
# 7  Big Bend Seagrasses          4  Winter        2021            12
#
#    Start Day  End Year  End Month   End Day  Start Date    End Date
# 0         28      2017           6       11   2/28/2017   6/11/2017
# 1         12      2017           9       11   6/12/2017   9/11/2017
# 2         12      2017          11       28   9/12/2017  11/28/2017
# 3         29      2018           2       27  11/29/2017   2/27/2018
# 4          3      2021           6        7    3/3/2021    6/7/2021
# 5          8      2021           9        7    6/8/2021    9/7/2021
# 6          8      2021          12        2    9/8/2021   12/2/2021
# 7          3      2022           3        2   12/3/2021    3/2/2022

# %%
# Function to filter data based on specified date ranges
selected_dfAllTime = idw_rk.filter_by_date_range(dfAll, seasons4)
selected_dfAllTime.head()
# Out:
#       RowID  ProgramID ParameterName ParameterUnits ProgramLocationID  \
# 1830    458         69  Secchi Depth              m     CHM2017091705
# 2394    599         69  Secchi Depth              m     CHM2017111102
# 2549    638         69  Secchi Depth              m     CHM2017070702
# 2582    646         69  Secchi Depth              m     CHM2017100707
# 2586    647         69  Secchi Depth              m     CHM2017110607
#
#      ActivityType SampleDate  Year  Month RelativeDepth  ...  Latitude_DD  \
# 1830        Field 2017-09-22  2017      9       Surface  ...    26.598450
# 2394        Field 2017-11-01  2017     11       Surface  ...    26.840333
# 2549        Field 2017-07-12  2017      7       Surface  ...    26.793850
# 2582        Field 2017-10-17  2017     10           NaN  ...    26.775283
# 2586        Field 2017-11-14  2017     11           NaN  ...    26.884983
#
#       Longitude_DD                                    ManagedAreaName AreaID  \
# 1830    -82.129733                 Pine Island Sound Aquatic Preserve     34
# 2394    -82.269916  Gasparilla Sound-Charlotte Harbor Aquatic Pres...     18
# 2549    -82.153633                         Cape Haze Aquatic Preserve      9
# 2582    -82.134300  Gasparilla Sound-Charlotte Harbor Aquatic Pres...     18
# 2586    -82.094050  Gasparilla Sound-Charlotte Harbor Aquatic Pres...     18
#
#       SEACAR_QAQCFlagCode         WaterBody WbodyAcronym  Season Start Date  \
# 1830                9Q/6Q  Charlotte Harbor           CH    Fall 2017-09-12
# 2394                6Q/9Q  Charlotte Harbor           CH    Fall 2017-09-12
# 2549                6Q/9Q  Charlotte Harbor           CH  Summer 2017-06-12
# 2582                   6Q  Charlotte Harbor           CH    Fall 2017-09-12
# 2586                   6Q  Charlotte Harbor           CH    Fall 2017-09-12
#
#        End Date
# 1830 2017-11-28
# 2394 2017-11-28
# 2549 2017-09-11
# 2582 2017-11-28
# 2586 2017-11-28
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 1.4 Calculating average values at unique observation points<a class="anchor" id="reg_average"></a>

# %%
dfAll_Mean = selected_dfAllTime.groupby(['WaterBody','ParameterName','ParameterUnits','Season','Latitude_DD','Longitude_DD','WbodyAcronym'])["ResultValue"].agg("mean").reset_index()
dfAll = dfAll_Mean

# %% [markdown]
# ### 1.5 Convert coordinate system to EPSG: 3086<a class="anchor" id="reg_coordinate"></a>

# %%
# Define the EPSG codes for source (EPSG:4326) and target (EPSG:3086) coordinate systems
source_epsg = 'EPSG:4326'
target_epsg = 'EPSG:3086'

# Create a PyProj Transformer for the conversion
transformer = pyproj.Transformer.from_crs(source_epsg, target_epsg, always_xy=True)

# Define a function to apply the transformation to each row of the DataFrame
def transform_coordinates(row):
    x, y = transformer.transform(row['Longitude_DD'], row['Latitude_DD'])
    return pd.Series({'x': x, 'y': y})

# Apply the transformation function to the DataFrame and create new columns for the converted coordinates
dfAll[['x', 'y']] = dfAll.apply(transform_coordinates, axis=1)

# %% [markdown]
# #### Save aggregated data to csv file

# %%
dfAll.to_csv(gis_path + 'OEAT_4Seasons_All_WQ-2024-May-02.csv', index=False)

# %% [markdown]
# ## 2. Prepare for batch interpolation<a class="anchor" id="reg_batch"></a>
# ### 2.1 Preset abbreviation for waterbody and parameter name<a class="anchor" id="reg_preset"></a>

# %%
area_shortnames = {
    'Guana Tolomato Matanzas': 'GTM',
    'Estero Bay': 'EB',
    'Charlotte Harbor': 'CH',
    'Biscayne Bay': 'BB',
    'Big Bend Seagrasses':'BBS'
}

param_shortnames = {
    'Salinity': 'Sal_ppt',
    'Total Nitrogen': 'TN_mgl',
    'Dissolved Oxygen': 'DO_mgl',
    'Turbidity':'Turb_ntu',
    'Secchi Depth':'Secc_m',
    'Water Temperature':'T_c'
}

covariates_dict = {
    "GTM":"LDI",
    "EB":"bathymetry+LDI+popden",
    "CH":"bathymetry+LDI+popden+water_flow_wet",
    "BB":"bathymetry+LDI+popden",
    "BBS":"bathymetry+LDI"
}

# %% [markdown]
# ### 2.2 Define the barrier files<a class="anchor" id="reg_barrier"></a>

# %%
barrier_folder = os.path.join(gis_path, 'Barriers')
barrier_folder

barriers = []
for file in os.listdir(barrier_folder):
    if file.endswith(".shp"):
        barriers.append(os.path.join(barrier_folder, file))

for barrier in barriers:
    print(barrier)
# Out:
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\BBS_Barriers.shp
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\BB_Barriers.shp
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\CH_Barriers.shp
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\EB_Barriers.shp
# E:/Projects/SEACAR_WQ_2024/GIS_Data/Barriers\GTM_Barriers.shp

# %% [markdown]
# ### 2.3 Define waterbody boundary for spatial extent and masking<a class="anchor" id="reg_boundary"></a>

# %%
waterbody_extent = os.path.join(gis_path, 'OEAT_Waterbody_Boundaries', 'OEAT_Waterbody_Boundary.shp')

unique_waterbodies = []
with arcpy.da.SearchCursor(waterbody_extent, ['WaterbodyA']) as cursor:
    for row in cursor:
        unique_waterbodies.append(row[0])

print("Unique Waterbodies:", unique_waterbodies)
# Out:
# Unique Waterbodies: ['BBS', 'BB', 'CH', 'EB', 'GTM']

# %% [markdown]
# ### 2.4 Load the table of study periods,  parameters, and seasons<a class="anchor" id="reg_study"></a>

# %%
seasons_all = pd.read_csv(gis_path + 'season_def/FourSeasons_all.csv', low_memory=False)
seasons_all
# Out:
#               WaterBody  Start Year  End Year  Season          Parameter  \
# 0      Charlotte Harbor        2017      2017  Spring     Total Nitrogen
# 1      Charlotte Harbor        2017      2017  Summer     Total Nitrogen
# 2      Charlotte Harbor        2017      2017    Fall     Total Nitrogen
# 3      Charlotte Harbor        2017      2018  Winter     Total Nitrogen
# 4      Charlotte Harbor        2017      2017  Spring           Salinity
# 5      Charlotte Harbor        2017      2017  Summer           Salinity
# 6      Charlotte Harbor        2017      2017    Fall           Salinity
# 7      Charlotte Harbor        2017      2018  Winter           Salinity
# 8      Charlotte Harbor        2017      2017  Spring   Dissolved Oxygen
# 9      Charlotte Harbor        2017      2017  Summer   Dissolved Oxygen
# 10     Charlotte Harbor        2017      2017    Fall   Dissolved Oxygen
# 11     Charlotte Harbor        2017      2018  Winter   Dissolved Oxygen
# 12     Charlotte Harbor        2017      2017  Spring          Turbidity
# 13     Charlotte Harbor        2017      2017  Summer          Turbidity
# 14     Charlotte Harbor        2017      2017    Fall          Turbidity
# 15     Charlotte Harbor        2017      2018  Winter          Turbidity
# 16     Charlotte Harbor        2017      2017  Spring       Secchi Depth
# 17     Charlotte Harbor        2017      2017  Summer       Secchi Depth
# 18     Charlotte Harbor        2017      2017    Fall       Secchi Depth
# 19     Charlotte Harbor        2017      2018  Winter       Secchi Depth
# 20     Charlotte Harbor        2017      2017  Spring  Water Temperature
# 21     Charlotte Harbor        2017      2017  Summer  Water Temperature
# 22     Charlotte Harbor        2017      2017    Fall  Water Temperature
# 23     Charlotte Harbor        2017      2018  Winter  Water Temperature
# 24  Big Bend Seagrasses        2021      2021  Spring     Total Nitrogen
# 25  Big Bend Seagrasses        2021      2021  Summer     Total Nitrogen
# 26  Big Bend Seagrasses        2021      2021    Fall     Total Nitrogen
# 27  Big Bend Seagrasses        2021      2022  Winter     Total Nitrogen
# 28  Big Bend Seagrasses        2021      2021  Spring           Salinity
# 29  Big Bend Seagrasses        2021      2021  Summer           Salinity
# 30  Big Bend Seagrasses        2021      2021    Fall           Salinity
# 31  Big Bend Seagrasses        2021      2022  Winter           Salinity
# 32  Big Bend Seagrasses        2021      2021  Spring   Dissolved Oxygen
# 33  Big Bend Seagrasses        2021      2021  Summer   Dissolved Oxygen
# 34  Big Bend Seagrasses        2021      2021    Fall   Dissolved Oxygen
# 35  Big Bend Seagrasses        2021      2022  Winter   Dissolved Oxygen
# 36  Big Bend Seagrasses        2021      2021  Spring          Turbidity
# 37  Big Bend Seagrasses        2021      2021  Summer          Turbidity
# 38  Big Bend Seagrasses        2021      2021    Fall          Turbidity
# 39  Big Bend Seagrasses        2021      2022  Winter          Turbidity
# 40  Big Bend Seagrasses        2021      2021  Spring       Secchi Depth
# 41  Big Bend Seagrasses        2021      2021  Summer       Secchi Depth
# 42  Big Bend Seagrasses        2021      2021    Fall       Secchi Depth
# 43  Big Bend Seagrasses        2021      2022  Winter       Secchi Depth
# 44  Big Bend Seagrasses        2021      2021  Spring  Water Temperature
# 45  Big Bend Seagrasses        2021      2021  Summer  Water Temperature
# 46  Big Bend Seagrasses        2021      2021    Fall  Water Temperature
# 47  Big Bend Seagrasses        2021      2022  Winter  Water Temperature
#
#     Filename  NumDataPoints  RMSE  ME
# 0        NaN            NaN   NaN NaN
# 1        NaN            NaN   NaN NaN
# 2        NaN            NaN   NaN NaN
# 3        NaN            NaN   NaN NaN
# 4        NaN            NaN   NaN NaN
# 5        NaN            NaN   NaN NaN
# 6        NaN            NaN   NaN NaN
# 7        NaN            NaN   NaN NaN
# 8        NaN            NaN   NaN NaN
# 9        NaN            NaN   NaN NaN
# 10       NaN            NaN   NaN NaN
# 11       NaN            NaN   NaN NaN
# 12       NaN            NaN   NaN NaN
# 13       NaN            NaN   NaN NaN
# 14       NaN            NaN   NaN NaN
# 15       NaN            NaN   NaN NaN
# 16       NaN            NaN   NaN NaN
# 17       NaN            NaN   NaN NaN
# 18       NaN            NaN   NaN NaN
# 19       NaN            NaN   NaN NaN
# 20       NaN            NaN   NaN NaN
# 21       NaN            NaN   NaN NaN
# 22       NaN            NaN   NaN NaN
# 23       NaN            NaN   NaN NaN
# 24       NaN            NaN   NaN NaN
# 25       NaN            NaN   NaN NaN
# 26       NaN            NaN   NaN NaN
# 27       NaN            NaN   NaN NaN
# 28       NaN            NaN   NaN NaN
# 29       NaN            NaN   NaN NaN
# 30       NaN            NaN   NaN NaN
# 31       NaN            NaN   NaN NaN
# 32       NaN            NaN   NaN NaN
# 33       NaN            NaN   NaN NaN
# 34       NaN            NaN   NaN NaN
# 35       NaN            NaN   NaN NaN
# 36       NaN            NaN   NaN NaN
# 37       NaN            NaN   NaN NaN
# 38       NaN            NaN   NaN NaN
# 39       NaN            NaN   NaN NaN
# 40       NaN            NaN   NaN NaN
# 41       NaN            NaN   NaN NaN
# 42       NaN            NaN   NaN NaN
# 43       NaN            NaN   NaN NaN
# 44       NaN            NaN   NaN NaN
# 45       NaN            NaN   NaN NaN
# 46       NaN            NaN   NaN NaN
# 47       NaN            NaN   NaN NaN

# %% [markdown]
# ### 2.5 Define output folders<a class="anchor" id="reg_output"></a>

# %%
# shpAll_folder = gis_path + r"shapefiles_2seasons" 
# idwAll_folder = gis_path + r"raster_idw_2seasons"

shpAll_folder = gis_path + r"shapefiles/FourSeasons_All" 
idwAll_folder = gis_path + r"raster_output/FourSeasons_IDW_All"

# Preview dataset
dfAll
# Out:
#                 WaterBody      ParameterName ParameterUnits  Season  \
# 0     Big Bend Seagrasses   Dissolved Oxygen           mg/L    Fall
# 1     Big Bend Seagrasses   Dissolved Oxygen           mg/L    Fall
# 2     Big Bend Seagrasses   Dissolved Oxygen           mg/L    Fall
# 3     Big Bend Seagrasses   Dissolved Oxygen           mg/L    Fall
# 4     Big Bend Seagrasses   Dissolved Oxygen           mg/L    Fall
# ...                   ...                ...            ...     ...
# 7141     Charlotte Harbor  Water Temperature      Degrees C  Winter
# 7142     Charlotte Harbor  Water Temperature      Degrees C  Winter
# 7143     Charlotte Harbor  Water Temperature      Degrees C  Winter
# 7144     Charlotte Harbor  Water Temperature      Degrees C  Winter
# 7145     Charlotte Harbor  Water Temperature      Degrees C  Winter
#
#       Latitude_DD  Longitude_DD WbodyAcronym  ResultValue              x  \
# 0       29.008300    -82.825250          BBS     6.873333  514236.629541
# 1       29.125000    -82.841666          BBS     7.180000  512518.602025
# 2       29.149500    -83.079500          BBS     7.225000  489395.986664
# 3       29.161167    -83.047333          BBS     7.110000  492509.872329
# 4       29.162167    -82.810500          BBS     6.675000  515506.111607
# ...           ...           ...          ...          ...            ...
# 7141    26.956683    -82.073533           CH    23.700000  590890.442311
# 7142    26.957016    -82.178716           CH    16.900000  580468.265764
# 7143    26.958566    -82.178250           CH    16.500000  580511.895379
# 7144    26.960560    -82.112840           CH    19.800000  586989.296420
# 7145    26.981300    -82.190566           CH    14.500000  579254.591073
#
#                   y
# 0     556316.261436
# 1     569259.744247
# 2     571785.532572
# 3     573104.729928
# 4     573415.523716
# ...             ...
# 7141  329432.468353
# 7142  329311.057959
# 7143  329483.813243
# 7144  329802.643699
# 7145  331989.675946
#
# [7146 rows x 10 columns]

# %% [markdown]
# ### 2.6 Fill NaN RowID with unique ID, IDW function needs unique ID <a class="anchor" id="reg_id"></a>

# %%
idw_rk.fill_nan_rowids(dfAll, 'RowID')

# Keep RowID as integer
dfAll['RowID'] = dfAll['RowID'].astype(int)
dfAll.head()
# Out:
#              WaterBody     ParameterName ParameterUnits Season  Latitude_DD  \
# 0  Big Bend Seagrasses  Dissolved Oxygen           mg/L   Fall    29.008300
# 1  Big Bend Seagrasses  Dissolved Oxygen           mg/L   Fall    29.125000
# 2  Big Bend Seagrasses  Dissolved Oxygen           mg/L   Fall    29.149500
# 3  Big Bend Seagrasses  Dissolved Oxygen           mg/L   Fall    29.161167
# 4  Big Bend Seagrasses  Dissolved Oxygen           mg/L   Fall    29.162167
#
#    Longitude_DD WbodyAcronym  ResultValue              x              y  RowID
# 0    -82.825250          BBS     6.873333  514236.629541  556316.261436      1
# 1    -82.841666          BBS     7.180000  512518.602025  569259.744247      2
# 2    -83.079500          BBS     7.225000  489395.986664  571785.532572      3
# 3    -83.047333          BBS     7.110000  492509.872329  573104.729928      4
# 4    -82.810500          BBS     6.675000  515506.111607  573415.523716      5

# %% [markdown]
# ## 3. Create Shapefiles <a class="anchor" id="reg_create_shp"></a>

# %%
# Merge interested with latitude and longitude columns
seasons_all_coord = idw_rk.merge_with_lat_long_new(seasons_all, dfAll, "Season")
seasons_all_coord
# Out:
#                 WaterBody  Start Year  End Year  Season          Parameter  \
# 0        Charlotte Harbor        2017      2017  Spring     Total Nitrogen
# 1        Charlotte Harbor        2017      2017  Spring     Total Nitrogen
# 2        Charlotte Harbor        2017      2017  Spring     Total Nitrogen
# 3        Charlotte Harbor        2017      2017  Spring     Total Nitrogen
# 4        Charlotte Harbor        2017      2017  Spring     Total Nitrogen
# ...                   ...         ...       ...     ...                ...
# 7141  Big Bend Seagrasses        2021      2022  Winter  Water Temperature
# 7142  Big Bend Seagrasses        2021      2022  Winter  Water Temperature
# 7143  Big Bend Seagrasses        2021      2022  Winter  Water Temperature
# 7144  Big Bend Seagrasses        2021      2022  Winter  Water Temperature
# 7145  Big Bend Seagrasses        2021      2022  Winter  Water Temperature
#
#       Filename  NumDataPoints  RMSE  ME              x              y  RowID  \
# 0          NaN            NaN   NaN NaN  591484.839075  272735.047067   5267
# 1          NaN            NaN   NaN NaN  589465.802362  275500.164081   5268
# 2          NaN            NaN   NaN NaN  582451.183526  278043.792487   5269
# 3          NaN            NaN   NaN NaN  584823.590495  278587.753297   5270
# 4          NaN            NaN   NaN NaN  585413.995613  280195.521648   5271
# ...        ...            ...   ...  ..            ...            ...    ...
# 7141       NaN            NaN   NaN NaN  371688.784902  691953.259259   1194
# 7142       NaN            NaN   NaN NaN  371015.252225  692080.963200   1195
# 7143       NaN            NaN   NaN NaN  401894.709931  699334.789795   1196
# 7144       NaN            NaN   NaN NaN  401457.471573  702258.561096   1197
# 7145       NaN            NaN   NaN NaN  418526.095780  706988.568308   1198
#
#       ResultValue
# 0           0.870
# 1           0.780
# 2           0.594
# 3           0.690
# 4           0.780
# ...           ...
# 7141       21.100
# 7142       20.700
# 7143       19.200
# 7144       20.100
# 7145       17.200
#
# [7146 rows x 13 columns]

# %%
idw_rk.create_shp_season_new(seasons_all_coord, "Season", shpAll_folder, start_year_included=True)
# Out:
# Number of data rows for BBS, DO_mgl, 2021, Fall: 39
# Shapefile for BBS, DO_mgl for 2021 and season Fall has been saved as SHP_BBS_DO_mgl_2021_Fall.shp
# Number of data rows for BBS, Sal_ppt, 2021, Fall: 30
# Shapefile for BBS, Sal_ppt for 2021 and season Fall has been saved as SHP_BBS_Sal_ppt_2021_Fall.shp
# Number of data rows for BBS, Secc_m, 2021, Fall: 31
# Shapefile for BBS, Secc_m for 2021 and season Fall has been saved as SHP_BBS_Secc_m_2021_Fall.shp
# Number of data rows for BBS, TN_mgl, 2021, Fall: 34
# Shapefile for BBS, TN_mgl for 2021 and season Fall has been saved as SHP_BBS_TN_mgl_2021_Fall.shp
# Number of data rows for BBS, Turb_ntu, 2021, Fall: 35
# Shapefile for BBS, Turb_ntu for 2021 and season Fall has been saved as SHP_BBS_Turb_ntu_2021_Fall.shp
# Number of data rows for BBS, T_c, 2021, Fall: 39
# Shapefile for BBS, T_c for 2021 and season Fall has been saved as SHP_BBS_T_c_2021_Fall.shp
# Number of data rows for BBS, DO_mgl, 2021, Spring: 48
# Shapefile for BBS, DO_mgl for 2021 and season Spring has been saved as SHP_BBS_DO_mgl_2021_Spring.shp
# Number of data rows for BBS, Sal_ppt, 2021, Spring: 37
# Shapefile for BBS, Sal_ppt for 2021 and season Spring has been saved as SHP_BBS_Sal_ppt_2021_Spring.shp
# Number of data rows for BBS, Secc_m, 2021, Spring: 41
# Shapefile for BBS, Secc_m for 2021 and season Spring has been saved as SHP_BBS_Secc_m_2021_Spring.shp
# Number of data rows for BBS, TN_mgl, 2021, Spring: 37
# Shapefile for BBS, TN_mgl for 2021 and season Spring has been saved as SHP_BBS_TN_mgl_2021_Spring.shp
# Number of data rows for BBS, Turb_ntu, 2021, Spring: 40
# Shapefile for BBS, Turb_ntu for 2021 and season Spring has been saved as SHP_BBS_Turb_ntu_2021_Spring.shp
# Number of data rows for BBS, T_c, 2021, Spring: 48
# Shapefile for BBS, T_c for 2021 and season Spring has been saved as SHP_BBS_T_c_2021_Spring.shp
# Number of data rows for BBS, DO_mgl, 2021, Summer: 47
# Shapefile for BBS, DO_mgl for 2021 and season Summer has been saved as SHP_BBS_DO_mgl_2021_Summer.shp
# Number of data rows for BBS, Sal_ppt, 2021, Summer: 39
# Shapefile for BBS, Sal_ppt for 2021 and season Summer has been saved as SHP_BBS_Sal_ppt_2021_Summer.shp
# Number of data rows for BBS, Secc_m, 2021, Summer: 36
# Shapefile for BBS, Secc_m for 2021 and season Summer has been saved as SHP_BBS_Secc_m_2021_Summer.shp
# Number of data rows for BBS, TN_mgl, 2021, Summer: 33
# Shapefile for BBS, TN_mgl for 2021 and season Summer has been saved as SHP_BBS_TN_mgl_2021_Summer.shp
# Number of data rows for BBS, Turb_ntu, 2021, Summer: 37
# Shapefile for BBS, Turb_ntu for 2021 and season Summer has been saved as SHP_BBS_Turb_ntu_2021_Summer.shp
# Number of data rows for BBS, T_c, 2021, Summer: 47
# Shapefile for BBS, T_c for 2021 and season Summer has been saved as SHP_BBS_T_c_2021_Summer.shp
# Number of data rows for BBS, DO_mgl, 2021, Winter: 133
# Shapefile for BBS, DO_mgl for 2021 and season Winter has been saved as SHP_BBS_DO_mgl_2021_Winter.shp
# Number of data rows for BBS, Sal_ppt, 2021, Winter: 132
# Shapefile for BBS, Sal_ppt for 2021 and season Winter has been saved as SHP_BBS_Sal_ppt_2021_Winter.shp
# Number of data rows for BBS, Secc_m, 2021, Winter: 24
# Shapefile for BBS, Secc_m for 2021 and season Winter has been saved as SHP_BBS_Secc_m_2021_Winter.shp
# Number of data rows for BBS, TN_mgl, 2021, Winter: 33
# Shapefile for BBS, TN_mgl for 2021 and season Winter has been saved as SHP_BBS_TN_mgl_2021_Winter.shp
# Number of data rows for BBS, Turb_ntu, 2021, Winter: 39
# Shapefile for BBS, Turb_ntu for 2021 and season Winter has been saved as SHP_BBS_Turb_ntu_2021_Winter.shp
# Number of data rows for BBS, T_c, 2021, Winter: 139
# Shapefile for BBS, T_c for 2021 and season Winter has been saved as SHP_BBS_T_c_2021_Winter.shp
# Number of data rows for CH, DO_mgl, 2017, Fall: 445
# Shapefile for CH, DO_mgl for 2017 and season Fall has been saved as SHP_CH_DO_mgl_2017_Fall.shp
# Number of data rows for CH, Sal_ppt, 2017, Fall: 411
# Shapefile for CH, Sal_ppt for 2017 and season Fall has been saved as SHP_CH_Sal_ppt_2017_Fall.shp
# Number of data rows for CH, Secc_m, 2017, Fall: 319
# Shapefile for CH, Secc_m for 2017 and season Fall has been saved as SHP_CH_Secc_m_2017_Fall.shp
# Number of data rows for CH, TN_mgl, 2017, Fall: 51
# Shapefile for CH, TN_mgl for 2017 and season Fall has been saved as SHP_CH_TN_mgl_2017_Fall.shp
# Number of data rows for CH, Turb_ntu, 2017, Fall: 51
# Shapefile for CH, Turb_ntu for 2017 and season Fall has been saved as SHP_CH_Turb_ntu_2017_Fall.shp
# Number of data rows for CH, T_c, 2017, Fall: 445
# Shapefile for CH, T_c for 2017 and season Fall has been saved as SHP_CH_T_c_2017_Fall.shp
# Number of data rows for CH, DO_mgl, 2017, Spring: 434
# Shapefile for CH, DO_mgl for 2017 and season Spring has been saved as SHP_CH_DO_mgl_2017_Spring.shp
# Number of data rows for CH, Sal_ppt, 2017, Spring: 402
# Shapefile for CH, Sal_ppt for 2017 and season Spring has been saved as SHP_CH_Sal_ppt_2017_Spring.shp
# Number of data rows for CH, Secc_m, 2017, Spring: 351
# Shapefile for CH, Secc_m for 2017 and season Spring has been saved as SHP_CH_Secc_m_2017_Spring.shp
# Number of data rows for CH, TN_mgl, 2017, Spring: 57
# Shapefile for CH, TN_mgl for 2017 and season Spring has been saved as SHP_CH_TN_mgl_2017_Spring.shp
# Number of data rows for CH, Turb_ntu, 2017, Spring: 57
# Shapefile for CH, Turb_ntu for 2017 and season Spring has been saved as SHP_CH_Turb_ntu_2017_Spring.shp
# Number of data rows for CH, T_c, 2017, Spring: 440
# Shapefile for CH, T_c for 2017 and season Spring has been saved as SHP_CH_T_c_2017_Spring.shp
# Number of data rows for CH, DO_mgl, 2017, Summer: 461
# Shapefile for CH, DO_mgl for 2017 and season Summer has been saved as SHP_CH_DO_mgl_2017_Summer.shp
# Number of data rows for CH, Sal_ppt, 2017, Summer: 434
# Shapefile for CH, Sal_ppt for 2017 and season Summer has been saved as SHP_CH_Sal_ppt_2017_Summer.shp
# Number of data rows for CH, Secc_m, 2017, Summer: 339
# Shapefile for CH, Secc_m for 2017 and season Summer has been saved as SHP_CH_Secc_m_2017_Summer.shp
# Number of data rows for CH, TN_mgl, 2017, Summer: 42
# Shapefile for CH, TN_mgl for 2017 and season Summer has been saved as SHP_CH_TN_mgl_2017_Summer.shp
# Number of data rows for CH, Turb_ntu, 2017, Summer: 42
# Shapefile for CH, Turb_ntu for 2017 and season Summer has been saved as SHP_CH_Turb_ntu_2017_Summer.shp
# Number of data rows for CH, T_c, 2017, Summer: 461
# Shapefile for CH, T_c for 2017 and season Summer has been saved as SHP_CH_T_c_2017_Summer.shp
# Number of data rows for CH, DO_mgl, 2017, Winter: 170
# Shapefile for CH, DO_mgl for 2017 and season Winter has been saved as SHP_CH_DO_mgl_2017_Winter.shp
# Number of data rows for CH, Sal_ppt, 2017, Winter: 143
# Shapefile for CH, Sal_ppt for 2017 and season Winter has been saved as SHP_CH_Sal_ppt_2017_Winter.shp
# Number of data rows for CH, Secc_m, 2017, Winter: 108
# Shapefile for CH, Secc_m for 2017 and season Winter has been saved as SHP_CH_Secc_m_2017_Winter.shp
# Number of data rows for CH, TN_mgl, 2017, Winter: 56
# Shapefile for CH, TN_mgl for 2017 and season Winter has been saved as SHP_CH_TN_mgl_2017_Winter.shp
# Number of data rows for CH, Turb_ntu, 2017, Winter: 56
# Shapefile for CH, Turb_ntu for 2017 and season Winter has been saved as SHP_CH_Turb_ntu_2017_Winter.shp
# Number of data rows for CH, T_c, 2017, Winter: 173
# Shapefile for CH, T_c for 2017 and season Winter has been saved as SHP_CH_T_c_2017_Winter.shp

# %% [markdown]
# ## 4. Cross Validation for IDW <a class="anchor" id="reg_cv_idw"></a>

# %%
# Empty the shapefile folder
# idw_rk.delete_all_files(idwAll_folder)

# %%
# Select a section of table to process
seasons_slct = seasons_all.iloc[:]
# seasons_slct.drop(seasons_slct[seasons_slct['WaterBody'] == 'Charlotte Harbor'].index, inplace=True)
# seasons_slct = seasons_slct.reset_index()

# %%
seasons_slct
# Out:
#               WaterBody  Start Year  End Year  Season          Parameter  \
# 0      Charlotte Harbor        2017      2017  Spring     Total Nitrogen
# 1      Charlotte Harbor        2017      2017  Summer     Total Nitrogen
# 2      Charlotte Harbor        2017      2017    Fall     Total Nitrogen
# 3      Charlotte Harbor        2017      2018  Winter     Total Nitrogen
# 4      Charlotte Harbor        2017      2017  Spring           Salinity
# 5      Charlotte Harbor        2017      2017  Summer           Salinity
# 6      Charlotte Harbor        2017      2017    Fall           Salinity
# 7      Charlotte Harbor        2017      2018  Winter           Salinity
# 8      Charlotte Harbor        2017      2017  Spring   Dissolved Oxygen
# 9      Charlotte Harbor        2017      2017  Summer   Dissolved Oxygen
# 10     Charlotte Harbor        2017      2017    Fall   Dissolved Oxygen
# 11     Charlotte Harbor        2017      2018  Winter   Dissolved Oxygen
# 12     Charlotte Harbor        2017      2017  Spring          Turbidity
# 13     Charlotte Harbor        2017      2017  Summer          Turbidity
# 14     Charlotte Harbor        2017      2017    Fall          Turbidity
# 15     Charlotte Harbor        2017      2018  Winter          Turbidity
# 16     Charlotte Harbor        2017      2017  Spring       Secchi Depth
# 17     Charlotte Harbor        2017      2017  Summer       Secchi Depth
# 18     Charlotte Harbor        2017      2017    Fall       Secchi Depth
# 19     Charlotte Harbor        2017      2018  Winter       Secchi Depth
# 20     Charlotte Harbor        2017      2017  Spring  Water Temperature
# 21     Charlotte Harbor        2017      2017  Summer  Water Temperature
# 22     Charlotte Harbor        2017      2017    Fall  Water Temperature
# 23     Charlotte Harbor        2017      2018  Winter  Water Temperature
# 24  Big Bend Seagrasses        2021      2021  Spring     Total Nitrogen
# 25  Big Bend Seagrasses        2021      2021  Summer     Total Nitrogen
# 26  Big Bend Seagrasses        2021      2021    Fall     Total Nitrogen
# 27  Big Bend Seagrasses        2021      2022  Winter     Total Nitrogen
# 28  Big Bend Seagrasses        2021      2021  Spring           Salinity
# 29  Big Bend Seagrasses        2021      2021  Summer           Salinity
# 30  Big Bend Seagrasses        2021      2021    Fall           Salinity
# 31  Big Bend Seagrasses        2021      2022  Winter           Salinity
# 32  Big Bend Seagrasses        2021      2021  Spring   Dissolved Oxygen
# 33  Big Bend Seagrasses        2021      2021  Summer   Dissolved Oxygen
# 34  Big Bend Seagrasses        2021      2021    Fall   Dissolved Oxygen
# 35  Big Bend Seagrasses        2021      2022  Winter   Dissolved Oxygen
# 36  Big Bend Seagrasses        2021      2021  Spring          Turbidity
# 37  Big Bend Seagrasses        2021      2021  Summer          Turbidity
# 38  Big Bend Seagrasses        2021      2021    Fall          Turbidity
# 39  Big Bend Seagrasses        2021      2022  Winter          Turbidity
# 40  Big Bend Seagrasses        2021      2021  Spring       Secchi Depth
# 41  Big Bend Seagrasses        2021      2021  Summer       Secchi Depth
# 42  Big Bend Seagrasses        2021      2021    Fall       Secchi Depth
# 43  Big Bend Seagrasses        2021      2022  Winter       Secchi Depth
# 44  Big Bend Seagrasses        2021      2021  Spring  Water Temperature
# 45  Big Bend Seagrasses        2021      2021  Summer  Water Temperature
# 46  Big Bend Seagrasses        2021      2021    Fall  Water Temperature
# 47  Big Bend Seagrasses        2021      2022  Winter  Water Temperature
#
#     Filename  NumDataPoints  RMSE  ME
# 0        NaN            NaN   NaN NaN
# 1        NaN            NaN   NaN NaN
# 2        NaN            NaN   NaN NaN
# 3        NaN            NaN   NaN NaN
# 4        NaN            NaN   NaN NaN
# 5        NaN            NaN   NaN NaN
# 6        NaN            NaN   NaN NaN
# 7        NaN            NaN   NaN NaN
# 8        NaN            NaN   NaN NaN
# 9        NaN            NaN   NaN NaN
# 10       NaN            NaN   NaN NaN
# 11       NaN            NaN   NaN NaN
# 12       NaN            NaN   NaN NaN
# 13       NaN            NaN   NaN NaN
# 14       NaN            NaN   NaN NaN
# 15       NaN            NaN   NaN NaN
# 16       NaN            NaN   NaN NaN
# 17       NaN            NaN   NaN NaN
# 18       NaN            NaN   NaN NaN
# 19       NaN            NaN   NaN NaN
# 20       NaN            NaN   NaN NaN
# 21       NaN            NaN   NaN NaN
# 22       NaN            NaN   NaN NaN
# 23       NaN            NaN   NaN NaN
# 24       NaN            NaN   NaN NaN
# 25       NaN            NaN   NaN NaN
# 26       NaN            NaN   NaN NaN
# 27       NaN            NaN   NaN NaN
# 28       NaN            NaN   NaN NaN
# 29       NaN            NaN   NaN NaN
# 30       NaN            NaN   NaN NaN
# 31       NaN            NaN   NaN NaN
# 32       NaN            NaN   NaN NaN
# 33       NaN            NaN   NaN NaN
# 34       NaN            NaN   NaN NaN
# 35       NaN            NaN   NaN NaN
# 36       NaN            NaN   NaN NaN
# 37       NaN            NaN   NaN NaN
# 38       NaN            NaN   NaN NaN
# 39       NaN            NaN   NaN NaN
# 40       NaN            NaN   NaN NaN
# 41       NaN            NaN   NaN NaN
# 42       NaN            NaN   NaN NaN
# 43       NaN            NaN   NaN NaN
# 44       NaN            NaN   NaN NaN
# 45       NaN            NaN   NaN NaN
# 46       NaN            NaN   NaN NaN
# 47       NaN            NaN   NaN NaN

# %%
# If the number of data points is less than 3，skipping calculate IDW
idw_rk.idw_interpolation_new(seasons_slct, shpAll_folder, idwAll_folder, waterbody_extent, barrier_folder, "Season", include_start_year=True)
# Out:
# Processing file: SHP_BBS_TN_mgl_2021_Spring.shp
# File SHP_BBS_TN_mgl_2021_Spring.shp has completed 37 cross-validation iterations.
# Processing file: SHP_BBS_TN_mgl_2021_Summer.shp
# File SHP_BBS_TN_mgl_2021_Summer.shp has completed 33 cross-validation iterations.
# Processing file: SHP_BBS_TN_mgl_2021_Fall.shp
# File SHP_BBS_TN_mgl_2021_Fall.shp has completed 34 cross-validation iterations.
# Processing file: SHP_BBS_TN_mgl_2021_Winter.shp
# File SHP_BBS_TN_mgl_2021_Winter.shp has completed 33 cross-validation iterations.
# Processing file: SHP_BBS_Sal_ppt_2021_Spring.shp
# File SHP_BBS_Sal_ppt_2021_Spring.shp has completed 37 cross-validation iterations.
# Processing file: SHP_BBS_Sal_ppt_2021_Summer.shp
# File SHP_BBS_Sal_ppt_2021_Summer.shp has completed 39 cross-validation iterations.
# Processing file: SHP_BBS_Sal_ppt_2021_Fall.shp
# File SHP_BBS_Sal_ppt_2021_Fall.shp has completed 30 cross-validation iterations.
# Processing file: SHP_BBS_Sal_ppt_2021_Winter.shp
# File SHP_BBS_Sal_ppt_2021_Winter.shp has completed 132 cross-validation iterations.
# Processing file: SHP_BBS_DO_mgl_2021_Spring.shp
# File SHP_BBS_DO_mgl_2021_Spring.shp has completed 48 cross-validation iterations.
# Processing file: SHP_BBS_DO_mgl_2021_Summer.shp
# File SHP_BBS_DO_mgl_2021_Summer.shp has completed 47 cross-validation iterations.
# Processing file: SHP_BBS_DO_mgl_2021_Fall.shp
# File SHP_BBS_DO_mgl_2021_Fall.shp has completed 39 cross-validation iterations.
# Processing file: SHP_BBS_DO_mgl_2021_Winter.shp
# File SHP_BBS_DO_mgl_2021_Winter.shp has completed 133 cross-validation iterations.
# Processing file: SHP_BBS_Turb_ntu_2021_Spring.shp
# File SHP_BBS_Turb_ntu_2021_Spring.shp has completed 40 cross-validation iterations.
# Processing file: SHP_BBS_Turb_ntu_2021_Summer.shp
# File SHP_BBS_Turb_ntu_2021_Summer.shp has completed 37 cross-validation iterations.
# Processing file: SHP_BBS_Turb_ntu_2021_Fall.shp
# File SHP_BBS_Turb_ntu_2021_Fall.shp has completed 35 cross-validation iterations.
# Processing file: SHP_BBS_Turb_ntu_2021_Winter.shp
# File SHP_BBS_Turb_ntu_2021_Winter.shp has completed 39 cross-validation iterations.
# Processing file: SHP_BBS_Secc_m_2021_Spring.shp
# File SHP_BBS_Secc_m_2021_Spring.shp has completed 41 cross-validation iterations.
# Processing file: SHP_BBS_Secc_m_2021_Summer.shp
# File SHP_BBS_Secc_m_2021_Summer.shp has completed 36 cross-validation iterations.
# Processing file: SHP_BBS_Secc_m_2021_Fall.shp
# File SHP_BBS_Secc_m_2021_Fall.shp has completed 31 cross-validation iterations.
# Processing file: SHP_BBS_Secc_m_2021_Winter.shp
# File SHP_BBS_Secc_m_2021_Winter.shp has completed 24 cross-validation iterations.
# Processing file: SHP_BBS_T_c_2021_Spring.shp
# File SHP_BBS_T_c_2021_Spring.shp has completed 48 cross-validation iterations.
# Processing file: SHP_BBS_T_c_2021_Summer.shp
# File SHP_BBS_T_c_2021_Summer.shp has completed 47 cross-validation iterations.
# Processing file: SHP_BBS_T_c_2021_Fall.shp
# File SHP_BBS_T_c_2021_Fall.shp has completed 39 cross-validation iterations.
# Processing file: SHP_BBS_T_c_2021_Winter.shp
# File SHP_BBS_T_c_2021_Winter.shp has completed 139 cross-validation iterations.
# Calculated RMSE: 3.485288488118486, ME: 0.6705474056920635 for file: SHP_BBS_T_c_2021_Winter.shp. Time used: 48417.54601120949

# %% [markdown]
# ## 5. RK Interpolation<a class="anchor" id="reg_rk"></a>
#
# ### Define output folder

# %%
# out_raster_folder = gis_path + r"rk_folder/FourSeasons_RK_all/"
# out_ga_folder     = gis_path + r"rk_folder/ga_output_rk_4s/"
# diagnostic_folder = gis_path + r"rk_folder/diagnostic_rk_4s/"
# std_error_folder  = gis_path + r"rk_folder/std_error_pred_4s/std_error_rk_4s/"

out_raster_folder = gis_path + r"raster_output/FourSeasons_RK_all/"
out_ga_folder     = gis_path + r"ga_output_rk/"
diagnostic_folder = gis_path + r"diagnostic_rk"
std_error_folder  = gis_path + r"std_error_pred/std_error_rk_4s/"

# Clean existing files in folders
idw_rk.delete_all_files(out_raster_folder)
idw_rk.delete_all_files(out_ga_folder)
idw_rk.delete_all_files(diagnostic_folder)
idw_rk.delete_all_files(std_error_folder)

# %%
seasons_all['covariates'] = seasons_all['WaterBody'].apply(lambda x: covariates_dict.get(x, 'default_covariate'))

rk_csv = gis_path + "rk_4s.csv" 
seasons_all.to_csv(rk_csv, index=False, encoding='utf-8-sig') 
seasons_all.head()
# Out:
#           WaterBody  Start Year  End Year  Season       Parameter  Filename  \
# 0  Charlotte Harbor        2017      2017  Spring  Total Nitrogen       NaN
# 1  Charlotte Harbor        2017      2017  Summer  Total Nitrogen       NaN
# 2  Charlotte Harbor        2017      2017    Fall  Total Nitrogen       NaN
# 3  Charlotte Harbor        2017      2018  Winter  Total Nitrogen       NaN
# 4  Charlotte Harbor        2017      2017  Spring        Salinity       NaN
#
#    NumDataPoints  RMSE  ME         covariates
# 0            NaN   NaN NaN  default_covariate
# 1            NaN   NaN NaN  default_covariate
# 2            NaN   NaN NaN  default_covariate
# 3            NaN   NaN NaN  default_covariate
# 4            NaN   NaN NaN  default_covariate

# %%
with open(gis_path + "rk_4s.csv", 'w', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    # Determine if year should be included in the output based on a condition
    start_year_included = True

    # Write the header line based on whether the year is included
    cols = list(seasons_all.columns)
    if not start_year_included:
        cols.remove('Start Year')
        cols.remove('End Year')
    csv_writer.writerow(cols)
    
    for i in seasons_all.index:
        s_time = time.time()
        process, rmse, me, count, file_loc = idw_rk.rk_interpolation_new(
            method="rk",
            radius=10000,
            folder_path=gis_path,
            waterbody=area_shortnames[seasons_all.iloc[i]["WaterBody"]],
            parameter=param_shortnames[seasons_all.iloc[i]["Parameter"]],
            year=seasons_all.iloc[i]["Start Year"],
            season=seasons_all.iloc[i]['Season'],
            covariates=covariates_dict[area_shortnames[seasons_all.iloc[i]["WaterBody"]]],
            out_raster_folder=out_raster_folder,
            out_ga_folder=out_ga_folder,
            std_error_folder=std_error_folder,
            diagnostic_folder=diagnostic_folder,
            shapefile_folder_name=gis_path+r"\shapefiles\FourSeasons_All",
            start_year_included=start_year_included  # Pass the variable to the function
        )
        e_time = time.time()

        # Write data row, conditionally include year based on the setting
        data_row = [
            seasons_all.iloc[i]["WaterBody"], 
            seasons_all.iloc[i]['Season'],
            seasons_all.iloc[i]["Parameter"],
            file_loc, count, rmse, me,
            covariates_dict[area_shortnames[seasons_all.iloc[i]["WaterBody"]]]
        ]
        if start_year_included:
            data_row.insert(1, seasons_all.iloc[i]["Start Year"])
            data_row.insert(2, seasons_all.iloc[i]["End Year"])

        print(f"{int(e_time - s_time)} seconds elapsed for processing {count} points in {i}th row: RMSE: {rmse}, ME: {me}, file exported to {file_loc}")
        csv_writer.writerow(data_row)
        if i % 10 == 0:
            csvfile.flush()  # Flush the csv file every 10 rows.
# Out:
# Processing file: SHP_CH_TN_mgl_2017_Spring.shp
# --- Time lapse: 1037.6216125488281 seconds ---
# 1038 seconds elapsed for processing 0 points in 0th row: RMSE: 0.282670778246, ME: 0.00631307578716, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/FourSeasons_RK_all/CH_TN_mgl_2017_Spring_RK.tif
# Processing file: SHP_CH_TN_mgl_2017_Summer.shp
# --- Time lapse: 787.626387834549 seconds ---
# 788 seconds elapsed for processing 0 points in 1th row: RMSE: 0.111242486399, ME: -0.000411451659123, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/FourSeasons_RK_all/CH_TN_mgl_2017_Summer_RK.tif
# Processing file: SHP_CH_TN_mgl_2017_Fall.shp
# --- Time lapse: 966.3231992721558 seconds ---
# 966 seconds elapsed for processing 0 points in 2th row: RMSE: 0.194217073213, ME: -0.00301999152275, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/FourSeasons_RK_all/CH_TN_mgl_2017_Fall_RK.tif
# Processing file: SHP_CH_TN_mgl_2017_Winter.shp
# --- Time lapse: 1072.7805433273315 seconds ---
# 1073 seconds elapsed for processing 0 points in 3th row: RMSE: 0.1342528512, ME: 0.00410512707981, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/FourSeasons_RK_all/CH_TN_mgl_2017_Winter_RK.tif
# Processing file: SHP_CH_Sal_ppt_2017_Spring.shp
# --- Time lapse: 5295.780497074127 seconds ---
# 5296 seconds elapsed for processing 0 points in 4th row: RMSE: 1.83914537144, ME: 0.0606140279184, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output/FourSeasons_RK_all/CH_Sal_ppt_2017_Spring_RK.tif
