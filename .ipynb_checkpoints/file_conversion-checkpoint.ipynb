# %%
import pandas as pd

# Define the path to your pipe-separated file
file_path = '../GIS_Data/OEAT_Continuous_WQ-2024-Feb-21.txt'  # Change this to the path of your file

# Read the pipe-separated file
df = pd.read_csv(file_path, sep='|')

# Define the path for the output CSV file
csv_file_path = '../GIS_Data/OEAT_Continuous_WQ-2024-Feb-21.csv'  # Change this to your desired output path

# Save the DataFrame as a CSV file
df.to_csv(csv_file_path, index=False)

# %%
df.head()
# Out:
#    RowID  ProgramID      ParameterName ParameterUnits ProgramLocationID  \
# 0      1        512  Water Temperature      Degrees C             CHWW1
# 1      2        512  Water Temperature      Degrees C             CHWW1
# 2      3        512  Water Temperature      Degrees C             CHWW1
# 3      4        512  Water Temperature      Degrees C             CHWW1
# 4      5        512  Water Temperature      Degrees C             CHWW1
#
#    ActivityType               SampleDate  Year  Month RelativeDepth  \
# 0           NaN  2021-11-25 11:45:00.000  2021     11        bottom
# 1           NaN  2021-11-13 16:15:00.000  2021     11        bottom
# 2           NaN  2021-10-26 14:15:00.000  2021     10        bottom
# 3           NaN  2022-09-16 12:45:00.000  2022      9        bottom
# 4           NaN  2022-09-20 10:30:00.000  2022      9        bottom
#
#    ResultValue  Latitude_DD  Longitude_DD             ManagedAreaName  AreaID  \
# 0         19.2      26.8325     -82.14805  Cape Haze Aquatic Preserve       9
# 1         22.3      26.8325     -82.14805  Cape Haze Aquatic Preserve       9
# 2         28.3      26.8325     -82.14805  Cape Haze Aquatic Preserve       9
# 3         29.7      26.8325     -82.14805  Cape Haze Aquatic Preserve       9
# 4         29.3      26.8325     -82.14805  Cape Haze Aquatic Preserve       9
#
#   SEACAR_QAQCFlagCode         WaterBody WbodyAcronym Season
# 0                  6Q  Charlotte Harbor           CH   Fall
# 1                  6Q  Charlotte Harbor           CH   Fall
# 2                  6Q  Charlotte Harbor           CH   Fall
# 3                  6Q  Charlotte Harbor           CH   Fall
# 4                  6Q  Charlotte Harbor           CH   Fall

# %%
import pandas as pd

# Define the path to your pipe-separated file
file_path = '../GIS_Data/OEAT_Discrete_WQ-2024-Feb-15.txt'  # Change this to the path of your file

# Read the pipe-separated file
df_dis = pd.read_csv(file_path, sep='|')

# Define the path for the output CSV file
csv_file_path = '../GIS_Data/OEAT_Discrete_WQ-2024-Feb-15.csv'  # Change this to your desired output path

# Save the DataFrame as a CSV file
df_dis.to_csv(csv_file_path, index=False)
