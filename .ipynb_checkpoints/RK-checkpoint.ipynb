# %% [markdown]
# # RK Interpolation
#
# This document includes Python codes that conduct Regression Kriging (RK) Interpolation on each waterbody, including Guana Tolomato Matanzas (GTM), Estero Bay (EB), Charlotte Harbor (CH), Biscayne Bay (BB), Big Bend Seagrasses (BBS).
# parameters, including Dissolved oxygen (DO_mgl), Salinity (Sal_ppt), Turbidity (Turb_ntu), Temperature (T_c), Secchi (Secc_m), Total Nitrogen (TN_mgl) in arcpy environment.
#
# The analysis is conducted in the separate managed parameters of Total Nitrogen (TN_mgl), Dissolved oxygen (DO_mgl), Salinity (Sal_ppt), Turbidity (Turb_ntu), Temperature (T_c), and Secchi (Secc_m) in arcpy environment.
#
# * [1. Data Preprocess](#preprocessing)
# * [2. Generate Shapefiles](#create_shp)
# * [3. Regression Kriging for All Stations](#rk_all)
# * [4. Regression Kriging for Continuous Stations](#rk_con)

# %%
import pandas as pd
import numpy  as np
import arcpy
from arcpy.sa import *
import os, time, math, importlib, sys
path = r'../git/misc'
sys.path.insert(0, path)
import RK
import IDW
# !install conda install conda-forge::pyproj
import pyproj,csv

importlib.reload(RK)
importlib.reload(IDW)

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Preprocessing <a class="anchor" id="preprocessing"></a>
#
# ## If you are the first time to run this code, you could run the following cell.
# ## If you have already generated the combining csv, you could skip this cell and just run the next cell.

# %%
gis_path = r'E:/Projects/SEACAR_WQ_2024/GIS_Data/'

dfDis = pd.read_csv(gis_path + 'OEAT_Discrete_WQ-2024-Jan-16.csv', low_memory=False)
dfCon = pd.read_csv(gis_path + 'OEAT_Continuous_WQ-2024-Jan-16.csv', low_memory=False)

dfAll = pd.concat([dfDis, dfCon], ignore_index=True)

# %% [markdown]
# ### Include the time period from 9 am to 17 pm in a day

# %%
# Convert string to datetime
dfAll['SampleDate'] = pd.to_datetime(dfAll['SampleDate'], format='%b %d %Y %I:%M%p')

# Include date from 9:00 am to 17:00 pm
start_time = '09:00'
end_time = '17:00'

dfAllTime = dfAll[dfAll['SampleDate'].dt.time.between(pd.to_datetime(start_time).time(), pd.to_datetime(end_time).time())]
dfAllTime.head()
# Out:
#      RowID  ProgramID ParameterName ParameterUnits ProgramLocationID  \
# 0  5062527       5014      Salinity            ppt          GTMMKNUT
# 1  5062528       5014      Salinity            ppt          GTMMKNUT
# 2  5062529       5014  Secchi Depth              m          GTMMKNUT
# 3  5062606       5014      Salinity            ppt          GTMMKNUT
# 4  5062607       5014      Salinity            ppt          GTMMKNUT
#
#   ActivityType          SampleDate  Year  Month RelativeDepth  ResultValue  \
# 0        Field 2017-08-03 11:24:00  2017      8       Surface         0.34
# 1        Field 2017-09-20 09:06:00  2017      9       Surface         0.32
# 2        Field 2017-11-02 13:11:00  2017     11       Surface         1.20
# 3        Field 2017-10-18 12:52:00  2017     10       Surface         0.34
# 4        Field 2018-04-24 10:56:00  2018      4       Surface         0.33
#
#    Latitude_DD  Longitude_DD  \
# 0    30.160736    -81.360278
# 1    30.160736    -81.360278
# 2    30.160736    -81.360278
# 3    30.160736    -81.360278
# 4    30.160736    -81.360278
#
#                                      ManagedAreaName  AreaID  \
# 0  Guana Tolomato Matanzas National Estuarine Res...      20
# 1  Guana Tolomato Matanzas National Estuarine Res...      20
# 2  Guana Tolomato Matanzas National Estuarine Res...      20
# 3  Guana Tolomato Matanzas National Estuarine Res...      20
# 4  Guana Tolomato Matanzas National Estuarine Res...      20
#
#   SEACAR_QAQCFlagCode                WaterBody WbodyAcronym  Season
# 0                  6Q  Guana Tolomato Matanzas          GTM  Summer
# 1                  6Q  Guana Tolomato Matanzas          GTM    Fall
# 2                  6Q  Guana Tolomato Matanzas          GTM    Fall
# 3                  6Q  Guana Tolomato Matanzas          GTM    Fall
# 4                  6Q  Guana Tolomato Matanzas          GTM  Spring

# %%
area_shortnames = {
    'Guana Tolomato Matanzas': 'GTM',
    'Estero Bay': 'EB',
    'Charlotte Harbor': 'CH',
    'Biscayne Bay': 'BB',
    'Big Bend Seagrasses':'BBS'
}

param_shortnames = {
    'Salinity': 'Sal_ppt',
    'Total Nitrogen': 'TN_mgl',
    'Dissolved Oxygen': 'DO_mgl',
    'Turbidity':'Turb_ntu',
    'Secchi Depth':'Secc_m',
    'Water Temperature':'T_c'
}

# Set input parameters
waterbody_names = [
    'Guana Tolomato Matanzas',
    'Estero Bay',
    'Charlotte Harbor',
    'Biscayne Bay',
    'Big Bend Seagrasses'
]

covariates_dict = {
    "GTM":"LDI",
    "EB":"bathymetry+LDI+popden",
    "CH":"bathymetry+LDI+popden+water_flow_wet",
    "BB":"bathymetry+LDI+popden",
    "BBS":"bathymetry+LDI"
}

parameter_names = ['Dissolved Oxygen', 'Salinity', 'Secchi Depth', 'Total Nitrogen', 'Turbidity', 'Water Temperature']
# years = unique_years
seasons = ['Fall', 'Spring', 'Summer', 'Winter']
shp_folder = gis_path + r"shapefiles"

# %% [markdown]
# # 2. Generate Shapefiles<a class="anchor" id="create_shp"></a>
# ## First, you need to aggregate the repeatly observation data into one value in the time period.

# %%
dfAll_Mean = dfAllTime.groupby(['WaterBody','ParameterName','ParameterUnits', 'Year','Season','Latitude_DD','Longitude_DD','WbodyAcronym'])["ResultValue"].agg("mean").reset_index()

# Save aggregated data to a csv file
dfAll = dfAll_Mean

# %% [markdown]
# ### Convert coordinate system to EPSG: 3086

# %%
# Define the EPSG codes for source (EPSG:4326) and target (EPSG:3086) coordinate systems
source_epsg = 'EPSG:4326'
target_epsg = 'EPSG:3086'

# Create a PyProj Transformer for the conversion
transformer = pyproj.Transformer.from_crs(source_epsg, target_epsg, always_xy=True)

# Define a function to apply the transformation to each row of the DataFrame
def transform_coordinates(row):
    x, y = transformer.transform(row['Longitude_DD'], row['Latitude_DD'])
    return pd.Series({'x': x, 'y': y})

# Apply the transformation function to the DataFrame and create new columns for the converted coordinates
dfAll[['x', 'y']] = dfAll.apply(transform_coordinates, axis=1)

# %%
dfAll.to_csv(gis_path + 'OEAT_All_WQ-2024-Jan-16.csv', index=False)

# %% [markdown]
# ## Generate the shapefiles of input points for each waterbody, parameter, year, and season
#
# #### Fill NaN RowID with unique ID, IDW function needs unique ID

# %%
IDW.fill_nan_rowids(dfAll, 'RowID')

# Keep RowID as integer
dfAll['RowID'] = dfAll['RowID'].astype(int)
dfAll
# Out:
#                      WaterBody      ParameterName ParameterUnits  Year  \
# 0          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# 1          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# 2          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# 3          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# 4          Big Bend Seagrasses   Dissolved Oxygen           mg/L  2015
# ...                        ...                ...            ...   ...
# 24379  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
# 24380  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
# 24381  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
# 24382  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
# 24383  Guana Tolomato Matanzas  Water Temperature      Degrees C  2023
#
#        Season  Latitude_DD  Longitude_DD WbodyAcronym  ResultValue  \
# 0        Fall    29.287817    -83.166083          BBS     5.849359
# 1        Fall    29.813933    -83.628917          BBS     6.660736
# 2      Spring    29.101817    -83.076467          BBS     7.408284
# 3      Spring    29.287817    -83.166083          BBS     6.454961
# 4      Spring    29.813933    -83.628917          BBS     7.590892
# ...       ...          ...           ...          ...          ...
# 24379  Summer    29.906941    -81.298931          GTM    28.100000
# 24380  Summer    30.025360    -81.370918          GTM    29.150000
# 24381  Summer    30.026440    -81.369403          GTM    29.500000
# 24382  Summer    30.033611    -81.353027          GTM    29.766667
# 24383  Summer    30.050338    -81.371008          GTM    29.675000
#
#                    x              y  RowID
# 0      480883.595102  587084.408007      1
# 1      435816.660743  645279.231505      2
# 2      489730.191291  566492.917816      3
# 3      480883.595102  587084.408007      4
# 4      435816.660743  645279.231505      5
# ...              ...            ...    ...
# 24379  660458.612741  658403.260621  24380
# 24380  653237.855737  671395.778870  24381
# 24381  653381.222140  671518.795530  24382
# 24382  654941.244725  672348.384187  24383
# 24383  653170.099000  674167.687117  24384
#
# [24384 rows x 12 columns]

# %%
# Read the season table
seasons_all = pd.read_csv(gis_path + 'Seasons_all.csv', low_memory=False)

# Merge interested with latitude and longitude columns
seasons_all_coord = IDW.merge_with_lat_long(seasons_all, dfAll)
seasons_all_coord
# Out:
#                     WaterBody  Year  Season          Parameter  \
# 0     Guana Tolomato Matanzas  2015    Fall     Total Nitrogen
# 1     Guana Tolomato Matanzas  2015  Winter     Total Nitrogen
# 2     Guana Tolomato Matanzas  2016  Spring     Total Nitrogen
# 3     Guana Tolomato Matanzas  2016  Summer     Total Nitrogen
# 4     Guana Tolomato Matanzas  2016    Fall     Total Nitrogen
# ...                       ...   ...     ...                ...
# 4682      Big Bend Seagrasses  2022  Spring  Water Temperature
# 4683      Big Bend Seagrasses  2022  Spring  Water Temperature
# 4684      Big Bend Seagrasses  2022  Spring  Water Temperature
# 4685      Big Bend Seagrasses  2022  Spring  Water Temperature
# 4686      Big Bend Seagrasses  2022  Spring  Water Temperature
#
#                                                Filename  NumDataPoints  \
# 0                                                   NaN              0
# 1                                                   NaN              0
# 2                                                   NaN              0
# 3                                                   NaN              0
# 4                                                   NaN              0
# ...                                                 ...            ...
# 4682  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             27
# 4683  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             27
# 4684  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             27
# 4685  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             27
# 4686  E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_out...             27
#
#                RMSE             ME              x              y  RowID  \
# 0               NaN            NaN            NaN            NaN   <NA>
# 1               NaN            NaN            NaN            NaN   <NA>
# 2               NaN            NaN            NaN            NaN   <NA>
# 3               NaN            NaN            NaN            NaN   <NA>
# 4               NaN            NaN            NaN            NaN   <NA>
# ...             ...            ...            ...            ...    ...
# 4682 -1.797693e+308 -1.797693e+308  374832.258094  689623.109934   4393
# 4683 -1.797693e+308 -1.797693e+308  371015.252225  692080.963200   4394
# 4684 -1.797693e+308 -1.797693e+308  401894.709931  699334.789795   4395
# 4685 -1.797693e+308 -1.797693e+308  401457.471573  702258.561096   4396
# 4686 -1.797693e+308 -1.797693e+308  418526.095780  706988.568308   4397
#
#       ResultValue
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 4682    20.533333
# 4683    20.740000
# 4684    19.500000
# 4685    20.500000
# 4686    15.900000
#
# [4687 rows x 12 columns]

# %% [markdown]
# ### Create CSV files

# %%
# Clean the shapefile folder if necessary
# RK.delete_all_files(shp_folder)
# Print number of data points in each shapefile
IDW.create_shp_season(seasons_all_coord, shp_folder)
# Out:
# Number of data rows for BBS, DO_mgl, 2020, Fall: 26
# Shapefile for BBS: DO_mgl for year 2020 and season Fall has been saved as SHP_BBS_DO_mgl_2020_Fall.shp
# Number of data rows for BBS, Sal_ppt, 2020, Fall: 21
# Shapefile for BBS: Sal_ppt for year 2020 and season Fall has been saved as SHP_BBS_Sal_ppt_2020_Fall.shp
# Number of data rows for BBS, Secc_m, 2020, Fall: 27
# Shapefile for BBS: Secc_m for year 2020 and season Fall has been saved as SHP_BBS_Secc_m_2020_Fall.shp
# Number of data rows for BBS, TN_mgl, 2020, Fall: 23
# Shapefile for BBS: TN_mgl for year 2020 and season Fall has been saved as SHP_BBS_TN_mgl_2020_Fall.shp
# Number of data rows for BBS, Turb_ntu, 2020, Fall: 26
# Shapefile for BBS: Turb_ntu for year 2020 and season Fall has been saved as SHP_BBS_Turb_ntu_2020_Fall.shp
# Number of data rows for BBS, T_c, 2020, Fall: 26
# Shapefile for BBS: T_c for year 2020 and season Fall has been saved as SHP_BBS_T_c_2020_Fall.shp
# Number of data rows for BBS, DO_mgl, 2020, Summer: 26
# Shapefile for BBS: DO_mgl for year 2020 and season Summer has been saved as SHP_BBS_DO_mgl_2020_Summer.shp
# Number of data rows for BBS, Sal_ppt, 2020, Summer: 20
# Shapefile for BBS: Sal_ppt for year 2020 and season Summer has been saved as SHP_BBS_Sal_ppt_2020_Summer.shp
# Number of data rows for BBS, Secc_m, 2020, Summer: 24
# Shapefile for BBS: Secc_m for year 2020 and season Summer has been saved as SHP_BBS_Secc_m_2020_Summer.shp
# Number of data rows for BBS, TN_mgl, 2020, Summer: 21
# Shapefile for BBS: TN_mgl for year 2020 and season Summer has been saved as SHP_BBS_TN_mgl_2020_Summer.shp
# Number of data rows for BBS, Turb_ntu, 2020, Summer: 25
# Shapefile for BBS: Turb_ntu for year 2020 and season Summer has been saved as SHP_BBS_Turb_ntu_2020_Summer.shp
# Number of data rows for BBS, T_c, 2020, Summer: 26
# Shapefile for BBS: T_c for year 2020 and season Summer has been saved as SHP_BBS_T_c_2020_Summer.shp
# Number of data rows for BBS, DO_mgl, 2020, Winter: 34
# Shapefile for BBS: DO_mgl for year 2020 and season Winter has been saved as SHP_BBS_DO_mgl_2020_Winter.shp
# Number of data rows for BBS, Sal_ppt, 2020, Winter: 32
# Shapefile for BBS: Sal_ppt for year 2020 and season Winter has been saved as SHP_BBS_Sal_ppt_2020_Winter.shp
# Number of data rows for BBS, Secc_m, 2020, Winter: 30
# Shapefile for BBS: Secc_m for year 2020 and season Winter has been saved as SHP_BBS_Secc_m_2020_Winter.shp
# Number of data rows for BBS, TN_mgl, 2020, Winter: 32
# Shapefile for BBS: TN_mgl for year 2020 and season Winter has been saved as SHP_BBS_TN_mgl_2020_Winter.shp
# Number of data rows for BBS, Turb_ntu, 2020, Winter: 35
# Shapefile for BBS: Turb_ntu for year 2020 and season Winter has been saved as SHP_BBS_Turb_ntu_2020_Winter.shp
# Number of data rows for BBS, T_c, 2020, Winter: 34
# Shapefile for BBS: T_c for year 2020 and season Winter has been saved as SHP_BBS_T_c_2020_Winter.shp
# Number of data rows for BBS, DO_mgl, 2021, Fall: 38
# Shapefile for BBS: DO_mgl for year 2021 and season Fall has been saved as SHP_BBS_DO_mgl_2021_Fall.shp
# Number of data rows for BBS, Sal_ppt, 2021, Fall: 29
# Shapefile for BBS: Sal_ppt for year 2021 and season Fall has been saved as SHP_BBS_Sal_ppt_2021_Fall.shp
# Number of data rows for BBS, Secc_m, 2021, Fall: 31
# Shapefile for BBS: Secc_m for year 2021 and season Fall has been saved as SHP_BBS_Secc_m_2021_Fall.shp
# Number of data rows for BBS, TN_mgl, 2021, Fall: 33
# Shapefile for BBS: TN_mgl for year 2021 and season Fall has been saved as SHP_BBS_TN_mgl_2021_Fall.shp
# Number of data rows for BBS, Turb_ntu, 2021, Fall: 34
# Shapefile for BBS: Turb_ntu for year 2021 and season Fall has been saved as SHP_BBS_Turb_ntu_2021_Fall.shp
# Number of data rows for BBS, T_c, 2021, Fall: 38
# Shapefile for BBS: T_c for year 2021 and season Fall has been saved as SHP_BBS_T_c_2021_Fall.shp
# Number of data rows for BBS, DO_mgl, 2021, Spring: 44
# Shapefile for BBS: DO_mgl for year 2021 and season Spring has been saved as SHP_BBS_DO_mgl_2021_Spring.shp
# Number of data rows for BBS, Sal_ppt, 2021, Spring: 33
# Shapefile for BBS: Sal_ppt for year 2021 and season Spring has been saved as SHP_BBS_Sal_ppt_2021_Spring.shp
# Number of data rows for BBS, Secc_m, 2021, Spring: 38
# Shapefile for BBS: Secc_m for year 2021 and season Spring has been saved as SHP_BBS_Secc_m_2021_Spring.shp
# Number of data rows for BBS, TN_mgl, 2021, Spring: 35
# Shapefile for BBS: TN_mgl for year 2021 and season Spring has been saved as SHP_BBS_TN_mgl_2021_Spring.shp
# Number of data rows for BBS, Turb_ntu, 2021, Spring: 37
# Shapefile for BBS: Turb_ntu for year 2021 and season Spring has been saved as SHP_BBS_Turb_ntu_2021_Spring.shp
# Number of data rows for BBS, T_c, 2021, Spring: 44
# Shapefile for BBS: T_c for year 2021 and season Spring has been saved as SHP_BBS_T_c_2021_Spring.shp
# Number of data rows for BBS, DO_mgl, 2021, Summer: 37
# Shapefile for BBS: DO_mgl for year 2021 and season Summer has been saved as SHP_BBS_DO_mgl_2021_Summer.shp
# Number of data rows for BBS, Sal_ppt, 2021, Summer: 28
# Shapefile for BBS: Sal_ppt for year 2021 and season Summer has been saved as SHP_BBS_Sal_ppt_2021_Summer.shp
# Number of data rows for BBS, Secc_m, 2021, Summer: 29
# Shapefile for BBS: Secc_m for year 2021 and season Summer has been saved as SHP_BBS_Secc_m_2021_Summer.shp
# Number of data rows for BBS, TN_mgl, 2021, Summer: 28
# Shapefile for BBS: TN_mgl for year 2021 and season Summer has been saved as SHP_BBS_TN_mgl_2021_Summer.shp
# Number of data rows for BBS, Turb_ntu, 2021, Summer: 30
# Shapefile for BBS: Turb_ntu for year 2021 and season Summer has been saved as SHP_BBS_Turb_ntu_2021_Summer.shp
# Number of data rows for BBS, T_c, 2021, Summer: 37
# Shapefile for BBS: T_c for year 2021 and season Summer has been saved as SHP_BBS_T_c_2021_Summer.shp
# Number of data rows for BBS, DO_mgl, 2021, Winter: 39
# Shapefile for BBS: DO_mgl for year 2021 and season Winter has been saved as SHP_BBS_DO_mgl_2021_Winter.shp
# Number of data rows for BBS, Sal_ppt, 2021, Winter: 32
# Shapefile for BBS: Sal_ppt for year 2021 and season Winter has been saved as SHP_BBS_Sal_ppt_2021_Winter.shp
# Number of data rows for BBS, Secc_m, 2021, Winter: 32
# Shapefile for BBS: Secc_m for year 2021 and season Winter has been saved as SHP_BBS_Secc_m_2021_Winter.shp
# Number of data rows for BBS, TN_mgl, 2021, Winter: 31
# Shapefile for BBS: TN_mgl for year 2021 and season Winter has been saved as SHP_BBS_TN_mgl_2021_Winter.shp
# Number of data rows for BBS, Turb_ntu, 2021, Winter: 35
# Shapefile for BBS: Turb_ntu for year 2021 and season Winter has been saved as SHP_BBS_Turb_ntu_2021_Winter.shp
# Number of data rows for BBS, T_c, 2021, Winter: 39
# Shapefile for BBS: T_c for year 2021 and season Winter has been saved as SHP_BBS_T_c_2021_Winter.shp
# Number of data rows for BBS, DO_mgl, 2022, Spring: 29
# Shapefile for BBS: DO_mgl for year 2022 and season Spring has been saved as SHP_BBS_DO_mgl_2022_Spring.shp
# Number of data rows for BBS, Sal_ppt, 2022, Spring: 16
# Shapefile for BBS: Sal_ppt for year 2022 and season Spring has been saved as SHP_BBS_Sal_ppt_2022_Spring.shp
# Number of data rows for BBS, Secc_m, 2022, Spring: 28
# Shapefile for BBS: Secc_m for year 2022 and season Spring has been saved as SHP_BBS_Secc_m_2022_Spring.shp
# Number of data rows for BBS, TN_mgl, 2022, Spring: 25
# Shapefile for BBS: TN_mgl for year 2022 and season Spring has been saved as SHP_BBS_TN_mgl_2022_Spring.shp
# Number of data rows for BBS, Turb_ntu, 2022, Spring: 28
# Shapefile for BBS: Turb_ntu for year 2022 and season Spring has been saved as SHP_BBS_Turb_ntu_2022_Spring.shp
# Number of data rows for BBS, T_c, 2022, Spring: 27
# Shapefile for BBS: T_c for year 2022 and season Spring has been saved as SHP_BBS_T_c_2022_Spring.shp
# Number of data rows for BB, DO_mgl, 2021, Fall: 83
# Shapefile for BB: DO_mgl for year 2021 and season Fall has been saved as SHP_BB_DO_mgl_2021_Fall.shp
# Number of data rows for BB, Sal_ppt, 2021, Fall: 63
# Shapefile for BB: Sal_ppt for year 2021 and season Fall has been saved as SHP_BB_Sal_ppt_2021_Fall.shp
# No valid data found for area: BB, parameter: Secc_m, year: 2021, and season: Fall
# Number of data rows for BB, TN_mgl, 2021, Fall: 78
# Shapefile for BB: TN_mgl for year 2021 and season Fall has been saved as SHP_BB_TN_mgl_2021_Fall.shp
# Number of data rows for BB, Turb_ntu, 2021, Fall: 62
# Shapefile for BB: Turb_ntu for year 2021 and season Fall has been saved as SHP_BB_Turb_ntu_2021_Fall.shp
# Number of data rows for BB, T_c, 2021, Fall: 83
# Shapefile for BB: T_c for year 2021 and season Fall has been saved as SHP_BB_T_c_2021_Fall.shp
# Number of data rows for BB, DO_mgl, 2021, Summer: 83
# Shapefile for BB: DO_mgl for year 2021 and season Summer has been saved as SHP_BB_DO_mgl_2021_Summer.shp
# Number of data rows for BB, Sal_ppt, 2021, Summer: 61
# Shapefile for BB: Sal_ppt for year 2021 and season Summer has been saved as SHP_BB_Sal_ppt_2021_Summer.shp
# Number of data rows for BB, Secc_m, 2021, Summer: 1
# Shapefile for BB: Secc_m for year 2021 and season Summer has been saved as SHP_BB_Secc_m_2021_Summer.shp
# Number of data rows for BB, TN_mgl, 2021, Summer: 76
# Shapefile for BB: TN_mgl for year 2021 and season Summer has been saved as SHP_BB_TN_mgl_2021_Summer.shp
# Number of data rows for BB, Turb_ntu, 2021, Summer: 61
# Shapefile for BB: Turb_ntu for year 2021 and season Summer has been saved as SHP_BB_Turb_ntu_2021_Summer.shp
# Number of data rows for BB, T_c, 2021, Summer: 83
# Shapefile for BB: T_c for year 2021 and season Summer has been saved as SHP_BB_T_c_2021_Summer.shp
# Number of data rows for BB, DO_mgl, 2021, Winter: 85
# Shapefile for BB: DO_mgl for year 2021 and season Winter has been saved as SHP_BB_DO_mgl_2021_Winter.shp
# Number of data rows for BB, Sal_ppt, 2021, Winter: 62
# Shapefile for BB: Sal_ppt for year 2021 and season Winter has been saved as SHP_BB_Sal_ppt_2021_Winter.shp
# No valid data found for area: BB, parameter: Secc_m, year: 2021, and season: Winter
# Number of data rows for BB, TN_mgl, 2021, Winter: 80
# Shapefile for BB: TN_mgl for year 2021 and season Winter has been saved as SHP_BB_TN_mgl_2021_Winter.shp
# Number of data rows for BB, Turb_ntu, 2021, Winter: 61
# Shapefile for BB: Turb_ntu for year 2021 and season Winter has been saved as SHP_BB_Turb_ntu_2021_Winter.shp
# Number of data rows for BB, T_c, 2021, Winter: 85
# Shapefile for BB: T_c for year 2021 and season Winter has been saved as SHP_BB_T_c_2021_Winter.shp
# Number of data rows for BB, DO_mgl, 2022, Fall: 68
# Shapefile for BB: DO_mgl for year 2022 and season Fall has been saved as SHP_BB_DO_mgl_2022_Fall.shp
# Number of data rows for BB, Sal_ppt, 2022, Fall: 50
# Shapefile for BB: Sal_ppt for year 2022 and season Fall has been saved as SHP_BB_Sal_ppt_2022_Fall.shp
# No valid data found for area: BB, parameter: Secc_m, year: 2022, and season: Fall
# Number of data rows for BB, TN_mgl, 2022, Fall: 58
# Shapefile for BB: TN_mgl for year 2022 and season Fall has been saved as SHP_BB_TN_mgl_2022_Fall.shp
# Number of data rows for BB, Turb_ntu, 2022, Fall: 50
# Shapefile for BB: Turb_ntu for year 2022 and season Fall has been saved as SHP_BB_Turb_ntu_2022_Fall.shp
# Number of data rows for BB, T_c, 2022, Fall: 70
# Shapefile for BB: T_c for year 2022 and season Fall has been saved as SHP_BB_T_c_2022_Fall.shp
# Number of data rows for BB, DO_mgl, 2022, Spring: 45
# Shapefile for BB: DO_mgl for year 2022 and season Spring has been saved as SHP_BB_DO_mgl_2022_Spring.shp
# Number of data rows for BB, Sal_ppt, 2022, Spring: 47
# Shapefile for BB: Sal_ppt for year 2022 and season Spring has been saved as SHP_BB_Sal_ppt_2022_Spring.shp
# No valid data found for area: BB, parameter: Secc_m, year: 2022, and season: Spring
# Number of data rows for BB, TN_mgl, 2022, Spring: 34
# Shapefile for BB: TN_mgl for year 2022 and season Spring has been saved as SHP_BB_TN_mgl_2022_Spring.shp
# Number of data rows for BB, Turb_ntu, 2022, Spring: 46
# Shapefile for BB: Turb_ntu for year 2022 and season Spring has been saved as SHP_BB_Turb_ntu_2022_Spring.shp
# Number of data rows for BB, T_c, 2022, Spring: 47
# Shapefile for BB: T_c for year 2022 and season Spring has been saved as SHP_BB_T_c_2022_Spring.shp
# Number of data rows for BB, DO_mgl, 2022, Summer: 69
# Shapefile for BB: DO_mgl for year 2022 and season Summer has been saved as SHP_BB_DO_mgl_2022_Summer.shp
# Number of data rows for BB, Sal_ppt, 2022, Summer: 48
# Shapefile for BB: Sal_ppt for year 2022 and season Summer has been saved as SHP_BB_Sal_ppt_2022_Summer.shp
# Number of data rows for BB, Secc_m, 2022, Summer: 1
# Shapefile for BB: Secc_m for year 2022 and season Summer has been saved as SHP_BB_Secc_m_2022_Summer.shp
# Number of data rows for BB, TN_mgl, 2022, Summer: 57
# Shapefile for BB: TN_mgl for year 2022 and season Summer has been saved as SHP_BB_TN_mgl_2022_Summer.shp
# Number of data rows for BB, Turb_ntu, 2022, Summer: 49
# Shapefile for BB: Turb_ntu for year 2022 and season Summer has been saved as SHP_BB_Turb_ntu_2022_Summer.shp
# Number of data rows for BB, T_c, 2022, Summer: 69
# Shapefile for BB: T_c for year 2022 and season Summer has been saved as SHP_BB_T_c_2022_Summer.shp
# Number of data rows for BB, DO_mgl, 2022, Winter: 64
# Shapefile for BB: DO_mgl for year 2022 and season Winter has been saved as SHP_BB_DO_mgl_2022_Winter.shp
# Number of data rows for BB, Sal_ppt, 2022, Winter: 50
# Shapefile for BB: Sal_ppt for year 2022 and season Winter has been saved as SHP_BB_Sal_ppt_2022_Winter.shp
# No valid data found for area: BB, parameter: Secc_m, year: 2022, and season: Winter
# Number of data rows for BB, TN_mgl, 2022, Winter: 53
# Shapefile for BB: TN_mgl for year 2022 and season Winter has been saved as SHP_BB_TN_mgl_2022_Winter.shp
# Number of data rows for BB, Turb_ntu, 2022, Winter: 50
# Shapefile for BB: Turb_ntu for year 2022 and season Winter has been saved as SHP_BB_Turb_ntu_2022_Winter.shp
# Number of data rows for BB, T_c, 2022, Winter: 66
# Shapefile for BB: T_c for year 2022 and season Winter has been saved as SHP_BB_T_c_2022_Winter.shp
# Number of data rows for BB, DO_mgl, 2023, Spring: 54
# Shapefile for BB: DO_mgl for year 2023 and season Spring has been saved as SHP_BB_DO_mgl_2023_Spring.shp
# Number of data rows for BB, Sal_ppt, 2023, Spring: 48
# Shapefile for BB: Sal_ppt for year 2023 and season Spring has been saved as SHP_BB_Sal_ppt_2023_Spring.shp
# No valid data found for area: BB, parameter: Secc_m, year: 2023, and season: Spring
# Number of data rows for BB, TN_mgl, 2023, Spring: 23
# Shapefile for BB: TN_mgl for year 2023 and season Spring has been saved as SHP_BB_TN_mgl_2023_Spring.shp
# Number of data rows for BB, Turb_ntu, 2023, Spring: 35
# Shapefile for BB: Turb_ntu for year 2023 and season Spring has been saved as SHP_BB_Turb_ntu_2023_Spring.shp
# Number of data rows for BB, T_c, 2023, Spring: 56
# Shapefile for BB: T_c for year 2023 and season Spring has been saved as SHP_BB_T_c_2023_Spring.shp
# Number of data rows for CH, DO_mgl, 2016, Fall: 3
# Shapefile for CH: DO_mgl for year 2016 and season Fall has been saved as SHP_CH_DO_mgl_2016_Fall.shp
# Number of data rows for CH, Sal_ppt, 2016, Fall: 3
# Shapefile for CH: Sal_ppt for year 2016 and season Fall has been saved as SHP_CH_Sal_ppt_2016_Fall.shp
# No valid data found for area: CH, parameter: Secc_m, year: 2016, and season: Fall
# No valid data found for area: CH, parameter: TN_mgl, year: 2016, and season: Fall
# Number of data rows for CH, Turb_ntu, 2016, Fall: 3
# Shapefile for CH: Turb_ntu for year 2016 and season Fall has been saved as SHP_CH_Turb_ntu_2016_Fall.shp
# Number of data rows for CH, T_c, 2016, Fall: 3
# Shapefile for CH: T_c for year 2016 and season Fall has been saved as SHP_CH_T_c_2016_Fall.shp
# Number of data rows for CH, DO_mgl, 2016, Summer: 3
# Shapefile for CH: DO_mgl for year 2016 and season Summer has been saved as SHP_CH_DO_mgl_2016_Summer.shp
# Number of data rows for CH, Sal_ppt, 2016, Summer: 3
# Shapefile for CH: Sal_ppt for year 2016 and season Summer has been saved as SHP_CH_Sal_ppt_2016_Summer.shp
# No valid data found for area: CH, parameter: Secc_m, year: 2016, and season: Summer
# No valid data found for area: CH, parameter: TN_mgl, year: 2016, and season: Summer
# Number of data rows for CH, Turb_ntu, 2016, Summer: 3
# Shapefile for CH: Turb_ntu for year 2016 and season Summer has been saved as SHP_CH_Turb_ntu_2016_Summer.shp
# Number of data rows for CH, T_c, 2016, Summer: 3
# Shapefile for CH: T_c for year 2016 and season Summer has been saved as SHP_CH_T_c_2016_Summer.shp
# Number of data rows for CH, DO_mgl, 2016, Winter: 11
# Shapefile for CH: DO_mgl for year 2016 and season Winter has been saved as SHP_CH_DO_mgl_2016_Winter.shp
# Number of data rows for CH, Sal_ppt, 2016, Winter: 11
# Shapefile for CH: Sal_ppt for year 2016 and season Winter has been saved as SHP_CH_Sal_ppt_2016_Winter.shp
# Number of data rows for CH, Secc_m, 2016, Winter: 8
# Shapefile for CH: Secc_m for year 2016 and season Winter has been saved as SHP_CH_Secc_m_2016_Winter.shp
# Number of data rows for CH, TN_mgl, 2016, Winter: 8
# Shapefile for CH: TN_mgl for year 2016 and season Winter has been saved as SHP_CH_TN_mgl_2016_Winter.shp
# Number of data rows for CH, Turb_ntu, 2016, Winter: 11
# Shapefile for CH: Turb_ntu for year 2016 and season Winter has been saved as SHP_CH_Turb_ntu_2016_Winter.shp
# Number of data rows for CH, T_c, 2016, Winter: 11
# Shapefile for CH: T_c for year 2016 and season Winter has been saved as SHP_CH_T_c_2016_Winter.shp
# Number of data rows for CH, DO_mgl, 2017, Fall: 3
# Shapefile for CH: DO_mgl for year 2017 and season Fall has been saved as SHP_CH_DO_mgl_2017_Fall.shp
# Number of data rows for CH, Sal_ppt, 2017, Fall: 3
# Shapefile for CH: Sal_ppt for year 2017 and season Fall has been saved as SHP_CH_Sal_ppt_2017_Fall.shp
# No valid data found for area: CH, parameter: Secc_m, year: 2017, and season: Fall
# No valid data found for area: CH, parameter: TN_mgl, year: 2017, and season: Fall
# Number of data rows for CH, Turb_ntu, 2017, Fall: 3
# Shapefile for CH: Turb_ntu for year 2017 and season Fall has been saved as SHP_CH_Turb_ntu_2017_Fall.shp
# Number of data rows for CH, T_c, 2017, Fall: 3
# Shapefile for CH: T_c for year 2017 and season Fall has been saved as SHP_CH_T_c_2017_Fall.shp
# Number of data rows for CH, DO_mgl, 2017, Spring: 3
# Shapefile for CH: DO_mgl for year 2017 and season Spring has been saved as SHP_CH_DO_mgl_2017_Spring.shp
# Number of data rows for CH, Sal_ppt, 2017, Spring: 3
# Shapefile for CH: Sal_ppt for year 2017 and season Spring has been saved as SHP_CH_Sal_ppt_2017_Spring.shp
# No valid data found for area: CH, parameter: Secc_m, year: 2017, and season: Spring
# No valid data found for area: CH, parameter: TN_mgl, year: 2017, and season: Spring
# Number of data rows for CH, Turb_ntu, 2017, Spring: 3
# Shapefile for CH: Turb_ntu for year 2017 and season Spring has been saved as SHP_CH_Turb_ntu_2017_Spring.shp
# Number of data rows for CH, T_c, 2017, Spring: 3
# Shapefile for CH: T_c for year 2017 and season Spring has been saved as SHP_CH_T_c_2017_Spring.shp
# Number of data rows for CH, DO_mgl, 2017, Summer: 3
# Shapefile for CH: DO_mgl for year 2017 and season Summer has been saved as SHP_CH_DO_mgl_2017_Summer.shp
# Number of data rows for CH, Sal_ppt, 2017, Summer: 3
# Shapefile for CH: Sal_ppt for year 2017 and season Summer has been saved as SHP_CH_Sal_ppt_2017_Summer.shp
# No valid data found for area: CH, parameter: Secc_m, year: 2017, and season: Summer
# No valid data found for area: CH, parameter: TN_mgl, year: 2017, and season: Summer
# Number of data rows for CH, Turb_ntu, 2017, Summer: 3
# Shapefile for CH: Turb_ntu for year 2017 and season Summer has been saved as SHP_CH_Turb_ntu_2017_Summer.shp
# Number of data rows for CH, T_c, 2017, Summer: 3
# Shapefile for CH: T_c for year 2017 and season Summer has been saved as SHP_CH_T_c_2017_Summer.shp
# Number of data rows for CH, DO_mgl, 2017, Winter: 3
# Shapefile for CH: DO_mgl for year 2017 and season Winter has been saved as SHP_CH_DO_mgl_2017_Winter.shp
# Number of data rows for CH, Sal_ppt, 2017, Winter: 3
# Shapefile for CH: Sal_ppt for year 2017 and season Winter has been saved as SHP_CH_Sal_ppt_2017_Winter.shp
# No valid data found for area: CH, parameter: Secc_m, year: 2017, and season: Winter
# No valid data found for area: CH, parameter: TN_mgl, year: 2017, and season: Winter
# Number of data rows for CH, Turb_ntu, 2017, Winter: 3
# Shapefile for CH: Turb_ntu for year 2017 and season Winter has been saved as SHP_CH_Turb_ntu_2017_Winter.shp
# Number of data rows for CH, T_c, 2017, Winter: 3
# Shapefile for CH: T_c for year 2017 and season Winter has been saved as SHP_CH_T_c_2017_Winter.shp
# Number of data rows for CH, DO_mgl, 2018, Spring: 36
# Shapefile for CH: DO_mgl for year 2018 and season Spring has been saved as SHP_CH_DO_mgl_2018_Spring.shp
# Number of data rows for CH, Sal_ppt, 2018, Spring: 3
# Shapefile for CH: Sal_ppt for year 2018 and season Spring has been saved as SHP_CH_Sal_ppt_2018_Spring.shp
# No valid data found for area: CH, parameter: Secc_m, year: 2018, and season: Spring
# Number of data rows for CH, TN_mgl, 2018, Spring: 49
# Shapefile for CH: TN_mgl for year 2018 and season Spring has been saved as SHP_CH_TN_mgl_2018_Spring.shp
# Number of data rows for CH, Turb_ntu, 2018, Spring: 52
# Shapefile for CH: Turb_ntu for year 2018 and season Spring has been saved as SHP_CH_Turb_ntu_2018_Spring.shp
# Number of data rows for CH, T_c, 2018, Spring: 36
# Shapefile for CH: T_c for year 2018 and season Spring has been saved as SHP_CH_T_c_2018_Spring.shp
# Number of data rows for EB, DO_mgl, 2016, Fall: 3
# Shapefile for EB: DO_mgl for year 2016 and season Fall has been saved as SHP_EB_DO_mgl_2016_Fall.shp
# Number of data rows for EB, Sal_ppt, 2016, Fall: 3
# Shapefile for EB: Sal_ppt for year 2016 and season Fall has been saved as SHP_EB_Sal_ppt_2016_Fall.shp
# No valid data found for area: EB, parameter: Secc_m, year: 2016, and season: Fall
# No valid data found for area: EB, parameter: TN_mgl, year: 2016, and season: Fall
# Number of data rows for EB, Turb_ntu, 2016, Fall: 2
# Shapefile for EB: Turb_ntu for year 2016 and season Fall has been saved as SHP_EB_Turb_ntu_2016_Fall.shp
# Number of data rows for EB, T_c, 2016, Fall: 3
# Shapefile for EB: T_c for year 2016 and season Fall has been saved as SHP_EB_T_c_2016_Fall.shp
# Number of data rows for EB, DO_mgl, 2016, Summer: 3
# Shapefile for EB: DO_mgl for year 2016 and season Summer has been saved as SHP_EB_DO_mgl_2016_Summer.shp
# Number of data rows for EB, Sal_ppt, 2016, Summer: 3
# Shapefile for EB: Sal_ppt for year 2016 and season Summer has been saved as SHP_EB_Sal_ppt_2016_Summer.shp
# No valid data found for area: EB, parameter: Secc_m, year: 2016, and season: Summer
# No valid data found for area: EB, parameter: TN_mgl, year: 2016, and season: Summer
# Number of data rows for EB, Turb_ntu, 2016, Summer: 3
# Shapefile for EB: Turb_ntu for year 2016 and season Summer has been saved as SHP_EB_Turb_ntu_2016_Summer.shp
# Number of data rows for EB, T_c, 2016, Summer: 3
# Shapefile for EB: T_c for year 2016 and season Summer has been saved as SHP_EB_T_c_2016_Summer.shp
# Number of data rows for EB, DO_mgl, 2016, Winter: 3
# Shapefile for EB: DO_mgl for year 2016 and season Winter has been saved as SHP_EB_DO_mgl_2016_Winter.shp
# Number of data rows for EB, Sal_ppt, 2016, Winter: 3
# Shapefile for EB: Sal_ppt for year 2016 and season Winter has been saved as SHP_EB_Sal_ppt_2016_Winter.shp
# No valid data found for area: EB, parameter: Secc_m, year: 2016, and season: Winter
# No valid data found for area: EB, parameter: TN_mgl, year: 2016, and season: Winter
# Number of data rows for EB, Turb_ntu, 2016, Winter: 3
# Shapefile for EB: Turb_ntu for year 2016 and season Winter has been saved as SHP_EB_Turb_ntu_2016_Winter.shp
# Number of data rows for EB, T_c, 2016, Winter: 3
# Shapefile for EB: T_c for year 2016 and season Winter has been saved as SHP_EB_T_c_2016_Winter.shp
# Number of data rows for EB, DO_mgl, 2017, Fall: 3
# Shapefile for EB: DO_mgl for year 2017 and season Fall has been saved as SHP_EB_DO_mgl_2017_Fall.shp
# Number of data rows for EB, Sal_ppt, 2017, Fall: 3
# Shapefile for EB: Sal_ppt for year 2017 and season Fall has been saved as SHP_EB_Sal_ppt_2017_Fall.shp
# No valid data found for area: EB, parameter: Secc_m, year: 2017, and season: Fall
# No valid data found for area: EB, parameter: TN_mgl, year: 2017, and season: Fall
# Number of data rows for EB, Turb_ntu, 2017, Fall: 3
# Shapefile for EB: Turb_ntu for year 2017 and season Fall has been saved as SHP_EB_Turb_ntu_2017_Fall.shp
# Number of data rows for EB, T_c, 2017, Fall: 3
# Shapefile for EB: T_c for year 2017 and season Fall has been saved as SHP_EB_T_c_2017_Fall.shp
# Number of data rows for EB, DO_mgl, 2017, Spring: 3
# Shapefile for EB: DO_mgl for year 2017 and season Spring has been saved as SHP_EB_DO_mgl_2017_Spring.shp
# Number of data rows for EB, Sal_ppt, 2017, Spring: 3
# Shapefile for EB: Sal_ppt for year 2017 and season Spring has been saved as SHP_EB_Sal_ppt_2017_Spring.shp
# No valid data found for area: EB, parameter: Secc_m, year: 2017, and season: Spring
# No valid data found for area: EB, parameter: TN_mgl, year: 2017, and season: Spring
# Number of data rows for EB, Turb_ntu, 2017, Spring: 3
# Shapefile for EB: Turb_ntu for year 2017 and season Spring has been saved as SHP_EB_Turb_ntu_2017_Spring.shp
# Number of data rows for EB, T_c, 2017, Spring: 3
# Shapefile for EB: T_c for year 2017 and season Spring has been saved as SHP_EB_T_c_2017_Spring.shp
# Number of data rows for EB, DO_mgl, 2017, Summer: 3
# Shapefile for EB: DO_mgl for year 2017 and season Summer has been saved as SHP_EB_DO_mgl_2017_Summer.shp
# Number of data rows for EB, Sal_ppt, 2017, Summer: 3
# Shapefile for EB: Sal_ppt for year 2017 and season Summer has been saved as SHP_EB_Sal_ppt_2017_Summer.shp
# No valid data found for area: EB, parameter: Secc_m, year: 2017, and season: Summer
# No valid data found for area: EB, parameter: TN_mgl, year: 2017, and season: Summer
# Number of data rows for EB, Turb_ntu, 2017, Summer: 3
# Shapefile for EB: Turb_ntu for year 2017 and season Summer has been saved as SHP_EB_Turb_ntu_2017_Summer.shp
# Number of data rows for EB, T_c, 2017, Summer: 3
# Shapefile for EB: T_c for year 2017 and season Summer has been saved as SHP_EB_T_c_2017_Summer.shp
# Number of data rows for EB, DO_mgl, 2017, Winter: 3
# Shapefile for EB: DO_mgl for year 2017 and season Winter has been saved as SHP_EB_DO_mgl_2017_Winter.shp
# Number of data rows for EB, Sal_ppt, 2017, Winter: 3
# Shapefile for EB: Sal_ppt for year 2017 and season Winter has been saved as SHP_EB_Sal_ppt_2017_Winter.shp
# No valid data found for area: EB, parameter: Secc_m, year: 2017, and season: Winter
# No valid data found for area: EB, parameter: TN_mgl, year: 2017, and season: Winter
# Number of data rows for EB, Turb_ntu, 2017, Winter: 3
# Shapefile for EB: Turb_ntu for year 2017 and season Winter has been saved as SHP_EB_Turb_ntu_2017_Winter.shp
# Number of data rows for EB, T_c, 2017, Winter: 3
# Shapefile for EB: T_c for year 2017 and season Winter has been saved as SHP_EB_T_c_2017_Winter.shp
# Number of data rows for EB, DO_mgl, 2018, Spring: 27
# Shapefile for EB: DO_mgl for year 2018 and season Spring has been saved as SHP_EB_DO_mgl_2018_Spring.shp
# Number of data rows for EB, Sal_ppt, 2018, Spring: 3
# Shapefile for EB: Sal_ppt for year 2018 and season Spring has been saved as SHP_EB_Sal_ppt_2018_Spring.shp
# No valid data found for area: EB, parameter: Secc_m, year: 2018, and season: Spring
# Number of data rows for EB, TN_mgl, 2018, Spring: 27
# Shapefile for EB: TN_mgl for year 2018 and season Spring has been saved as SHP_EB_TN_mgl_2018_Spring.shp
# Number of data rows for EB, Turb_ntu, 2018, Spring: 30
# Shapefile for EB: Turb_ntu for year 2018 and season Spring has been saved as SHP_EB_Turb_ntu_2018_Spring.shp
# Number of data rows for EB, T_c, 2018, Spring: 27
# Shapefile for EB: T_c for year 2018 and season Spring has been saved as SHP_EB_T_c_2018_Spring.shp
# Number of data rows for GTM, DO_mgl, 2015, Fall: 8
# Shapefile for GTM: DO_mgl for year 2015 and season Fall has been saved as SHP_GTM_DO_mgl_2015_Fall.shp
# Number of data rows for GTM, Sal_ppt, 2015, Fall: 8
# Shapefile for GTM: Sal_ppt for year 2015 and season Fall has been saved as SHP_GTM_Sal_ppt_2015_Fall.shp
# No valid data found for area: GTM, parameter: Secc_m, year: 2015, and season: Fall
# No valid data found for area: GTM, parameter: TN_mgl, year: 2015, and season: Fall
# Number of data rows for GTM, Turb_ntu, 2015, Fall: 4
# Shapefile for GTM: Turb_ntu for year 2015 and season Fall has been saved as SHP_GTM_Turb_ntu_2015_Fall.shp
# Number of data rows for GTM, T_c, 2015, Fall: 8
# Shapefile for GTM: T_c for year 2015 and season Fall has been saved as SHP_GTM_T_c_2015_Fall.shp
# Number of data rows for GTM, DO_mgl, 2015, Winter: 7
# Shapefile for GTM: DO_mgl for year 2015 and season Winter has been saved as SHP_GTM_DO_mgl_2015_Winter.shp
# Number of data rows for GTM, Sal_ppt, 2015, Winter: 7
# Shapefile for GTM: Sal_ppt for year 2015 and season Winter has been saved as SHP_GTM_Sal_ppt_2015_Winter.shp
# No valid data found for area: GTM, parameter: Secc_m, year: 2015, and season: Winter
# No valid data found for area: GTM, parameter: TN_mgl, year: 2015, and season: Winter
# Number of data rows for GTM, Turb_ntu, 2015, Winter: 4
# Shapefile for GTM: Turb_ntu for year 2015 and season Winter has been saved as SHP_GTM_Turb_ntu_2015_Winter.shp
# Number of data rows for GTM, T_c, 2015, Winter: 7
# Shapefile for GTM: T_c for year 2015 and season Winter has been saved as SHP_GTM_T_c_2015_Winter.shp
# Number of data rows for GTM, DO_mgl, 2016, Fall: 8
# Shapefile for GTM: DO_mgl for year 2016 and season Fall has been saved as SHP_GTM_DO_mgl_2016_Fall.shp
# Number of data rows for GTM, Sal_ppt, 2016, Fall: 5
# Shapefile for GTM: Sal_ppt for year 2016 and season Fall has been saved as SHP_GTM_Sal_ppt_2016_Fall.shp
# No valid data found for area: GTM, parameter: Secc_m, year: 2016, and season: Fall
# No valid data found for area: GTM, parameter: TN_mgl, year: 2016, and season: Fall
# Number of data rows for GTM, Turb_ntu, 2016, Fall: 4
# Shapefile for GTM: Turb_ntu for year 2016 and season Fall has been saved as SHP_GTM_Turb_ntu_2016_Fall.shp
# Number of data rows for GTM, T_c, 2016, Fall: 8
# Shapefile for GTM: T_c for year 2016 and season Fall has been saved as SHP_GTM_T_c_2016_Fall.shp
# Number of data rows for GTM, DO_mgl, 2016, Spring: 8
# Shapefile for GTM: DO_mgl for year 2016 and season Spring has been saved as SHP_GTM_DO_mgl_2016_Spring.shp
# Number of data rows for GTM, Sal_ppt, 2016, Spring: 4
# Shapefile for GTM: Sal_ppt for year 2016 and season Spring has been saved as SHP_GTM_Sal_ppt_2016_Spring.shp
# No valid data found for area: GTM, parameter: Secc_m, year: 2016, and season: Spring
# No valid data found for area: GTM, parameter: TN_mgl, year: 2016, and season: Spring
# Number of data rows for GTM, Turb_ntu, 2016, Spring: 4
# Shapefile for GTM: Turb_ntu for year 2016 and season Spring has been saved as SHP_GTM_Turb_ntu_2016_Spring.shp
# Number of data rows for GTM, T_c, 2016, Spring: 8
# Shapefile for GTM: T_c for year 2016 and season Spring has been saved as SHP_GTM_T_c_2016_Spring.shp
# Number of data rows for GTM, DO_mgl, 2016, Summer: 8
# Shapefile for GTM: DO_mgl for year 2016 and season Summer has been saved as SHP_GTM_DO_mgl_2016_Summer.shp
# Number of data rows for GTM, Sal_ppt, 2016, Summer: 4
# Shapefile for GTM: Sal_ppt for year 2016 and season Summer has been saved as SHP_GTM_Sal_ppt_2016_Summer.shp
# No valid data found for area: GTM, parameter: Secc_m, year: 2016, and season: Summer
# No valid data found for area: GTM, parameter: TN_mgl, year: 2016, and season: Summer
# Number of data rows for GTM, Turb_ntu, 2016, Summer: 4
# Shapefile for GTM: Turb_ntu for year 2016 and season Summer has been saved as SHP_GTM_Turb_ntu_2016_Summer.shp
# Number of data rows for GTM, T_c, 2016, Summer: 8
# Shapefile for GTM: T_c for year 2016 and season Summer has been saved as SHP_GTM_T_c_2016_Summer.shp
# Number of data rows for GTM, DO_mgl, 2016, Winter: 8
# Shapefile for GTM: DO_mgl for year 2016 and season Winter has been saved as SHP_GTM_DO_mgl_2016_Winter.shp
# Number of data rows for GTM, Sal_ppt, 2016, Winter: 4
# Shapefile for GTM: Sal_ppt for year 2016 and season Winter has been saved as SHP_GTM_Sal_ppt_2016_Winter.shp
# No valid data found for area: GTM, parameter: Secc_m, year: 2016, and season: Winter
# No valid data found for area: GTM, parameter: TN_mgl, year: 2016, and season: Winter
# Number of data rows for GTM, Turb_ntu, 2016, Winter: 4
# Shapefile for GTM: Turb_ntu for year 2016 and season Winter has been saved as SHP_GTM_Turb_ntu_2016_Winter.shp
# Number of data rows for GTM, T_c, 2016, Winter: 8
# Shapefile for GTM: T_c for year 2016 and season Winter has been saved as SHP_GTM_T_c_2016_Winter.shp
# Number of data rows for GTM, DO_mgl, 2017, Spring: 8
# Shapefile for GTM: DO_mgl for year 2017 and season Spring has been saved as SHP_GTM_DO_mgl_2017_Spring.shp
# Number of data rows for GTM, Sal_ppt, 2017, Spring: 4
# Shapefile for GTM: Sal_ppt for year 2017 and season Spring has been saved as SHP_GTM_Sal_ppt_2017_Spring.shp
# No valid data found for area: GTM, parameter: Secc_m, year: 2017, and season: Spring
# No valid data found for area: GTM, parameter: TN_mgl, year: 2017, and season: Spring
# Number of data rows for GTM, Turb_ntu, 2017, Spring: 4
# Shapefile for GTM: Turb_ntu for year 2017 and season Spring has been saved as SHP_GTM_Turb_ntu_2017_Spring.shp
# Number of data rows for GTM, T_c, 2017, Spring: 8
# Shapefile for GTM: T_c for year 2017 and season Spring has been saved as SHP_GTM_T_c_2017_Spring.shp
# Number of data rows for GTM, DO_mgl, 2017, Summer: 15
# Shapefile for GTM: DO_mgl for year 2017 and season Summer has been saved as SHP_GTM_DO_mgl_2017_Summer.shp
# Number of data rows for GTM, Sal_ppt, 2017, Summer: 16
# Shapefile for GTM: Sal_ppt for year 2017 and season Summer has been saved as SHP_GTM_Sal_ppt_2017_Summer.shp
# Number of data rows for GTM, Secc_m, 2017, Summer: 9
# Shapefile for GTM: Secc_m for year 2017 and season Summer has been saved as SHP_GTM_Secc_m_2017_Summer.shp
# Number of data rows for GTM, TN_mgl, 2017, Summer: 13
# Shapefile for GTM: TN_mgl for year 2017 and season Summer has been saved as SHP_GTM_TN_mgl_2017_Summer.shp
# Number of data rows for GTM, Turb_ntu, 2017, Summer: 4
# Shapefile for GTM: Turb_ntu for year 2017 and season Summer has been saved as SHP_GTM_Turb_ntu_2017_Summer.shp
# Number of data rows for GTM, T_c, 2017, Summer: 17
# Shapefile for GTM: T_c for year 2017 and season Summer has been saved as SHP_GTM_T_c_2017_Summer.shp

# %% [markdown]
# # 3. Regression Kriging for both continuous and discrete data<a class="anchor" id="rk_all"></a>
#
# ## Loop for all parameters

# %% [markdown]
# ### Clean the output folder

# %%
out_raster_floder = gis_path + "raster_output_rk/"
out_ga_folder     = gis_path + "ga_output_rk/"
diagnostic_folder = gis_path + "diagnostic_rk/"
RK.delete_all_files(out_raster_floder)
RK.delete_all_files(out_ga_folder)
RK.delete_all_files(diagnostic_folder)

# %%
seasons_all.iloc[1]
# Out:
# WaterBody        Guana Tolomato Matanzas
# Year                                2015
# Season                            Winter
# Parameter                 Total Nitrogen
# Filename                             NaN
# NumDataPoints                          0
# RMSE                                 NaN
# ME                                   NaN
# Name: 1, dtype: object

# %%
# Write the output in a csv file
with open(gis_path+"result_RK_all.csv", 'w', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    # Write the header line
    cols = list(seasons_all.columns)
    cols.append('covariates')
    csv_writer.writerow(cols)
    
    for i in seasons_all.index:
    #for i in range(42,48):
        s_time =time.time() 
        process,rmse,me,count,file_loc = RK.rk_interpolation(method = "rk",
                                           folder_path = gis_path,
                                           waterbody = area_shortnames[seasons_all.iloc[i]["WaterBody"]],
                                           parameter = param_shortnames[seasons_all.iloc[i]["Parameter"]],
                                           year      = seasons_all.iloc[i]["Year"],
                                           season    = seasons_all.iloc[i]['Season'],
                                           covariates= covariates_dict[area_shortnames[seasons_all.iloc[i]["WaterBody"]]],
                                           out_raster_folder = out_raster_floder,
                                           out_ga_folder     = out_ga_folder,
                                           diagnostic_folder = diagnostic_folder)
        e_time =time.time()

        print(f"{int(e_time-s_time)} seconds elapsed for processing {count} points in {i}th row: RMSE: {rmse}, ME: {me}, file exported to {file_loc}")
        csv_writer.writerow([seasons_all.iloc[i]["WaterBody"], 
                             seasons_all.iloc[i]["Year"],
                             seasons_all.iloc[i]['Season'],
                             param_shortnames[seasons_all.iloc[i]["Parameter"]],
                             file_loc, count, rmse, me,
                             covariates_dict[area_shortnames[seasons_all.iloc[i]["WaterBody"]]]])
        if i%10 == 0: csvfile.flush() # flush the csv file in every 20 rows.
#         seasons_all['RMSE'][i:i+1] = rmse
#         seasons_all['ME'][i:i+1] = me
#         seasons_all['NumDataPoints'][i:i+1] = count
#         seasons_all['Filename'][i:i+1] = file_loc
#     seasons_all.to_csv(gis_path+"result_RK_all.csv")
# Out:
# No data for RK interpolation in SHP_GTM_TN_mgl_2015_Fall.shp, skipping
# 0 seconds elapsed for processing 0 points in 0th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_GTM_TN_mgl_2015_Winter.shp, skipping
# 0 seconds elapsed for processing 0 points in 1th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_GTM_TN_mgl_2016_Spring.shp, skipping
# 0 seconds elapsed for processing 0 points in 2th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_GTM_TN_mgl_2016_Summer.shp, skipping
# 0 seconds elapsed for processing 0 points in 3th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_GTM_TN_mgl_2016_Fall.shp, skipping
# 0 seconds elapsed for processing 0 points in 4th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_GTM_TN_mgl_2016_Winter.shp, skipping
# 0 seconds elapsed for processing 0 points in 5th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_GTM_TN_mgl_2017_Spring.shp, skipping
# 0 seconds elapsed for processing 0 points in 6th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_GTM_TN_mgl_2017_Summer.shp
# --- Time lapse: 30.121296882629395 seconds ---
# 30 seconds elapsed for processing 13 points in 7th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/GTM_TN_mgl_2017_Summer_RK.tif
# No data for RK interpolation in SHP_EB_TN_mgl_2016_Summer.shp, skipping
# 0 seconds elapsed for processing 0 points in 8th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_EB_TN_mgl_2016_Fall.shp, skipping
# 0 seconds elapsed for processing 0 points in 9th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_EB_TN_mgl_2016_Winter.shp, skipping
# 0 seconds elapsed for processing 0 points in 10th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_EB_TN_mgl_2017_Spring.shp, skipping
# 0 seconds elapsed for processing 0 points in 11th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_EB_TN_mgl_2017_Summer.shp, skipping
# 0 seconds elapsed for processing 0 points in 12th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_EB_TN_mgl_2017_Fall.shp, skipping
# 0 seconds elapsed for processing 0 points in 13th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_EB_TN_mgl_2017_Winter.shp, skipping
# 0 seconds elapsed for processing 0 points in 14th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_EB_TN_mgl_2018_Spring.shp
# --- Time lapse: 36.983463287353516 seconds ---
# 37 seconds elapsed for processing 27 points in 15th row: RMSE: 0.107226165985, ME: 0.0076019081258, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/EB_TN_mgl_2018_Spring_RK.tif
# No data for RK interpolation in SHP_CH_TN_mgl_2016_Summer.shp, skipping
# 0 seconds elapsed for processing 0 points in 16th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_CH_TN_mgl_2016_Fall.shp, skipping
# 0 seconds elapsed for processing 0 points in 17th row: RMSE: nan, ME: nan, file exported to nan
# TN_mgl in 2016 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 8 points in 18th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_CH_TN_mgl_2017_Spring.shp, skipping
# 0 seconds elapsed for processing 0 points in 19th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_CH_TN_mgl_2017_Summer.shp, skipping
# 0 seconds elapsed for processing 0 points in 20th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_CH_TN_mgl_2017_Fall.shp, skipping
# 0 seconds elapsed for processing 0 points in 21th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_CH_TN_mgl_2017_Winter.shp, skipping
# 0 seconds elapsed for processing 0 points in 22th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_CH_TN_mgl_2018_Spring.shp
# --- Time lapse: 513.7819979190826 seconds ---
# 513 seconds elapsed for processing 49 points in 23th row: RMSE: 0.126518603256, ME: -0.00107738970384, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/CH_TN_mgl_2018_Spring_RK.tif
# Processing file: SHP_BB_TN_mgl_2021_Summer.shp
# --- Time lapse: 212.31624603271484 seconds ---
# 212 seconds elapsed for processing 76 points in 24th row: RMSE: 0.258688501723, ME: 0.00842321884073, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_TN_mgl_2021_Summer_RK.tif
# Processing file: SHP_BB_TN_mgl_2021_Fall.shp
# --- Time lapse: 207.54073643684387 seconds ---
# 207 seconds elapsed for processing 78 points in 25th row: RMSE: 0.229371678108, ME: 0.00709232554532, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_TN_mgl_2021_Fall_RK.tif
# Processing file: SHP_BB_TN_mgl_2021_Winter.shp
# --- Time lapse: 211.87415099143982 seconds ---
# 211 seconds elapsed for processing 80 points in 26th row: RMSE: 0.221435945023, ME: 0.00515407700761, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_TN_mgl_2021_Winter_RK.tif
# Processing file: SHP_BB_TN_mgl_2022_Spring.shp
# --- Time lapse: 95.53472423553467 seconds ---
# 95 seconds elapsed for processing 34 points in 27th row: RMSE: 0.160780950078, ME: -0.00431201633062, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_TN_mgl_2022_Spring_RK.tif
# Processing file: SHP_BB_TN_mgl_2022_Summer.shp
# --- Time lapse: 163.45694398880005 seconds ---
# 163 seconds elapsed for processing 57 points in 28th row: RMSE: 0.151362581863, ME: -0.00554157563033, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_TN_mgl_2022_Summer_RK.tif
# Processing file: SHP_BB_TN_mgl_2022_Fall.shp
# --- Time lapse: 115.19234871864319 seconds ---
# 115 seconds elapsed for processing 58 points in 29th row: RMSE: 0.173730291033, ME: -0.0131389661283, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_TN_mgl_2022_Fall_RK.tif
# Processing file: SHP_BB_TN_mgl_2022_Winter.shp
# --- Time lapse: 147.23620557785034 seconds ---
# 147 seconds elapsed for processing 53 points in 30th row: RMSE: 0.109351222331, ME: -0.00425372464731, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_TN_mgl_2022_Winter_RK.tif
# Processing file: SHP_BB_TN_mgl_2023_Spring.shp
# --- Time lapse: 69.66054606437683 seconds ---
# 69 seconds elapsed for processing 23 points in 31th row: RMSE: 0.0578996607282, ME: -0.00492869897804, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_TN_mgl_2023_Spring_RK.tif
# Processing file: SHP_BBS_TN_mgl_2020_Summer.shp
# --- Time lapse: 137.88986992835999 seconds ---
# 137 seconds elapsed for processing 21 points in 32th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_TN_mgl_2020_Summer_RK.tif
# Processing file: SHP_BBS_TN_mgl_2020_Fall.shp
# --- Time lapse: 182.97012424468994 seconds ---
# 183 seconds elapsed for processing 23 points in 33th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_TN_mgl_2020_Fall_RK.tif
# Processing file: SHP_BBS_TN_mgl_2020_Winter.shp
# --- Time lapse: 274.01035809516907 seconds ---
# 274 seconds elapsed for processing 32 points in 34th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_TN_mgl_2020_Winter_RK.tif
# Processing file: SHP_BBS_TN_mgl_2021_Spring.shp
# --- Time lapse: 313.7937259674072 seconds ---
# 313 seconds elapsed for processing 35 points in 35th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_TN_mgl_2021_Spring_RK.tif
# Processing file: SHP_BBS_TN_mgl_2021_Summer.shp
# --- Time lapse: 306.7210075855255 seconds ---
# 306 seconds elapsed for processing 28 points in 36th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_TN_mgl_2021_Summer_RK.tif
# Processing file: SHP_BBS_TN_mgl_2021_Fall.shp
# --- Time lapse: 294.26614809036255 seconds ---
# 294 seconds elapsed for processing 33 points in 37th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_TN_mgl_2021_Fall_RK.tif
# Processing file: SHP_BBS_TN_mgl_2021_Winter.shp
# --- Time lapse: 323.93779587745667 seconds ---
# 324 seconds elapsed for processing 31 points in 38th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_TN_mgl_2021_Winter_RK.tif
# Processing file: SHP_BBS_TN_mgl_2022_Spring.shp
# --- Time lapse: 156.80019235610962 seconds ---
# 156 seconds elapsed for processing 25 points in 39th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_TN_mgl_2022_Spring_RK.tif
# Sal_ppt in 2015 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 8 points in 40th row: RMSE: nan, ME: nan, file exported to nan
# Sal_ppt in 2015 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 7 points in 41th row: RMSE: nan, ME: nan, file exported to nan
# Sal_ppt in 2016 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 4 points in 42th row: RMSE: nan, ME: nan, file exported to nan
# Sal_ppt in 2016 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 4 points in 43th row: RMSE: nan, ME: nan, file exported to nan
# Sal_ppt in 2016 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 5 points in 44th row: RMSE: nan, ME: nan, file exported to nan
# Sal_ppt in 2016 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 4 points in 45th row: RMSE: nan, ME: nan, file exported to nan
# Sal_ppt in 2017 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 4 points in 46th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_GTM_Sal_ppt_2017_Summer.shp
# --- Time lapse: 36.34315896034241 seconds ---
# 36 seconds elapsed for processing 16 points in 47th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/GTM_Sal_ppt_2017_Summer_RK.tif
# Sal_ppt in 2016 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 48th row: RMSE: nan, ME: nan, file exported to nan
# Sal_ppt in 2016 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 49th row: RMSE: nan, ME: nan, file exported to nan
# Sal_ppt in 2016 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 50th row: RMSE: nan, ME: nan, file exported to nan
# Sal_ppt in 2017 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 51th row: RMSE: nan, ME: nan, file exported to nan
# Sal_ppt in 2017 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 52th row: RMSE: nan, ME: nan, file exported to nan
# Sal_ppt in 2017 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 53th row: RMSE: nan, ME: nan, file exported to nan
# Sal_ppt in 2017 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 54th row: RMSE: nan, ME: nan, file exported to nan
# Sal_ppt in 2018 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 55th row: RMSE: nan, ME: nan, file exported to nan
# Sal_ppt in 2016 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 56th row: RMSE: nan, ME: nan, file exported to nan
# Sal_ppt in 2016 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 57th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_CH_Sal_ppt_2016_Winter.shp
# --- Time lapse: 134.7788369655609 seconds ---
# 134 seconds elapsed for processing 11 points in 58th row: RMSE: 3.03728840113, ME: 0.183961394513, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/CH_Sal_ppt_2016_Winter_RK.tif
# Sal_ppt in 2017 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 59th row: RMSE: nan, ME: nan, file exported to nan
# Sal_ppt in 2017 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 60th row: RMSE: nan, ME: nan, file exported to nan
# Sal_ppt in 2017 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 61th row: RMSE: nan, ME: nan, file exported to nan
# Sal_ppt in 2017 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 62th row: RMSE: nan, ME: nan, file exported to nan
# Sal_ppt in 2018 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 63th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_BB_Sal_ppt_2021_Summer.shp
# --- Time lapse: 86.32694602012634 seconds ---
# 86 seconds elapsed for processing 61 points in 64th row: RMSE: 5.35214750159, ME: 0.65856344665, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_Sal_ppt_2021_Summer_RK.tif
# Processing file: SHP_BB_Sal_ppt_2021_Fall.shp
# --- Time lapse: 112.26880860328674 seconds ---
# 112 seconds elapsed for processing 63 points in 65th row: RMSE: 4.48798173419, ME: -0.131137604467, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_Sal_ppt_2021_Fall_RK.tif
# Processing file: SHP_BB_Sal_ppt_2021_Winter.shp
# --- Time lapse: 165.03913617134094 seconds ---
# 165 seconds elapsed for processing 62 points in 66th row: RMSE: 6.17075906639, ME: 0.0193811514781, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_Sal_ppt_2021_Winter_RK.tif
# Processing file: SHP_BB_Sal_ppt_2022_Spring.shp
# --- Time lapse: 76.74844813346863 seconds ---
# 76 seconds elapsed for processing 47 points in 67th row: RMSE: 5.41453045563, ME: 0.441257311999, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_Sal_ppt_2022_Spring_RK.tif
# Processing file: SHP_BB_Sal_ppt_2022_Summer.shp
# --- Time lapse: 82.76739430427551 seconds ---
# 82 seconds elapsed for processing 48 points in 68th row: RMSE: 3.83263798067, ME: 0.458672273308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_Sal_ppt_2022_Summer_RK.tif
# Processing file: SHP_BB_Sal_ppt_2022_Fall.shp
# --- Time lapse: 85.44923520088196 seconds ---
# 85 seconds elapsed for processing 50 points in 69th row: RMSE: 3.81649699363, ME: 0.209299748564, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_Sal_ppt_2022_Fall_RK.tif
# Processing file: SHP_BB_Sal_ppt_2022_Winter.shp
# --- Time lapse: 134.27708220481873 seconds ---
# 134 seconds elapsed for processing 50 points in 70th row: RMSE: 3.72300308158, ME: 0.224682961631, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_Sal_ppt_2022_Winter_RK.tif
# Processing file: SHP_BB_Sal_ppt_2023_Spring.shp
# --- Time lapse: 79.7324607372284 seconds ---
# 79 seconds elapsed for processing 48 points in 71th row: RMSE: 3.34391301569, ME: 0.248323914762, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_Sal_ppt_2023_Spring_RK.tif
# Processing file: SHP_BBS_Sal_ppt_2020_Summer.shp
# --- Time lapse: 158.536390542984 seconds ---
# 158 seconds elapsed for processing 20 points in 72th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Sal_ppt_2020_Summer_RK.tif
# Processing file: SHP_BBS_Sal_ppt_2020_Fall.shp
# --- Time lapse: 158.99813532829285 seconds ---
# 159 seconds elapsed for processing 21 points in 73th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Sal_ppt_2020_Fall_RK.tif
# Processing file: SHP_BBS_Sal_ppt_2020_Winter.shp
# --- Time lapse: 295.49718713760376 seconds ---
# 295 seconds elapsed for processing 32 points in 74th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Sal_ppt_2020_Winter_RK.tif
# Processing file: SHP_BBS_Sal_ppt_2021_Spring.shp
# --- Time lapse: 304.40235781669617 seconds ---
# 304 seconds elapsed for processing 33 points in 75th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Sal_ppt_2021_Spring_RK.tif
# Processing file: SHP_BBS_Sal_ppt_2021_Summer.shp
# --- Time lapse: 297.0558795928955 seconds ---
# 297 seconds elapsed for processing 28 points in 76th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Sal_ppt_2021_Summer_RK.tif
# Processing file: SHP_BBS_Sal_ppt_2021_Fall.shp
# --- Time lapse: 290.1253125667572 seconds ---
# 290 seconds elapsed for processing 29 points in 77th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Sal_ppt_2021_Fall_RK.tif
# Processing file: SHP_BBS_Sal_ppt_2021_Winter.shp
# --- Time lapse: 298.2176070213318 seconds ---
# 298 seconds elapsed for processing 32 points in 78th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Sal_ppt_2021_Winter_RK.tif
# Processing file: SHP_BBS_Sal_ppt_2022_Spring.shp
# --- Time lapse: 154.33135175704956 seconds ---
# 154 seconds elapsed for processing 16 points in 79th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Sal_ppt_2022_Spring_RK.tif
# DO_mgl in 2015 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 8 points in 80th row: RMSE: nan, ME: nan, file exported to nan
# DO_mgl in 2015 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 7 points in 81th row: RMSE: nan, ME: nan, file exported to nan
# DO_mgl in 2016 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 8 points in 82th row: RMSE: nan, ME: nan, file exported to nan
# DO_mgl in 2016 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 8 points in 83th row: RMSE: nan, ME: nan, file exported to nan
# DO_mgl in 2016 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 8 points in 84th row: RMSE: nan, ME: nan, file exported to nan
# DO_mgl in 2016 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 8 points in 85th row: RMSE: nan, ME: nan, file exported to nan
# DO_mgl in 2017 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 8 points in 86th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_GTM_DO_mgl_2017_Summer.shp
# --- Time lapse: 38.10535264015198 seconds ---
# 38 seconds elapsed for processing 15 points in 87th row: RMSE: 2.60682726527, ME: -0.222469564088, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/GTM_DO_mgl_2017_Summer_RK.tif
# DO_mgl in 2016 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 88th row: RMSE: nan, ME: nan, file exported to nan
# DO_mgl in 2016 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 89th row: RMSE: nan, ME: nan, file exported to nan
# DO_mgl in 2016 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 90th row: RMSE: nan, ME: nan, file exported to nan
# DO_mgl in 2017 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 91th row: RMSE: nan, ME: nan, file exported to nan
# DO_mgl in 2017 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 92th row: RMSE: nan, ME: nan, file exported to nan
# DO_mgl in 2017 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 93th row: RMSE: nan, ME: nan, file exported to nan
# DO_mgl in 2017 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 94th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_EB_DO_mgl_2018_Spring.shp
# --- Time lapse: 34.851032972335815 seconds ---
# 34 seconds elapsed for processing 27 points in 95th row: RMSE: 0.475260881394, ME: -0.00982405948897, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/EB_DO_mgl_2018_Spring_RK.tif
# DO_mgl in 2016 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 96th row: RMSE: nan, ME: nan, file exported to nan
# DO_mgl in 2016 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 97th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_CH_DO_mgl_2016_Winter.shp
# --- Time lapse: 135.8546051979065 seconds ---
# 135 seconds elapsed for processing 11 points in 98th row: RMSE: 0.543622308691, ME: 0.0317388142186, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/CH_DO_mgl_2016_Winter_RK.tif
# DO_mgl in 2017 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 99th row: RMSE: nan, ME: nan, file exported to nan
# DO_mgl in 2017 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 100th row: RMSE: nan, ME: nan, file exported to nan
# DO_mgl in 2017 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 101th row: RMSE: nan, ME: nan, file exported to nan
# DO_mgl in 2017 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 102th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_CH_DO_mgl_2018_Spring.shp
# --- Time lapse: 338.3436236381531 seconds ---
# 338 seconds elapsed for processing 36 points in 103th row: RMSE: 0.698904322061, ME: -0.0640475843972, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/CH_DO_mgl_2018_Spring_RK.tif
# Processing file: SHP_BB_DO_mgl_2021_Summer.shp
# --- Time lapse: 209.3016073703766 seconds ---
# 209 seconds elapsed for processing 83 points in 104th row: RMSE: 1.08321746126, ME: 0.000895091565736, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_DO_mgl_2021_Summer_RK.tif
# Processing file: SHP_BB_DO_mgl_2021_Fall.shp
# --- Time lapse: 223.28926277160645 seconds ---
# 223 seconds elapsed for processing 83 points in 105th row: RMSE: 0.815418489492, ME: -0.0108528215578, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_DO_mgl_2021_Fall_RK.tif
# Processing file: SHP_BB_DO_mgl_2021_Winter.shp
# --- Time lapse: 226.5128972530365 seconds ---
# 226 seconds elapsed for processing 85 points in 106th row: RMSE: 1.17989351095, ME: -0.0016154172846, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_DO_mgl_2021_Winter_RK.tif
# Processing file: SHP_BB_DO_mgl_2022_Spring.shp
# --- Time lapse: 112.63246297836304 seconds ---
# 112 seconds elapsed for processing 45 points in 107th row: RMSE: 0.870721182104, ME: 0.0127986271153, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_DO_mgl_2022_Spring_RK.tif
# Processing file: SHP_BB_DO_mgl_2022_Summer.shp
# --- Time lapse: 188.7333927154541 seconds ---
# 188 seconds elapsed for processing 69 points in 108th row: RMSE: 0.892753064926, ME: 0.0577357124916, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_DO_mgl_2022_Summer_RK.tif
# Processing file: SHP_BB_DO_mgl_2022_Fall.shp
# --- Time lapse: 188.5658118724823 seconds ---
# 188 seconds elapsed for processing 68 points in 109th row: RMSE: 0.870556528522, ME: -0.0136880589249, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_DO_mgl_2022_Fall_RK.tif
# Processing file: SHP_BB_DO_mgl_2022_Winter.shp
# --- Time lapse: 167.9737515449524 seconds ---
# 168 seconds elapsed for processing 64 points in 110th row: RMSE: 0.735034019099, ME: 0.0218232849875, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_DO_mgl_2022_Winter_RK.tif
# Processing file: SHP_BB_DO_mgl_2023_Spring.shp
# --- Time lapse: 142.8617594242096 seconds ---
# 142 seconds elapsed for processing 54 points in 111th row: RMSE: 1.20394148389, ME: 0.0571786983335, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_DO_mgl_2023_Spring_RK.tif
# Processing file: SHP_BBS_DO_mgl_2020_Summer.shp
# --- Time lapse: 178.19801378250122 seconds ---
# 178 seconds elapsed for processing 26 points in 112th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_DO_mgl_2020_Summer_RK.tif
# Processing file: SHP_BBS_DO_mgl_2020_Fall.shp
# --- Time lapse: 174.8214361667633 seconds ---
# 174 seconds elapsed for processing 26 points in 113th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_DO_mgl_2020_Fall_RK.tif
# Processing file: SHP_BBS_DO_mgl_2020_Winter.shp
# --- Time lapse: 294.63063073158264 seconds ---
# 294 seconds elapsed for processing 34 points in 114th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_DO_mgl_2020_Winter_RK.tif
# Processing file: SHP_BBS_DO_mgl_2021_Spring.shp
# --- Time lapse: 297.6178674697876 seconds ---
# 297 seconds elapsed for processing 44 points in 115th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_DO_mgl_2021_Spring_RK.tif
# Processing file: SHP_BBS_DO_mgl_2021_Summer.shp
# --- Time lapse: 294.5727264881134 seconds ---
# 294 seconds elapsed for processing 37 points in 116th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_DO_mgl_2021_Summer_RK.tif
# Processing file: SHP_BBS_DO_mgl_2021_Fall.shp
# --- Time lapse: 311.8365852832794 seconds ---
# 311 seconds elapsed for processing 38 points in 117th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_DO_mgl_2021_Fall_RK.tif
# Processing file: SHP_BBS_DO_mgl_2021_Winter.shp
# --- Time lapse: 302.2405970096588 seconds ---
# 302 seconds elapsed for processing 39 points in 118th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_DO_mgl_2021_Winter_RK.tif
# Processing file: SHP_BBS_DO_mgl_2022_Spring.shp
# --- Time lapse: 215.33910942077637 seconds ---
# 215 seconds elapsed for processing 29 points in 119th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_DO_mgl_2022_Spring_RK.tif
# Turb_ntu in 2015 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 4 points in 120th row: RMSE: nan, ME: nan, file exported to nan
# Turb_ntu in 2015 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 4 points in 121th row: RMSE: nan, ME: nan, file exported to nan
# Turb_ntu in 2016 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 4 points in 122th row: RMSE: nan, ME: nan, file exported to nan
# Turb_ntu in 2016 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 4 points in 123th row: RMSE: nan, ME: nan, file exported to nan
# Turb_ntu in 2016 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 4 points in 124th row: RMSE: nan, ME: nan, file exported to nan
# Turb_ntu in 2016 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 4 points in 125th row: RMSE: nan, ME: nan, file exported to nan
# Turb_ntu in 2017 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 4 points in 126th row: RMSE: nan, ME: nan, file exported to nan
# Turb_ntu in 2017 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 4 points in 127th row: RMSE: nan, ME: nan, file exported to nan
# Turb_ntu in 2016 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 128th row: RMSE: nan, ME: nan, file exported to nan
# Turb_ntu in 2016 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 2 points in 129th row: RMSE: nan, ME: nan, file exported to nan
# Turb_ntu in 2016 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 130th row: RMSE: nan, ME: nan, file exported to nan
# Turb_ntu in 2017 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 131th row: RMSE: nan, ME: nan, file exported to nan
# Turb_ntu in 2017 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 132th row: RMSE: nan, ME: nan, file exported to nan
# Turb_ntu in 2017 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 133th row: RMSE: nan, ME: nan, file exported to nan
# Turb_ntu in 2017 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 134th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_EB_Turb_ntu_2018_Spring.shp
# --- Time lapse: 39.64551115036011 seconds ---
# 39 seconds elapsed for processing 30 points in 135th row: RMSE: 1.49053900674, ME: 0.0388944796704, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/EB_Turb_ntu_2018_Spring_RK.tif
# Turb_ntu in 2016 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 136th row: RMSE: nan, ME: nan, file exported to nan
# Turb_ntu in 2016 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 137th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_CH_Turb_ntu_2016_Winter.shp
# --- Time lapse: 129.1493616104126 seconds ---
# 129 seconds elapsed for processing 11 points in 138th row: RMSE: 0.874655832881, ME: -0.244893697436, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/CH_Turb_ntu_2016_Winter_RK.tif
# Turb_ntu in 2017 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 139th row: RMSE: nan, ME: nan, file exported to nan
# Turb_ntu in 2017 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 140th row: RMSE: nan, ME: nan, file exported to nan
# Turb_ntu in 2017 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 141th row: RMSE: nan, ME: nan, file exported to nan
# Turb_ntu in 2017 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 142th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_CH_Turb_ntu_2018_Spring.shp
# --- Time lapse: 126.16027784347534 seconds ---
# 126 seconds elapsed for processing 52 points in 143th row: RMSE: 13.0686359763, ME: -0.697055298247, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/CH_Turb_ntu_2018_Spring_RK.tif
# Processing file: SHP_BB_Turb_ntu_2021_Summer.shp
# --- Time lapse: 161.59596371650696 seconds ---
# 161 seconds elapsed for processing 61 points in 144th row: RMSE: 1.41492707667, ME: -0.0260620347921, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_Turb_ntu_2021_Summer_RK.tif
# Processing file: SHP_BB_Turb_ntu_2021_Fall.shp
# --- Time lapse: 114.02951979637146 seconds ---
# 114 seconds elapsed for processing 62 points in 145th row: RMSE: 2.02563335369, ME: 0.0487513208508, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_Turb_ntu_2021_Fall_RK.tif
# Processing file: SHP_BB_Turb_ntu_2021_Winter.shp
# --- Time lapse: 102.22889518737793 seconds ---
# 102 seconds elapsed for processing 61 points in 146th row: RMSE: 2.31528502869, ME: -0.131326555124, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_Turb_ntu_2021_Winter_RK.tif
# Processing file: SHP_BB_Turb_ntu_2022_Spring.shp
# --- Time lapse: 111.77948927879333 seconds ---
# 111 seconds elapsed for processing 46 points in 147th row: RMSE: 1.87150742163, ME: 0.0962259726208, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_Turb_ntu_2022_Spring_RK.tif
# Processing file: SHP_BB_Turb_ntu_2022_Summer.shp
# --- Time lapse: 119.35028791427612 seconds ---
# 119 seconds elapsed for processing 49 points in 148th row: RMSE: 1.56405089698, ME: -0.0681558719688, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_Turb_ntu_2022_Summer_RK.tif
# Processing file: SHP_BB_Turb_ntu_2022_Fall.shp
# --- Time lapse: 133.4976179599762 seconds ---
# 133 seconds elapsed for processing 50 points in 149th row: RMSE: 1.13995231662, ME: -0.0253894899922, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_Turb_ntu_2022_Fall_RK.tif
# Processing file: SHP_BB_Turb_ntu_2022_Winter.shp
# --- Time lapse: 126.25686883926392 seconds ---
# 126 seconds elapsed for processing 50 points in 150th row: RMSE: 0.907392462886, ME: -0.000383436978117, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_Turb_ntu_2022_Winter_RK.tif
# Processing file: SHP_BB_Turb_ntu_2023_Spring.shp
# --- Time lapse: 86.67822027206421 seconds ---
# 86 seconds elapsed for processing 35 points in 151th row: RMSE: 1.42851702915, ME: -0.00165927818006, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_Turb_ntu_2023_Spring_RK.tif
# Processing file: SHP_BBS_Turb_ntu_2020_Summer.shp
# --- Time lapse: 175.03097558021545 seconds ---
# 175 seconds elapsed for processing 25 points in 152th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Turb_ntu_2020_Summer_RK.tif
# Processing file: SHP_BBS_Turb_ntu_2020_Fall.shp
# --- Time lapse: 167.0335202217102 seconds ---
# 167 seconds elapsed for processing 26 points in 153th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Turb_ntu_2020_Fall_RK.tif
# Processing file: SHP_BBS_Turb_ntu_2020_Winter.shp
# --- Time lapse: 272.1831841468811 seconds ---
# 272 seconds elapsed for processing 35 points in 154th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Turb_ntu_2020_Winter_RK.tif
# Processing file: SHP_BBS_Turb_ntu_2021_Spring.shp
# --- Time lapse: 274.4380648136139 seconds ---
# 274 seconds elapsed for processing 37 points in 155th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Turb_ntu_2021_Spring_RK.tif
# Processing file: SHP_BBS_Turb_ntu_2021_Summer.shp
# --- Time lapse: 163.4456479549408 seconds ---
# 163 seconds elapsed for processing 30 points in 156th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Turb_ntu_2021_Summer_RK.tif
# Processing file: SHP_BBS_Turb_ntu_2021_Fall.shp
# --- Time lapse: 267.0979881286621 seconds ---
# 267 seconds elapsed for processing 34 points in 157th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Turb_ntu_2021_Fall_RK.tif
# Processing file: SHP_BBS_Turb_ntu_2021_Winter.shp
# --- Time lapse: 303.44953513145447 seconds ---
# 303 seconds elapsed for processing 35 points in 158th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Turb_ntu_2021_Winter_RK.tif
# Processing file: SHP_BBS_Turb_ntu_2022_Spring.shp
# --- Time lapse: 190.74674701690674 seconds ---
# 190 seconds elapsed for processing 28 points in 159th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Turb_ntu_2022_Spring_RK.tif
# No data for RK interpolation in SHP_GTM_Secc_m_2015_Fall.shp, skipping
# 0 seconds elapsed for processing 0 points in 160th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_GTM_Secc_m_2015_Winter.shp, skipping
# 0 seconds elapsed for processing 0 points in 161th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_GTM_Secc_m_2016_Spring.shp, skipping
# 0 seconds elapsed for processing 0 points in 162th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_GTM_Secc_m_2016_Summer.shp, skipping
# 0 seconds elapsed for processing 0 points in 163th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_GTM_Secc_m_2016_Fall.shp, skipping
# 0 seconds elapsed for processing 0 points in 164th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_GTM_Secc_m_2016_Winter.shp, skipping
# 0 seconds elapsed for processing 0 points in 165th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_GTM_Secc_m_2017_Spring.shp, skipping
# 0 seconds elapsed for processing 0 points in 166th row: RMSE: nan, ME: nan, file exported to nan
# Secc_m in 2017 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 9 points in 167th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_EB_Secc_m_2016_Summer.shp, skipping
# 0 seconds elapsed for processing 0 points in 168th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_EB_Secc_m_2016_Fall.shp, skipping
# 0 seconds elapsed for processing 0 points in 169th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_EB_Secc_m_2016_Winter.shp, skipping
# 0 seconds elapsed for processing 0 points in 170th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_EB_Secc_m_2017_Spring.shp, skipping
# 0 seconds elapsed for processing 0 points in 171th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_EB_Secc_m_2017_Summer.shp, skipping
# 0 seconds elapsed for processing 0 points in 172th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_EB_Secc_m_2017_Fall.shp, skipping
# 0 seconds elapsed for processing 0 points in 173th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_EB_Secc_m_2017_Winter.shp, skipping
# 0 seconds elapsed for processing 0 points in 174th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_EB_Secc_m_2018_Spring.shp, skipping
# 0 seconds elapsed for processing 0 points in 175th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_CH_Secc_m_2016_Summer.shp, skipping
# 0 seconds elapsed for processing 0 points in 176th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_CH_Secc_m_2016_Fall.shp, skipping
# 0 seconds elapsed for processing 0 points in 177th row: RMSE: nan, ME: nan, file exported to nan
# Secc_m in 2016 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 8 points in 178th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_CH_Secc_m_2017_Spring.shp, skipping
# 0 seconds elapsed for processing 0 points in 179th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_CH_Secc_m_2017_Summer.shp, skipping
# 0 seconds elapsed for processing 0 points in 180th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_CH_Secc_m_2017_Fall.shp, skipping
# 0 seconds elapsed for processing 0 points in 181th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_CH_Secc_m_2017_Winter.shp, skipping
# 0 seconds elapsed for processing 0 points in 182th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_CH_Secc_m_2018_Spring.shp, skipping
# 0 seconds elapsed for processing 0 points in 183th row: RMSE: nan, ME: nan, file exported to nan
# Secc_m in 2021 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 3 seconds elapsed for processing 1 points in 184th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_BB_Secc_m_2021_Fall.shp, skipping
# 0 seconds elapsed for processing 0 points in 185th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_BB_Secc_m_2021_Winter.shp, skipping
# 0 seconds elapsed for processing 0 points in 186th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_BB_Secc_m_2022_Spring.shp, skipping
# 0 seconds elapsed for processing 0 points in 187th row: RMSE: nan, ME: nan, file exported to nan
# Secc_m in 2022 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 3 seconds elapsed for processing 1 points in 188th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_BB_Secc_m_2022_Fall.shp, skipping
# 0 seconds elapsed for processing 0 points in 189th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_BB_Secc_m_2022_Winter.shp, skipping
# 0 seconds elapsed for processing 0 points in 190th row: RMSE: nan, ME: nan, file exported to nan
# No data for RK interpolation in SHP_BB_Secc_m_2023_Spring.shp, skipping
# 0 seconds elapsed for processing 0 points in 191th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_BBS_Secc_m_2020_Summer.shp
# --- Time lapse: 107.44769597053528 seconds ---
# 107 seconds elapsed for processing 24 points in 192th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Secc_m_2020_Summer_RK.tif
# Processing file: SHP_BBS_Secc_m_2020_Fall.shp
# --- Time lapse: 156.58062386512756 seconds ---
# 156 seconds elapsed for processing 27 points in 193th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Secc_m_2020_Fall_RK.tif
# Processing file: SHP_BBS_Secc_m_2020_Winter.shp
# --- Time lapse: 177.27158427238464 seconds ---
# 177 seconds elapsed for processing 30 points in 194th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Secc_m_2020_Winter_RK.tif
# Processing file: SHP_BBS_Secc_m_2021_Spring.shp
# --- Time lapse: 210.2716405391693 seconds ---
# 210 seconds elapsed for processing 38 points in 195th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Secc_m_2021_Spring_RK.tif
# Processing file: SHP_BBS_Secc_m_2021_Summer.shp
# --- Time lapse: 126.20961117744446 seconds ---
# 126 seconds elapsed for processing 29 points in 196th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Secc_m_2021_Summer_RK.tif
# Processing file: SHP_BBS_Secc_m_2021_Fall.shp
# --- Time lapse: 206.97630667686462 seconds ---
# 207 seconds elapsed for processing 31 points in 197th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Secc_m_2021_Fall_RK.tif
# Processing file: SHP_BBS_Secc_m_2021_Winter.shp
# --- Time lapse: 228.9862585067749 seconds ---
# 229 seconds elapsed for processing 32 points in 198th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Secc_m_2021_Winter_RK.tif
# Processing file: SHP_BBS_Secc_m_2022_Spring.shp
# --- Time lapse: 150.19860529899597 seconds ---
# 150 seconds elapsed for processing 28 points in 199th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_Secc_m_2022_Spring_RK.tif
# T_c in 2015 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 8 points in 200th row: RMSE: nan, ME: nan, file exported to nan
# T_c in 2015 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 7 points in 201th row: RMSE: nan, ME: nan, file exported to nan
# T_c in 2016 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 8 points in 202th row: RMSE: nan, ME: nan, file exported to nan
# T_c in 2016 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 8 points in 203th row: RMSE: nan, ME: nan, file exported to nan
# T_c in 2016 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 8 points in 204th row: RMSE: nan, ME: nan, file exported to nan
# T_c in 2016 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 8 points in 205th row: RMSE: nan, ME: nan, file exported to nan
# T_c in 2017 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 1 seconds elapsed for processing 8 points in 206th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_GTM_T_c_2017_Summer.shp
# --- Time lapse: 36.9335355758667 seconds ---
# 37 seconds elapsed for processing 17 points in 207th row: RMSE: 0.384421323149, ME: -0.0641628659705, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/GTM_T_c_2017_Summer_RK.tif
# T_c in 2016 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 208th row: RMSE: nan, ME: nan, file exported to nan
# T_c in 2016 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 209th row: RMSE: nan, ME: nan, file exported to nan
# T_c in 2016 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 210th row: RMSE: nan, ME: nan, file exported to nan
# T_c in 2017 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 211th row: RMSE: nan, ME: nan, file exported to nan
# T_c in 2017 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 212th row: RMSE: nan, ME: nan, file exported to nan
# T_c in 2017 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 213th row: RMSE: nan, ME: nan, file exported to nan
# T_c in 2017 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 0 seconds elapsed for processing 3 points in 214th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_EB_T_c_2018_Spring.shp
# --- Time lapse: 35.27595520019531 seconds ---
# 35 seconds elapsed for processing 27 points in 215th row: RMSE: 1.50532964109, ME: 0.0578306417084, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/EB_T_c_2018_Spring_RK.tif
# T_c in 2016 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 216th row: RMSE: nan, ME: nan, file exported to nan
# T_c in 2016 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 217th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_CH_T_c_2016_Winter.shp
# --- Time lapse: 130.8850610256195 seconds ---
# 131 seconds elapsed for processing 11 points in 218th row: RMSE: 0.652806594636, ME: -0.0728420521705, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/CH_T_c_2016_Winter_RK.tif
# T_c in 2017 Spring caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 219th row: RMSE: nan, ME: nan, file exported to nan
# T_c in 2017 Summer caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 220th row: RMSE: nan, ME: nan, file exported to nan
# T_c in 2017 Fall caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 221th row: RMSE: nan, ME: nan, file exported to nan
# T_c in 2017 Winter caused an error:
# ERROR 040039: Not enough data to compute method.
# Failed to execute (EBKRegressionPrediction).
#
# 4 seconds elapsed for processing 3 points in 222th row: RMSE: nan, ME: nan, file exported to nan
# Processing file: SHP_CH_T_c_2018_Spring.shp
# --- Time lapse: 345.3093020915985 seconds ---
# 345 seconds elapsed for processing 36 points in 223th row: RMSE: 3.39080204798, ME: -0.048499424185, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/CH_T_c_2018_Spring_RK.tif
# Processing file: SHP_BB_T_c_2021_Summer.shp
# --- Time lapse: 224.08558201789856 seconds ---
# 224 seconds elapsed for processing 83 points in 224th row: RMSE: 0.96811003527, ME: -0.0161342409022, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_T_c_2021_Summer_RK.tif
# Processing file: SHP_BB_T_c_2021_Fall.shp
# --- Time lapse: 215.3038592338562 seconds ---
# 215 seconds elapsed for processing 83 points in 225th row: RMSE: 1.11118297236, ME: -0.0944168547001, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_T_c_2021_Fall_RK.tif
# Processing file: SHP_BB_T_c_2021_Winter.shp
# --- Time lapse: 230.7955083847046 seconds ---
# 230 seconds elapsed for processing 85 points in 226th row: RMSE: 0.854317139098, ME: 0.0088193630648, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_T_c_2021_Winter_RK.tif
# Processing file: SHP_BB_T_c_2022_Spring.shp
# --- Time lapse: 124.2785496711731 seconds ---
# 124 seconds elapsed for processing 47 points in 227th row: RMSE: 0.509092700576, ME: -0.0101065277828, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_T_c_2022_Spring_RK.tif
# Processing file: SHP_BB_T_c_2022_Summer.shp
# --- Time lapse: 195.19838285446167 seconds ---
# 195 seconds elapsed for processing 69 points in 228th row: RMSE: 0.60710045504, ME: 0.0023090700872, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_T_c_2022_Summer_RK.tif
# Processing file: SHP_BB_T_c_2022_Fall.shp
# --- Time lapse: 184.85495448112488 seconds ---
# 184 seconds elapsed for processing 70 points in 229th row: RMSE: 1.05064896358, ME: 0.0634217728718, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_T_c_2022_Fall_RK.tif
# Processing file: SHP_BB_T_c_2022_Winter.shp
# --- Time lapse: 162.8117160797119 seconds ---
# 162 seconds elapsed for processing 66 points in 230th row: RMSE: 0.891252114571, ME: 0.0312820620533, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_T_c_2022_Winter_RK.tif
# Processing file: SHP_BB_T_c_2023_Spring.shp
# --- Time lapse: 145.96365404129028 seconds ---
# 146 seconds elapsed for processing 56 points in 231th row: RMSE: 0.981116055748, ME: 0.0131127806256, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BB_T_c_2023_Spring_RK.tif
# Processing file: SHP_BBS_T_c_2020_Summer.shp
# --- Time lapse: 170.5410647392273 seconds ---
# 170 seconds elapsed for processing 26 points in 232th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_T_c_2020_Summer_RK.tif
# Processing file: SHP_BBS_T_c_2020_Fall.shp
# --- Time lapse: 167.3575472831726 seconds ---
# 167 seconds elapsed for processing 26 points in 233th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_T_c_2020_Fall_RK.tif
# Processing file: SHP_BBS_T_c_2020_Winter.shp
# --- Time lapse: 286.2273941040039 seconds ---
# 286 seconds elapsed for processing 34 points in 234th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_T_c_2020_Winter_RK.tif
# Processing file: SHP_BBS_T_c_2021_Spring.shp
# --- Time lapse: 294.0584976673126 seconds ---
# 294 seconds elapsed for processing 44 points in 235th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_T_c_2021_Spring_RK.tif
# Processing file: SHP_BBS_T_c_2021_Summer.shp
# --- Time lapse: 249.06943368911743 seconds ---
# 249 seconds elapsed for processing 37 points in 236th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_T_c_2021_Summer_RK.tif
# Processing file: SHP_BBS_T_c_2021_Fall.shp
# --- Time lapse: 301.68009757995605 seconds ---
# 301 seconds elapsed for processing 38 points in 237th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_T_c_2021_Fall_RK.tif
# Processing file: SHP_BBS_T_c_2021_Winter.shp
# --- Time lapse: 300.27372097969055 seconds ---
# 300 seconds elapsed for processing 39 points in 238th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_T_c_2021_Winter_RK.tif
# Processing file: SHP_BBS_T_c_2022_Spring.shp
# --- Time lapse: 192.1791341304779 seconds ---
# 192 seconds elapsed for processing 27 points in 239th row: RMSE: -1.79769313486e+308, ME: -1.79769313486e+308, file exported to E:/Projects/SEACAR_WQ_2024/GIS_Data/raster_output_rk/BBS_T_c_2022_Spring_RK.tif

# %% [markdown]
# # 4. Regression Kriging for Continuous Stations<a class="anchor" id="rk_con"></a>

# %%
dfCon_orig = pd.read_csv(gis_path + "OEAT_Continuous_WQ-2024-Jan-16.csv", low_memory=False)

# %%
dfMean_con = dfCon_orig.groupby(['WaterBody','ParameterName','Year','Season','Latitude_DD','Longitude_DD'])["ResultValue"].agg("mean").reset_index()

# %%
con_shp_folder = gis_path + r"shapefiles_con"

# %%
RK.delete_all_files(con_shp_folder)

# %%
RK.create_shp_season(dfMean_con, waterbody_names, parameter_names, years, seasons, con_shp_folder)

# %%
season_con = pd.read_csv(gis_path+"Seasons_con.csv")

# %%
season_con

# %%
# If you would like to partially generate results in some rows, you could use range(a,b):
# If you would like to generate all rows automated, you could use season_result.index:

# for i in season_con.index:
for i in range(0,8):
    process,rmse,me,count,file_loc = RK.rk_interpolation(method = "rk",
                                       folder_path = gis_path,
                                       waterbody = area_shortnames[season_con.iloc[i]["WaterBody"]],
                                       parameter = param_shortnames[season_con.iloc[i]["Parameter"]],
                                       year      = season_con.iloc[i]["Year"],
                                       season    = season_con.iloc[i]['Season'],
                                       covariates= covariates_dict[area_shortnames[season_con.iloc[i]["WaterBody"]]],
                                       out_raster_folder = gis_path + "raster_output_con/",
                                       out_ga_folder     = gis_path + "ga_output_con/",
                                       diagnostic_folder = gis_path + "diagnostic_output_con/")
    print(process,rmse,me,count,file_loc)
    season_con['RMSE'][i:i+1] = rmse
    season_con['ME'][i:i+1] = me
    season_con['NumDataPoints'][i:i+1] = count
    season_con['Filename'][i:i+1] = file_loc
season_con.to_csv(gis_path+"Seasons_con.csv")
