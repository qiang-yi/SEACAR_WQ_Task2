# %% [markdown]
# # Cross Validation for IDW Interpolation
# ## Task 2A (continuous)
#
# This document includes Python codes that conduct cross validation (CV) for Inverse Distance Weighting (IDW) Interpolation on water quality parameters, including 4 water quality parameters in arcpy environment:
# - Dissolved oxygen (DO_mgl)
# - Salinity (Sal_ppt)
# - Turbidity (Turb_ntu)
# - Temperature (T_c)
#
# The analysis is conducted in the separate water bodies:
# - Guana Tolomato Matanzas (GTM)
# - Estero Bay (EB)
# - Charlotte Harbor (CH)
# - Biscayne Bay (BB)
# - Big Bend Seagrasses (BBS)
#
# **Tasks:**
#
# - Task 2A Calculate the RMSE and Mean Error (ME) for IDW results using both continuous and discrete data
#
# - **Task 2B Calculate the RMSE and Mean Error (ME) for IDW results using continuous data.**
#
#
# Time periods one year before and after storm event for Task 2A tests (seasons).
# <br>
# <div style="text-align: left;">
#     <img src="misc/TimePeriods.png" style="display: block; margin-left: 0; margin-right: auto; width: 600px;"/>
# </div>
#
# Summary of IDW and RK Accuracy Assessments.
# <br>
# <div style="text-align: left;">
#     <img src="misc/Table3.png" style="display: block; margin-left: 0; margin-right: auto; width: 600px;"/>
# </div>
#
# **Contents:**
# * [1. Data Preprocess](#reg_preprocessing)
#     * [1.1 Subsetting Dataset](#reg_subset)
#     * [1.2 Preview Dataset](#reg_preview)
#     * [1.3 Fill Unique ID](#reg_id)
# * [2. Create Shapefile](#reg_create_shp)
# * [3. Cross Validation for IDW](#reg_cv_idw)

# %%
import pandas as pd
import numpy as np
import arcpy
from arcpy.sa import *
import os
import math

import importlib
import sys
#path = r'M:\2024\WQ\Spring\IDW\git\misc'
path = r'E:\Projects\SEACAR_WQ_2024\git\misc'
sys.path.insert(0, path)
import IDW
importlib.reload(IDW)

# define scratch folder to avoid overwritting from parallel threats
arcpy.env.scratchWorkspace = r"E:\Projects\SEACAR_WQ_2024\scratch/IDW_con"

# %% [markdown]
# # 1. Data Preprocessing <a class="anchor" id="reg_preprocessing"></a>

# %%
gis_path = r'E:\Projects\SEACAR_WQ_2024/GIS_Data/'
dfCon = pd.read_csv(gis_path + 'OEAT_Continuous_WQ-2024-Jan-16.csv', low_memory=False)

# %% [markdown]
# ## 1.1 Subsetting Data <a class="anchor" id="reg_subset"></a>

# %% [markdown]
# ### Include the time period from 9 am to 17 pm in a day

# %%
dfCon['SampleDate'] = pd.to_datetime(dfCon['SampleDate'], format='%b %d %Y %I:%M%p')

# %%
# Include date from 9:00 am to 17:00 pm
start_time = '09:00'
end_time = '17:00'

dfConTime = dfCon[dfCon['SampleDate'].dt.time.between(pd.to_datetime(start_time).time(), pd.to_datetime(end_time).time())]
dfConTime.head()

# %% [markdown]
# ### Aggregate observations at the same location into an average point (continuous data)

# %%
dfCon_Mean = dfConTime.groupby(['ProgramID','WaterBody','ParameterName','ParameterUnits','ProgramLocationID', 'Year','Season','Latitude_DD','Longitude_DD','AreaID','WbodyAcronym'])["ResultValue"].agg("mean").reset_index()

# %% [markdown]
# ### Preset abbreviation for waterbody and parameter name

# %%
area_shortnames = {
    'Guana Tolomato Matanzas': 'GTM',
    'Estero Bay': 'EB',
    'Charlotte Harbor': 'CH',
    'Biscayne Bay': 'BB',
    'Big Bend Seagrasses':'BBS'
}

param_shortnames = {
    'Salinity': 'Sal_ppt',
    'Total Nitrogen': 'TN_mgl',
    'Dissolved Oxygen': 'DO_mgl',
    'Turbidity':'Turb_ntu',
    'Secchi Depth':'Secc_m',
    'Water Temperature':'T_c'
}

# %% [markdown]
# ### Define the barrier files

# %%
barrier_folder = os.path.join(gis_path, 'Barriers')
barrier_folder

barriers = []
for file in os.listdir(barrier_folder):
    if file.endswith(".shp"):
        barriers.append(os.path.join(barrier_folder, file))

for barrier in barriers:
    print(barrier)
# Out:
# E:\Projects\SEACAR_WQ_2024/GIS_Data/Barriers\BBS_Barriers.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/Barriers\BB_Barriers.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/Barriers\CH_Barriers.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/Barriers\EB_Barriers.shp
# E:\Projects\SEACAR_WQ_2024/GIS_Data/Barriers\GTM_Barriers.shp

# %% [markdown]
# ### Define waterbody boundary for spatial extent and masking

# %%
waterbody_extent = os.path.join(gis_path, 'OEAT_Waterbody_Boundaries', 'OEAT_Waterbody_Boundary.shp')

unique_waterbodies = []
with arcpy.da.SearchCursor(waterbody_extent, ['WaterbodyA']) as cursor:
    for row in cursor:
        unique_waterbodies.append(row[0])

print("Unique Waterbodies:", unique_waterbodies)
# Out:
# Unique Waterbodies: ['BBS', 'BB', 'CH', 'EB', 'GTM']

# %% [markdown]
# ### Define interested study periods and parameters

# %%
seasons_con = pd.read_csv(gis_path + 'Seasons_con.csv', low_memory=False)

# %% [markdown]
# ### Define output folders

# %%
shpCon_folder = gis_path + r"shapefiles_Con"
idwCon_folder = gis_path + r"idw_Con"

# %% [markdown]
# # 1.2 Preview Dataset <a class="anchor" id="reg_preview"></a>

# %%
dfCon_Mean
# Out:
#       ProgramID            WaterBody      ParameterName ParameterUnits  \
# 0           471  Big Bend Seagrasses   Dissolved Oxygen           mg/L
# 1           471  Big Bend Seagrasses   Dissolved Oxygen           mg/L
# 2           471  Big Bend Seagrasses   Dissolved Oxygen           mg/L
# 3           471  Big Bend Seagrasses   Dissolved Oxygen           mg/L
# 4           471  Big Bend Seagrasses   Dissolved Oxygen           mg/L
# ...         ...                  ...                ...            ...
# 1668       5077         Biscayne Bay  Water Temperature      Degrees C
# 1669       5077         Biscayne Bay  Water Temperature      Degrees C
# 1670       5077         Biscayne Bay  Water Temperature      Degrees C
# 1671       5077         Biscayne Bay  Water Temperature      Degrees C
# 1672       5077         Biscayne Bay  Water Temperature      Degrees C
#
#      ProgramLocationID  Year  Season  Latitude_DD  Longitude_DD  AreaID  \
# 0                BBSDB  2015    Fall    29.813933    -83.628917       5
# 1                BBSDB  2015  Spring    29.813933    -83.628917       5
# 2                BBSDB  2015  Summer    29.813933    -83.628917       5
# 3                BBSDB  2015  Winter    29.813933    -83.628917       5
# 4                BBSDB  2016  Winter    29.813933    -83.628917       5
# ...                ...   ...     ...          ...           ...     ...
# 1668            BBMRDW  2022  Winter    25.777300    -80.204000       6
# 1669            BBMRRB  2022    Fall    25.769800    -80.180850       6
# 1670            BBMRRB  2022  Spring    25.769800    -80.180850       6
# 1671            BBMRRB  2022  Summer    25.769800    -80.180850       6
# 1672            BBMRRB  2022  Winter    25.769800    -80.180850       6
#
#      WbodyAcronym  ResultValue
# 0             BBS     6.660736
# 1             BBS     7.590892
# 2             BBS     4.792978
# 3             BBS     7.648991
# 4             BBS     9.000758
# ...           ...          ...
# 1668           BB    23.919125
# 1669           BB    27.758205
# 1670           BB    27.123605
# 1671           BB    31.159306
# 1672           BB    23.494158
#
# [1673 rows x 12 columns]

# %% [markdown]
# ## 1.3 Fill NaN RowID with unique ID, IDW function needs unique ID <a class="anchor" id="reg_id"></a>

# %%
IDW.fill_nan_rowids(dfCon_Mean, 'RowID')
dfCon_Mean
# Out:
#       ProgramID            WaterBody      ParameterName ParameterUnits  \
# 0           471  Big Bend Seagrasses   Dissolved Oxygen           mg/L
# 1           471  Big Bend Seagrasses   Dissolved Oxygen           mg/L
# 2           471  Big Bend Seagrasses   Dissolved Oxygen           mg/L
# 3           471  Big Bend Seagrasses   Dissolved Oxygen           mg/L
# 4           471  Big Bend Seagrasses   Dissolved Oxygen           mg/L
# ...         ...                  ...                ...            ...
# 1668       5077         Biscayne Bay  Water Temperature      Degrees C
# 1669       5077         Biscayne Bay  Water Temperature      Degrees C
# 1670       5077         Biscayne Bay  Water Temperature      Degrees C
# 1671       5077         Biscayne Bay  Water Temperature      Degrees C
# 1672       5077         Biscayne Bay  Water Temperature      Degrees C
#
#      ProgramLocationID  Year  Season  Latitude_DD  Longitude_DD  AreaID  \
# 0                BBSDB  2015    Fall    29.813933    -83.628917       5
# 1                BBSDB  2015  Spring    29.813933    -83.628917       5
# 2                BBSDB  2015  Summer    29.813933    -83.628917       5
# 3                BBSDB  2015  Winter    29.813933    -83.628917       5
# 4                BBSDB  2016  Winter    29.813933    -83.628917       5
# ...                ...   ...     ...          ...           ...     ...
# 1668            BBMRDW  2022  Winter    25.777300    -80.204000       6
# 1669            BBMRRB  2022    Fall    25.769800    -80.180850       6
# 1670            BBMRRB  2022  Spring    25.769800    -80.180850       6
# 1671            BBMRRB  2022  Summer    25.769800    -80.180850       6
# 1672            BBMRRB  2022  Winter    25.769800    -80.180850       6
#
#      WbodyAcronym  ResultValue  RowID
# 0             BBS     6.660736      1
# 1             BBS     7.590892      2
# 2             BBS     4.792978      3
# 3             BBS     7.648991      4
# 4             BBS     9.000758      5
# ...           ...          ...    ...
# 1668           BB    23.919125   1669
# 1669           BB    27.758205   1670
# 1670           BB    27.123605   1671
# 1671           BB    31.159306   1672
# 1672           BB    23.494158   1673
#
# [1673 rows x 13 columns]

# %% [markdown]
# # 2. Create Shapefile <a class="anchor" id="reg_create_shp"></a>

# %%
IDW.delete_all_files(shpCon_folder)

# %%
# Merge interested with latitude and longitude columns
seasons_con_coord = IDW.merge_with_lat_long(seasons_con, dfCon_Mean)
seasons_con_coord
# Out:
#                    WaterBody  Year  Season          Parameter  Filename  \
# 0    Guana Tolomato Matanzas  2015    Fall           Salinity       NaN
# 1    Guana Tolomato Matanzas  2015    Fall           Salinity       NaN
# 2    Guana Tolomato Matanzas  2015    Fall           Salinity       NaN
# 3    Guana Tolomato Matanzas  2015    Fall           Salinity       NaN
# 4    Guana Tolomato Matanzas  2015  Winter           Salinity       NaN
# ..                       ...   ...     ...                ...       ...
# 494      Big Bend Seagrasses  2021  Spring  Water Temperature       NaN
# 495      Big Bend Seagrasses  2021  Summer  Water Temperature       NaN
# 496      Big Bend Seagrasses  2021    Fall  Water Temperature       NaN
# 497      Big Bend Seagrasses  2021  Winter  Water Temperature       NaN
# 498      Big Bend Seagrasses  2022  Spring  Water Temperature       NaN
#
#      NumDataPoints  RMSE  ME  Latitude_DD  Longitude_DD  RowID  ResultValue
# 0              NaN   NaN NaN    29.737041    -81.245953   1048    33.437808
# 1              NaN   NaN NaN    29.667071    -81.257403   1078    17.855211
# 2              NaN   NaN NaN    30.050857    -81.367465   1108    21.881559
# 3              NaN   NaN NaN    29.868851    -81.307428   1138    32.107294
# 4              NaN   NaN NaN    29.737041    -81.245953   1051    32.739977
# ..             ...   ...  ..          ...           ...    ...          ...
# 494            NaN   NaN NaN    29.647203    -83.421196     98    23.379975
# 495            NaN   NaN NaN    29.647203    -83.421196     99    28.912870
# 496            NaN   NaN NaN    29.647203    -83.421196     97    23.467407
# 497            NaN   NaN NaN    29.647203    -83.421196    100    16.404781
# 498            NaN   NaN NaN    29.647203    -83.421196    102    24.153515
#
# [499 rows x 12 columns]

# %%
IDW.create_shp_season(seasons_con_coord, shpCon_folder)
# Out:
# Number of data rows for BBS, DO_mgl, 2020, Fall: 1
# Shapefile for BBS: DO_mgl for year 2020 and season Fall has been saved as SHP_BBS_DO_mgl_2020_Fall.shp
# Number of data rows for BBS, Sal_ppt, 2020, Fall: 1
# Shapefile for BBS: Sal_ppt for year 2020 and season Fall has been saved as SHP_BBS_Sal_ppt_2020_Fall.shp
# Number of data rows for BBS, Turb_ntu, 2020, Fall: 1
# Shapefile for BBS: Turb_ntu for year 2020 and season Fall has been saved as SHP_BBS_Turb_ntu_2020_Fall.shp
# Number of data rows for BBS, T_c, 2020, Fall: 1
# Shapefile for BBS: T_c for year 2020 and season Fall has been saved as SHP_BBS_T_c_2020_Fall.shp
# Number of data rows for BBS, DO_mgl, 2020, Summer: 1
# Shapefile for BBS: DO_mgl for year 2020 and season Summer has been saved as SHP_BBS_DO_mgl_2020_Summer.shp
# Number of data rows for BBS, Sal_ppt, 2020, Summer: 1
# Shapefile for BBS: Sal_ppt for year 2020 and season Summer has been saved as SHP_BBS_Sal_ppt_2020_Summer.shp
# Number of data rows for BBS, Turb_ntu, 2020, Summer: 1
# Shapefile for BBS: Turb_ntu for year 2020 and season Summer has been saved as SHP_BBS_Turb_ntu_2020_Summer.shp
# Number of data rows for BBS, T_c, 2020, Summer: 1
# Shapefile for BBS: T_c for year 2020 and season Summer has been saved as SHP_BBS_T_c_2020_Summer.shp
# Number of data rows for BBS, DO_mgl, 2020, Winter: 1
# Shapefile for BBS: DO_mgl for year 2020 and season Winter has been saved as SHP_BBS_DO_mgl_2020_Winter.shp
# Number of data rows for BBS, Sal_ppt, 2020, Winter: 1
# Shapefile for BBS: Sal_ppt for year 2020 and season Winter has been saved as SHP_BBS_Sal_ppt_2020_Winter.shp
# Number of data rows for BBS, Turb_ntu, 2020, Winter: 1
# Shapefile for BBS: Turb_ntu for year 2020 and season Winter has been saved as SHP_BBS_Turb_ntu_2020_Winter.shp
# Number of data rows for BBS, T_c, 2020, Winter: 1
# Shapefile for BBS: T_c for year 2020 and season Winter has been saved as SHP_BBS_T_c_2020_Winter.shp
# Number of data rows for BBS, DO_mgl, 2021, Fall: 1
# Shapefile for BBS: DO_mgl for year 2021 and season Fall has been saved as SHP_BBS_DO_mgl_2021_Fall.shp
# Number of data rows for BBS, Sal_ppt, 2021, Fall: 1
# Shapefile for BBS: Sal_ppt for year 2021 and season Fall has been saved as SHP_BBS_Sal_ppt_2021_Fall.shp
# Number of data rows for BBS, Turb_ntu, 2021, Fall: 1
# Shapefile for BBS: Turb_ntu for year 2021 and season Fall has been saved as SHP_BBS_Turb_ntu_2021_Fall.shp
# Number of data rows for BBS, T_c, 2021, Fall: 1
# Shapefile for BBS: T_c for year 2021 and season Fall has been saved as SHP_BBS_T_c_2021_Fall.shp
# Number of data rows for BBS, DO_mgl, 2021, Spring: 1
# Shapefile for BBS: DO_mgl for year 2021 and season Spring has been saved as SHP_BBS_DO_mgl_2021_Spring.shp
# Number of data rows for BBS, Sal_ppt, 2021, Spring: 1
# Shapefile for BBS: Sal_ppt for year 2021 and season Spring has been saved as SHP_BBS_Sal_ppt_2021_Spring.shp
# Number of data rows for BBS, Turb_ntu, 2021, Spring: 1
# Shapefile for BBS: Turb_ntu for year 2021 and season Spring has been saved as SHP_BBS_Turb_ntu_2021_Spring.shp
# Number of data rows for BBS, T_c, 2021, Spring: 1
# Shapefile for BBS: T_c for year 2021 and season Spring has been saved as SHP_BBS_T_c_2021_Spring.shp
# Number of data rows for BBS, DO_mgl, 2021, Summer: 1
# Shapefile for BBS: DO_mgl for year 2021 and season Summer has been saved as SHP_BBS_DO_mgl_2021_Summer.shp
# Number of data rows for BBS, Sal_ppt, 2021, Summer: 1
# Shapefile for BBS: Sal_ppt for year 2021 and season Summer has been saved as SHP_BBS_Sal_ppt_2021_Summer.shp
# Number of data rows for BBS, Turb_ntu, 2021, Summer: 1
# Shapefile for BBS: Turb_ntu for year 2021 and season Summer has been saved as SHP_BBS_Turb_ntu_2021_Summer.shp
# Number of data rows for BBS, T_c, 2021, Summer: 1
# Shapefile for BBS: T_c for year 2021 and season Summer has been saved as SHP_BBS_T_c_2021_Summer.shp
# Number of data rows for BBS, DO_mgl, 2021, Winter: 1
# Shapefile for BBS: DO_mgl for year 2021 and season Winter has been saved as SHP_BBS_DO_mgl_2021_Winter.shp
# Number of data rows for BBS, Sal_ppt, 2021, Winter: 1
# Shapefile for BBS: Sal_ppt for year 2021 and season Winter has been saved as SHP_BBS_Sal_ppt_2021_Winter.shp
# Number of data rows for BBS, Turb_ntu, 2021, Winter: 1
# Shapefile for BBS: Turb_ntu for year 2021 and season Winter has been saved as SHP_BBS_Turb_ntu_2021_Winter.shp
# Number of data rows for BBS, T_c, 2021, Winter: 1
# Shapefile for BBS: T_c for year 2021 and season Winter has been saved as SHP_BBS_T_c_2021_Winter.shp
# Number of data rows for BBS, DO_mgl, 2022, Spring: 1
# Shapefile for BBS: DO_mgl for year 2022 and season Spring has been saved as SHP_BBS_DO_mgl_2022_Spring.shp
# Number of data rows for BBS, Sal_ppt, 2022, Spring: 1
# Shapefile for BBS: Sal_ppt for year 2022 and season Spring has been saved as SHP_BBS_Sal_ppt_2022_Spring.shp
# Number of data rows for BBS, Turb_ntu, 2022, Spring: 1
# Shapefile for BBS: Turb_ntu for year 2022 and season Spring has been saved as SHP_BBS_Turb_ntu_2022_Spring.shp
# Number of data rows for BBS, T_c, 2022, Spring: 1
# Shapefile for BBS: T_c for year 2022 and season Spring has been saved as SHP_BBS_T_c_2022_Spring.shp
# Number of data rows for BB, DO_mgl, 2021, Fall: 4
# Shapefile for BB: DO_mgl for year 2021 and season Fall has been saved as SHP_BB_DO_mgl_2021_Fall.shp
# Number of data rows for BB, Sal_ppt, 2021, Fall: 4
# Shapefile for BB: Sal_ppt for year 2021 and season Fall has been saved as SHP_BB_Sal_ppt_2021_Fall.shp
# Number of data rows for BB, Turb_ntu, 2021, Fall: 4
# Shapefile for BB: Turb_ntu for year 2021 and season Fall has been saved as SHP_BB_Turb_ntu_2021_Fall.shp
# Number of data rows for BB, T_c, 2021, Fall: 4
# Shapefile for BB: T_c for year 2021 and season Fall has been saved as SHP_BB_T_c_2021_Fall.shp
# Number of data rows for BB, DO_mgl, 2021, Summer: 4
# Shapefile for BB: DO_mgl for year 2021 and season Summer has been saved as SHP_BB_DO_mgl_2021_Summer.shp
# Number of data rows for BB, Sal_ppt, 2021, Summer: 4
# Shapefile for BB: Sal_ppt for year 2021 and season Summer has been saved as SHP_BB_Sal_ppt_2021_Summer.shp
# Number of data rows for BB, Turb_ntu, 2021, Summer: 4
# Shapefile for BB: Turb_ntu for year 2021 and season Summer has been saved as SHP_BB_Turb_ntu_2021_Summer.shp
# Number of data rows for BB, T_c, 2021, Summer: 4
# Shapefile for BB: T_c for year 2021 and season Summer has been saved as SHP_BB_T_c_2021_Summer.shp
# Number of data rows for BB, DO_mgl, 2021, Winter: 4
# Shapefile for BB: DO_mgl for year 2021 and season Winter has been saved as SHP_BB_DO_mgl_2021_Winter.shp
# Number of data rows for BB, Sal_ppt, 2021, Winter: 4
# Shapefile for BB: Sal_ppt for year 2021 and season Winter has been saved as SHP_BB_Sal_ppt_2021_Winter.shp
# Number of data rows for BB, Turb_ntu, 2021, Winter: 4
# Shapefile for BB: Turb_ntu for year 2021 and season Winter has been saved as SHP_BB_Turb_ntu_2021_Winter.shp
# Number of data rows for BB, T_c, 2021, Winter: 4
# Shapefile for BB: T_c for year 2021 and season Winter has been saved as SHP_BB_T_c_2021_Winter.shp
# Number of data rows for BB, DO_mgl, 2022, Fall: 6
# Shapefile for BB: DO_mgl for year 2022 and season Fall has been saved as SHP_BB_DO_mgl_2022_Fall.shp
# Number of data rows for BB, Sal_ppt, 2022, Fall: 6
# Shapefile for BB: Sal_ppt for year 2022 and season Fall has been saved as SHP_BB_Sal_ppt_2022_Fall.shp
# Number of data rows for BB, Turb_ntu, 2022, Fall: 6
# Shapefile for BB: Turb_ntu for year 2022 and season Fall has been saved as SHP_BB_Turb_ntu_2022_Fall.shp
# Number of data rows for BB, T_c, 2022, Fall: 6
# Shapefile for BB: T_c for year 2022 and season Fall has been saved as SHP_BB_T_c_2022_Fall.shp
# Number of data rows for BB, DO_mgl, 2022, Spring: 6
# Shapefile for BB: DO_mgl for year 2022 and season Spring has been saved as SHP_BB_DO_mgl_2022_Spring.shp
# Number of data rows for BB, Sal_ppt, 2022, Spring: 6
# Shapefile for BB: Sal_ppt for year 2022 and season Spring has been saved as SHP_BB_Sal_ppt_2022_Spring.shp
# Number of data rows for BB, Turb_ntu, 2022, Spring: 6
# Shapefile for BB: Turb_ntu for year 2022 and season Spring has been saved as SHP_BB_Turb_ntu_2022_Spring.shp
# Number of data rows for BB, T_c, 2022, Spring: 6
# Shapefile for BB: T_c for year 2022 and season Spring has been saved as SHP_BB_T_c_2022_Spring.shp
# Number of data rows for BB, DO_mgl, 2022, Summer: 6
# Shapefile for BB: DO_mgl for year 2022 and season Summer has been saved as SHP_BB_DO_mgl_2022_Summer.shp
# Number of data rows for BB, Sal_ppt, 2022, Summer: 6
# Shapefile for BB: Sal_ppt for year 2022 and season Summer has been saved as SHP_BB_Sal_ppt_2022_Summer.shp
# Number of data rows for BB, Turb_ntu, 2022, Summer: 6
# Shapefile for BB: Turb_ntu for year 2022 and season Summer has been saved as SHP_BB_Turb_ntu_2022_Summer.shp
# Number of data rows for BB, T_c, 2022, Summer: 6
# Shapefile for BB: T_c for year 2022 and season Summer has been saved as SHP_BB_T_c_2022_Summer.shp
# Number of data rows for BB, DO_mgl, 2022, Winter: 6
# Shapefile for BB: DO_mgl for year 2022 and season Winter has been saved as SHP_BB_DO_mgl_2022_Winter.shp
# Number of data rows for BB, Sal_ppt, 2022, Winter: 6
# Shapefile for BB: Sal_ppt for year 2022 and season Winter has been saved as SHP_BB_Sal_ppt_2022_Winter.shp
# Number of data rows for BB, Turb_ntu, 2022, Winter: 6
# Shapefile for BB: Turb_ntu for year 2022 and season Winter has been saved as SHP_BB_Turb_ntu_2022_Winter.shp
# Number of data rows for BB, T_c, 2022, Winter: 6
# Shapefile for BB: T_c for year 2022 and season Winter has been saved as SHP_BB_T_c_2022_Winter.shp
# No valid data found for area: BB, parameter: DO_mgl, year: 2023, and season: Spring
# No valid data found for area: BB, parameter: Sal_ppt, year: 2023, and season: Spring
# No valid data found for area: BB, parameter: Turb_ntu, year: 2023, and season: Spring
# No valid data found for area: BB, parameter: T_c, year: 2023, and season: Spring
# Number of data rows for CH, DO_mgl, 2016, Fall: 3
# Shapefile for CH: DO_mgl for year 2016 and season Fall has been saved as SHP_CH_DO_mgl_2016_Fall.shp
# Number of data rows for CH, Sal_ppt, 2016, Fall: 3
# Shapefile for CH: Sal_ppt for year 2016 and season Fall has been saved as SHP_CH_Sal_ppt_2016_Fall.shp
# Number of data rows for CH, Turb_ntu, 2016, Fall: 3
# Shapefile for CH: Turb_ntu for year 2016 and season Fall has been saved as SHP_CH_Turb_ntu_2016_Fall.shp
# Number of data rows for CH, T_c, 2016, Fall: 3
# Shapefile for CH: T_c for year 2016 and season Fall has been saved as SHP_CH_T_c_2016_Fall.shp
# Number of data rows for CH, DO_mgl, 2016, Summer: 3
# Shapefile for CH: DO_mgl for year 2016 and season Summer has been saved as SHP_CH_DO_mgl_2016_Summer.shp
# Number of data rows for CH, Sal_ppt, 2016, Summer: 3
# Shapefile for CH: Sal_ppt for year 2016 and season Summer has been saved as SHP_CH_Sal_ppt_2016_Summer.shp
# Number of data rows for CH, Turb_ntu, 2016, Summer: 3
# Shapefile for CH: Turb_ntu for year 2016 and season Summer has been saved as SHP_CH_Turb_ntu_2016_Summer.shp
# Number of data rows for CH, T_c, 2016, Summer: 3
# Shapefile for CH: T_c for year 2016 and season Summer has been saved as SHP_CH_T_c_2016_Summer.shp
# Number of data rows for CH, DO_mgl, 2016, Winter: 3
# Shapefile for CH: DO_mgl for year 2016 and season Winter has been saved as SHP_CH_DO_mgl_2016_Winter.shp
# Number of data rows for CH, Sal_ppt, 2016, Winter: 3
# Shapefile for CH: Sal_ppt for year 2016 and season Winter has been saved as SHP_CH_Sal_ppt_2016_Winter.shp
# Number of data rows for CH, Turb_ntu, 2016, Winter: 3
# Shapefile for CH: Turb_ntu for year 2016 and season Winter has been saved as SHP_CH_Turb_ntu_2016_Winter.shp
# Number of data rows for CH, T_c, 2016, Winter: 3
# Shapefile for CH: T_c for year 2016 and season Winter has been saved as SHP_CH_T_c_2016_Winter.shp
# Number of data rows for CH, DO_mgl, 2017, Fall: 3
# Shapefile for CH: DO_mgl for year 2017 and season Fall has been saved as SHP_CH_DO_mgl_2017_Fall.shp
# Number of data rows for CH, Sal_ppt, 2017, Fall: 3
# Shapefile for CH: Sal_ppt for year 2017 and season Fall has been saved as SHP_CH_Sal_ppt_2017_Fall.shp
# Number of data rows for CH, Turb_ntu, 2017, Fall: 3
# Shapefile for CH: Turb_ntu for year 2017 and season Fall has been saved as SHP_CH_Turb_ntu_2017_Fall.shp
# Number of data rows for CH, T_c, 2017, Fall: 3
# Shapefile for CH: T_c for year 2017 and season Fall has been saved as SHP_CH_T_c_2017_Fall.shp
# Number of data rows for CH, DO_mgl, 2017, Spring: 3
# Shapefile for CH: DO_mgl for year 2017 and season Spring has been saved as SHP_CH_DO_mgl_2017_Spring.shp
# Number of data rows for CH, Sal_ppt, 2017, Spring: 3
# Shapefile for CH: Sal_ppt for year 2017 and season Spring has been saved as SHP_CH_Sal_ppt_2017_Spring.shp
# Number of data rows for CH, Turb_ntu, 2017, Spring: 3
# Shapefile for CH: Turb_ntu for year 2017 and season Spring has been saved as SHP_CH_Turb_ntu_2017_Spring.shp
# Number of data rows for CH, T_c, 2017, Spring: 3
# Shapefile for CH: T_c for year 2017 and season Spring has been saved as SHP_CH_T_c_2017_Spring.shp
# Number of data rows for CH, DO_mgl, 2017, Summer: 3
# Shapefile for CH: DO_mgl for year 2017 and season Summer has been saved as SHP_CH_DO_mgl_2017_Summer.shp
# Number of data rows for CH, Sal_ppt, 2017, Summer: 3
# Shapefile for CH: Sal_ppt for year 2017 and season Summer has been saved as SHP_CH_Sal_ppt_2017_Summer.shp
# Number of data rows for CH, Turb_ntu, 2017, Summer: 3
# Shapefile for CH: Turb_ntu for year 2017 and season Summer has been saved as SHP_CH_Turb_ntu_2017_Summer.shp
# Number of data rows for CH, T_c, 2017, Summer: 3
# Shapefile for CH: T_c for year 2017 and season Summer has been saved as SHP_CH_T_c_2017_Summer.shp
# Number of data rows for CH, DO_mgl, 2017, Winter: 3
# Shapefile for CH: DO_mgl for year 2017 and season Winter has been saved as SHP_CH_DO_mgl_2017_Winter.shp
# Number of data rows for CH, Sal_ppt, 2017, Winter: 3
# Shapefile for CH: Sal_ppt for year 2017 and season Winter has been saved as SHP_CH_Sal_ppt_2017_Winter.shp
# Number of data rows for CH, Turb_ntu, 2017, Winter: 3
# Shapefile for CH: Turb_ntu for year 2017 and season Winter has been saved as SHP_CH_Turb_ntu_2017_Winter.shp
# Number of data rows for CH, T_c, 2017, Winter: 3
# Shapefile for CH: T_c for year 2017 and season Winter has been saved as SHP_CH_T_c_2017_Winter.shp
# Number of data rows for CH, DO_mgl, 2018, Spring: 3
# Shapefile for CH: DO_mgl for year 2018 and season Spring has been saved as SHP_CH_DO_mgl_2018_Spring.shp
# Number of data rows for CH, Sal_ppt, 2018, Spring: 3
# Shapefile for CH: Sal_ppt for year 2018 and season Spring has been saved as SHP_CH_Sal_ppt_2018_Spring.shp
# Number of data rows for CH, Turb_ntu, 2018, Spring: 3
# Shapefile for CH: Turb_ntu for year 2018 and season Spring has been saved as SHP_CH_Turb_ntu_2018_Spring.shp
# Number of data rows for CH, T_c, 2018, Spring: 3
# Shapefile for CH: T_c for year 2018 and season Spring has been saved as SHP_CH_T_c_2018_Spring.shp
# Number of data rows for EB, DO_mgl, 2016, Fall: 3
# Shapefile for EB: DO_mgl for year 2016 and season Fall has been saved as SHP_EB_DO_mgl_2016_Fall.shp
# Number of data rows for EB, Sal_ppt, 2016, Fall: 3
# Shapefile for EB: Sal_ppt for year 2016 and season Fall has been saved as SHP_EB_Sal_ppt_2016_Fall.shp
# Number of data rows for EB, Turb_ntu, 2016, Fall: 2
# Shapefile for EB: Turb_ntu for year 2016 and season Fall has been saved as SHP_EB_Turb_ntu_2016_Fall.shp
# Number of data rows for EB, T_c, 2016, Fall: 3
# Shapefile for EB: T_c for year 2016 and season Fall has been saved as SHP_EB_T_c_2016_Fall.shp
# Number of data rows for EB, DO_mgl, 2016, Summer: 3
# Shapefile for EB: DO_mgl for year 2016 and season Summer has been saved as SHP_EB_DO_mgl_2016_Summer.shp
# Number of data rows for EB, Sal_ppt, 2016, Summer: 3
# Shapefile for EB: Sal_ppt for year 2016 and season Summer has been saved as SHP_EB_Sal_ppt_2016_Summer.shp
# Number of data rows for EB, Turb_ntu, 2016, Summer: 3
# Shapefile for EB: Turb_ntu for year 2016 and season Summer has been saved as SHP_EB_Turb_ntu_2016_Summer.shp
# Number of data rows for EB, T_c, 2016, Summer: 3
# Shapefile for EB: T_c for year 2016 and season Summer has been saved as SHP_EB_T_c_2016_Summer.shp
# Number of data rows for EB, DO_mgl, 2016, Winter: 3
# Shapefile for EB: DO_mgl for year 2016 and season Winter has been saved as SHP_EB_DO_mgl_2016_Winter.shp
# Number of data rows for EB, Sal_ppt, 2016, Winter: 3
# Shapefile for EB: Sal_ppt for year 2016 and season Winter has been saved as SHP_EB_Sal_ppt_2016_Winter.shp
# Number of data rows for EB, Turb_ntu, 2016, Winter: 3
# Shapefile for EB: Turb_ntu for year 2016 and season Winter has been saved as SHP_EB_Turb_ntu_2016_Winter.shp
# Number of data rows for EB, T_c, 2016, Winter: 3
# Shapefile for EB: T_c for year 2016 and season Winter has been saved as SHP_EB_T_c_2016_Winter.shp
# Number of data rows for EB, DO_mgl, 2017, Fall: 3
# Shapefile for EB: DO_mgl for year 2017 and season Fall has been saved as SHP_EB_DO_mgl_2017_Fall.shp
# Number of data rows for EB, Sal_ppt, 2017, Fall: 3
# Shapefile for EB: Sal_ppt for year 2017 and season Fall has been saved as SHP_EB_Sal_ppt_2017_Fall.shp
# Number of data rows for EB, Turb_ntu, 2017, Fall: 3
# Shapefile for EB: Turb_ntu for year 2017 and season Fall has been saved as SHP_EB_Turb_ntu_2017_Fall.shp
# Number of data rows for EB, T_c, 2017, Fall: 3
# Shapefile for EB: T_c for year 2017 and season Fall has been saved as SHP_EB_T_c_2017_Fall.shp
# Number of data rows for EB, DO_mgl, 2017, Spring: 3
# Shapefile for EB: DO_mgl for year 2017 and season Spring has been saved as SHP_EB_DO_mgl_2017_Spring.shp
# Number of data rows for EB, Sal_ppt, 2017, Spring: 3
# Shapefile for EB: Sal_ppt for year 2017 and season Spring has been saved as SHP_EB_Sal_ppt_2017_Spring.shp
# Number of data rows for EB, Turb_ntu, 2017, Spring: 3
# Shapefile for EB: Turb_ntu for year 2017 and season Spring has been saved as SHP_EB_Turb_ntu_2017_Spring.shp
# Number of data rows for EB, T_c, 2017, Spring: 3
# Shapefile for EB: T_c for year 2017 and season Spring has been saved as SHP_EB_T_c_2017_Spring.shp
# Number of data rows for EB, DO_mgl, 2017, Summer: 3
# Shapefile for EB: DO_mgl for year 2017 and season Summer has been saved as SHP_EB_DO_mgl_2017_Summer.shp
# Number of data rows for EB, Sal_ppt, 2017, Summer: 3
# Shapefile for EB: Sal_ppt for year 2017 and season Summer has been saved as SHP_EB_Sal_ppt_2017_Summer.shp
# Number of data rows for EB, Turb_ntu, 2017, Summer: 3
# Shapefile for EB: Turb_ntu for year 2017 and season Summer has been saved as SHP_EB_Turb_ntu_2017_Summer.shp
# Number of data rows for EB, T_c, 2017, Summer: 3
# Shapefile for EB: T_c for year 2017 and season Summer has been saved as SHP_EB_T_c_2017_Summer.shp
# Number of data rows for EB, DO_mgl, 2017, Winter: 3
# Shapefile for EB: DO_mgl for year 2017 and season Winter has been saved as SHP_EB_DO_mgl_2017_Winter.shp
# Number of data rows for EB, Sal_ppt, 2017, Winter: 3
# Shapefile for EB: Sal_ppt for year 2017 and season Winter has been saved as SHP_EB_Sal_ppt_2017_Winter.shp
# Number of data rows for EB, Turb_ntu, 2017, Winter: 3
# Shapefile for EB: Turb_ntu for year 2017 and season Winter has been saved as SHP_EB_Turb_ntu_2017_Winter.shp
# Number of data rows for EB, T_c, 2017, Winter: 3
# Shapefile for EB: T_c for year 2017 and season Winter has been saved as SHP_EB_T_c_2017_Winter.shp
# Number of data rows for EB, DO_mgl, 2018, Spring: 3
# Shapefile for EB: DO_mgl for year 2018 and season Spring has been saved as SHP_EB_DO_mgl_2018_Spring.shp
# Number of data rows for EB, Sal_ppt, 2018, Spring: 3
# Shapefile for EB: Sal_ppt for year 2018 and season Spring has been saved as SHP_EB_Sal_ppt_2018_Spring.shp
# Number of data rows for EB, Turb_ntu, 2018, Spring: 3
# Shapefile for EB: Turb_ntu for year 2018 and season Spring has been saved as SHP_EB_Turb_ntu_2018_Spring.shp
# Number of data rows for EB, T_c, 2018, Spring: 3
# Shapefile for EB: T_c for year 2018 and season Spring has been saved as SHP_EB_T_c_2018_Spring.shp
# Number of data rows for GTM, DO_mgl, 2015, Fall: 4
# Shapefile for GTM: DO_mgl for year 2015 and season Fall has been saved as SHP_GTM_DO_mgl_2015_Fall.shp
# Number of data rows for GTM, Sal_ppt, 2015, Fall: 4
# Shapefile for GTM: Sal_ppt for year 2015 and season Fall has been saved as SHP_GTM_Sal_ppt_2015_Fall.shp
# Number of data rows for GTM, Turb_ntu, 2015, Fall: 4
# Shapefile for GTM: Turb_ntu for year 2015 and season Fall has been saved as SHP_GTM_Turb_ntu_2015_Fall.shp
# Number of data rows for GTM, T_c, 2015, Fall: 4
# Shapefile for GTM: T_c for year 2015 and season Fall has been saved as SHP_GTM_T_c_2015_Fall.shp
# Number of data rows for GTM, DO_mgl, 2015, Winter: 4
# Shapefile for GTM: DO_mgl for year 2015 and season Winter has been saved as SHP_GTM_DO_mgl_2015_Winter.shp
# Number of data rows for GTM, Sal_ppt, 2015, Winter: 4
# Shapefile for GTM: Sal_ppt for year 2015 and season Winter has been saved as SHP_GTM_Sal_ppt_2015_Winter.shp
# Number of data rows for GTM, Turb_ntu, 2015, Winter: 4
# Shapefile for GTM: Turb_ntu for year 2015 and season Winter has been saved as SHP_GTM_Turb_ntu_2015_Winter.shp
# Number of data rows for GTM, T_c, 2015, Winter: 4
# Shapefile for GTM: T_c for year 2015 and season Winter has been saved as SHP_GTM_T_c_2015_Winter.shp
# Number of data rows for GTM, DO_mgl, 2016, Fall: 4
# Shapefile for GTM: DO_mgl for year 2016 and season Fall has been saved as SHP_GTM_DO_mgl_2016_Fall.shp
# Number of data rows for GTM, Sal_ppt, 2016, Fall: 4
# Shapefile for GTM: Sal_ppt for year 2016 and season Fall has been saved as SHP_GTM_Sal_ppt_2016_Fall.shp
# Number of data rows for GTM, Turb_ntu, 2016, Fall: 4
# Shapefile for GTM: Turb_ntu for year 2016 and season Fall has been saved as SHP_GTM_Turb_ntu_2016_Fall.shp
# Number of data rows for GTM, T_c, 2016, Fall: 4
# Shapefile for GTM: T_c for year 2016 and season Fall has been saved as SHP_GTM_T_c_2016_Fall.shp
# Number of data rows for GTM, DO_mgl, 2016, Spring: 4
# Shapefile for GTM: DO_mgl for year 2016 and season Spring has been saved as SHP_GTM_DO_mgl_2016_Spring.shp
# Number of data rows for GTM, Sal_ppt, 2016, Spring: 4
# Shapefile for GTM: Sal_ppt for year 2016 and season Spring has been saved as SHP_GTM_Sal_ppt_2016_Spring.shp
# Number of data rows for GTM, Turb_ntu, 2016, Spring: 4
# Shapefile for GTM: Turb_ntu for year 2016 and season Spring has been saved as SHP_GTM_Turb_ntu_2016_Spring.shp
# Number of data rows for GTM, T_c, 2016, Spring: 4
# Shapefile for GTM: T_c for year 2016 and season Spring has been saved as SHP_GTM_T_c_2016_Spring.shp
# Number of data rows for GTM, DO_mgl, 2016, Summer: 4
# Shapefile for GTM: DO_mgl for year 2016 and season Summer has been saved as SHP_GTM_DO_mgl_2016_Summer.shp
# Number of data rows for GTM, Sal_ppt, 2016, Summer: 4
# Shapefile for GTM: Sal_ppt for year 2016 and season Summer has been saved as SHP_GTM_Sal_ppt_2016_Summer.shp
# Number of data rows for GTM, Turb_ntu, 2016, Summer: 4
# Shapefile for GTM: Turb_ntu for year 2016 and season Summer has been saved as SHP_GTM_Turb_ntu_2016_Summer.shp
# Number of data rows for GTM, T_c, 2016, Summer: 4
# Shapefile for GTM: T_c for year 2016 and season Summer has been saved as SHP_GTM_T_c_2016_Summer.shp
# Number of data rows for GTM, DO_mgl, 2016, Winter: 4
# Shapefile for GTM: DO_mgl for year 2016 and season Winter has been saved as SHP_GTM_DO_mgl_2016_Winter.shp
# Number of data rows for GTM, Sal_ppt, 2016, Winter: 4
# Shapefile for GTM: Sal_ppt for year 2016 and season Winter has been saved as SHP_GTM_Sal_ppt_2016_Winter.shp
# Number of data rows for GTM, Turb_ntu, 2016, Winter: 4
# Shapefile for GTM: Turb_ntu for year 2016 and season Winter has been saved as SHP_GTM_Turb_ntu_2016_Winter.shp
# Number of data rows for GTM, T_c, 2016, Winter: 4
# Shapefile for GTM: T_c for year 2016 and season Winter has been saved as SHP_GTM_T_c_2016_Winter.shp
# Number of data rows for GTM, DO_mgl, 2017, Spring: 4
# Shapefile for GTM: DO_mgl for year 2017 and season Spring has been saved as SHP_GTM_DO_mgl_2017_Spring.shp
# Number of data rows for GTM, Sal_ppt, 2017, Spring: 4
# Shapefile for GTM: Sal_ppt for year 2017 and season Spring has been saved as SHP_GTM_Sal_ppt_2017_Spring.shp
# Number of data rows for GTM, Turb_ntu, 2017, Spring: 4
# Shapefile for GTM: Turb_ntu for year 2017 and season Spring has been saved as SHP_GTM_Turb_ntu_2017_Spring.shp
# Number of data rows for GTM, T_c, 2017, Spring: 4
# Shapefile for GTM: T_c for year 2017 and season Spring has been saved as SHP_GTM_T_c_2017_Spring.shp
# Number of data rows for GTM, DO_mgl, 2017, Summer: 4
# Shapefile for GTM: DO_mgl for year 2017 and season Summer has been saved as SHP_GTM_DO_mgl_2017_Summer.shp
# Number of data rows for GTM, Sal_ppt, 2017, Summer: 4
# Shapefile for GTM: Sal_ppt for year 2017 and season Summer has been saved as SHP_GTM_Sal_ppt_2017_Summer.shp
# Number of data rows for GTM, Turb_ntu, 2017, Summer: 4
# Shapefile for GTM: Turb_ntu for year 2017 and season Summer has been saved as SHP_GTM_Turb_ntu_2017_Summer.shp
# Number of data rows for GTM, T_c, 2017, Summer: 4
# Shapefile for GTM: T_c for year 2017 and season Summer has been saved as SHP_GTM_T_c_2017_Summer.shp

# %% [markdown]
# # 3. Cross Validation for IDW <a class="anchor" id="reg_cv_idw"></a>

# %%
# Empty the shapefile folder
IDW.delete_all_files(idwCon_folder)

# %%
# If the number of data points is less than 3，skipping calculate IDW
IDW.idw_interpolation(seasons_con, shpCon_folder, idwCon_folder, waterbody_extent, barrier_folder)
# Out:
# Processing file: SHP_GTM_Sal_ppt_2015_Fall.shp
# Calculated RMSE: 11.465092111629327, ME: 2.617005565025001 for file: SHP_GTM_Sal_ppt_2015_Fall.shp
# File SHP_GTM_Sal_ppt_2015_Fall.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2015_Winter.shp
# Calculated RMSE: 7.5095149853850325, ME: 1.3438841223750018 for file: SHP_GTM_Sal_ppt_2015_Winter.shp
# File SHP_GTM_Sal_ppt_2015_Winter.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_Spring.shp
# Calculated RMSE: 9.094061000437073, ME: 1.153808037100001 for file: SHP_GTM_Sal_ppt_2016_Spring.shp
# File SHP_GTM_Sal_ppt_2016_Spring.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_Summer.shp
# Calculated RMSE: 8.826177273157874, ME: 1.0447028336500015 for file: SHP_GTM_Sal_ppt_2016_Summer.shp
# File SHP_GTM_Sal_ppt_2016_Summer.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_Fall.shp
# Calculated RMSE: 8.657996312221368, ME: 1.8829896843499991 for file: SHP_GTM_Sal_ppt_2016_Fall.shp
# File SHP_GTM_Sal_ppt_2016_Fall.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2016_Winter.shp
# Calculated RMSE: 7.934022106537692, ME: 1.6974195107499988 for file: SHP_GTM_Sal_ppt_2016_Winter.shp
# File SHP_GTM_Sal_ppt_2016_Winter.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2017_Spring.shp
# Calculated RMSE: 7.971176009797393, ME: 0.877701971275 for file: SHP_GTM_Sal_ppt_2017_Spring.shp
# File SHP_GTM_Sal_ppt_2017_Spring.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Sal_ppt_2017_Summer.shp
# Calculated RMSE: 16.698709711038884, ME: 3.272389131625001 for file: SHP_GTM_Sal_ppt_2017_Summer.shp
# File SHP_GTM_Sal_ppt_2017_Summer.shp has completed 4 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2016_Summer.shp
# Calculated RMSE: 8.374733109413194, ME: 0.07726725550000069 for file: SHP_EB_Sal_ppt_2016_Summer.shp
# File SHP_EB_Sal_ppt_2016_Summer.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2016_Fall.shp
# Calculated RMSE: 4.242217406438678, ME: -0.042284188049999116 for file: SHP_EB_Sal_ppt_2016_Fall.shp
# File SHP_EB_Sal_ppt_2016_Fall.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2016_Winter.shp
# Calculated RMSE: 5.586262204986419, ME: 0.14638973515000053 for file: SHP_EB_Sal_ppt_2016_Winter.shp
# File SHP_EB_Sal_ppt_2016_Winter.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_Spring.shp
# Calculated RMSE: 1.422126232921503, ME: 0.04606586059999884 for file: SHP_EB_Sal_ppt_2017_Spring.shp
# File SHP_EB_Sal_ppt_2017_Spring.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_Summer.shp
# Calculated RMSE: 8.420085647846038, ME: 0.18229294510000038 for file: SHP_EB_Sal_ppt_2017_Summer.shp
# File SHP_EB_Sal_ppt_2017_Summer.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_Fall.shp
# Calculated RMSE: 13.47710717823451, ME: 0.5018248113000006 for file: SHP_EB_Sal_ppt_2017_Fall.shp
# File SHP_EB_Sal_ppt_2017_Fall.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2017_Winter.shp
# Calculated RMSE: 2.9083745595436743, ME: 0.025504396099998772 for file: SHP_EB_Sal_ppt_2017_Winter.shp
# File SHP_EB_Sal_ppt_2017_Winter.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Sal_ppt_2018_Spring.shp
# Calculated RMSE: 2.024928189987039, ME: -0.035210680500000535 for file: SHP_EB_Sal_ppt_2018_Spring.shp
# File SHP_EB_Sal_ppt_2018_Spring.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Sal_ppt_2016_Summer.shp
# Calculated RMSE: 0.4638090262501214, ME: 3.345500001472601e-07 for file: SHP_CH_Sal_ppt_2016_Summer.shp
# File SHP_CH_Sal_ppt_2016_Summer.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Sal_ppt_2016_Fall.shp
# Calculated RMSE: 0.13606034895137037, ME: 6.102499998661415e-07 for file: SHP_CH_Sal_ppt_2016_Fall.shp
# File SHP_CH_Sal_ppt_2016_Fall.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Sal_ppt_2016_Winter.shp
# Calculated RMSE: 0.7040468841000098, ME: -1.1589999893146796e-07 for file: SHP_CH_Sal_ppt_2016_Winter.shp
# File SHP_CH_Sal_ppt_2016_Winter.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Sal_ppt_2017_Spring.shp
# Calculated RMSE: 0.1901895088502737, ME: -3.223500009141844e-07 for file: SHP_CH_Sal_ppt_2017_Spring.shp
# File SHP_CH_Sal_ppt_2017_Spring.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Sal_ppt_2017_Summer.shp
# Calculated RMSE: 0.5775818708000198, ME: 1.5290000021650485e-07 for file: SHP_CH_Sal_ppt_2017_Summer.shp
# File SHP_CH_Sal_ppt_2017_Summer.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Sal_ppt_2017_Fall.shp
# Calculated RMSE: 1.4048191885300947, ME: -5.126699997859419e-07 for file: SHP_CH_Sal_ppt_2017_Fall.shp
# File SHP_CH_Sal_ppt_2017_Fall.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Sal_ppt_2017_Winter.shp
# Calculated RMSE: 1.1919711316001442, ME: -5.844999986237553e-07 for file: SHP_CH_Sal_ppt_2017_Winter.shp
# File SHP_CH_Sal_ppt_2017_Winter.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Sal_ppt_2018_Spring.shp
# Calculated RMSE: 3.1757607617500248, ME: -3.9244999960885707e-07 for file: SHP_CH_Sal_ppt_2018_Spring.shp
# File SHP_CH_Sal_ppt_2018_Spring.shp has completed 3 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2021_Summer.shp
# Calculated RMSE: 11.174758028371581, ME: 5.627809068006667 for file: SHP_BB_Sal_ppt_2021_Summer.shp
# File SHP_BB_Sal_ppt_2021_Summer.shp has completed 4 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2021_Fall.shp
# Calculated RMSE: 7.509138673619112, ME: 3.7982853685999998 for file: SHP_BB_Sal_ppt_2021_Fall.shp
# File SHP_BB_Sal_ppt_2021_Fall.shp has completed 4 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2021_Winter.shp
# Calculated RMSE: 7.425717852294722, ME: 3.762970636099999 for file: SHP_BB_Sal_ppt_2021_Winter.shp
# File SHP_BB_Sal_ppt_2021_Winter.shp has completed 4 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_Spring.shp
# Calculated RMSE: 6.830807386765445, ME: 2.6753114595600005 for file: SHP_BB_Sal_ppt_2022_Spring.shp
# File SHP_BB_Sal_ppt_2022_Spring.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_Summer.shp
# Calculated RMSE: 7.761655611541825, ME: 3.023957750000001 for file: SHP_BB_Sal_ppt_2022_Summer.shp
# File SHP_BB_Sal_ppt_2022_Summer.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_Fall.shp
# Calculated RMSE: 5.618249805369366, ME: 2.1793633756600004 for file: SHP_BB_Sal_ppt_2022_Fall.shp
# File SHP_BB_Sal_ppt_2022_Fall.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Sal_ppt_2022_Winter.shp
# Calculated RMSE: 6.132218669822134, ME: 2.3995962176800005 for file: SHP_BB_Sal_ppt_2022_Winter.shp
# File SHP_BB_Sal_ppt_2022_Winter.shp has completed 6 cross-validation iterations.
# Shapefile not found for: SHP_BB_Sal_ppt_2023_Spring.shp
# Processing file: SHP_BBS_Sal_ppt_2020_Summer.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2020_Summer.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2020_Fall.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2020_Fall.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2020_Winter.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2020_Winter.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_Spring.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_Spring.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_Summer.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_Summer.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_Fall.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_Fall.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2021_Winter.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2021_Winter.shp, skipping
# Processing file: SHP_BBS_Sal_ppt_2022_Spring.shp
# Not enough data for IDW interpolation in SHP_BBS_Sal_ppt_2022_Spring.shp, skipping
# Processing file: SHP_GTM_DO_mgl_2015_Fall.shp
# Calculated RMSE: 0.6689741796726012, ME: 0.17515553363000014 for file: SHP_GTM_DO_mgl_2015_Fall.shp
# File SHP_GTM_DO_mgl_2015_Fall.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_DO_mgl_2015_Winter.shp
# Calculated RMSE: 0.40068754276758173, ME: 0.05577908064999981 for file: SHP_GTM_DO_mgl_2015_Winter.shp
# File SHP_GTM_DO_mgl_2015_Winter.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_DO_mgl_2016_Spring.shp
# Calculated RMSE: 0.8733855458661026, ME: 0.16818793239750018 for file: SHP_GTM_DO_mgl_2016_Spring.shp
# File SHP_GTM_DO_mgl_2016_Spring.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_DO_mgl_2016_Summer.shp
# Calculated RMSE: 1.1126308680093586, ME: 0.22377996639499997 for file: SHP_GTM_DO_mgl_2016_Summer.shp
# File SHP_GTM_DO_mgl_2016_Summer.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_DO_mgl_2016_Fall.shp
# Calculated RMSE: 0.8978191664124523, ME: 0.19235122455249987 for file: SHP_GTM_DO_mgl_2016_Fall.shp
# File SHP_GTM_DO_mgl_2016_Fall.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_DO_mgl_2016_Winter.shp
# Calculated RMSE: 0.37376177772502067, ME: 0.09643043991 for file: SHP_GTM_DO_mgl_2016_Winter.shp
# File SHP_GTM_DO_mgl_2016_Winter.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_DO_mgl_2017_Spring.shp
# Calculated RMSE: 0.8313233998928988, ME: 0.16605939948249993 for file: SHP_GTM_DO_mgl_2017_Spring.shp
# File SHP_GTM_DO_mgl_2017_Spring.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_DO_mgl_2017_Summer.shp
# Calculated RMSE: 1.4465742341854888, ME: 0.32319266172500005 for file: SHP_GTM_DO_mgl_2017_Summer.shp
# File SHP_GTM_DO_mgl_2017_Summer.shp has completed 4 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2016_Summer.shp
# Calculated RMSE: 0.8431823761637481, ME: -0.0038807203099997523 for file: SHP_EB_DO_mgl_2016_Summer.shp
# File SHP_EB_DO_mgl_2016_Summer.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2016_Fall.shp
# Calculated RMSE: 0.03772063678381288, ME: -0.036285977859999985 for file: SHP_EB_DO_mgl_2016_Fall.shp
# File SHP_EB_DO_mgl_2016_Fall.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2016_Winter.shp
# Calculated RMSE: 0.07369358919283306, ME: -0.033389939770000154 for file: SHP_EB_DO_mgl_2016_Winter.shp
# File SHP_EB_DO_mgl_2016_Winter.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2017_Spring.shp
# Calculated RMSE: 0.10074719680557502, ME: -0.03893802284500003 for file: SHP_EB_DO_mgl_2017_Spring.shp
# File SHP_EB_DO_mgl_2017_Spring.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2017_Summer.shp
# Calculated RMSE: 1.1641461247650955, ME: 0.033674800980000086 for file: SHP_EB_DO_mgl_2017_Summer.shp
# File SHP_EB_DO_mgl_2017_Summer.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2017_Fall.shp
# Calculated RMSE: 0.45712008252764774, ME: 0.02515586991499985 for file: SHP_EB_DO_mgl_2017_Fall.shp
# File SHP_EB_DO_mgl_2017_Fall.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2017_Winter.shp
# Calculated RMSE: 0.13932158783943824, ME: -0.03081373214499994 for file: SHP_EB_DO_mgl_2017_Winter.shp
# File SHP_EB_DO_mgl_2017_Winter.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_DO_mgl_2018_Spring.shp
# Calculated RMSE: 0.1439693883754308, ME: -0.04476636078499974 for file: SHP_EB_DO_mgl_2018_Spring.shp
# File SHP_EB_DO_mgl_2018_Spring.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_2016_Summer.shp
# Calculated RMSE: 1.009757541135015, ME: -1.717749995577833e-07 for file: SHP_CH_DO_mgl_2016_Summer.shp
# File SHP_CH_DO_mgl_2016_Summer.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_2016_Fall.shp
# Calculated RMSE: 0.8834931387599996, ME: 3.3900002804898577e-09 for file: SHP_CH_DO_mgl_2016_Fall.shp
# File SHP_CH_DO_mgl_2016_Fall.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_2016_Winter.shp
# Calculated RMSE: 0.947056742180023, ME: -2.088500004049365e-07 for file: SHP_CH_DO_mgl_2016_Winter.shp
# File SHP_CH_DO_mgl_2016_Winter.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_2017_Spring.shp
# Calculated RMSE: 2.2330270779700014, ME: 7.42399999253962e-08 for file: SHP_CH_DO_mgl_2017_Spring.shp
# File SHP_CH_DO_mgl_2017_Spring.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_2017_Summer.shp
# Calculated RMSE: 1.3205677318650002, ME: -7.225000153709971e-09 for file: SHP_CH_DO_mgl_2017_Summer.shp
# File SHP_CH_DO_mgl_2017_Summer.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_2017_Fall.shp
# Calculated RMSE: 0.09665769907007621, ME: 1.2129999982235518e-07 for file: SHP_CH_DO_mgl_2017_Fall.shp
# File SHP_CH_DO_mgl_2017_Fall.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_2017_Winter.shp
# Calculated RMSE: 0.2878889222300039, ME: -4.689999988372051e-08 for file: SHP_CH_DO_mgl_2017_Winter.shp
# File SHP_CH_DO_mgl_2017_Winter.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_DO_mgl_2018_Spring.shp
# Calculated RMSE: 0.0916109203250205, ME: 6.134499974663754e-08 for file: SHP_CH_DO_mgl_2018_Spring.shp
# File SHP_CH_DO_mgl_2018_Spring.shp has completed 3 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2021_Summer.shp
# Calculated RMSE: 2.959116037750276, ME: 1.4961531588366668 for file: SHP_BB_DO_mgl_2021_Summer.shp
# File SHP_BB_DO_mgl_2021_Summer.shp has completed 4 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2021_Fall.shp
# Calculated RMSE: 2.166261910197647, ME: 1.095413943266667 for file: SHP_BB_DO_mgl_2021_Fall.shp
# File SHP_BB_DO_mgl_2021_Fall.shp has completed 4 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2021_Winter.shp
# Calculated RMSE: 2.1798389318060987, ME: 1.0140767100533343 for file: SHP_BB_DO_mgl_2021_Winter.shp
# File SHP_BB_DO_mgl_2021_Winter.shp has completed 4 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_Spring.shp
# Calculated RMSE: 1.8316272700988114, ME: 0.7157555366300004 for file: SHP_BB_DO_mgl_2022_Spring.shp
# File SHP_BB_DO_mgl_2022_Spring.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_Summer.shp
# Calculated RMSE: 1.8812885747013803, ME: 0.7376365823380002 for file: SHP_BB_DO_mgl_2022_Summer.shp
# File SHP_BB_DO_mgl_2022_Summer.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_Fall.shp
# Calculated RMSE: 1.8772694353499657, ME: 0.7330071777879998 for file: SHP_BB_DO_mgl_2022_Fall.shp
# File SHP_BB_DO_mgl_2022_Fall.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_DO_mgl_2022_Winter.shp
# Calculated RMSE: 1.7857297266057353, ME: 0.69848185068 for file: SHP_BB_DO_mgl_2022_Winter.shp
# File SHP_BB_DO_mgl_2022_Winter.shp has completed 6 cross-validation iterations.
# Shapefile not found for: SHP_BB_DO_mgl_2023_Spring.shp
# Processing file: SHP_BBS_DO_mgl_2020_Summer.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2020_Summer.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2020_Fall.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2020_Fall.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2020_Winter.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2020_Winter.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_Spring.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_Spring.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_Summer.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_Summer.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_Fall.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_Fall.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2021_Winter.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2021_Winter.shp, skipping
# Processing file: SHP_BBS_DO_mgl_2022_Spring.shp
# Not enough data for IDW interpolation in SHP_BBS_DO_mgl_2022_Spring.shp, skipping
# Processing file: SHP_GTM_Turb_ntu_2015_Fall.shp
# Calculated RMSE: 2.112465132659591, ME: -0.86212375111 for file: SHP_GTM_Turb_ntu_2015_Fall.shp
# File SHP_GTM_Turb_ntu_2015_Fall.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2015_Winter.shp
# Calculated RMSE: 1.5253687860661607, ME: 0.09298952034999997 for file: SHP_GTM_Turb_ntu_2015_Winter.shp
# File SHP_GTM_Turb_ntu_2015_Winter.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_Spring.shp
# Calculated RMSE: 3.191497119799532, ME: -0.8730673172849994 for file: SHP_GTM_Turb_ntu_2016_Spring.shp
# File SHP_GTM_Turb_ntu_2016_Spring.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_Summer.shp
# Calculated RMSE: 6.279572857906122, ME: -1.8006361907725004 for file: SHP_GTM_Turb_ntu_2016_Summer.shp
# File SHP_GTM_Turb_ntu_2016_Summer.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_Fall.shp
# Calculated RMSE: 2.838286534930408, ME: -0.5775013993825002 for file: SHP_GTM_Turb_ntu_2016_Fall.shp
# File SHP_GTM_Turb_ntu_2016_Fall.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2016_Winter.shp
# Calculated RMSE: 1.9303299101662708, ME: -0.00310662904499992 for file: SHP_GTM_Turb_ntu_2016_Winter.shp
# File SHP_GTM_Turb_ntu_2016_Winter.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2017_Spring.shp
# Calculated RMSE: 2.505664251576377, ME: -0.3973658601249994 for file: SHP_GTM_Turb_ntu_2017_Spring.shp
# File SHP_GTM_Turb_ntu_2017_Spring.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_Turb_ntu_2017_Summer.shp
# Calculated RMSE: 3.0215139827040085, ME: -0.6888530012249996 for file: SHP_GTM_Turb_ntu_2017_Summer.shp
# File SHP_GTM_Turb_ntu_2017_Summer.shp has completed 4 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2016_Summer.shp
# Calculated RMSE: 4.921656494907445, ME: -0.03595843262999976 for file: SHP_EB_Turb_ntu_2016_Summer.shp
# File SHP_EB_Turb_ntu_2016_Summer.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2016_Fall.shp
# Not enough data for IDW interpolation in SHP_EB_Turb_ntu_2016_Fall.shp, skipping
# Processing file: SHP_EB_Turb_ntu_2016_Winter.shp
# Calculated RMSE: 3.0532242051233562, ME: -0.21477999015000027 for file: SHP_EB_Turb_ntu_2016_Winter.shp
# File SHP_EB_Turb_ntu_2016_Winter.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_Spring.shp
# Calculated RMSE: 0.9406323345530938, ME: -0.46951154429999953 for file: SHP_EB_Turb_ntu_2017_Spring.shp
# File SHP_EB_Turb_ntu_2017_Spring.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_Summer.shp
# Calculated RMSE: 4.148144666939839, ME: 0.7744364310349998 for file: SHP_EB_Turb_ntu_2017_Summer.shp
# File SHP_EB_Turb_ntu_2017_Summer.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_Fall.shp
# Calculated RMSE: 1.6206023849533129, ME: 0.15993290356999967 for file: SHP_EB_Turb_ntu_2017_Fall.shp
# File SHP_EB_Turb_ntu_2017_Fall.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2017_Winter.shp
# Calculated RMSE: 5.3739480829156205, ME: -0.28703859684999955 for file: SHP_EB_Turb_ntu_2017_Winter.shp
# File SHP_EB_Turb_ntu_2017_Winter.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_Turb_ntu_2018_Spring.shp
# Calculated RMSE: 0.882785621258396, ME: -0.05817842659499961 for file: SHP_EB_Turb_ntu_2018_Spring.shp
# File SHP_EB_Turb_ntu_2018_Spring.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Turb_ntu_2016_Summer.shp
# Calculated RMSE: 7.014376039235005, ME: 2.6046499979059945e-07 for file: SHP_CH_Turb_ntu_2016_Summer.shp
# File SHP_CH_Turb_ntu_2016_Summer.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Turb_ntu_2016_Fall.shp
# Calculated RMSE: 1.1152637453300007, ME: -3.667000014750954e-08 for file: SHP_CH_Turb_ntu_2016_Fall.shp
# File SHP_CH_Turb_ntu_2016_Fall.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Turb_ntu_2016_Winter.shp
# Calculated RMSE: 2.3238449819050184, ME: -2.8399499996112354e-07 for file: SHP_CH_Turb_ntu_2016_Winter.shp
# File SHP_CH_Turb_ntu_2016_Winter.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Turb_ntu_2017_Spring.shp
# Calculated RMSE: 4.6675676550445, ME: -9.291549973866609e-08 for file: SHP_CH_Turb_ntu_2017_Spring.shp
# File SHP_CH_Turb_ntu_2017_Spring.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Turb_ntu_2017_Summer.shp
# Calculated RMSE: 3.2593874360800004, ME: 4.6780000317880877e-08 for file: SHP_CH_Turb_ntu_2017_Summer.shp
# File SHP_CH_Turb_ntu_2017_Summer.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Turb_ntu_2017_Fall.shp
# Calculated RMSE: 2.8910375665400005, ME: -5.471999964257179e-08 for file: SHP_CH_Turb_ntu_2017_Fall.shp
# File SHP_CH_Turb_ntu_2017_Fall.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Turb_ntu_2017_Winter.shp
# Calculated RMSE: 0.0990953777300143, ME: 5.343999998075333e-08 for file: SHP_CH_Turb_ntu_2017_Winter.shp
# File SHP_CH_Turb_ntu_2017_Winter.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_Turb_ntu_2018_Spring.shp
# Calculated RMSE: 0.8244485885599999, ME: -9.700000136447784e-09 for file: SHP_CH_Turb_ntu_2018_Spring.shp
# File SHP_CH_Turb_ntu_2018_Spring.shp has completed 3 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2021_Summer.shp
# Calculated RMSE: 0.6396658677295635, ME: -0.3184987023899999 for file: SHP_BB_Turb_ntu_2021_Summer.shp
# File SHP_BB_Turb_ntu_2021_Summer.shp has completed 4 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2021_Fall.shp
# Calculated RMSE: 0.690207853993302, ME: -0.18122581459000017 for file: SHP_BB_Turb_ntu_2021_Fall.shp
# File SHP_BB_Turb_ntu_2021_Fall.shp has completed 4 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2021_Winter.shp
# Calculated RMSE: 0.7319949631196404, ME: 0.32838154988 for file: SHP_BB_Turb_ntu_2021_Winter.shp
# File SHP_BB_Turb_ntu_2021_Winter.shp has completed 4 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_Spring.shp
# Calculated RMSE: 1.4421588160578924, ME: -0.49363166171799994 for file: SHP_BB_Turb_ntu_2022_Spring.shp
# File SHP_BB_Turb_ntu_2022_Spring.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_Summer.shp
# Calculated RMSE: 1.3215946598725727, ME: -0.4652142413080001 for file: SHP_BB_Turb_ntu_2022_Summer.shp
# File SHP_BB_Turb_ntu_2022_Summer.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_Fall.shp
# Calculated RMSE: 1.9653361279844592, ME: -0.43515269957599967 for file: SHP_BB_Turb_ntu_2022_Fall.shp
# File SHP_BB_Turb_ntu_2022_Fall.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_Turb_ntu_2022_Winter.shp
# Calculated RMSE: 0.8445095279700374, ME: -0.28078485516400004 for file: SHP_BB_Turb_ntu_2022_Winter.shp
# File SHP_BB_Turb_ntu_2022_Winter.shp has completed 6 cross-validation iterations.
# Shapefile not found for: SHP_BB_Turb_ntu_2023_Spring.shp
# Processing file: SHP_BBS_Turb_ntu_2020_Summer.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2020_Summer.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2020_Fall.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2020_Fall.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2020_Winter.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2020_Winter.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_Spring.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_Spring.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_Summer.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_Summer.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_Fall.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_Fall.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2021_Winter.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2021_Winter.shp, skipping
# Processing file: SHP_BBS_Turb_ntu_2022_Spring.shp
# Not enough data for IDW interpolation in SHP_BBS_Turb_ntu_2022_Spring.shp, skipping
# Processing file: SHP_GTM_T_c_2015_Fall.shp
# Calculated RMSE: 0.1184992988207203, ME: 0.01004952012499949 for file: SHP_GTM_T_c_2015_Fall.shp
# File SHP_GTM_T_c_2015_Fall.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2015_Winter.shp
# Calculated RMSE: 0.39812785870253947, ME: -0.051947893949999546 for file: SHP_GTM_T_c_2015_Winter.shp
# File SHP_GTM_T_c_2015_Winter.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_Spring.shp
# Calculated RMSE: 1.2277537915822614, ME: -0.25718384780000036 for file: SHP_GTM_T_c_2016_Spring.shp
# File SHP_GTM_T_c_2016_Spring.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_Summer.shp
# Calculated RMSE: 1.2288001017818657, ME: -0.26581249012499963 for file: SHP_GTM_T_c_2016_Summer.shp
# File SHP_GTM_T_c_2016_Summer.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_Fall.shp
# Calculated RMSE: 0.19498121128567505, ME: 0.046754678850000175 for file: SHP_GTM_T_c_2016_Fall.shp
# File SHP_GTM_T_c_2016_Fall.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2016_Winter.shp
# Calculated RMSE: 0.22570789616498338, ME: -0.03450894184999953 for file: SHP_GTM_T_c_2016_Winter.shp
# File SHP_GTM_T_c_2016_Winter.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2017_Spring.shp
# Calculated RMSE: 0.9817413670430315, ME: -0.19197461227500057 for file: SHP_GTM_T_c_2017_Spring.shp
# File SHP_GTM_T_c_2017_Spring.shp has completed 4 cross-validation iterations.
# Processing file: SHP_GTM_T_c_2017_Summer.shp
# Calculated RMSE: 1.4001428086402676, ME: -0.39365309082499866 for file: SHP_GTM_T_c_2017_Summer.shp
# File SHP_GTM_T_c_2017_Summer.shp has completed 4 cross-validation iterations.
# Processing file: SHP_EB_T_c_2016_Summer.shp
# Calculated RMSE: 0.15390155481850584, ME: 0.0006579615500008629 for file: SHP_EB_T_c_2016_Summer.shp
# File SHP_EB_T_c_2016_Summer.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_T_c_2016_Fall.shp
# Calculated RMSE: 0.7972028980168099, ME: 0.037096592650000204 for file: SHP_EB_T_c_2016_Fall.shp
# File SHP_EB_T_c_2016_Fall.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_T_c_2016_Winter.shp
# Calculated RMSE: 0.20514874635984023, ME: -0.024645045400001564 for file: SHP_EB_T_c_2016_Winter.shp
# File SHP_EB_T_c_2016_Winter.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_T_c_2017_Spring.shp
# Calculated RMSE: 0.17678580821786358, ME: -0.007655748199999479 for file: SHP_EB_T_c_2017_Spring.shp
# File SHP_EB_T_c_2017_Spring.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_T_c_2017_Summer.shp
# Calculated RMSE: 0.3019275525808608, ME: 0.0006456464499997594 for file: SHP_EB_T_c_2017_Summer.shp
# File SHP_EB_T_c_2017_Summer.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_T_c_2017_Fall.shp
# Calculated RMSE: 0.5192233764980589, ME: 0.02760482510000095 for file: SHP_EB_T_c_2017_Fall.shp
# File SHP_EB_T_c_2017_Fall.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_T_c_2017_Winter.shp
# Calculated RMSE: 0.2595378625291485, ME: -0.0209349569999997 for file: SHP_EB_T_c_2017_Winter.shp
# File SHP_EB_T_c_2017_Winter.shp has completed 3 cross-validation iterations.
# Processing file: SHP_EB_T_c_2018_Spring.shp
# Calculated RMSE: 1.1566019254200819, ME: 0.016548170750001034 for file: SHP_EB_T_c_2018_Spring.shp
# File SHP_EB_T_c_2018_Spring.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_T_c_2016_Summer.shp
# Calculated RMSE: 0.20421420120027792, ME: -3.3629999940387734e-07 for file: SHP_CH_T_c_2016_Summer.shp
# File SHP_CH_T_c_2016_Summer.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_T_c_2016_Fall.shp
# Calculated RMSE: 0.003570446688730135, ME: 7.960000001361323e-07 for file: SHP_CH_T_c_2016_Fall.shp
# File SHP_CH_T_c_2016_Fall.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_T_c_2016_Winter.shp
# Calculated RMSE: 0.018736010261500447, ME: -6.564500001360329e-07 for file: SHP_CH_T_c_2016_Winter.shp
# File SHP_CH_T_c_2016_Winter.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_T_c_2017_Spring.shp
# Calculated RMSE: 0.16970815355181781, ME: 7.852499983584948e-07 for file: SHP_CH_T_c_2017_Spring.shp
# File SHP_CH_T_c_2017_Spring.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_T_c_2017_Summer.shp
# Calculated RMSE: 0.33710148735002976, ME: -1.3955000000009932e-07 for file: SHP_CH_T_c_2017_Summer.shp
# File SHP_CH_T_c_2017_Summer.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_T_c_2017_Fall.shp
# Calculated RMSE: 0.20217572385065918, ME: 5.159499991691519e-07 for file: SHP_CH_T_c_2017_Fall.shp
# File SHP_CH_T_c_2017_Fall.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_T_c_2017_Winter.shp
# Calculated RMSE: 0.0987457088038875, ME: 8.762999996747567e-07 for file: SHP_CH_T_c_2017_Winter.shp
# File SHP_CH_T_c_2017_Winter.shp has completed 3 cross-validation iterations.
# Processing file: SHP_CH_T_c_2018_Spring.shp
# Calculated RMSE: 1.1667998867000007, ME: -4.5700000228521276e-08 for file: SHP_CH_T_c_2018_Spring.shp
# File SHP_CH_T_c_2018_Spring.shp has completed 3 cross-validation iterations.
# Processing file: SHP_BB_T_c_2021_Summer.shp
# Calculated RMSE: 0.6614516845151206, ME: 0.3339967829999999 for file: SHP_BB_T_c_2021_Summer.shp
# File SHP_BB_T_c_2021_Summer.shp has completed 4 cross-validation iterations.
# Processing file: SHP_BB_T_c_2021_Fall.shp
# Calculated RMSE: 0.1044702998335296, ME: -0.04311603216666645 for file: SHP_BB_T_c_2021_Fall.shp
# File SHP_BB_T_c_2021_Fall.shp has completed 4 cross-validation iterations.
# Processing file: SHP_BB_T_c_2021_Winter.shp
# Calculated RMSE: 0.3171840710255494, ME: -0.15345491153333177 for file: SHP_BB_T_c_2021_Winter.shp
# File SHP_BB_T_c_2021_Winter.shp has completed 4 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_Spring.shp
# Calculated RMSE: 0.5559297807003603, ME: 0.08896745977999956 for file: SHP_BB_T_c_2022_Spring.shp
# File SHP_BB_T_c_2022_Spring.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_Summer.shp
# Calculated RMSE: 0.5394389299962794, ME: 0.2046069261599996 for file: SHP_BB_T_c_2022_Summer.shp
# File SHP_BB_T_c_2022_Summer.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_Fall.shp
# Calculated RMSE: 0.19762106108741306, ME: 0.0602272940400006 for file: SHP_BB_T_c_2022_Fall.shp
# File SHP_BB_T_c_2022_Fall.shp has completed 6 cross-validation iterations.
# Processing file: SHP_BB_T_c_2022_Winter.shp
# Calculated RMSE: 0.6939649270718021, ME: -0.2707868320399996 for file: SHP_BB_T_c_2022_Winter.shp
# File SHP_BB_T_c_2022_Winter.shp has completed 6 cross-validation iterations.
# Shapefile not found for: SHP_BB_T_c_2023_Spring.shp
# Processing file: SHP_BBS_T_c_2020_Summer.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2020_Summer.shp, skipping
# Processing file: SHP_BBS_T_c_2020_Fall.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2020_Fall.shp, skipping
# Processing file: SHP_BBS_T_c_2020_Winter.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2020_Winter.shp, skipping
# Processing file: SHP_BBS_T_c_2021_Spring.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_Spring.shp, skipping
# Processing file: SHP_BBS_T_c_2021_Summer.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_Summer.shp, skipping
# Processing file: SHP_BBS_T_c_2021_Fall.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_Fall.shp, skipping
# Processing file: SHP_BBS_T_c_2021_Winter.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2021_Winter.shp, skipping
# Processing file: SHP_BBS_T_c_2022_Spring.shp
# Not enough data for IDW interpolation in SHP_BBS_T_c_2022_Spring.shp, skipping
