# %%
import pandas as pd

# Define the path to your pipe-separated file
file_path = '../GIS_Data/OEAT_Continuous_WQ-2024-Feb-21.txt'  # Change this to the path of your file

# Read the pipe-separated file
df = pd.read_csv(file_path, sep='|')

# Define the path for the output CSV file
csv_file_path = '../GIS_Data/OEAT_Continuous_WQ-2024-Feb-21.csv'  # Change this to your desired output path

# Save the DataFrame as a CSV file
df.to_csv(csv_file_path, index=False)

# %%
df.head()
# Out:
#    RowID  ProgramID ParameterName ParameterUnits ProgramLocationID  \
# 0      1         69  Secchi Depth              m     CKM2017100405
# 1      2         69  Secchi Depth              m     CKM2017080401
# 2      3         69  Secchi Depth              m     CKM2017060703
# 3      4         69  Secchi Depth              m     CKM2017060202
# 4      5         69  Secchi Depth              m     CKM2017110804
#
#   ActivityType               SampleDate  Year  Month RelativeDepth  \
# 0        Field  2017-10-06 00:00:00.000  2017     10           NaN
# 1        Field  2017-08-08 00:00:00.000  2017      8       Surface
# 2        Field  2017-06-19 00:00:00.000  2017      6       Surface
# 3        Field  2017-06-06 00:00:00.000  2017      6       Surface
# 4        Field  2017-11-14 00:00:00.000  2017     11       Surface
#
#    ResultValue  Latitude_DD  Longitude_DD  \
# 0          0.3    29.322100    -83.129866
# 1          0.6    29.145966    -83.072250
# ...

# %%
import pandas as pd

# Define the path to your pipe-separated file
file_path = 'E:\Projects\SEACAR_WQ_2024\GIS_Data/OEAT_Discrete_WQ-2024-May-06.txt'  # Change this to the path of your file

# Read the pipe-separated file
df_dis = pd.read_csv(file_path, sep='|')

# Define the path for the output CSV file
csv_file_path = 'E:\Projects\SEACAR_WQ_2024\GIS_Data/OEAT_Discrete_WQ-2024-May-06.csv'  # Change this to your desired output path

# Save the DataFrame as a CSV file
df_dis.to_csv(csv_file_path, index=False)
